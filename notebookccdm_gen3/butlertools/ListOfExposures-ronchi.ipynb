# %% [markdown]
# # List of Exposures with Ronchi
#
#
# - work with Weakly_2022_09
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/03/22
#
# - update : 2022/05/05

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/atmospec 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_09/conda/envs/lsst-scipipe-2.0.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g64fc59b30a+e1dba0a6f6 	w_latest w_2022_09 current setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num', 'type', 'target','filter','zenith_angle','expos','ra','dec','skyangle'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.exposure_time,info.tracking_ra, info.tracking_dec, info.sky_angle]
    
    if count < 0:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 0      2021021600208  AT_O_20210216_000208  20210216      208  science
# 1      2021021600163  AT_O_20210216_000163  20210216      163  science
# 2      2021021600070  AT_O_20210216_000070  20210216       70     bias
# 3      2021021600173  AT_O_20210216_000173  20210216      173  science
# 4      2021021600001  AT_O_20210216_000001  20210216        1     bias
# ...              ...                   ...       ...      ...      ...
# 15211  2022050200025  AT_O_20220502_000025  20220502       25     dark
# 15212  2022050200026  AT_O_20220502_000026  20220502       26     flat
# 15213  2022050200027  AT_O_20220502_000027  20220502       27     flat
# 15214  2022050200028  AT_O_20220502_000028  20220502       28  engtest
# 15215  2022050200029  AT_O_20220502_000029  20220502       29  engtest
#
#                    target           filter zenith_angle  expos          ra  \
# 0                HD 50896      empty~empty    24.314073    2.0  103.384002
# 1                HD 50896      RG610~empty    14.580611    3.0  103.404029
# 2             azel_target      empty~empty         None    0.0        None
# 3                HD 50896      RG610~empty      8.82931    2.0  103.395986
# 4             azel_target      empty~empty         None    0.0        None
# ...                   ...              ...          ...    ...         ...
# 15211  FlatField position  SDSSg~holo4_003         None    2.0        None
# 15212  FlatField position      SDSSi~empty    51.000067    3.0        None
# 15213  FlatField position      SDSSi~empty    51.000067    3.0        None
# 15214           slew_icrs  SDSSr~holo4_003    14.840243    2.0  160.345861
# 15215           slew_icrs      empty~empty     9.929399    2.0  158.499978
#
#              dec    skyangle
# 0     -23.973448      -180.0
# 1      -23.92939 -208.621712
# 2           None        None
# 3     -23.927038 -208.621712
# 4           None        None
# ...          ...         ...
# 15211       None        None
# 15212       None        None
# 15213       None        None
# 15214  -15.32839    0.000144
# 15215 -20.127628    0.000015
#
# [15216 rows x 12 columns]

# %% [markdown]
# ## Selection of science

# %%
df_science = df_exposure[df_exposure.type == 'science']

# %%
df_science.sort_values(by="id",ascending=True,inplace=True)
# Out:
# /tmp/ipykernel_3937/3986782663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_science.sort_values(by="id",ascending=True,inplace=True)

# %%
df_science.tail(60)
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 15099  2022050300851  AT_O_20220503_000851  20220503      851  science
# 15100  2022050300852  AT_O_20220503_000852  20220503      852  science
# 15101  2022050300853  AT_O_20220503_000853  20220503      853  science
# 15102  2022050300854  AT_O_20220503_000854  20220503      854  science
# 15103  2022050300855  AT_O_20220503_000855  20220503      855  science
# 15104  2022050300856  AT_O_20220503_000856  20220503      856  science
# 15105  2022050300857  AT_O_20220503_000857  20220503      857  science
# 15106  2022050300858  AT_O_20220503_000858  20220503      858  science
# 15107  2022050300859  AT_O_20220503_000859  20220503      859  science
# 15108  2022050300860  AT_O_20220503_000860  20220503      860  science
# 15109  2022050300861  AT_O_20220503_000861  20220503      861  science
# 15110  2022050300862  AT_O_20220503_000862  20220503      862  science
# 15111  2022050300863  AT_O_20220503_000863  20220503      863  science
# 15112  2022050300864  AT_O_20220503_000864  20220503      864  science
# 15113  2022050300865  AT_O_20220503_000865  20220503      865  science
# 15114  2022050300866  AT_O_20220503_000866  20220503      866  science
# 15115  2022050300867  AT_O_20220503_000867  20220503      867  science
# 15116  2022050300868  AT_O_20220503_000868  20220503      868  science
# 15119  2022050300871  AT_O_20220503_000871  20220503      871  science
# 15120  2022050300872  AT_O_20220503_000872  20220503      872  science
# 15121  2022050300873  AT_O_20220503_000873  20220503      873  science
# 15122  2022050300874  AT_O_20220503_000874  20220503      874  science
# 15123  2022050300875  AT_O_20220503_000875  20220503      875  science
# 15124  2022050300876  AT_O_20220503_000876  20220503      876  science
# 15125  2022050300877  AT_O_20220503_000877  20220503      877  science
# 15126  2022050300878  AT_O_20220503_000878  20220503      878  science
# 15127  2022050300879  AT_O_20220503_000879  20220503      879  science
# 15128  2022050300880  AT_O_20220503_000880  20220503      880  science
# 15129  2022050300881  AT_O_20220503_000881  20220503      881  science
# 15130  2022050300882  AT_O_20220503_000882  20220503      882  science
# 15114  LATISS_E6A_00000041  SDSSg~empty    30.994219   30.0  220.821434
# 15115  LATISS_E6A_00000041  SDSSi~empty    31.109668   30.0    220.8215
# 15116  LATISS_E6A_00000041  SDSSi~empty    31.199998   30.0  220.821355
# 15119            HD 125566  SDSSg~empty    35.190269    5.0   215.33233
# 15120  LATISS_E6A_00000056  SDSSr~empty    31.389867   30.0  221.415786
# 15121  LATISS_E6A_00000056  SDSSr~empty    31.483028   30.0  221.415532
# 15122  LATISS_E6A_00000056  SDSSg~empty    31.595757   30.0  221.415677
# 15123  LATISS_E6A_00000056  SDSSg~empty    31.688952   30.0  221.415626
# 15124  LATISS_E6A_00000062  SDSSg~empty    32.150271   30.0  220.943242
# 15125  LATISS_E6A_00000062  SDSSg~empty     32.24362   30.0  220.942722
# 15126  LATISS_E6A_00000062  SDSSi~empty    32.359471   30.0  220.942896
# 15127  LATISS_E6A_00000062  SDSSi~empty    32.450308   30.0  220.942567
# 15128  LATISS_E6A_00000062  SDSSr~empty    32.566623   30.0  220.942362
# 15129  LATISS_E6A_00000062  SDSSr~empty    32.659923   30.0  220.942722
# 15130  LATISS_E6A_00000042  SDSSr~empty    32.722007   30.0  220.954816
# 15131  LATISS_E6A_00000042  SDSSr~empty    32.813352   30.0  220.954687
# 15132  LATISS_E6A_00000042  SDSSg~empty    32.930313   30.0  220.954748
# 15133  LATISS_E6A_00000042  SDSSg~empty    33.024545   30.0  220.954761
# 15134  LATISS_E6A_00000042  SDSSi~empty    33.139047   30.0   220.95447
# 15135  LATISS_E6A_00000042  SDSSi~empty     33.23319   30.0  220.954763
# 15136  LATISS_E6A_00000063  SDSSi~empty    33.310555   30.0  221.076767
# 15137  LATISS_E6A_00000063  SDSSi~empty    33.404692   30.0  221.076223
# 15138  LATISS_E6A_00000063  SDSSg~empty    33.518727   30.0    221.0762
# 15139  LATISS_E6A_00000063  SDSSg~empty     33.61284   30.0  221.076211
# 15140  LATISS_E6A_00000063  SDSSr~empty     33.72988   30.0  221.076169
# 15141  LATISS_E6A_00000063  SDSSr~empty    33.820722   30.0  221.076925
# 15142  LATISS_E6A_00000051  SDSSr~empty    34.145482   30.0  220.749286
# 15143  LATISS_E6A_00000051  SDSSr~empty    34.237479   30.0  220.748968
# 15144  LATISS_E6A_00000051  SDSSg~empty    34.355379   30.0  220.748625
# 15145  LATISS_E6A_00000051  SDSSg~empty    34.450264   30.0  220.748464
# 15146  LATISS_E6A_00000051  SDSSi~empty      34.5649   30.0  220.748865
# 15147  LATISS_E6A_00000051  SDSSi~empty    34.660061   30.0  220.748437
# 15148  LATISS_E6A_00000052  SDSSi~empty    34.685751   30.0  220.882616
# 15149  LATISS_E6A_00000052  SDSSi~empty    34.777866   30.0  220.882005
# 15150  LATISS_E6A_00000052  SDSSg~empty    34.895792   30.0  220.882084
# 15151  LATISS_E6A_00000052  SDSSg~empty    34.988028   30.0  220.881931
# 15152  LATISS_E6A_00000052  SDSSr~empty    35.105764   30.0  220.882425
# 15153  LATISS_E6A_00000052  SDSSr~empty    35.201323   30.0  220.881801
# 15154  LATISS_E6A_00000064  SDSSr~empty    35.110351   30.0  221.210746
# 15155  LATISS_E6A_00000064  SDSSr~empty    35.205217   30.0  221.210388
# 15156  LATISS_E6A_00000064  SDSSg~empty    35.323493   30.0  221.209934
# 15157  LATISS_E6A_00000064  SDSSg~empty    35.415731   30.0  221.209738
# 15158  LATISS_E6A_00000064  SDSSi~empty    35.533796   30.0  221.209729
# 15159  LATISS_E6A_00000064  SDSSi~empty    35.625912   30.0  221.209841
# 15165            HD 134992  SDSSr~empty    30.769044    5.0  228.561535
#
#              dec    skyangle
# 15099 -45.249325  359.997829
# 15100 -45.247902    0.000545
# 15101 -45.247874    0.000468
# 15102 -45.248013    0.000735
# 15103 -45.247878    0.000584
# 15104 -45.247866    0.000619
# 15105  -45.24958  359.997508
# 15106 -45.247874    0.000277
# 15107 -45.247902    0.000607
# 15108 -45.247908    0.000578
# 15109 -45.247882    0.000834
# 15110 -45.247903    0.000631
# 15111  -45.15421    0.000657
# 15112 -45.154137    0.000574
# 15113 -45.154129    0.000668
# 15114 -45.154183    0.000694
# 15115 -45.154166    0.000525
# 15116 -45.154207    0.000696
# 15119  -43.48849   26.220027
# 15120 -45.247921    0.000533
# 15121 -45.247858    0.000605
# 15122  -45.24786  359.999798
# 15123 -45.247885    0.000349
# 15124 -45.342783  359.998357
# 15125 -45.341653    0.000418
# 15126 -45.341548    0.000508
# 15127 -45.341609    0.000966
# 15128 -45.341668    0.001222
# 15129 -45.341599    0.007818
# 15130 -45.154187    0.000296
# 15131 -45.154169     0.00045
# 15132 -45.154147    0.001274
# 15133  -45.15417    0.000362
# 15134 -45.154197    0.000916
# 15135 -45.154155  359.999752
# 15136 -45.342629  359.999232
# 15137 -45.341617    0.000083
# 15138 -45.341605  359.999846
# 15139 -45.341603     0.00107
# 15140 -45.341628    0.007646
# 15141 -45.341559  359.999891
# 15142 -45.247903  359.999332
# 15143 -45.247848  359.999874
# 15144  -45.24782  359.999936
# 15145 -45.247889    0.001265
# 15146 -45.247853    0.000195
# 15147 -45.247878    0.001507
# 15148 -45.249555  359.998189
# 15149 -45.247843  359.999816
# 15150 -45.247842    0.000091
# 15151  -45.24786    0.000703
# 15152 -45.247775    0.000337
# 15153 -45.247925    0.000041
# 15154 -45.342967  359.998341
# 15155 -45.341553  359.999803
# 15156 -45.341611     0.00076
# 15157 -45.341602    0.000826
# 15158 -45.341599    0.008172
# 15159 -45.341632    0.007134
# 15165 -40.539717   20.423332

# %% [markdown]
# ## Selection of date

# %% [markdown]
# 2021-02-16  2021-02-18  2021-06-08  2021-06-10  2021-07-07  2021-09-07  2021-09-09  2021-10-06  2021-11-02  2021-11-04  2022-02-16  2022-03-15  2022-03-17  20220502
# 2021-02-17  2021-03-11  2021-06-09  2021-07-06  2021-07-08  2021-09-08  2021-10-05  2021-10-07  2021-11-03  2022-02-15  2022-02-17  2022-03-16  2022-03-18  20220503

# %%
date_sel = 20220503

# %%
df_science_selected = df_science[df_science.day_obs == date_sel ]

# %%
len(df_science_selected)
# Out:
# 614

# %% [markdown]
# # List of filters

# %%
list_of_filters = df_science_selected['filter'].unique()
list_of_filters
# Out:
# array(['SDSSr~empty', 'empty~empty', 'SDSSg~empty', 'SDSSi~empty',
#        'empty~ronchi170lpmm', 'empty~holo4_003'], dtype=object)

# %%
selected_filters = []
for filt in list_of_filters:
    #flag_sel = (filt.find('holo4') != -1) or (filt.find('ronchi90lpmm') != -1) or (filt.find('ronchi170lpmm') != -1)
    #flag_sel = (filt.find('holo4') != -1) 
    flag_sel = (filt.find('ronchi170') != -1) 
    if flag_sel:
        selected_filters.append(filt) 
selected_filters = np.array(selected_filters)
selected_filters
# Out:
# array(['empty~ronchi170lpmm'], dtype='<U19')

# %% [markdown]
# ## Selection of filter

# %%
#idx_sel_filt = 0
#selected_filter = selected_filters[0]
#selected_filter

# %% [markdown]
# ## Final selection of exposure

# %%
pd.set_option('display.max_rows', None)

# %%
all_def_science_selected_final = []

for selected_filter in selected_filters:

    print(selected_filter)
    df_science_selected_final = df_science_selected[df_science_selected["filter"] ==  selected_filter]
    
    #print(df_science_selected_final)
    all_def_science_selected_final.append(df_science_selected_final.copy())
    
    df = df_science_selected_final
    df_sel = df[['day_obs', 'seq_num']]
    
    
    NN = len(df)
    
    if NN>0:
        # build the line
        
        df_sel['line'] = df_sel.apply(lambda row: str(row['day_obs'])  + " " + str(row['seq_num']),axis = 1)
    
    
         # prepare output
        filename_out = "visitdispersers_"+ str(date_sel) + "_filt_" + selected_filter.replace('~','-') + ".list"
        print(filename_out)
        
        df_out = df_sel[["line"]]
        df_out.to_csv(filename_out, index=False, header=None)
# Out:
# empty~ronchi170lpmm
# visitdispersers_20220503_filt_empty-ronchi170lpmm.list
# /tmp/ipykernel_3937/3368292521.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sel['line'] = df_sel.apply(lambda row: str(row['day_obs'])  + " " + str(row['seq_num']),axis = 1)

# %%
len(all_def_science_selected_final)
# Out:
# 1

# %%
all_def_science_selected_final[0]
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 14797  2022050300549  AT_O_20220503_000549  20220503      549  science
# 14798  2022050300550  AT_O_20220503_000550  20220503      550  science
# 14799  2022050300551  AT_O_20220503_000551  20220503      551  science
# 14800  2022050300552  AT_O_20220503_000552  20220503      552  science
# 14801  2022050300553  AT_O_20220503_000553  20220503      553  science
# 14804  2022050300556  AT_O_20220503_000556  20220503      556  science
# 14805  2022050300557  AT_O_20220503_000557  20220503      557  science
# 14806  2022050300558  AT_O_20220503_000558  20220503      558  science
# 14807  2022050300559  AT_O_20220503_000559  20220503      559  science
# 14808  2022050300560  AT_O_20220503_000560  20220503      560  science
# 14811  2022050300563  AT_O_20220503_000563  20220503      563  science
# 14812  2022050300564  AT_O_20220503_000564  20220503      564  science
# 14813  2022050300565  AT_O_20220503_000565  20220503      565  science
# 14814  2022050300566  AT_O_20220503_000566  20220503      566  science
# 14815  2022050300567  AT_O_20220503_000567  20220503      567  science
# 14824  2022050300576  AT_O_20220503_000576  20220503      576  science
# 14825  2022050300577  AT_O_20220503_000577  20220503      577  science
# 14831  spec:HD111980  empty~ronchi170lpmm    18.113476    2.0  193.312923
# 14832  spec:HD111980  empty~ronchi170lpmm     18.20228    2.0  193.277848
# 14833  spec:HD111980  empty~ronchi170lpmm    18.263772    2.0  193.277951
# 14834  spec:HD111980  empty~ronchi170lpmm    18.307951   20.0  193.277925
# 14835  spec:HD111980  empty~ronchi170lpmm    18.408165   20.0  193.277897
# 14838  spec:HD111980  empty~ronchi170lpmm     18.74187    2.0  193.312939
# 14839  spec:HD111980  empty~ronchi170lpmm    18.829403    2.0  193.278407
# 14840  spec:HD111980  empty~ronchi170lpmm    18.889357    2.0  193.278358
# 14841  spec:HD111980  empty~ronchi170lpmm    18.934385   20.0   193.27833
# 14842  spec:HD111980  empty~ronchi170lpmm    19.033517   20.0  193.278468
# 14845  spec:HD111980  empty~ronchi170lpmm    19.358959    2.0  193.312853
# 14846  spec:HD111980  empty~ronchi170lpmm     19.44796    2.0  193.278901
# 14847  spec:HD111980  empty~ronchi170lpmm    19.508926    2.0  193.278954
# 14848  spec:HD111980  empty~ronchi170lpmm    19.554791   20.0  193.278975
# 14849  spec:HD111980  empty~ronchi170lpmm    19.655856   20.0  193.278933
# 14852  spec:HD111980  empty~ronchi170lpmm    20.599737    2.0  193.312832
# 14853  spec:HD111980  empty~ronchi170lpmm     20.69431    2.0  193.280144
# 14854  spec:HD111980  empty~ronchi170lpmm    20.757227    2.0  193.280059
# 14855  spec:HD111980  empty~ronchi170lpmm    20.804369   20.0  193.280163
# 14856  spec:HD111980  empty~ronchi170lpmm    20.908477   20.0  193.280055
#
#              dec    skyangle
# 14797 -18.522179  233.814684
# 14798 -18.541601  233.814138
# 14799 -18.541614  233.814222
# 14800 -18.541536  233.814542
# 14801 -18.541526  233.814712
# 14804 -18.522145  230.730129
# 14805 -18.543463  230.729928
# 14806 -18.543406  230.730072
# 14807 -18.543497  230.729876
# 14808  -18.54343  230.729884
# 14811 -18.522264  228.773327
# 14812 -18.544797  228.773491
# 14813 -18.544789  228.773537
# 14814   -18.5449  228.773169
# 14815 -18.544868  228.773217
# 14824 -18.522279  224.485192
# 14825 -18.547212    224.4853
# 14826 -18.547218  224.485353
# 14827 -18.547221  224.485427
# 14828 -18.547143  224.485548
# 14831 -18.522271  222.411435
# 14832 -18.548414  222.411606
# 14833 -18.548495  222.411608
# 14834   -18.5484  222.411749
# 14835 -18.548419  222.411703
# 14838 -18.522146  221.040409
# 14839 -18.549338  221.040502
# 14840 -18.549357  221.040458
# 14841 -18.549379  221.040313
# 14842 -18.549435  221.040305
# 14845 -18.522164  219.782994
# 14846 -18.550147  219.783089
# 14847 -18.550179  219.783019
# 14848 -18.550107  219.783172
# 14849 -18.550108  219.783173
# 14852 -18.522146  217.659489
# 14853 -18.551373  217.659572
# 14854 -18.551429  217.659429
# 14855 -18.551426  217.659465
# 14856 -18.551452  217.659384

# %%
all_def_science_selected_final[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [312], in <cell line: 1>()
# ----> 1 all_def_science_selected_final[1]
#
# IndexError: list index out of range

# %%
all_def_science_selected_final[2]

# %%
all_def_science_selected_final[3]
