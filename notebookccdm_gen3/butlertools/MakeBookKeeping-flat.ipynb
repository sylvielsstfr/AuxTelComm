# %% [markdown]
# # Make bookkeeping For Flats
#
#
# - work with Weakly_2022_09
# - use jupyter kernel LSST
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/06/17

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/atmospec 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_09/conda/envs/lsst-scipipe-2.0.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g64fc59b30a+e1dba0a6f6 	w_latest w_2022_09 current setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %%
collection = "u/dagoret/first_test2"
datasetRefs1 = registry.queryDatasets(datasetType='postISRCCD', collections=collection, where= "instrument='LATISS'")
datasetRefs2 = registry.queryDatasets(datasetType='calexp', collections=collection, where= "instrument='LATISS'")

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs','group_name' ,'seq_num', 'type', 'target','filter','zenith_angle','expos','ra','dec','skyangle','postISRCCD','calexp'])

# %%
df_exposure.astype({"id":str,
                    "obs_id":str,
                    "day_obs": str,
                    "group_name":str,
                    "seq_num":'int32',
                    'type':str,
                    "target":str,
                    "filter":str,
                    "zenith_angle":'float',
                    "expos":'float',
                    "ra":'float',
                    "dec":'float',
                    "skyangle":'float',
                    "postISRCCD":bool,
                    "calexp":bool
                   }              
                  )
# Out:
# Empty DataFrame
# Columns: [id, obs_id, day_obs, group_name, seq_num, type, target, filter, zenith_angle, expos, ra, dec, skyangle, postISRCCD, calexp]
# Index: []

# %%
#df_exposure = pd.DataFrame( {"id":'int64',
#                             "obs_id":str,
#                             "day_obs": str,
#                             "seq_num":'int32',
#                             "type":str,
#                             "target":str,
#                             "filter":str,
#                             "zenith_angle":'float32',
#                             "expos":'float32',
#                             "ra":'float32',
#                             "dec":'float32',
#                             "skyangle":'float32'})

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    flag_postisrccd = False
    flag_calexp = False
    
    #for count, ref in enumerate(datasetRefs1):    
    #    if ref.dataId["exposure"]== info.id:
    #        flag_postisrccd = True
    #        break
    #for count, ref in enumerate(datasetRefs2):    
    #    if ref.dataId["exposure"]== info.id:
    #        flag_calexp = True
    #        break        
            
    
    
    
    df_exposure.loc[count] = [str(info.id), str(info.obs_id), str(info.day_obs), str(info.group_name),int(info.seq_num), str(info.observation_type), str(info.target_name), str(info.physical_filter), info.zenith_angle, \
                             info.exposure_time,info.tracking_ra, info.tracking_dec, info.sky_angle,flag_postisrccd,flag_calexp]
    
    if count < 0:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t group_name:          ",info.group_name)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)

# %%
df_exposure.dtypes
# Out:
# id               object
# obs_id           object
# day_obs          object
# group_name       object
# seq_num           int64
# type             object
# target           object
# filter           object
# zenith_angle     object
# expos           float64
# ra               object
# dec              object
# skyangle         object
# postISRCCD         bool
# calexp             bool
# dtype: object

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs               group_name  \
# 0      2021021600208  AT_O_20210216_000208  20210216  2021-02-17T03:35:45.035
# 1      2021021600163  AT_O_20210216_000163  20210216  2021-02-17T00:50:15.536
# 2      2021021600070  AT_O_20210216_000070  20210216  2021-02-16T20:39:31.417
# 3      2021021600173  AT_O_20210216_000173  20210216  2021-02-17T01:21:19.215
# 4      2021021600001  AT_O_20210216_000001  20210216  2021-02-16T19:50:21.993
# ...              ...                   ...       ...                      ...
# 19070  2022060900838  AT_O_20220609_000838  20220609  2022-06-10T08:52:06.482
# 19071  2022060900839  AT_O_20220609_000839  20220609  2022-06-10T08:52:06.482
# 19072  2022060900840  AT_O_20220609_000840  20220609  2022-06-10T08:52:06.482
# 19073  2022060900841  AT_O_20220609_000841  20220609  2022-06-10T08:52:06.482
# 19074  2022060900842  AT_O_20220609_000842  20220609  2022-06-10T08:52:06.482
#
#        seq_num     type         target              filter zenith_angle  \
# 0          208  science       HD 50896         empty~empty    24.314073
# 1          163  science       HD 50896         RG610~empty    14.580611
# 2           70     bias    azel_target         empty~empty         None
# 3          173  science       HD 50896         RG610~empty      8.82931
# 4            1     bias    azel_target         empty~empty         None
# ...        ...      ...            ...                 ...          ...
# 19070      838  science  spec:HD185975      BG40~holo4_003    57.194196
# 19071      839  science  spec:HD185975  FELH0600~holo4_003    57.196255
# 19072      840  science  spec:HD185975  FELH0600~holo4_003    57.198265
# 19073      841  science  spec:HD185975  FELH0600~holo4_003    57.200339
# 19074      842  science  spec:HD185975  FELH0600~holo4_003    57.202411
#
#        expos          ra        dec    skyangle  postISRCCD  calexp
# 0        2.0  103.384002 -23.973448      -180.0       False   False
# 1        3.0  103.404029  -23.92939 -208.621712       False   False
# 2        0.0        None       None        None       False   False
# 3        2.0  103.395986 -23.927038 -208.621712       False   False
# 4        0.0        None       None        None       False   False
# ...      ...         ...        ...         ...         ...     ...
# 19070   30.0  307.708009  -87.50686   105.70201       False   False
# 19071   30.0  307.707897 -87.506868  105.701922       False   False
# 19072   30.0  307.708264 -87.506854  105.701541       False   False
# 19073   30.0  307.708109 -87.506873  105.701644       False   False
# 19074   30.0  307.708048 -87.506865  105.701559       False   False
#
# [19075 rows x 15 columns]

# %% [markdown]
# ## Selection of science

# %%
df_flat = df_exposure[df_exposure.type == 'flat']

# %%
df_flat.sort_values(by="id",ascending=True,inplace=True)
# Out:
# /tmp/ipykernel_8551/2352331422.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df
# 17593      107  flat  FlatField position  FELH0600~empty    51.060269    8.0
# 17638      153  flat  FlatField position  FELH0600~empty    51.060456    8.0
# 17639      154  flat  FlatField position  FELH0600~empty    51.060456    8.0
# 17640      155  flat  FlatField position  FELH0600~empty    51.060459    8.0
# 17641      156  flat  FlatField position  FELH0600~empty    51.060463    8.0
# 17642      157  flat  FlatField position  FELH0600~empty    51.060465    8.0
# 17643      158  flat  FlatField position  FELH0600~empty    51.060465    8.0
# 17644      159  flat  FlatField position  FELH0600~empty    51.060467    8.0
# 17645      160  flat  FlatField position  FELH0600~empty    51.060469    8.0
# 17646      161  flat  FlatField position  FELH0600~empty    51.060474    8.0
# 17647      162  flat  FlatField position  FELH0600~empty    51.060474    8.0
# 17648      163  flat  FlatField position  FELH0600~empty    51.060475    8.0
# 17649      164  flat  FlatField position  FELH0600~empty    51.060477    8.0
# 17650      165  flat  FlatField position  FELH0600~empty     51.06048    8.0
# 17651      166  flat  FlatField position  FELH0600~empty    51.060481    8.0
# 17652      167  flat  FlatField position  FELH0600~empty    51.060484    8.0
# 18257       25  flat  FlatField position  FELH0600~empty    51.003452    6.0
# 18258       26  flat  FlatField position  FELH0600~empty    51.003451    6.0
# 18259       27  flat  FlatField position  FELH0600~empty    51.003453    6.0
# 18260       28  flat  FlatField position  FELH0600~empty    51.003452    6.0
# 18261       29  flat  FlatField position  FELH0600~empty    51.003455    6.0
# 18262       30  flat  FlatField position  FELH0600~empty    51.003456    6.0
# 18263       31  flat  FlatField position  FELH0600~empty    51.003456    6.0
# 18264       32  flat  FlatField position  FELH0600~empty    51.003458    6.0
# 18265       33  flat  FlatField position  FELH0600~empty    51.003461    6.0
# 18266       34  flat  FlatField position  FELH0600~empty    51.003461    6.0
# 18267       35  flat  FlatField position      BG40~empty    51.003498    6.0
# 18268       36  flat  FlatField position      BG40~empty    51.003493    6.0
# 18269       37  flat  FlatField position      BG40~empty      51.0035    6.0
# 18270       38  flat  FlatField position      BG40~empty      51.0035    6.0
# 18271       39  flat  FlatField position      BG40~empty      51.0035    6.0
# 18272       40  flat  FlatField position      BG40~empty      51.0035    6.0
# 18273       41  flat  FlatField position      BG40~empty    51.003503    6.0
# 18274       42  flat  FlatField position      BG40~empty    51.003503    6.0
# 18275       43  flat  FlatField position      BG40~empty    51.003506    6.0
# 18276       44  flat  FlatField position      BG40~empty    51.003504    6.0
# 18277       45  flat  FlatField position     SDSSg~empty    51.003509    6.0
# 18278       46  flat  FlatField position     SDSSg~empty    51.003513    6.0
# 18279       47  flat  FlatField position     SDSSg~empty    51.003514    6.0
# 18280       48  flat  FlatField position     SDSSg~empty    51.003515    6.0
# 18281       49  flat  FlatField position     SDSSg~empty    51.003517    6.0
# 18282       50  flat  FlatField position     SDSSg~empty    51.003518    6.0
# 18283       51  flat  FlatField position     SDSSg~empty    51.003522    6.0
# 18284       52  flat  FlatField position     SDSSg~empty    51.003518    6.0
# 18285       53  flat  FlatField position     SDSSg~empty     51.00352    6.0
# 18286       54  flat  FlatField position     SDSSg~empty    51.003523    6.0
#
#          ra   dec skyangle  postISRCCD  calexp
# 17579  None  None     None       False   False
# 17580  None  None     None       False   False
# 17581  None  None     None       False   False
# 17582  None  None     None       False   False
# 17583  None  None     None       False   False
# 17584  None  None     None       False   False
# 17585  None  None     None       False   False
# 17586  None  None     None       False   False
# 17587  None  None     None       False   False
# 17588  None  None     None       False   False
# 17589  None  None     None       False   False
# 17590  None  None     None       False   False
# 17591  None  None     None       False   False
# 17592  None  None     None       False   False
# 17593  None  None     None       False   False
# 17638  None  None     None       False   False
# 17639  None  None     None       False   False
# 17640  None  None     None       False   False
# 17641  None  None     None       False   False
# 17642  None  None     None       False   False
# 17643  None  None     None       False   False
# 17644  None  None     None       False   False
# 17645  None  None     None       False   False
# 17646  None  None     None       False   False
# 17647  None  None     None       False   False
# 17648  None  None     None       False   False
# 17649  None  None     None       False   False
# 17650  None  None     None       False   False
# 17651  None  None     None       False   False
# 17652  None  None     None       False   False
# 18257  None  None     None       False   False
# 18258  None  None     None       False   False
# 18259  None  None     None       False   False
# 18260  None  None     None       False   False
# 18261  None  None     None       False   False
# 18262  None  None     None       False   False
# 18263  None  None     None       False   False
# 18264  None  None     None       False   False
# 18265  None  None     None       False   False
# 18266  None  None     None       False   False
# 18267  None  None     None       False   False
# 18268  None  None     None       False   False
# 18269  None  None     None       False   False
# 18270  None  None     None       False   False
# 18271  None  None     None       False   False
# 18272  None  None     None       False   False
# 18273  None  None     None       False   False
# 18274  None  None     None       False   False
# 18275  None  None     None       False   False
# 18276  None  None     None       False   False
# 18277  None  None     None       False   False
# 18278  None  None     None       False   False
# 18279  None  None     None       False   False
# 18280  None  None     None       False   False
# 18281  None  None     None       False   False
# 18282  None  None     None       False   False
# 18283  None  None     None       False   False
# 18284  None  None     None       False   False
# 18285  None  None     None       False   False
# 18286  None  None     None       False   False

# %% [markdown]
# # Generate Book Keeping files

# %%
writer = pd.ExcelWriter('BookKeepingAuxtelFlat_raw.xlsx', engine='xlsxwriter')
current_page = 0

# %%
ListOfDates = df_flat.day_obs.unique()

# %%
ListOfDates
# Out:
# array(['20210216', '20210217', '20210218', '20210311', '20210608',
#        '20210609', '20210707', '20210708', '20210907', '20210908',
#        '20210909', '20211005', '20211006', '20211007', '20211102',
#        '20211104', '20220215', '20220216', '20220217', '20220315',
#        '20220316', '20220317', '20220502', '20220503', '20220504',
#        '20220524', '20220607', '20220608', '20220609'], dtype=object)

# %%
for date_sel in ListOfDates:
    
    # get for that date
    df_flat_selected = df_flat[df_flat.day_obs == date_sel ]
    N = len(df_flat_selected)
    
    list_of_filters = df_flat_selected['filter'].unique()
    
    selected_filters = []
    # Select hologram
    for filt in list_of_filters:
        #flag_sel = (filt.find('holo4') != -1) or (filt.find('ronchi90lpmm') != -1) or (filt.find('ronchi170lpmm') != -1)
        #flag_sel = (filt.find('holo4') != -1) 
        #flag_sel = (filt.find('ronchi170') != -1)
        flag_sel = True
        if flag_sel:
            selected_filters.append(filt) 
    Nfilt = len(selected_filters)
    # sort by filter name
    if(Nfilt>0):
        selected_filters = np.array(selected_filters)
        df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
        df_flat_selected.to_excel(writer, sheet_name=str(date_sel))
# Out:
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)
# /tmp/ipykernel_8551/2896391560.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat_selected.sort_values(by=['filter','id'],ascending=True,inplace=True)

# %%
writer.save()
