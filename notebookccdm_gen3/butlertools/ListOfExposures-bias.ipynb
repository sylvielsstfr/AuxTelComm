# %% [markdown]
# # List of Exposures
#
#
# - work with Weakly_2022_09
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/03/21

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/atmospec 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_09/conda/envs/lsst-scipipe-2.0.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g64fc59b30a+e1dba0a6f6 	w_latest w_2022_09 current setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num', 'type', 'target','filter','zenith_angle','ra','dec','skyangle'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.tracking_ra, info.tracking_dec, info.sky_angle]
    
    if count < 2:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
# Out:
# ----------------------------------------------------- 0 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600208
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000208'
#   exposure_time: 2.0
#   dark_time: 2.33517265319824
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 208
#   group_name: '2021-02-17T03:35:45.035'
#   group_id: 1934625450350000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.384001783548
#   tracking_dec: -23.9734478006315
#   sky_angle: -180.0
#   zenith_angle: 24.314073266185005
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 03:35:45.295446', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 03:35:47.540000', scale='tai', format='iso'))
# 	 id:                   2021021600208
# 	 day_obs:              20210216
# 	 seq_num:              208
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 1 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600163
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000163'
#   exposure_time: 3.0
#   dark_time: 3.3251359462738
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 163
#   group_name: '2021-02-17T00:50:15.536'
#   group_id: 1934526155360000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.404029472597
#   tracking_dec: -23.9293904683577
#   sky_angle: -208.6217120790572
#   zenith_angle: 14.580610783508703
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 00:50:15.703984', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 00:50:18.939000', scale='tai', format='iso'))
# 	 id:                   2021021600163
# 	 day_obs:              20210216
# 	 seq_num:              163
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 2 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600070
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000070'
#   exposure_time: 0.0
#   dark_time: 0.0956339836120605
#   observation_type: 'bias'
#   observation_reason: 'unknown'
#   day_obs: 20210216
#   seq_num: 70
#   group_name: '2021-02-16T20:39:31.417'
#   group_id: 1934375714170000
#   target_name: 'azel_target'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   zenith_angle: None
#   timespan: Timespan(begin=astropy.time.Time('2021-02-16 20:39:31.586841', scale='tai', format='iso'), end=astropy.time.Time('2021-02-16 20:39:31.592000', scale='tai', format='iso'))
# 	 id:                   2021021600070
# 	 day_obs:              20210216
# 	 seq_num:              70
# 	 type-of-observation:  bias
# 	 target:               azel_target
# ----------------------------------------------------- 3 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600173
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000173'
#   exposure_time: 2.0
#   dark_time: 2.32638740539551
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 173
#   group_name: '2021-02-17T01:21:19.215'
#   group_id: 1934544792150000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.395985711384
#   tracking_dec: -23.9270381200679
#   sky_angle: -208.6217120790572
#   zenith_angle: 8.829310478380606
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 01:21:19.482543', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 01:21:21.719000', scale='tai', format='iso'))
# 	 id:                   2021021600173
# 	 day_obs:              20210216
# 	 seq_num:              173
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 4 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600001
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000001'
#   exposure_time: 0.0
#   dark_time: 0.0993173122406006
#   observation_type: 'bias'
#   observation_reason: 'unknown'
#   day_obs: 20210216
#   seq_num: 1
#   group_name: '2021-02-16T19:50:21.993'
#   group_id: 1934346219930000
#   target_name: 'azel_target'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   zenith_angle: None
#   timespan: Timespan(begin=astropy.time.Time('2021-02-16 19:50:22.184100', scale='tai', format='iso'), end=astropy.time.Time('2021-02-16 19:50:22.190000', scale='tai', format='iso'))
# 	 id:                   2021021600001
# 	 day_obs:              20210216
# 	 seq_num:              1
# 	 type-of-observation:  bias
# 	 target:               azel_target

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 0      2021021600208  AT_O_20210216_000208  20210216      208  science
# 1      2021021600163  AT_O_20210216_000163  20210216      163  science
# 2      2021021600070  AT_O_20210216_000070  20210216       70     bias
# 3      2021021600173  AT_O_20210216_000173  20210216      173  science
# 4      2021021600001  AT_O_20210216_000001  20210216        1     bias
# ...              ...                   ...       ...      ...      ...
# 12869  2022031500091  AT_O_20220315_000091  20220315       91     flat
# 12870  2022031500031  AT_O_20220315_000031  20220315       31     bias
# 12871  2022031500109  AT_O_20220315_000109  20220315      109     flat
# 12872  2022031500068  AT_O_20220315_000068  20220315       68     bias
# 12873  2022031500062  AT_O_20220315_000062  20220315       62     bias
#
#                    target       filter zenith_angle          ra        dec  \
# 0                HD 50896  empty~empty    24.314073  103.384002 -23.973448
# 1                HD 50896  RG610~empty    14.580611  103.404029  -23.92939
# 2             azel_target  empty~empty         None        None       None
# 3                HD 50896  RG610~empty      8.82931  103.395986 -23.927038
# 4             azel_target  empty~empty         None        None       None
# ...                   ...          ...          ...         ...        ...
# 12869  FlatField position  SDSSr~empty    51.333026        None       None
# 12870  FlatField position  empty~empty         None        None       None
# 12871  FlatField position  SDSSg~empty    51.333308        None       None
# 12872  FlatField position  empty~empty         None        None       None
# 12873  FlatField position  empty~empty         None        None       None
#
#          skyangle
# 0          -180.0
# 1     -208.621712
# 2            None
# 3     -208.621712
# 4            None
# ...           ...
# 12869        None
# 12870        None
# 12871        None
# 12872        None
# 12873        None
#
# [12874 rows x 11 columns]

# %% [markdown]
# ## Selection of biases

# %%
df_bias = df_exposure[df_exposure.type == 'bias']

# %%
df_bias.sort_values(by="day_obs",ascending=False,inplace=True)
# Out:
# /tmp/ipykernel_20234/1543303844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bias.sort_values(by="day_obs",ascending=False,inplace=True)

# %%
df_bias.tail(50)
# Out:
#                 id                obs_id   day_obs  seq_num  type  \
# 187  2021021600077  AT_O_20210216_000077  20210216       77  bias
# 296  2021021600003  AT_O_20210216_000003  20210216        3  bias
# 264  2021021600033  AT_O_20210216_000033  20210216       33  bias
# 265  2021021600034  AT_O_20210216_000034  20210216       34  bias
# 268  2021021600008  AT_O_20210216_000008  20210216        8  bias
# 270  2021021600024  AT_O_20210216_000024  20210216       24  bias
# 275  2021021600063  AT_O_20210216_000063  20210216       63  bias
# 276  2021021600020  AT_O_20210216_000020  20210216       20  bias
# 285  2021021600038  AT_O_20210216_000038  20210216       38  bias
# 286  2021021600066  AT_O_20210216_000066  20210216       66  bias
# 290  2021021600041  AT_O_20210216_000041  20210216       41  bias
# 292  2021021600025  AT_O_20210216_000025  20210216       25  bias
# 302  2021021600048  AT_O_20210216_000048  20210216       48  bias
# 188  2021021600026  AT_O_20210216_000026  20210216       26  bias
# 303  2021021600052  AT_O_20210216_000052  20210216       52  bias
# 306  2021021600071  AT_O_20210216_000071  20210216       71  bias
# 308  2021021600055  AT_O_20210216_000055  20210216       55  bias
# 319  2021021600062  AT_O_20210216_000062  20210216       62  bias
# 327  2021021600004  AT_O_20210216_000004  20210216        4  bias
# 331  2021021600036  AT_O_20210216_000036  20210216       36  bias
# 335  2021021600040  AT_O_20210216_000040  20210216       40  bias
# 337  2021021600099  AT_O_20210216_000099  20210216       99  bias
# 339  2021021600088  AT_O_20210216_000088  20210216       88  bias
# 340  2021021600058  AT_O_20210216_000058  20210216       58  bias
# 263  2021021600045  AT_O_20210216_000045  20210216       45  bias
# 256  2021021600015  AT_O_20210216_000015  20210216       15  bias
# 255  2021021600039  AT_O_20210216_000039  20210216       39  bias
# 253  2021021600078  AT_O_20210216_000078  20210216       78  bias
# 189  2021021600021  AT_O_20210216_000021  20210216       21  bias
# 195  2021021600019  AT_O_20210216_000019  20210216       19  bias
# 200  2021021600074  AT_O_20210216_000074  20210216       74  bias
# 201  2021021600094  AT_O_20210216_000094  20210216       94  bias
# 205  2021021600053  AT_O_20210216_000053  20210216       53  bias
# 211  2021021600011  AT_O_20210216_000011  20210216       11  bias
# 213  2021021600007  AT_O_20210216_000007  20210216        7  bias
# 214  2021021600082  AT_O_20210216_000082  20210216       82  bias
# 215  2021021600083  AT_O_20210216_000083  20210216       83  bias
# 217  2021021600031  AT_O_20210216_000031  20210216       31  bias
# 222  2021021600087  AT_O_20210216_000087  20210216       87  bias
# 225  2021021600093  AT_O_20210216_000093  20210216       93  bias
# 226  2021021600013  AT_O_20210216_000013  20210216       13  bias
# 227  2021021600032  AT_O_20210216_000032  20210216       32  bias
# 228  2021021600030  AT_O_20210216_000030  20210216       30  bias
# 234  2021021600069  AT_O_20210216_000069  20210216       69  bias
# 237  2021021600100  AT_O_20210216_000100  20210216      100  bias
# 241  2021021600089  AT_O_20210216_000089  20210216       89  bias
# 243  2021021600076  AT_O_20210216_000076  20210216       76  bias
# 244  2021021600097  AT_O_20210216_000097  20210216       97  bias
# 247  2021021600028  AT_O_20210216_000028  20210216       28  bias
# 2    2021021600070  AT_O_20210216_000070  20210216       70  bias
#
#           target       filter zenith_angle    ra   dec skyangle
# 187  azel_target  empty~empty         None  None  None     None
# 296  azel_target  empty~empty         None  None  None     None
# 264  azel_target  empty~empty         None  None  None     None
# 265  azel_target  empty~empty         None  None  None     None
# 268  azel_target  empty~empty         None  None  None     None
# 270  azel_target  empty~empty         None  None  None     None
# 275  azel_target  empty~empty         None  None  None     None
# 276  azel_target  empty~empty         None  None  None     None
# 285  azel_target  empty~empty         None  None  None     None
# 286  azel_target  empty~empty         None  None  None     None
# 290  azel_target  empty~empty         None  None  None     None
# 292  azel_target  empty~empty         None  None  None     None
# 302  azel_target  empty~empty         None  None  None     None
# 188  azel_target  empty~empty         None  None  None     None
# 303  azel_target  empty~empty         None  None  None     None
# 306  azel_target  empty~empty         None  None  None     None
# 308  azel_target  empty~empty         None  None  None     None
# 319  azel_target  empty~empty         None  None  None     None
# 327  azel_target  empty~empty         None  None  None     None
# 331  azel_target  empty~empty         None  None  None     None
# 335  azel_target  empty~empty         None  None  None     None
# 337  azel_target  empty~empty         None  None  None     None
# 339  azel_target  empty~empty         None  None  None     None
# 340  azel_target  empty~empty         None  None  None     None
# 263  azel_target  empty~empty         None  None  None     None
# 256  azel_target  empty~empty         None  None  None     None
# 255  azel_target  empty~empty         None  None  None     None
# 253  azel_target  empty~empty         None  None  None     None
# 189  azel_target  empty~empty         None  None  None     None
# 195  azel_target  empty~empty         None  None  None     None
# 200  azel_target  empty~empty         None  None  None     None
# 201  azel_target  empty~empty         None  None  None     None
# 205  azel_target  empty~empty         None  None  None     None
# 211  azel_target  empty~empty         None  None  None     None
# 213  azel_target  empty~empty         None  None  None     None
# 214  azel_target  empty~empty         None  None  None     None
# 215  azel_target  empty~empty         None  None  None     None
# 217  azel_target  empty~empty         None  None  None     None
# 222  azel_target  empty~empty         None  None  None     None
# 225  azel_target  empty~empty         None  None  None     None
# 226  azel_target  empty~empty         None  None  None     None
# 227  azel_target  empty~empty         None  None  None     None
# 228  azel_target  empty~empty         None  None  None     None
# 234  azel_target  empty~empty         None  None  None     None
# 237  azel_target  empty~empty         None  None  None     None
# 241  azel_target  empty~empty         None  None  None     None
# 243  azel_target  empty~empty         None  None  None     None
# 244  azel_target  empty~empty         None  None  None     None
# 247  azel_target  empty~empty         None  None  None     None
# 2    azel_target  empty~empty         None  None  None     None
