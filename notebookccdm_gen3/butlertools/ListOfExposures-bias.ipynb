# %% [markdown]
# # List of Exposures
#
#
# - work with Weakly_2022_09
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/03/21

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/atmospec 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_09/conda/envs/lsst-scipipe-2.0.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g64fc59b30a+e1dba0a6f6 	w_latest w_2022_09 current setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num', 'type', 'target','filter','zenith_angle','ra','dec','skyangle'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.tracking_ra, info.tracking_dec, info.sky_angle]
    
    if count < 0:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 0      2021021600208  AT_O_20210216_000208  20210216      208  science
# 1      2021021600163  AT_O_20210216_000163  20210216      163  science
# 2      2021021600070  AT_O_20210216_000070  20210216       70     bias
# 3      2021021600173  AT_O_20210216_000173  20210216      173  science
# 4      2021021600001  AT_O_20210216_000001  20210216        1     bias
# ...              ...                   ...       ...      ...      ...
# 12869  2022031500091  AT_O_20220315_000091  20220315       91     flat
# 12870  2022031500031  AT_O_20220315_000031  20220315       31     bias
# 12871  2022031500109  AT_O_20220315_000109  20220315      109     flat
# 12872  2022031500068  AT_O_20220315_000068  20220315       68     bias
# 12873  2022031500062  AT_O_20220315_000062  20220315       62     bias
#
#                    target       filter zenith_angle          ra        dec  \
# 0                HD 50896  empty~empty    24.314073  103.384002 -23.973448
# 1                HD 50896  RG610~empty    14.580611  103.404029  -23.92939
# 2             azel_target  empty~empty         None        None       None
# 3                HD 50896  RG610~empty      8.82931  103.395986 -23.927038
# 4             azel_target  empty~empty         None        None       None
# ...                   ...          ...          ...         ...        ...
# 12869  FlatField position  SDSSr~empty    51.333026        None       None
# 12870  FlatField position  empty~empty         None        None       None
# 12871  FlatField position  SDSSg~empty    51.333308        None       None
# 12872  FlatField position  empty~empty         None        None       None
# 12873  FlatField position  empty~empty         None        None       None
#
#          skyangle
# 0          -180.0
# 1     -208.621712
# 2            None
# 3     -208.621712
# 4            None
# ...           ...
# 12869        None
# 12870        None
# 12871        None
# 12872        None
# 12873        None
#
# [12874 rows x 11 columns]

# %% [markdown]
# ## Selection of biases

# %%
df_bias = df_exposure[df_exposure.type == 'bias']

# %%
df_bias.sort_values(by="id",ascending=True,inplace=True)
# Out:
# /tmp/ipykernel_25229/1884773382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bias.sort_values(by="id",ascending=True,inplace=True)

# %%
df_bias.tail(50)
# Out:
#                   id                obs_id   day_obs  seq_num  type  \
# 12870  2022031500031  AT_O_20220315_000031  20220315       31  bias
# 12850  2022031500032  AT_O_20220315_000032  20220315       32  bias
# 12766  2022031500033  AT_O_20220315_000033  20220315       33  bias
# 12803  2022031500034  AT_O_20220315_000034  20220315       34  bias
# 12789  2022031500035  AT_O_20220315_000035  20220315       35  bias
# 12820  2022031500036  AT_O_20220315_000036  20220315       36  bias
# 12821  2022031500037  AT_O_20220315_000037  20220315       37  bias
# 12824  2022031500038  AT_O_20220315_000038  20220315       38  bias
# 12859  2022031500039  AT_O_20220315_000039  20220315       39  bias
# 12794  2022031500040  AT_O_20220315_000040  20220315       40  bias
# 12765  2022031500041  AT_O_20220315_000041  20220315       41  bias
# 12838  2022031500042  AT_O_20220315_000042  20220315       42  bias
# 12852  2022031500043  AT_O_20220315_000043  20220315       43  bias
# 12829  2022031500044  AT_O_20220315_000044  20220315       44  bias
# 12793  2022031500045  AT_O_20220315_000045  20220315       45  bias
# 12839  2022031500046  AT_O_20220315_000046  20220315       46  bias
# 12855  2022031500047  AT_O_20220315_000047  20220315       47  bias
# 12840  2022031500048  AT_O_20220315_000048  20220315       48  bias
# 12863  2022031500049  AT_O_20220315_000049  20220315       49  bias
# 12832  2022031500050  AT_O_20220315_000050  20220315       50  bias
# 12798  2022031500051  AT_O_20220315_000051  20220315       51  bias
# 12861  2022031500052  AT_O_20220315_000052  20220315       52  bias
# 11902  2022031500053  AT_O_20220315_000053  20220315       53  bias
# 12773  2022031500054  AT_O_20220315_000054  20220315       54  bias
# 12792  2022031500055  AT_O_20220315_000055  20220315       55  bias
# 12773  FlatField position  empty~empty         None  None  None     None
# 12792  FlatField position  empty~empty         None  None  None     None
# 12790  FlatField position  empty~empty         None  None  None     None
# 12865  FlatField position  empty~empty         None  None  None     None
# 12856  FlatField position  empty~empty         None  None  None     None
# 12769  FlatField position  empty~empty         None  None  None     None
# 12768  FlatField position  empty~empty         None  None  None     None
# 12812  FlatField position  empty~empty         None  None  None     None
# 12873  FlatField position  empty~empty         None  None  None     None
# 12802  FlatField position  empty~empty         None  None  None     None
# 12830  FlatField position  empty~empty         None  None  None     None
# 12862  FlatField position  empty~empty         None  None  None     None
# 12779  FlatField position  empty~empty         None  None  None     None
# 12788  FlatField position  empty~empty         None  None  None     None
# 12872  FlatField position  empty~empty         None  None  None     None
# 12825  FlatField position  empty~empty         None  None  None     None
# 12831  FlatField position  empty~empty         None  None  None     None
# 12804  FlatField position  empty~empty         None  None  None     None
# 12783  FlatField position  empty~empty         None  None  None     None
# 12815  FlatField position  empty~empty         None  None  None     None
# 12844  FlatField position  empty~empty         None  None  None     None
# 12827  FlatField position  empty~empty         None  None  None     None
# 12813  FlatField position  empty~empty         None  None  None     None
# 12809  FlatField position  empty~empty         None  None  None     None
# 12781  FlatField position  empty~empty         None  None  None     None
# 12858  FlatField position  empty~empty         None  None  None     None
# 12787  FlatField position  empty~empty         None  None  None     None

# %% [markdown]
# ## Selection of date

# %%
df_bias_selected = df_bias[df_bias.day_obs == '20220315' ]

# %%
df_bias
# Out:
#                   id                obs_id   day_obs  seq_num  type  \
# 4      2021021600001  AT_O_20210216_000001  20210216        1  bias
# 89     2021021600002  AT_O_20210216_000002  20210216        2  bias
# 296    2021021600003  AT_O_20210216_000003  20210216        3  bias
# 327    2021021600004  AT_O_20210216_000004  20210216        4  bias
# 136    2021021600005  AT_O_20210216_000005  20210216        5  bias
# ...              ...                   ...       ...      ...   ...
# 12813  2022031500076  AT_O_20220315_000076  20220315       76  bias
# 12809  2022031500077  AT_O_20220315_000077  20220315       77  bias
# 12781  2022031500078  AT_O_20220315_000078  20220315       78  bias
# 12858  2022031500079  AT_O_20220315_000079  20220315       79  bias
# 12787  2022031500080  AT_O_20220315_000080  20220315       80  bias
#
#                    target       filter zenith_angle    ra   dec skyangle
# 4             azel_target  empty~empty         None  None  None     None
# 89            azel_target  empty~empty         None  None  None     None
# 296           azel_target  empty~empty         None  None  None     None
# 327           azel_target  empty~empty         None  None  None     None
# 136           azel_target  empty~empty         None  None  None     None
# ...                   ...          ...          ...   ...   ...      ...
# 12813  FlatField position  empty~empty         None  None  None     None
# 12809  FlatField position  empty~empty         None  None  None     None
# 12781  FlatField position  empty~empty         None  None  None     None
# 12858  FlatField position  empty~empty         None  None  None     None
# 12787  FlatField position  empty~empty         None  None  None     None
#
# [1216 rows x 11 columns]
