# %% [markdown]
# # List of Exposures with Bias
#
#
# - work with Weakly_2022_39
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/06/17
# - Last update : 2022-11-15

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/atmospec 	setup
# drp_pipe              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/drp_pipe 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_39/conda/envs/lsst-scipipe-4.1.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g0b29ad24fb+a10408d0bf 	w_latest current w_2022_39 setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs','group_name' ,'seq_num', 'type', 'target','filter','zenith_angle','expos','ra','dec','skyangle'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.group_name,info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.exposure_time,info.tracking_ra, info.tracking_dec, info.sky_angle]
    
    if count < 0:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t group_name:             ",info.group_name)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs               group_name  \
# 0      2021021600208  AT_O_20210216_000208  20210216  2021-02-17T03:35:45.035
# 1      2021021600163  AT_O_20210216_000163  20210216  2021-02-17T00:50:15.536
# 2      2021021600070  AT_O_20210216_000070  20210216  2021-02-16T20:39:31.417
# 3      2021021600173  AT_O_20210216_000173  20210216  2021-02-17T01:21:19.215
# 4      2021021600001  AT_O_20210216_000001  20210216  2021-02-16T19:50:21.993
# ...              ...                   ...       ...                      ...
# 21152  2022063000801  AT_O_20220630_000801  20220630  2022-07-01T09:23:29.769
# 21153  2022063000802  AT_O_20220630_000802  20220630  2022-07-01T09:24:43.587
# 21154  2022063000803  AT_O_20220630_000803  20220630  2022-07-01T09:24:43.587
# 21155  2022063000804  AT_O_20220630_000804  20220630  2022-07-01T09:25:58.670
# 21156  2022063000805  AT_O_20220630_000805  20220630  2022-07-01T09:25:58.670
#
#        seq_num     type                                target       filter  \
# 0          208  science                              HD 50896  empty~empty
# 1          163  science                              HD 50896  RG610~empty
# 2           70     bias                           azel_target  empty~empty
# 3          173  science                              HD 50896  RG610~empty
# 4            1     bias                           azel_target  empty~empty
# ...        ...      ...                                   ...          ...
# 21152      801  science  AUXTEL_DRP_IMAGING:WFI-2026-4536_062  SDSSr~empty
# 21153      802  science  AUXTEL_DRP_IMAGING:WFI-2026-4536_063  SDSSr~empty
# 21154      803  science  AUXTEL_DRP_IMAGING:WFI-2026-4536_063  SDSSr~empty
# 21155      804  science  AUXTEL_DRP_IMAGING:WFI-2026-4536_064  SDSSr~empty
# 21156      805  science  AUXTEL_DRP_IMAGING:WFI-2026-4536_064  SDSSr~empty
#
#       zenith_angle  expos          ra        dec    skyangle
# 0        24.314073    2.0  103.384002 -23.973448      -180.0
# 1        14.580611    3.0  103.404029  -23.92939 -208.621712
# 2             None    0.0        None       None        None
# 3          8.82931    2.0  103.395986 -23.927038 -208.621712
# 4             None    0.0        None       None        None
# ...            ...    ...         ...        ...         ...
# 21152    36.396484   30.0  306.677395 -45.325215  359.998841
# 21153    36.437127   30.0  306.811224 -45.325305    0.005404
# 21154    36.530061   30.0  306.811146 -45.325195   359.99891
# 21155     36.57364   30.0  306.944962 -45.325294  359.998843
# 21156    36.666615   30.0  306.944896  -45.32522  359.998972
#
# [21157 rows x 13 columns]

# %% [markdown]
# ## Selection of Bias

# %%
df_bias = df_exposure[df_exposure.type == 'bias']

# %%
df_bias.sort_values(by="id",ascending=True,inplace=True)
# Out:
# /scratch/users/d/dagoret/ipykernel_8831/1884773382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bias.sort_values(by="id",ascending=True,inplace=True)

# %%
df_bias.tail(60)
# Out:
#                   id                obs_id   day_obs               group_name  \
# 17595  2022060800109  AT_O_20220608_000109  20220608  2022-06-08T21:22:37.536
# 17596  2022060800110  AT_O_20220608_000110  20220608  2022-06-08T21:22:39.872
# 17597  2022060800111  AT_O_20220608_000111  20220608  2022-06-08T21:22:42.361
# 17598  2022060800112  AT_O_20220608_000112  20220608  2022-06-08T21:22:44.695
# 17599  2022060800113  AT_O_20220608_000113  20220608  2022-06-08T21:22:47.182
# 17600  2022060800114  AT_O_20220608_000114  20220608  2022-06-08T21:22:49.514
# 17601  2022060800115  AT_O_20220608_000115  20220608  2022-06-08T21:22:52.005
# 17616      131  bias  FlatField position       FELH0600~empty         None
# 17617      132  bias  FlatField position       FELH0600~empty         None
# 17618      133  bias  FlatField position       FELH0600~empty         None
# 17619      134  bias  FlatField position       FELH0600~empty         None
# 17620      135  bias  FlatField position       FELH0600~empty         None
# 17621      136  bias  FlatField position       FELH0600~empty         None
# 17622      137  bias  FlatField position       FELH0600~empty         None
# 18233        1  bias       Park position  empty~ronchi170lpmm         None
# 18237        5  bias  FlatField position          empty~empty         None
# 18238        6  bias  FlatField position          empty~empty         None
# 18239        7  bias  FlatField position          empty~empty         None
# 18240        8  bias  FlatField position          empty~empty         None
# 18241        9  bias  FlatField position          empty~empty         None
# 18242       10  bias  FlatField position          empty~empty         None
# 18243       11  bias  FlatField position          empty~empty         None
# 18244       12  bias  FlatField position          empty~empty         None
# 18245       13  bias  FlatField position          empty~empty         None
# 18246       14  bias  FlatField position          empty~empty         None
# 18520        4  bias       Park position          SDSSr~empty         None
# 18619       10  bias  FlatField position       FELH0600~empty         None
# 19082       11  bias  FlatField position       FELH0600~empty         None
# 19083       12  bias  FlatField position       FELH0600~empty         None
# 19084       13  bias  FlatField position       FELH0600~empty         None
# 19085       14  bias  FlatField position       FELH0600~empty         None
# 19086       15  bias  FlatField position       FELH0600~empty         None
# 19376        1  bias       Park position          SDSSr~empty         None
# 19839        6  bias  FlatField position          SDSSr~empty         None
# 19840        7  bias  FlatField position          SDSSr~empty         None
# 19841        8  bias  FlatField position          SDSSr~empty         None
# 19842        9  bias  FlatField position          SDSSr~empty         None
# 19843       10  bias  FlatField position          SDSSr~empty         None
# 19844       11  bias  FlatField position          SDSSr~empty         None
# 19806        1  bias       Park position          SDSSr~empty         None
# 19807        3  bias  FlatField position      SDSSr~holo4_003         None
# 20071        4  bias  FlatField position      SDSSr~holo4_003         None
# 20387        5  bias  FlatField position      SDSSr~holo4_003         None
# 19808        6  bias  FlatField position      SDSSr~holo4_003         None
# 20388        7  bias  FlatField position      SDSSr~holo4_003         None
# 19809        8  bias  FlatField position      SDSSr~holo4_003         None
#
#        expos    ra   dec skyangle
# 17595    0.0  None  None     None
# 17596    0.0  None  None     None
# 17597    0.0  None  None     None
# 17598    0.0  None  None     None
# 17599    0.0  None  None     None
# 17600    0.0  None  None     None
# 17601    0.0  None  None     None
# 17602    0.0  None  None     None
# 17603    0.0  None  None     None
# 17604    0.0  None  None     None
# 17605    0.0  None  None     None
# 17606    0.0  None  None     None
# 17607    0.0  None  None     None
# 17608    0.0  None  None     None
# 17609    0.0  None  None     None
# 17610    0.0  None  None     None
# 17611    0.0  None  None     None
# 17612    0.0  None  None     None
# 17613    0.0  None  None     None
# 17614    0.0  None  None     None
# 17615    0.0  None  None     None
# 17616    0.0  None  None     None
# 17617    0.0  None  None     None
# 17618    0.0  None  None     None
# 17619    0.0  None  None     None
# 17620    0.0  None  None     None
# 17621    0.0  None  None     None
# 17622    0.0  None  None     None
# 18233    0.0  None  None     None
# 18237    0.0  None  None     None
# 18238    0.0  None  None     None
# 18239    0.0  None  None     None
# 18240    0.0  None  None     None
# 18241    0.0  None  None     None
# 18242    0.0  None  None     None
# 18243    0.0  None  None     None
# 18244    0.0  None  None     None
# 18245    0.0  None  None     None
# 18246    0.0  None  None     None
# 18520    0.0  None  None     None
# 18619    0.0  None  None     None
# 19082    0.0  None  None     None
# 19083    0.0  None  None     None
# 19084    0.0  None  None     None
# 19085    0.0  None  None     None
# 19086    0.0  None  None     None
# 19376    0.0  None  None     None
# 19839    0.0  None  None     None
# 19840    0.0  None  None     None
# 19841    0.0  None  None     None
# 19842    0.0  None  None     None
# 19843    0.0  None  None     None
# 19844    0.0  None  None     None
# 19806    0.0  None  None     None
# 19807    0.0  None  None     None
# 20071    0.0  None  None     None
# 20387    0.0  None  None     None
# 19808    0.0  None  None     None
# 20388    0.0  None  None     None
# 19809    0.0  None  None     None

# %%
df_bias.day_obs.unique()
# Out:
# array([20210216, 20210217, 20210218, 20210311, 20210608, 20210609,
#        20210610, 20210706, 20210707, 20210708, 20210907, 20210908,
#        20210909, 20211005, 20211006, 20211007, 20211102, 20211103,
#        20211104, 20220215, 20220216, 20220217, 20220315, 20220316,
#        20220317, 20220318, 20220502, 20220503, 20220504, 20220524,
#        20220607, 20220608, 20220609, 20220628, 20220629, 20220630])

# %% [markdown]
# ## Selection of date

# %%
date_sel = 20220609

# %%
df_bias_selected = df_bias[df_bias.day_obs == date_sel ]

# %%
len(df_bias_selected)
# Out:
# 11

# %% [markdown]
# ## Final selection of exposure

# %%
pd.set_option('display.max_rows', None)

# %%
df = df_bias_selected
df_sel = df[['day_obs', 'seq_num']]
    
    
NN = len(df)
    
if NN>0:
        # build the line
        
    df_sel['line'] = df_sel.apply(lambda row: str(row['day_obs'])  + " " + str(row['seq_num']),axis = 1)
    
    
    # prepare output
    filename_out = "visitbias_"+ str(date_sel) + ".list"
    print(filename_out)
        
    df_out = df_sel[["line"]]
    df_out.to_csv(filename_out, index=False, header=None)
# Out:
# visitbias_20220609.list
# /tmp/ipykernel_11839/1927370446.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sel['line'] = df_sel.apply(lambda row: str(row['day_obs'])  + " " + str(row['seq_num']),axis = 1)

# %%
df_sel
# Out:
#         day_obs  seq_num         line
# 18233  20220609        1   20220609 1
# 18237  20220609        5   20220609 5
# 18238  20220609        6   20220609 6
# 18239  20220609        7   20220609 7
# 18240  20220609        8   20220609 8
# 18241  20220609        9   20220609 9
# 18242  20220609       10  20220609 10
# 18243  20220609       11  20220609 11
# 18244  20220609       12  20220609 12
# 18245  20220609       13  20220609 13
# 18246  20220609       14  20220609 14
