# %% [markdown]
# # List of Exposures Flats
#
#
# - work with Weakly_2022_09
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/03/21

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/atmospec 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_09/conda/envs/lsst-scipipe-2.0.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g64fc59b30a+e1dba0a6f6 	w_latest w_2022_09 current setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num', 'type', 'target','filter','zenith_angle','ra','dec','skyangle'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.tracking_ra, info.tracking_dec, info.sky_angle]
    
    if count < 2:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
# Out:
# ----------------------------------------------------- 0 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600208
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000208'
#   exposure_time: 2.0
#   dark_time: 2.33517265319824
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 208
#   group_name: '2021-02-17T03:35:45.035'
#   group_id: 1934625450350000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.384001783548
#   tracking_dec: -23.9734478006315
#   sky_angle: -180.0
#   zenith_angle: 24.314073266185005
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 03:35:45.295446', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 03:35:47.540000', scale='tai', format='iso'))
# 	 id:                   2021021600208
# 	 day_obs:              20210216
# 	 seq_num:              208
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 1 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600163
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000163'
#   exposure_time: 3.0
#   dark_time: 3.3251359462738
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 163
#   group_name: '2021-02-17T00:50:15.536'
#   group_id: 1934526155360000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.404029472597
#   tracking_dec: -23.9293904683577
#   sky_angle: -208.6217120790572
#   zenith_angle: 14.580610783508703
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 00:50:15.703984', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 00:50:18.939000', scale='tai', format='iso'))
# 	 id:                   2021021600163
# 	 day_obs:              20210216
# 	 seq_num:              163
# 	 type-of-observation:  science
# 	 target:               HD 50896

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 0      2021021600208  AT_O_20210216_000208  20210216      208  science
# 1      2021021600163  AT_O_20210216_000163  20210216      163  science
# 2      2021021600070  AT_O_20210216_000070  20210216       70     bias
# 3      2021021600173  AT_O_20210216_000173  20210216      173  science
# 4      2021021600001  AT_O_20210216_000001  20210216        1     bias
# ...              ...                   ...       ...      ...      ...
# 12869  2022031500091  AT_O_20220315_000091  20220315       91     flat
# 12870  2022031500031  AT_O_20220315_000031  20220315       31     bias
# 12871  2022031500109  AT_O_20220315_000109  20220315      109     flat
# 12872  2022031500068  AT_O_20220315_000068  20220315       68     bias
# 12873  2022031500062  AT_O_20220315_000062  20220315       62     bias
#
#                    target       filter zenith_angle          ra        dec  \
# 0                HD 50896  empty~empty    24.314073  103.384002 -23.973448
# 1                HD 50896  RG610~empty    14.580611  103.404029  -23.92939
# 2             azel_target  empty~empty         None        None       None
# 3                HD 50896  RG610~empty      8.82931  103.395986 -23.927038
# 4             azel_target  empty~empty         None        None       None
# ...                   ...          ...          ...         ...        ...
# 12869  FlatField position  SDSSr~empty    51.333026        None       None
# 12870  FlatField position  empty~empty         None        None       None
# 12871  FlatField position  SDSSg~empty    51.333308        None       None
# 12872  FlatField position  empty~empty         None        None       None
# 12873  FlatField position  empty~empty         None        None       None
#
#          skyangle
# 0          -180.0
# 1     -208.621712
# 2            None
# 3     -208.621712
# 4            None
# ...           ...
# 12869        None
# 12870        None
# 12871        None
# 12872        None
# 12873        None
#
# [12874 rows x 11 columns]

# %% [markdown]
# ## Selection of flats

# %%
df_flat = df_exposure[df_exposure.type == 'flat']

# %%
df_flat.sort_values(by="day_obs",ascending=True,inplace=True)
# Out:
# /tmp/ipykernel_4584/2047437805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat.sort_values(by="day_obs",ascending=True,inplace=True)

# %%
df_flat.tail(50)
# Out:
#                   id                obs_id   day_obs  seq_num  type  \
# 17548  2022060800062  AT_O_20220608_000062  20220608       62  flat
# 17534  2022060800048  AT_O_20220608_000048  20220608       48  flat
# 17550  2022060800064  AT_O_20220608_000064  20220608       64  flat
# 17549  2022060800063  AT_O_20220608_000063  20220608       63  flat
# 17567  2022060800081  AT_O_20220608_000081  20220608       81  flat
# 17565  2022060800079  AT_O_20220608_000079  20220608       79  flat
# 17564  2022060800078  AT_O_20220608_000078  20220608       78  flat
# 17563  2022060800077  AT_O_20220608_000077  20220608       77  flat
# 17560  FlatField position      BG40~empty    51.060012  None  None     None
# 17559  FlatField position      BG40~empty    51.060009  None  None     None
# 17566  FlatField position      BG40~empty    51.060039  None  None     None
# 17557  FlatField position      BG40~empty    51.060002  None  None     None
# 17556  FlatField position      BG40~empty    51.059998  None  None     None
# 17555  FlatField position      BG40~empty    51.059996  None  None     None
# 17554  FlatField position      BG40~empty     51.05999  None  None     None
# 17553  FlatField position      BG40~empty    51.059986  None  None     None
# 17552  FlatField position      BG40~empty    51.059969  None  None     None
# 17558  FlatField position      BG40~empty    51.060005  None  None     None
# 17551  FlatField position     SDSSg~empty    51.059952  None  None     None
# 18273  FlatField position      BG40~empty    51.003503  None  None     None
# 18274  FlatField position      BG40~empty    51.003503  None  None     None
# 18275  FlatField position      BG40~empty    51.003506  None  None     None
# 18276  FlatField position      BG40~empty    51.003504  None  None     None
# 18277  FlatField position     SDSSg~empty    51.003509  None  None     None
# 18278  FlatField position     SDSSg~empty    51.003513  None  None     None
# 18281  FlatField position     SDSSg~empty    51.003517  None  None     None
# 18280  FlatField position     SDSSg~empty    51.003515  None  None     None
# 18282  FlatField position     SDSSg~empty    51.003518  None  None     None
# 18283  FlatField position     SDSSg~empty    51.003522  None  None     None
# 18284  FlatField position     SDSSg~empty    51.003518  None  None     None
# 18272  FlatField position      BG40~empty      51.0035  None  None     None
# 18279  FlatField position     SDSSg~empty    51.003514  None  None     None
# 18271  FlatField position      BG40~empty      51.0035  None  None     None
# 18262  FlatField position  FELH0600~empty    51.003456  None  None     None
# 18269  FlatField position      BG40~empty      51.0035  None  None     None
# 18268  FlatField position      BG40~empty    51.003493  None  None     None
# 18267  FlatField position      BG40~empty    51.003498  None  None     None
# 18266  FlatField position  FELH0600~empty    51.003461  None  None     None
# 18265  FlatField position  FELH0600~empty    51.003461  None  None     None
# 18264  FlatField position  FELH0600~empty    51.003458  None  None     None
# 18263  FlatField position  FELH0600~empty    51.003456  None  None     None
# 18261  FlatField position  FELH0600~empty    51.003455  None  None     None
# 18260  FlatField position  FELH0600~empty    51.003452  None  None     None
# 18259  FlatField position  FELH0600~empty    51.003453  None  None     None
# 18258  FlatField position  FELH0600~empty    51.003451  None  None     None
# 18257  FlatField position  FELH0600~empty    51.003452  None  None     None
# 18285  FlatField position     SDSSg~empty     51.00352  None  None     None
# 18270  FlatField position      BG40~empty      51.0035  None  None     None
# 18286  FlatField position     SDSSg~empty    51.003523  None  None     None

# %% [markdown]
# # List of dates

# %%
list_of_dates_flats = df_flat['day_obs'].unique() 
list_of_dates_flats
# Out:
# array([20210216, 20210217, 20210218, 20210311, 20210608, 20210609,
#        20210707, 20210708, 20210907, 20210908, 20210909, 20211005,
#        20211006, 20211007, 20211102, 20211104, 20220215, 20220216,
#        20220217, 20220315, 20220316, 20220317, 20220502, 20220503,
#        20220504, 20220524, 20220607, 20220608, 20220609])

# %% [markdown]
# # List of filters

# %%
list_of_filters = df_flat['filter'].unique()
list_of_filters
# Out:
# array(['empty~empty', 'RG610~empty', 'empty~holo4_003', 'BG40~empty',
#        'FELH0600~empty', 'SDSSg~empty', 'SDSSr~empty', 'SDSSi~empty',
#        'SDSSg~holo4_003'], dtype=object)
