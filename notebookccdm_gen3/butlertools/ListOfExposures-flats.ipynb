# %% [markdown]
# # List of Exposures Flats
#
#
# - work with Weakly_2022_09
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/03/21

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/atmospec 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_09/conda/envs/lsst-scipipe-2.0.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g64fc59b30a+e1dba0a6f6 	w_latest w_2022_09 current setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num', 'type', 'target','filter','zenith_angle','ra','dec','skyangle'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.tracking_ra, info.tracking_dec, info.sky_angle]
    
    if count < 2:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
# Out:
# ----------------------------------------------------- 0 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600208
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000208'
#   exposure_time: 2.0
#   dark_time: 2.33517265319824
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 208
#   group_name: '2021-02-17T03:35:45.035'
#   group_id: 1934625450350000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.384001783548
#   tracking_dec: -23.9734478006315
#   sky_angle: -180.0
#   zenith_angle: 24.314073266185005
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 03:35:45.295446', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 03:35:47.540000', scale='tai', format='iso'))
# 	 id:                   2021021600208
# 	 day_obs:              20210216
# 	 seq_num:              208
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 1 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600163
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000163'
#   exposure_time: 3.0
#   dark_time: 3.3251359462738
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 163
#   group_name: '2021-02-17T00:50:15.536'
#   group_id: 1934526155360000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.404029472597
#   tracking_dec: -23.9293904683577
#   sky_angle: -208.6217120790572
#   zenith_angle: 14.580610783508703
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 00:50:15.703984', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 00:50:18.939000', scale='tai', format='iso'))
# 	 id:                   2021021600163
# 	 day_obs:              20210216
# 	 seq_num:              163
# 	 type-of-observation:  science
# 	 target:               HD 50896

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 0      2021021600208  AT_O_20210216_000208  20210216      208  science
# 1      2021021600163  AT_O_20210216_000163  20210216      163  science
# 2      2021021600070  AT_O_20210216_000070  20210216       70     bias
# 3      2021021600173  AT_O_20210216_000173  20210216      173  science
# 4      2021021600001  AT_O_20210216_000001  20210216        1     bias
# ...              ...                   ...       ...      ...      ...
# 12869  2022031500091  AT_O_20220315_000091  20220315       91     flat
# 12870  2022031500031  AT_O_20220315_000031  20220315       31     bias
# 12871  2022031500109  AT_O_20220315_000109  20220315      109     flat
# 12872  2022031500068  AT_O_20220315_000068  20220315       68     bias
# 12873  2022031500062  AT_O_20220315_000062  20220315       62     bias
#
#                    target       filter zenith_angle          ra        dec  \
# 0                HD 50896  empty~empty    24.314073  103.384002 -23.973448
# 1                HD 50896  RG610~empty    14.580611  103.404029  -23.92939
# 2             azel_target  empty~empty         None        None       None
# 3                HD 50896  RG610~empty      8.82931  103.395986 -23.927038
# 4             azel_target  empty~empty         None        None       None
# ...                   ...          ...          ...         ...        ...
# 12869  FlatField position  SDSSr~empty    51.333026        None       None
# 12870  FlatField position  empty~empty         None        None       None
# 12871  FlatField position  SDSSg~empty    51.333308        None       None
# 12872  FlatField position  empty~empty         None        None       None
# 12873  FlatField position  empty~empty         None        None       None
#
#          skyangle
# 0          -180.0
# 1     -208.621712
# 2            None
# 3     -208.621712
# 4            None
# ...           ...
# 12869        None
# 12870        None
# 12871        None
# 12872        None
# 12873        None
#
# [12874 rows x 11 columns]

# %% [markdown]
# ## Selection of flats

# %%
df_flat = df_exposure[df_exposure.type == 'flat']

# %%
df_flat.sort_values(by="day_obs",ascending=True,inplace=True)
# Out:
# /tmp/ipykernel_6659/2047437805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flat.sort_values(by="day_obs",ascending=True,inplace=True)

# %%
df_flat.tail(50)
# Out:
#                   id                obs_id   day_obs  seq_num  type  \
# 11345  2022021600061  AT_O_20220216_000061  20220216       61  flat
# 11338  2022021600057  AT_O_20220216_000057  20220216       57  flat
# 11317  2022021600063  AT_O_20220216_000063  20220216       63  flat
# 11279  2022021600050  AT_O_20220216_000050  20220216       50  flat
# 11700  2022021600051  AT_O_20220216_000051  20220216       51  flat
# 12316  2022021700050  AT_O_20220217_000050  20220217       50  flat
# 12346  2022021700004  AT_O_20220217_000004  20220217        4  flat
# 12350  2022021700064  AT_O_20220217_000064  20220217       64  flat
# 12375  FlatField position  SDSSr~empty    51.000088  None  None     None
# 12742  FlatField position  SDSSr~empty    51.000086  None  None     None
# 12617  FlatField position  SDSSr~empty    51.000087  None  None     None
# 12299  FlatField position  SDSSr~empty    51.000087  None  None     None
# 12760  FlatField position  SDSSr~empty    51.000089  None  None     None
# 12452  FlatField position  SDSSr~empty    51.000089  None  None     None
# 12218  FlatField position  SDSSr~empty    51.000087  None  None     None
# 12531  FlatField position  SDSSr~empty    51.000088  None  None     None
# 12053  FlatField position  SDSSr~empty    51.000088  None  None     None
# 12040  FlatField position  SDSSr~empty    51.000088  None  None     None
# 12036  FlatField position  SDSSr~empty    51.000087  None  None     None
# 12024  FlatField position  SDSSr~empty    51.000086  None  None     None
# 12014  FlatField position  SDSSr~empty    51.000087  None  None     None
# 12010  FlatField position  SDSSr~empty    51.000086  None  None     None
# 12009  FlatField position  SDSSr~empty    51.000087  None  None     None
# 11998  FlatField position  SDSSr~empty    51.000087  None  None     None
# 11997  FlatField position  SDSSr~empty    51.000086  None  None     None
# 12204  FlatField position  SDSSr~empty    51.000086  None  None     None
# 12834  FlatField position  SDSSr~empty    51.333132  None  None     None
# 12835  FlatField position  SDSSg~empty    51.333304  None  None     None
# 12841  FlatField position  SDSSg~empty    51.333314  None  None     None
# 12853  FlatField position  SDSSg~empty    51.333282  None  None     None
# 12864  FlatField position  SDSSr~empty    51.333134  None  None     None
# 12857  FlatField position  SDSSg~empty    51.333308  None  None     None
# 12860  FlatField position  SDSSg~empty     51.33331  None  None     None
# 12833  FlatField position  SDSSg~empty    51.333314  None  None     None
# 12868  FlatField position  SDSSg~empty    51.333103  None  None     None
# 12854  FlatField position  SDSSr~empty    51.333136  None  None     None
# 12816  FlatField position  SDSSr~empty    51.333131  None  None     None
# 12797  FlatField position  SDSSr~empty    51.333136  None  None     None
# 12807  FlatField position  SDSSr~empty    51.333132  None  None     None
# 12805  FlatField position  SDSSr~empty    51.333128  None  None     None
# 12800  FlatField position  SDSSg~empty    51.333316  None  None     None
# 12785  FlatField position  SDSSr~empty    51.333136  None  None     None
# 12784  FlatField position  SDSSr~empty    51.333131  None  None     None
# 12777  FlatField position  SDSSg~empty    51.333288  None  None     None
# 12771  FlatField position  SDSSg~empty    51.333318  None  None     None
# 12767  FlatField position  SDSSg~empty    51.333312  None  None     None
# 12764  FlatField position  SDSSr~empty    51.333129  None  None     None
# 12869  FlatField position  SDSSr~empty    51.333026  None  None     None
# 12808  FlatField position  SDSSg~empty    51.333304  None  None     None
# 12871  FlatField position  SDSSg~empty    51.333308  None  None     None

# %% [markdown]
# # List of dates

# %%
list_of_dates_flats = df_flat['day_obs'].unique() 
list_of_dates_flats
# Out:
# array([20210216, 20210217, 20210218, 20210311, 20210608, 20210609,
#        20210707, 20210708, 20210907, 20210908, 20210909, 20211005,
#        20211006, 20211007, 20211102, 20211104, 20220215, 20220216,
#        20220217, 20220315])

# %% [markdown]
# # List of filters

# %%
list_of_filters = df_flat['filter'].unique()
list_of_filters
# Out:
# array(['empty~empty', 'RG610~empty', 'empty~holo4_003', 'BG40~empty',
#        'FELH0600~empty', 'SDSSg~empty', 'SDSSr~empty'], dtype=object)
