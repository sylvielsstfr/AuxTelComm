# %% [markdown]
# # List of Exposures Flats
#
#
# - work with Weakly_2022_39
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/11/08

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/atmospec 	setup
# drp_pipe              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/drp_pipe 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_39/conda/envs/lsst-scipipe-4.1.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g0b29ad24fb+a10408d0bf 	w_latest current w_2022_39 setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num', 'type', 'target','filter','zenith_angle','ra','dec','skyangle','exptime'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.tracking_ra, info.tracking_dec, info.sky_angle,info.exposure_time]
    
    if count < 2:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
        print("\t exposure_time:       ",info.exposure_time)
# Out:
# ----------------------------------------------------- 0 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600208
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000208'
#   exposure_time: 2.0
#   dark_time: 2.33517265319824
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 208
#   group_name: '2021-02-17T03:35:45.035'
#   group_id: 1934625450350000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.384001783548
#   tracking_dec: -23.9734478006315
#   sky_angle: -180.0
#   zenith_angle: 24.314073266185005
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 03:35:45.295446', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 03:35:47.540000', scale='tai', format='iso'))
# 	 id:                   2021021600208
# 	 day_obs:              20210216
# 	 seq_num:              208
# 	 type-of-observation:  science
# 	 target:               HD 50896
# 	 exposure_time:        2.0
# ----------------------------------------------------- 1 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600163
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000163'
#   exposure_time: 3.0
#   dark_time: 3.3251359462738
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 163
#   group_name: '2021-02-17T00:50:15.536'
#   group_id: 1934526155360000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.404029472597
#   tracking_dec: -23.9293904683577
#   sky_angle: -208.6217120790572
#   zenith_angle: 14.580610783508703
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 00:50:15.703984', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 00:50:18.939000', scale='tai', format='iso'))
# 	 id:                   2021021600163
# 	 day_obs:              20210216
# 	 seq_num:              163
# 	 type-of-observation:  science
# 	 target:               HD 50896
# 	 exposure_time:        3.0

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 0      2021021600208  AT_O_20210216_000208  20210216      208  science
# 1      2021021600163  AT_O_20210216_000163  20210216      163  science
# 2      2021021600070  AT_O_20210216_000070  20210216       70     bias
# 3      2021021600173  AT_O_20210216_000173  20210216      173  science
# 4      2021021600001  AT_O_20210216_000001  20210216        1     bias
# ...              ...                   ...       ...      ...      ...
# 21152  2022063000801  AT_O_20220630_000801  20220630      801  science
# 21153  2022063000802  AT_O_20220630_000802  20220630      802  science
# 21154  2022063000803  AT_O_20220630_000803  20220630      803  science
# 21155  2022063000804  AT_O_20220630_000804  20220630      804  science
# 21156  2022063000805  AT_O_20220630_000805  20220630      805  science
#
#                                      target       filter zenith_angle  \
# 0                                  HD 50896  empty~empty    24.314073
# 1                                  HD 50896  RG610~empty    14.580611
# 2                               azel_target  empty~empty         None
# 3                                  HD 50896  RG610~empty      8.82931
# 4                               azel_target  empty~empty         None
# ...                                     ...          ...          ...
# 21152  AUXTEL_DRP_IMAGING:WFI-2026-4536_062  SDSSr~empty    36.396484
# 21153  AUXTEL_DRP_IMAGING:WFI-2026-4536_063  SDSSr~empty    36.437127
# 21154  AUXTEL_DRP_IMAGING:WFI-2026-4536_063  SDSSr~empty    36.530061
# 21155  AUXTEL_DRP_IMAGING:WFI-2026-4536_064  SDSSr~empty     36.57364
# 21156  AUXTEL_DRP_IMAGING:WFI-2026-4536_064  SDSSr~empty    36.666615
#
#                ra        dec    skyangle  exptime
# 0      103.384002 -23.973448      -180.0      2.0
# 1      103.404029  -23.92939 -208.621712      3.0
# 2            None       None        None      0.0
# 3      103.395986 -23.927038 -208.621712      2.0
# 4            None       None        None      0.0
# ...           ...        ...         ...      ...
# 21152  306.677395 -45.325215  359.998841     30.0
# 19817  2022063000024  AT_O_20220630_000024  20220630       24  flat
# 19816  2022063000022  AT_O_20220630_000022  20220630       22  flat
# 19815  2022063000020  AT_O_20220630_000020  20220630       20  flat
# 19814  2022063000018  AT_O_20220630_000018  20220630       18  flat
# 19813  2022063000016  AT_O_20220630_000016  20220630       16  flat
# 20397  2022063000025  AT_O_20220630_000025  20220630       25  flat
# 20392  2022063000015  AT_O_20220630_000015  20220630       15  flat
# 20393  2022063000017  AT_O_20220630_000017  20220630       17  flat
# 20394  2022063000019  AT_O_20220630_000019  20220630       19  flat
# 20395  2022063000021  AT_O_20220630_000021  20220630       21  flat
# 20396  2022063000023  AT_O_20220630_000023  20220630       23  flat
# 20398  2022063000027  AT_O_20220630_000027  20220630       27  flat
#
#                    target           filter zenith_angle    ra   dec skyangle  \
# 18262  FlatField position   FELH0600~empty    51.003456  None  None     None
# 18260  FlatField position   FELH0600~empty    51.003452  None  None     None
# 18264  FlatField position   FELH0600~empty    51.003458  None  None     None
# 18265  FlatField position   FELH0600~empty    51.003461  None  None     None
# 18266  FlatField position   FELH0600~empty    51.003461  None  None     None
# 18267  FlatField position       BG40~empty    51.003498  None  None     None
# 18268  FlatField position       BG40~empty    51.003493  None  None     None
# 18269  FlatField position       BG40~empty      51.0035  None  None     None
# 18263  FlatField position   FELH0600~empty    51.003456  None  None     None
# 19100  FlatField position   FELH0600~empty    50.999871  None  None     None
# 19106  FlatField position   FELH0600~empty    50.999848  None  None     None
# 19105  FlatField position   FELH0600~empty     50.99985  None  None     None
# 19104  FlatField position   FELH0600~empty     50.99985  None  None     None
# 19102  FlatField position   FELH0600~empty    50.999873  None  None     None
# 19101  FlatField position   FELH0600~empty    50.999873  None  None     None
# 19099  FlatField position   FELH0600~empty    50.999872  None  None     None
# 19103  FlatField position   FELH0600~empty    50.999854  None  None     None
# 19097  FlatField position   FELH0600~empty     50.99987  None  None     None
# 19080  FlatField position   FELH0600~empty    50.999888  None  None     None
# 19081  FlatField position   FELH0600~empty    50.999885  None  None     None
# 19093  FlatField position   FELH0600~empty    50.999874  None  None     None
# 19098  FlatField position   FELH0600~empty    50.999872  None  None     None
# 19095  FlatField position   FELH0600~empty    50.999874  None  None     None
# 19096  FlatField position   FELH0600~empty    50.999873  None  None     None
# 19094  FlatField position   FELH0600~empty    50.999869  None  None     None
# 19863  FlatField position      SDSSr~empty    50.999765  None  None     None
# 19853  FlatField position      SDSSr~empty    50.999763  None  None     None
# 19861  FlatField position      SDSSr~empty    50.999765  None  None     None
# 19858  FlatField position      SDSSr~empty    50.999766  None  None     None
# 19857  FlatField position      SDSSr~empty    50.999763  None  None     None
# 19856  FlatField position      SDSSr~empty    50.999762  None  None     None
# 19855  FlatField position      SDSSr~empty    50.999766  None  None     None
# 19854  FlatField position      SDSSr~empty    50.999764  None  None     None
# 19862  FlatField position      SDSSr~empty    50.999765  None  None     None
# 19852  FlatField position      SDSSr~empty    50.999765  None  None     None
# 19851  FlatField position      SDSSr~empty    50.999766  None  None     None
# 19819  FlatField position  SDSSr~holo4_003      50.9999  None  None     None
# 19818  FlatField position  SDSSr~holo4_003      50.9999  None  None     None
# 19817  FlatField position  SDSSr~holo4_003      50.9999  None  None     None
# 19816  FlatField position  SDSSr~holo4_003    50.999901  None  None     None
# 19815  FlatField position  SDSSr~holo4_003    50.999903  None  None     None
# 19814  FlatField position  SDSSr~holo4_003    50.999902  None  None     None
# 19813  FlatField position  SDSSr~holo4_003    50.999901  None  None     None
# 20397  FlatField position  SDSSr~holo4_003    50.999901  None  None     None
# 20392  FlatField position  SDSSr~holo4_003    50.999903  None  None     None
# 20393  FlatField position  SDSSr~holo4_003    50.999901  None  None     None
# 20394  FlatField position  SDSSr~holo4_003      50.9999  None  None     None
# 20395  FlatField position  SDSSr~holo4_003    50.999903  None  None     None
# 20396  FlatField position  SDSSr~holo4_003    50.999899  None  None     None
# 20398  FlatField position  SDSSr~holo4_003    50.999899  None  None     None
#
#        exptime
# 18262     6.00
# 18260     6.00
# 18264     6.00
# 18265     6.00
# 18266     6.00
# 18267     6.00
# 18268     6.00
# 18269     6.00
# 18263     6.00
# 19100     1.80
# 19106     5.60
# 19105     5.60
# 19104     3.80
# 19102     2.50
# 19101     2.50
# 19099     1.80
# 19103     3.80
# 19097     0.60
# 19080     1.00
# 19081     1.00
# 19093     0.10
# 19098     0.60
# 19095     0.35
# 19096     0.35
# 19094     0.10
# 19863     5.60
# 19853     0.35
# 19861     3.80
# 19858     2.50
# 19857     1.80
# 19856     1.80
# 19855     0.60
# 19854     0.60
# 19862     5.60
# 19852     0.10
# 19851     0.10
# 19819     5.60
# 19818     3.80
# 19817     2.50
# 19816     1.80
# 19815     0.60
# 19814     0.35
# 19813     0.10
# 20397     3.80
# 20392     0.10
# 20393     0.35
# 20394     0.60
# 20395     1.80
# 20396     2.50
# 20398     5.60

# %% [markdown]
# # List of dates

# %%
list_of_dates_flats = df_flat['day_obs'].unique() 
list_of_dates_flats
# Out:
# array([20210216, 20210217, 20210218, 20210311, 20210608, 20210609,
#        20210707, 20210708, 20210907, 20210908, 20210909, 20211005,
#        20211006, 20211007, 20211102, 20211104, 20220215, 20220216,
#        20220217, 20220315, 20220316, 20220317, 20220502, 20220503,
#        20220504, 20220524, 20220607, 20220608, 20220609, 20220628,
#        20220629, 20220630])

# %% [markdown]
# # List of filters

# %%
list_of_filters = df_flat['filter'].unique()
list_of_filters
# Out:
# array(['empty~empty', 'RG610~empty', 'empty~holo4_003', 'BG40~empty',
#        'FELH0600~empty', 'SDSSg~empty', 'SDSSr~empty', 'SDSSi~empty',
#        'SDSSg~holo4_003', 'SDSSr~holo4_003'], dtype=object)

# %% [markdown]
# # Selection of the filter

# %%
cut_filter = df_flat['filter'] == 'empty~empty'

# %%
for the_date in list_of_dates_flats:
    cut_date = df_flat['day_obs'] == the_date
    cut_combined = cut_date & cut_filter
    
    df_flat_this_date = df_flat[cut_combined]
    
    N = len(df_flat_this_date) 
    if N >0:
        print("=======================================================================")   
        print(f"{the_date} :: N={N}")
