# %% [markdown]
# # List of Exposures Biases
#
#
# - work with Weakly_2022_39
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/11/10

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/atmospec 	setup
# drp_pipe              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/drp_pipe 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_39/conda/envs/lsst-scipipe-4.1.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_39/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g0b29ad24fb+a10408d0bf 	w_latest current w_2022_39 setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs', 'seq_num', 'type', 'target','filter','zenith_angle','ra','dec','skyangle','exptime'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.tracking_ra, info.tracking_dec, info.sky_angle,info.exposure_time]
    
    if count < 2:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)
        print("\t exposure_time:       ",info.exposure_time)
# Out:
# ----------------------------------------------------- 0 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600208
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000208'
#   exposure_time: 2.0
#   dark_time: 2.33517265319824
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 208
#   group_name: '2021-02-17T03:35:45.035'
#   group_id: 1934625450350000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.384001783548
#   tracking_dec: -23.9734478006315
#   sky_angle: -180.0
#   zenith_angle: 24.314073266185005
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 03:35:45.295446', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 03:35:47.540000', scale='tai', format='iso'))
# 	 id:                   2021021600208
# 	 day_obs:              20210216
# 	 seq_num:              208
# 	 type-of-observation:  science
# 	 target:               HD 50896
# 	 exposure_time:        2.0
# ----------------------------------------------------- 1 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600163
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000163'
#   exposure_time: 3.0
#   dark_time: 3.3251359462738
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 163
#   group_name: '2021-02-17T00:50:15.536'
#   group_id: 1934526155360000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.404029472597
#   tracking_dec: -23.9293904683577
#   sky_angle: -208.6217120790572
#   zenith_angle: 14.580610783508703
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 00:50:15.703984', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 00:50:18.939000', scale='tai', format='iso'))
# 	 id:                   2021021600163
# 	 day_obs:              20210216
# 	 seq_num:              163
# 	 type-of-observation:  science
# 	 target:               HD 50896
# 	 exposure_time:        3.0

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs  seq_num     type  \
# 0      2021021600208  AT_O_20210216_000208  20210216      208  science
# 1      2021021600163  AT_O_20210216_000163  20210216      163  science
# 2      2021021600070  AT_O_20210216_000070  20210216       70     bias
# 3      2021021600173  AT_O_20210216_000173  20210216      173  science
# 4      2021021600001  AT_O_20210216_000001  20210216        1     bias
# ...              ...                   ...       ...      ...      ...
# 21152  2022063000801  AT_O_20220630_000801  20220630      801  science
# 21153  2022063000802  AT_O_20220630_000802  20220630      802  science
# 21154  2022063000803  AT_O_20220630_000803  20220630      803  science
# 21155  2022063000804  AT_O_20220630_000804  20220630      804  science
# 21156  2022063000805  AT_O_20220630_000805  20220630      805  science
#
#                                      target       filter zenith_angle  \
# 0                                  HD 50896  empty~empty    24.314073
# 1                                  HD 50896  RG610~empty    14.580611
# 2                               azel_target  empty~empty         None
# 3                                  HD 50896  RG610~empty      8.82931
# 4                               azel_target  empty~empty         None
# ...                                     ...          ...          ...
# 21152  AUXTEL_DRP_IMAGING:WFI-2026-4536_062  SDSSr~empty    36.396484
# 21153  AUXTEL_DRP_IMAGING:WFI-2026-4536_063  SDSSr~empty    36.437127
# 21154  AUXTEL_DRP_IMAGING:WFI-2026-4536_063  SDSSr~empty    36.530061
# 21155  AUXTEL_DRP_IMAGING:WFI-2026-4536_064  SDSSr~empty     36.57364
# 21156  AUXTEL_DRP_IMAGING:WFI-2026-4536_064  SDSSr~empty    36.666615
#
#                ra        dec    skyangle  exptime
# 0      103.384002 -23.973448      -180.0      2.0
# 1      103.404029  -23.92939 -208.621712      3.0
# 2            None       None        None      0.0
# 3      103.395986 -23.927038 -208.621712      2.0
# 4            None       None        None      0.0
# ...           ...        ...         ...      ...
# 21152  306.677395 -45.325215  359.998841     30.0
# 21153  306.811224 -45.325305    0.005404     30.0
# 21154  306.811146 -45.325195   359.99891     30.0
# 21155  306.944962 -45.325294  359.998843     30.0
# 21156  306.944896  -45.32522  359.998972     30.0
#
# [21157 rows x 12 columns]

# %% [markdown]
# ## Selection of biases

# %%
df_bias = df_exposure[df_exposure.type == 'bias']

# %%
df_bias.sort_values(by="day_obs",ascending=True,inplace=True)
# Out:
# /scratch/users/d/dagoret/ipykernel_17226/2002991969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bias.sort_values(by="day_obs",ascending=True,inplace=True)

# %%
df_bias.tail(50)
# Out:
#                   id                obs_id   day_obs  seq_num  type  \
# 17496  2022060800010  AT_O_20220608_000010  20220608       10  bias
# 17497  2022060800011  AT_O_20220608_000011  20220608       11  bias
# 17498  2022060800012  AT_O_20220608_000012  20220608       12  bias
# 17597  2022060800111  AT_O_20220608_000111  20220608      111  bias
# 17500  2022060800014  AT_O_20220608_000014  20220608       14  bias
# 17499  2022060800013  AT_O_20220608_000013  20220608       13  bias
# 17502  2022060800016  AT_O_20220608_000016  20220608       16  bias
# 17595  2022060800109  AT_O_20220608_000109  20220608      109  bias
# 17594  2022060800108  AT_O_20220608_000108  20220608      108  bias
# 17501  2022060800015  AT_O_20220608_000015  20220608       15  bias
# 17509  2022060800023  AT_O_20220608_000023  20220608       23  bias
# 17508  2022060800022  AT_O_20220608_000022  20220608       22  bias
# 17510  2022060800024  AT_O_20220608_000024  20220608       24  bias
# 17506  2022060800020  AT_O_20220608_000020  20220608       20  bias
# 17505  2022060800019  AT_O_20220608_000019  20220608       19  bias
# 17504  2022060800018  AT_O_20220608_000018  20220608       18  bias
# 17503  2022060800017  AT_O_20220608_000017  20220608       17  bias
# 17507  2022060800021  AT_O_20220608_000021  20220608       21  bias
# 18246  2022060900014  AT_O_20220609_000014  20220609       14  bias
# 18245  2022060900013  AT_O_20220609_000013  20220609       13  bias
# 18244  2022060900012  AT_O_20220609_000012  20220609       12  bias
# 18243  2022060900011  AT_O_20220609_000011  20220609       11  bias
# 18242  2022060900010  AT_O_20220609_000010  20220609       10  bias
# 18239  2022060900007  AT_O_20220609_000007  20220609        7  bias
# 18240  2022060900008  AT_O_20220609_000008  20220609        8  bias
# 18238  2022060900006  AT_O_20220609_000006  20220609        6  bias
# 18237  2022060900005  AT_O_20220609_000005  20220609        5  bias
# 18233  2022060900001  AT_O_20220609_000001  20220609        1  bias
# 18241  2022060900009  AT_O_20220609_000009  20220609        9  bias
# 19086  2022062800015  AT_O_20220628_000015  20220628       15  bias
# 19085  2022062800014  AT_O_20220628_000014  20220628       14  bias
# 19084  2022062800013  AT_O_20220628_000013  20220628       13  bias
# 19083  2022062800012  AT_O_20220628_000012  20220628       12  bias
# 19082  2022062800011  AT_O_20220628_000011  20220628       11  bias
# 18619  2022062800010  AT_O_20220628_000010  20220628       10  bias
# 18520  2022062800004  AT_O_20220628_000004  20220628        4  bias
# 19844  2022062900011  AT_O_20220629_000011  20220629       11  bias
# 19843  2022062900010  AT_O_20220629_000010  20220629       10  bias
# 19842  2022062900009  AT_O_20220629_000009  20220629        9  bias
# 19841  2022062900008  AT_O_20220629_000008  20220629        8  bias
# 19840  2022062900007  AT_O_20220629_000007  20220629        7  bias
# 19376  2022062900001  AT_O_20220629_000001  20220629        1  bias
# 19839  2022062900006  AT_O_20220629_000006  20220629        6  bias
# 19809  2022063000008  AT_O_20220630_000008  20220630        8  bias
# 19808  2022063000006  AT_O_20220630_000006  20220630        6  bias
# 19807  2022063000003  AT_O_20220630_000003  20220630        3  bias
# 19806  2022063000001  AT_O_20220630_000001  20220630        1  bias
# 20387  2022063000005  AT_O_20220630_000005  20220630        5  bias
# 20071  2022063000004  AT_O_20220630_000004  20220630        4  bias
# 20388  2022063000007  AT_O_20220630_000007  20220630        7  bias
#
#                    target               filter zenith_angle    ra   dec  \
# 17496  FlatField position          empty~empty         None  None  None
# 17497  FlatField position          empty~empty         None  None  None
# 17498  FlatField position          empty~empty         None  None  None
# 17597  FlatField position       FELH0600~empty         None  None  None
# 17500  FlatField position          empty~empty         None  None  None
# 17499  FlatField position          empty~empty         None  None  None
# 17502  FlatField position          empty~empty         None  None  None
# 17595  FlatField position       FELH0600~empty         None  None  None
# 17594  FlatField position       FELH0600~empty         None  None  None
# 17501  FlatField position          empty~empty         None  None  None
# 17509  FlatField position          empty~empty         None  None  None
# 17508  FlatField position          empty~empty         None  None  None
# 17510  FlatField position          empty~empty         None  None  None
# 17506  FlatField position          empty~empty         None  None  None
# 17505  FlatField position          empty~empty         None  None  None
# 17504  FlatField position          empty~empty         None  None  None
# 17503  FlatField position          empty~empty         None  None  None
# 17507  FlatField position          empty~empty         None  None  None
# 18246  FlatField position          empty~empty         None  None  None
# 18245  FlatField position          empty~empty         None  None  None
# 18244  FlatField position          empty~empty         None  None  None
# 18243  FlatField position          empty~empty         None  None  None
# 18242  FlatField position          empty~empty         None  None  None
# 18239  FlatField position          empty~empty         None  None  None
# 18240  FlatField position          empty~empty         None  None  None
# 18238  FlatField position          empty~empty         None  None  None
# 18237  FlatField position          empty~empty         None  None  None
# 18233       Park position  empty~ronchi170lpmm         None  None  None
# 18241  FlatField position          empty~empty         None  None  None
# 19086  FlatField position       FELH0600~empty         None  None  None
# 19085  FlatField position       FELH0600~empty         None  None  None
# 19084  FlatField position       FELH0600~empty         None  None  None
# 19083  FlatField position       FELH0600~empty         None  None  None
# 19082  FlatField position       FELH0600~empty         None  None  None
# 18619  FlatField position       FELH0600~empty         None  None  None
# 18520       Park position          SDSSr~empty         None  None  None
# 19844  FlatField position          SDSSr~empty         None  None  None
# 19843  FlatField position          SDSSr~empty         None  None  None
# 19842  FlatField position          SDSSr~empty         None  None  None
# 19841  FlatField position          SDSSr~empty         None  None  None
# 19840  FlatField position          SDSSr~empty         None  None  None
# 19376       Park position          SDSSr~empty         None  None  None
# 19839  FlatField position          SDSSr~empty         None  None  None
# 19809  FlatField position      SDSSr~holo4_003         None  None  None
# 19808  FlatField position      SDSSr~holo4_003         None  None  None
# 19807  FlatField position      SDSSr~holo4_003         None  None  None
# 19806       Park position          SDSSr~empty         None  None  None
# 20387  FlatField position      SDSSr~holo4_003         None  None  None
# 20071  FlatField position      SDSSr~holo4_003         None  None  None
# 20388  FlatField position      SDSSr~holo4_003         None  None  None
#
#       skyangle  exptime
# 17496     None      0.0
# 17497     None      0.0
# 17498     None      0.0
# 17597     None      0.0
# 17500     None      0.0
# 17499     None      0.0
# 17502     None      0.0
# 17595     None      0.0
# 17594     None      0.0
# 17501     None      0.0
# 17509     None      0.0
# 17508     None      0.0
# 17510     None      0.0
# 17506     None      0.0
# 17505     None      0.0
# 17504     None      0.0
# 17503     None      0.0
# 17507     None      0.0
# 18246     None      0.0
# 18245     None      0.0
# 18244     None      0.0
# 18243     None      0.0
# 18242     None      0.0
# 18239     None      0.0
# 18240     None      0.0
# 18238     None      0.0
# 18237     None      0.0
# 18233     None      0.0
# 18241     None      0.0
# 19086     None      0.0
# 19085     None      0.0
# 19084     None      0.0
# 19083     None      0.0
# 19082     None      0.0
# 18619     None      0.0
# 18520     None      0.0
# 19844     None      0.0
# 19843     None      0.0
# 19842     None      0.0
# 19841     None      0.0
# 19840     None      0.0
# 19376     None      0.0
# 19839     None      0.0
# 19809     None      0.0
# 19808     None      0.0
# 19807     None      0.0
# 19806     None      0.0
# 20387     None      0.0
# 20071     None      0.0
# 20388     None      0.0

# %% [markdown]
# # List of dates

# %%
list_of_dates_bias = df_bias['day_obs'].unique() 
list_of_dates_bias
# Out:
# array([20210216, 20210217, 20210218, 20210311, 20210608, 20210609,
#        20210610, 20210706, 20210707, 20210708, 20210907, 20210908,
#        20210909, 20211005, 20211006, 20211007, 20211102, 20211103,
#        20211104, 20220215, 20220216, 20220217, 20220315, 20220316,
#        20220317, 20220318, 20220502, 20220503, 20220504, 20220524,
#        20220607, 20220608, 20220609, 20220628, 20220629, 20220630])

# %% [markdown]
# # List of filters

# %%
list_of_filters = df_flat['filter'].unique()
list_of_filters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 list_of_filters = df_flat['filter'].unique()
#       2 list_of_filters
#
# NameError: name 'df_flat' is not defined

# %%
assert False

# %% [markdown]
# # Selection of the filter

# %%
cut_filter = df_flat['filter'] == 'empty~empty'

# %%
for the_date in list_of_dates_flats:
    cut_date = df_flat['day_obs'] == the_date
    cut_combined = cut_date & cut_filter
    
    df_flat_this_date = df_flat[cut_combined]
    
    N = len(df_flat_this_date) 
    if N >0:
        print("=======================================================================")   
        print(f"{the_date} :: N={N}")
        print(df_flat_this_date.id.values)
