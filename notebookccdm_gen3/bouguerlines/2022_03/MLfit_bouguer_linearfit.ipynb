# %% [markdown]
# # Linear fit of Bouguer lines on  AuxTel Data

# %% [markdown]
# Read the spectra from Pic du Midi (2019).
# The spectra has been reconstructed by Spectractor.
# The Spectra in fits file has been converted into panda in
#
#
# - author Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNRS
# - creation date : April 7th 2022
# - updatedate : April 19th 2022

# %% [markdown]
# # Import

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.cm as cm 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import os,sys,re

from astropy.io import fits
import matplotlib.colors as colors
import matplotlib.cm as cmx
import matplotlib.dates as mdates
from matplotlib import gridspec
# %matplotlib inline
import pickle

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (10, 6),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
pysynphot_root_path=os.environ['PYSYN_CDBS']
path_sed_calspec=os.path.join(pysynphot_root_path,'calspec')
# pysynphot
import pysynphot as S
S.refs.setref(area=1)
S.refs.getref()
# Out:
# {'graphtable': '/sps/lsst/groups/auxtel/softs/utils/PySynPhotData/grp/hst/cdbs/mtab/41g16069m_tmg.fits',
#  'comptable': '/sps/lsst/groups/auxtel/softs/utils/PySynPhotData/grp/hst/cdbs/mtab/49i2235im_tmc.fits',
#  'thermtable': '/sps/lsst/groups/auxtel/softs/utils/PySynPhotData/grp/hst/cdbs/mtab/3241637sm_tmt.fits',
#  'area': 1,
#  'waveset': 'Min: 500, Max: 26000, Num: 10000, Delta: None, Log: True'}

# %%
import time
from datetime import datetime,date
import dateutil.parser
import pytz

import argparse

import logging
import coloredlogs
import configparser

# %%
from scipy import interpolate

# %% [markdown]
# # Functions

# %%
def find_nearest(a, a0):
    "Element in nd array `a` closest to the scalar value `a0`"
    idx = np.abs(a - a0).argmin()
    return a.flat[idx],int(idx)

# %%
def GetSpectra(dict_spectra):
    """
    GetSpectra(dict_spectra)
    
    input:
      - dict_spectra : dictionnary of input spectra
      
      
      {'number': 238.0, 'object': 'mu. Col', 'dateobs': '2022-03-18T00:51:22.049', 'refhour': 0.0, 'airmass': 1.11557476948966, 'pressure': 743.45, 'temperature': 8.9, 
      'humidity': 48.0, 'targetx_pix': 312.7442668572934, 'targety_pix': 1738.0006619324693, 'rotangle': 0.1753951396614214, 'd2ccd': 181.0974436798836, 
      'all_lambdas': array([ 302.20970512,  302.91544585,  303.62117594, ..., 1108.67461764,
       1109.35162338, 1110.02859124]), 'all_fluxes': array([1.04110833e-13, 9.83856109e-14, 8.99209206e-14, ...,
       5.34113538e-13, 5.36905940e-13, 5.53127394e-13]), 'all_fluxes_err': array([3.51303583e-15, 3.10100695e-15, 2.58677333e-15, ...,
       3.34568263e-15, 4.01784054e-15, 4.54242555e-15]), 'all_lambdas_order2': array([ 302.24857475,  302.9543149 ,  303.66004442, ..., 1108.71192607,
       1109.38892974, 1110.06589555]), 'all_fluxes_order2': array([420.23653349, 386.95227531, 344.90384603, ...,  60.47440612,
        60.74615545,  62.53491353]), 'all_fluxes_err_order2': array([14.15542468, 12.17674916,  9.90751987, ...,  0.37846535,
        0.45415764,  0.51307916])}
      
    
    return
      - list of dataframes
    """
    
    list_of_columns = ["number","object",'dateobs','refhour','airmass','pressure','temperature','humidity','filename']   

    all_df = []  # container for spectra
    
    df_info = pd.DataFrame(columns=list_of_columns)
    
    idx=0
    for key, value in dict_spectra.items():
        
        df_info.loc[idx] = [int(value["number"]),value["object"],value["dateobs"],value["refhour"],value["airmass"],value["pressure"],value["temperature"],value["humidity"],key]
         
        df = pd.DataFrame()
        df["all_lambdas"] = value["all_lambdas"]
        df["all_fluxes"] = value["all_fluxes"]
        df["all_fluxes_err"] = value["all_fluxes_err"]
        
        if 'all_lambdas_order2' in value.keys():
            df["all_lambdas_order2"] = value["all_lambdas_order2"]
            df["all_fluxes_order2"] = value["all_fluxes_order2"]
            df["all_fluxes_err_order2"] = value["all_fluxes_err_order2"]
            
        
        all_df.append(df)
        
        
        idx+=1
        
    return df_info , all_df

# %%
def GetSpectraFiltered(dict_spectra,list_of_bad_spectra):
    """
    GetSpectraFiltered(inputdir,inputfiles)
    
    input:
      - dict_spectra
      - ist_of_bad_spectra
    
    return
      - filtered infos, filtered spectra
    """
    
    
    
    list_of_columns = ["number","object",'dateobs','refhour','airmass','pressure','temperature','humidity','filename']   

    all_df = []  # container for spectra
    
    df_info = pd.DataFrame(columns=list_of_columns)
    
    idx=0       # counter on input spectra
    idx_out = 0 # counter on save spectra
    for key, value in dict_spectra.items():
        
        
        if int(value["number"]) not in list_of_bad_spectra:
        
            df_info.loc[idx_out] = [int(value["number"]),value["object"],value["dateobs"],value["refhour"],value["airmass"],value["pressure"],value["temperature"],value["humidity"],key]
         
            df = pd.DataFrame()
            df["all_lambdas"] = value["all_lambdas"]
            df["all_fluxes"] = value["all_fluxes"]
            df["all_fluxes_err"] = value["all_fluxes_err"]
        
            if 'all_lambdas_order2' in value.keys():
                df["all_lambdas_order2"] = value["all_lambdas_order2"]
                df["all_fluxes_order2"] = value["all_fluxes_order2"]
                df["all_fluxes_err_order2"] = value["all_fluxes_err_order2"]
               
            all_df.append(df)
            idx_out+=1  # increase count on saved spectra
            
        else:
            num = int(value["number"])
            msg = f"Remove spectrum {idx} for exposure {num}"
            print(msg)
            
        idx+=1
            

        
    return df_info,all_df

# %%
def ConvertToImage(info, all_df,WLMIN=350,WLMAX=1100):
    """
    
    call 
    WL,Mags1,EMags1,AirM,Tim = ConvertToImage(info,all_spectra,WLMIN= WLMINSEL ,WLMAX= WLMAXSEL)
    
    
    
    
    
    """
    
    N=len(all_df)
    WL=np.arange(WLMIN,WLMAX+1)
    NWL=len(WL)
    
    mag_table=np.zeros((N,NWL))   # table of  magnitudes
    emag_table=np.zeros((N,NWL))  # table of error on magnitudes
    
    
    airm_table=np.zeros(N)
    time_table=np.zeros(N)
    
    for idx in np.arange(N):
        df=all_df[idx]
        
        mag = -2.5*np.log10(df["all_fluxes"])
        errmag = 2.5/np.log(10) * df["all_fluxes_err"]/df["all_fluxes"]
        wavelength = df["all_lambdas"]
        fcn = interpolate.interp1d(wavelength,mag,bounds_error=False,fill_value=(0,0))
        fcn2 = interpolate.interp1d(wavelength,errmag,bounds_error=False,fill_value=(0,0))
            
        mag_table[idx,:] = fcn(WL) 
        emag_table[idx,:] = fcn2(WL) 
        
        airm_table[idx]  = info["airmass"][idx]
        time_table[idx]  = info["refhour"][idx]
        
    return WL, mag_table, emag_table,airm_table,time_table

# %%
def GetBouguerLinesTim(Npoints,wl,tim,magref ,emag,title="log of atmospheric transmission vs time",FLAG_PLOT=True,YMIN=0,YMAX=0):
    """
    
    """
    
    WLMIN=wl.min()
    WLMAX=wl.max()
    
    wl_sel=np.linspace(WLMIN,WLMAX,Npoints)
    wl_label = [ "{:3.0f} nm".format(w) for w in wl_sel]
    iwl_sel=[ find_nearest(wl, wl0)[1] for wl0 in wl_sel]
    NIWSEL=len(iwl_sel)
    
    Mags=np.zeros(NIWSEL)
    EMags=np.zeros(NIWSEL)
    
    N=NIWSEL
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
    the_x=tim
    
    
    x_fit=np.linspace(0,the_x.max(),100)
    
    if FLAG_PLOT:
        fig=plt.figure(figsize=(15,8))
        ax=fig.add_subplot(111)

    for idx in np.arange(N):
        iwl=iwl_sel[idx]
        
        the_y=magref[:,iwl]
        the_ey=emag[:,iwl]
        the_ey=np.where(the_ey>1,0,the_ey)
        
        

        if FLAG_PLOT:
            ax.plot(the_x,the_y,'+',color=all_colors[idx],label=wl_label[idx])
            ax.errorbar(the_x,the_y,yerr=the_ey, fmt = '+', color=all_colors[idx],capsize = 1., ecolor=all_colors[idx], elinewidth = 1.)
    
        
    
    
    if FLAG_PLOT:
        ax.legend(loc='upper right')
        ax.set_xlim(0,the_x.max()*1.2)
        ax.grid()
        ax.set_xlabel("time (Hour)")
        ax.set_ylabel("log transmission atmosphere (mag)")
        ax.set_title(title)
        if not (YMIN==0 and YMAX==0) and (YMAX>YMIN):
            ax.set_ylim(YMIN,YMAX)
        plt.show()
        
     
    return

# %%
def GetBouguerLinesAtm(Npoints,wl,airmass,magref ,emag,title="log of atmospheric transmission vs airmass",FLAG_PLOT=True,YMIN=0,YMAX=0):
    """
    
    """
    
    WLMIN=wl.min()
    WLMAX=wl.max()
    
    wl_sel=np.linspace(WLMIN,WLMAX,Npoints)
    wl_label = [ "{:3.0f} nm".format(w) for w in wl_sel]
    iwl_sel=[ find_nearest(wl, wl0)[1] for wl0 in wl_sel]
    NIWSEL=len(iwl_sel)
    
    Mags=np.zeros(NIWSEL)
    EMags=np.zeros(NIWSEL)
    
    N=NIWSEL
    jet = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0, vmax=N)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
    all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)
    
    the_x=airmass
    
    
    x_fit=np.linspace(0,the_x.max(),100)
    
    if FLAG_PLOT:
        fig=plt.figure(figsize=(15,8))
        ax=fig.add_subplot(111)

    for idx in np.arange(N):
        iwl=iwl_sel[idx]
        
        the_y=magref[:,iwl]
        the_ey=emag[:,iwl]
        the_ey=np.where(the_ey>1,0,the_ey)
        

        if FLAG_PLOT:
            ax.plot(the_x,the_y,'+',color=all_colors[idx],label=wl_label[idx])
            ax.errorbar(the_x,the_y,yerr=the_ey, fmt = '+', color=all_colors[idx],capsize = 1, ecolor=all_colors[idx], elinewidth =1)
    
        # fit
        popt,cov = np.polyfit(the_x, the_y, 1,cov=True)
        perr=np.sqrt(np.diag(cov))
        nstd=1
        sigmaf=np.sqrt(x_fit**2*cov[0,0]+cov[1,1]+x_fit*(cov[0,1]+cov[1,0]))
        
        Mags[idx]=popt[-1]
        EMags[idx]=sigmaf[0]
        
        p = np.poly1d(popt)
        
        y_fit=p(x_fit)
        y_fit_up=y_fit+nstd*sigmaf
        y_fit_dw=y_fit-nstd*sigmaf
        
        if FLAG_PLOT:
            ax.plot(x_fit,y_fit,'-',color=all_colors[idx])
            ax.fill_between(x_fit,y_fit_up, y_fit_dw, alpha=.25, color="gray")
    
    
    if FLAG_PLOT:
        ax.legend()
        ax.set_xlim(0,the_x.max())
        ax.grid()
        ax.set_xlabel("airmass")
        ax.set_ylabel("log transmission atmosphere (mag)")
        ax.set_title(title)
        if not (YMIN==0 and YMAX==0) and (YMAX>YMIN):
            ax.set_ylim(YMIN,YMAX)
        plt.show()
     
    return wl_sel,Mags,EMags

# %% [markdown]
# # Constants

# %% [markdown]
# # Initialisation

# %%
# start with logs
#-----------------
logging.basicConfig()
logging.root.setLevel(logging.NOTSET)

handle = __name__

logger = logging.getLogger(handle)
# logging.getLogger().setLevel(logging.INFO)
logger.setLevel(logging.DEBUG)

# If you don't want to see log messages from libraries, you can pass a
# specific logger object to the install() function. In this case only log
# messages originating from that logger will show up on the terminal.
coloredlogs.install(level='DEBUG', logger=logger)
coloredlogs.install(fmt='%(asctime)s,%(msecs)03d %(hostname)s %(name)s[%(process)d] %(levelname)s %(message)s')

# %%
# set time
# date
today = date.today()
string_date = today.strftime("%Y-%m-%d")

# time
now = datetime.now()
current_time = now.strftime("%H:%M:%S")

tim = time.localtime()
current_time = time.strftime("%H:%M:%S", tim)

# timezones
tz_LA = pytz.timezone('America/Los_Angeles')
datetime_LA = datetime.now(tz_LA)
msg="LA time:"+  datetime_LA.strftime("%H:%M:%S")
logger.info(msg)

tz_NY = pytz.timezone('America/New_York')
datetime_NY = datetime.now(tz_NY)
msg="NY time:"+ datetime_NY.strftime("%H:%M:%S")
logger.info(msg)

tz_London = pytz.timezone('Europe/London')
datetime_London = datetime.now(tz_London)
msg="London time:"+ datetime_London.strftime("%H:%M:%S")
logger.info(msg)

tz_Paris = pytz.timezone('Europe/Paris')
datetime_Paris = datetime.now(tz_Paris)
msg="Paris time:"+ datetime_Paris.strftime("%H:%M:%S")
logger.info(msg)

msg="************************ START *********************"
logger.info(msg)
# Out:
# 2022-04-19 16:59:42,305 jns-dagoret.cc.in2p3.fr __main__[1972] INFO LA time:07:59:42
# 2022-04-19 16:59:42,307 jns-dagoret.cc.in2p3.fr __main__[1972] INFO NY time:10:59:42
# 2022-04-19 16:59:42,309 jns-dagoret.cc.in2p3.fr __main__[1972] INFO London time:15:59:42
# 2022-04-19 16:59:42,311 jns-dagoret.cc.in2p3.fr __main__[1972] INFO Paris time:16:59:42
# 2022-04-19 16:59:42,312 jns-dagoret.cc.in2p3.fr __main__[1972] INFO ************************ START *********************

# %%
# arguments
#----------

parser = argparse.ArgumentParser()
parser.add_argument("--config",action="store", dest="configfile",help=f" run generate -config configfilename, with by ex configfilename = default.ini")
#results_args = parser.parse_args()

results_args=""

# %% [markdown]
# # Configuration

# %%
# config file
# --------------
#configfile = "config/default.ini"
configfile = "config/confprog_run-auxtel-holo-20220317-configHb.ini"
#config_filename = results_args.configfile
config_filename = configfile
msg = f"Configuration file : {config_filename}"
logger.info(msg)
# Out:
# 2022-04-19 16:59:42,337 jns-dagoret.cc.in2p3.fr __main__[1972] INFO Configuration file : config/confprog_run-auxtel-holo-20220317-configHb.ini

# %%
# 1) CONFIGURATION
#------------------
logger.info('1) Configuration')

config = configparser.ConfigParser()

if os.path.exists(config_filename):
    config.read(config_filename)
else:
    msg = f"config file {config_filename} does not exist !"
    logger.error(msg)
# Out:
# 2022-04-19 16:59:42,354 jns-dagoret.cc.in2p3.fr __main__[1972] INFO 1) Configuration

# %%
config_section = config.sections()

# %%
if len(config_section) == 0:
    msg = f"empty config file {config_filename} !"
    logger.error(msg)

# %%
if 'GENERAL' in config_section:

    FLAG_DEBUG = bool(int(config['GENERAL']['FLAG_DEBUG']))
    FLAG_VERBOSE = bool(int(config['GENERAL']['FLAG_VERBOSE']))
    FLAG_PLOT   = bool(int(config['GENERAL']['FLAG_PLOT']))
    FLAG_PRINT  = bool(int(config['GENERAL']['FLAG_PRINT']))
    
    SITE          = config['GENERAL']['SITE']
    DATE          = config['GENERAL']['DATE']
    
    inputdir    = config['GENERAL']['inputdir']
    inputfile   = config['GENERAL']['inputfile']
    target      = config['GENERAL']['object']
    sedfilename = config['GENERAL']['sedfilename']
    normalisationfactor = float(config['GENERAL']['normalisationfactor'])
    WLMINSEL      = float(config['GENERAL']['WLMINSEL'])
    WLMAXSEL      = float(config['GENERAL']['WLMAXSEL'])
    NPOINTSVIEW       =    int(config['GENERAL']['NPOINTSVIEW']) 
    NPOINTSSAVE       =    int(config['GENERAL']['NPOINTSSAVE']) 
    outputfile_linearfit =  config['GENERAL']['outputfile_linearfit']
    outputfile_gp        =  config['GENERAL']['outputfile_gp']
    
    BADEXPOS = config['GENERAL']['BADEXPOS']
    

else:
    msg = f"Configuration file : empty section GENERAL in config file {config_filename} !"   
    logger.error(msg)

# %%
msg=f" Object observed {target} at {SITE} ({DATE})"
logger.info(msg)
# Out:
# 2022-04-19 16:59:42,417 jns-dagoret.cc.in2p3.fr __main__[1972] INFO  Object observed MU col at AUXTEL/Rubin Obs (2022-03-17)

# %%
input_file_split=inputfile.split(".")    
basefilename=input_file_split[0]
extendfilename=input_file_split[1]

# %%
inputfile
# Out:
# 'run-auxtel-holo-20220317-configHb.pickle'

# %%
list_of_badnums = [int(nn)  for nn in BADEXPOS.split()]

list_of_badnums
# Out:
# [251, 300, 301, 428, 429]

# %% [markdown]
# # input files

# %% [markdown]
# ## Get Calspec SED

# %% [markdown]
# - Notice we use a relative normalisation factor

# %%
s0=S.FileSpectrum(os.path.join(path_sed_calspec,sedfilename))

# %%
sed_w=s0.wave/10
sed_f=s0.flux*10*normalisationfactor
sed_idx=np.where(np.logical_and(sed_w>350,sed_w<1100))[0]
sed_w=sed_w[sed_idx]
sed_f=sed_f[sed_idx]

# %%
sed_m=-2.5*np.log10(sed_f)

# %% [markdown]
# ## spectrum data

# %%
fullfilename=os.path.join(inputdir,inputfile)

# %%
with open(fullfilename, 'rb') as f:
    summary_content = pickle.load(f)

# %%
NBSPECTRA=len(summary_content)

# %%
msg=f" Number of selected files is {NBSPECTRA}"
logger.info(msg)
# Out:
# 2022-04-19 16:59:42,558 jns-dagoret.cc.in2p3.fr __main__[1972] INFO  Number of selected files is 44

# %%
# wavelength bin colors
jet = plt.get_cmap('jet')
cNorm = colors.Normalize(vmin=0, vmax=NBSPECTRA)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
all_colors = scalarMap.to_rgba(np.arange(NBSPECTRA), alpha=1)

# %% [markdown]
# ### Read all files

# %%
info, all_spectra  = all_df=GetSpectra(summary_content)

# %%
info
# Out:
#     number    object                  dateobs   refhour   airmass  pressure  \
# 0      238   mu. Col  2022-03-18T00:51:22.049  0.000000  1.115575    743.45
# 1      244   mu. Col  2022-03-18T00:54:16.312  0.048406  1.121577    743.45
# 2      245   mu. Col  2022-03-18T00:54:49.235  0.057552  1.122727    743.40
# 3      251   mu. Col  2022-03-18T00:57:47.565  0.107088  1.129107    743.40
# 4      252   mu. Col  2022-03-18T00:58:20.709  0.116294  1.130309    743.40
# 5      265   mu. Col  2022-03-18T01:04:49.716  0.224352  1.145030    743.30
# 6      272   mu. Col  2022-03-18T01:08:18.080  0.282231  1.153339    743.30
# 7      273   mu. Col  2022-03-18T01:08:50.992  0.291373  1.154683    743.35
# 8      279   mu. Col  2022-03-18T01:11:46.031  0.339995  1.161939    743.40
# 9      286   mu. Col  2022-03-18T01:15:18.583  0.399037  1.171053    743.45
# 10     293   mu. Col  2022-03-18T01:18:45.526  0.456521  1.180249    743.45
# 11     300   mu. Col  2022-03-18T01:22:16.238  0.515053  1.189962    743.40
# 12     301   mu. Col  2022-03-18T01:22:49.144  0.524193  1.191505    743.45
# 13     310   mu. Col  2022-03-18T01:43:57.837  0.876608  1.258227    743.55
# 14     316   mu. Col  2022-03-18T01:46:52.361  0.925087  1.268584    743.55
# 15     317   mu. Col  2022-03-18T01:47:25.256  0.934224  1.270563    743.55
# 16     330   mu. Col  2022-03-18T01:53:46.736  1.040191  1.294394    743.50
# 17     331   mu. Col  2022-03-18T01:54:19.724  1.049354  1.296523    743.50
# 18     338   mu. Col  2022-03-18T01:57:49.306  1.107571  1.310358    743.45
# 19     345   mu. Col  2022-03-18T02:01:19.196  1.165874  1.324717    743.45
# 20     351   mu. Col  2022-03-18T02:04:16.794  1.215207  1.337275    743.45
# 21     352   mu. Col  2022-03-18T02:04:49.712  1.224351  1.339637    743.35
# 22     358   mu. Col  2022-03-18T02:07:49.074  1.274174  1.352787    743.40
# 23     365   mu. Col  2022-03-18T02:11:20.051  1.332778  1.368766    743.40
# 24     366   mu. Col  2022-03-18T02:11:53.006  1.341933  1.371319    743.45
# 25     372   mu. Col  2022-03-18T02:14:46.798  1.390208  1.385012    743.45
# 26     373   mu. Col  2022-03-18T02:15:19.743  1.399359  1.387650    743.45
# 27     380   mu. Col  2022-03-18T02:33:33.012  1.703045  1.484524    743.35
# 28     386   mu. Col  2022-03-18T02:36:30.874  1.752451  1.502136    743.45
# 29     387   mu. Col  2022-03-18T02:37:03.815  1.761602  1.505457    743.35
# 30     393   mu. Col  2022-03-18T02:40:00.839  1.810775  1.523658    743.40
# 31     394   mu. Col  2022-03-18T02:40:33.787  1.819927  1.527115    743.40
# 32     401   mu. Col  2022-03-18T02:44:05.105  1.878627  1.549764    743.45
# 33     407   mu. Col  2022-03-18T02:47:02.835  1.927996  1.569520    743.40
# 34     408   mu. Col  2022-03-18T02:47:35.769  1.937144  1.573248    743.45
# 35     414   mu. Col  2022-03-18T02:50:38.306  1.987849  1.594345    743.45
# 36     421   mu. Col  2022-03-18T03:08:41.573  2.288757  1.735941    743.50
# 37     422   mu. Col  2022-03-18T03:09:14.484  2.297899  1.740715    743.50
# 38     428  HD185975  2022-03-18T03:12:54.310  2.358961  2.129246    743.50
# 39     429  HD185975  2022-03-18T03:13:27.208  2.368100  2.129068    743.50
# 40     435   mu. Col  2022-03-18T03:17:06.794  2.429096  1.813094    743.45
# 41     436   mu. Col  2022-03-18T03:17:39.779  2.438258  1.818418    743.40
# 42     442   mu. Col  2022-03-18T03:21:26.873  2.501340  1.856070    743.40
# 43     443   mu. Col  2022-03-18T03:21:59.878  2.510508  1.861692    743.45
#
#     temperature  humidity                                         filename
# 0           8.9      48.0  exposure_2022031700238_postisrccd_spectrum.fits
# 1           8.9      49.0  exposure_2022031700244_postisrccd_spectrum.fits
# 2           8.8      49.0  exposure_2022031700245_postisrccd_spectrum.fits
# 3           8.9      50.0  exposure_2022031700251_postisrccd_spectrum.fits
# 4           8.9      50.0  exposure_2022031700252_postisrccd_spectrum.fits
# 5           8.9      53.0  exposure_2022031700265_postisrccd_spectrum.fits
# 6           8.9      51.0  exposure_2022031700272_postisrccd_spectrum.fits
# 7           8.9      51.0  exposure_2022031700273_postisrccd_spectrum.fits
# 8           8.9      53.0  exposure_2022031700279_postisrccd_spectrum.fits
# 9           8.9      54.0  exposure_2022031700286_postisrccd_spectrum.fits
# 10          9.0      53.0  exposure_2022031700293_postisrccd_spectrum.fits
# 11          8.9      56.0  exposure_2022031700300_postisrccd_spectrum.fits
# 12          9.0      56.0  exposure_2022031700301_postisrccd_spectrum.fits
# 13          8.8      56.0  exposure_2022031700310_postisrccd_spectrum.fits
# 14          8.7      56.0  exposure_2022031700316_postisrccd_spectrum.fits
# 15          8.7      56.0  exposure_2022031700317_postisrccd_spectrum.fits
# 16          8.6      56.0  exposure_2022031700330_postisrccd_spectrum.fits
# 17          8.6      56.0  exposure_2022031700331_postisrccd_spectrum.fits
# 18          8.7      57.0  exposure_2022031700338_postisrccd_spectrum.fits
# 19          8.6      59.0  exposure_2022031700345_postisrccd_spectrum.fits
# 20          8.5      58.0  exposure_2022031700351_postisrccd_spectrum.fits
# 21          8.5      58.0  exposure_2022031700352_postisrccd_spectrum.fits
# 22          8.4      59.0  exposure_2022031700358_postisrccd_spectrum.fits
# 23          8.4      59.0  exposure_2022031700365_postisrccd_spectrum.fits
# 24          8.4      59.0  exposure_2022031700366_postisrccd_spectrum.fits
# 25          8.4      61.0  exposure_2022031700372_postisrccd_spectrum.fits
# 26          8.4      61.0  exposure_2022031700373_postisrccd_spectrum.fits
# 27          8.0      63.0  exposure_2022031700380_postisrccd_spectrum.fits
# 28          8.1      64.0  exposure_2022031700386_postisrccd_spectrum.fits
# 29          8.1      64.0  exposure_2022031700387_postisrccd_spectrum.fits
# 30          8.0      64.0  exposure_2022031700393_postisrccd_spectrum.fits
# 31          8.0      64.0  exposure_2022031700394_postisrccd_spectrum.fits
# 32          8.0      64.0  exposure_2022031700401_postisrccd_spectrum.fits
# 33          8.0      64.0  exposure_2022031700407_postisrccd_spectrum.fits
# 34          8.0      64.0  exposure_2022031700408_postisrccd_spectrum.fits
# 35          8.0      63.0  exposure_2022031700414_postisrccd_spectrum.fits
# 36          7.7      63.0  exposure_2022031700421_postisrccd_spectrum.fits
# 37          7.7      63.0  exposure_2022031700422_postisrccd_spectrum.fits
# 38          7.8      62.0  exposure_2022031700428_postisrccd_spectrum.fits
# 39          7.8      62.0  exposure_2022031700429_postisrccd_spectrum.fits
# 40          7.7      63.0  exposure_2022031700435_postisrccd_spectrum.fits
# 41          7.7      63.0  exposure_2022031700436_postisrccd_spectrum.fits
# 42          7.8      62.0  exposure_2022031700442_postisrccd_spectrum.fits
# 43          7.7      63.0  exposure_2022031700443_postisrccd_spectrum.fits

# %%
all_spectra[0].head()
# Out:
#    all_lambdas    all_fluxes  all_fluxes_err  all_lambdas_order2  \
# 0   302.209705  1.041108e-13    3.513036e-15          302.248575
# 1   302.915446  9.838561e-14    3.101007e-15          302.954315
# 2   303.621176  8.992092e-14    2.586773e-15          303.660044
# 3   304.326895  7.665794e-14    2.160885e-15          304.365763
# 4   305.032604  6.365679e-14    1.933779e-15          305.071471
#
#    all_fluxes_order2  all_fluxes_err_order2
# 0         420.236533              14.155425
# 1         386.952275              12.176749
# 2         344.903846               9.907520
# 3         286.837179               8.072919
# 4         232.392431               7.047083

# %%
# wavelength bin colors
jet = plt.get_cmap('jet')
cNorm = colors.Normalize(vmin=0, vmax=NBSPECTRA)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
all_colors = scalarMap.to_rgba(np.arange(NBSPECTRA), alpha=1)

# %%
msg=f" Number of good spectra is {NBSPECTRA}"
logger.info(msg)
# Out:
# 2022-04-19 16:59:42,873 jns-dagoret.cc.in2p3.fr __main__[1972] INFO  Number of good spectra is 44

# %%
fig=plt.figure(figsize=(16,10))
ax=fig.add_subplot(111)
for ifile in np.arange(NBSPECTRA):
    the_df=all_spectra[ifile]
    airmassvalue = info.iloc[ifile]["airmass"]
    label_airmass = f" z = {airmassvalue:.3f}"
    #ax.plot(the_df.wavelength,the_df.flux,color=all_colors[ifile])
    ax.errorbar(the_df.all_lambdas,the_df.all_fluxes,yerr=the_df.all_fluxes_err, fmt = '-', color=all_colors[ifile],capsize = 0.1, ecolor=all_colors[ifile], elinewidth = .1,label=label_airmass)
ax.grid()
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("flux (erg/sec/m$^2$/nm)")
title=f"Spectra of {target} observed at {SITE} ({DATE})"
ax.set_title(title)
ax.plot(sed_w,sed_f,'k-')
ax.set_xlim(300,1200)
ax.set_ylim(1e-13,1e-9)
ax.set_yscale("log")
ax.legend(loc="upper right",ncol=4)

# %% [markdown]
# # Convert Not filtered spectra into Mag table

# %%
WL,Mags1,EMags1,AirM,Tim = ConvertToImage(info,all_spectra,WLMIN= WLMINSEL ,WLMAX= WLMAXSEL)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig=plt.figure(figsize=(16,6))
ax1=fig.add_subplot(211)
ax1.plot(AirM,"bo-")
ax1.set_ylabel("airmass")
ax1.set_xlabel("index")
title=f"Airmass night scan for {target} observed at Auxtel (2022) (no qual cut)"
ax1.set_title(title)
ax1.grid()


ax2=fig.add_subplot(212)
ax2.plot(Tim,AirM,"bo-")
ax2.set_ylabel("airmass")
ax2.set_xlabel("time (H)")
ax2.grid()

plt.tight_layout()

# %%
fcn_sed_mag0 = interpolate.interp1d(sed_w,sed_m,bounds_error=False,fill_value=(0,0))
sed_mag0 =fcn_sed_mag0(WL)

# %%
MagsRef1=Mags1-sed_mag0
title="instrumental magnitude - sed magnitude vs time"

# %%
GetBouguerLinesTim(NPOINTSVIEW,WL,Tim,MagsRef1,EMags1,title=title,FLAG_PLOT=True,YMIN=0,YMAX=2.2)

# %%
fig=plt.figure(figsize=(10,10))

gs = fig.add_gridspec(2, 1,height_ratios=[4,1])

ax1=fig.add_subplot(gs[0, :])

extent=(WL.min(),WL.max(),0,NBSPECTRA)
norm = mpl.colors.Normalize(vmin=1, vmax=5)
im=ax1.imshow(MagsRef1,origin="lower",norm=norm,extent=extent,cmap="jet")
fig.colorbar(cm.ScalarMappable(norm=norm, cmap="jet"), ax=ax1, orientation="horizontal" )
ax1.grid()
ax1.set_xlabel("$\lambda$ (nm)")
ax1.set_ylabel("Observation number")
title=f"Magnitudes of {target} observed at Auxtel"
ax1.set_title(title)


ax2=fig.add_subplot(gs[1, :],sharex=ax1)

Y=np.average(MagsRef1,axis=0)
ax2.plot(WL,Y,"b-")
ax2.set_ylim(0,10)
ax2.set_xlabel("$\lambda$ (nm)")
ax2.set_ylabel("Average relative magnitude")
ax2.grid()
plt.tight_layout()

# %%
fig=plt.figure(figsize=(11,5))
ax=fig.add_subplot(111)
ax.imshow(MagsRef1[:,-200:].T,origin="lower",norm=norm,cmap="jet",aspect="auto")
ax.grid()

# %%
info
# Out:
#     number    object                  dateobs   refhour   airmass  pressure  \
# 0      238   mu. Col  2022-03-18T00:51:22.049  0.000000  1.115575    743.45
# 1      244   mu. Col  2022-03-18T00:54:16.312  0.048406  1.121577    743.45
# 2      245   mu. Col  2022-03-18T00:54:49.235  0.057552  1.122727    743.40
# 3      251   mu. Col  2022-03-18T00:57:47.565  0.107088  1.129107    743.40
# 4      252   mu. Col  2022-03-18T00:58:20.709  0.116294  1.130309    743.40
# 5      265   mu. Col  2022-03-18T01:04:49.716  0.224352  1.145030    743.30
# 6      272   mu. Col  2022-03-18T01:08:18.080  0.282231  1.153339    743.30
# 7      273   mu. Col  2022-03-18T01:08:50.992  0.291373  1.154683    743.35
# 8      279   mu. Col  2022-03-18T01:11:46.031  0.339995  1.161939    743.40
# 9      286   mu. Col  2022-03-18T01:15:18.583  0.399037  1.171053    743.45
# 10     293   mu. Col  2022-03-18T01:18:45.526  0.456521  1.180249    743.45
# 11     300   mu. Col  2022-03-18T01:22:16.238  0.515053  1.189962    743.40
# 12     301   mu. Col  2022-03-18T01:22:49.144  0.524193  1.191505    743.45
# 13     310   mu. Col  2022-03-18T01:43:57.837  0.876608  1.258227    743.55
# 14     316   mu. Col  2022-03-18T01:46:52.361  0.925087  1.268584    743.55
# 15     317   mu. Col  2022-03-18T01:47:25.256  0.934224  1.270563    743.55
# 16     330   mu. Col  2022-03-18T01:53:46.736  1.040191  1.294394    743.50
# 17     331   mu. Col  2022-03-18T01:54:19.724  1.049354  1.296523    743.50
# 18     338   mu. Col  2022-03-18T01:57:49.306  1.107571  1.310358    743.45
# 19     345   mu. Col  2022-03-18T02:01:19.196  1.165874  1.324717    743.45
# 20     351   mu. Col  2022-03-18T02:04:16.794  1.215207  1.337275    743.45
# 21     352   mu. Col  2022-03-18T02:04:49.712  1.224351  1.339637    743.35
# 22     358   mu. Col  2022-03-18T02:07:49.074  1.274174  1.352787    743.40
# 23     365   mu. Col  2022-03-18T02:11:20.051  1.332778  1.368766    743.40
# 24     366   mu. Col  2022-03-18T02:11:53.006  1.341933  1.371319    743.45
# 25     372   mu. Col  2022-03-18T02:14:46.798  1.390208  1.385012    743.45
# 26     373   mu. Col  2022-03-18T02:15:19.743  1.399359  1.387650    743.45
# 27     380   mu. Col  2022-03-18T02:33:33.012  1.703045  1.484524    743.35
# 28     386   mu. Col  2022-03-18T02:36:30.874  1.752451  1.502136    743.45
# 29     387   mu. Col  2022-03-18T02:37:03.815  1.761602  1.505457    743.35
# 30     393   mu. Col  2022-03-18T02:40:00.839  1.810775  1.523658    743.40
# 31     394   mu. Col  2022-03-18T02:40:33.787  1.819927  1.527115    743.40
# 32     401   mu. Col  2022-03-18T02:44:05.105  1.878627  1.549764    743.45
# 33     407   mu. Col  2022-03-18T02:47:02.835  1.927996  1.569520    743.40
# 34     408   mu. Col  2022-03-18T02:47:35.769  1.937144  1.573248    743.45
# 35     414   mu. Col  2022-03-18T02:50:38.306  1.987849  1.594345    743.45
# 36     421   mu. Col  2022-03-18T03:08:41.573  2.288757  1.735941    743.50
# 37     422   mu. Col  2022-03-18T03:09:14.484  2.297899  1.740715    743.50
# 38     428  HD185975  2022-03-18T03:12:54.310  2.358961  2.129246    743.50
# 39     429  HD185975  2022-03-18T03:13:27.208  2.368100  2.129068    743.50
# 40     435   mu. Col  2022-03-18T03:17:06.794  2.429096  1.813094    743.45
# 41     436   mu. Col  2022-03-18T03:17:39.779  2.438258  1.818418    743.40
# 42     442   mu. Col  2022-03-18T03:21:26.873  2.501340  1.856070    743.40
# 43     443   mu. Col  2022-03-18T03:21:59.878  2.510508  1.861692    743.45
#
#     temperature  humidity                                         filename
# 0           8.9      48.0  exposure_2022031700238_postisrccd_spectrum.fits
# 1           8.9      49.0  exposure_2022031700244_postisrccd_spectrum.fits
# 2           8.8      49.0  exposure_2022031700245_postisrccd_spectrum.fits
# 3           8.9      50.0  exposure_2022031700251_postisrccd_spectrum.fits
# 4           8.9      50.0  exposure_2022031700252_postisrccd_spectrum.fits
# 5           8.9      53.0  exposure_2022031700265_postisrccd_spectrum.fits
# 6           8.9      51.0  exposure_2022031700272_postisrccd_spectrum.fits
# 7           8.9      51.0  exposure_2022031700273_postisrccd_spectrum.fits
# 8           8.9      53.0  exposure_2022031700279_postisrccd_spectrum.fits
# 9           8.9      54.0  exposure_2022031700286_postisrccd_spectrum.fits
# 10          9.0      53.0  exposure_2022031700293_postisrccd_spectrum.fits
# 11          8.9      56.0  exposure_2022031700300_postisrccd_spectrum.fits
# 12          9.0      56.0  exposure_2022031700301_postisrccd_spectrum.fits
# 13          8.8      56.0  exposure_2022031700310_postisrccd_spectrum.fits
# 14          8.7      56.0  exposure_2022031700316_postisrccd_spectrum.fits
# 15          8.7      56.0  exposure_2022031700317_postisrccd_spectrum.fits
# 16          8.6      56.0  exposure_2022031700330_postisrccd_spectrum.fits
# 17          8.6      56.0  exposure_2022031700331_postisrccd_spectrum.fits
# 18          8.7      57.0  exposure_2022031700338_postisrccd_spectrum.fits
# 19          8.6      59.0  exposure_2022031700345_postisrccd_spectrum.fits
# 20          8.5      58.0  exposure_2022031700351_postisrccd_spectrum.fits
# 21          8.5      58.0  exposure_2022031700352_postisrccd_spectrum.fits
# 22          8.4      59.0  exposure_2022031700358_postisrccd_spectrum.fits
# 23          8.4      59.0  exposure_2022031700365_postisrccd_spectrum.fits
# 24          8.4      59.0  exposure_2022031700366_postisrccd_spectrum.fits
# 25          8.4      61.0  exposure_2022031700372_postisrccd_spectrum.fits
# 26          8.4      61.0  exposure_2022031700373_postisrccd_spectrum.fits
# 27          8.0      63.0  exposure_2022031700380_postisrccd_spectrum.fits
# 28          8.1      64.0  exposure_2022031700386_postisrccd_spectrum.fits
# 29          8.1      64.0  exposure_2022031700387_postisrccd_spectrum.fits
# 30          8.0      64.0  exposure_2022031700393_postisrccd_spectrum.fits
# 31          8.0      64.0  exposure_2022031700394_postisrccd_spectrum.fits
# 32          8.0      64.0  exposure_2022031700401_postisrccd_spectrum.fits
# 33          8.0      64.0  exposure_2022031700407_postisrccd_spectrum.fits
# 34          8.0      64.0  exposure_2022031700408_postisrccd_spectrum.fits
# 35          8.0      63.0  exposure_2022031700414_postisrccd_spectrum.fits
# 36          7.7      63.0  exposure_2022031700421_postisrccd_spectrum.fits
# 37          7.7      63.0  exposure_2022031700422_postisrccd_spectrum.fits
# 38          7.8      62.0  exposure_2022031700428_postisrccd_spectrum.fits
# 39          7.8      62.0  exposure_2022031700429_postisrccd_spectrum.fits
# 40          7.7      63.0  exposure_2022031700435_postisrccd_spectrum.fits
# 41          7.7      63.0  exposure_2022031700436_postisrccd_spectrum.fits
# 42          7.8      62.0  exposure_2022031700442_postisrccd_spectrum.fits
# 43          7.7      63.0  exposure_2022031700443_postisrccd_spectrum.fits

# %% [markdown]
# # Filtered spectra

# %%
list_of_badnums
# Out:
# [251, 300, 301, 428, 429]

# %%
infos, all_spectra =  GetSpectraFiltered(summary_content,list_of_bad_spectra=list_of_badnums)
# Out:
# Remove spectrum 3 for exposure 251
# Remove spectrum 11 for exposure 300
# Remove spectrum 12 for exposure 301
# Remove spectrum 38 for exposure 428
# Remove spectrum 39 for exposure 429

# %%
infos
# Out:
#     number   object                  dateobs   refhour   airmass  pressure  \
# 0      238  mu. Col  2022-03-18T00:51:22.049  0.000000  1.115575    743.45
# 1      244  mu. Col  2022-03-18T00:54:16.312  0.048406  1.121577    743.45
# 2      245  mu. Col  2022-03-18T00:54:49.235  0.057552  1.122727    743.40
# 3      252  mu. Col  2022-03-18T00:58:20.709  0.116294  1.130309    743.40
# 4      265  mu. Col  2022-03-18T01:04:49.716  0.224352  1.145030    743.30
# 5      272  mu. Col  2022-03-18T01:08:18.080  0.282231  1.153339    743.30
# 6      273  mu. Col  2022-03-18T01:08:50.992  0.291373  1.154683    743.35
# 7      279  mu. Col  2022-03-18T01:11:46.031  0.339995  1.161939    743.40
# 8      286  mu. Col  2022-03-18T01:15:18.583  0.399037  1.171053    743.45
# 9      293  mu. Col  2022-03-18T01:18:45.526  0.456521  1.180249    743.45
# 10     310  mu. Col  2022-03-18T01:43:57.837  0.876608  1.258227    743.55
# 11     316  mu. Col  2022-03-18T01:46:52.361  0.925087  1.268584    743.55
# 12     317  mu. Col  2022-03-18T01:47:25.256  0.934224  1.270563    743.55
# 13     330  mu. Col  2022-03-18T01:53:46.736  1.040191  1.294394    743.50
# 14     331  mu. Col  2022-03-18T01:54:19.724  1.049354  1.296523    743.50
# 15     338  mu. Col  2022-03-18T01:57:49.306  1.107571  1.310358    743.45
# 16     345  mu. Col  2022-03-18T02:01:19.196  1.165874  1.324717    743.45
# 17     351  mu. Col  2022-03-18T02:04:16.794  1.215207  1.337275    743.45
# 18     352  mu. Col  2022-03-18T02:04:49.712  1.224351  1.339637    743.35
# 19     358  mu. Col  2022-03-18T02:07:49.074  1.274174  1.352787    743.40
# 20     365  mu. Col  2022-03-18T02:11:20.051  1.332778  1.368766    743.40
# 21     366  mu. Col  2022-03-18T02:11:53.006  1.341933  1.371319    743.45
# 22     372  mu. Col  2022-03-18T02:14:46.798  1.390208  1.385012    743.45
# 23     373  mu. Col  2022-03-18T02:15:19.743  1.399359  1.387650    743.45
# 24     380  mu. Col  2022-03-18T02:33:33.012  1.703045  1.484524    743.35
# 25     386  mu. Col  2022-03-18T02:36:30.874  1.752451  1.502136    743.45
# 26     387  mu. Col  2022-03-18T02:37:03.815  1.761602  1.505457    743.35
# 27     393  mu. Col  2022-03-18T02:40:00.839  1.810775  1.523658    743.40
# 28     394  mu. Col  2022-03-18T02:40:33.787  1.819927  1.527115    743.40
# 29     401  mu. Col  2022-03-18T02:44:05.105  1.878627  1.549764    743.45
# 30     407  mu. Col  2022-03-18T02:47:02.835  1.927996  1.569520    743.40
# 31     408  mu. Col  2022-03-18T02:47:35.769  1.937144  1.573248    743.45
# 32     414  mu. Col  2022-03-18T02:50:38.306  1.987849  1.594345    743.45
# 33     421  mu. Col  2022-03-18T03:08:41.573  2.288757  1.735941    743.50
# 34     422  mu. Col  2022-03-18T03:09:14.484  2.297899  1.740715    743.50
# 35     435  mu. Col  2022-03-18T03:17:06.794  2.429096  1.813094    743.45
# 36     436  mu. Col  2022-03-18T03:17:39.779  2.438258  1.818418    743.40
# 37     442  mu. Col  2022-03-18T03:21:26.873  2.501340  1.856070    743.40
# 38     443  mu. Col  2022-03-18T03:21:59.878  2.510508  1.861692    743.45
#
#     temperature  humidity                                         filename
# 0           8.9      48.0  exposure_2022031700238_postisrccd_spectrum.fits
# 1           8.9      49.0  exposure_2022031700244_postisrccd_spectrum.fits
# 2           8.8      49.0  exposure_2022031700245_postisrccd_spectrum.fits
# 3           8.9      50.0  exposure_2022031700252_postisrccd_spectrum.fits
# 4           8.9      53.0  exposure_2022031700265_postisrccd_spectrum.fits
# 5           8.9      51.0  exposure_2022031700272_postisrccd_spectrum.fits
# 6           8.9      51.0  exposure_2022031700273_postisrccd_spectrum.fits
# 7           8.9      53.0  exposure_2022031700279_postisrccd_spectrum.fits
# 8           8.9      54.0  exposure_2022031700286_postisrccd_spectrum.fits
# 9           9.0      53.0  exposure_2022031700293_postisrccd_spectrum.fits
# 10          8.8      56.0  exposure_2022031700310_postisrccd_spectrum.fits
# 11          8.7      56.0  exposure_2022031700316_postisrccd_spectrum.fits
# 12          8.7      56.0  exposure_2022031700317_postisrccd_spectrum.fits
# 13          8.6      56.0  exposure_2022031700330_postisrccd_spectrum.fits
# 14          8.6      56.0  exposure_2022031700331_postisrccd_spectrum.fits
# 15          8.7      57.0  exposure_2022031700338_postisrccd_spectrum.fits
# 16          8.6      59.0  exposure_2022031700345_postisrccd_spectrum.fits
# 17          8.5      58.0  exposure_2022031700351_postisrccd_spectrum.fits
# 18          8.5      58.0  exposure_2022031700352_postisrccd_spectrum.fits
# 19          8.4      59.0  exposure_2022031700358_postisrccd_spectrum.fits
# 20          8.4      59.0  exposure_2022031700365_postisrccd_spectrum.fits
# 21          8.4      59.0  exposure_2022031700366_postisrccd_spectrum.fits
# 22          8.4      61.0  exposure_2022031700372_postisrccd_spectrum.fits
# 23          8.4      61.0  exposure_2022031700373_postisrccd_spectrum.fits
# 24          8.0      63.0  exposure_2022031700380_postisrccd_spectrum.fits
# 25          8.1      64.0  exposure_2022031700386_postisrccd_spectrum.fits
# 26          8.1      64.0  exposure_2022031700387_postisrccd_spectrum.fits
# 27          8.0      64.0  exposure_2022031700393_postisrccd_spectrum.fits
# 28          8.0      64.0  exposure_2022031700394_postisrccd_spectrum.fits
# 29          8.0      64.0  exposure_2022031700401_postisrccd_spectrum.fits
# 30          8.0      64.0  exposure_2022031700407_postisrccd_spectrum.fits
# 31          8.0      64.0  exposure_2022031700408_postisrccd_spectrum.fits
# 32          8.0      63.0  exposure_2022031700414_postisrccd_spectrum.fits
# 33          7.7      63.0  exposure_2022031700421_postisrccd_spectrum.fits
# 34          7.7      63.0  exposure_2022031700422_postisrccd_spectrum.fits
# 35          7.7      63.0  exposure_2022031700435_postisrccd_spectrum.fits
# 36          7.7      63.0  exposure_2022031700436_postisrccd_spectrum.fits
# 37          7.8      62.0  exposure_2022031700442_postisrccd_spectrum.fits
# 38          7.7      63.0  exposure_2022031700443_postisrccd_spectrum.fits

# %% [markdown]
# # Convert Not filtered spectra into Mag table

# %%
NBSPECTRA=len(all_spectra)

# %%
# wavelength bin colors
jet = plt.get_cmap('jet')
cNorm = colors.Normalize(vmin=0, vmax=NBSPECTRA)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
all_colors = scalarMap.to_rgba(np.arange(NBSPECTRA), alpha=1)

# %%
msg=f" Number of good spectra is {NBSPECTRA}"
logger.info(msg)
# Out:
# 2022-04-19 16:59:52,567 jns-dagoret.cc.in2p3.fr __main__[1972] INFO  Number of good spectra is 39

# %%
fig=plt.figure(figsize=(16,10))
ax=fig.add_subplot(111)
for ifile in np.arange(NBSPECTRA):
    the_df=all_spectra[ifile]

    #ax.plot(the_df.wavelength,the_df.flux,color=all_colors[ifile])
    ax.errorbar(the_df["all_lambdas"],the_df['all_fluxes'],yerr=the_df["all_fluxes_err"], fmt = '.', color=all_colors[ifile],capsize = 0.01, ecolor=all_colors[ifile], elinewidth = .01)
ax.grid()
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("flux (erg/sec/m$^2$/nm)")
title=f"Selected Spectra of {target} observed at AuxTel"
ax.set_title(title)
ax.plot(sed_w,sed_f,'k-')
ax.set_xlim(300,1200)
ax.set_yscale("log")

# %%
fig=plt.figure(figsize=(16,10))
ax=fig.add_subplot(111)
for ifile in np.arange(NBSPECTRA):
    the_df=the_df=all_spectra[ifile]

    #ax.plot(the_df.wavelength,the_df.mag,color=all_colors[ifile])
    mag = -2.5*np.log10(the_df["all_fluxes"])
    errmag = 2.5/np.log(10)*the_df["all_fluxes_err"]/(the_df["all_fluxes"])
    ax.errorbar(the_df["all_lambdas"],mag,yerr=errmag, fmt = '.', color=all_colors[ifile],capsize = 0.01, ecolor=all_colors[ifile], elinewidth = .01)
ax.grid()
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("magnitude ")
title=f"Spectra of {target} observed at {SITE} ({DATE})"
ax.set_title(title)
ax.plot(sed_w,sed_m,'k-')
ax.set_xlim(300,1200)
ax.set_ylim(25,35)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (25.0, 35.0)

# %% [markdown]
# ## Convert to image

# %%
WL,Mags2,EMags2 ,AirM,Tim = ConvertToImage(info,all_spectra, WLMIN= WLMINSEL ,WLMAX= WLMAXSEL )
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig=plt.figure(figsize=(16,6))
ax1=fig.add_subplot(211)
ax1.plot(AirM,"bo-")
ax1.set_ylabel("airmass")
ax1.set_xlabel("index")
title=f"Airmass night scan for {target} observed at Pic du Midi (with qual cut)"
ax1.set_title(title)
ax1.grid()


ax2=fig.add_subplot(212)
ax2.plot(Tim,AirM,"bo-")
ax2.set_ylabel("time (H)")
ax2.set_xlabel("index")
ax2.grid()

plt.tight_layout()

# %%
MagsRef2=Mags2-sed_mag0
title="instrumental magnitude - sed magnitude vs time"

# %%
MagsRef2.shape
# Out:
# (39, 701)

# %%
EMags2.shape
# Out:
# (39, 701)

# %%
GetBouguerLinesTim(NPOINTSVIEW,WL,Tim,MagsRef2,EMags2,title=title,FLAG_PLOT=True,YMIN=0,YMAX=2.2)

# %% [markdown]
# # Quality selection of observations

# %%
fig=plt.figure(figsize=(10,10))

gs = fig.add_gridspec(2, 1,height_ratios=[4,1])

ax1=fig.add_subplot(gs[0, :])

extent=(WL.min(),WL.max(),0,NBSPECTRA)
norm = mpl.colors.Normalize(vmin=1, vmax=5)
im=ax1.imshow(MagsRef2,origin="lower",norm=norm,extent=extent,cmap="jet")
fig.colorbar(cm.ScalarMappable(norm=norm, cmap="jet"), ax=ax1, orientation="horizontal" )
ax1.grid()
ax1.set_xlabel("$\lambda$ (nm)")
ax1.set_ylabel("Observation number")
title=f"Magnitudes of {target} observed at Pic du Midi"
ax1.set_title(title)


ax2=fig.add_subplot(gs[1, :],sharex=ax1)

Y=np.average(MagsRef2,axis=0)
ax2.plot(WL,Y,"b-")
ax2.set_ylim(0,10)
ax2.set_xlabel("$\lambda$ (nm)")
ax2.set_ylabel("Average relative magnitude")
ax2.grid()
plt.tight_layout()

# %% [markdown]
# # Bouguer line

# %%
title="instrumental magnitude - sed magnitude vs time"

# %%
GetBouguerLinesTim(NPOINTSVIEW,WL,Tim,MagsRef2,EMags2,title=title,FLAG_PLOT=True,YMIN=0,YMAX=2.2)

# %%
title="instrumental magnitude - sed magnitude vs airmass"

# %%
w,m,e=GetBouguerLinesAtm(NPOINTSVIEW,WL,AirM,MagsRef2,EMags2,title=title,FLAG_PLOT=True,YMIN=0,YMAX=2.2)

# %% [markdown]
# # Throughput

# %%
w_s1,m_s1,em_s1=GetBouguerLinesAtm(NPOINTSSAVE,WL,AirM,MagsRef2,EMags2,FLAG_PLOT=False)

# %%
transm_s1=np.power(10,-m_s1/2.5)
etransm_s1=em_s1*transm_s1

# %%
factor=1.0 # suppose Spectractor has divided the flux by Ronchi efficiency
transm_s1=transm_s1*factor
etransm_s1=etransm_s1*factor

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.errorbar(w_s1,transm_s1,yerr=etransm_s1,  fmt = 'o', color="r",capsize = 3, ecolor = 'k', elinewidth = 1, capthick = 1)
#ax.errorbar(w_s,transm_s,yerr=em_s,  fmt = 'o', color="r",ecolor = 'k', elinewidth = 1)
#ax.plot(w,transm,"or")
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("throughput")
title=f"Linear fit : Optical Through (Bouguer lines)"
ax.set_title(title)
ax.grid()

# %% [markdown]
# # TOA Spectrum

# %%
title="instrumental magnitude vs airmass"

# %%
w,m,e=GetBouguerLinesAtm(NPOINTSVIEW,WL,AirM,Mags2,EMags2,title=title,FLAG_PLOT=True,YMIN=26,YMAX=33)

# %%
w_s2,m_s2,em_s2=GetBouguerLinesAtm(NPOINTSSAVE,WL,AirM,Mags2,EMags2,FLAG_PLOT=False)

# %%
transm_s2=np.power(10,-m_s2/2.5)
etransm_s2=em_s2*transm_s2

# %%
factor=1.0 # suppose Spectractor has divided the flux by Ronchi efficiency
transm_s2=transm_s2*factor
etransm_s2=etransm_s2*factor

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.errorbar(w_s2,transm_s2,yerr=etransm_s2,  fmt = 'o', color="r",capsize = 3, ecolor = 'k', elinewidth = 1, capthick = 1,label="data")
#ax.errorbar(w_s,transm_s,yerr=em_s,  fmt = 'o', color="r",ecolor = 'k', elinewidth = 1)
#ax.plot(w,transm,"or")
plt.plot(sed_w,sed_f/5,"b-",label="SED/5")
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("spectrum")
title=f"Linear fit : Spectrum at TOA (with Bouguer lines)"
ax.set_title(title)
ax.legend()
ax.grid()

# %% [markdown]
# # Save in file

# %%
dfout = pd.DataFrame()

# %%
dfout["wavelength"]=w_s1
dfout["throu"]=transm_s1
dfout["errthrou"]=etransm_s1
dfout["sedtoa"]=transm_s2
dfout["errsedtoa"]=etransm_s2

# %%
dfout
# Out:
#       wavelength         throu      errthrou        sedtoa     errsedtoa
# 0     350.000000  5.062964e-13  4.857162e-14  5.062964e-13  4.857162e-14
# 1     352.341137  1.158691e-02  8.733971e-04  8.001318e-13  6.031227e-14
# 2     354.682274  2.118233e-02  1.167072e-03  1.414418e-12  7.792946e-14
# 3     357.023411  2.918812e-02  1.407614e-03  1.900200e-12  9.163823e-14
# 4     359.364548  3.806763e-02  1.625459e-03  2.384746e-12  1.018268e-13
# ..           ...           ...           ...           ...           ...
# 295  1040.635452  1.478876e-01  1.130983e-02  2.127577e-13  1.627082e-14
# 296  1042.976589  1.621142e-01  1.260703e-02  2.314354e-13  1.799789e-14
# 297  1045.317726  1.779968e-01  1.380217e-02  2.523109e-13  1.956460e-14
# 298  1047.658863  1.994375e-01  1.589376e-02  2.796225e-13  2.228394e-14
# 299  1050.000000  2.158911e-01  1.815743e-02  3.003954e-13  2.526464e-14
#
# [300 rows x 5 columns]

# %%
# Save CSV file
dfout.to_csv(outputfile_linearfit)
