# %% [markdown]
# # process spectra for AuxTel with new spectractor (March 2022) for particular config Hb

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : April 5th 2022
#
# - version v5 : Work with exposure butlen gen3
#
#
# - Config H:
#
#
#        After pull request from Jeremy on git-branch issue-auxteltarget
#
#        pour faire simple, je propose une pull request d'une branche qui contient mes réglages vers ta branche issue-auxteltarget :
#
#        https://github.com/LSSTDESC/Spectractor/pull/95
#
#
# This notebook is to help for finding the position of order 0
#
# CCIN2P3:
#
# - works with kernels **anaconda3_auxtel** (with libradtran) and **anaconda3_auxtel_v2** (no libradtran)
# - works with kernel **python 3** locally

# %% [markdown]
# # Scan
#
#     # wide scan : HD 160617
#     # all_myseq_holo=range(234,310)
#     # narrow scan :  HD 160617
#     # all_myseq_holo=range(317,365)

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
print(sys.path)
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03', '', '/opt/conda/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload', '/pbs/home/d/dagoret/.local/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/certifi-2020.12.5-py3.8.egg']

# %%
all_paths_to_remove = ['/opt/conda/lib/python3.8/site-packages','/pbs/home/d/dagoret/.local/lib/python3.8/site-packages']

for path_to_remove in all_paths_to_remove:
    if path_to_remove in sys.path:
        print(f"remove {path_to_remove} from sys.path")
        sys.path.remove(path_to_remove)
# Out:
# remove /opt/conda/lib/python3.8/site-packages from sys.path
# remove /pbs/home/d/dagoret/.local/lib/python3.8/site-packages from sys.path

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/certifi-2020.12.5-py3.8.egg']

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
from matplotlib import  transforms
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (12,12)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/certifi-2020.12.5-py3.8.egg']

# %%
print(sys.executable)
print(sys.version)
#print(sys.version_info)
# Out:
# /sps/lsst/groups/auxtel/softs/utils/anaconda3/bin/python
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_subplot(1,1,1)
X=np.linspace(-10,10,50)
Y=np.sin(X)
ax.plot(X,Y)
plt.show()

# %%
from iminuit import Minuit
import iminuit

# %%
iminuit.__version__
# Out:
# '2.2.0'

# %%
from astropy.io import fits
from spectractor import parameters
from spectractor.extractor.extractor import Spectractor
from spectractor.extractor.images import *
from scipy import ndimage, misc

# %%
from astroquery.simbad import Simbad
result_table = Simbad.query_object("mu. Col")
print(result_table)
result_table = Simbad.query_object("HD111980")
print(result_table)
result_table = Simbad.query_object("eta dor")
print(result_table)
# Out:
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... ------------------- ----------------
# * mu. Col 05 45 59.8950 -32 18 23.162 ... 2020yCat.1350....0G                1
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... ------------------- ----------------
# HD 111980 12 53 15.0529 -18 31 20.013 ... 2020yCat.1350....0G                1
#   MAIN_ID         RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... ------------------- ----------------
# * eta02 Dor 06 11 14.9816 -65 35 21.904 ... 2020yCat.1350....0G                1

# %%
result_table = Simbad.query_object("ETA DOR")

# %%
result_table
# Out:
# <Table length=1>
#   MAIN_ID         RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
#    object       str13         str13     ...        object            int32
# ----------- ------------- ------------- ... ------------------- ----------------
# * eta02 Dor 06 11 14.9816 -65 35 21.904 ... 2020yCat.1350....0G                1

# %%
from scipy.stats import kurtosis,skew
from scipy.stats import kurtosistest,skewtest,normaltest

# %%
from distutils.dir_util import copy_tree
import shutil

# %% [markdown]
# # Configuration

# %%
version="v5.0"  # version of flipping
# create output directories if not exist and clean existing files
FLAG_MANAGE_OUTPUT_SPECTRACTOR=True
# allow to run reconstruction with Spectractor
FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR=True

FLAG_REMOVE_WCS=False

# %%
# Choose the config filename
list_of_spectractorconfigfiles= ["auxtel_configA.ini","auxtel_configB.ini","auxtel_configC.ini","auxtel_configD.ini","auxtel_configE.ini",
                                 "auxtel_configF.ini","auxtel_configG.ini","auxtel_configHb.ini"]
config_idx = 7
configfilename= os.path.join("./config",list_of_spectractorconfigfiles[config_idx])
configdir = (list_of_spectractorconfigfiles[config_idx].split("_")[-1]).split(".") [0]

# %% [markdown]
# # Path

# %%
# path index for each month
DATE="20220317"

# %%
# select if we run at CC or not (locally) 
# /sps/lsst/groups/auxtel/data/2022/holo/20220317
HOSTCC=True

# %%
# Set path depending on which computer running (according HOSTCC)
if HOSTCC:
    path_auxtel="/sps/lsst/groups/auxtel"
    path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    path_images=os.path.join(path_auxtel,"data/2022/holo/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/holo/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/holo/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/holo/"+configdir)
    
else:
    #path_auxtel="/Users/dagoret/DATA/AuxTelData2021"
    path_auxtel="/Users/sylvie/DATA/AuxTelDATA2022/2022"
    #path_spectractor=os.path.join(path_auxtel,"/users/dagoret/MacOSX/github/LSST/Spectractor")
    path_spectractor=os.path.join(path_auxtel,"/Users/sylvie/MacOSX/GitHub/LSST/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    #path_images=os.path.join(path_auxtel,"holo/quickLookExp_v2/"+DATE)
    path_images=os.path.join(path_auxtel,"holo/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+configdir)
    #path_output_spectractor=os.path.join(path_auxtel,"holo/OutputSpectractor/"+DATE)

# %% [markdown]
# # Utility Functions

# %%
def is_nan(x):
    return (x != x)

# %% [markdown]
# # Logbook for input file selection
#
# - the logbook contains all input image path and possibily the order 0 position

# %%
filename_logbook='logbooks/auxtelholologbook_'+DATE+'_' + version+'.csv'

# %%
df=pd.read_csv(filename_logbook,index_col=0)

# %%
pd.set_option('display.max_rows', None)

# %%
# show the list of input files from the logbook to select the file index in the logbook
df
# Out:
#     index                     date  \
# 0       0  2022-03-18T00:51:03.112
# 1       1  2022-03-18T00:51:36.190
# 2       2  2022-03-18T00:54:30.463
# 3       3  2022-03-18T00:55:03.377
# 4       4  2022-03-18T00:58:01.707
# 5       5  2022-03-18T00:58:34.835
# 6       6  2022-03-18T01:01:32.859
# 7       7  2022-03-18T01:02:05.775
# 8       8  2022-03-18T01:05:03.839
# 9       9  2022-03-18T01:05:36.766
# 10     10  2022-03-18T01:08:32.232
# 11     11  2022-03-18T01:09:05.133
# 12     12  2022-03-18T01:12:00.164
# 13     13  2022-03-18T01:12:33.079
# 14     14  2022-03-18T01:15:32.735
# 15     15  2022-03-18T01:16:05.627
# 16     16  2022-03-18T01:18:59.663
# 17     17  2022-03-18T01:19:32.577
# 18     18  2022-03-18T01:22:30.386
# 19     19  2022-03-18T01:23:03.286
# 20     20  2022-03-18T01:43:39.078
# 21     21  2022-03-18T01:44:11.982
# 22     22  2022-03-18T01:47:06.515
# 23     23  2022-03-18T01:47:39.407
# 24     24  2022-03-18T01:50:33.593
# 25     25  2022-03-18T01:51:06.516
# 26     26  2022-03-18T01:54:00.883
# 27     27  2022-03-18T01:54:33.856
# 28     28  2022-03-18T01:57:30.505
# 29     29  2022-03-18T01:58:03.446
# 30     30  2022-03-18T02:01:00.181
# 31     31  2022-03-18T02:01:33.339
# 32     32  2022-03-18T02:04:30.946
# 33     33  2022-03-18T02:05:03.843
# 34     34  2022-03-18T02:08:03.232
# 35     35  2022-03-18T02:08:36.262
# 36     36  2022-03-18T02:11:34.200
# 37     37  2022-03-18T02:12:07.156
# 38     38  2022-03-18T02:15:00.952
# 39     39  2022-03-18T02:15:33.886
# 40     40  2022-03-18T02:33:14.260
# 41     41  2022-03-18T02:33:47.167
# 42     42  2022-03-18T02:36:45.029
# 43     43  2022-03-18T02:37:17.962
# 44     44  2022-03-18T02:40:14.985
# 45     45  2022-03-18T02:40:47.930
# 46     46  2022-03-18T02:43:46.361
# 47     47  2022-03-18T02:44:19.255
# 48     48  2022-03-18T02:47:16.976
# 49     49  2022-03-18T02:47:49.912
# 50     50  2022-03-18T02:50:52.460
# 51     51  2022-03-18T02:51:25.626
# 52     52  2022-03-18T03:08:55.717
# 53     53  2022-03-18T03:09:28.629
# 54     54  2022-03-18T03:13:08.467
# 55     55  2022-03-18T03:13:41.360
# 56     56  2022-03-18T03:17:20.920
# 57     57  2022-03-18T03:17:53.934
# 58     58  2022-03-18T03:21:41.018
# 59     59  2022-03-18T03:22:14.022
#
#                                                path  \
# 0   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 1   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 2   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 3   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 4   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 5   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 6   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 7   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 8   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 9   /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 10  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 11  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 12  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 13  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 14  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 15  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 16  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 17  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 18  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 19  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 20  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 21  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 22  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 23  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 24  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 25  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 26  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 27  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 28  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 29  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 30  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 31  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 32  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 33  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 34  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 35  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 36  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 37  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 38  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 39  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 40  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 41  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 42  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 43  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 44  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 45  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 46  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 47  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 48  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 49  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 50  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 51  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 52  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 53  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 54  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 55  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 56  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 57  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 58  /sps/lsst/groups/auxtel/data/2022/holo/20220317
# 59  /sps/lsst/groups/auxtel/data/2022/holo/20220317
#
#                                       file  num    object   filter  disperser  \
# 0   exposure_2022031700237_postisrccd.fits  237   mu. Col  empty_1  holo4_003
# 1   exposure_2022031700238_postisrccd.fits  238   mu. Col  empty_1  holo4_003
# 2   exposure_2022031700244_postisrccd.fits  244   mu. Col  empty_1  holo4_003
# 3   exposure_2022031700245_postisrccd.fits  245   mu. Col  empty_1  holo4_003
# 4   exposure_2022031700251_postisrccd.fits  251   mu. Col  empty_1  holo4_003
# 5   exposure_2022031700252_postisrccd.fits  252   mu. Col  empty_1  holo4_003
# 6   exposure_2022031700258_postisrccd.fits  258   mu. Col  empty_1  holo4_003
# 7   exposure_2022031700259_postisrccd.fits  259   mu. Col  empty_1  holo4_003
# 8   exposure_2022031700265_postisrccd.fits  265   mu. Col  empty_1  holo4_003
# 9   exposure_2022031700266_postisrccd.fits  266   mu. Col  empty_1  holo4_003
# 10  exposure_2022031700272_postisrccd.fits  272   mu. Col  empty_1  holo4_003
# 11  exposure_2022031700273_postisrccd.fits  273   mu. Col  empty_1  holo4_003
# 12  exposure_2022031700279_postisrccd.fits  279   mu. Col  empty_1  holo4_003
# 13  exposure_2022031700280_postisrccd.fits  280   mu. Col  empty_1  holo4_003
# 14  exposure_2022031700286_postisrccd.fits  286   mu. Col  empty_1  holo4_003
# 15  exposure_2022031700287_postisrccd.fits  287   mu. Col  empty_1  holo4_003
# 16  exposure_2022031700293_postisrccd.fits  293   mu. Col  empty_1  holo4_003
# 17  exposure_2022031700294_postisrccd.fits  294   mu. Col  empty_1  holo4_003
# 18  exposure_2022031700300_postisrccd.fits  300   mu. Col  empty_1  holo4_003
# 19  exposure_2022031700301_postisrccd.fits  301   mu. Col  empty_1  holo4_003
# 20  exposure_2022031700309_postisrccd.fits  309   mu. Col  empty_1  holo4_003
# 21  exposure_2022031700310_postisrccd.fits  310   mu. Col  empty_1  holo4_003
# 22  exposure_2022031700316_postisrccd.fits  316   mu. Col  empty_1  holo4_003
# 23  exposure_2022031700317_postisrccd.fits  317   mu. Col  empty_1  holo4_003
# 24  exposure_2022031700323_postisrccd.fits  323   mu. Col  empty_1  holo4_003
# 25  exposure_2022031700324_postisrccd.fits  324   mu. Col  empty_1  holo4_003
# 26  exposure_2022031700330_postisrccd.fits  330   mu. Col  empty_1  holo4_003
# 27  exposure_2022031700331_postisrccd.fits  331   mu. Col  empty_1  holo4_003
# 28  exposure_2022031700337_postisrccd.fits  337   mu. Col  empty_1  holo4_003
# 29  exposure_2022031700338_postisrccd.fits  338   mu. Col  empty_1  holo4_003
# 30  exposure_2022031700344_postisrccd.fits  344   mu. Col  empty_1  holo4_003
# 31  exposure_2022031700345_postisrccd.fits  345   mu. Col  empty_1  holo4_003
# 32  exposure_2022031700351_postisrccd.fits  351   mu. Col  empty_1  holo4_003
# 33  exposure_2022031700352_postisrccd.fits  352   mu. Col  empty_1  holo4_003
# 34  exposure_2022031700358_postisrccd.fits  358   mu. Col  empty_1  holo4_003
# 35  exposure_2022031700359_postisrccd.fits  359   mu. Col  empty_1  holo4_003
# 36  exposure_2022031700365_postisrccd.fits  365   mu. Col  empty_1  holo4_003
# 37  exposure_2022031700366_postisrccd.fits  366   mu. Col  empty_1  holo4_003
# 38  exposure_2022031700372_postisrccd.fits  372   mu. Col  empty_1  holo4_003
# 39  exposure_2022031700373_postisrccd.fits  373   mu. Col  empty_1  holo4_003
# 40  exposure_2022031700379_postisrccd.fits  379   mu. Col  empty_1  holo4_003
# 41  exposure_2022031700380_postisrccd.fits  380   mu. Col  empty_1  holo4_003
# 42  exposure_2022031700386_postisrccd.fits  386   mu. Col  empty_1  holo4_003
# 43  exposure_2022031700387_postisrccd.fits  387   mu. Col  empty_1  holo4_003
# 44  exposure_2022031700393_postisrccd.fits  393   mu. Col  empty_1  holo4_003
# 45  exposure_2022031700394_postisrccd.fits  394   mu. Col  empty_1  holo4_003
# 46  exposure_2022031700400_postisrccd.fits  400   mu. Col  empty_1  holo4_003
# 47  exposure_2022031700401_postisrccd.fits  401   mu. Col  empty_1  holo4_003
# 48  exposure_2022031700407_postisrccd.fits  407   mu. Col  empty_1  holo4_003
# 49  exposure_2022031700408_postisrccd.fits  408   mu. Col  empty_1  holo4_003
# 50  exposure_2022031700414_postisrccd.fits  414   mu. Col  empty_1  holo4_003
# 51  exposure_2022031700415_postisrccd.fits  415   mu. Col  empty_1  holo4_003
# 52  exposure_2022031700421_postisrccd.fits  421   mu. Col  empty_1  holo4_003
# 53  exposure_2022031700422_postisrccd.fits  422   mu. Col  empty_1  holo4_003
# 54  exposure_2022031700428_postisrccd.fits  428  HD185975  empty_1  holo4_003
# 55  exposure_2022031700429_postisrccd.fits  429  HD185975  empty_1  holo4_003
# 56  exposure_2022031700435_postisrccd.fits  435   mu. Col  empty_1  holo4_003
# 57  exposure_2022031700436_postisrccd.fits  436   mu. Col  empty_1  holo4_003
# 58  exposure_2022031700442_postisrccd.fits  442   mu. Col  empty_1  holo4_003
# 59  exposure_2022031700443_postisrccd.fits  443   mu. Col  empty_1  holo4_003
#
#      airmass  exposure  ...  temperature  humidity  windspd  Obj-posXpix  \
# 0   1.114069      20.0  ...          8.9      48.0      9.4          NaN
# 1   1.115188      20.0  ...          8.9      48.0      9.4          NaN
# 2   1.121178      20.0  ...          8.9      49.0      8.7          NaN
# 3   1.122325      20.0  ...          8.8      49.0      7.5          NaN
# 4   1.128693      20.0  ...          8.9      50.0     10.2          NaN
# 5   1.129892      20.0  ...          8.9      50.0     10.2          NaN
# 6   1.136492      20.0  ...          8.9      53.0     10.1          NaN
# 7   1.137732      20.0  ...          8.9      52.0     10.4          NaN
# 8   1.144579      20.0  ...          8.9      53.0     10.5          NaN
# 9   1.145874      20.0  ...          8.9      53.0     10.5          NaN
# 10  1.152876      20.0  ...          8.9      51.0     10.4          NaN
# 11  1.154218      20.0  ...          8.9      51.0      9.2          NaN
# 12  1.161455      20.0  ...          8.9      53.0      9.8          NaN
# 13  1.162845      20.0  ...          8.9      53.0      9.8          NaN
# 14  1.170556      20.0  ...          8.9      54.0      9.5          NaN
# 15  1.171988      20.0  ...          8.9      55.0      9.5          NaN
# 16  1.179733      20.0  ...          9.0      53.0     10.1          NaN
# 17  1.181227      20.0  ...          9.0      53.0     10.1          NaN
# 18  1.189428      20.0  ...          8.9      56.0      9.9          NaN
# 19  1.190967      20.0  ...          9.0      56.0      9.9          NaN
# 20  1.255654      20.0  ...          8.8      55.0      9.3          NaN
# 21  1.257560      20.0  ...          8.8      56.0      9.6          NaN
# 22  1.267898      20.0  ...          8.7      56.0     10.3          NaN
# 23  1.269875      20.0  ...          8.7      56.0     10.3          NaN
# 24  1.280549      20.0  ...          8.7      56.0      9.1          NaN
# 25  1.282593      20.0  ...          8.7      57.0      7.4          NaN
# 26  1.293660      20.0  ...          8.6      56.0      9.0          NaN
# 27  1.295776      20.0  ...          8.6      56.0      9.0          NaN
# 28  1.307385      20.0  ...          8.7      58.0      6.6          NaN
# 29  1.309591      20.0  ...          8.7      57.0      7.9          NaN
# 30  1.321621      20.0  ...          8.6      59.0      9.7          NaN
# 31  1.323924      20.0  ...          8.6      59.0      9.7          NaN
# 32  1.336458      20.0  ...          8.5      58.0      9.4          NaN
# 33  1.338813      20.0  ...          8.5      58.0     10.5          NaN
# 34  1.351940      20.0  ...          8.4      59.0      8.7          NaN
# 35  1.354396      20.0  ...          8.4      59.0      8.7          NaN
# 36  1.367887      20.0  ...          8.4      59.0      9.0          NaN
# 37  1.370434      20.0  ...          8.4      59.0      9.0          NaN
# 38  1.384099      20.0  ...          8.4      61.0      9.4          NaN
# 39  1.386726      20.0  ...          8.4      61.0      9.4          NaN
# 40  1.480215      20.0  ...          8.1      62.0      9.1          NaN
# 41  1.483412      20.0  ...          8.0      63.0      9.7          NaN
# 42  1.500990      20.0  ...          8.1      64.0      8.9          NaN
# 43  1.504292      20.0  ...          8.1      64.0      9.3          NaN
# 44  1.522465      20.0  ...          8.0      64.0      8.8          NaN
# 45  1.525915      20.0  ...          8.0      64.0      9.3          NaN
# 46  1.544950      20.0  ...          8.0      64.0      9.4          NaN
# 47  1.548520      20.0  ...          8.0      64.0      9.4          NaN
# 48  1.568220      20.0  ...          8.0      64.0      9.1          NaN
# 49  1.571954      20.0  ...          8.0      64.0      7.6          NaN
# 50  1.592992      20.0  ...          8.0      63.0      8.6          NaN
# 51  1.596903      20.0  ...          8.0      63.0      8.6          NaN
# 52  1.734290      20.0  ...          7.7      63.0      7.9          NaN
# 53  1.739049      20.0  ...          7.7      63.0      7.9          NaN
# 54  2.129307      20.0  ...          7.8      62.0      7.9          NaN
# 55  2.129130      20.0  ...          7.8      62.0      7.9          NaN
# 56  1.811260      20.0  ...          7.7      63.0      7.3          NaN
# 57  1.816575      20.0  ...          7.7      63.0      8.6          NaN
# 58  1.854138      20.0  ...          7.8      62.0      8.4          NaN
# 59  1.859741      20.0  ...          7.7      63.0      7.9          NaN
#
#     Obj-posYpix  Dx  Dy  skip  run  quality
# 0           NaN NaN NaN        NaN      NaN
# 1           NaN NaN NaN        NaN      NaN
# 2           NaN NaN NaN        NaN      NaN
# 3           NaN NaN NaN        NaN      NaN
# 4           NaN NaN NaN        NaN      NaN
# 5           NaN NaN NaN        NaN      NaN
# 6           NaN NaN NaN        NaN      NaN
# 7           NaN NaN NaN        NaN      NaN
# 8           NaN NaN NaN        NaN      NaN
# 9           NaN NaN NaN        NaN      NaN
# 10          NaN NaN NaN        NaN      NaN
# 11          NaN NaN NaN        NaN      NaN
# 12          NaN NaN NaN        NaN      NaN
# 13          NaN NaN NaN        NaN      NaN
# 14          NaN NaN NaN        NaN      NaN
# 15          NaN NaN NaN        NaN      NaN
# 16          NaN NaN NaN        NaN      NaN
# 17          NaN NaN NaN        NaN      NaN
# 18          NaN NaN NaN        NaN      NaN
# 19          NaN NaN NaN        NaN      NaN
# 20          NaN NaN NaN        NaN      NaN
# 21          NaN NaN NaN        NaN      NaN
# 22          NaN NaN NaN        NaN      NaN
# 23          NaN NaN NaN        NaN      NaN
# 24          NaN NaN NaN        NaN      NaN
# 25          NaN NaN NaN        NaN      NaN
# 26          NaN NaN NaN        NaN      NaN
# 27          NaN NaN NaN        NaN      NaN
# 28          NaN NaN NaN        NaN      NaN
# 29          NaN NaN NaN        NaN      NaN
# 30          NaN NaN NaN        NaN      NaN
# 31          NaN NaN NaN        NaN      NaN
# 32          NaN NaN NaN        NaN      NaN
# 33          NaN NaN NaN        NaN      NaN
# 34          NaN NaN NaN        NaN      NaN
# 35          NaN NaN NaN        NaN      NaN
# 36          NaN NaN NaN        NaN      NaN
# 37          NaN NaN NaN        NaN      NaN
# 38          NaN NaN NaN        NaN      NaN
# 39          NaN NaN NaN        NaN      NaN
# 40          NaN NaN NaN        NaN      NaN
# 41          NaN NaN NaN        NaN      NaN
# 42          NaN NaN NaN        NaN      NaN
# 43          NaN NaN NaN        NaN      NaN
# 44          NaN NaN NaN        NaN      NaN
# 45          NaN NaN NaN        NaN      NaN
# 46          NaN NaN NaN        NaN      NaN
# 47          NaN NaN NaN        NaN      NaN
# 48          NaN NaN NaN        NaN      NaN
# 49          NaN NaN NaN        NaN      NaN
# 50          NaN NaN NaN        NaN      NaN
# 51          NaN NaN NaN        NaN      NaN
# 52          NaN NaN NaN        NaN      NaN
# 53          NaN NaN NaN        NaN      NaN
# 54          NaN NaN NaN        NaN      NaN
# 55          NaN NaN NaN        NaN      NaN
# 56          NaN NaN NaN        NaN      NaN
# 57          NaN NaN NaN        NaN      NaN
# 58          NaN NaN NaN        NaN      NaN
# 59          NaN NaN NaN        NaN      NaN
#
# [60 rows x 23 columns]

# %% [markdown]
# # Selection of input file
# - the input file is selected from the logbook list above

# %%
idx=0

# %%
print(df.iloc[idx]['file'])
# Out:
# exposure_2022031700237_postisrccd.fits

# %%
print(df.iloc[idx])
# Out:
# index                                                        0
# date                                   2022-03-18T00:51:03.112
# path           /sps/lsst/groups/auxtel/data/2022/holo/20220317
# file                    exposure_2022031700237_postisrccd.fits
# num                                                        237
# object                                                 mu. Col
# filter                                                 empty_1
# disperser                                            holo4_003
# airmass                                                1.11407
# exposure                                                    20
# focus                                                0.0448927
# seeing                                                 1.22429
# pressure                                                743.45
# temperature                                                8.9
# humidity                                                    48
# windspd                                                    9.4
# Obj-posXpix                                                NaN
# Obj-posYpix                                                NaN
# Dx                                                         NaN
# Dy                                                         NaN
# skip
# run                                                        NaN
# quality                                                    NaN
# Name: 0, dtype: object

# %%
myhome=os.getenv("HOME")

# %%
dir_images=path_images

# %%
dir_images
# Out:
# '/sps/lsst/groups/auxtel/data/2022/holo/20220317'

# %%
filename_image=df['file'][idx]
filename_image
# Out:
# 'exposure_2022031700237_postisrccd.fits'

# %%
target = df['object'][idx]
target
# Out:
# 'mu. Col'

# %% [markdown]
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

# %%
x0=df['Obj-posXpix'][idx]
y0=df['Obj-posYpix'][idx]

# %%
FLAG_ORDER0_LOCATION=False

# %%
if not is_nan(x0)and not is_nan(y0):
    FLAG_ORDER0_LOCATION=True
    print("Order 0 location from logbook : ({},{})".format(x0,y0))
else:
    print("NO Order 0 location from logbook ! ")
# Out:
# NO Order 0 location from logbook !

# %% [markdown]
# ## Spectractor Configuration
#
# - Usually the Spectractor configuration file is put in local dir **./config**
#
#
# Ma suggestion, pour l'étude du centre optique via les scans des hologrammes, est de **mettre SPECTRACTOR_COMPUTE_ROTATION_ANGLE sur False** .
#
# Comme les angles ne sont pas très grands, si les marges du rectangle sont assez larges, réglables avec :
#
#     [background subtraction parameters]
#     # half transverse width of the signal rectangular window in pixels
#     PIXWIDTH_SIGNAL = 40
#
# alors le spectrogramme devrait tenir dans une boite rectangulaire même sans rotation de l'image. **L'important est de garder SPECTRACTOR_DECONVOLUTION_FFM à True car c'est lui qui te donnera l'angle de l'axe de dispersion ajusté sur les données, dont la valeur sera dans le mot clé ROTANGLE du header de sortie**.

# %%
rootfilename = filename_image.split(".")[0]
rootfilename_split =  rootfilename.split("_") 
filenumberdir = rootfilename_split[1]

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317'

# %%
# Fullfilename
filename=os.path.join(dir_images,filename_image)


# subdirectory
#subdir=filename_image.split(".")[0]
subdir=filenumberdir

# final output directory (where results will be copied to be backed up at the end)
finalpath_output_spectractor=os.path.join(path_output_spectractor,subdir)


# local directories to put spectra and plots
if configdir =="":
    output_directory="./outputs_process_holo"
    output_figures="figures_process_holo"
else:
    output_directory = "./outputs_process_holo_" + configdir
    output_figures   = "./figures_process_holo_" + configdir
    
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
if not os.path.isdir(output_figures):
    os.mkdir(output_figures)
    

# Final output directory


guess = [300,1700]
disperser_label = "holo4_003"
# old version
# config = os.path.join(path_spectractor_config,"auxtel_quicklook.ini")
# new version (September 20th 2021)

# configuration

# standard spectractor init configuration
#config = os.path.join(path_spectractor_config,"auxtel.ini")
# special for scan in XY
if configdir=="":
    config="./config/auxtel_scanXY.ini"
else:
    config=configfilename
    
target=df.iloc[idx]["object"]

# %%
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
if not os.path.isdir(output_figures):
    os.mkdir(output_figures)

# %%
print("config filename",config)
# Out:
# config filename ./config/auxtel_configHb.ini

# %%
finalpath_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237'

# %% [markdown]
# ### manage output dir

# %%
def cleandir(path):
    if os.path.isdir(path):
        files=os.listdir(path)
        if len(files) > 0:
            for f in files:
                if os.path.isdir(os.path.join(path,f)):
                    if f==".ipynb_checkpoints":
                        shutil.rmtree(os.path.join(path,f))
                    else:
                        print(" Cannot remove this directory {}".format(os.path.join(path,f)))
                else:
                    os.remove(os.path.join(path,f))

# %%
# this flag must be set if one want to clean results from previous runs
if FLAG_MANAGE_OUTPUT_SPECTRACTOR:
    
    # manage global output directory of spectractor
    # Basically it has the name of the input file image
    
    # added recently    
    if configdir !="":
    # top directory    
        if not os.path.isdir(path_topoutput_spectractor):
            os.mkdir(path_topoutput_spectractor)   
            
            
        if not os.path.isdir(path_output_spectractor):
            os.mkdir(path_output_spectractor)

    
    if not os.path.isdir(output_directory):
        os.mkdir(output_directory)
    else:
        cleandir(output_directory)
 
    # manage subdirs spectrum/ and plots/
    if not os.path.isdir(output_figures):
        os.mkdir(output_figures)
    else:
        cleandir(output_figures)
    
    if not os.path.isdir(finalpath_output_spectractor):
        os.mkdir(finalpath_output_spectractor)
        os.mkdir(os.path.join(finalpath_output_spectractor,"basespec"))
        os.mkdir(os.path.join(finalpath_output_spectractor,"plots"))
    else:
        #cleandir(finalpath_output_spectractor)
        cleandir(os.path.join(finalpath_output_spectractor,"basespec"))
        cleandir(os.path.join(finalpath_output_spectractor,"plots"))

# %%
# /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo"

# %% [markdown]
# # Configuration of the Spectractor running mode

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

# %%
target
# Out:
# 'mu. Col'

# %% [markdown]
# ## Load the image in the new image file with Spectractor

# %%
#image=Image(file_name=filename, target_label=target, disperser_label=disperser_label, config=config)
image=Image(file_name=filename, disperser_label=disperser_label, config=config)
# Out:
# target_name = mu.col, Selected object name for Simbad : mu. Col
#  MAIN_ID        RA           DEC      ...  Z_VALUE  SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... --------- ----------------
# * mu. Col 05 45 59.8950 -32 18 23.162 ... 0.0003640                1

# %%
image.data.shape
# Out:
# (4072, 4000)

# %% [markdown]
# ## Show relevant parameters

# %%
print(parameters)
# Out:
# <module 'spectractor.parameters' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/parameters.py'>

# %%
parameters.LSST_SAVEFIGPATH=True
parameters.LSST_SAVEFIGPATH=output_figures

# %%
image.filter_label
# Out:
# ''

# %%
image.header["FILTER"]
# Out:
# 'empty_1'

# %%
image.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'LSST DM Header Service'
# TIMESYS = 'TAI     '
# DATE    = '2022-03-18T00:50:48.964'
# DATE-OBS= '2022-03-18T00:50:48.964'
# DATE-BEG= '2022-03-18T00:51:03.112'
# DATE-END= '2022-03-18T00:51:23.343'
# MJD     =     59656.0352889316
# MJD-OBS =     59656.0354526851
# MJD-BEG =     59656.0354526851
# MJD-END =     59656.0356868358
# OBSID   = 'AT_O_20220317_000237'
# GROUPID = '2022-03-18T00:44:50.208'
# IMGTYPE = 'OBJECT  '
# BUNIT   = 'adu     '
# FACILITY= 'Vera C. Rubin Observatory'
# TELESCOP= 'LSST AuxTelescope'
# INSTRUME= 'LATISS  '
# OBSERVER= 'LSST    '
# OBS-LONG=   -70.74941699999999
# OBS-LAT =           -30.244639
# OBS-ELEV=               2663.0
# OBSGEO-X=           1818938.94
# OBSGEO-Y=          -5208470.95
# OBSGEO-Z=          -3195172.08
# RA      =                 86.5
# DEC     =    -32.3064444444444
# RASTART =    86.48730329103419
# DECSTART=     -32.346338263007
# RAEND   =    86.48733401444809
# DECEND  =    -32.3463459116088
# ROTPA   =     183.405783337354
# ROTCOORD= 'sky     '
# HASTART =     2.04917496424215
# ELSTART =     63.8290982528561
# AZSTART =     257.365917045405
# AMSTART =     1.11406949878107
# HAEND   =     2.05551954382557
# ELEND   =     63.7480995639198
# AZEND   =     257.354049611633
# AMEND   =     1.11483643146515
# INSTPORT=                    2
# ATM3PORT=
# TRACKSYS= 'SIDEREAL'
# FOCUSZ  =   0.0448927097022533
# OBJECT  = 'mu. col '
# DOMEAZ  =               260.51
# SHUTLOWR=                  0.0
# SHUTUPPR=                100.0
# CAMCODE = 'AT      '
# CONTRLLR= 'O       '
# DAYOBS  = '20220317'
# SEQNUM  =                  237
# TESTTYPE= 'OBJECT  '
# EMUIMAGE= ''
# PROGRAM =
# REASON  =
# CURINDEX=                    0
# MAXINDEX=                    1
# TSTAND  =
# IMAGETAG= 'c83d43ac33743dc'
# OBSANNOT= ''
# TEMP_SET=   -94.15000152587891
# FILTBAND= 'Empty   '
# FILTER  = 'empty_1 '
# FILTSLOT=                    0
# GRATING = 'holo4_003'          / name of the disperser
# GRATBAND= 'Empty   '
# GRATSLOT=                    3
# LINSPOS =     67.9980010986328
# EXPTIME =                 20.0
# SHUTTIME=
# DARKTIME=     20.3163089752197
# AIRTEMP =                  8.9
# PRESSURE=               743.45
# HUMIDITY=                 48.0
# WINDSPD =                  9.4
# WINDDIR =                308.0
# SEEING  =     1.22428774833679
# FILENAME= 'AT_O_20220317_000237.fits'
# HEADVER = '2.9.5   '
# CHECKSUM=
# DATASUM =
# HIERARCH SIMULATE ATMCS =
# HIERARCH SIMULATE ATHEXAPOD = 0
# HIERARCH SIMULATE ATPNEUMATICS =
# HIERARCH SIMULATE ATDOME = 0
# HIERARCH SIMULATE ATSPECTROGRAPH = 0
# CCD_MANU= 'ITL     '
# CCD_TYPE=                    2
# CCD_SERN= '20862   '
# CCDTEMP =
# LSST_NUM= 'ITL-3800C-068'
# SEQCKSUM= '2552520002'
# SEQNAME = 'FP_ITL_2s_ir2_v25.seq'
# REBNAME = 'Unknown '
# CONTNUM = '412227310'
# CCDSLOT = 'S00     '
# RAFTBAY = 'R00     '
# OVERH   =                   64
# OVERV   =                   48
# PREH    =                    0
# INHERIT =                    T
# EXTNAME = 'Segment10'
# DATASEC = '[1:509,1:2000]'
# DETSEC  = '[509:1,1:2000]'
# DETSIZE = '[1:4072,1:4000]'
# DTV1    =                  510
# DTV2    =                    0
# DTM1_1  =                 -1.0
# DTM2_2  =                  1.0
# DTM1_2  =                    0
# DTM2_1  =                    0
# HIERARCH ASTRO METADATA FIX MODIFIED = T
# HIERARCH ASTRO METADATA FIX DATE = '2022-03-29T11:18:55.198041'
# HIERARCH ASTRO METADATA FIX VERSION = 'g66e8411885+78f5e69161'
# HA      =     2.05234725403386
# PARANGLE=    93.74272252137011 / parallactic angle in degree
# AIRMASS =     1.11445296512311
# OUTTEMP =                  8.9
# OUTPRESS=               743.45
# OUTHUM  =                 48.0
# CCDREBIN=                    2
# TARGET  = 'mu.col  '           / name of the target in the image
# REDSHIFT= '0.000364'           / redshift of the target
# ROTANGLE=                    0 / [deg] angle of the dispersion axis
# D2CCD   =    182.9980010986328 / [mm] distance between disperser and CCD
# COMMENT ["  FITS (Flexible Image Transport System) format is defined in 'Astrono
# COMMENT my", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376.
# COMMENT .359H", "= '        '", '---- Date, night and basic image information --
# COMMENT --', "= '        '", '---- Telescope info, location, observer ----', "=
# COMMENT '        '", '---- Pointing info, etc. ----', "= '        '", '---- TAN
# COMMENT Projection ----', "= '        '", '---- Image-identifying used to build
# COMMENT OBS-ID ----', "= '        '", '---- Additional Keys Information from Cam
# COMMENT era ----', "= '        '", '---- Image sequence numbers', "= '        '"
# COMMENT , '---- Test Stand information ----', "= '        '", '---- Information
# COMMENT from Camera (Common block) ----', "= '        '", '---- Information from
# COMMENT  Camera ----', "= '        '", '---- Filter/grating information ----', "
# COMMENT = '        '", '---- Exposure-related information ----', "= '        '",
# COMMENT  '---- Weather information ----', "= '        '", '---- Header informati
# COMMENT on ----', "= '        '", '---- Checksums ----', "= '        '", '---- H
# COMMENT ierarch information for CSC Simulatiom Mode ----', '---- Information fro
# COMMENT m Camera per sensor ----', "= '        '", '---- Geometry from Camera --
# COMMENT --']

# %% [markdown]
# # Plot image and find the target position
#
# - this image plotting is used to find the order 0 location to be set in logbook
#
# - for the moment this is humanly done

# %% [markdown]
# ## Load the new image file with Spectractor

# %%
title="{}) {}".format(idx,filename_image)
image.plot_image(figsize=(12, 10),scale="log",title=title)

# %% [markdown]
# - note now the position are written in the make_logbook.ipynb notebook

# %% [markdown]
# ## Set the 0th order location to be provided to Spectractor

# %%
filename_image
# Out:
# 'exposure_2022031700237_postisrccd.fits'

# %%
# overwrite if localtion is taken from that in logbook
if FLAG_ORDER0_LOCATION : 
    print("Set Order 0 location from logbook : ({},{})".format(x0,y0))
    guess = [x0,y0]

# %% [markdown]
# ## Let Spectractor find the location of the 0th order

# %%
parameters.VERBOSE = True
parameters.DEBUG = True
#x1, y1 = find_target(image, guess,rotated=False, use_wcs=False)
x1, y1 = find_target(image, guess,rotated=False)
# Out:
# 2022-04-05 14:34:14  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0               c1_0                c0_1
#     ----------------- ------------------- -------------------
#     7.156019070139631 0.07862265300802157 0.15817976505913667
# 2022-04-05 14:34:18  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 12 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-04-05 14:34:19  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 1 iterations because the relative change of cost is below ftol=5e-05.

# %%
print(x1,y1)
# Out:
# 313.72404716354947 1734.729272651256

# %% [markdown]
# ## Check the location of 0th order and Analysis of the quality of its focus

# %%
if x1>100:
    WID=100
else:
    WID=50
    

thumbnail=np.copy(image.data[int(y1)-WID:int(y1)+WID,int(x1)-WID:int(x1)+WID])
thumbnail_y=thumbnail.sum(axis=1)
thumbnail_x=thumbnail.sum(axis=0)
xx=np.linspace(int(x1)-WID,int(x1)+WID,len(thumbnail_x))
yy=np.linspace(int(y1)-WID,int(y1)+WID,len(thumbnail_y))
k0=kurtosis(thumbnail,axis=None,bias=True,fisher=True)
kx=kurtosis(thumbnail_x,bias=True,fisher=True)
ky=kurtosis(thumbnail_y,bias=True,fisher=True)
s0=skew(thumbnail,axis=None,bias=True)
sx=skew(thumbnail_x,bias=True)
sy=skew(thumbnail_y,bias=True)

# %%
shape_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}, Skx = {:3.3f}, Sky = {:3.3f} \n'.format(s0,sx,sy),
        r'kurtosis : K0  = {:3.3f}, Kx  = {:3.3f},  Ky = {:3.3f}'.format(k0,kx,ky)))

# %%
skew_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}'.format(s0),
        r'             : Skx = {:3.3f}'.format(sx),
        r'             : Sky = {:3.3f}'.format(sy)))

# %%
kurt_str='\n'.join((
        r'kurtosis : K0 = {:3.3f}'.format(k0),
        r'             : Kx = {:3.3f}'.format(kx),
        r'             : Ky = {:3.3f}'.format(ky)))

# %%
kurtosis_test_prob=kurtosistest(thumbnail,axis=None).pvalue
skew_test_prob=skewtest(thumbnail,axis=None).pvalue
normal_test_prob=normaltest(thumbnail,axis=None).pvalue

# %%
kurtosis_test_val=kurtosistest(thumbnail,axis=None).statistic
skew_test_val=skewtest(thumbnail,axis=None).statistic
normal_test_val=normaltest(thumbnail,axis=None).statistic

# %%
kurtosis_test_prob_x=kurtosistest(thumbnail_x).pvalue
skew_test_prob_x=skewtest(thumbnail_x).pvalue
normal_test_prob_x=normaltest(thumbnail_x).pvalue

# %%
kurtosis_test_prob_y=kurtosistest(thumbnail_y).pvalue
skew_test_prob_y=skewtest(thumbnail_y).pvalue
normal_test_prob_y=normaltest(thumbnail_y).pvalue

# %%
skew_str='\n'.join((
    r'skew     : Sk0 = {:3.3f}'.format(s0),
    r'             : Skx = {:3.3f}'.format(sx),
    r'             : Sky = {:3.3f}'.format(sy),
    r'             : p_test   = {:3.3e}'.format(skew_test_prob),
    r'             : p_test_x = {:3.3e}'.format(skew_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(skew_test_prob_y)))

# %%
kurt_str='\n'.join((
    r'kurtosis : K0 = {:3.3f}'.format(k0),
    r'             : Kx = {:3.3f}'.format(kx),
    r'             : Ky = {:3.3f}'.format(ky),
    r'             : p_test   = {:3.3e}'.format(kurtosis_test_prob),
    r'             : p_test_x = {:3.3e}'.format(kurtosis_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(kurtosis_test_prob_y)))

# %%
norm_str='\n'.join((
    r'normal  : p_test   = {:3.3e}'.format(normal_test_prob),
    r'             : p_test_x = {:3.3e}'.format(normal_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(normal_test_prob_y)))

# %%
props = dict(boxstyle='round',edgecolor="w",facecolor="w", alpha=0.5)

# %%
#matplotlib.pyplot.hist(x, 
#                       bins=10, 
#                       range=None, 
#                       normed=False, 
#                       weights=None, 
#                       cumulative=False, 
#                       bottom=None, 
#                       histtype=u'bar', 
#                       align=u'mid', 
#                       orientation=u'vertical', 
#                       rwidth=None, 
#                       log=False, 
#                       color=None, 
#                       label=None, 
#                       stacked=False, 
#                       hold=None, 
#                       **kwargs)

# %%
fig=plt.figure(figsize=(10,10))
fig.subplots_adjust(left=0.12, right=0.95, wspace=0.3,
                    bottom=0.15, top=0.9)

ax=fig.add_subplot(222)
ax.imshow(thumbnail,origin="lower",extent=(int(x1)-WID,int(x1)+WID,int(y1)-WID,int(y1)+WID))
ax.set_xlabel("X")
ax.set_ylabel("Y")

ax=fig.add_subplot(221)
base = plt.gca().transData
rot = transforms.Affine2D().rotate_deg(-90)
#ax.plot(yy,thumbnail_y,"g",rotation=u'vertical')
ax.plot(-yy,thumbnail_y,"g",transform= rot + base)
ax.set_ylabel("Y")

ax=fig.add_subplot(224)
ax.plot(xx,thumbnail_x,"b")
ax.set_xlabel("X")
plt.tight_layout()

ax=fig.add_subplot(223)
ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_yticks([])

ax.text(0.05, 0.9, skew_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.55, kurt_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.2, norm_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
plt.suptitle(title)
# Out:
# Text(0.5, 0.98, '0) exposure_2022031700237_postisrccd.fits')

# %%
# Usually stop here if one just want to get the 0th order location
if not FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR:
    assert False
else:
    assert True

# %% [markdown]
# # Go for spectrum reconstruction

# %%
#parameters.debug=True
#parameters.verbose=True
#parameters.display=True
#parameters.LIVE_FIT=False

# %%
parameters.debug=False
parameters.verbose=False
parameters.display=True
parameters.LIVE_FIT=False

# %%
filename
# Out:
# '/sps/lsst/groups/auxtel/data/2022/holo/20220317/exposure_2022031700237_postisrccd.fits'

# %%
#spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target, disperser_label=disperser_label, config=config)

# %%
try:
    spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target, disperser_label=disperser_label, config=config)
except:
    errtype = sys.exc_info()[0]  # E.g. <class 'PermissionError'>
    description = sys.exc_info()[1]   # E.g. [Errno 13] Permission denied: ...
        
    print("\t +++++++++++++++++++++ Exception occured +++++++++++++++++++++++++++++++++++++++++")
    print(f"\t >>>>>  errtype = {errtype}")
    print(f"\t >>>>>> description = {description}")
# Out:
# 2022-04-05 14:34:23  spectractor.extractor.extractor Spectractor          INFO
# 	Start SPECTRACTOR
# 2022-04-05 14:34:23  Image      load_AUXTEL_image    INFO
# 	Loading AUXTEL image /sps/lsst/groups/auxtel/data/2022/holo/20220317/exposure_2022031700237_postisrccd.fits...
# Section: paths
# x disperser_dir: extractor/dispersers/	=> parameters.DISPERSER_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/	 <class 'str'>
# x throughput_dir: simulation/AuxTelThroughput/	=> parameters.THROUGHPUT_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/	 <class 'str'>
# Section: pipeline
# x spectractor_fit_target_centroid: fit	=> parameters.SPECTRACTOR_FIT_TARGET_CENTROID: fit	 <class 'str'>
# x spectractor_compute_rotation_angle: disperser	=> parameters.SPECTRACTOR_COMPUTE_ROTATION_ANGLE: disperser	 <class 'str'>
# x spectractor_deconvolution_psf2d: False	=> parameters.SPECTRACTOR_DECONVOLUTION_PSF2D: False	 <class 'bool'>
# x spectractor_deconvolution_ffm: True	=> parameters.SPECTRACTOR_DECONVOLUTION_FFM: True	 <class 'bool'>
# x spectractor_deconvolution_sigma_clip: 100	=> parameters.SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP: 100	 <class 'int'>
# Section: instrument
# x obs_name: AUXTEL	=> parameters.OBS_NAME: AUXTEL	 <class 'str'>
# x obs_altitude: 2.66299616375123	=> parameters.OBS_ALTITUDE: 2.66299616375123	 <class 'float'>
# x obs_latitude: -30.2446389756252	=> parameters.OBS_LATITUDE: -30.2446389756252	 <class 'float'>
# x obs_diameter: 1.20	=> parameters.OBS_DIAMETER: 1.2 m	 <class 'astropy.units.quantity.Quantity'>
# x obs_epoch: J2000.0	=> parameters.OBS_EPOCH: J2000.0	 <class 'str'>
# x obs_transmission_systematics: 0.005	=> parameters.OBS_TRANSMISSION_SYSTEMATICS: 0.005	 <class 'float'>
# x obs_object_type: STAR	=> parameters.OBS_OBJECT_TYPE: STAR	 <class 'str'>
# x obs_telescope_transmission: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_TELESCOPE_TRANSMISSION: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_full_instrument_transmisson: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_FULL_INSTRUMENT_TRANSMISSON: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_quantum_efficiency: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_QUANTUM_EFFICIENCY: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_camera_rotation: 0	=> parameters.OBS_CAMERA_ROTATION: 0	 <class 'int'>
# x obs_camera_dec_flip_sign: 1	=> parameters.OBS_CAMERA_DEC_FLIP_SIGN: 1	 <class 'int'>
# x obs_camera_ra_flip_sign: 1	=> parameters.OBS_CAMERA_RA_FLIP_SIGN: 1	 <class 'int'>
# Section: CCD
# x ccd_imsize: 4096	=> parameters.CCD_IMSIZE: 2048	 <class 'int'>
# x ccd_pixel2mm: 10e-3	=> parameters.CCD_PIXEL2MM: 0.02	 <class 'float'>
# x ccd_pixel2arcsec: 0.0952	=> parameters.CCD_PIXEL2ARCSEC: 0.1904	 <class 'float'>
# x ccd_maxadu: 170000	=> parameters.CCD_MAXADU: 170000	 <class 'int'>
# x ccd_gain: 1.1	=> parameters.CCD_GAIN: 1.1	 <class 'float'>
# x ccd_rebin: 2	=> parameters.CCD_REBIN: 2	 <class 'int'>
# Section: spectrograph
# x distance2ccd: 175	=> parameters.DISTANCE2CCD: 175	 <class 'int'>
# x distance2ccd_err: 0.75	=> parameters.DISTANCE2CCD_ERR: 0.75	 <class 'float'>
# x grating_order_2over1: 0.1	=> parameters.GRATING_ORDER_2OVER1: 0.1	 <class 'float'>
# Section: search windows
# x xwindow: 100	=> parameters.XWINDOW: 50	 <class 'int'>
# x ywindow: 100	=> parameters.YWINDOW: 50	 <class 'int'>
# x xwindow_rot: 50	=> parameters.XWINDOW_ROT: 25	 <class 'int'>
# x ywindow_rot: 50	=> parameters.YWINDOW_ROT: 25	 <class 'int'>
# x pixshift_prior: 5	=> parameters.PIXSHIFT_PRIOR: 5	 <class 'int'>
# Section: rotation parameters
# x rot_prefilter: True	=> parameters.ROT_PREFILTER: True	 <class 'bool'>
# x rot_order: 5	=> parameters.ROT_ORDER: 5	 <class 'int'>
# x rot_angle_min: -10	=> parameters.ROT_ANGLE_MIN: -10	 <class 'int'>
# x rot_angle_max: 10	=> parameters.ROT_ANGLE_MAX: 10	 <class 'int'>
# Section: spectrum range
# x lambda_min: 300	=> parameters.LAMBDA_MIN: 300	 <class 'int'>
# x lambda_max: 1100	=> parameters.LAMBDA_MAX: 1100	 <class 'int'>
# Section: background subtraction parameters
# x pixwidth_signal: 40	=> parameters.PIXWIDTH_SIGNAL: 20	 <class 'int'>
# x pixdist_background: 140	=> parameters.PIXDIST_BACKGROUND: 70	 <class 'int'>
# x pixwidth_background: 40	=> parameters.PIXWIDTH_BACKGROUND: 20	 <class 'int'>
# x pixwidth_boxsize: 20	=> parameters.PIXWIDTH_BOXSIZE: 10	 <class 'int'>
# Section: PSF
# x psf_type: Moffat	=> parameters.PSF_TYPE: Moffat	 <class 'str'>
# x psf_poly_order: 2	=> parameters.PSF_POLY_ORDER: 2	 <class 'int'>
# x psf_fit_reg_param: 1	=> parameters.PSF_FIT_REG_PARAM: 1	 <class 'int'>
# x psf_pixel_step_transverse_fit: 50	=> parameters.PSF_PIXEL_STEP_TRANSVERSE_FIT: 25	 <class 'int'>
# x psf_fwhm_clip: 2	=> parameters.PSF_FWHM_CLIP: 2	 <class 'int'>
# Section: detection line algorithm parameters
# x calib_bgd_order: 3	=> parameters.CALIB_BGD_ORDER: 3	 <class 'int'>
# x calib_peak_width: 7	=> parameters.CALIB_PEAK_WIDTH: 7	 <class 'int'>
# x calib_bgd_width: 15	=> parameters.CALIB_BGD_WIDTH: 15	 <class 'int'>
# x calib_savgol_window: 5	=> parameters.CALIB_SAVGOL_WINDOW: 5	 <class 'int'>
# x calib_savgol_order: 2	=> parameters.CALIB_SAVGOL_ORDER: 2	 <class 'int'>
# Section: plot settings
# x paper: False	=> parameters.PAPER: False	 <class 'bool'>
# x linewidth: 2	=> parameters.LINEWIDTH: 2	 <class 'int'>
# x plot_dir: plots	=> parameters.PLOT_DIR: plots	 <class 'str'>
# x save: False	=> parameters.SAVE: False	 <class 'bool'>
# 2022-04-05 14:34:27  Image      load_AUXTEL_image    INFO
# 	Image loaded
# 2022-04-05 14:34:31  Image      load_image           INFO
# 	Loading disperser holo4_003...
# 2022-04-05 14:34:31  Hologram   load_specs           INFO
# 	Load disperser holo4_003:
# 	from /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/holo4_003
# 2022-04-05 14:34:31  Hologram   load_specs           INFO
# 	Grating characteristics:
# 	N = 156.00 +/- 1.00 grooves/mm
# 	Average tilt of -0.3 degrees
# target_name = mu.col, Selected object name for Simbad : mu. Col
# 2022-04-05 14:35:37  Star       load                 INFO
# 	Simbad:
#  MAIN_ID        RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... --------- ----------------
# * mu. Col 05 45 59.8950 -32 18 23.162 ... 0.0003640                1
#  MAIN_ID        RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... --------- ----------------
# * mu. Col 05 45 59.8950 -32 18 23.162 ... 0.0003640                1
# 2022-04-05 14:35:38  Star       load_spectra         INFO
# 	Loading /sps/lsst/groups/auxtel/softs/utils/PySynPhotData/grp/hst/cdbs//calspec/mucol_stis_005.fits
# 2022-04-05 14:36:04  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the image with guess=[156.86202358 867.36463633]...
# 2022-04-05 14:36:04  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                c1_0                 c0_1
#     ------------------ -------------------- --------------------
#     30.431593391751043 0.015430911911846881 -0.01213943787382659
# 2022-04-05 14:36:05  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 15 iterations because the relative change of cost is below ftol=5e-05.
# 2022-04-05 14:36:05  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 2 iterations because the relative change of cost is below ftol=0.0002.
# 2022-04-05 14:36:07  Image      find_target          INFO
# 	X,Y target position in pixels: 156.436,867.021
# 2022-04-05 14:36:07  Image      turn_image           INFO
# 	Rotate the image with angle theta=-0.28 degree
# 2022-04-05 14:36:11  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the rotated image...
# 2022-04-05 14:36:12  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0               c1_0              c0_1
#     ------------------ ----------------- ------------------
#     2155.5741069997744 5.276465253761024 18.081282804384784
# 2022-04-05 14:36:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: x_c has a null Jacobian; parameter is fixed at its last known current value (26.805054207728386).
# 2022-04-05 14:36:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: y_c has a null Jacobian; parameter is fixed at its last known current value (24.428712257711325).
# 2022-04-05 14:36:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: gamma has a null Jacobian; parameter is fixed at its last known current value (50.0).
# 2022-04-05 14:36:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: alpha has a null Jacobian; parameter is fixed at its last known current value (48.220243258413824).
# 2022-04-05 14:36:12  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 1 iterations because the relative change of cost is below ftol=0.0002.
# 2022-04-05 14:36:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: amplitude has a null Jacobian; parameter is fixed at its last known current value (-2.0954757928848267e-09).
# 2022-04-05 14:36:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: x_c has a null Jacobian; parameter is fixed at its last known current value (11.369078186428672).
# 2022-04-05 14:36:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: y_c has a null Jacobian; parameter is fixed at its last known current value (13.657719246930013).
# 2022-04-05 14:36:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: gamma has a null Jacobian; parameter is fixed at its last known current value (50.0).
# 2022-04-05 14:36:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: alpha has a null Jacobian; parameter is fixed at its last known current value (48.220243258413824).
# 2022-04-05 14:36:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Gradient descent terminated in 0 iterations because all parameters have null Jacobian.
# 2022-04-05 14:36:14  Image      find_target          INFO
# 	X,Y target position in pixels: 162.369,867.658
# 2022-04-05 14:36:14  Spectrum   __init__             INFO
# 	Spectrum info copied from image
# 2022-04-05 14:36:14  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extracting spectrum from image: spectrum with width 2*20 pixels and background from 70 to 90 pixels
# 2022-04-05 14:36:14  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop rotated image [591:1755,777:957] (size (1164, 180))
# 2022-04-05 14:36:17  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Start PSF1D transverse fit...
# 2022-04-05 14:36:25  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=7.776e+07 initial chisq_red=1670.1
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [ 0.80787426  0.56875118 -2.80264082  1.20174105  0.2983334  -2.57063316
#  -0.6103501  -1.57721316 -1.76956321]
# 	New parameters: [ 3.5597207  -3.88380895 -9.4928918   4.73049919 -4.85098112 -3.9025017
#   0.76539748 -2.41850553 -2.00820432]
# 	Final cost=5.5435e+07 final chisq_red=1190.6 computed in 1.56s
# 2022-04-05 14:36:26  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=5.5435e+07 initial chisq_red=1190.6
# 		 Line search: alpha_min=2.43 iter=0 funcalls=5
# 	Parameter shifts: [2.07674417 4.60820396 2.90970884 1.32744347 5.12251158 8.82822725
#  1.31876737 3.06691101 3.24816473]
# 	New parameters: [ 5.63646487  0.72439501 -6.58318296  6.05794266  0.27153046  4.92572556
#   2.08416485  0.64840548  1.23996042]
# 	Final cost=3.8244e+07 final chisq_red=821.39 computed in 1.05s
# 2022-04-05 14:36:27  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=3.8244e+07 initial chisq_red=821.39
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [ 2.46489582  3.70241485  5.03950708  3.11332312  2.1932523   2.38049112
#   0.11626804 -0.62346092  0.08116492]
# 	New parameters: [ 8.10136069  4.42680987 -1.54367588  9.17126578  2.46478276  7.30621667
#   2.20043289  0.02494456  1.32112533]
# 	Final cost=1.015e+07 final chisq_red=217.99 computed in 1.07s
# 2022-04-05 14:36:28  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=1.015e+07 initial chisq_red=217.99
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.5255528   1.27568048  0.88865767 -4.08747192 -5.54612384 -7.42777965
#  -0.76899634 -0.95511141 -1.70575867]
# 	New parameters: [ 8.62691349  5.70249035 -0.65501821  5.08379385 -3.08134108 -0.12156298
#   1.43143655 -0.93016685 -0.38463334]
# 	Final cost=2.5492e+06 final chisq_red=54.752 computed in 1.06s
# 2022-04-05 14:36:29  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=2.5492e+06 initial chisq_red=54.752
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [-0.03234844 -0.06899955  0.00847704  0.56863058  0.39042652  1.08902525
#   0.1540367   0.06874395  0.32803014]
# 	New parameters: [ 8.59456505  5.6334908  -0.64654117  5.65242443 -2.69091456  0.96746227
#   1.58547325 -0.8614229  -0.0566032 ]
# 	Final cost=1.5392e+06 final chisq_red=33.057 computed in 1.01s
# 2022-04-05 14:36:30  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=5: initial cost=1.5392e+06 initial chisq_red=33.057
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.01598244 -0.02674851 -0.04948661 -0.10745163  0.13322576 -0.65556139
#   0.01280174  0.1233993  -0.10213959]
# 	New parameters: [ 8.57858262  5.60674229 -0.69602778  5.5449728  -2.5576888   0.31190088
#   1.59827498 -0.73802359 -0.15874278]
# 	Final cost=1.3652e+06 final chisq_red=29.321 computed in 1.14s
# 2022-04-05 14:36:31  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=6: initial cost=1.3652e+06 initial chisq_red=29.321
# 		 Line search: alpha_min=3.38 iter=0 funcalls=6
# 	Parameter shifts: [ 0.00726829  0.0115893   0.0814076   0.29943686  0.80113797 -0.37472399
#   0.12543966  0.31089775 -0.03283424]
# 	New parameters: [ 8.58585091  5.61833159 -0.61462018  5.84440966 -1.75655083 -0.0628231
#   1.72371465 -0.42712585 -0.19157702]
# 	Final cost=1.1851e+06 final chisq_red=25.454 computed in 1.14s
# 2022-04-05 14:36:32  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=7: initial cost=1.1851e+06 initial chisq_red=25.454
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.02028758 -0.03607184 -0.07248436  0.23694026  0.29498365  1.29093874
#   0.05242098  0.05592714  0.35471595]
# 	New parameters: [ 8.56556332  5.58225975 -0.68710454  6.08134992 -1.46156718  1.22811564
#   1.77613563 -0.37119871  0.16313893]
# 	Final cost=1.0602e+06 final chisq_red=22.771 computed in 1.04s
# 2022-04-05 14:36:33  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=8: initial cost=1.0602e+06 initial chisq_red=22.771
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00298895 -0.00484454 -0.01343738  0.07382929 -0.0048964   0.23843974
#   0.02730226 -0.00231321  0.08802524]
# 	New parameters: [ 8.56257438  5.57741521 -0.70054192  6.15517921 -1.46646358  1.46655538
#   1.80343789 -0.37351191  0.25116417]
# 	Final cost=1.0559e+06 final chisq_red=22.677 computed in 1.10s
# 2022-04-05 14:36:34  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=9: initial cost=1.0559e+06 initial chisq_red=22.677
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.0004839   0.00145433  0.00044099 -0.00049784 -0.04151607  0.00585589
#   0.00032838 -0.01478567  0.0035506 ]
# 	New parameters: [ 8.56305828  5.57886954 -0.70010092  6.15468137 -1.50797965  1.47241127
#   1.80376627 -0.38829759  0.25471477]
# 	Final cost=1.0556e+06 final chisq_red=22.673 computed in 1.11s
# 2022-04-05 14:36:35  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=10: initial cost=1.0556e+06 initial chisq_red=22.673
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 4.72133427e-05  1.87785489e-04 -3.00940536e-04  3.20625993e-03
#  -2.40427605e-03  1.62118642e-02  1.15728426e-03 -9.79429556e-04
#   5.85043223e-03]
# 	New parameters: [ 8.56310549  5.57905733 -0.70040186  6.15788763 -1.51038392  1.48862313
#   1.80492355 -0.38927702  0.2605652 ]
# 	Final cost=1.0556e+06 final chisq_red=22.672 computed in 1.06s
# 2022-04-05 14:36:35  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 10 iterations because the relative change of cost is below ftol=2.147766323024055e-05.
# 2022-04-05 14:36:35  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: 8.5631 +0.0004 -0.0004
# 	y_c_1: 5.5791 +0.0007 -0.0007
# 	y_c_2: -0.7004 +0.001 -0.001
# 	gamma_0: 6.158 +0.002 -0.002
# 	gamma_1: -1.510 +0.004 -0.004
# 	gamma_2: 1.489 +0.005 -0.005
# 	alpha_0: 1.8049 +0.0006 -0.0006
# 	alpha_1: -0.389 +0.001 -0.001
# 	alpha_2: 0.261 +0.002 -0.002
#
# 2022-04-05 14:36:39  ChromaticPSF1DFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_holo_configHb/parameters_correlation.pdf.
# 2022-04-05 14:36:47  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop raw image [584:1748,770:956] (size (1164, 186))
# 2022-04-05 14:36:49  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Background statistics: mean=4.656 ADU/s, RMS=0.301 ADU/s.
# 2022-04-05 14:36:49  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop image [584:1748,770:956] (size (1164, 186))
# 	New target position in spectrogram frame: [-427.56365450686474, 97.02059465394291]
# 2022-04-05 14:36:51  spectractor.extractor.extractor Spectractor          INFO
# 	Calibrating order 1 spectrum...
# 2022-04-05 14:37:25  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: -0.159pix
# 	D = 181.314 mm (default: DISTANCE2CCD = 183.00 +/- 0.75 mm, -2.2 sigma shift)
# 2022-04-05 14:37:35  FullForwardModelFitWorkspace __init__             INFO
# 	Full forward model fitting with regularisation parameter r=1.
# 2022-04-05 14:41:11  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=2.3886e+08 initial chisq_red=5677.3
# 		 Line search: alpha_min=2.15 iter=0 funcalls=5
# 	Parameter shifts: [ 8.95180852e+00 -1.22311915e-03]
# 	New parameters: [ 8.95180852 -0.28122312]
# 	Final cost=6.596e+07 final chisq_red=1567.8 computed in 185.98s
# 2022-04-05 14:44:20  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=6.596e+07 initial chisq_red=1567.8
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-8.52989407  0.48877875]
# 	New parameters: [0.42191445 0.20755563]
# 	Final cost=2.5609e+07 final chisq_red=608.68 computed in 188.82s
# 2022-04-05 14:46:31  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=2.5609e+07 initial chisq_red=608.68
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [0.25894953 0.00046836]
# 	New parameters: [0.68086398 0.208024  ]
# 	Final cost=2.5151e+07 final chisq_red=597.79 computed in 130.63s
# 2022-04-05 14:48:48  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=2.5151e+07 initial chisq_red=597.79
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.08410121  0.00086034]
# 	New parameters: [0.59676277 0.20888434]
# 	Final cost=2.5144e+07 final chisq_red=597.63 computed in 137.28s
# 2022-04-05 14:48:48  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 3 iterations because the relative change of cost is below ftol=0.0018676228895861348.
# 2022-04-05 14:48:48  spectractor.fit.fitter print_parameter_summary INFO
# 	shift_y [pix]: 0.5968 +0.0004 -0.0004
# 	angle [deg]: 0.20888 +1e-05 -1e-05
#
# 2022-04-05 14:49:06  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit.pdf.
# 2022-04-05 14:49:08  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit_2.pdf.
# 2022-04-05 14:49:09  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_holo_configHb/parameters_correlation.pdf.
# 2022-04-05 14:49:32  spectractor.extractor.extractor run_ffm_minimisation INFO
# 	Start guess: [ 1.00000000e+00  1.81313588e+02 -1.58811519e-01  5.96762768e-01
#   2.08884339e-01  1.00000000e+00  8.65942167e+01  1.01011886e+03
#   5.81493056e+02 -2.94766568e-13  3.62659196e+00  2.73725693e+00
#  -7.00393499e-01  6.15788763e+00 -1.51038392e+00  1.48862313e+00
#   1.80492355e+00 -3.89277018e-01  2.60565200e-01  8.50000000e+03]
# 	with ['A2', 'D_CCD [mm]', 'shift_x [pix]', 'shift_y [pix]', 'angle [deg]', 'B', 'R', 'x_c_0', 'x_c_1', 'x_c_2', 'y_c_0', 'y_c_1', 'y_c_2', 'gamma_0', 'gamma_1', 'gamma_2', 'alpha_0', 'alpha_1', 'alpha_2', 'saturation_0']
# 2022-04-05 14:54:03  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=2.5537e+07 initial chisq_red=606.97
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.58170266 -0.0524096  -1.92484134 -1.67466415 -0.10140766  0.0741351
#  -0.21873456 -0.04336497]
# 	New parameters: [ 1.17846543  0.15647473  4.23304629 -3.18504807  1.38721547  1.87905866
#  -0.60801158  0.21720023]
# 	Final cost=4.3521e+06 final chisq_red=103.44 computed in 252.64s
# 2022-04-05 14:58:20  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=4.3521e+06 initial chisq_red=103.44
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.23633576  0.0177818   1.19739491  0.15557851  0.0036474   0.25923721
#  -0.1148975  -0.00644992]
# 	New parameters: [ 0.94212967  0.17425653  5.4304412  -3.02946956  1.39086287  2.13829586
#  -0.72290907  0.21075031]
# 	Final cost=1.8115e+06 final chisq_red=43.057 computed in 257.42s
# 2022-04-05 15:02:41  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=1.8115e+06 initial chisq_red=43.057
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.04008224  0.00314004  0.34297717  0.46897754  0.20795402  0.09828299
#   0.09223505  0.03593231]
# 	New parameters: [ 0.90204743  0.17739658  5.77341837 -2.56049202  1.59881688  2.23657885
#  -0.63067403  0.24668263]
# 	Final cost=1.7243e+06 final chisq_red=40.984 computed in 261.26s
# 2022-04-05 15:07:17  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=1.7243e+06 initial chisq_red=40.984
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.01654108 -0.00122407  0.04498796  0.09226351  0.03292464  0.01672187
#   0.03308508  0.01050848]
# 	New parameters: [ 0.91858851  0.1761725   5.81840633 -2.4682285   1.63174152  2.25330073
#  -0.59758895  0.25719111]
# 	Final cost=1.7205e+06 final chisq_red=40.893 computed in 275.78s
# 2022-04-05 15:11:06  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=1.7205e+06 initial chisq_red=40.893
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-6.28317750e-04  3.74443733e-05  6.14833415e-03  1.83349031e-02
#  -6.61935093e-03  1.89314289e-03  5.77051980e-03 -2.57504265e-03]
# 	New parameters: [ 0.91796019  0.17620995  5.82455467 -2.4498936   1.62512217  2.25519387
#  -0.59181843  0.25461607]
# 	Final cost=1.7204e+06 final chisq_red=40.891 computed in 229.19s
# 2022-04-05 15:11:06  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 4 iterations because the relative change of cost is below ftol=0.00018676228895861348.
# 2022-04-05 15:11:06  spectractor.fit.fitter print_parameter_summary INFO
# 	shift_y [pix]: 0.918 +0.001 -0.001
# 	angle [deg]: 0.17621 +6e-05 -6e-05
# 	gamma_0: 5.825 +0.002 -0.002
# 	gamma_1: -2.450 +0.004 -0.004
# 	gamma_2: 1.625 +0.005 -0.005
# 	alpha_0: 2.2552 +0.0006 -0.0006
# 	alpha_1: -0.592 +0.001 -0.001
# 	alpha_2: 0.255 +0.002 -0.002
#
# 2022-04-05 15:11:26  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit.pdf.
# 2022-04-05 15:11:28  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit_2.pdf.
# 2022-04-05 15:11:30  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_holo_configHb/parameters_correlation.pdf.
# 2022-04-05 15:12:08  RegFitWorkspace print_regularisation_summary INFO
# 	Optimal regularisation parameter: 13.01667315579268
# 	Tr(R) = 129.82580564865543
# 	N_params = 1164
# 	N_data = 42073 (without mask and outliers)
# 2022-04-05 15:12:27  FullForwardModelFitWorkspace run_ffm_minimisation WARNING
# 	Trace of final covariance matrix (279612.056256991) is below the trace of the prior covariance matrix (715032.8623483349). This is probably due to a very high regularisation parameter in case of a bad fit. Therefore the final covariance matrix is mulitiplied by the ratio of the traces and the amplitude parameters are very close the amplitude priors.
# 2022-04-05 15:16:23  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=1.696e+06 initial chisq_red=40.439
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-2.34942447e-03  8.03678138e-05 -4.68008529e-03 -1.01847883e-02
#   3.70696685e-03 -2.60447464e-03 -4.50248927e-03  2.67220785e-03]
# 	New parameters: [ 0.91561077  0.17629032  5.81987458 -2.46007839  1.62882914  2.2525894
#  -0.59632092  0.25728828]
# 	Final cost=1.6958e+06 final chisq_red=40.434 computed in 214.47s
# 2022-04-05 15:19:47  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=1.6958e+06 initial chisq_red=40.434
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.0042634  -0.00024993 -0.00342343  0.0002167   0.0014407  -0.00119442
#   0.00030739  0.00054143]
# 	New parameters: [ 0.91987417  0.17604039  5.81645115 -2.45986169  1.63026984  2.25139498
#  -0.59601353  0.2578297 ]
# 	Final cost=1.6958e+06 final chisq_red=40.433 computed in 203.68s
# 2022-04-05 15:19:47  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 1 iterations because the relative change of cost is below ftol=1.8676228895861346e-05.
# 2022-04-05 15:19:47  spectractor.fit.fitter print_parameter_summary INFO
# 	shift_y [pix]: 0.920 +0.001 -0.001
# 	angle [deg]: 0.17604 +6e-05 -6e-05
# 	gamma_0: 5.816 +0.002 -0.002
# 	gamma_1: -2.460 +0.004 -0.004
# 	gamma_2: 1.630 +0.005 -0.005
# 	alpha_0: 2.2514 +0.0006 -0.0006
# 	alpha_1: -0.596 +0.001 -0.001
# 	alpha_2: 0.258 +0.002 -0.002
#
# 2022-04-05 15:20:05  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit.pdf.
# 2022-04-05 15:20:07  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit_2.pdf.
# 2022-04-05 15:20:08  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_holo_configHb/parameters_correlation.pdf.
# 2022-04-05 15:20:10  spectractor.fit.fitter run_minimisation_sigma_clipping INFO
# 	No outliers detected at first iteration: break the sigma clipping iterations.
# 2022-04-05 15:20:10  spectractor.extractor.extractor run_ffm_minimisation INFO
# 	Newton: total computation time: 1837.6837539672852s
# 2022-04-05 15:20:11  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit.pdf.
# 2022-04-05 15:20:13  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit_2.pdf.
# 2022-04-05 15:20:41  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: -0.795pix
# 	D = 181.166 mm (default: DISTANCE2CCD = 183.00 +/- 0.75 mm, -2.4 sigma shift)
# 2022-04-05 15:24:32  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=1.6669e+06 initial chisq_red=39.743
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-1.50941011e-03 -7.02925457e-04  4.44152990e-03  1.37184901e-03
#  -1.34751101e-02  1.47126922e-03  7.73686125e-05 -2.57235612e-03]
# 	New parameters: [ 0.91836476  0.17533746  5.82089268 -2.45848984  1.61679473  2.25286625
#  -0.59593616  0.25525735]
# 	Final cost=1.6647e+06 final chisq_red=39.69 computed in 208.36s
# 2022-04-05 15:28:04  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=1.6647e+06 initial chisq_red=39.69
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.0059204   0.00035582  0.0009944   0.01121427  0.00586955 -0.00013074
#   0.00320708  0.00103806]
# 	New parameters: [ 0.91244437  0.17569329  5.82188708 -2.44727557  1.62266428  2.25273551
#  -0.59272908  0.25629541]
# 	Final cost=1.6646e+06 final chisq_red=39.689 computed in 211.89s
# 2022-04-05 15:31:45  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=1.6646e+06 initial chisq_red=39.689
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 1.53646025e-04 -1.36767892e-05 -5.52760469e-04 -4.81135109e-04
#  -2.60070224e-03 -1.51729464e-04 -1.37015138e-05 -8.33949219e-04]
# 	New parameters: [ 0.91259801  0.17567961  5.82133432 -2.44775671  1.62006357  2.25258378
#  -0.59274278  0.25546146]
# 	Final cost=1.6646e+06 final chisq_red=39.689 computed in 220.63s
# 2022-04-05 15:31:45  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 2 iterations because the relative change of cost is below ftol=1.8676228895861346e-05.
# 2022-04-05 15:31:45  spectractor.fit.fitter print_parameter_summary INFO
# 	shift_y [pix]: 0.913 +0.001 -0.001
# 	angle [deg]: 0.17568 +6e-05 -6e-05
# 	gamma_0: 5.821 +0.002 -0.002
# 	gamma_1: -2.448 +0.004 -0.004
# 	gamma_2: 1.620 +0.005 -0.005
# 	alpha_0: 2.2526 +0.0006 -0.0006
# 	alpha_1: -0.593 +0.001 -0.001
# 	alpha_2: 0.255 +0.002 -0.002
#
# 2022-04-05 15:32:02  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit.pdf.
# 2022-04-05 15:32:04  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit_2.pdf.
# 2022-04-05 15:32:05  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_holo_configHb/parameters_correlation.pdf.
# 2022-04-05 15:32:07  spectractor.fit.fitter run_minimisation_sigma_clipping INFO
# 	No outliers detected at first iteration: break the sigma clipping iterations.
# 2022-04-05 15:32:07  spectractor.extractor.extractor run_ffm_minimisation INFO
# 	Newton: total computation time: 2554.694309949875s
# 2022-04-05 15:32:08  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit.pdf.
# 2022-04-05 15:32:11  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_holo_configHb/ffm_bestfit_2.pdf.
# 2022-04-05 15:32:37  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: -0.361pix
# 	D = 181.232 mm (default: DISTANCE2CCD = 183.00 +/- 0.75 mm, -2.4 sigma shift)
# 2022-04-05 15:32:53  Spectrum   convert_from_ADUrate_to_flam WARNING You ask to convert spectrum already in erg/s/cm$^2$/nm in erg/s/cm^2/nm... check your code ! Skip the instruction.
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# 2022-04-05 15:32:53  astropy    _showwarning         WARNING VerifyWarning: Card is too long, comment will be truncated.
# 2022-04-05 15:32:54  Spectrum   save_spectrum        INFO
# 	Spectrum saved in ./outputs_process_holo_configHb/exposure_2022031700237_postisrccd_spectrum.fits
# Set header key DATE-OBS to 2022-03-18T00:50:48.964 from attr date_obs
# Set header key EXPTIME to 20.0 from attr expo
# Set header key AIRMASS to 1.1144529651231099 from attr airmass
# Set header key GRATING to holo4_003 from attr disperser_label
# Set header key UNIT2 to erg/s/cm$^2$/nm from attr units
# Set header key ROTANGLE to 0.17567960969989102 from attr rotation_angle
# Set header key DEC to -32.3064444444444 from attr dec
# Set header key HA to 30.737624463632244 from attr hour_angle
# Set header key OUTTEMP to 8.9 from attr temperature
# Set header key OUTPRESS to 743.45 from attr pressure
# Set header key OUTHUM to 48.0 from attr humidity
# Set header key LBDA_REF to 626.8154250174346 from attr lambda_ref
# Set header key PARANGLE to 93.74272252137011 from attr parallactic_angle
# 2022-04-05 15:32:54  Spectrum   save_spectrogram     INFO
# 	Spectrogram saved in ./outputs_process_holo_configHb/exposure_2022031700237_postisrccd_spectrogram.fits
# WARNING: UnitsWarning: 'erg/s/cm$^2$/nm' did not parse as fits unit: Invalid character at col 8 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# 2022-04-05 15:32:55  astropy    _showwarning         WARNING UnitsWarning: 'erg/s/cm$^2$/nm' did not parse as fits unit: Invalid character at col 8 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
# WARNING: UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# 2022-04-05 15:32:55  astropy    _showwarning         WARNING UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html

# %% [markdown]
# # Backup output

# %%
copy_tree(output_directory,os.path.join(finalpath_output_spectractor,"basespec"))
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_table.csv',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_spectrum.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_spectrogram.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_lines.csv']

# %%
copy_tree(output_figures,os.path.join(finalpath_output_spectractor,"plots"))
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/amplitude_correlation_matrix.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/background_extraction.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/.ipynb_checkpoints/fit_chromatic_psf_best_fit_noprior-checkpoint.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/.ipynb_checkpoints/image-checkpoint.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/regularisation.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/extractedLines.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/D2CCD_x0_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/intermediate_spectrum.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/ffm_bestfit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/image.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/order0_centroid_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/parameters_correlation.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/fwhm.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/fit_chromatic_psf_best_fit_noprior.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/rotated_image.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237/plots/ffm_bestfit_2.pdf']

# %%
# !ls -l  $finalpath_output_spectractor/basespec
# Out:
# total 18614
# -rw-r--r-- 1 dagoret lsst     2212 Apr  5 15:32 exposure_2022031700237_postisrccd_lines.csv
# -rw-r--r-- 1 dagoret lsst  7822080 Apr  5 15:32 exposure_2022031700237_postisrccd_spectrogram.fits
# -rw-r--r-- 1 dagoret lsst 10941120 Apr  5 15:32 exposure_2022031700237_postisrccd_spectrum.fits
# -rw-r--r-- 1 dagoret lsst   294284 Apr  5 15:32 exposure_2022031700237_postisrccd_table.csv

# %%
# !ls -l  $finalpath_output_spectractor/plots
# Out:
# total 1176
# -rw-r--r-- 1 dagoret lsst  48032 Apr  5 15:12 amplitude_correlation_matrix.pdf
# -rw-r--r-- 1 dagoret lsst  51558 Apr  5 14:36 background_extraction.pdf
# -rw-r--r-- 1 dagoret lsst  20032 Apr  5 15:32 D2CCD_x0_fit.pdf
# -rw-r--r-- 1 dagoret lsst  11520 Apr  5 15:32 extractedLines.fits
# -rw-r--r-- 1 dagoret lsst 203691 Apr  5 15:32 ffm_bestfit_2.pdf
# -rw-r--r-- 1 dagoret lsst 222405 Apr  5 15:32 ffm_bestfit.pdf
# -rw-r--r-- 1 dagoret lsst  95301 Apr  5 14:36 fit_chromatic_psf_best_fit_noprior.pdf
# -rw-r--r-- 1 dagoret lsst  21213 Apr  5 14:36 fwhm.pdf
# -rw-r--r-- 1 dagoret lsst  60533 Apr  5 14:36 image.pdf
# -rw-r--r-- 1 dagoret lsst 284120 Apr  5 14:36 intermediate_spectrum.pdf
# -rw-r--r-- 1 dagoret lsst  26930 Apr  5 14:36 order0_centroid_fit.pdf
# -rw-r--r-- 1 dagoret lsst  21687 Apr  5 15:32 parameters_correlation.pdf
# -rw-r--r-- 1 dagoret lsst  21575 Apr  5 15:11 regularisation.pdf
# -rw-r--r-- 1 dagoret lsst 111779 Apr  5 14:36 rotated_image.pdf

# %%
finalpath_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configHb/20220317/2022031700237'
