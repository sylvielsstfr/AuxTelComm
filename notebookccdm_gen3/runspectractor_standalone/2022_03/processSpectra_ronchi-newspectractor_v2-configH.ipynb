# %% [markdown]
# # process spectra for AuxTel with new spectractor (March 2022) for particular config H, for Ronchi

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : May 20th 2022
#
# - version v5 : Work with exposure butlen gen3
#
#
# - Config H:
#
#
#        After pull request from Jeremy on git-branch issue-auxteltarget
#
#        pour faire simple, je propose une pull request d'une branche qui contient mes réglages vers ta branche issue-auxteltarget :
#
#        https://github.com/LSSTDESC/Spectractor/pull/95
#
#
# This notebook is to help for finding the position of order 0
#
# CCIN2P3:
#
# - works with kernels **anaconda3_auxtel** (with libradtran) and **anaconda3_auxtel_v2** (no libradtran)
# - works with kernel **python 3** locally

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
print(sys.path)
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03', '', '/opt/conda/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload', '/pbs/home/d/dagoret/.local/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/certifi-2020.12.5-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/delight-1.0.1-py3.8-linux-x86_64.egg']

# %%
all_paths_to_remove = ['/opt/conda/lib/python3.8/site-packages','/pbs/home/d/dagoret/.local/lib/python3.8/site-packages']

for path_to_remove in all_paths_to_remove:
    if path_to_remove in sys.path:
        print(f"remove {path_to_remove} from sys.path")
        sys.path.remove(path_to_remove)
# Out:
# remove /opt/conda/lib/python3.8/site-packages from sys.path
# remove /pbs/home/d/dagoret/.local/lib/python3.8/site-packages from sys.path

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/certifi-2020.12.5-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/delight-1.0.1-py3.8-linux-x86_64.egg']

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
from matplotlib import  transforms
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (12,12)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/certifi-2020.12.5-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/delight-1.0.1-py3.8-linux-x86_64.egg']

# %%
print(sys.executable)
print(sys.version)
#print(sys.version_info)
# Out:
# /sps/lsst/groups/auxtel/softs/utils/anaconda3/bin/python
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_subplot(1,1,1)
X=np.linspace(-10,10,50)
Y=np.sin(X)
ax.plot(X,Y)
plt.show()

# %%
from iminuit import Minuit
import iminuit

# %%
iminuit.__version__
# Out:
# '2.8.4'

# %%
from astropy.io import fits
from astropy.coordinates import Angle
from astropy import units as u
from spectractor import parameters
from spectractor.extractor.extractor import Spectractor
from spectractor.extractor.images import *
from scipy import ndimage, misc

# %%
from astroquery.simbad import Simbad
result_table = Simbad.query_object("mu. Col")
print(result_table)
result_table = Simbad.query_object("HD111980")
print(result_table)
result_table = Simbad.query_object("eta1 dor")
print(result_table)
# Out:
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... ------------------- ----------------
# * mu. Col 05 45 59.8950 -32 18 23.162 ... 2020yCat.1350....0G                1
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... ------------------- ----------------
# HD 111980 12 53 15.0529 -18 31 20.013 ... 2020yCat.1350....0G                1
#   MAIN_ID         RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... ------------------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 2020yCat.1350....0G                1

# %%
result_table = Simbad.query_object("ETA01 DOR")

# %%
result_table
# Out:
# <Table length=1>
#   MAIN_ID         RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
#    object       str13         str13     ...        object            int32
# ----------- ------------- ------------- ... ------------------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 2020yCat.1350....0G                1

# %%
result_table["RA"]
# Out:
# <MaskedColumn name='RA' dtype='str13' unit='"h:m:s"' description='Right ascension' length=1>
# 06 06 09.3817

# %%
ra = Angle('06 06 09.3817 hours').deg 
ra
# Out:
# 91.53909041666665

# %%
dec=Angle('-66 02 22.635 degrees').deg 
dec
# Out:
# -66.03962083333333

# %%
from scipy.stats import kurtosis,skew
from scipy.stats import kurtosistest,skewtest,normaltest

# %%
from distutils.dir_util import copy_tree
import shutil

# %% [markdown]
# # Configuration

# %%
version="v5.0"  # version of flipping
# create output directories if not exist and clean existing files
FLAG_MANAGE_OUTPUT_SPECTRACTOR=True
# allow to run reconstruction with Spectractor
FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR=True

FLAG_REMOVE_WCS=False

# %%
# Choose the config filename
list_of_spectractorconfigfiles= ["auxtel_configA.ini","auxtel_configB.ini","auxtel_configC.ini","auxtel_configD.ini","auxtel_configE.ini","auxtel_configF.ini","auxtel_configG.ini","auxtel_configH_ronc.ini"]
config_idx = 7
configfilename= os.path.join("./config",list_of_spectractorconfigfiles[config_idx])
configdir = (list_of_spectractorconfigfiles[config_idx].split("_")[-1]).split(".") [0]

# %% [markdown]
# # Path

# %%
# path index for each month
DATE="20220316"
disperserfiltername = "empty~ronchi170lpmm"

# %%
# select if we run at CC or not (locally) 
# /sps/lsst/groups/auxtel/data/2022/holo/20220317
HOSTCC=True

# %%
# Set path depending on which computer running (according HOSTCC)
if HOSTCC:
    path_auxtel="/sps/lsst/groups/auxtel"
    path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    path_images=os.path.join(path_auxtel,"data/2022/"+disperserfiltername+"/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+disperserfiltername+"/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+disperserfiltername+"/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+disperserfiltername+"/"+configdir)
    
else:
    #path_auxtel="/Users/dagoret/DATA/AuxTelData2021"
    path_auxtel="/Users/sylvie/DATA/AuxTelDATA2022/2022"
    #path_spectractor=os.path.join(path_auxtel,"/users/dagoret/MacOSX/github/LSST/Spectractor")
    path_spectractor=os.path.join(path_auxtel,"/Users/sylvie/MacOSX/GitHub/LSST/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    #path_images=os.path.join(path_auxtel,"holo/quickLookExp_v2/"+DATE)
    path_images=os.path.join(path_auxtel,"holo/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+configdir)
    #path_output_spectractor=os.path.join(path_auxtel,"holo/OutputSpectractor/"+DATE)

# %% [markdown]
# # Utility Functions

# %%
def is_nan(x):
    return (x != x)

# %% [markdown]
# # Logbook for input file selection
#
# - the logbook contains all input image path and possibily the order 0 position

# %%
filename_logbook='logbooks/auxtelronchilogbook_'+DATE+'_' + version+'.csv'

# %%
df=pd.read_csv(filename_logbook,index_col=0)

# %%
pd.set_option('display.max_rows', None)

# %%
# show the list of input files from the logbook to select the file index in the logbook
df
# Out:
#     index                     date  \
# 0       0  2022-03-17T02:01:36.967
# 1       1  2022-03-17T02:01:51.934
# 2       2  2022-03-17T02:02:25.113
# 3       3  2022-03-17T02:04:15.406
# 4       4  2022-03-17T02:04:42.650
# 5       5  2022-03-17T02:05:03.885
# 6       6  2022-03-17T02:05:18.889
# 7       7  2022-03-17T02:05:51.894
# 8       8  2022-03-17T02:08:45.652
# 9       9  2022-03-17T02:09:12.307
# 10     10  2022-03-17T02:09:33.654
# 11     11  2022-03-17T02:09:48.656
# 12     12  2022-03-17T02:10:21.638
# 13     13  2022-03-17T02:12:14.155
# 14     14  2022-03-17T02:12:41.599
# 15     15  2022-03-17T02:13:03.412
# 16     16  2022-03-17T02:24:19.103
# 17     17  2022-03-17T02:24:40.714
# 18     18  2022-03-17T02:24:55.729
# 19     19  2022-03-17T02:25:28.642
# 20     20  2022-03-17T02:27:18.796
# 21     21  2022-03-17T02:27:48.401
# 22     22  2022-03-17T02:28:10.001
# 23     23  2022-03-17T02:28:25.010
# 24     24  2022-03-17T02:28:58.026
# 25     25  2022-03-17T02:31:54.053
# 26     26  2022-03-17T02:32:27.199
# 27     27  2022-03-17T02:32:48.575
# 28     28  2022-03-17T02:33:03.497
# 29     29  2022-03-17T02:33:36.619
# 30     30  2022-03-17T02:36:33.296
# 31     31  2022-03-17T03:14:49.425
# 32     32  2022-03-17T03:19:33.410
# 33     33  2022-03-17T03:20:00.755
# 34     34  2022-03-17T03:20:22.035
# 35     35  2022-03-17T03:20:36.955
# 36     36  2022-03-17T03:21:10.026
#
#                                                  path  \
# 0   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 1   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 2   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 3   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 4   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 5   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 6   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 7   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 8   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 9   /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 10  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 11  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 12  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 13  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 14  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 15  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 16  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 17  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 18  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 19  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 20  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 21  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 22  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 23  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 24  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 25  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 26  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 27  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 28  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 29  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 30  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 31  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 32  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 33  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 34  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 35  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# 36  /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
#
#                                       file  num    object   filter  \
# 0   exposure_2022031600334_postisrccd.fits  334   eta dor  empty_1
# 1   exposure_2022031600335_postisrccd.fits  335   eta dor  empty_1
# 2   exposure_2022031600336_postisrccd.fits  336   eta dor  empty_1
# 3   exposure_2022031600339_postisrccd.fits  339   eta dor  empty_1
# 4   exposure_2022031600340_postisrccd.fits  340   eta dor  empty_1
# 5   exposure_2022031600341_postisrccd.fits  341   eta dor  empty_1
# 6   exposure_2022031600342_postisrccd.fits  342   eta dor  empty_1
# 7   exposure_2022031600343_postisrccd.fits  343   eta dor  empty_1
# 8   exposure_2022031600346_postisrccd.fits  346  HD111980  empty_1
# 9   exposure_2022031600347_postisrccd.fits  347  HD111980  empty_1
# 10  exposure_2022031600348_postisrccd.fits  348  HD111980  empty_1
# 11  exposure_2022031600349_postisrccd.fits  349  HD111980  empty_1
# 12  exposure_2022031600350_postisrccd.fits  350  HD111980  empty_1
# 13  exposure_2022031600353_postisrccd.fits  353  HD111980  empty_1
# 14  exposure_2022031600354_postisrccd.fits  354  HD111980  empty_1
# 15  exposure_2022031600355_postisrccd.fits  355  HD111980  empty_1
# 16  exposure_2022031600375_postisrccd.fits  375   eta dor  empty_1
# 17  exposure_2022031600376_postisrccd.fits  376   eta dor  empty_1
# 18  exposure_2022031600377_postisrccd.fits  377   eta dor  empty_1
# 19  exposure_2022031600378_postisrccd.fits  378   eta dor  empty_1
# 20  exposure_2022031600381_postisrccd.fits  381   eta dor  empty_1
# 21  exposure_2022031600382_postisrccd.fits  382   eta dor  empty_1
# 22  exposure_2022031600383_postisrccd.fits  383   eta dor  empty_1
# 23  exposure_2022031600384_postisrccd.fits  384   eta dor  empty_1
# 24  exposure_2022031600385_postisrccd.fits  385   eta dor  empty_1
# 25  exposure_2022031600388_postisrccd.fits  388  HD111980  empty_1
# 26  exposure_2022031600389_postisrccd.fits  389  HD111980  empty_1
# 27  exposure_2022031600390_postisrccd.fits  390  HD111980  empty_1
# 28  exposure_2022031600391_postisrccd.fits  391  HD111980  empty_1
# 29  exposure_2022031600392_postisrccd.fits  392  HD111980  empty_1
# 30  exposure_2022031600395_postisrccd.fits  395   eta dor  empty_1
# 31  exposure_2022031600426_postisrccd.fits  426  HD111980  empty_1
# 32  exposure_2022031600429_postisrccd.fits  429  HD111980  empty_1
# 33  exposure_2022031600430_postisrccd.fits  430  HD111980  empty_1
# 34  exposure_2022031600431_postisrccd.fits  431  HD111980  empty_1
# 35  exposure_2022031600432_postisrccd.fits  432  HD111980  empty_1
# 36  exposure_2022031600433_postisrccd.fits  433  HD111980  empty_1
#
#         disperser   airmass  exposure     focus    seeing  pressure  \
# 0   ronchi170lpmm  1.389254       2.0  0.041059  0.690994    743.55
# 1   ronchi170lpmm  1.389746      20.0  0.041059  0.690994    743.55
# 2   ronchi170lpmm  1.390854      20.0  0.041059  0.901880    743.55
# 3   ronchi170lpmm  1.394221       2.0  0.041059  0.888362    743.55
# 4   ronchi170lpmm  1.395503       2.0  0.041059  0.769506    743.55
# 5   ronchi170lpmm  1.396225       2.0  0.041059  0.769506    743.55
# 6   ronchi170lpmm  1.396737      20.0  0.041059  0.769506    743.55
# 7   ronchi170lpmm  1.397864      20.0  0.041059  0.707492    743.55
# 8   ronchi170lpmm  1.665598       2.0  0.041059  0.636733    743.65
# 9   ronchi170lpmm  1.662427       2.0  0.041059  0.636733    743.65
# 10  ronchi170lpmm  1.659471       2.0  0.041059  0.710495    743.65
# 11  ronchi170lpmm  1.657402      20.0  0.041059  0.710495    743.65
# 12  ronchi170lpmm  1.652880      20.0  0.041059  0.710495    743.65
# 13  ronchi170lpmm  1.637197       2.0  0.041059  0.735194    743.55
# 14  ronchi170lpmm  1.634057       2.0  0.041059  0.744490    743.55
# 15  ronchi170lpmm  1.631143       2.0  0.041059  0.744490    743.60
# 16  ronchi170lpmm  1.438622       2.0  0.041059  0.606999    743.50
# 17  ronchi170lpmm  1.439470       2.0  0.041059  0.581734    743.50
# 18  ronchi170lpmm  1.440061      20.0  0.041059  0.581734    743.55
# 19  ronchi170lpmm  1.441358      20.0  0.041059  0.581734    743.55
# 20  ronchi170lpmm  1.445364       2.0  0.041059  0.622773    743.50
# 21  ronchi170lpmm  1.446956       2.0  0.041059  0.628092    743.50
# 22  ronchi170lpmm  1.447827       2.0  0.041059  0.628092    743.50
# 23  ronchi170lpmm  1.448432      20.0  0.041059  0.628092    743.50
# 24  ronchi170lpmm  1.449770      20.0  0.041059  0.684298    743.50
# 25  ronchi170lpmm  1.497534       2.0  0.041059  0.636733    743.50
# 26  ronchi170lpmm  1.494483       2.0  0.041059  0.636733    743.50
# 27  ronchi170lpmm  1.492258       2.0  0.041059  0.586542    743.50
# 28  ronchi170lpmm  1.490701      20.0  0.041059  0.586542    743.50
# 29  ronchi170lpmm  1.487297      20.0  0.041059  0.586542    743.50
# 30  ronchi170lpmm  1.468369       2.0  0.041059  0.575878    743.50
# 31  ronchi170lpmm  1.284489      20.0  0.044863  1.042027    743.50
# 32  ronchi170lpmm  1.266355       2.0  0.044863  0.933063    743.50
# 33  ronchi170lpmm  1.264959       2.0  0.044863  0.992551    743.45
# 34  ronchi170lpmm  1.263655       2.0  0.044863  0.992551    743.45
# 35  ronchi170lpmm  1.262760      20.0  0.044863  1.031583    743.45
# 36  ronchi170lpmm  1.260765      20.0  0.044863  1.031583    743.50
#
#     temperature  humidity  windspd
# 0          10.6      44.0      7.8
# 1          10.6      45.0      7.9
# 2          10.6      45.0      7.9
# 3          10.6      44.0      9.6
# 4          10.6      44.0      9.6
# 5          10.6      43.0      7.7
# 6          10.6      43.0      7.7
# 7          10.5      43.0      8.2
# 8          10.5      42.0      6.1
# 9          10.5      42.0      6.1
# 10         10.5      42.0      6.1
# 11         10.5      43.0      7.2
# 12         10.5      43.0      7.2
# 13         10.5      43.0      7.6
# 14         10.5      43.0      7.6
# 15         10.5      43.0      8.2
# 16         10.5      42.0      6.2
# 17         10.5      42.0      6.2
# 18         10.5      42.0      7.4
# 19         10.5      42.0      7.4
# 20         10.5      42.0      6.4
# 21         10.5      42.0      7.8
# 22         10.5      42.0      7.8
# 23         10.5      42.0      7.8
# 24         10.5      42.0      8.2
# 25         10.6      42.0      6.5
# 26         10.6      42.0      6.5
# 27         10.5      42.0      6.6
# 28         10.5      42.0      6.6
# 29         10.5      42.0      6.6
# 30         10.5      42.0      5.4
# 31         10.7      50.0      4.8
# 32         10.8      49.0      4.3
# 33         10.6      49.0      3.8
# 34         10.6      49.0      3.8
# 35         10.6      49.0      3.8
# 36         10.7      49.0      3.7

# %% [markdown]
# # Selection of input file
# - the input file is selected from the logbook list above

# %%
idx=1

# %%
print(df.iloc[idx]['file'])
# Out:
# exposure_2022031600335_postisrccd.fits

# %%
print(df.iloc[idx])
# Out:
# index                                                          1
# date                                     2022-03-17T02:01:51.934
# path           /sps/lsst/groups/auxtel/data/2022/empty~ronchi...
# file                      exposure_2022031600335_postisrccd.fits
# num                                                          335
# object                                                   eta dor
# filter                                                   empty_1
# disperser                                          ronchi170lpmm
# airmass                                                  1.38975
# exposure                                                      20
# focus                                                  0.0410588
# seeing                                                  0.690994
# pressure                                                  743.55
# temperature                                                 10.6
# humidity                                                      45
# windspd                                                      7.9
# Name: 1, dtype: object

# %%
myhome=os.getenv("HOME")

# %%
dir_images=path_images

# %%
dir_images
# Out:
# '/sps/lsst/groups/auxtel/data/2022/empty~ronchi170lpmm/20220316'

# %%
filename_image=df['file'][idx]
filename_image
# Out:
# 'exposure_2022031600335_postisrccd.fits'

# %%
target = df['object'][idx]
target
# Out:
# 'eta dor'

# %% [markdown]
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

# %%
if 'Obj-posXpix' in df.columns:
    x0=df['Obj-posXpix'][idx]
else:
    x0=300
    
if 'Obj-posYpix' in df.columns:    
    y0=df['Obj-posYpix'][idx]
else:
    y0=1700

# %%
FLAG_ORDER0_LOCATION=False

# %%
if not is_nan(x0)and not is_nan(y0):
    FLAG_ORDER0_LOCATION=True
    print("Order 0 location from logbook : ({},{})".format(x0,y0))
else:
    print("NO Order 0 location from logbook ! ")
# Out:
# Order 0 location from logbook : (300,1700)

# %% [markdown]
# ## Spectractor Configuration
#
# - Usually the Spectractor configuration file is put in local dir **./config**
#
#
# Ma suggestion, pour l'étude du centre optique via les scans des hologrammes, est de **mettre SPECTRACTOR_COMPUTE_ROTATION_ANGLE sur False** .
#
# Comme les angles ne sont pas très grands, si les marges du rectangle sont assez larges, réglables avec :
#
#     [background subtraction parameters]
#     # half transverse width of the signal rectangular window in pixels
#     PIXWIDTH_SIGNAL = 40
#
# alors le spectrogramme devrait tenir dans une boite rectangulaire même sans rotation de l'image. **L'important est de garder SPECTRACTOR_DECONVOLUTION_FFM à True car c'est lui qui te donnera l'angle de l'axe de dispersion ajusté sur les données, dont la valeur sera dans le mot clé ROTANGLE du header de sortie**.

# %%
rootfilename = filename_image.split(".")[0]
rootfilename_split =  rootfilename.split("_") 
filenumberdir = rootfilename_split[1]

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316'

# %%
# Fullfilename
filename=os.path.join(dir_images,filename_image)


# subdirectory
#subdir=filename_image.split(".")[0]
subdir=filenumberdir

# final output directory (where results will be copied to be backed up at the end)
finalpath_output_spectractor=os.path.join(path_output_spectractor,subdir)


# local directories to put spectra and plots
if configdir =="":
    output_directory="./outputs_process_ronchi"
    output_figures="figures_process_ronchi"
else:
    output_directory = "./outputs_process_ronchi_" + configdir
    output_figures   = "./figures_process_ronchi_" + configdir
    
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
if not os.path.isdir(output_figures):
    os.mkdir(output_figures)
    

# Final output directory


guess = [300,1700]
disperser_label = "ronchi170lpmm"
# old version
# config = os.path.join(path_spectractor_config,"auxtel_quicklook.ini")
# new version (September 20th 2021)

# configuration

# standard spectractor init configuration
#config = os.path.join(path_spectractor_config,"auxtel.ini")
# special for scan in XY
if configdir=="":
    config="./config/auxtel_scanXY.ini"
else:
    config=configfilename
    
target=df.iloc[idx]["object"]

# %%
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
if not os.path.isdir(output_figures):
    os.mkdir(output_figures)

# %%
print("config filename",config)
# Out:
# config filename ./config/auxtel_configH_ronc.ini

# %%
finalpath_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335'

# %% [markdown]
# ### manage output dir

# %%
def cleandir(path):
    if os.path.isdir(path):
        files=os.listdir(path)
        if len(files) > 0:
            for f in files:
                if os.path.isdir(os.path.join(path,f)):
                    if f==".ipynb_checkpoints":
                        shutil.rmtree(os.path.join(path,f))
                    else:
                        print(" Cannot remove this directory {}".format(os.path.join(path,f)))
                else:
                    os.remove(os.path.join(path,f))

# %%
# this flag must be set if one want to clean results from previous runs
if FLAG_MANAGE_OUTPUT_SPECTRACTOR:
    
    # manage global output directory of spectractor
    # Basically it has the name of the input file image
    
    # added recently    
    if configdir !="":
    # top directory    
        if not os.path.isdir(path_topoutput_spectractor):
            os.mkdir(path_topoutput_spectractor)   
            
            
        if not os.path.isdir(path_output_spectractor):
            os.mkdir(path_output_spectractor)

    
    if not os.path.isdir(output_directory):
        os.mkdir(output_directory)
    else:
        cleandir(output_directory)
 
    # manage subdirs spectrum/ and plots/
    if not os.path.isdir(output_figures):
        os.mkdir(output_figures)
    else:
        cleandir(output_figures)
    
    if not os.path.isdir(finalpath_output_spectractor):
        os.mkdir(finalpath_output_spectractor)
        os.mkdir(os.path.join(finalpath_output_spectractor,"basespec"))
        os.mkdir(os.path.join(finalpath_output_spectractor,"plots"))
    else:
        #cleandir(finalpath_output_spectractor)
        cleandir(os.path.join(finalpath_output_spectractor,"basespec"))
        cleandir(os.path.join(finalpath_output_spectractor,"plots"))

# %%
# /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo"

# %% [markdown]
# # Configuration of the Spectractor running mode

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

# %%
target
# Out:
# 'eta dor'

# %% [markdown]
# ## Load the image in the new image file with Spectractor

# %%
#image=Image(file_name=filename, target_label=target, disperser_label=disperser_label, config=config)
image=Image(file_name=filename, disperser_label=disperser_label, config=config)
# Out:
# No rebinning: parameters.REBIN is forced to 1.
# target_name = etador, Selected object name for Simbad : ETA1 DOR
#   MAIN_ID         RA           DEC      ...  Z_VALUE  SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... --------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 0.0000590                1

# %%
image.data.shape
# Out:
# (4072, 4000)

# %% [markdown]
# ## Show relevant parameters

# %%
print(parameters)
# Out:
# <module 'spectractor.parameters' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/parameters.py'>

# %%
parameters.LSST_SAVEFIGPATH=True
parameters.LSST_SAVEFIGPATH=output_figures

# %%
image.filter_label
# Out:
# ''

# %%
image.header["FILTER"]
# Out:
# 'empty_1'

# %%
image.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'LSST DM Header Service'
# TIMESYS = 'TAI     '
# DATE    = '2022-03-17T02:01:37.784'
# DATE-OBS= '2022-03-17T02:01:37.784'
# DATE-BEG= '2022-03-17T02:01:51.934'
# DATE-END= '2022-03-17T02:02:12.162'
# MJD     =     59655.0844650913
# MJD-OBS =     59655.0846288691
# MJD-BEG =     59655.0846288691
# MJD-END =     59655.0848629915
# OBSID   = 'AT_O_20220316_000335'
# GROUPID = '2022-03-17T01:56:22.288'
# IMGTYPE = 'OBJECT  '
# BUNIT   = 'adu     '
# FACILITY= 'Vera C. Rubin Observatory'
# TELESCOP= 'LSST AuxTelescope'
# INSTRUME= 'LATISS  '
# OBSERVER= 'LSST    '
# OBS-LONG=   -70.74941699999999
# OBS-LAT =           -30.244639
# OBS-ELEV=               2663.0
# OBSGEO-X=           1818938.94
# OBSGEO-Y=          -5208470.95
# OBSGEO-Z=          -3195172.08
# RA      =    91.53749999999999
# DEC     =    -66.0397222222222
# RASTART =     91.5661381137062
# DECSTART=    -66.0850426425273
# RAEND   =      91.566111708452
# DECEND  =    -66.0850240335554
# ROTPA   =     146.920777350738
# ROTCOORD= 'sky     '
# HASTART =     2.84146589722502
# ELSTART =       45.97005566796
# AZSTART =     203.150833477033
# AMSTART =     1.38974647736939
# HAEND   =     2.84788031897628
# ELEND   =     45.9373291416996
# AZEND   =     203.181149591459
# AMEND   =     1.39051292157413
# INSTPORT=                    2
# ATM3PORT=
# TRACKSYS= 'SIDEREAL'
# FOCUSZ  =   0.0410588495433331
# OBJECT  = 'eta dor '
# DOMEAZ  =               204.36
# SHUTLOWR=                  0.0
# SHUTUPPR=                100.0
# CAMCODE = 'AT      '
# CONTRLLR= 'O       '
# DAYOBS  = '20220316'
# SEQNUM  =                  335
# TESTTYPE= 'OBJECT  '
# EMUIMAGE= ''
# PROGRAM =
# REASON  =
# CURINDEX=                    0
# MAXINDEX=                    1
# TSTAND  =
# IMAGETAG= '20ce442178721b1e'
# OBSANNOT= ''
# TEMP_SET=   -94.15000152587891
# FILTBAND= 'Empty   '
# FILTER  = 'empty_1 '
# FILTSLOT=                    0
# GRATING = 'ronchi170lpmm'      / name of the disperser
# GRATBAND= 'Empty   '
# GRATSLOT=                    2
# LINSPOS =     67.9980010986328
# EXPTIME =                 20.0
# SHUTTIME=
# DARKTIME=     20.3166892528534
# AIRTEMP =                 10.6
# PRESSURE=               743.55
# HUMIDITY=                 45.0
# WINDSPD =                  7.9
# WINDDIR =                321.0
# SEEING  =   0.6909941434860229
# FILENAME= 'AT_O_20220316_000335.fits'
# HEADVER = '2.9.5   '
# CHECKSUM=
# DATASUM =
# HIERARCH SIMULATE ATMCS =
# HIERARCH SIMULATE ATHEXAPOD = 0
# HIERARCH SIMULATE ATPNEUMATICS =
# HIERARCH SIMULATE ATDOME = 0
# HIERARCH SIMULATE ATSPECTROGRAPH = 0
# CCD_MANU= 'ITL     '
# CCD_TYPE=                    2
# CCD_SERN= '20862   '
# CCDTEMP =
# LSST_NUM= 'ITL-3800C-068'
# SEQCKSUM= '2552520002'
# SEQNAME = 'FP_ITL_2s_ir2_v25.seq'
# REBNAME = 'Unknown '
# CONTNUM = '412227310'
# CCDSLOT = 'S00     '
# RAFTBAY = 'R00     '
# OVERH   =                   64
# OVERV   =                   48
# PREH    =                    0
# INHERIT =                    T
# EXTNAME = 'Segment10'
# DATASEC = '[1:509,1:2000]'
# DETSEC  = '[509:1,1:2000]'
# DETSIZE = '[1:4072,1:4000]'
# DTV1    =                  510
# DTV2    =                    0
# DTM1_1  =                 -1.0
# DTM2_2  =                  1.0
# DTM1_2  =                    0
# DTM2_1  =                    0
# HIERARCH ASTRO METADATA FIX MODIFIED = T
# HIERARCH ASTRO METADATA FIX DATE = '2022-05-19T12:07:04.142595'
# HIERARCH ASTRO METADATA FIX VERSION = 'g66e8411885+78f5e69161'
# HA      =     2.84467310810065
# PARANGLE=    57.24498896382314 / parallactic angle in degree
# AIRMASS =     1.39012969947176
# OUTTEMP =                 10.6
# OUTPRESS=               743.55
# OUTHUM  =                 45.0
# CCDREBIN=                    1
# TARGET  = 'etador  '           / name of the target in the image
# REDSHIFT= '5.9e-05 '           / redshift of the target
# ROTANGLE=                    0 / [deg] angle of the dispersion axis
# D2CCD   =    180.9980010986328 / [mm] distance between disperser and CCD
# COMMENT ["  FITS (Flexible Image Transport System) format is defined in 'Astrono
# COMMENT my", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376.
# COMMENT .359H", "= '        '", '---- Date, night and basic image information --
# COMMENT --', "= '        '", '---- Telescope info, location, observer ----', "=
# COMMENT '        '", '---- Pointing info, etc. ----', "= '        '", '---- TAN
# COMMENT Projection ----', "= '        '", '---- Image-identifying used to build
# COMMENT OBS-ID ----', "= '        '", '---- Additional Keys Information from Cam
# COMMENT era ----', "= '        '", '---- Image sequence numbers', "= '        '"
# COMMENT , '---- Test Stand information ----', "= '        '", '---- Information
# COMMENT from Camera (Common block) ----', "= '        '", '---- Information from
# COMMENT  Camera ----', "= '        '", '---- Filter/grating information ----', "
# COMMENT = '        '", '---- Exposure-related information ----', "= '        '",
# COMMENT  '---- Weather information ----', "= '        '", '---- Header informati
# COMMENT on ----', "= '        '", '---- Checksums ----', "= '        '", '---- H
# COMMENT ierarch information for CSC Simulatiom Mode ----', '---- Information fro
# COMMENT m Camera per sensor ----', "= '        '", '---- Geometry from Camera --
# COMMENT --']

# %% [markdown]
# # Plot image and find the target position
#
# - this image plotting is used to find the order 0 location to be set in logbook
#
# - for the moment this is humanly done

# %% [markdown]
# ## Load the new image file with Spectractor

# %%
title="{}) {}".format(idx,filename_image)
image.plot_image(figsize=(12, 10),scale="log",title=title)

# %% [markdown]
# - note now the position are written in the make_logbook.ipynb notebook

# %% [markdown]
# ## Set the 0th order location to be provided to Spectractor

# %%
filename_image
# Out:
# 'exposure_2022031600335_postisrccd.fits'

# %%
# overwrite if localtion is taken from that in logbook
if FLAG_ORDER0_LOCATION : 
    print("Set Order 0 location from logbook : ({},{})".format(x0,y0))
    guess = [x0,y0]
# Out:
# Set Order 0 location from logbook : (300,1700)

# %% [markdown]
# ## Let Spectractor find the location of the 0th order

# %%
parameters.VERBOSE = True
parameters.DEBUG = True
#x1, y1 = find_target(image, guess,rotated=False, use_wcs=False)
x1, y1 = find_target(image, guess,rotated=False)
# Out:
# 2022-05-20 17:39:51  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                c1_0                 c0_1
#     ------------------ -------------------- -------------------
#     6.9472254494081955 0.028265294372017566 0.06557521319730124
# 2022-05-20 17:39:52  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 24 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-05-20 17:39:53  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 2 iterations because the sum of parameter shift relative to the sum of the parameters is below xtol=1e-06.

# %%
print(x1,y1)
# Out:
# 308.7274570056671 1721.2852342570309

# %% [markdown]
# ## Check the location of 0th order and Analysis of the quality of its focus

# %%
if x1>100:
    WID=100
else:
    WID=50
    

thumbnail=np.copy(image.data[int(y1)-WID:int(y1)+WID,int(x1)-WID:int(x1)+WID])
thumbnail_y=thumbnail.sum(axis=1)
thumbnail_x=thumbnail.sum(axis=0)
xx=np.linspace(int(x1)-WID,int(x1)+WID,len(thumbnail_x))
yy=np.linspace(int(y1)-WID,int(y1)+WID,len(thumbnail_y))
k0=kurtosis(thumbnail,axis=None,bias=True,fisher=True)
kx=kurtosis(thumbnail_x,bias=True,fisher=True)
ky=kurtosis(thumbnail_y,bias=True,fisher=True)
s0=skew(thumbnail,axis=None,bias=True)
sx=skew(thumbnail_x,bias=True)
sy=skew(thumbnail_y,bias=True)

# %%
shape_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}, Skx = {:3.3f}, Sky = {:3.3f} \n'.format(s0,sx,sy),
        r'kurtosis : K0  = {:3.3f}, Kx  = {:3.3f},  Ky = {:3.3f}'.format(k0,kx,ky)))

# %%
skew_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}'.format(s0),
        r'             : Skx = {:3.3f}'.format(sx),
        r'             : Sky = {:3.3f}'.format(sy)))

# %%
kurt_str='\n'.join((
        r'kurtosis : K0 = {:3.3f}'.format(k0),
        r'             : Kx = {:3.3f}'.format(kx),
        r'             : Ky = {:3.3f}'.format(ky)))

# %%
kurtosis_test_prob=kurtosistest(thumbnail,axis=None).pvalue
skew_test_prob=skewtest(thumbnail,axis=None).pvalue
normal_test_prob=normaltest(thumbnail,axis=None).pvalue

# %%
kurtosis_test_val=kurtosistest(thumbnail,axis=None).statistic
skew_test_val=skewtest(thumbnail,axis=None).statistic
normal_test_val=normaltest(thumbnail,axis=None).statistic

# %%
kurtosis_test_prob_x=kurtosistest(thumbnail_x).pvalue
skew_test_prob_x=skewtest(thumbnail_x).pvalue
normal_test_prob_x=normaltest(thumbnail_x).pvalue

# %%
kurtosis_test_prob_y=kurtosistest(thumbnail_y).pvalue
skew_test_prob_y=skewtest(thumbnail_y).pvalue
normal_test_prob_y=normaltest(thumbnail_y).pvalue

# %%
skew_str='\n'.join((
    r'skew     : Sk0 = {:3.3f}'.format(s0),
    r'             : Skx = {:3.3f}'.format(sx),
    r'             : Sky = {:3.3f}'.format(sy),
    r'             : p_test   = {:3.3e}'.format(skew_test_prob),
    r'             : p_test_x = {:3.3e}'.format(skew_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(skew_test_prob_y)))

# %%
kurt_str='\n'.join((
    r'kurtosis : K0 = {:3.3f}'.format(k0),
    r'             : Kx = {:3.3f}'.format(kx),
    r'             : Ky = {:3.3f}'.format(ky),
    r'             : p_test   = {:3.3e}'.format(kurtosis_test_prob),
    r'             : p_test_x = {:3.3e}'.format(kurtosis_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(kurtosis_test_prob_y)))

# %%
norm_str='\n'.join((
    r'normal  : p_test   = {:3.3e}'.format(normal_test_prob),
    r'             : p_test_x = {:3.3e}'.format(normal_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(normal_test_prob_y)))

# %%
props = dict(boxstyle='round',edgecolor="w",facecolor="w", alpha=0.5)

# %%
#matplotlib.pyplot.hist(x, 
#                       bins=10, 
#                       range=None, 
#                       normed=False, 
#                       weights=None, 
#                       cumulative=False, 
#                       bottom=None, 
#                       histtype=u'bar', 
#                       align=u'mid', 
#                       orientation=u'vertical', 
#                       rwidth=None, 
#                       log=False, 
#                       color=None, 
#                       label=None, 
#                       stacked=False, 
#                       hold=None, 
#                       **kwargs)

# %%
fig=plt.figure(figsize=(10,10))
fig.subplots_adjust(left=0.12, right=0.95, wspace=0.3,
                    bottom=0.15, top=0.9)

ax=fig.add_subplot(222)
ax.imshow(thumbnail,origin="lower",extent=(int(x1)-WID,int(x1)+WID,int(y1)-WID,int(y1)+WID))
ax.set_xlabel("X")
ax.set_ylabel("Y")

ax=fig.add_subplot(221)
base = plt.gca().transData
rot = transforms.Affine2D().rotate_deg(-90)
#ax.plot(yy,thumbnail_y,"g",rotation=u'vertical')
ax.plot(-yy,thumbnail_y,"g",transform= rot + base)
ax.set_ylabel("Y")

ax=fig.add_subplot(224)
ax.plot(xx,thumbnail_x,"b")
ax.set_xlabel("X")
plt.tight_layout()

ax=fig.add_subplot(223)
ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_yticks([])

ax.text(0.05, 0.9, skew_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.55, kurt_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.2, norm_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
plt.suptitle(title)
# Out:
# Text(0.5, 0.98, '1) exposure_2022031600335_postisrccd.fits')

# %%
# Usually stop here if one just want to get the 0th order location
if not FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR:
    assert False
else:
    assert True

# %% [markdown]
# # Go for spectrum reconstruction

# %%
#parameters.debug=True
#parameters.verbose=True
#parameters.display=True
#parameters.LIVE_FIT=False

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

# %%
filename
# Out:
# '/sps/lsst/groups/auxtel/data/2022/empty~ronchi170lpmm/20220316/exposure_2022031600335_postisrccd.fits'

# %%
#spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target, disperser_label=disperser_label, config=config)

# %%
try:
    spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target, disperser_label=disperser_label, config=config)
except:
    errtype = sys.exc_info()[0]  # E.g. <class 'PermissionError'>
    description = sys.exc_info()[1]   # E.g. [Errno 13] Permission denied: ...
        
    print("\t +++++++++++++++++++++ Exception occured +++++++++++++++++++++++++++++++++++++++++")
    print(f"\t >>>>>  errtype = {errtype}")
    print(f"\t >>>>>> description = {description}")
# Out:
# 2022-05-20 17:39:55  spectractor.extractor.extractor Spectractor          INFO
# 	Start SPECTRACTOR
# 2022-05-20 17:39:55  Image      load_AUXTEL_image    INFO
# 	Loading AUXTEL image /sps/lsst/groups/auxtel/data/2022/empty~ronchi170lpmm/20220316/exposure_2022031600335_postisrccd.fits...
# 2022-05-20 17:39:55  Image      load_AUXTEL_image    INFO
# 	Image loaded
# 2022-05-20 17:39:55  Image      load_image           INFO
# 	Loading disperser ronchi170lpmm...
# 2022-05-20 17:39:55  Hologram   load_specs           INFO
# 	Load disperser ronchi170lpmm:
# 	from /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/ronchi170lpmm
# 2022-05-20 17:39:55  Hologram   load_specs           INFO
# 	Grating characteristics:
# 	N = 170.00 +/- 0.10 grooves/mm
# 	Average tilt of -1.1 degrees
# No rebinning: parameters.REBIN is forced to 1.
# Section: paths
# x disperser_dir: extractor/dispersers/	=> parameters.DISPERSER_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/	 <class 'str'>
# x throughput_dir: simulation/AuxTelThroughput/	=> parameters.THROUGHPUT_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/	 <class 'str'>
# Section: pipeline
# x spectractor_fit_target_centroid: fit	=> parameters.SPECTRACTOR_FIT_TARGET_CENTROID: fit	 <class 'str'>
# x spectractor_compute_rotation_angle: hessian	=> parameters.SPECTRACTOR_COMPUTE_ROTATION_ANGLE: hessian	 <class 'str'>
# x spectractor_deconvolution_psf2d: False	=> parameters.SPECTRACTOR_DECONVOLUTION_PSF2D: False	 <class 'bool'>
# x spectractor_deconvolution_ffm: True	=> parameters.SPECTRACTOR_DECONVOLUTION_FFM: True	 <class 'bool'>
# x spectractor_deconvolution_sigma_clip: 100	=> parameters.SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP: 100	 <class 'int'>
# Section: instrument
# x obs_name: AUXTEL	=> parameters.OBS_NAME: AUXTEL	 <class 'str'>
# x obs_altitude: 2.66299616375123	=> parameters.OBS_ALTITUDE: 2.66299616375123	 <class 'float'>
# x obs_latitude: -30.2446389756252	=> parameters.OBS_LATITUDE: -30.2446389756252	 <class 'float'>
# x obs_diameter: 1.20	=> parameters.OBS_DIAMETER: 1.2 m	 <class 'astropy.units.quantity.Quantity'>
# x obs_epoch: J2000.0	=> parameters.OBS_EPOCH: J2000.0	 <class 'str'>
# x obs_transmission_systematics: 0.005	=> parameters.OBS_TRANSMISSION_SYSTEMATICS: 0.005	 <class 'float'>
# x obs_object_type: STAR	=> parameters.OBS_OBJECT_TYPE: STAR	 <class 'str'>
# x obs_telescope_transmission: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_TELESCOPE_TRANSMISSION: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_full_instrument_transmisson: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_FULL_INSTRUMENT_TRANSMISSON: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_quantum_efficiency: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_QUANTUM_EFFICIENCY: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_camera_rotation: 0	=> parameters.OBS_CAMERA_ROTATION: 0	 <class 'int'>
# x obs_camera_dec_flip_sign: 1	=> parameters.OBS_CAMERA_DEC_FLIP_SIGN: 1	 <class 'int'>
# x obs_camera_ra_flip_sign: 1	=> parameters.OBS_CAMERA_RA_FLIP_SIGN: 1	 <class 'int'>
# Section: CCD
# x ccd_imsize: 4096	=> parameters.CCD_IMSIZE: 4096	 <class 'int'>
# x ccd_pixel2mm: 10e-3	=> parameters.CCD_PIXEL2MM: 0.01	 <class 'float'>
# x ccd_pixel2arcsec: 0.0952	=> parameters.CCD_PIXEL2ARCSEC: 0.0952	 <class 'float'>
# x ccd_maxadu: 170000	=> parameters.CCD_MAXADU: 170000	 <class 'int'>
# x ccd_gain: 1.1	=> parameters.CCD_GAIN: 1.1	 <class 'float'>
# x ccd_rebin: 1	=> parameters.CCD_REBIN: 1	 <class 'int'>
# Section: spectrograph
# x distance2ccd: 175	=> parameters.DISTANCE2CCD: 175	 <class 'int'>
# x distance2ccd_err: 0.75	=> parameters.DISTANCE2CCD_ERR: 0.75	 <class 'float'>
# x grating_order_2over1: 0.1	=> parameters.GRATING_ORDER_2OVER1: 0.1	 <class 'float'>
# Section: search windows
# x xwindow: 100	=> parameters.XWINDOW: 100	 <class 'int'>
# x ywindow: 100	=> parameters.YWINDOW: 100	 <class 'int'>
# x xwindow_rot: 50	=> parameters.XWINDOW_ROT: 50	 <class 'int'>
# x ywindow_rot: 50	=> parameters.YWINDOW_ROT: 50	 <class 'int'>
# x pixshift_prior: 5	=> parameters.PIXSHIFT_PRIOR: 5	 <class 'int'>
# Section: rotation parameters
# x rot_prefilter: True	=> parameters.ROT_PREFILTER: True	 <class 'bool'>
# x rot_order: 5	=> parameters.ROT_ORDER: 5	 <class 'int'>
# x rot_angle_min: -10	=> parameters.ROT_ANGLE_MIN: -10	 <class 'int'>
# x rot_angle_max: 10	=> parameters.ROT_ANGLE_MAX: 10	 <class 'int'>
# Section: spectrum range
# x lambda_min: 300	=> parameters.LAMBDA_MIN: 300	 <class 'int'>
# x lambda_max: 1100	=> parameters.LAMBDA_MAX: 1100	 <class 'int'>
# Section: background subtraction parameters
# x pixwidth_signal: 40	=> parameters.PIXWIDTH_SIGNAL: 40	 <class 'int'>
# x pixdist_background: 140	=> parameters.PIXDIST_BACKGROUND: 140	 <class 'int'>
# x pixwidth_background: 40	=> parameters.PIXWIDTH_BACKGROUND: 40	 <class 'int'>
# x pixwidth_boxsize: 20	=> parameters.PIXWIDTH_BOXSIZE: 20	 <class 'int'>
# Section: PSF
# x psf_type: Moffat	=> parameters.PSF_TYPE: Moffat	 <class 'str'>
# x psf_poly_order: 2	=> parameters.PSF_POLY_ORDER: 2	 <class 'int'>
# x psf_fit_reg_param: 1	=> parameters.PSF_FIT_REG_PARAM: 1	 <class 'int'>
# x psf_pixel_step_transverse_fit: 50	=> parameters.PSF_PIXEL_STEP_TRANSVERSE_FIT: 50	 <class 'int'>
# x psf_fwhm_clip: 2	=> parameters.PSF_FWHM_CLIP: 2	 <class 'int'>
# Section: detection line algorithm parameters
# x calib_bgd_order: 3	=> parameters.CALIB_BGD_ORDER: 3	 <class 'int'>
# x calib_peak_width: 7	=> parameters.CALIB_PEAK_WIDTH: 7	 <class 'int'>
# x calib_bgd_width: 15	=> parameters.CALIB_BGD_WIDTH: 15	 <class 'int'>
# x calib_savgol_window: 5	=> parameters.CALIB_SAVGOL_WINDOW: 5	 <class 'int'>
# x calib_savgol_order: 2	=> parameters.CALIB_SAVGOL_ORDER: 2	 <class 'int'>
# Section: plot settings
# x paper: False	=> parameters.PAPER: False	 <class 'bool'>
# x linewidth: 2	=> parameters.LINEWIDTH: 2	 <class 'int'>
# x plot_dir: plots	=> parameters.PLOT_DIR: plots	 <class 'str'>
# x save: True	=> parameters.SAVE: True	 <class 'bool'>
# 2022-05-20 17:39:58  Star       load                 INFO
# 	Simbad:
#   MAIN_ID         RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... --------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 0.0000590                1
# 2022-05-20 17:39:58  Star       load_spectra         INFO
# 	Loading /sps/lsst/groups/auxtel/softs/utils/PySynPhotData/grp/hst/cdbs//calspec/eta1dor_stis_002.fits
# target_name = etador, Selected object name for Simbad : ETA1 DOR
#   MAIN_ID         RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... --------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 0.0000590                1
# 2022-05-20 17:39:59  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the image with guess=[ 308.72745701 1721.28523426]...
# 2022-05-20 17:40:00  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                 c1_0                 c0_1
#     ------------------ --------------------- -------------------
#     15.212978537641357 0.0036949807498636317 0.00881423449765225
# 2022-05-20 17:40:00  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 9 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-05-20 17:40:01  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 1 iterations because the relative change of cost is below ftol=5e-05.
# 2022-05-20 17:40:02  Image      find_target          INFO
# 	X,Y target position in pixels: 309.135,1723.733
# 2022-05-20 17:40:02  Image      turn_image           INFO
# 	Rotate the image with angle theta=2.21 degree
# 2022-05-20 17:40:12  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the rotated image...
# 2022-05-20 17:40:12  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0              c1_0                c0_1
#     ----------------- ------------------ -------------------
#     2168.469321049362 4.1982857419674735 -2.4765795843811245
# 2022-05-20 17:40:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: x_c has a null Jacobian; parameter is fixed at its last known current value (47.388847045077945).
# 2022-05-20 17:40:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: y_c has a null Jacobian; parameter is fixed at its last known current value (49.32132060872351).
# 2022-05-20 17:40:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: gamma has a null Jacobian; parameter is fixed at its last known current value (100.0).
# 2022-05-20 17:40:12  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: alpha has a null Jacobian; parameter is fixed at its last known current value (7.407373411763766).
# 2022-05-20 17:40:12  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 1 iterations because the relative change of cost is below ftol=5e-05.
# 2022-05-20 17:40:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: amplitude has a null Jacobian; parameter is fixed at its last known current value (-3.818422555923462e-08).
# 2022-05-20 17:40:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: x_c has a null Jacobian; parameter is fixed at its last known current value (27.40460796846548).
# 2022-05-20 17:40:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: y_c has a null Jacobian; parameter is fixed at its last known current value (25.760815137403657).
# 2022-05-20 17:40:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: gamma has a null Jacobian; parameter is fixed at its last known current value (100.0).
# 2022-05-20 17:40:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: alpha has a null Jacobian; parameter is fixed at its last known current value (7.407373411763766).
# 2022-05-20 17:40:13  spectractor.fit.fitter gradient_descent     WARNING
# 	Gradient descent terminated in 0 iterations because all parameters have null Jacobian.
# 2022-05-20 17:40:13  Image      find_target          INFO
# 	X,Y target position in pixels: 374.405,1863.761
# 2022-05-20 17:40:13  Spectrum   __init__             INFO
# 	Spectrum info copied from image
# 2022-05-20 17:40:13  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extracting spectrum from image: spectrum with width 2*40 pixels and background from 140 to 180 pixels
# 2022-05-20 17:40:13  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop rotated image [1299:3819,1683:2043] (size (2520, 360))
# 2022-05-20 17:40:17  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Start PSF1D transverse fit...
# 2022-05-20 17:40:26  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=1.4895e+08 initial chisq_red=738.83
# 		 Line search: alpha_min=84.7 iter=0 funcalls=11
# 	Parameter shifts: [  -6.83169751   29.57508428   16.69921974 -237.88832715 -539.46207477
#  -687.14274201 -177.81521503 -218.60679862 -282.96991274]
# 	New parameters: [  -7.65808709   29.49478797   16.57966677 -235.52852958 -538.96819581
#  -686.37499808 -176.64002445 -218.47650718 -282.82826483]
# 	Final cost=1.2995e+08 final chisq_red=644.61 computed in 2.75s
# 2022-05-20 17:40:27  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: alpha_0 has a null Jacobian; parameter is fixed at its last known current value (-176.64002445109148).
# 2022-05-20 17:40:27  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: alpha_1 has a null Jacobian; parameter is fixed at its last known current value (-218.476507177412).
# 2022-05-20 17:40:27  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: alpha_2 has a null Jacobian; parameter is fixed at its last known current value (-282.8282648343964).
# 2022-05-20 17:40:28  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=1.2995e+08 initial chisq_red=644.61
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-1.44732858e-01 -2.01643150e-01 -5.60083972e-03  2.42349755e+02
#   5.42939255e+02  6.83884800e+02]
# 	New parameters: [-7.80281994 29.29314482 16.57406593  6.82122536  3.97105959 -2.49019771]
# 	Final cost=9.0845e+07 final chisq_red=450.62 computed in 1.95s
# 2022-05-20 17:40:30  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=9.0845e+07 initial chisq_red=450.62
# 		 Line search: alpha_min=2.62 iter=1 funcalls=7
# 	Parameter shifts: [-13.08011065 -13.30430666   2.99834109  14.25317837  12.66222389
#    4.4490728 ]
# 	New parameters: [-20.88293059  15.98883816  19.57240702  21.07440374  16.63328348
#    1.95887509]
# 	Final cost=4.7707e+07 final chisq_red=236.64 computed in 1.84s
# 2022-05-20 17:40:31  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=4.7707e+07 initial chisq_red=236.64
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-21.72994473 -34.47119521 -25.34830987   1.23727705   8.73414559
#   17.6279141 ]
# 	New parameters: [-42.61287532 -18.48235706  -5.77590285  22.31168079  25.36742907
#   19.58678919]
# 	Final cost=2.0847e+07 final chisq_red=103.41 computed in 1.57s
# 2022-05-20 17:40:33  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=2.0847e+07 initial chisq_red=103.41
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [  4.05047123   7.52516822   0.27566583 -17.71842829 -32.96825449
#  -26.0835633 ]
# 	New parameters: [-38.5624041  -10.95718883  -5.50023702   4.5932525   -7.60082542
#   -6.49677412]
# 	Final cost=1.1935e+07 final chisq_red=59.202 computed in 1.57s
# 2022-05-20 17:40:35  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=5: initial cost=1.1935e+07 initial chisq_red=59.202
# 		 Line search: alpha_min=2.38 iter=0 funcalls=5
# 	Parameter shifts: [ 1.14637419  1.70788269 -1.04441988  2.24166913  4.57375301  3.70702973]
# 	New parameters: [-37.4160299   -9.24930615  -6.5446569    6.83492163  -3.0270724
#   -2.78974439]
# 	Final cost=8.4704e+06 final chisq_red=42.016 computed in 1.57s
# 2022-05-20 17:40:36  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=6: initial cost=8.4704e+06 initial chisq_red=42.016
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.42634454 -0.63823453  0.10072129  0.63590028  1.00017264  2.02160446]
# 	New parameters: [-37.84237445  -9.88754068  -6.44393561   7.47082191  -2.02689977
#   -0.76813993]
# 	Final cost=8.1202e+06 final chisq_red=40.279 computed in 1.58s
# 2022-05-20 17:40:38  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=7: initial cost=8.1202e+06 initial chisq_red=40.279
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.2523128  -0.47927397 -0.17598141  0.0749616   0.15149854 -0.1374891 ]
# 	New parameters: [-38.09468724 -10.36681464  -6.61991702   7.54578351  -1.87540123
#   -0.90562903]
# 	Final cost=8.1048e+06 final chisq_red=40.202 computed in 1.87s
# 2022-05-20 17:40:40  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=8: initial cost=8.1048e+06 initial chisq_red=40.202
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [-0.21597889 -0.39702435 -0.30199443  0.03561616  0.06152404  0.1119012 ]
# 	New parameters: [-38.31066614 -10.763839    -6.92191145   7.58139967  -1.81387718
#   -0.79372783]
# 	Final cost=8.1025e+06 final chisq_red=40.191 computed in 1.63s
# 2022-05-20 17:40:41  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=9: initial cost=8.1025e+06 initial chisq_red=40.191
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.01413242 -0.02996444 -0.02099936  0.00065382  0.00682071 -0.05075022]
# 	New parameters: [-38.32479856 -10.79380344  -6.9429108    7.58205349  -1.80705647
#   -0.84447806]
# 	Final cost=8.1023e+06 final chisq_red=40.19 computed in 1.56s
# 2022-05-20 17:40:43  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=10: initial cost=8.1023e+06 initial chisq_red=40.19
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00660854 -0.01224228 -0.01596342  0.00194254  0.00290416  0.01609323]
# 	New parameters: [-38.33140709 -10.80604571  -6.95887422   7.58399603  -1.80415231
#   -0.82838483]
# 	Final cost=8.1023e+06 final chisq_red=40.19 computed in 1.56s
# 2022-05-20 17:40:43  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 10 iterations because the relative change of cost is below ftol=4.96031746031746e-06.
# 2022-05-20 17:40:43  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: -38.331 +0.004 -0.004
# 	y_c_1: -10.806 +0.008 -0.008
# 	y_c_2: -6.959 +0.008 -0.008
# 	gamma_0: 7.584 +0.002 -0.002
# 	gamma_1: -1.804 +0.004 -0.004
# 	gamma_2: -0.828 +0.005 -0.005
#
# 2022-05-20 17:40:45  ChromaticPSF1DFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_ronchi_ronc/parameters_correlation.pdf.
# 2022-05-20 17:40:52  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop raw image [1232:3751,1578:2036] (size (2519, 458))
# 2022-05-20 17:40:57  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Background statistics: mean=2.724 ADU/s, RMS=0.553 ADU/s.
# 2022-05-20 17:40:57  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop image [1232:3751,1578:2036] (size (2519, 458))
# 	New target position in spectrogram frame: [-922.8651718529866, 145.73305720551798]
# 2022-05-20 17:40:58  spectractor.extractor.extractor Spectractor          INFO
# 	Calibrating order 1 spectrum...
# 2022-05-20 17:41:36  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: -0.222pix
# 	D = 182.454 mm (default: DISTANCE2CCD = 181.00 +/- 0.75 mm, 1.9 sigma shift)
# 2022-05-20 17:41:45  FullForwardModelFitWorkspace __init__             INFO
# 	Full forward model fitting with regularisation parameter r=1.
# 	 +++++++++++++++++++++ Exception occured +++++++++++++++++++++++++++++++++++++++++
# 	 >>>>>  errtype = <class 'ValueError'>
# 	 >>>>>> description = matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2520 is different from 2519)

# %% [markdown]
# # Backup output

# %%
copy_tree(output_directory,os.path.join(finalpath_output_spectractor,"basespec"))
# Out:
# []

# %%
copy_tree(output_figures,os.path.join(finalpath_output_spectractor,"plots"))
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/background_extraction.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/D2CCD_x0_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/rotation_hessian.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/intermediate_spectrum.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/image.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/order0_centroid_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/parameters_correlation.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/fwhm.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/fit_chromatic_psf_best_fit_noprior.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335/plots/rotated_image.pdf']

# %%
# !ls -l  $finalpath_output_spectractor/basespec
# Out:
# total 0

# %%
# !ls -l  $finalpath_output_spectractor/plots
# Out:
# total 1022
# -rw-r--r-- 1 dagoret lsst  70549 May 20 17:40 background_extraction.pdf
# -rw-r--r-- 1 dagoret lsst  19713 May 20 17:41 D2CCD_x0_fit.pdf
# -rw-r--r-- 1 dagoret lsst 119959 May 20 17:40 fit_chromatic_psf_best_fit_noprior.pdf
# -rw-r--r-- 1 dagoret lsst  18548 May 20 17:40 fwhm.pdf
# -rw-r--r-- 1 dagoret lsst  55223 May 20 17:39 image.pdf
# -rw-r--r-- 1 dagoret lsst 587863 May 20 17:40 intermediate_spectrum.pdf
# -rw-r--r-- 1 dagoret lsst  33137 May 20 17:40 order0_centroid_fit.pdf
# -rw-r--r-- 1 dagoret lsst  19069 May 20 17:40 parameters_correlation.pdf
# -rw-r--r-- 1 dagoret lsst 102620 May 20 17:40 rotated_image.pdf
# -rw-r--r-- 1 dagoret lsst  17354 May 20 17:40 rotation_hessian.pdf

# %%
finalpath_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/empty~ronchi170lpmm/ronc/20220316/2022031600335'
