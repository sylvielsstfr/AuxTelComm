# %% [markdown]
# # process spectra for AuxTel with new spectractor (March 2022) for particular config F

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : March 31th 2022
# - last update : November 2nd 2021
# - version v5 : Work with exposure butlen gen3
#
#
# - Config F:
#
#        # Camera (x,y) flip signs with respect to (north-up, east-left) system
#        OBS_CAMERA_DEC_FLIP_SIGN = -1
#        OBS_CAMERA_RA_FLIP_SIGN = 1
#
#
#        # deconvolve spectrogram with simple 2D PSF analysis: False, True
#        SPECTRACTOR_DECONVOLUTION_PSF2D = True
#        # deconvolve spectrogram with full forward model: False, True
#        SPECTRACTOR_DECONVOLUTION_FFM = False
#
# This notebook is to help for finding the position of order 0
#
# CCIN2P3:
#
# - works with kernels **anaconda3_auxtel** (with libradtran) and **anaconda3_auxtel_v2** (no libradtran)
# - works with kernel **python 3** locally

# %% [markdown]
# # Scan
#
#     # wide scan : HD 160617
#     # all_myseq_holo=range(234,310)
#     # narrow scan :  HD 160617
#     # all_myseq_holo=range(317,365)

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
print(sys.path)
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03', '', '/opt/conda/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload', '/pbs/home/d/dagoret/.local/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg']

# %%
all_paths_to_remove = ['/opt/conda/lib/python3.8/site-packages','/pbs/home/d/dagoret/.local/lib/python3.8/site-packages']

for path_to_remove in all_paths_to_remove:
    if path_to_remove in sys.path:
        print(f"remove {path_to_remove} from sys.path")
        sys.path.remove(path_to_remove)
# Out:
# remove /opt/conda/lib/python3.8/site-packages from sys.path
# remove /pbs/home/d/dagoret/.local/lib/python3.8/site-packages from sys.path

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg']

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
from matplotlib import  transforms
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (12,12)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_03',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg']

# %%
print(sys.executable)
print(sys.version)
#print(sys.version_info)
# Out:
# /sps/lsst/groups/auxtel/softs/utils/anaconda3/bin/python
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_subplot(1,1,1)
X=np.linspace(-10,10,50)
Y=np.sin(X)
ax.plot(X,Y)
plt.show()

# %%
from iminuit import Minuit
import iminuit

# %%
iminuit.__version__
# Out:
# '2.2.0'

# %%
from astropy.io import fits
from spectractor import parameters
from spectractor.extractor.extractor import Spectractor
from spectractor.extractor.images import *
from scipy import ndimage, misc

# %%
from astroquery.simbad import Simbad
result_table = Simbad.query_object("mu. Col")
print(result_table)
result_table = Simbad.query_object("HD111980")
print(result_table)
result_table = Simbad.query_object("eta dor")
print(result_table)
# Out:
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... ------------------- ----------------
# * mu. Col 05 45 59.8950 -32 18 23.162 ... 2020yCat.1350....0G                1
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... ------------------- ----------------
# HD 111980 12 53 15.0529 -18 31 20.013 ... 2020yCat.1350....0G                1
#   MAIN_ID         RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... ------------------- ----------------
# * eta02 Dor 06 11 14.9816 -65 35 21.904 ... 2020yCat.1350....0G                1

# %%
result_table = Simbad.query_object("ETA DOR")

# %%
result_table
# Out:
# <Table length=1>
#   MAIN_ID         RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
#    object       str13         str13     ...        object            int32
# ----------- ------------- ------------- ... ------------------- ----------------
# * eta02 Dor 06 11 14.9816 -65 35 21.904 ... 2020yCat.1350....0G                1

# %%
from scipy.stats import kurtosis,skew
from scipy.stats import kurtosistest,skewtest,normaltest

# %%
from distutils.dir_util import copy_tree
import shutil

# %% [markdown]
# # Configuration

# %%
version="v5.0"  # version of flipping
# create output directories if not exist and clean existing files
FLAG_MANAGE_OUTPUT_SPECTRACTOR=True
# allow to run reconstruction with Spectractor
FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR=True

FLAG_REMOVE_WCS=False

# %%
# Choose the config filename
list_of_spectractorconfigfiles= ["auxtel_configA.ini","auxtel_configB.ini","auxtel_configC.ini","auxtel_configD.ini","auxtel_configE.ini","auxtel_configF.ini"]
config_idx = 5
configfilename= os.path.join("./config",list_of_spectractorconfigfiles[config_idx])
configdir = (list_of_spectractorconfigfiles[config_idx].split("_")[-1]).split(".") [0]

# %% [markdown]
# # Path

# %%
# path index for each month
DATE="20220316"

# %%
# select if we run at CC or not (locally) 
# /sps/lsst/groups/auxtel/data/2022/holo/20220317
HOSTCC=True

# %%
# Set path depending on which computer running (according HOSTCC)
if HOSTCC:
    path_auxtel="/sps/lsst/groups/auxtel"
    path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    path_images=os.path.join(path_auxtel,"data/2022/holo/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/holo/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/holo/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/holo/"+configdir)
    
else:
    #path_auxtel="/Users/dagoret/DATA/AuxTelData2021"
    path_auxtel="/Users/sylvie/DATA/AuxTelDATA2022/2022"
    #path_spectractor=os.path.join(path_auxtel,"/users/dagoret/MacOSX/github/LSST/Spectractor")
    path_spectractor=os.path.join(path_auxtel,"/Users/sylvie/MacOSX/GitHub/LSST/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    #path_images=os.path.join(path_auxtel,"holo/quickLookExp_v2/"+DATE)
    path_images=os.path.join(path_auxtel,"holo/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"OutputSpectractor/holo/"+configdir)
    #path_output_spectractor=os.path.join(path_auxtel,"holo/OutputSpectractor/"+DATE)

# %% [markdown]
# # Utility Functions

# %%
def is_nan(x):
    return (x != x)

# %% [markdown]
# # Logbook for input file selection
#
# - the logbook contains all input image path and possibily the order 0 position

# %%
filename_logbook='logbooks/auxtelholologbook_'+DATE+'_' + version+'.csv'

# %%
df=pd.read_csv(filename_logbook,index_col=0)

# %%
pd.set_option('display.max_rows', None)

# %%
# show the list of input files from the logbook to select the file index in the logbook
df
# Out:
#     index                     date  \
# 0       0  2022-03-17T01:59:37.776
# 1       1  2022-03-17T02:00:10.693
# 2       2  2022-03-17T02:03:04.275
# 3       3  2022-03-17T02:03:37.365
# 3   exposure_2022031600338_postisrccd.fits  338   ETA DOR  empty_1  holo4_003
# 4   exposure_2022031600344_postisrccd.fits  344   ETA DOR  empty_1  holo4_003
# 5   exposure_2022031600345_postisrccd.fits  345   ETA DOR  empty_1  holo4_003
# 6   exposure_2022031600351_postisrccd.fits  351  HD111980  empty_1  holo4_003
# 7   exposure_2022031600352_postisrccd.fits  352  HD111980  empty_1  holo4_003
# 8   exposure_2022031600358_postisrccd.fits  358  HD111980  empty_1  holo4_003
# 9   exposure_2022031600359_postisrccd.fits  359  HD111980  empty_1  holo4_003
# 10  exposure_2022031600365_postisrccd.fits  365  HD111980  empty_1  holo4_003
# 11  exposure_2022031600366_postisrccd.fits  366  HD111980  empty_1  holo4_003
# 12  exposure_2022031600372_postisrccd.fits  372   ETA DOR  empty_1  holo4_003
# 13  exposure_2022031600373_postisrccd.fits  373   ETA DOR  empty_1  holo4_003
# 14  exposure_2022031600379_postisrccd.fits  379   ETA DOR  empty_1  holo4_003
# 15  exposure_2022031600380_postisrccd.fits  380   ETA DOR  empty_1  holo4_003
# 16  exposure_2022031600386_postisrccd.fits  386   ETA DOR  empty_1  holo4_003
# 17  exposure_2022031600387_postisrccd.fits  387   ETA DOR  empty_1  holo4_003
# 18  exposure_2022031600393_postisrccd.fits  393  HD111980  empty_1  holo4_003
# 19  exposure_2022031600394_postisrccd.fits  394  HD111980  empty_1  holo4_003
# 20  exposure_2022031600400_postisrccd.fits  400   ETA DOR  empty_1  holo4_003
# 21  exposure_2022031600401_postisrccd.fits  401   ETA DOR  empty_1  holo4_003
# 22  exposure_2022031600420_postisrccd.fits  420  HD111980  empty_1  holo4_003
# 23  exposure_2022031600421_postisrccd.fits  421  HD111980  empty_1  holo4_003
# 24  exposure_2022031600427_postisrccd.fits  427  HD111980  empty_1  holo4_003
# 25  exposure_2022031600428_postisrccd.fits  428  HD111980  empty_1  holo4_003
# 26  exposure_2022031600434_postisrccd.fits  434  HD111980  empty_1  holo4_003
# 27  exposure_2022031600435_postisrccd.fits  435  HD111980  empty_1  holo4_003
#
#      airmass  exposure  ...  temperature  humidity  windspd  Obj-posXpix  \
# 0   1.385409      20.0  ...         10.6      44.0      7.2          NaN
# 1   1.386483      20.0  ...         10.6      44.0      7.4          NaN
# 2   1.392269      20.0  ...         10.6      43.0      7.4          NaN
# 3   1.393378      20.0  ...         10.6      43.0      7.4          NaN
# 4   1.399309      20.0  ...         10.5      43.0      8.2          NaN
# 5   1.400449      20.0  ...         10.5      43.0      7.6          NaN
# 6   1.647734      20.0  ...         10.5      43.0     13.1        300.0
# 7   1.643280      20.0  ...         10.5      43.0     13.1          NaN
# 8   1.619945      20.0  ...         10.5      43.0     12.1          NaN
# 9   1.615702      20.0  ...         10.5      44.0      6.9          NaN
# 10  1.593415      20.0  ...         10.5      42.0      6.8          NaN
# 11  1.589327      20.0  ...         10.5      42.0      6.8          NaN
# 12  1.434807      20.0  ...         10.5      42.0      6.6          NaN
# 13  1.436089      20.0  ...         10.4      42.0     14.9          NaN
# 14  1.443028      20.0  ...         10.5      42.0      6.7          NaN
# 15  1.444342      20.0  ...         10.5      42.0      6.7          NaN
# 16  1.451472      20.0  ...         10.5      42.0      8.2          NaN
# 17  1.452820      20.0  ...         10.5      42.0      5.5          NaN
# 18  1.483400      20.0  ...         10.5      42.0      6.3          NaN
# 19  1.480042      20.0  ...         10.6      42.0      6.5          NaN
# 20  1.475077      20.0  ...         10.5      43.0      6.1          NaN
# 21  1.476509      20.0  ...         10.5      43.0      6.1          NaN
# 22  1.295777      20.0  ...         10.6      51.0      4.5          NaN
# 23  1.293586      20.0  ...         10.6      51.0      4.5          NaN
# 24  1.282047      20.0  ...         10.7      50.0      4.8          NaN
# 25  1.279939      20.0  ...         10.7      49.0      5.1          NaN
# 26  1.258452      20.0  ...         10.7      49.0      3.4          NaN
# 27  1.256483      20.0  ...         10.7      49.0      3.4          NaN
#
#     Obj-posYpix  Dx  Dy  skip  run  quality
# 0           NaN NaN NaN        NaN      NaN
# 1           NaN NaN NaN        NaN      NaN
# 2           NaN NaN NaN        NaN      NaN
# 3           NaN NaN NaN        NaN      NaN
# 4           NaN NaN NaN        NaN      NaN
# 5           NaN NaN NaN        NaN      NaN
# 6        1700.0 NaN NaN        1.0      1.0
# 7           NaN NaN NaN        NaN      NaN
# 8           NaN NaN NaN        NaN      NaN
# 9           NaN NaN NaN        NaN      NaN
# 10          NaN NaN NaN        NaN      NaN
# 11          NaN NaN NaN        NaN      NaN
# 12          NaN NaN NaN        NaN      NaN
# 13          NaN NaN NaN        NaN      NaN
# 14          NaN NaN NaN        NaN      NaN
# 15          NaN NaN NaN        NaN      NaN
# 16          NaN NaN NaN        NaN      NaN
# 17          NaN NaN NaN        NaN      NaN
# 18          NaN NaN NaN        NaN      NaN
# 19          NaN NaN NaN        NaN      NaN
# 20          NaN NaN NaN        NaN      NaN
# 21          NaN NaN NaN        NaN      NaN
# 22          NaN NaN NaN        NaN      NaN
# 23          NaN NaN NaN        NaN      NaN
# 24          NaN NaN NaN        NaN      NaN
# 25          NaN NaN NaN        NaN      NaN
# 26          NaN NaN NaN        NaN      NaN
# 27          NaN NaN NaN        NaN      NaN
#
# [28 rows x 23 columns]

# %% [markdown]
# # Selection of input file
# - the input file is selected from the logbook list above

# %%
idx=0

# %%
print(df.iloc[idx]['file'])
# Out:
# exposure_2022031600330_postisrccd.fits

# %%
print(df.iloc[idx])
# Out:
# index                                                        0
# date                                   2022-03-17T01:59:37.776
# path           /sps/lsst/groups/auxtel/data/2022/holo/20220316
# file                    exposure_2022031600330_postisrccd.fits
# num                                                        330
# object                                                 ETA DOR
# filter                                                 empty_1
# disperser                                            holo4_003
# airmass                                                1.38541
# exposure                                                    20
# focus                                                0.0410588
# seeing                                                0.921627
# pressure                                                743.55
# temperature                                               10.6
# humidity                                                    44
# windspd                                                    7.2
# Obj-posXpix                                                NaN
# Obj-posYpix                                                NaN
# Dx                                                         NaN
# Dy                                                         NaN
# skip
# run                                                        NaN
# quality                                                    NaN
# Name: 0, dtype: object

# %%
myhome=os.getenv("HOME")

# %%
dir_images=path_images

# %%
dir_images
# Out:
# '/sps/lsst/groups/auxtel/data/2022/holo/20220316'

# %%
filename_image=df['file'][idx]
filename_image
# Out:
# 'exposure_2022031600330_postisrccd.fits'

# %%
target = df['object'][idx]
target
# Out:
# 'ETA DOR'

# %% [markdown]
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

# %%
x0=df['Obj-posXpix'][idx]
y0=df['Obj-posYpix'][idx]

# %%
FLAG_ORDER0_LOCATION=False

# %%
if not is_nan(x0)and not is_nan(y0):
    FLAG_ORDER0_LOCATION=True
    print("Order 0 location from logbook : ({},{})".format(x0,y0))
else:
    print("NO Order 0 location from logbook ! ")
# Out:
# NO Order 0 location from logbook !

# %% [markdown]
# ## Spectractor Configuration
#
# - Usually the Spectractor configuration file is put in local dir **./config**
#
#
# Ma suggestion, pour l'étude du centre optique via les scans des hologrammes, est de **mettre SPECTRACTOR_COMPUTE_ROTATION_ANGLE sur False** .
#
# Comme les angles ne sont pas très grands, si les marges du rectangle sont assez larges, réglables avec :
#
#     [background subtraction parameters]
#     # half transverse width of the signal rectangular window in pixels
#     PIXWIDTH_SIGNAL = 40
#
# alors le spectrogramme devrait tenir dans une boite rectangulaire même sans rotation de l'image. **L'important est de garder SPECTRACTOR_DECONVOLUTION_FFM à True car c'est lui qui te donnera l'angle de l'axe de dispersion ajusté sur les données, dont la valeur sera dans le mot clé ROTANGLE du header de sortie**.

# %%
rootfilename = filename_image.split(".")[0]
rootfilename_split =  rootfilename.split("_") 
filenumberdir = rootfilename_split[1]

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316'

# %%
# Fullfilename
filename=os.path.join(dir_images,filename_image)


# subdirectory
#subdir=filename_image.split(".")[0]
subdir=filenumberdir

# final output directory (where results will be copied to be backed up at the end)
finalpath_output_spectractor=os.path.join(path_output_spectractor,subdir)


# local directories to put spectra and plots
if configdir =="":
    output_directory="./outputs_process_holo"
    output_figures="figures_process_holo"
else:
    output_directory = "./outputs_process_holo_" + configdir
    output_figures   = "./figures_process_holo_" + configdir
    
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
if not os.path.isdir(output_figures):
    os.mkdir(output_figures)
    

# Final output directory


guess = [300,1700]
disperser_label = "holo4_003"
# old version
# config = os.path.join(path_spectractor_config,"auxtel_quicklook.ini")
# new version (September 20th 2021)

# configuration

# standard spectractor init configuration
#config = os.path.join(path_spectractor_config,"auxtel.ini")
# special for scan in XY
if configdir=="":
    config="./config/auxtel_scanXY.ini"
else:
    config=configfilename
    
target=df.iloc[idx]["object"]

# %%
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
if not os.path.isdir(output_figures):
    os.mkdir(output_figures)

# %%
print("config filename",config)
# Out:
# config filename ./config/auxtel_configF.ini

# %%
finalpath_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330'

# %% [markdown]
# ### manage output dir

# %%
def cleandir(path):
    if os.path.isdir(path):
        files=os.listdir(path)
        if len(files) > 0:
            for f in files:
                if os.path.isdir(os.path.join(path,f)):
                    if f==".ipynb_checkpoints":
                        shutil.rmtree(os.path.join(path,f))
                    else:
                        print(" Cannot remove this directory {}".format(os.path.join(path,f)))
                else:
                    os.remove(os.path.join(path,f))

# %%
# this flag must be set if one want to clean results from previous runs
if FLAG_MANAGE_OUTPUT_SPECTRACTOR:
    
    # manage global output directory of spectractor
    # Basically it has the name of the input file image
    
    # added recently    
    if configdir !="":
    # top directory    
        if not os.path.isdir(path_topoutput_spectractor):
            os.mkdir(path_topoutput_spectractor)   
            
            
        if not os.path.isdir(path_output_spectractor):
            os.mkdir(path_output_spectractor)

    
    if not os.path.isdir(output_directory):
        os.mkdir(output_directory)
    else:
        cleandir(output_directory)
 
    # manage subdirs spectrum/ and plots/
    if not os.path.isdir(output_figures):
        os.mkdir(output_figures)
    else:
        cleandir(output_figures)
    
    if not os.path.isdir(finalpath_output_spectractor):
        os.mkdir(finalpath_output_spectractor)
        os.mkdir(os.path.join(finalpath_output_spectractor,"basespec"))
        os.mkdir(os.path.join(finalpath_output_spectractor,"plots"))
    else:
        #cleandir(finalpath_output_spectractor)
        cleandir(os.path.join(finalpath_output_spectractor,"basespec"))
        cleandir(os.path.join(finalpath_output_spectractor,"plots"))

# %%
# /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo"

# %% [markdown]
# # Configuration of the Spectractor running mode

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

# %%
target
# Out:
# 'ETA DOR'

# %% [markdown]
# ## Load the image in the new image file with Spectractor

# %%
#image=Image(file_name=filename, target_label=target, disperser_label=disperser_label, config=config)
image=Image(file_name=filename, disperser_label=disperser_label, config=config)
# Out:
# No rebinning: parameters.REBIN is forced to 1.
# target_name = etador, Selected object name for Simbad : ETA1 DOR
#   MAIN_ID         RA           DEC      ...  Z_VALUE  SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... --------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 0.0000590                1

# %%
image.data.shape
# Out:
# (4072, 4000)

# %% [markdown]
# ## Show relevant parameters

# %%
print(parameters)
# Out:
# <module 'spectractor.parameters' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/parameters.py'>

# %%
parameters.LSST_SAVEFIGPATH=True
parameters.LSST_SAVEFIGPATH=output_figures

# %%
image.filter_label
# Out:
# ''

# %%
image.header["FILTER"]
# Out:
# 'empty_1'

# %%
image.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'LSST DM Header Service'
# TIMESYS = 'TAI     '
# DATE    = '2022-03-17T01:59:23.629'
# DATE-OBS= '2022-03-17T01:59:23.629'
# DATE-BEG= '2022-03-17T01:59:37.776'
# DATE-END= '2022-03-17T01:59:58.006'
# MJD     =     59655.0829123696
# MJD-OBS =     59655.0830761163
# MJD-BEG =     59655.0830761163
# MJD-END =     59655.0833102581
# OBSID   = 'AT_O_20220316_000330'
# GROUPID = '2022-03-17T01:55:08.262'
# IMGTYPE = 'OBJECT  '
# BUNIT   = 'adu     '
# FACILITY= 'Vera C. Rubin Observatory'
# TELESCOP= 'LSST AuxTelescope'
# INSTRUME= 'LATISS  '
# OBSERVER= 'LSST    '
# OBS-LONG=   -70.74941699999999
# OBS-LAT =           -30.244639
# OBS-ELEV=               2663.0
# OBSGEO-X=           1818938.94
# OBSGEO-Y=          -5208470.95
# OBSGEO-Z=          -3195172.08
# RA      =    91.53749999999999
# DEC     =    -66.0397222222222
# RASTART =      91.568473136546
# DECSTART=   -66.08471651975501
# RAEND   =     91.5684978765825
# DECEND  =    -66.0846398729667
# ROTPA   =     145.706554377335
# ROTCOORD= 'sky     '
# HASTART =     2.80397609502474
# ELSTART =     46.1564960165997
# AZSTART =     202.972003002418
# AMSTART =     1.38540884027162
# HAEND   =     2.81032070556436
# ELEND   =     46.1240569337242
# AZEND   =     203.002992351307
# AMEND   =     1.38615421445324
# INSTPORT=                    2
# ATM3PORT=
# TRACKSYS= 'SIDEREAL'
# FOCUSZ  =   0.0410588495433331
# OBJECT  = 'eta dor '
# DOMEAZ  =               204.36
# SHUTLOWR=                  0.0
# SHUTUPPR=                100.0
# CAMCODE = 'AT      '
# CONTRLLR= 'O       '
# DAYOBS  = '20220316'
# SEQNUM  =                  330
# TESTTYPE= 'OBJECT  '
# EMUIMAGE= ''
# PROGRAM =
# REASON  =
# CURINDEX=                    0
# MAXINDEX=                    1
# TSTAND  =
# IMAGETAG= 'bbb8117247baa2fc'
# OBSANNOT= ''
# TEMP_SET=   -94.15000152587891
# FILTBAND= 'Empty   '
# FILTER  = 'empty_1 '
# FILTSLOT=                    0
# GRATING = 'holo4_003'          / name of the disperser
# GRATBAND= 'Empty   '
# GRATSLOT=                    3
# LINSPOS =     67.9980010986328
# EXPTIME =                 20.0
# SHUTTIME=
# DARKTIME=     20.3184969425201
# AIRTEMP =                 10.6
# PRESSURE=               743.55
# HUMIDITY=                 44.0
# WINDSPD =                  7.2
# WINDDIR =                311.0
# SEEING  =   0.9216266870498659
# FILENAME= 'AT_O_20220316_000330.fits'
# HEADVER = '2.9.5   '
# CHECKSUM=
# DATASUM =
# HIERARCH SIMULATE ATMCS =
# HIERARCH SIMULATE ATHEXAPOD = 0
# HIERARCH SIMULATE ATPNEUMATICS =
# HIERARCH SIMULATE ATDOME = 0
# HIERARCH SIMULATE ATSPECTROGRAPH = 0
# CCD_MANU= 'ITL     '
# CCD_TYPE=                    2
# CCD_SERN= '20862   '
# CCDTEMP =
# LSST_NUM= 'ITL-3800C-068'
# SEQCKSUM= '2552520002'
# SEQNAME = 'FP_ITL_2s_ir2_v25.seq'
# REBNAME = 'Unknown '
# CONTNUM = '412227310'
# CCDSLOT = 'S00     '
# RAFTBAY = 'R00     '
# OVERH   =                   64
# OVERV   =                   48
# PREH    =                    0
# INHERIT =                    T
# EXTNAME = 'Segment10'
# DATASEC = '[1:509,1:2000]'
# DETSEC  = '[509:1,1:2000]'
# DETSIZE = '[1:4072,1:4000]'
# DTV1    =                  510
# DTV2    =                    0
# DTM1_1  =                 -1.0
# DTM2_2  =                  1.0
# DTM1_2  =                    0
# DTM2_1  =                    0
# HIERARCH ASTRO METADATA FIX MODIFIED = T
# HIERARCH ASTRO METADATA FIX DATE = '2022-03-29T11:37:37.041204'
# HIERARCH ASTRO METADATA FIX VERSION = 'g66e8411885+78f5e69161'
# HA      =     2.80714840029455
# PARANGLE=     56.6019400533159 / parallactic angle in degree
# AIRMASS =     1.38578152736243
# OUTTEMP =                 10.6
# OUTPRESS=               743.55
# OUTHUM  =                 44.0
# CCDREBIN=                    1
# TARGET  = 'etador  '           / name of the target in the image
# REDSHIFT= '5.9e-05 '           / redshift of the target
# ROTANGLE=                    0 / [deg] angle of the dispersion axis
# D2CCD   =    182.9980010986328 / [mm] distance between disperser and CCD
# COMMENT ["  FITS (Flexible Image Transport System) format is defined in 'Astrono
# COMMENT my", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376.
# COMMENT .359H", "= '        '", '---- Date, night and basic image information --
# COMMENT --', "= '        '", '---- Telescope info, location, observer ----', "=
# COMMENT '        '", '---- Pointing info, etc. ----', "= '        '", '---- TAN
# COMMENT Projection ----', "= '        '", '---- Image-identifying used to build
# COMMENT OBS-ID ----', "= '        '", '---- Additional Keys Information from Cam
# COMMENT era ----', "= '        '", '---- Image sequence numbers', "= '        '"
# COMMENT , '---- Test Stand information ----', "= '        '", '---- Information
# COMMENT from Camera (Common block) ----', "= '        '", '---- Information from
# COMMENT  Camera ----', "= '        '", '---- Filter/grating information ----', "
# COMMENT = '        '", '---- Exposure-related information ----', "= '        '",
# COMMENT  '---- Weather information ----', "= '        '", '---- Header informati
# COMMENT on ----', "= '        '", '---- Checksums ----', "= '        '", '---- H
# COMMENT ierarch information for CSC Simulatiom Mode ----', '---- Information fro
# COMMENT m Camera per sensor ----', "= '        '", '---- Geometry from Camera --
# COMMENT --']

# %% [markdown]
# # Plot image and find the target position
#
# - this image plotting is used to find the order 0 location to be set in logbook
#
# - for the moment this is humanly done

# %% [markdown]
# ## Load the new image file with Spectractor

# %%
title="{}) {}".format(idx,filename_image)
image.plot_image(figsize=(12, 10),scale="log",title=title)

# %% [markdown]
# - note now the position are written in the make_logbook.ipynb notebook

# %% [markdown]
# ## Set the 0th order location to be provided to Spectractor

# %%
filename_image
# Out:
# 'exposure_2022031600330_postisrccd.fits'

# %%
# overwrite if localtion is taken from that in logbook
if FLAG_ORDER0_LOCATION : 
    print("Set Order 0 location from logbook : ({},{})".format(x0,y0))
    guess = [x0,y0]

# %% [markdown]
# ## Let Spectractor find the location of the 0th order

# %%
parameters.VERBOSE = True
parameters.DEBUG = True
#x1, y1 = find_target(image, guess,rotated=False, use_wcs=False)
x1, y1 = find_target(image, guess,rotated=False)
# Out:
# 2022-03-31 19:58:00  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0               c1_0                c0_1
#     ----------------- ------------------- -------------------
#     6.885715301852056 0.04827591382585266 0.10196826356092538
# 2022-03-31 19:58:03  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 18 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-03-31 19:58:04  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 3 iterations because the relative change of cost is below ftol=5e-05.

# %%
print(x1,y1)
# Out:
# 312.6219178676066 1735.907895269525

# %% [markdown]
# ## Check the location of 0th order and Analysis of the quality of its focus

# %%
if x1>100:
    WID=100
else:
    WID=50
    

thumbnail=np.copy(image.data[int(y1)-WID:int(y1)+WID,int(x1)-WID:int(x1)+WID])
thumbnail_y=thumbnail.sum(axis=1)
thumbnail_x=thumbnail.sum(axis=0)
xx=np.linspace(int(x1)-WID,int(x1)+WID,len(thumbnail_x))
yy=np.linspace(int(y1)-WID,int(y1)+WID,len(thumbnail_y))
k0=kurtosis(thumbnail,axis=None,bias=True,fisher=True)
kx=kurtosis(thumbnail_x,bias=True,fisher=True)
ky=kurtosis(thumbnail_y,bias=True,fisher=True)
s0=skew(thumbnail,axis=None,bias=True)
sx=skew(thumbnail_x,bias=True)
sy=skew(thumbnail_y,bias=True)

# %%
shape_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}, Skx = {:3.3f}, Sky = {:3.3f} \n'.format(s0,sx,sy),
        r'kurtosis : K0  = {:3.3f}, Kx  = {:3.3f},  Ky = {:3.3f}'.format(k0,kx,ky)))

# %%
skew_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}'.format(s0),
        r'             : Skx = {:3.3f}'.format(sx),
        r'             : Sky = {:3.3f}'.format(sy)))

# %%
kurt_str='\n'.join((
        r'kurtosis : K0 = {:3.3f}'.format(k0),
        r'             : Kx = {:3.3f}'.format(kx),
        r'             : Ky = {:3.3f}'.format(ky)))

# %%
kurtosis_test_prob=kurtosistest(thumbnail,axis=None).pvalue
skew_test_prob=skewtest(thumbnail,axis=None).pvalue
normal_test_prob=normaltest(thumbnail,axis=None).pvalue

# %%
kurtosis_test_val=kurtosistest(thumbnail,axis=None).statistic
skew_test_val=skewtest(thumbnail,axis=None).statistic
normal_test_val=normaltest(thumbnail,axis=None).statistic

# %%
kurtosis_test_prob_x=kurtosistest(thumbnail_x).pvalue
skew_test_prob_x=skewtest(thumbnail_x).pvalue
normal_test_prob_x=normaltest(thumbnail_x).pvalue

# %%
kurtosis_test_prob_y=kurtosistest(thumbnail_y).pvalue
skew_test_prob_y=skewtest(thumbnail_y).pvalue
normal_test_prob_y=normaltest(thumbnail_y).pvalue

# %%
skew_str='\n'.join((
    r'skew     : Sk0 = {:3.3f}'.format(s0),
    r'             : Skx = {:3.3f}'.format(sx),
    r'             : Sky = {:3.3f}'.format(sy),
    r'             : p_test   = {:3.3e}'.format(skew_test_prob),
    r'             : p_test_x = {:3.3e}'.format(skew_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(skew_test_prob_y)))

# %%
kurt_str='\n'.join((
    r'kurtosis : K0 = {:3.3f}'.format(k0),
    r'             : Kx = {:3.3f}'.format(kx),
    r'             : Ky = {:3.3f}'.format(ky),
    r'             : p_test   = {:3.3e}'.format(kurtosis_test_prob),
    r'             : p_test_x = {:3.3e}'.format(kurtosis_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(kurtosis_test_prob_y)))

# %%
norm_str='\n'.join((
    r'normal  : p_test   = {:3.3e}'.format(normal_test_prob),
    r'             : p_test_x = {:3.3e}'.format(normal_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(normal_test_prob_y)))

# %%
props = dict(boxstyle='round',edgecolor="w",facecolor="w", alpha=0.5)

# %%
#matplotlib.pyplot.hist(x, 
#                       bins=10, 
#                       range=None, 
#                       normed=False, 
#                       weights=None, 
#                       cumulative=False, 
#                       bottom=None, 
#                       histtype=u'bar', 
#                       align=u'mid', 
#                       orientation=u'vertical', 
#                       rwidth=None, 
#                       log=False, 
#                       color=None, 
#                       label=None, 
#                       stacked=False, 
#                       hold=None, 
#                       **kwargs)

# %%
fig=plt.figure(figsize=(10,10))
fig.subplots_adjust(left=0.12, right=0.95, wspace=0.3,
                    bottom=0.15, top=0.9)

ax=fig.add_subplot(222)
ax.imshow(thumbnail,origin="lower",extent=(int(x1)-WID,int(x1)+WID,int(y1)-WID,int(y1)+WID))
ax.set_xlabel("X")
ax.set_ylabel("Y")

ax=fig.add_subplot(221)
base = plt.gca().transData
rot = transforms.Affine2D().rotate_deg(-90)
#ax.plot(yy,thumbnail_y,"g",rotation=u'vertical')
ax.plot(-yy,thumbnail_y,"g",transform= rot + base)
ax.set_ylabel("Y")

ax=fig.add_subplot(224)
ax.plot(xx,thumbnail_x,"b")
ax.set_xlabel("X")
plt.tight_layout()

ax=fig.add_subplot(223)
ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_yticks([])

ax.text(0.05, 0.9, skew_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.55, kurt_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.2, norm_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
plt.suptitle(title)
# Out:
# Text(0.5, 0.98, '0) exposure_2022031600330_postisrccd.fits')

# %%
# Usually stop here if one just want to get the 0th order location
if not FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR:
    assert False
else:
    assert True

# %% [markdown]
# # Go for spectrum reconstruction

# %%
#parameters.debug=True
#parameters.verbose=True
#parameters.display=True
#parameters.LIVE_FIT=False

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=True

# %%
filename
# Out:
# '/sps/lsst/groups/auxtel/data/2022/holo/20220316/exposure_2022031600330_postisrccd.fits'

# %%
spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target, disperser_label=disperser_label, config=config)
# Out:
# 2022-03-31 19:58:06  spectractor.extractor.extractor Spectractor          INFO
# 	Start SPECTRACTOR
# 2022-03-31 19:58:06  Image      load_AUXTEL_image    INFO
# 	Loading AUXTEL image /sps/lsst/groups/auxtel/data/2022/holo/20220316/exposure_2022031600330_postisrccd.fits...
# 2022-03-31 19:58:06  Image      load_AUXTEL_image    INFO
# 	Image loaded
# No rebinning: parameters.REBIN is forced to 1.
# Section: paths
# x disperser_dir: extractor/dispersers/	=> parameters.DISPERSER_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/	 <class 'str'>
# x throughput_dir: simulation/AuxTelThroughput/	=> parameters.THROUGHPUT_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/	 <class 'str'>
# Section: pipeline
# x spectractor_fit_target_centroid: fit	=> parameters.SPECTRACTOR_FIT_TARGET_CENTROID: fit	 <class 'str'>
# x spectractor_compute_rotation_angle: False	=> parameters.SPECTRACTOR_COMPUTE_ROTATION_ANGLE: False	 <class 'bool'>
# x spectractor_deconvolution_psf2d: True	=> parameters.SPECTRACTOR_DECONVOLUTION_PSF2D: True	 <class 'bool'>
# x spectractor_deconvolution_ffm: False	=> parameters.SPECTRACTOR_DECONVOLUTION_FFM: False	 <class 'bool'>
# Section: instrument
# x obs_name: AUXTEL	=> parameters.OBS_NAME: AUXTEL	 <class 'str'>
# x obs_altitude: 2.66299616375123	=> parameters.OBS_ALTITUDE: 2.66299616375123	 <class 'float'>
# x obs_latitude: -30.2446389756252	=> parameters.OBS_LATITUDE: -30.2446389756252	 <class 'float'>
# x obs_diameter: 1.20	=> parameters.OBS_DIAMETER: 1.2 m	 <class 'astropy.units.quantity.Quantity'>
# x obs_epoch: J2000.0	=> parameters.OBS_EPOCH: J2000.0	 <class 'str'>
# x obs_transmission_systematics: 0.005	=> parameters.OBS_TRANSMISSION_SYSTEMATICS: 0.005	 <class 'float'>
# x obs_object_type: STAR	=> parameters.OBS_OBJECT_TYPE: STAR	 <class 'str'>
# x obs_telescope_transmission: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_TELESCOPE_TRANSMISSION: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_full_instrument_transmisson: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_FULL_INSTRUMENT_TRANSMISSON: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_quantum_efficiency: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	=> parameters.OBS_QUANTUM_EFFICIENCY: calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt	 <class 'str'>
# x obs_camera_rotation: 0	=> parameters.OBS_CAMERA_ROTATION: 0	 <class 'int'>
# x obs_camera_dec_flip_sign: -1	=> parameters.OBS_CAMERA_DEC_FLIP_SIGN: -1	 <class 'int'>
# x obs_camera_ra_flip_sign: 1	=> parameters.OBS_CAMERA_RA_FLIP_SIGN: 1	 <class 'int'>
# Section: CCD
# x ccd_imsize: 4096	=> parameters.CCD_IMSIZE: 4096	 <class 'int'>
# x ccd_pixel2mm: 10e-3	=> parameters.CCD_PIXEL2MM: 0.01	 <class 'float'>
# x ccd_pixel2arcsec: 0.0952	=> parameters.CCD_PIXEL2ARCSEC: 0.0952	 <class 'float'>
# x ccd_maxadu: 170000	=> parameters.CCD_MAXADU: 170000	 <class 'int'>
# x ccd_gain: 1.1	=> parameters.CCD_GAIN: 1.1	 <class 'float'>
# x ccd_rebin: 1	=> parameters.CCD_REBIN: 1	 <class 'int'>
# Section: spectrograph
# x distance2ccd: 175	=> parameters.DISTANCE2CCD: 175	 <class 'int'>
# x distance2ccd_err: 0.75	=> parameters.DISTANCE2CCD_ERR: 0.75	 <class 'float'>
# x grating_order_2over1: 0.1	=> parameters.GRATING_ORDER_2OVER1: 0.1	 <class 'float'>
# Section: search windows
# x xwindow: 100	=> parameters.XWINDOW: 100	 <class 'int'>
# x ywindow: 100	=> parameters.YWINDOW: 100	 <class 'int'>
# x xwindow_rot: 50	=> parameters.XWINDOW_ROT: 50	 <class 'int'>
# x ywindow_rot: 50	=> parameters.YWINDOW_ROT: 50	 <class 'int'>
# x pixshift_prior: 5	=> parameters.PIXSHIFT_PRIOR: 5	 <class 'int'>
# Section: rotation parameters
# x rot_prefilter: True	=> parameters.ROT_PREFILTER: True	 <class 'bool'>
# x rot_order: 5	=> parameters.ROT_ORDER: 5	 <class 'int'>
# x rot_angle_min: -10	=> parameters.ROT_ANGLE_MIN: -10	 <class 'int'>
# x rot_angle_max: 10	=> parameters.ROT_ANGLE_MAX: 10	 <class 'int'>
# Section: spectrum range
# x lambda_min: 300	=> parameters.LAMBDA_MIN: 300	 <class 'int'>
# x lambda_max: 1100	=> parameters.LAMBDA_MAX: 1100	 <class 'int'>
# Section: background subtraction parameters
# x pixwidth_signal: 40	=> parameters.PIXWIDTH_SIGNAL: 40	 <class 'int'>
# x pixdist_background: 140	=> parameters.PIXDIST_BACKGROUND: 140	 <class 'int'>
# x pixwidth_background: 40	=> parameters.PIXWIDTH_BACKGROUND: 40	 <class 'int'>
# x pixwidth_boxsize: 20	=> parameters.PIXWIDTH_BOXSIZE: 20	 <class 'int'>
# Section: PSF
# x psf_type: Moffat	=> parameters.PSF_TYPE: Moffat	 <class 'str'>
# x psf_poly_order: 2	=> parameters.PSF_POLY_ORDER: 2	 <class 'int'>
# x psf_fit_reg_param: 1	=> parameters.PSF_FIT_REG_PARAM: 1	 <class 'int'>
# x psf_pixel_step_transverse_fit: 50	=> parameters.PSF_PIXEL_STEP_TRANSVERSE_FIT: 50	 <class 'int'>
# x psf_fwhm_clip: 2	=> parameters.PSF_FWHM_CLIP: 2	 <class 'int'>
# Section: detection line algorithm parameters
# x calib_bgd_order: 3	=> parameters.CALIB_BGD_ORDER: 3	 <class 'int'>
# x calib_peak_width: 7	=> parameters.CALIB_PEAK_WIDTH: 7	 <class 'int'>
# x calib_bgd_width: 15	=> parameters.CALIB_BGD_WIDTH: 15	 <class 'int'>
# x calib_savgol_window: 5	=> parameters.CALIB_SAVGOL_WINDOW: 5	 <class 'int'>
# x calib_savgol_order: 2	=> parameters.CALIB_SAVGOL_ORDER: 2	 <class 'int'>
# Section: plot settings
# x paper: False	=> parameters.PAPER: False	 <class 'bool'>
# x linewidth: 2	=> parameters.LINEWIDTH: 2	 <class 'int'>
# x plot_dir: plots	=> parameters.PLOT_DIR: plots	 <class 'str'>
# x save: False	=> parameters.SAVE: False	 <class 'bool'>
# 2022-03-31 19:58:06  Image      load_image           INFO
# 	Loading disperser holo4_003...
# 2022-03-31 19:58:06  Hologram   load_specs           INFO
# 	Load disperser holo4_003:
# 	from /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/holo4_003
# 2022-03-31 19:58:06  Hologram   load_specs           INFO
# 	Grating characteristics:
# 	N = 156.00 +/- 1.00 grooves/mm
# 	Average tilt of -0.3 degrees
# 2022-03-31 19:58:13  Star       load                 INFO
# 	Simbad:
#   MAIN_ID         RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... --------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 0.0000590                1
# 2022-03-31 19:58:13  Star       load_spectra         INFO
# 	Loading /sps/lsst/groups/auxtel/softs/utils/PySynPhotData/grp/hst/cdbs//calspec/eta1dor_stis_002.fits
# 2022-03-31 19:58:13  Star       load_spectra         DEBUG
# 	Target label: ETA1 DOR
# 	Calspec? True
# 	Number of spectra: 1
# 	Redshift: 5.9e-05
# 	Emission spectrum ? False
# 	Lines: ['$Fe_{I}$', '$Ca_{II}$', '$Ca_{II}$', '$H\\epsilon$', '$H\\delta$', '$Fe_{I}$', '$H\\gamma$', '$Fe_{I}$', '$He_{I}$', '$H\\beta$', '$Mg_{I}$', '$Mg_{I}$', '$Fe_{I}$', '$H\\alpha$', '$O_2(B)$', '', '$O_2$', '$O_2(Z)$', '$O_2(Y)$', '$H_2 O$']
# target_name = etador, Selected object name for Simbad : ETA1 DOR
#   MAIN_ID         RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... --------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 0.0000590                1
# 2022-03-31 19:58:15  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the image with guess=[ 312.62191787 1735.90789527]...
# 2022-03-31 19:58:15  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                c1_0                  c0_1
#     ------------------ -------------------- ---------------------
#     22.660629062473806 0.003462438205544085 -0.006561428711674441
# 2022-03-31 19:58:16  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 19 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-03-31 19:58:17  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 3 iterations because the relative change of cost is below ftol=5e-05.
# 2022-03-31 19:58:18  Image      find_target          INFO
# 	X,Y target position in pixels: 312.637,1735.924
# 2022-03-31 19:58:18  Image      turn_image           INFO
# 	Rotate the image with angle theta=0.00 degree
# 2022-03-31 19:58:29  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the rotated image...
# 2022-03-31 19:58:29  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0               c1_0               c0_1
#     ------------------ ------------------ ------------------
#     1737.4803613355887 1.8548135774508854 3.9610351280584575
# 2022-03-31 19:58:29  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: x_c has a null Jacobian; parameter is fixed at its last known current value (50.39682538254475).
# 2022-03-31 19:58:29  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: y_c has a null Jacobian; parameter is fixed at its last known current value (49.13382553918802).
# 2022-03-31 19:58:29  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: gamma has a null Jacobian; parameter is fixed at its last known current value (100.0).
# 2022-03-31 19:58:29  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 1: alpha has a null Jacobian; parameter is fixed at its last known current value (35.98445440197927).
# 2022-03-31 19:58:29  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 1 iterations because the relative change of cost is below ftol=5e-05.
# 2022-03-31 19:58:30  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: amplitude has a null Jacobian; parameter is fixed at its last known current value (-1.4901161193847656e-08).
# 2022-03-31 19:58:30  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: x_c has a null Jacobian; parameter is fixed at its last known current value (25.954195850718698).
# 2022-03-31 19:58:30  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: y_c has a null Jacobian; parameter is fixed at its last known current value (27.241780683303872).
# 2022-03-31 19:58:30  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: gamma has a null Jacobian; parameter is fixed at its last known current value (100.0).
# 2022-03-31 19:58:30  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: alpha has a null Jacobian; parameter is fixed at its last known current value (35.98445440197927).
# 2022-03-31 19:58:30  spectractor.fit.fitter gradient_descent     WARNING
# 	Gradient descent terminated in 0 iterations because all parameters have null Jacobian.
# 2022-03-31 19:58:30  Image      find_target          INFO
# 	X,Y target position in pixels: 312.954,1736.242
# 2022-03-31 19:58:30  Spectrum   __init__             INFO
# 	Spectrum info copied from image
# 2022-03-31 19:58:30  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extracting spectrum from image: spectrum with width 2*40 pixels and background from 140 to 180 pixels
# 2022-03-31 19:58:31  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop rotated image [1170:3500,1556:1916] (size (2330, 360))
# 2022-03-31 19:58:34  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Start PSF1D transverse fit...
# 2022-03-31 19:58:43  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=1.6439e+08 initial chisq_red=881.94
# 		 Line search: alpha_min=1.84 iter=0 funcalls=5
# 	Parameter shifts: [ 1.88493639  2.18068946 -4.37289644  0.47434723 -0.75543675  5.96742355
#  -1.61977965 -2.26444423  8.26572134]
# 	New parameters: [ 3.93471428e+00  4.54710211e+00 -8.03837579e+00  7.26577977e+00
#  -2.22493008e-03 -3.45530422e+00  9.71345266e-02 -1.78455886e+00
#   4.13421124e+00]
# 	Final cost=8.5607e+07 final chisq_red=459.26 computed in 2.36s
# 2022-03-31 19:58:45  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=8.5607e+07 initial chisq_red=459.26
# 		 Line search: alpha_min=0.618 iter=3 funcalls=7
# 	Parameter shifts: [ 0.18003609  0.90650008  1.0115803  -0.69670815  1.05805581  3.47392185
#   1.2618502   2.16984042 -4.29148653]
# 	New parameters: [ 4.11475037  5.45360219 -7.02679549  6.56907162  1.05583088  0.01861763
#   1.35898472  0.38528156 -0.15727529]
# 	Final cost=2.8533e+07 final chisq_red=153.07 computed in 2.63s
# 2022-03-31 19:58:48  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=2.8533e+07 initial chisq_red=153.07
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.38927503  1.11544235  0.69648577  1.28536642  1.07992838  0.11599928
#  -0.06269146 -0.30520979 -0.18763307]
# 	New parameters: [ 4.5040254   6.56904454 -6.33030972  7.85443804  2.13575926  0.13461691
#   1.29629326  0.08007177 -0.34490836]
# 	Final cost=1.1824e+07 final chisq_red=63.434 computed in 2.27s
# 2022-03-31 19:58:50  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=1.1824e+07 initial chisq_red=63.434
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [0.41204465 0.77292361 0.99179608 1.4960137  0.25172539 2.21314414
#  0.25010755 0.09257235 0.39701032]
# 	New parameters: [ 4.91607006  7.34196815 -5.33851364  9.35045175  2.38748465  2.34776105
#   1.54640081  0.17264412  0.05210196]
# 	Final cost=9.9026e+06 final chisq_red=53.126 computed in 2.33s
# 2022-03-31 19:58:52  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=9.9026e+06 initial chisq_red=53.126
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.10040969 -0.20978439 -0.22577339  0.38322882  0.44495104  2.2159465
#   0.0749071   0.08644993  0.37905163]
# 	New parameters: [ 4.81566036  7.13218376 -5.56428702  9.73368057  2.83243569  4.56370755
#   1.62130791  0.25909405  0.4311536 ]
# 	Final cost=9.6408e+06 final chisq_red=51.721 computed in 2.39s
# 2022-03-31 19:58:55  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=5: initial cost=9.6408e+06 initial chisq_red=51.721
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00379291 -0.00812829 -0.02469336 -0.1021452  -0.27331398 -0.27823186
#  -0.02172918 -0.05933997 -0.0608102 ]
# 	New parameters: [ 4.81186745  7.12405547 -5.58898039  9.63153537  2.5591217   4.28547569
#   1.59957873  0.19975408  0.37034339]
# 	Final cost=9.6327e+06 final chisq_red=51.677 computed in 2.37s
# 2022-03-31 19:58:57  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=6: initial cost=9.6327e+06 initial chisq_red=51.677
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00073903 -0.00105181 -0.00448452  0.08095755  0.1306425   0.211427
#   0.01457695  0.02327166  0.03827611]
# 	New parameters: [ 4.81112842  7.12300366 -5.59346491  9.71249292  2.6897642   4.49690269
#   1.61415568  0.22302574  0.40861951]
# 	Final cost=9.6318e+06 final chisq_red=51.673 computed in 2.36s
# 2022-03-31 19:59:00  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=7: initial cost=9.6318e+06 initial chisq_red=51.673
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00125721 -0.0023097  -0.00232359 -0.03241885 -0.05751775 -0.07726624
#  -0.00592728 -0.01057794 -0.01456441]
# 	New parameters: [ 4.80987121  7.12069397 -5.5957885   9.68007406  2.63224645  4.41963645
#   1.6082284   0.2124478   0.3940551 ]
# 	Final cost=9.6316e+06 final chisq_red=51.672 computed in 2.38s
# 2022-03-31 19:59:02  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=8: initial cost=9.6316e+06 initial chisq_red=51.672
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [0.0003654  0.00069196 0.00045259 0.01553909 0.02672662 0.03719411
#  0.00276905 0.00476167 0.00680164]
# 	New parameters: [ 4.81023661  7.12138593 -5.59533591  9.69561315  2.65897307  4.45683056
#   1.61099745  0.21720947  0.40085674]
# 	Final cost=9.6316e+06 final chisq_red=51.672 computed in 2.59s
# 2022-03-31 19:59:02  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 8 iterations because the relative change of cost is below ftol=5.36480686695279e-06.
# 2022-03-31 19:59:02  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: 4.8102 +0.0005 -0.0005
# 	y_c_1: 7.1214 +0.0008 -0.0008
# 	y_c_2: -5.595 +0.001 -0.001
# 	gamma_0: 9.696 +0.003 -0.003
# 	gamma_1: 2.659 +0.005 -0.005
# 	gamma_2: 4.457 +0.006 -0.006
# 	alpha_0: 1.6110 +0.0005 -0.0005
# 	alpha_1: 0.2172 +0.0008 -0.0008
# 	alpha_2: 0.401 +0.001 -0.001
#
# 2022-03-31 19:59:10  spectractor.extractor.extractor extract_spectrum_from_image DEBUG
# 	Transverse fit table before derotation:
#      amplitude       x_c   ...         Dy         Dy_disp_axis
# ------------------- ------ ... ------------------ ------------
#   -8.28887334748971    0.0 ... -7.906485234273191          0.0
#  -4.818203915086935    1.0 ... -7.885961244341075          0.0
#  -9.886983549398163    2.0 ... -7.865449632920701          0.0
# -12.640459136374647    3.0 ... -7.844950400012067          0.0
#  -4.997043132238318    4.0 ... -7.824463545615174          0.0
#  -7.743844767009884    5.0 ... -7.803989069730022          0.0
#  -8.628847641359794    6.0 ...  -7.78352697235664          0.0
#  -4.481093170340704    7.0 ... -7.763077253494998          0.0
# -5.5300222971628825    8.0 ... -7.742639913145098          0.0
#  -3.636890465513299    9.0 ... -7.722214951306938          0.0
#                 ...    ... ...                ...          ...
#  2268.7089594644276 2319.0 ...  6.418661445813541          0.0
#   2260.673159446247 2320.0 ...  6.410479667003216          0.0
#  2245.2825801751105 2321.0 ...  6.402285509681121          0.0
#    2225.80981309159 2322.0 ...  6.394078973847286          0.0
#  2255.9862398720475 2323.0 ...  6.385860059501709          0.0
#   2269.919860133348 2324.0 ...  6.377628766644364          0.0
#   2247.014330093527 2325.0 ...  6.369385095275305          0.0
#   2232.939790813391 2326.0 ... 6.3611290453944775          0.0
#  2242.8129909154763 2327.0 ...  6.352860617001909          0.0
#   2233.271415357067 2328.0 ...  6.344579810097599          0.0
#   2223.932861319128 2329.0 ...   6.33628662468152          0.0
# Length = 2330 rows
# 2022-03-31 19:59:10  spectractor.extractor.extractor extract_spectrum_from_image DEBUG
# 	Transverse fit table after derotation:
#      amplitude             x_c         ...         Dy         Dy_disp_axis
#  2239.109728878594  2322.683000814932 ...  6.394078973847286          0.0
#  2235.375715789293  2323.683000814932 ...  6.385860059501709          0.0
#  2260.403186139942  2324.683000814931 ...  6.377628766644364          0.0
# 2262.6588257771486  2325.683000814932 ...  6.369385095275305          0.0
# 2242.5527126115007  2326.683000814932 ... 6.3611290453944775          0.0
# 2236.0695871997764  2327.683000814932 ...  6.352860617001909          0.0
#  2239.788319239185  2328.683000814931 ...  6.344579810097571          0.0
# 2230.3111013373164  2329.683000814931 ...   6.33628662468152          0.0
# Length = 2330 rows
# 2022-03-31 19:59:19  spectractor.extractor.extractor run_spectrogram_deconvolution_psf2d INFO
# 	Start ChromaticPSF polynomial fit with mode=2D and amplitude_priors_method=psf1d...
# 2022-03-31 19:59:23  spectractor.fit.fitter run_minimisation     DEBUG
# 	Start guess: [ 2.02154580e+03  1.16450000e+03 -5.02844992e-13  4.81023661e+00
#   7.12138593e+00 -5.59533591e+00  9.69561315e+00  2.65897307e+00
#   4.45683056e+00  1.61099745e+00  2.17209470e-01  4.00856735e-01
#   8.49993483e+03]
# 2022-03-31 20:08:42  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=8.2141e+07 initial chisq_red=469.52
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.21065416 -0.24202465  0.21685218 -2.52087713 -0.02194157 -0.91177911
#   0.14697639 -0.01862247 -0.1027471 ]
# 	New parameters: [ 5.02089077  6.87936128 -5.37848373  7.17473602  2.6370315   3.54505146
#   1.75797383  0.198587    0.29810964]
# 	Final cost=1.4915e+07 final chisq_red=85.256 computed in 521.80s
# 2022-03-31 20:17:26  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=1.4915e+07 initial chisq_red=85.256
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.04774751  0.10984438 -0.08362841  2.27041367  0.51237825  1.11318412
#   0.28916608  0.08368771  0.12502046]
# 	New parameters: [ 5.06863827  6.98920566 -5.46211214  9.44514968  3.14940975  4.65823557
#   2.04713991  0.28227471  0.42313009]
# 	Final cost=9.9043e+06 final chisq_red=56.613 computed in 523.82s
# 2022-03-31 20:26:07  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=9.9043e+06 initial chisq_red=56.613
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.01324703  0.0083145  -0.24557098  0.30326115 -0.22376092 -0.1385952
#   0.06441061 -0.01782496 -0.0133861 ]
# 	New parameters: [ 5.05539124  6.99752015 -5.70768312  9.74841084  2.92564883  4.51964038
#   2.11155052  0.26444974  0.409744  ]
# 	Final cost=9.7187e+06 final chisq_red=55.552 computed in 520.71s
# 2022-03-31 20:34:50  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=9.7187e+06 initial chisq_red=55.552
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [0.05570907 0.12147808 0.09719896 0.02589225 0.0335144  0.10448192
#  0.00626213 0.00469829 0.01456437]
# 	New parameters: [ 5.11110031  7.11899823 -5.61048416  9.77430309  2.95916323  4.62412229
#   2.11781265  0.26914803  0.42430836]
# 	Final cost=9.6937e+06 final chisq_red=55.409 computed in 523.11s
# 2022-03-31 20:43:31  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=9.6937e+06 initial chisq_red=55.409
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.00414209  0.00749039  0.00152903 -0.0741969  -0.13085123 -0.12724051
#  -0.00994609 -0.0177946  -0.016004  ]
# 	New parameters: [ 5.1152424   7.12648862 -5.60895513  9.70010619  2.82831199  4.49688179
#   2.10786656  0.25135343  0.40830437]
# 	Final cost=9.6924e+06 final chisq_red=55.402 computed in 521.54s
# 2022-03-31 20:55:08  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=5: initial cost=9.6924e+06 initial chisq_red=55.402
# 		 Line search: alpha_min=-0.0136 iter=6 funcalls=10
# 	Parameter shifts: [ 3.12098380e-05  1.51645471e-04  4.35424369e-05 -1.28622053e-04
#  -1.95746724e-04 -3.37869426e-04 -2.91563996e-05 -4.40847854e-05
#  -7.97494307e-05]
# 	New parameters: [ 5.11527361  7.12664026 -5.60891159  9.69997757  2.82811625  4.49654392
#   2.1078374   0.25130935  0.40822462]
# 	Final cost=9.6924e+06 final chisq_red=55.402 computed in 696.20s
# 2022-03-31 20:55:08  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 5 iterations because the sum of parameter shift relative to the sum of the parameters is below xtol=0.0001.
# 2022-03-31 20:55:08  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: 5.1153 +0.0004 -0.0004
# 	y_c_1: 7.1266 +0.0006 -0.0006
# 	y_c_2: -5.609 +0.001 -0.001
# 	gamma_0: 9.700 +0.003 -0.003
# 	gamma_1: 2.828 +0.005 -0.005
# 	gamma_2: 4.497 +0.007 -0.007
# 	alpha_0: 2.1078 +0.0005 -0.0005
# 	alpha_1: 0.2513 +0.0008 -0.0008
# 	alpha_2: 0.408 +0.001 -0.001
#
# 2022-03-31 20:55:45  spectractor.fit.fitter run_minimisation     DEBUG
# 	Newton: total computation time: 3344.199381828308s
# 2022-03-31 20:55:45  spectractor.fit.fitter run_minimisation     DEBUG
# 	Start guess: [0.]
# 2022-03-31 20:56:58  spectractor.fit.fitter run_minimisation     DEBUG
# 	 final_simplex: (array([[0.2044375],
#        [0.2045   ]]), array([5.04444182e-08, 5.04444182e-08]))
#            fun: 5.044441821328887e-08
#        message: 'Optimization terminated successfully.'
#           nfev: 40
#            nit: 20
#         status: 0
#        success: True
#              x: array([0.2044375])
# 2022-03-31 20:56:58  spectractor.fit.fitter run_minimisation     DEBUG
# 	Minimize: total computation time: 73.62475085258484s
# 2022-03-31 20:59:51  RegFitWorkspace print_regularisation_summary INFO
# 	Optimal regularisation parameter: 1.6011702048476955
# 	Tr(R) = 250.91738445371772
# 	N_params = 2330
# 	N_data = 174947 (without mask and outliers)
# 2022-03-31 21:00:29  spectractor.fit.fitter run_minimisation_sigma_clipping INFO
# 	Sigma-clipping step 0/3 (sigma=20)
# 2022-03-31 21:12:38  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration
spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=6.5172e+06 initial chisq_red=37.373
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.06125683  0.12007925 -0.35244022 -0.81913451 -1.61531304 -0.44746176
#  -0.10816294 -0.20886034 -0.09544485]
# 	New parameters: [ 5.17630569  7.24619559 -5.96166583  8.88310862  1.21640555  4.05531064
#   2.00019126  0.04326249  0.31422196]
# 	Final cost=5.9367e+06 final chisq_red=34.044 computed in 519.06s
# 2022-03-31 21:42:03  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=5.9367e+06 initial chisq_red=34.044
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [0.07787841 0.15867381 0.13090963 0.38375863 0.66304062 0.66722039
#  0.06449968 0.10641128 0.11562282]
# 	New parameters: [ 5.25418409  7.4048694  -5.8307562   9.26686725  1.87944617  4.72253103
#   2.06469094  0.14967377  0.42984478]
# 	Final cost=5.8742e+06 final chisq_red=33.686 computed in 518.91s
# 2022-03-31 21:50:41  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=5.8742e+06 initial chisq_red=33.686
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.01485584  0.05247368  0.03818099 -0.29430339 -0.50382738 -0.52021343
#  -0.04628986 -0.07671043 -0.08527543]
# 	New parameters: [ 5.26903993  7.45734308 -5.79257521  8.97256386  1.37561879  4.20231759
#   2.01840108  0.07296334  0.34456935]
# 	Final cost=5.8572e+06 final chisq_red=33.588 computed in 517.68s
# 2022-03-31 21:59:22  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=5.8572e+06 initial chisq_red=33.588
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.00493007  0.01101627 -0.00203073  0.06158796  0.10730374  0.12727484
#   0.01173724  0.02013182  0.02609863]
# 	New parameters: [ 5.27397     7.46835935 -5.79460594  9.03415182  1.48292253  4.32959243
#   2.03013832  0.09309516  0.37066798]
# 	Final cost=5.8564e+06 final chisq_red=33.583 computed in 520.86s
# 2022-03-31 22:07:58  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=5.8564e+06 initial chisq_red=33.583
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.0001932  -0.00024071  0.00025742 -0.02153002 -0.03635636 -0.04686915
#  -0.00351104 -0.00592672 -0.00809726]
# 	New parameters: [ 5.2737768   7.46811864 -5.79434852  9.0126218   1.44656617  4.28272328
#   2.02662728  0.08716844  0.36257072]
# 	Final cost=5.8563e+06 final chisq_red=33.583 computed in 516.69s
# 2022-03-31 22:16:36  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration
spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=5.365e+06 initial chisq_red=30.766
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [0.00469279 0.00572007 0.02593174 0.09550974 0.1697011  0.15407281
#  0.01745066 0.02950785 0.03073619]
# 	New parameters: [ 5.39261464  7.7205355  -5.87477216  8.60308144  0.61603737  4.08363139
#   1.97512653 -0.01817654  0.33210517]
# 	Final cost=5.3614e+06 final chisq_red=30.745 computed in 517.37s
# 2022-03-31 22:43:47  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=5.3614e+06 initial chisq_red=30.745
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00379523 -0.00712777 -0.00599365 -0.02152767 -0.03653291 -0.04561145
#  -0.00327357 -0.00545187 -0.00730094]
# 	New parameters: [ 5.38881941  7.71340773 -5.88076581  8.58155377  0.57950446  4.03801993
#   1.97185296 -0.02362841  0.32480423]
# 	Final cost=5.3614e+06 final chisq_red=30.745 computed in 524.50s
# 2022-03-31 22:52:31  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=5.3614e+06 initial chisq_red=30.745
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [0.0038309  0.00732186 0.00582036 0.00556629 0.00947217 0.01199511
#  0.0008408  0.00142195 0.00185425]
# 	New parameters: [ 5.39265031  7.72072958 -5.87494545  8.58712006  0.58897663  4.05001504
#   1.97269376 -0.02220646  0.32665848]
# 	Final cost=5.3613e+06 final chisq_red=30.744 computed in 523.91s
# 2022-03-31 23:04:07  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=5.3613e+06 initial chisq_red=30.744
# 		 Line search: alpha_min=0.0573 iter=6 funcalls=10
# 	Parameter shifts: [-2.09066574e-04 -4.01108137e-04 -3.14707189e-04 -1.50670334e-04
#  -2.69817494e-04 -3.49087596e-04 -2.15198401e-05 -3.94612747e-05
#  -4.79658698e-05]
# 	New parameters: [ 5.39244125  7.72032848 -5.87526016  8.58696939  0.58870681  4.04966595
#   1.97267224 -0.02224592  0.32661052]
# 	Final cost=5.3613e+06 final chisq_red=30.744 computed in 695.85s
# 2022-03-31 23:04:07  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 4 iterations because the relative change of cost is below ftol=5.298574683410162e-06.
# 2022-03-31 23:04:07  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: 5.3924 +0.0004 -0.0004
# 	y_c_1: 7.7203 +0.0008 -0.0008
# 	y_c_2: -5.875 +0.001 -0.001
# 	gamma_0: 8.587 +0.002 -0.002
# 	gamma_1: 0.589 +0.004 -0.004
# 	gamma_2: 4.050 +0.006 -0.006
# 	alpha_0: 1.9727 +0.0004 -0.0004
# 	alpha_1: -0.0222 +0.0007 -0.0007
# 	alpha_2: 0.3266 +0.001 -0.001
#
# 2022-03-31 23:04:44  spectractor.fit.fitter run_minimisation_sigma_clipping DEBUG
 69110, 69111, 69112, 69113, 69114, 69115, 69116, 69117, 69118, 69119, 69120, 69121, 69122, 69123, 69125, 69126, 69127, 69129, 69130, 69131, 69136, 69137, 71207, 71208, 71210, 71211, 71212, 71213, 71214, 71215, 71216, 71217, 71218, 71219, 71220, 71222, 71223, 71224, 71225, 71226, 71227, 71228, 71229, 71230, 71231, 71232, 71233, 71234, 71235, 71236, 71237, 71238, 71239, 71240, 71241, 71242, 71243, 71244, 71245, 71246, 71247, 71248, 71249, 71250, 71251, 71252, 71253, 71254, 71255, 71256, 71257, 71258, 71259, 71260, 71261, 71262, 71263, 71264, 71265, 71266, 71267, 71268, 71269, 71270, 71271, 71272, 71273, 71274, 71275, 71276, 71277, 71278, 71279, 71280, 71281, 71282, 71283, 71284, 71285, 71286, 71287, 71288, 71289, 71290, 71291, 71292, 71293, 71294, 71295, 71296, 71297, 71298, 71299, 71300, 71301, 71302, 71303, 71304, 71305, 71306, 71307, 71308, 71309, 71310, 71311, 71312, 71313, 71314, 71315, 71316, 71317, 71318, 71319, 71320, 71321, 71322, 71323, 71324, 71325, 71326, 71327, 71328, 71329, 71330, 71331, 71332, 71333, 71334, 71335, 71336, 71337, 71338, 71339, 71340, 71341, 71342, 71343, 71344, 71345, 71346, 71347, 71348, 71349, 713 ...
# 2022-03-31 23:04:44  spectractor.fit.fitter run_minimisation_sigma_clipping INFO
# 	Outliers: 8035 / 188730 data points (4.26%) at more than 20-sigma from best-fit model.
# 2022-03-31 23:07:43  spectractor.extractor.extractor Spectractor          INFO
# 	Calibrating order 1 spectrum...
# 2022-03-31 23:08:56  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: 1.989pix
# 	D = 180.806 mm (default: DISTANCE2CCD = 183.00 +/- 0.75 mm, -2.9 sigma shift)
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# 2022-03-31 23:08:56  astropy    _showwarning         WARNING VerifyWarning: Card is too long, comment will be truncated.
# 2022-03-31 23:08:56  Spectrum   save_spectrum        INFO
# 	Spectrum saved in ./outputs_process_holo_configF/exposure_2022031600330_postisrccd_spectrum.fits
# 2022-03-31 23:08:57  Spectrum   save_spectrogram     INFO
# 	Spectrogram saved in ./outputs_process_holo_configF/exposure_2022031600330_postisrccd_spectrogram.fits

# %%
#try:
#    spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target, disperser_label=disperser_label, config=config)
#except:
#    errtype = sys.exc_info()[0]  # E.g. <class 'PermissionError'>
#    description = sys.exc_info()[1]   # E.g. [Errno 13] Permission denied: ...
        
#    print("\t +++++++++++++++++++++ Exception occured +++++++++++++++++++++++++++++++++++++++++")
#    print(f"\t >>>>>  errtype = {errtype}")
#    print(f"\t >>>>>> description = {description}")

# %% [markdown]
# # Backup output

# %%
copy_tree(output_directory,os.path.join(finalpath_output_spectractor,"basespec"))
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/basespec/exposure_2022031600330_postisrccd_spectrogram.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/basespec/exposure_2022031600330_postisrccd_lines.csv',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/basespec/exposure_2022031600330_postisrccd_spectrum.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/basespec/exposure_2022031600330_postisrccd_table.csv']

# %%
copy_tree(output_figures,os.path.join(finalpath_output_spectractor,"plots"))
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/amplitude_correlation_matrix.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/background_extraction.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/fit_chromatic_psf_best_fit_psf1d.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/regularisation.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/fwhm_2.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/D2CCD_x0_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/intermediate_spectrum.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/image.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/order0_centroid_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/fwhm.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/fit_chromatic_psf_best_fit_noprior.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330/plots/rotated_image.pdf']

# %%
# !ls -l  $finalpath_output_spectractor/basespec
# Out:
# total 82708
# -rw-r--r-- 1 dagoret lsst     3295 Mar 31 23:09 exposure_2022031600330_postisrccd_lines.csv
# -rw-r--r-- 1 dagoret lsst 40412160 Mar 31 23:08 exposure_2022031600330_postisrccd_spectrogram.fits
# -rw-r--r-- 1 dagoret lsst 43652160 Mar 31 23:08 exposure_2022031600330_postisrccd_spectrum.fits
# -rw-r--r-- 1 dagoret lsst   624097 Mar 31 23:09 exposure_2022031600330_postisrccd_table.csv

# %%
# !ls -l  $finalpath_output_spectractor/plots
# Out:
# total 1231
# -rw-r--r-- 1 dagoret lsst  53763 Mar 31 20:59 amplitude_correlation_matrix.pdf
# -rw-r--r-- 1 dagoret lsst  50923 Mar 31 19:59 background_extraction.pdf
# -rw-r--r-- 1 dagoret lsst  19880 Mar 31 23:08 D2CCD_x0_fit.pdf
# -rw-r--r-- 1 dagoret lsst 165335 Mar 31 19:59 fit_chromatic_psf_best_fit_noprior.pdf
# -rw-r--r-- 1 dagoret lsst 161467 Mar 31 23:05 fit_chromatic_psf_best_fit_psf1d.pdf
# -rw-r--r-- 1 dagoret lsst  19163 Mar 31 23:07 fwhm_2.pdf
# -rw-r--r-- 1 dagoret lsst  19046 Mar 31 19:59 fwhm.pdf
# -rw-r--r-- 1 dagoret lsst  49598 Mar 31 19:58 image.pdf
# -rw-r--r-- 1 dagoret lsst 528598 Mar 31 19:59 intermediate_spectrum.pdf
# -rw-r--r-- 1 dagoret lsst  32782 Mar 31 19:58 order0_centroid_fit.pdf
# -rw-r--r-- 1 dagoret lsst  21619 Mar 31 20:59 regularisation.pdf
# -rw-r--r-- 1 dagoret lsst 134248 Mar 31 19:58 rotated_image.pdf

# %%
finalpath_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/holo/configF/20220316/2022031600330'
