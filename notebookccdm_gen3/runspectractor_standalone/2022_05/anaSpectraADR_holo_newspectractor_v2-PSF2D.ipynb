# %% [markdown]
# #  Analyse spectra ADR holo at AuxTel for Configuration PSF2D

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# -
# - creation date : June 27th  2022
# - last update : June 27th 2022
#
# - **kernel anaconda3_auxtel** at CC or **python 3** locally
#
#
# ## ANalyse ADR subtraction

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re
import pandas as pd

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_subplot(1,1,1)
X=np.linspace(-10,10,50)
Y=np.sin(X)
ax.plot(X,Y)
plt.show()

# %%
import matplotlib.offsetbox
props = dict(boxstyle='round',edgecolor="w",facecolor="w", alpha=0.5)

# %%
from datetime import datetime,date

# %%
#pip install fpdf
#from fpdf import FPDF

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
today = date.today()
string_date=today.strftime("%Y-%m-%d")

# %%
string_date
# Out:
# '2022-06-27'

# %%
from iminuit import Minuit
import iminuit

# %%
iminuit.__version__
# Out:
# '2.8.4'

# %%
from astropy.io import fits
from spectractor import parameters
from spectractor.extractor.extractor import Spectractor, dumpParameters, FullForwardModelFitWorkspace,  run_ffm_minimisation, plot_comparison_truth
from spectractor.extractor.spectrum import Spectrum, detect_lines
from spectractor.extractor.spectrum import *
#from spectractor.extractor.spectroscopy import Lines, Line ,HALPHA, HBETA, O2_1, H2O_1,H2O_2
from spectractor.extractor.spectroscopy import Lines, Line ,HALPHA, HBETA, O2_1, H2O_1, ATMOSPHERIC_LINES
from spectractor.config import load_config
from spectractor import parameters
from spectractor.extractor.images import *
from scipy import ndimage, misc
from scipy.interpolate import interp1d

# %%
H2O_2 = Line(960, atmospheric=True, label=r'$H_2 O$', label_pos=[0.007, 0.02],width_bounds=[5, 30])  # libradtran paper fig.3, broad line

# %%
from time import sleep

# %%
from astropy.time import Time
import astropy.units as u

# %%
import pickle

# %% [markdown]
# # Function

# %%
def file_tag_forsorting(filename):
    # m=re.findall('^Cor_holo4_003_.*([0-9][0-9][0-9][0-9]-[0-9][0-9]-[0-9][0-9]_.*)[.]fits$',filename)
    m = re.findall('^exposure_.*([0-9][0-9][0-9][0-9][0-9])_postisrccd.*', filename)
    if len(m)>0:
        return m[0]
    else:
        return None

# %%
def subdir_tag_forsorting(subdir):
    # m=re.findall('^Cor_holo4_003_.*([0-9][0-9][0-9][0-9]-[0-9][0-9]-[0-9][0-9]_.*)[.]fits$',filename)
    m = re.findall('.*([0-9][0-9][0-9][0-9][0-9])$', subdir)
    if len(m)>0:
        return m[0]
    else:
        return None

# %%
file_tag_forsorting('exposure_2022031600330_postisrccd.fits')
# Out:
# '00330'

# %%
subdir_tag_forsorting('2022031600330')
# Out:
# '00330'

# %% [markdown]
# # Config

# %%
# path index for each month
DATE="20220317"
#DATE="20211104"
filterdispersername = "empty~holo4_003"
#filterdispersername = "BG40~holo4_003"
imagemode = "postISRCCD"
#imagemode = "unflattened"

# %%
version="v5.0"

# %%
# Choose the config filename
list_of_spectractorconfigfiles= ['auxtel_config_holo_DECONVOLUTION_PSF1D.ini' ,'auxtel_config_holo_DECONVOLUTION_PSF2D.ini','auxtel_config_holo_DECONVOLUTION_FFM.ini','auxtel_config_holo_DECONVOLUTION_PSF2DFFM.ini']
config_idx = 1
configfilename= os.path.join("./config",list_of_spectractorconfigfiles[config_idx])
#configdir = (list_of_spectractorconfigfiles[config_idx].split("_")[-1]).split(".") [0]
configdir = "config_" + (list_of_spectractorconfigfiles[config_idx].split("auxtel_config_holo_")[-1]).split(".") [0]

# %%
configdir
# Out:
# 'config_DECONVOLUTION_PSF2D'

# %%
load_config(configfilename)
# Out:
# No rebinning: parameters.REBIN is forced to 1.

# %%
dumpParameters()
# Out:
# ASTROMETRYNET_DIR
# BGD_ORDER 1
# CALIB_BGD_NPARAMS 4
# CALIB_BGD_ORDER 3
# CALIB_BGD_WIDTH 15
# CALIB_PEAK_WIDTH 7
# CALIB_SAVGOL_ORDER 2
# CALIB_SAVGOL_WINDOW 5
# CCD_ARCSEC2RADIANS 4.84813681109536e-06
# CCD_GAIN 1.1
# CCD_IMSIZE 4096
# CCD_MAXADU 170000
# CCD_PIXEL2ARCSEC 0.0952
# CCD_PIXEL2MM 0.01
# CCD_REBIN 1
# CONFIG_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/../config/
# DEBUG False
# DEBUG_LOGGING False
# DISPERSER_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/
# DISPLAY False
# DISTANCE2CCD 175
# DISTANCE2CCD_ERR 0.75
# FGB37 {'label': 'FGB37', 'min': 350, 'max': 750}
# FILTERS [{'label': 'RG715', 'min': 690, 'max': 1100}, {'label': 'FGB37', 'min': 350, 'max': 750}, {'label': 'Halfa', 'min': 0.0006431, 'max': 0.0006686999999999999}, {'label': 'Z-Gunn', 'min': 800, 'max': 1100}]
# FLAM_TO_ADURATE 5175865186660.421
# GRATING_ORDER_2OVER1 0.1
# GROOVES_PER_MM 350
# HALPHA_CENTER 0.0006559
# HALPHA_FILTER {'label': 'Halfa', 'min': 0.0006431, 'max': 0.0006686999999999999}
# HALPHA_WIDTH 6.4e-06
# LAMBDAS [ 300  301  302  303  304  305  306  307  308  309  310  311  312  313
#   314  315  316  317  318  319  320  321  322  323  324  325  326  327
#   328  329  330  331  332  333  334  335  336  337  338  339  340  341
#   342  343  344  345  346  347  348  349  350  351  352  353  354  355
#   356  357  358  359  360  361  362  363  364  365  366  367  368  369
#   370  371  372  373  374  375  376  377  378  379  380  381  382  383
#   384  385  386  387  388  389  390  391  392  393  394  395  396  397
#   398  399  400  401  402  403  404  405  406  407  408  409  410  411
#   412  413  414  415  416  417  418  419  420  421  422  423  424  425
#   426  427  428  429  430  431  432  433  434  435  436  437  438  439
#   440  441  442  443  444  445  446  447  448  449  450  451  452  453
#   454  455  456  457  458  459  460  461  462  463  464  465  466  467
#   468  469  470  471  472  473  474  475  476  477  478  479  480  481
#   482  483  484  485  486  487  488  489  490  491  492  493  494  495
#   496  497  498  499  500  501  502  503  504  505  506  507  508  509
#   510  511  512  513  514  515  516  517  518  519  520  521  522  523
#   524  525  526  527  528  529  530  531  532  533  534  535  536  537
#   538  539  540  541  542  543  544  545  546  547  548  549  550  551
#   552  553  554  555  556  557  558  559  560  561  562  563  564  565
#   566  567  568  569  570  571  572  573  574  575  576  577  578  579
#   580  581  582  583  584  585  586  587  588  589  590  591  592  593
#   594  595  596  597  598  599  600  601  602  603  604  605  606  607
#   608  609  610  611  612  613  614  615  616  617  618  619  620  621
#   622  623  624  625  626  627  628  629  630  631  632  633  634  635
#   636  637  638  639  640  641  642  643  644  645  646  647  648  649
#   650  651  652  653  654  655  656  657  658  659  660  661  662  663
#   664  665  666  667  668  669  670  671  672  673  674  675  676  677
#   678  679  680  681  682  683  684  685  686  687  688  689  690  691
#   692  693  694  695  696  697  698  699  700  701  702  703  704  705
#   706  707  708  709  710  711  712  713  714  715  716  717  718  719
#   720  721  722  723  724  725  726  727  728  729  730  731  732  733
#   734  735  736  737  738  739  740  741  742  743  744  745  746  747
#   748  749  750  751  752  753  754  755  756  757  758  759  760  761
#   762  763  764  765  766  767  768  769  770  771  772  773  774  775
#   776  777  778  779  780  781  782  783  784  785  786  787  788  789
#   790  791  792  793  794  795  796  797  798  799  800  801  802  803
#   804  805  806  807  808  809  810  811  812  813  814  815  816  817
#   818  819  820  821  822  823  824  825  826  827  828  829  830  831
#   832  833  834  835  836  837  838  839  840  841  842  843  844  845
#   846  847  848  849  850  851  852  853  854  855  856  857  858  859
#   860  861  862  863  864  865  866  867  868  869  870  871  872  873
#   874  875  876  877  878  879  880  881  882  883  884  885  886  887
#   888  889  890  891  892  893  894  895  896  897  898  899  900  901
#   902  903  904  905  906  907  908  909  910  911  912  913  914  915
#   916  917  918  919  920  921  922  923  924  925  926  927  928  929
#   930  931  932  933  934  935  936  937  938  939  940  941  942  943
#   944  945  946  947  948  949  950  951  952  953  954  955  956  957
#   958  959  960  961  962  963  964  965  966  967  968  969  970  971
#   972  973  974  975  976  977  978  979  980  981  982  983  984  985
#   986  987  988  989  990  991  992  993  994  995  996  997  998  999
#  1000 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013
#  1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027
#  1028 1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041
#  1042 1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055
#  1056 1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068 1069
#  1070 1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082 1083
#  1084 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096 1097
#  1098 1099]
# LAMBDA_CONSTRUCTOR 0.000639
# LAMBDA_MAX 1100
# LAMBDA_MIN 300
# LAMBDA_STEP 0.2
# LIBRADTRAN_DIR
# LINEWIDTH 2
# MY_FORMAT %(asctime)-20s %(name)-10s %(funcName)-20s %(levelname)-6s %(message)s
# OBS_ALTITUDE 2.66299616375123
# OBS_CAMERA_DEC_FLIP_SIGN 1
# OBS_CAMERA_RA_FLIP_SIGN 1
# OBS_CAMERA_ROTATION 0
# OBS_DIAMETER 1.2 m
# OBS_EPOCH J2000.0
# OBS_FULL_INSTRUMENT_TRANSMISSON calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt
# OBS_LATITUDE -30.2446389756252
# OBS_NAME AUXTEL
# OBS_OBJECT_TYPE STAR
# OBS_QUANTUM_EFFICIENCY calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt
# OBS_SURFACE 1.1309733552923256 m2
# OBS_TELESCOPE_TRANSMISSION calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt
# OBS_TRANSMISSION_SYSTEMATICS 0.005
# PAPER False
# PIXDIST_BACKGROUND 140
# PIXSHIFT_PRIOR 5
# PIXWIDTH_BACKGROUND 40
# PIXWIDTH_BOXSIZE 20
# PIXWIDTH_SIGNAL 40
# PLATE_CENTER_SHIFT_X -6.0
# PLATE_CENTER_SHIFT_X_ERR 2.0
# PLATE_CENTER_SHIFT_Y -8.0
# PLATE_CENTER_SHIFT_Y_ERR 2.0
# PLOT_DIR plots
# PLOT_ROT_LABEL $\alpha$ [degrees]
# PLOT_XLABEL $x$ [pixels]
# PLOT_YLABEL $y$ [pixels]
# PSF_FIT_REG_PARAM 1
# PSF_FWHM_CLIP 2
# PSF_PIXEL_STEP_TRANSVERSE_FIT 50
# PSF_POLY_ORDER 2
# PSF_TYPE Moffat
# RG715 {'label': 'RG715', 'min': 690, 'max': 1100}
# ROT_ANGLE_MAX 10
# ROT_ANGLE_MIN -10
# ROT_ANGL_MAX 10
# ROT_ORDER 5
# ROT_PREFILTER True
# SAVE False
# SED_UNIT 1.0 erg / (cm2 nm s)
# SPECTRACTOR_COMPUTE_ROTATION_ANGLE disperser
# SPECTRACTOR_DECONVOLUTION_FFM False
# SPECTRACTOR_DECONVOLUTION_PSF2D True
# SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP 100
# SPECTRACTOR_FIT_TARGET_CENTROID fit
# SPEC_ORDER 1
# THROUGHPUT_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/
# TIME_UNIT 1.0 s
# VERBOSE False
# XWINDOW 100
# XWINDOW_ROT 50
# YWINDOW 100
# YWINDOW_ROT 50
# ZGUNN {'label': 'Z-Gunn', 'min': 800, 'max': 1100}
# const <module 'astropy.constants' from '/pbs/home/d/dagoret/.local/lib/python3.8/site-packages/astropy/constants/__init__.py'>
# hc 1.9864458571489286e-25 J m
# mpl <module 'matplotlib' from '/opt/conda/lib/python3.8/site-packages/matplotlib/__init__.py'>
# mypath /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor
# np <module 'numpy' from '/opt/conda/lib/python3.8/site-packages/numpy/__init__.py'>
# os <module 'os' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/os.py'>
# units <module 'astropy.units' from '/pbs/home/d/dagoret/.local/lib/python3.8/site-packages/astropy/units/__init__.py'>
# wl_dwl_unit nm2

# %%
configmode = list_of_spectractorconfigfiles[config_idx].split("auxtel_config_holo_DECONVOLUTION_")[-1].split(".") [0]
configmode
# Out:
# 'PSF2D'

# %% [markdown]
# # Path

# %%
HOSTCC=True

# %%
# Set path depending on which computer running (according HOSTCC)
if HOSTCC:
    path_auxtel="/sps/lsst/groups/auxtel"
    path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
        path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
        path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)

else:
    path_auxtel="/Users/sylvie/DATA/AuxTelData2022"
    path_spectractor=os.path.join(path_auxtel,"/Users/sylvie/MacOSX/GitHub/LSST/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
        path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
        path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317'

# %%
! ls -l $path_output_spectractor
# Out:
# total 0
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:43 2022031700237
# drwxrws--- 1 dagoret lsst 2 Jun 13 02:09 2022031700238
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:56 2022031700244
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:19 2022031700245
# drwxrws--- 1 dagoret lsst 2 Jun 13 01:54 2022031700251
# drwxrws--- 1 dagoret lsst 2 Jun 13 05:57 2022031700252
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:07 2022031700258
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:13 2022031700259
# drwxrws--- 1 dagoret lsst 2 Jun 13 07:47 2022031700265
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:22 2022031700266
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:31 2022031700272
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:38 2022031700273
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:01 2022031700279
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:17 2022031700280
# drwxrws--- 1 dagoret lsst 2 Jun 13 01:02 2022031700286
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:19 2022031700287
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:28 2022031700293
# drwxrws--- 1 dagoret lsst 2 Jun 13 02:15 2022031700294
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:18 2022031700300
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:40 2022031700301
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:34 2022031700309
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:37 2022031700310
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:41 2022031700316
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:20 2022031700317
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:43 2022031700323
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:53 2022031700324
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:18 2022031700330
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:09 2022031700331
# drwxrws--- 1 dagoret lsst 2 Jun 13 01:58 2022031700337
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:37 2022031700338
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:03 2022031700344
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:59 2022031700345
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:09 2022031700351
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:21 2022031700352
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:07 2022031700358
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:56 2022031700359
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:11 2022031700365
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:54 2022031700366
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:48 2022031700372
# drwxrws--- 1 dagoret lsst 2 Jun 12 22:44 2022031700373
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:35 2022031700379
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:16 2022031700380
# drwxrws--- 1 dagoret lsst 2 Jun 13 10:56 2022031700386
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:59 2022031700387
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:04 2022031700393
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:29 2022031700394
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:16 2022031700400
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:05 2022031700401
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:13 2022031700407
# drwxrws--- 1 dagoret lsst 2 Jun 13 03:09 2022031700408
# drwxrws--- 1 dagoret lsst 2 Jun 13 17:13 2022031700414
# drwxrws--- 1 dagoret lsst 2 Jun 13 04:44 2022031700415
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:34 2022031700421
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:15 2022031700422
# drwxrws--- 1 dagoret lsst 2 Jun 13 02:34 2022031700428
# drwxrws--- 1 dagoret lsst 2 Jun 13 01:09 2022031700429
# drwxrws--- 1 dagoret lsst 2 Jun 13 01:01 2022031700435
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:58 2022031700436
# drwxrws--- 1 dagoret lsst 2 Jun 12 23:37 2022031700442
# drwxrws--- 1 dagoret lsst 2 Jun 13 00:10 2022031700443

# %%
# standard configuration for spectractor
#config = os.path.join(path_spectractor_config,"auxtel.ini")
#config=os.path.join("./config",configfilename)
config=configfilename
print(f">>>>> Spectractor configuration filename : {configfilename}")
# Out:
# >>>>> Spectractor configuration filename : ./config/auxtel_config_holo_DECONVOLUTION_PSF2D.ini

# %%
load_config(configfilename)
# Out:
# No rebinning: parameters.REBIN is forced to 1.

# %% [markdown]
# ## Logbook for file selection

# %%
filename_logbook='logbooks/auxtellogbook_'+filterdispersername+"_"+DATE+'_' + version+'.csv'

# %%
df=pd.read_csv(filename_logbook,index_col=0)

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#     index                     date  \
# 0       0  2022-03-18T00:51:03.112
# 1       1  2022-03-18T00:51:36.190
# 2       2  2022-03-18T00:54:30.463
# 3       3  2022-03-18T00:55:03.377
# 4       4  2022-03-18T00:58:01.707
# 5       5  2022-03-18T00:58:34.835
# 6       6  2022-03-18T01:01:32.859
# 7       7  2022-03-18T01:02:05.775
# 8       8  2022-03-18T01:05:03.839
# 9       9  2022-03-18T01:05:36.766
# 10     10  2022-03-18T01:08:32.232
# 11     11  2022-03-18T01:09:05.133
# 12     12  2022-03-18T01:12:00.164
# 13     13  2022-03-18T01:12:33.079
# 14     14  2022-03-18T01:15:32.735
# 15     15  2022-03-18T01:16:05.627
# 16     16  2022-03-18T01:18:59.663
# 17     17  2022-03-18T01:19:32.577
# 18     18  2022-03-18T01:22:30.386
# 19     19  2022-03-18T01:23:03.286
# 20     20  2022-03-18T01:43:39.078
# 21     21  2022-03-18T01:44:11.982
# 22     22  2022-03-18T01:47:06.515
# 23     23  2022-03-18T01:47:39.407
# 24     24  2022-03-18T01:50:33.593
# 25     25  2022-03-18T01:51:06.516
# 26     26  2022-03-18T01:54:00.883
# 27     27  2022-03-18T01:54:33.856
# 28     28  2022-03-18T01:57:30.505
# 29     29  2022-03-18T01:58:03.446
# 30     30  2022-03-18T02:01:00.181
# 31     31  2022-03-18T02:01:33.339
# 32     32  2022-03-18T02:04:30.946
# 33     33  2022-03-18T02:05:03.843
# 34     34  2022-03-18T02:08:03.232
# 35     35  2022-03-18T02:08:36.262
# 36     36  2022-03-18T02:11:34.200
# 37     37  2022-03-18T02:12:07.156
# 38     38  2022-03-18T02:15:00.952
# 39     39  2022-03-18T02:15:33.886
# 40     40  2022-03-18T02:33:14.260
# 41     41  2022-03-18T02:33:47.167
# 42     42  2022-03-18T02:36:45.029
# 43     43  2022-03-18T02:37:17.962
# 44     44  2022-03-18T02:40:14.985
# 45     45  2022-03-18T02:40:47.930
# 46     46  2022-03-18T02:43:46.361
# 47     47  2022-03-18T02:44:19.255
# 48     48  2022-03-18T02:47:16.976
# 49     49  2022-03-18T02:47:49.912
# 50     50  2022-03-18T02:50:52.460
# 51     51  2022-03-18T02:51:25.626
# 52     52  2022-03-18T03:08:55.717
# 53     53  2022-03-18T03:09:28.629
# 54     54  2022-03-18T03:13:08.467
# 55     55  2022-03-18T03:13:41.360
# 56     56  2022-03-18T03:17:20.920
# 57     57  2022-03-18T03:17:53.934
# 58     58  2022-03-18T03:21:41.018
# 59     59  2022-03-18T03:22:14.022
#
#                                                  path  \
# 0   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 1   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 2   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 3   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 4   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 5   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 6   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 7   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 8   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 9   /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 10  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 11  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 12  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 13  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 14  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 15  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 16  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 17  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 18  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 19  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 20  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 21  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 22  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 23  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 24  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 25  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 26  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 27  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 28  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 29  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 30  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 31  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 32  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 33  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 34  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 35  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 36  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 37  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 38  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 39  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 40  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 41  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 42  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 43  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 44  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 45  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 46  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 47  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 48  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 49  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 50  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 51  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 52  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 53  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 54  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 55  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 56  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 57  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 58  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
# 59  /sps/lsst/groups/auxtel/data/2022/empty~holo4_...
#
#                                       file  num    object   filter  disperser  \
# 0   exposure_2022031700237_postisrccd.fits  237   mu. col  empty_1  holo4_003
# 1   exposure_2022031700238_postisrccd.fits  238   mu. col  empty_1  holo4_003
# 2   exposure_2022031700244_postisrccd.fits  244   mu. col  empty_1  holo4_003
# 3   exposure_2022031700245_postisrccd.fits  245   mu. col  empty_1  holo4_003
# 4   exposure_2022031700251_postisrccd.fits  251   mu. col  empty_1  holo4_003
# 5   exposure_2022031700252_postisrccd.fits  252   mu. col  empty_1  holo4_003
# 6   exposure_2022031700258_postisrccd.fits  258   mu. col  empty_1  holo4_003
# 7   exposure_2022031700259_postisrccd.fits  259   mu. col  empty_1  holo4_003
# 8   exposure_2022031700265_postisrccd.fits  265   mu. col  empty_1  holo4_003
# 9   exposure_2022031700266_postisrccd.fits  266   mu. col  empty_1  holo4_003
# 10  exposure_2022031700272_postisrccd.fits  272   mu. col  empty_1  holo4_003
# 11  exposure_2022031700273_postisrccd.fits  273   mu. col  empty_1  holo4_003
# 12  exposure_2022031700279_postisrccd.fits  279   mu. col  empty_1  holo4_003
# 13  exposure_2022031700280_postisrccd.fits  280   mu. col  empty_1  holo4_003
# 14  exposure_2022031700286_postisrccd.fits  286   mu. col  empty_1  holo4_003
# 15  exposure_2022031700287_postisrccd.fits  287   mu. col  empty_1  holo4_003
# 16  exposure_2022031700293_postisrccd.fits  293   mu. col  empty_1  holo4_003
# 17  exposure_2022031700294_postisrccd.fits  294   mu. col  empty_1  holo4_003
# 18  exposure_2022031700300_postisrccd.fits  300   mu. col  empty_1  holo4_003
# 19  exposure_2022031700301_postisrccd.fits  301   mu. col  empty_1  holo4_003
# 20  exposure_2022031700309_postisrccd.fits  309   mu. col  empty_1  holo4_003
# 21  exposure_2022031700310_postisrccd.fits  310   mu. col  empty_1  holo4_003
# 22  exposure_2022031700316_postisrccd.fits  316   mu. col  empty_1  holo4_003
# 23  exposure_2022031700317_postisrccd.fits  317   mu. col  empty_1  holo4_003
# 24  exposure_2022031700323_postisrccd.fits  323   mu. col  empty_1  holo4_003
# 25  exposure_2022031700324_postisrccd.fits  324   mu. col  empty_1  holo4_003
# 26  exposure_2022031700330_postisrccd.fits  330   mu. col  empty_1  holo4_003
# 27  exposure_2022031700331_postisrccd.fits  331   mu. col  empty_1  holo4_003
# 28  exposure_2022031700337_postisrccd.fits  337   mu. col  empty_1  holo4_003
# 29  exposure_2022031700338_postisrccd.fits  338   mu. col  empty_1  holo4_003
# 30  exposure_2022031700344_postisrccd.fits  344   mu. col  empty_1  holo4_003
# 31  exposure_2022031700345_postisrccd.fits  345   mu. col  empty_1  holo4_003
# 32  exposure_2022031700351_postisrccd.fits  351   mu. col  empty_1  holo4_003
# 33  exposure_2022031700352_postisrccd.fits  352   mu. col  empty_1  holo4_003
# 34  exposure_2022031700358_postisrccd.fits  358   mu. col  empty_1  holo4_003
# 35  exposure_2022031700359_postisrccd.fits  359   mu. col  empty_1  holo4_003
# 36  exposure_2022031700365_postisrccd.fits  365   mu. col  empty_1  holo4_003
# 37  exposure_2022031700366_postisrccd.fits  366   mu. col  empty_1  holo4_003
# 38  exposure_2022031700372_postisrccd.fits  372   mu. col  empty_1  holo4_003
# 39  exposure_2022031700373_postisrccd.fits  373   mu. col  empty_1  holo4_003
# 40  exposure_2022031700379_postisrccd.fits  379   mu. col  empty_1  holo4_003
# 41  exposure_2022031700380_postisrccd.fits  380   mu. col  empty_1  holo4_003
# 42  exposure_2022031700386_postisrccd.fits  386   mu. col  empty_1  holo4_003
# 43  exposure_2022031700387_postisrccd.fits  387   mu. col  empty_1  holo4_003
# 44  exposure_2022031700393_postisrccd.fits  393   mu. col  empty_1  holo4_003
# 45  exposure_2022031700394_postisrccd.fits  394   mu. col  empty_1  holo4_003
# 46  exposure_2022031700400_postisrccd.fits  400   mu. col  empty_1  holo4_003
# 47  exposure_2022031700401_postisrccd.fits  401   mu. col  empty_1  holo4_003
# 48  exposure_2022031700407_postisrccd.fits  407   mu. col  empty_1  holo4_003
# 49  exposure_2022031700408_postisrccd.fits  408   mu. col  empty_1  holo4_003
# 50  exposure_2022031700414_postisrccd.fits  414   mu. col  empty_1  holo4_003
# 51  exposure_2022031700415_postisrccd.fits  415   mu. col  empty_1  holo4_003
# 52  exposure_2022031700421_postisrccd.fits  421   mu. col  empty_1  holo4_003
# 53  exposure_2022031700422_postisrccd.fits  422   mu. col  empty_1  holo4_003
# 54  exposure_2022031700428_postisrccd.fits  428  HD185975  empty_1  holo4_003
# 55  exposure_2022031700429_postisrccd.fits  429  HD185975  empty_1  holo4_003
# 56  exposure_2022031700435_postisrccd.fits  435   mu. col  empty_1  holo4_003
# 57  exposure_2022031700436_postisrccd.fits  436   mu. col  empty_1  holo4_003
# 58  exposure_2022031700442_postisrccd.fits  442   mu. col  empty_1  holo4_003
# 59  exposure_2022031700443_postisrccd.fits  443   mu. col  empty_1  holo4_003
#
#      airmass  exposure  ...  temperature  humidity  windspd  Obj-posXpix  \
# 0   1.114069      20.0  ...          8.9      48.0      9.4          NaN
# 1   1.115188      20.0  ...          8.9      48.0      9.4          NaN
# 2   1.121178      20.0  ...          8.9      49.0      8.7          NaN
# 3   1.122325      20.0  ...          8.8      49.0      7.5          NaN
# 4   1.128693      20.0  ...          8.9      50.0     10.2          NaN
# 5   1.129892      20.0  ...          8.9      50.0     10.2          NaN
# 6   1.136492      20.0  ...          8.9      53.0     10.1          NaN
# 7   1.137732      20.0  ...          8.9      52.0     10.4          NaN
# 8   1.144579      20.0  ...          8.9      53.0     10.5          NaN
# 9   1.145874      20.0  ...          8.9      53.0     10.5          NaN
# 10  1.152876      20.0  ...          8.9      51.0     10.4          NaN
# 11  1.154218      20.0  ...          8.9      51.0      9.2          NaN
# 12  1.161455      20.0  ...          8.9      53.0      9.8          NaN
# 13  1.162845      20.0  ...          8.9      53.0      9.8          NaN
# 14  1.170556      20.0  ...          8.9      54.0      9.5          NaN
# 15  1.171988      20.0  ...          8.9      55.0      9.5          NaN
# 16  1.179733      20.0  ...          9.0      53.0     10.1          NaN
# 17  1.181227      20.0  ...          9.0      53.0     10.1          NaN
# 18  1.189428      20.0  ...          8.9      56.0      9.9          NaN
# 19  1.190967      20.0  ...          9.0      56.0      9.9          NaN
# 20  1.255654      20.0  ...          8.8      55.0      9.3          NaN
# 21  1.257560      20.0  ...          8.8      56.0      9.6          NaN
# 22  1.267898      20.0  ...          8.7      56.0     10.3          NaN
# 23  1.269875      20.0  ...          8.7      56.0     10.3          NaN
# 24  1.280549      20.0  ...          8.7      56.0      9.1          NaN
# 25  1.282593      20.0  ...          8.7      57.0      7.4          NaN
# 26  1.293660      20.0  ...          8.6      56.0      9.0          NaN
# 27  1.295776      20.0  ...          8.6      56.0      9.0          NaN
# 28  1.307385      20.0  ...          8.7      58.0      6.6          NaN
# 29  1.309591      20.0  ...          8.7      57.0      7.9          NaN
# 30  1.321621      20.0  ...          8.6      59.0      9.7          NaN
# 31  1.323924      20.0  ...          8.6      59.0      9.7          NaN
# 32  1.336458      20.0  ...          8.5      58.0      9.4          NaN
# 33  1.338813      20.0  ...          8.5      58.0     10.5          NaN
# 34  1.351940      20.0  ...          8.4      59.0      8.7          NaN
# 35  1.354396      20.0  ...          8.4      59.0      8.7          NaN
# 36  1.367887      20.0  ...          8.4      59.0      9.0          NaN
# 37  1.370434      20.0  ...          8.4      59.0      9.0          NaN
# 38  1.384099      20.0  ...          8.4      61.0      9.4          NaN
# 39  1.386726      20.0  ...          8.4      61.0      9.4          NaN
# 40  1.480215      20.0  ...          8.1      62.0      9.1          NaN
# 41  1.483412      20.0  ...          8.0      63.0      9.7          NaN
# 42  1.500990      20.0  ...          8.1      64.0      8.9          NaN
# 43  1.504292      20.0  ...          8.1      64.0      9.3          NaN
# 44  1.522465      20.0  ...          8.0      64.0      8.8          NaN
# 45  1.525915      20.0  ...          8.0      64.0      9.3          NaN
# 46  1.544950      20.0  ...          8.0      64.0      9.4          NaN
# 47  1.548520      20.0  ...          8.0      64.0      9.4          NaN
# 48  1.568220      20.0  ...          8.0      64.0      9.1          NaN
# 49  1.571954      20.0  ...          8.0      64.0      7.6          NaN
# 50  1.592992      20.0  ...          8.0      63.0      8.6          NaN
# 51  1.596903      20.0  ...          8.0      63.0      8.6          NaN
# 52  1.734290      20.0  ...          7.7      63.0      7.9          NaN
# 53  1.739049      20.0  ...          7.7      63.0      7.9          NaN
# 54  2.129307      20.0  ...          7.8      62.0      7.9          NaN
# 55  2.129130      20.0  ...          7.8      62.0      7.9          NaN
# 56  1.811260      20.0  ...          7.7      63.0      7.3          NaN
# 57  1.816575      20.0  ...          7.7      63.0      8.6          NaN
# 58  1.854138      20.0  ...          7.8      62.0      8.4          NaN
# 59  1.859741      20.0  ...          7.7      63.0      7.9          NaN
#
#     Obj-posYpix  Dx  Dy  skip  run  quality
# 0           NaN NaN NaN        NaN      NaN
# 1           NaN NaN NaN        NaN      NaN
# 2           NaN NaN NaN        NaN      NaN
# 3           NaN NaN NaN        NaN      NaN
# 4           NaN NaN NaN        NaN      NaN
# 5           NaN NaN NaN        NaN      NaN
# 6           NaN NaN NaN        NaN      NaN
# 7           NaN NaN NaN        NaN      NaN
# 8           NaN NaN NaN        NaN      NaN
# 9           NaN NaN NaN        NaN      NaN
# 10          NaN NaN NaN        NaN      NaN
# 11          NaN NaN NaN        NaN      NaN
# 12          NaN NaN NaN        NaN      NaN
# 13          NaN NaN NaN        NaN      NaN
# 14          NaN NaN NaN        NaN      NaN
# 15          NaN NaN NaN        NaN      NaN
# 16          NaN NaN NaN        NaN      NaN
# 17          NaN NaN NaN        NaN      NaN
# 18          NaN NaN NaN        NaN      NaN
# 19          NaN NaN NaN        NaN      NaN
# 20          NaN NaN NaN        NaN      NaN
# 21          NaN NaN NaN        NaN      NaN
# 22          NaN NaN NaN        NaN      NaN
# 23          NaN NaN NaN        NaN      NaN
# 24          NaN NaN NaN        NaN      NaN
# 25          NaN NaN NaN        NaN      NaN
# 26          NaN NaN NaN        NaN      NaN
# 27          NaN NaN NaN        NaN      NaN
# 28          NaN NaN NaN        NaN      NaN
# 29          NaN NaN NaN        NaN      NaN
# 30          NaN NaN NaN        NaN      NaN
# 31          NaN NaN NaN        NaN      NaN
# 32          NaN NaN NaN        NaN      NaN
# 33          NaN NaN NaN        NaN      NaN
# 34          NaN NaN NaN        NaN      NaN
# 35          NaN NaN NaN        NaN      NaN
# 36          NaN NaN NaN        NaN      NaN
# 37          NaN NaN NaN        NaN      NaN
# 38          NaN NaN NaN        NaN      NaN
# 39          NaN NaN NaN        NaN      NaN
# 40          NaN NaN NaN        NaN      NaN
# 41          NaN NaN NaN        NaN      NaN
# 42          NaN NaN NaN        NaN      NaN
# 43          NaN NaN NaN        NaN      NaN
# 44          NaN NaN NaN        NaN      NaN
# 45          NaN NaN NaN        NaN      NaN
# 46          NaN NaN NaN        NaN      NaN
# 47          NaN NaN NaN        NaN      NaN
# 48          NaN NaN NaN        NaN      NaN
# 49          NaN NaN NaN        NaN      NaN
# 50          NaN NaN NaN        NaN      NaN
# 51          NaN NaN NaN        NaN      NaN
# 52          NaN NaN NaN        NaN      NaN
# 53          NaN NaN NaN        NaN      NaN
# 54          NaN NaN NaN        NaN      NaN
# 55          NaN NaN NaN        NaN      NaN
# 56          NaN NaN NaN        NaN      NaN
# 57          NaN NaN NaN        NaN      NaN
# 58          NaN NaN NaN        NaN      NaN
# 59          NaN NaN NaN        NaN      NaN
#
# [60 rows x 23 columns]

# %% [markdown]
# ## Selection of input files

# %%
# Do not consider flag
#df_good=df[df["quality"]==1]

# %%
df_good=df
df_good["quality"] = 1

# %%
for spectra_file in df_good["file"]:
    print(spectra_file)
# Out:
# exposure_2022031700237_postisrccd.fits
# exposure_2022031700238_postisrccd.fits
# exposure_2022031700244_postisrccd.fits
# exposure_2022031700245_postisrccd.fits
# exposure_2022031700251_postisrccd.fits
# exposure_2022031700252_postisrccd.fits
# exposure_2022031700258_postisrccd.fits
# exposure_2022031700259_postisrccd.fits
# exposure_2022031700265_postisrccd.fits
# exposure_2022031700266_postisrccd.fits
# exposure_2022031700272_postisrccd.fits
# exposure_2022031700273_postisrccd.fits
# exposure_2022031700279_postisrccd.fits
# exposure_2022031700280_postisrccd.fits
# exposure_2022031700286_postisrccd.fits
# exposure_2022031700287_postisrccd.fits
# exposure_2022031700293_postisrccd.fits
# exposure_2022031700294_postisrccd.fits
# exposure_2022031700300_postisrccd.fits
# exposure_2022031700301_postisrccd.fits
# exposure_2022031700309_postisrccd.fits
# exposure_2022031700310_postisrccd.fits
# exposure_2022031700316_postisrccd.fits
# exposure_2022031700317_postisrccd.fits
# exposure_2022031700323_postisrccd.fits
# exposure_2022031700324_postisrccd.fits
# exposure_2022031700330_postisrccd.fits
# exposure_2022031700331_postisrccd.fits
# exposure_2022031700337_postisrccd.fits
# exposure_2022031700338_postisrccd.fits
# exposure_2022031700344_postisrccd.fits
# exposure_2022031700345_postisrccd.fits
# exposure_2022031700351_postisrccd.fits
# exposure_2022031700352_postisrccd.fits
# exposure_2022031700358_postisrccd.fits
# exposure_2022031700359_postisrccd.fits
# exposure_2022031700365_postisrccd.fits
# exposure_2022031700366_postisrccd.fits
# exposure_2022031700372_postisrccd.fits
# exposure_2022031700373_postisrccd.fits
# exposure_2022031700379_postisrccd.fits
# exposure_2022031700380_postisrccd.fits
# exposure_2022031700386_postisrccd.fits
# exposure_2022031700387_postisrccd.fits
# exposure_2022031700393_postisrccd.fits
# exposure_2022031700394_postisrccd.fits
# exposure_2022031700400_postisrccd.fits
# exposure_2022031700401_postisrccd.fits
# exposure_2022031700407_postisrccd.fits
# exposure_2022031700408_postisrccd.fits
# exposure_2022031700414_postisrccd.fits
# exposure_2022031700415_postisrccd.fits
# exposure_2022031700421_postisrccd.fits
# exposure_2022031700422_postisrccd.fits
# exposure_2022031700428_postisrccd.fits
# exposure_2022031700429_postisrccd.fits
# exposure_2022031700435_postisrccd.fits
# exposure_2022031700436_postisrccd.fits
# exposure_2022031700442_postisrccd.fits
# exposure_2022031700443_postisrccd.fits

# %% [markdown]
# ## Selection of Spectractor output files

# %%
# total number of exposures
NBEXP=0
# total number of exposures without dir
NBEXPNODIR=0
# total number of exposures with dir
NBEXPWTHDIR=0
# total number of exposures with plots
NBEXPWTHPLT=0
# total number of exposures with spectra
NBEXPWTHSPEC=0

# list of exposures
LISTNUM=[]
# list of exposure without dir (not run spectraction)
LISTNUMNODIR=[]
# list of exposure with dir (spectraction has been run)
LISTNUMWTHDIR=[]
# list of exposures with plots (Spectractor has run up to some point)
LISTNUMWTHPLOTS=[]
# list of exposures with spectraction output (Spectractor has completed)
LISTNUMWTHSPECTR=[]

# list of selected spectra path
List_of_spectra_path=[]

# %%
list_of_files=os.listdir(path_output_spectractor)
list_of_files=sorted(list_of_files)


print("list of subdir found ",list_of_files)

for subdir in list_of_files:
    
    
    #tag = file_tag_forsorting(subdir)
    tag = subdir_tag_forsorting(subdir)
    
        
    print(tag)    
    #if tag is not None and int(tag)<317:
    #    continue
    if tag is None :
        continue
  
    
    
    fulldir=os.path.join(path_output_spectractor,subdir)



    if not os.path.isdir(fulldir):
        
        print("---------------------------------------------")
        print(subdir," \t  ",tag)
        print("{} is not a directory".format(subdir))
        

        NBEXPNODIR+=1


    else:

        
        print("---------------------------------------------")
        print(subdir," \t  ",tag)
        print("{} is a directory".format(subdir))

        tagname=subdir_tag_forsorting(subdir)
        print("tagname= {}".format(tagname))
        #targetname=file_target(subdir)
        #print("targetname= {}".format(targetname))
        



        NBEXP += 1
        LISTNUM.append(tagname)



        dir_plots=os.path.join(fulldir,"plots")
        dir_spectration = os.path.join(fulldir, "basespec")

        flag_empty1 = True
        flag_empty2 = True


        if os.path.isdir(dir_plots):
            if any(os.scandir(dir_plots)):
                print("dir_plots is not empty")
                NBEXPWTHPLT+=1
                LISTNUMWTHPLOTS.append(tagname)
                flag_empty1 = False

            else:
                print("dir_plots is empty")


        if os.path.isdir(dir_spectration):
            if any(os.scandir(dir_spectration)):
                print("dir_spectration is not empty")
                NBEXPWTHSPEC+=1
                LISTNUMWTHSPECTR.append(tagname)
                flag_empty2 = False
                List_of_spectra_path.append(dir_spectration)

            else:
                print("dir_spectration is empty")

        if flag_empty1 and flag_empty2 :
            NBEXPNODIR+=1
            LISTNUMNODIR.append(tagname)
        else:
            NBEXPWTHDIR += 1
            LISTNUMWTHDIR.append(tagname)



print("-----------------------------------------------------------------")


#LISTNUM=sorted(LISTNUM)
#LISTNUMNODIR=sorted(LISTNUMNODIR)
#LISTNUMWTHDIR=sorted(LISTNUMWTHDIR)
#LISTNUMWTHPLOTS=sorted(LISTNUMWTHPLOTS)
#LISTNUMWTHSPECTR=sorted(LISTNUMWTHSPECTR)
List_of_spectra_path=sorted(List_of_spectra_path)

print("Full list of Exposures : .......................{}".format(LISTNUM))
print("Full list of Exposures without output dir: .....{}".format(LISTNUMNODIR))
print("Full list of Exposures with output dir: ....... {}".format(LISTNUMWTHDIR))
print("Full list of Exposures with output plots: ..... {}".format(LISTNUMWTHPLOTS))
print("Full list of Exposures with output spectra: ....{}".format(LISTNUMWTHSPECTR))




print("Total number of exposures : .....................{}".format(NBEXP))
print("Total number of exposures without dir : .........{}".format(NBEXPNODIR))
print("Total number of exposures with dir :.............{}".format(NBEXPWTHDIR))
print("Total number of exposures with plots : ..........{}".format(NBEXPWTHPLT))
print("Total number of exposures with spectra: .........{}".format(NBEXPWTHSPEC))
# Out:
# list of subdir found  ['2022031700237', '2022031700238', '2022031700244', '2022031700245', '2022031700251', '2022031700252', '2022031700258', '2022031700259', '2022031700265', '2022031700266', '2022031700272', '2022031700273', '2022031700279', '2022031700280', '2022031700286', '2022031700287', '2022031700293', '2022031700294', '2022031700300', '2022031700301', '2022031700309', '2022031700310', '2022031700316', '2022031700317', '2022031700323', '2022031700324', '2022031700330', '2022031700331', '2022031700337', '2022031700338', '2022031700344', '2022031700345', '2022031700351', '2022031700352', '2022031700358', '2022031700359', '2022031700365', '2022031700366', '2022031700372', '2022031700373', '2022031700379', '2022031700380', '2022031700386', '2022031700387', '2022031700393', '2022031700394', '2022031700400', '2022031700401', '2022031700407', '2022031700408', '2022031700414', '2022031700415', '2022031700421', '2022031700422', '2022031700428', '2022031700429', '2022031700435', '2022031700436', '2022031700442', '2022031700443']
# 00237
# ---------------------------------------------
# 2022031700237  	   00237
# 2022031700237 is a directory
# tagname= 00237
# dir_plots is not empty
# dir_spectration is not empty
# 00238
# ---------------------------------------------
# 2022031700238  	   00238
# 2022031700238 is a directory
# tagname= 00238
# dir_plots is not empty
# dir_spectration is not empty
# 00244
# ---------------------------------------------
# 2022031700244  	   00244
# 2022031700244 is a directory
# tagname= 00244
# dir_plots is not empty
# dir_spectration is not empty
# 00245
# ---------------------------------------------
# 2022031700245  	   00245
# 2022031700245 is a directory
# tagname= 00245
# dir_plots is not empty
# dir_spectration is not empty
# 00251
# ---------------------------------------------
# 2022031700251  	   00251
# 2022031700251 is a directory
# tagname= 00251
# dir_plots is not empty
# dir_spectration is not empty
# 00252
# ---------------------------------------------
# 2022031700252  	   00252
# 2022031700252 is a directory
# tagname= 00252
# dir_plots is not empty
# dir_spectration is not empty
# 00258
# ---------------------------------------------
# 2022031700258  	   00258
# 2022031700258 is a directory
# tagname= 00258
# dir_plots is not empty
# dir_spectration is not empty
# 00259
# ---------------------------------------------
# 2022031700259  	   00259
# 2022031700259 is a directory
# tagname= 00259
# dir_plots is not empty
# dir_spectration is not empty
# 00265
# ---------------------------------------------
# 2022031700265  	   00265
# 2022031700265 is a directory
# tagname= 00265
# dir_plots is not empty
# dir_spectration is not empty
# 00266
# ---------------------------------------------
# 2022031700266  	   00266
# 2022031700266 is a directory
# tagname= 00266
# dir_plots is not empty
# dir_spectration is not empty
# 00272
# ---------------------------------------------
# 2022031700272  	   00272
# 2022031700272 is a directory
# tagname= 00272
# dir_plots is not empty
# dir_spectration is not empty
# 00273
# ---------------------------------------------
# 2022031700273  	   00273
# 2022031700273 is a directory
# tagname= 00273
# dir_plots is not empty
# dir_spectration is not empty
# 00279
# ---------------------------------------------
# 2022031700279  	   00279
# 2022031700279 is a directory
# tagname= 00279
# dir_plots is not empty
# dir_spectration is not empty
# 00280
# ---------------------------------------------
# 2022031700280  	   00280
# 2022031700280 is a directory
# tagname= 00280
# dir_plots is not empty
# dir_spectration is not empty
# 00286
# ---------------------------------------------
# 2022031700286  	   00286
# 2022031700286 is a directory
# tagname= 00286
# dir_plots is not empty
# dir_spectration is not empty
# 00287
# ---------------------------------------------
# 2022031700287  	   00287
# 2022031700287 is a directory
# tagname= 00287
# dir_plots is not empty
# dir_spectration is not empty
# 00293
# ---------------------------------------------
# 2022031700293  	   00293
# 2022031700293 is a directory
# tagname= 00293
# dir_plots is not empty
# dir_spectration is not empty
# 00294
# ---------------------------------------------
# 2022031700294  	   00294
# 2022031700294 is a directory
# tagname= 00294
# dir_plots is not empty
# dir_spectration is not empty
# 00300
# ---------------------------------------------
# 2022031700300  	   00300
# 2022031700300 is a directory
# tagname= 00300
# dir_plots is not empty
# dir_spectration is not empty
# 00301
# ---------------------------------------------
# 2022031700301  	   00301
# 2022031700301 is a directory
# tagname= 00301
# dir_plots is not empty
# dir_spectration is not empty
# 00309
# ---------------------------------------------
# 2022031700309  	   00309
# 2022031700309 is a directory
# tagname= 00309
# dir_plots is not empty
# dir_spectration is not empty
# 00310
# ---------------------------------------------
# 2022031700310  	   00310
# 2022031700310 is a directory
# tagname= 00310
# dir_plots is not empty
# dir_spectration is not empty
# 00316
# ---------------------------------------------
# 2022031700316  	   00316
# 2022031700316 is a directory
# tagname= 00316
# dir_plots is not empty
# dir_spectration is not empty
# 00317
# ---------------------------------------------
# 2022031700317  	   00317
# 2022031700317 is a directory
# tagname= 00317
# dir_plots is not empty
# dir_spectration is not empty
# 00323
# ---------------------------------------------
# 2022031700323  	   00323
# 2022031700323 is a directory
# tagname= 00323
# dir_plots is not empty
# dir_spectration is not empty
# 00324
# ---------------------------------------------
# 2022031700324  	   00324
# 2022031700324 is a directory
# tagname= 00324
# dir_plots is not empty
# dir_spectration is not empty
# 00330
# ---------------------------------------------
# 2022031700330  	   00330
# 2022031700330 is a directory
# tagname= 00330
# dir_plots is not empty
# dir_spectration is not empty
# 00331
# ---------------------------------------------
# 2022031700331  	   00331
# 2022031700331 is a directory
# tagname= 00331
# dir_plots is not empty
# dir_spectration is not empty
# 00337
# ---------------------------------------------
# 2022031700337  	   00337
# 2022031700337 is a directory
# tagname= 00337
# dir_plots is not empty
# dir_spectration is not empty
# 00338
# ---------------------------------------------
# 2022031700338  	   00338
# 2022031700338 is a directory
# tagname= 00338
# dir_plots is not empty
# dir_spectration is not empty
# 00344
# ---------------------------------------------
# 2022031700344  	   00344
# 2022031700344 is a directory
# tagname= 00344
# dir_plots is not empty
# dir_spectration is not empty
# 00345
# ---------------------------------------------
# 2022031700345  	   00345
# 2022031700345 is a directory
# tagname= 00345
# dir_plots is not empty
# dir_spectration is not empty
# 00351
# ---------------------------------------------
# 2022031700351  	   00351
# 2022031700351 is a directory
# tagname= 00351
# dir_plots is not empty
# dir_spectration is not empty
# 00352
# ---------------------------------------------
# 2022031700352  	   00352
# 2022031700352 is a directory
# tagname= 00352
# dir_plots is not empty
# dir_spectration is not empty
# 00358
# ---------------------------------------------
# 2022031700358  	   00358
# 2022031700358 is a directory
# tagname= 00358
# dir_plots is not empty
# dir_spectration is not empty
# 00359
# ---------------------------------------------
# 2022031700359  	   00359
# 2022031700359 is a directory
# tagname= 00359
# dir_plots is not empty
# dir_spectration is not empty
# 00365
# ---------------------------------------------
# 2022031700365  	   00365
# 2022031700365 is a directory
# tagname= 00365
# dir_plots is not empty
# dir_spectration is not empty
# 00366
# ---------------------------------------------
# 2022031700366  	   00366
# 2022031700366 is a directory
# tagname= 00366
# dir_plots is not empty
# dir_spectration is not empty
# 00372
# ---------------------------------------------
# 2022031700372  	   00372
# 2022031700372 is a directory
# tagname= 00372
# dir_plots is not empty
# dir_spectration is not empty
# 00373
# ---------------------------------------------
# 2022031700373  	   00373
# 2022031700373 is a directory
# tagname= 00373
# dir_plots is not empty
# dir_spectration is not empty
# 00379
# ---------------------------------------------
# 2022031700379  	   00379
# 2022031700379 is a directory
# tagname= 00379
# dir_plots is not empty
# dir_spectration is not empty
# 00380
# ---------------------------------------------
# 2022031700380  	   00380
# 2022031700380 is a directory
# tagname= 00380
# dir_plots is not empty
# dir_spectration is not empty
# 00386
# ---------------------------------------------
# 2022031700386  	   00386
# 2022031700386 is a directory
# tagname= 00386
# dir_plots is not empty
# dir_spectration is not empty
# 00387
# ---------------------------------------------
# 2022031700387  	   00387
# 2022031700387 is a directory
# tagname= 00387
# dir_plots is not empty
# dir_spectration is not empty
# 00393
# ---------------------------------------------
# 2022031700393  	   00393
# 2022031700393 is a directory
# tagname= 00393
# dir_plots is not empty
# dir_spectration is not empty
# 00394
# ---------------------------------------------
# 2022031700394  	   00394
# 2022031700394 is a directory
# tagname= 00394
# dir_plots is not empty
# dir_spectration is not empty
# 00400
# ---------------------------------------------
# 2022031700400  	   00400
# 2022031700400 is a directory
# tagname= 00400
# dir_plots is not empty
# dir_spectration is not empty
# 00401
# ---------------------------------------------
# 2022031700401  	   00401
# 2022031700401 is a directory
# tagname= 00401
# dir_plots is not empty
# dir_spectration is not empty
# 00407
# ---------------------------------------------
# 2022031700407  	   00407
# 2022031700407 is a directory
# tagname= 00407
# dir_plots is not empty
# dir_spectration is not empty
# 00408
# ---------------------------------------------
# 2022031700408  	   00408
# 2022031700408 is a directory
# tagname= 00408
# dir_plots is not empty
# dir_spectration is not empty
# 00414
# ---------------------------------------------
# 2022031700414  	   00414
# 2022031700414 is a directory
# tagname= 00414
# dir_plots is not empty
# dir_spectration is not empty
# 00415
# ---------------------------------------------
# 2022031700415  	   00415
# 2022031700415 is a directory
# tagname= 00415
# dir_plots is not empty
# dir_spectration is not empty
# 00421
# ---------------------------------------------
# 2022031700421  	   00421
# 2022031700421 is a directory
# tagname= 00421
# dir_plots is not empty
# dir_spectration is not empty
# 00422
# ---------------------------------------------
# 2022031700422  	   00422
# 2022031700422 is a directory
# tagname= 00422
# dir_plots is not empty
# dir_spectration is not empty
# 00428
# ---------------------------------------------
# 2022031700428  	   00428
# 2022031700428 is a directory
# tagname= 00428
# dir_plots is not empty
# dir_spectration is not empty
# 00429
# ---------------------------------------------
# 2022031700429  	   00429
# 2022031700429 is a directory
# tagname= 00429
# dir_plots is not empty
# dir_spectration is not empty
# 00435
# ---------------------------------------------
# 2022031700435  	   00435
# 2022031700435 is a directory
# tagname= 00435
# dir_plots is not empty
# dir_spectration is not empty
# 00436
# ---------------------------------------------
# 2022031700436  	   00436
# 2022031700436 is a directory
# tagname= 00436
# dir_plots is not empty
# dir_spectration is not empty
# 00442
# ---------------------------------------------
# 2022031700442  	   00442
# 2022031700442 is a directory
# tagname= 00442
# dir_plots is not empty
# dir_spectration is not empty
# 00443
# ---------------------------------------------
# 2022031700443  	   00443
# 2022031700443 is a directory
# tagname= 00443
# dir_plots is not empty
# dir_spectration is not empty
# -----------------------------------------------------------------
# Full list of Exposures : .......................['00237', '00238', '00244', '00245', '00251', '00252', '00258', '00259', '00265', '00266', '00272', '00273', '00279', '00280', '00286', '00287', '00293', '00294', '00300', '00301', '00309', '00310', '00316', '00317', '00323', '00324', '00330', '00331', '00337', '00338', '00344', '00345', '00351', '00352', '00358', '00359', '00365', '00366', '00372', '00373', '00379', '00380', '00386', '00387', '00393', '00394', '00400', '00401', '00407', '00408', '00414', '00415', '00421', '00422', '00428', '00429', '00435', '00436', '00442', '00443']
# Full list of Exposures without output dir: .....[]
# Full list of Exposures with output dir: ....... ['00237', '00238', '00244', '00245', '00251', '00252', '00258', '00259', '00265', '00266', '00272', '00273', '00279', '00280', '00286', '00287', '00293', '00294', '00300', '00301', '00309', '00310', '00316', '00317', '00323', '00324', '00330', '00331', '00337', '00338', '00344', '00345', '00351', '00352', '00358', '00359', '00365', '00366', '00372', '00373', '00379', '00380', '00386', '00387', '00393', '00394', '00400', '00401', '00407', '00408', '00414', '00415', '00421', '00422', '00428', '00429', '00435', '00436', '00442', '00443']
# Full list of Exposures with output plots: ..... ['00237', '00238', '00244', '00245', '00251', '00252', '00258', '00259', '00265', '00266', '00272', '00273', '00279', '00280', '00286', '00287', '00293', '00294', '00300', '00301', '00309', '00310', '00316', '00317', '00323', '00324', '00330', '00331', '00337', '00338', '00344', '00345', '00351', '00352', '00358', '00359', '00365', '00366', '00372', '00373', '00379', '00380', '00386', '00387', '00393', '00394', '00400', '00401', '00407', '00408', '00414', '00415', '00421', '00422', '00428', '00429', '00435', '00436', '00442', '00443']
# Full list of Exposures with output spectra: ....['00237', '00238', '00244', '00245', '00251', '00252', '00258', '00259', '00265', '00266', '00272', '00273', '00279', '00280', '00286', '00287', '00293', '00294', '00300', '00301', '00309', '00310', '00316', '00317', '00323', '00324', '00330', '00331', '00337', '00338', '00344', '00345', '00351', '00352', '00358', '00359', '00365', '00366', '00372', '00373', '00379', '00380', '00386', '00387', '00393', '00394', '00400', '00401', '00407', '00408', '00414', '00415', '00421', '00422', '00428', '00429', '00435', '00436', '00442', '00443']
# Total number of exposures : .....................60
# Total number of exposures without dir : .........0
# Total number of exposures with dir :.............60
# Total number of exposures with plots : ..........60
# Total number of exposures with spectra: .........60

# %%
#dir_spectra="outputs_reprocess"
print(List_of_spectra_path)
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700237/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700244/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700245/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700251/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700252/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700258/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700259/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700265/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700266/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700272/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700273/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700279/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700280/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700286/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700287/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700293/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700294/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700300/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700301/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700309/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700310/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700316/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700317/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700323/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700324/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700330/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700331/basespec', '/sps/lsst/groups/auxtel/data/2022/OutputSpectracto ...

# %%
config
# Out:
# './config/auxtel_config_holo_DECONVOLUTION_PSF2D.ini'

# %% [markdown]
# ## Extraction of spectra

# %%
all_files_spectra = []
all_files_spectrogram = []
all_files_lines = []
all_files_table = []

# loop on topdir
for dir_spectra in List_of_spectra_path:
    for filename in os.listdir(dir_spectra):
        if re.search("_spectrum.fits$",filename):
            the_file_spectrum=os.path.join(dir_spectra,filename)
            all_files_spectra.append(the_file_spectrum)
            the_file_spectrogram=the_file_spectrum.replace("_spectrum","_spectrogram")
            all_files_spectrogram.append(the_file_spectrogram)
            the_file_lines=the_file_spectrum.replace("_spectrum.fits","_lines.csv")
            all_files_lines.append(the_file_lines)
            the_file_table=the_file_spectrum.replace("_spectrum.fits","_table.csv")
            all_files_table.append(the_file_table)

# %%
all_files_spectra[:3]
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_spectrum.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031700238_postisrccd_spectrum.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031600331_postisrccd_spectrum.fits']

# %%
all_files_spectrogram[:3]
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_spectrogram.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031700238_postisrccd_spectrogram.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031600331_postisrccd_spectrogram.fits']

# %%
all_files_lines[:3]
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_lines.csv',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031700238_postisrccd_lines.csv',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031600331_postisrccd_lines.csv']

# %%
all_files_table[:3]
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700237/basespec/exposure_2022031700237_postisrccd_table.csv',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031700238_postisrccd_table.csv',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031600331_postisrccd_table.csv']

# %% [markdown]
# ## Selection of good spectra

# %%
all_good_spectra_spectrum_files = sorted(all_files_spectra)

# %%
N=len(all_good_spectra_spectrum_files)

# wavelength bin colors
jet = plt.get_cmap('jet')
cNorm = colors.Normalize(vmin=0, vmax=N)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
all_colors = scalarMap.to_rgba(np.arange(N), alpha=1)

# %% [markdown]
# ## All Spectra

# %%
all_num=[]
idx=0
for fullfilename in all_good_spectra_spectrum_files:
    filename= os.path.basename(fullfilename)
    tag=file_tag_forsorting(filename.split(".")[0])
    all_num.append(tag)
    idx+=1

# %%
if False:
    parameters.DISPLAY=True

    FLAG_ORDER2 = True

    infos = []
    all_lambdas=[]
    all_data=[]
    all_data_err=[]

    if FLAG_ORDER2:
        all_lambdas_order2=[]
        all_data_order2=[]
        all_data_err_order2=[]

    all_num=[]
    all_figs = []


    idx=0
    for fullfilename in all_good_spectra_spectrum_files:
    
        filename = os.path.basename(fullfilename)
        print(idx,")",filename," ",fullfilename)
    
    
        fig=plt.figure(figsize=(16,4))
        ax1 = fig.add_subplot(1, 2, 1)
    
        filename= os.path.basename(fullfilename)
        tag=file_tag_forsorting(filename.split(".")[0])
        all_num.append(tag)
    
   
     
        s=Spectrum(fullfilename, config=config,fast_load=False)
        label=filename.split('.')[0]+" "
        s.plot_spectrum(ax=ax1,force_lines=True,label=label)
    
        all_lambdas.append(s.lambdas)
        all_data.append(s.data)
        all_data_err.append(s.err)
    
        if FLAG_ORDER2:
            all_lambdas_order2.append(s.lambdas_order2)
            all_data_order2.append(s.data_order2)
            all_data_err_order2.append(s.err_order2)
    
        ax2 = fig.add_subplot(1, 2, 2)
    
        fullfilename2=all_files_spectrogram[idx]
    
        s.load_spectrogram(fullfilename2)
        s.plot_spectrogram(ax=ax2,scale="log")
    
    
        infos.append([idx,s.target.label,s.date_obs,s.airmass,s.temperature,s.pressure,s.humidity])
    
    
        plt.show()
        all_figs.append(fig)
    
        idx+=1

# %% [markdown]
# ## View one spectrum

# %%
idx=1

fullfilename = all_good_spectra_spectrum_files[idx]
    
filename = os.path.basename(fullfilename)
print(idx,")",filename," ",fullfilename)
    
    
fig=plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(1, 1, 1)
    
filename= os.path.basename(fullfilename)
tag=file_tag_forsorting(filename.split(".")[0])
all_num.append(tag)
    
   
     
s=Spectrum(fullfilename, config=config,fast_load=False)
label=filename.split('.')[0]+" "
#s.plot_spectrum(ax=ax1,force_lines=True,label=label)
s.plot_spectrum(ax=ax1,force_lines=True)
    
    
#ax2 = fig.add_subplot(1, 2, 2)
    
#fullfilename2=all_files_spectrogram[idx]
    
#s.load_spectrogram(fullfilename2)
#s.plot_spectrogram(ax=ax2,scale="log")
    

plt.show()
# Out:
# 1 ) exposure_2022031600331_postisrccd_spectrum.fits   /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031600331_postisrccd_spectrum.fits
# No rebinning: parameters.REBIN is forced to 1.
# set date_obs to 2022-03-17T01:59:56.544
# set expo to 20.0
# set airmass to 1.386860919079735
# set disperser_label to holo4_003
# set units to erg/s/cm$^2$/nm
# set rotation_angle to -0.28
# set dec to -66.0397222222222
# set hour_angle to 42.19664412811424
# set temperature to 10.6
# set pressure to 743.55
# set humidity to 44.0
# set lambda_ref to 642.4510060106066
# set parallactic_angle to 56.75888867802155
# WARNING: AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version. [astroquery._astropy_init]
# 2022-06-27 20:36:25  astropy    _showwarning         WARNING AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version.
# WARNING: AstropyDeprecationWarning: "pedantic" was deprecated in version 5.0 and will be removed in a future version. Use argument "verify" instead. [astropy.io.votable.table]
# 2022-06-27 20:36:29  astropy    _showwarning         WARNING AstropyDeprecationWarning: "pedantic" was deprecated in version 5.0 and will be removed in a future version. Use argument "verify" instead.
# target_name = etador, Selected object name for Simbad : ETA1 DOR
#   MAIN_ID         RA           DEC      ...  Z_VALUE  SCRIPT_NUMBER_ID
#                "h:m:s"       "d:m:s"    ...
# ----------- ------------- ------------- ... --------- ----------------
# * eta01 Dor 06 06 09.3817 -66 02 22.635 ... 0.0000590                1

# %%
s.header['LBDAS_T'] = True

# %%
from spectractor.simulation.adr import adr_calib, flip_and_rotate_adr_to_image_xy_coordinates

# %%
parameters.DISPLAY = True
parameters.DEBUG = True
parameters.VERBOSE = True
parameters.LSST_SAVEFIGPATH = "fig_PSF2DtoFFM"

# %%
w = FullForwardModelFitWorkspace(s, verbose=parameters.VERBOSE, plot=True, live_fit=True,
                                         amplitude_priors_method="spectrum")
# Out:
# 2022-06-27 20:36:50  FullForwardModelFitWorkspace __init__             INFO
# 	Full forward model fitting with regularisation parameter r=10.26981215511283.

# %%
spectrum = run_ffm_minimisation(w, method="newton", niter=2)
# Out:
# 2022-06-27 20:46:50  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=4.8665e+08 initial chisq_red=2870.2
# 		 Line search: alpha_min=2.62 iter=0 funcalls=5
# 	Parameter shifts: [1.43484858e+01 9.09429014e-03]
# 	New parameters: [14.34848578 -0.27090571]
# 	Final cost=2.0335e+08 final chisq_red=1199.3 computed in 523.23s
# 2022-06-27 20:47:55  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit.pdf.
# 2022-06-27 20:47:57  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit_2.pdf.
# 2022-06-27 20:56:22  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=2.0335e+08 initial chisq_red=1199.3
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [-23.64712625   0.71944492]
# 	New parameters: [-9.29864047  0.44853921]
# 	Final cost=6.8614e+07 final chisq_red=404.67 computed in 503.61s
# 2022-06-27 20:57:25  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit.pdf.
# 2022-06-27 20:57:27  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit_2.pdf.
# 2022-06-27 21:05:54  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=6.8614e+07 initial chisq_red=404.67
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 3.24703097 -0.09615907]
# 	New parameters: [-6.0516095   0.35238014]
# 	Final cost=6.2643e+07 final chisq_red=369.45 computed in 506.32s
# 2022-06-27 21:07:02  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit.pdf.
# 2022-06-27 21:07:04  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit_2.pdf.
# 2022-06-27 21:15:30  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=6.2643e+07 initial chisq_red=369.45
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.17061744 -0.00648638]
# 	New parameters: [-5.88099206  0.34589376]
# 	Final cost=6.261e+07 final chisq_red=369.26 computed in 505.06s
# 2022-06-27 21:16:33  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit.pdf.
# 2022-06-27 21:16:35  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit_2.pdf.
# 2022-06-27 21:25:02  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=6.261e+07 initial chisq_red=369.26
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.01493905 -0.00048167]
# 	New parameters: [-5.86605301  0.34541209]
# 	Final cost=6.261e+07 final chisq_red=369.26 computed in 505.47s
# 2022-06-27 21:26:06  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit.pdf.
# 2022-06-27 21:26:08  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit_2.pdf.
# 2022-06-27 21:26:09  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 4 iterations because the relative change of cost is below ftol=0.00047176932367149757.
# 2022-06-27 21:26:09  spectractor.fit.fitter print_parameter_summary INFO
# 	shift_y [pix]: -5.866 +0.001 -0.001
# 	angle [deg]: 0.34541 +4e-05 -4e-05
#
# 2022-06-27 21:27:14  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit.pdf.
# 2022-06-27 21:27:16  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure fig_PSF2DtoFFM/ffm_bestfit_2.pdf.
# 2022-06-27 21:27:17  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_PSF2D/20220317/2022031700238/basespec/exposure_2022031600331_postisrccd_spectrum_correlation.pdf.
# 2022-06-27 21:27:17  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure fig_PSF2DtoFFM/parameters_correlation.pdf.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 spectrum = run_ffm_minimisation(w, method="newton", niter=2)
#
# File /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/extractor.py:665, in run_ffm_minimisation(w, method, niter)
#     630 """Interface function to fit spectrogram simulation parameters to data.
#     631
#     632 Parameters
#    (...)
#     662
#     663 """
#     664 my_logger = set_logger(__name__)
# --> 665 w.adjust_spectrogram_position_parameters()
#     667 if method != "newton":
#     668     run_minimisation(w, method=method)
#
# File /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/extractor.py:625, in FullForwardModelFitWorkspace.adjust_spectrogram_position_parameters(self)
#     623 fixed[3:5] = [False, False]  # shift_y and angle
#     624 self.sparse_indices = None
# --> 625 run_minimisation(self, "newton", epsilon, fixed, xtol=1e-4, ftol=100 / self.data.size)
#     626 self.sparse_indices = None
#
# File /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/fit/fitter.py:1372, in run_minimisation(fit_workspace, method, epsilon, fix, xtol, ftol, niter, verbose, with_line_search, minimizer_method)
#    1370 if fit_workspace.filename != "":
#    1371     ipar = np.array(np.where(np.array(fit_workspace.fixed).astype(int) == 0)[0])
# -> 1372     fit_workspace.save_parameters_summary(ipar)
#    1373     save_gradient_descent(fit_workspace, costs, params_table)
#
# File /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/fit/fitter.py:551, in FitWorkspace.save_parameters_summary(self, ipar, header)
#     549     txt += header + "\n"
#     550 for k, ip in enumerate(ipar):
# --> 551     txt += "%s: %s +%s -%s\n" % formatting_numbers(self.p[ip], np.sqrt(self.cov[k, k]),
#     552                                                    np.sqrt(self.cov[k, k]),
#     553                                                    label=self.input_labels[ip])
#     554 for row in self.cov:
#     555     txt += np.array_str(row, max_line_width=20 * self.cov.shape[0]) + '\n'
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
arr = np.arange(10,100,10)
arr
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
for k, ip in enumerate(arr):
    print(k,ip)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 5 60
# 6 70
# 7 80
# 8 90

# %%
assert False

# %%
#w = FullForwardModelFitWorkspace(spectrum=s, amplitude_priors_method="spectrum")

# %%
w = FullForwardModelFitWorkspace(spectrum=s ,amplitude_priors_method="fixed", verbose=True)

# %%
y, mod, mod_err = w.simulate(*w.p)

# %%
w.plot_fit()

# %%
w.adjust_spectrogram_position_parameters()

# %%
w = FullForwardModelFitWorkspace(s, verbose=1, plot=True, live_fit=True, amplitude_priors_method="spectrum")

# %%
s = run_ffm_minimisation(w, method="newton")

# %%
plot_comparison_truth(s,w)
