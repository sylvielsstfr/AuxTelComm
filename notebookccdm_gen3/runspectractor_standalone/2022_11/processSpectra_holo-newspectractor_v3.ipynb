# %% [markdown]
# # process spectra for AuxTel with new spectractor (version=2.1, November 2022) for particular config for Hologram

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : October 31th 2022
# - update : 2022-11-07
#
# - version v3 : Work with exposure butlen gen3
#
# This notebook is to help for finding the position of order 0
#
# CCIN2P3:
#
# - works with kernels **anaconda3_auxtel** (with libradtran) and **anaconda3_auxtel_v2** (no libradtran)
# - works with kernel **python 3** locally

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
print(sys.path)
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_11', '', '/opt/conda/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload', '/pbs/home/d/dagoret/.local/lib/python3.8/site-packages', '/pbs/throng/lsst/users/dagoret/desc/firecrown', '/pbs/throng/lsst/users/dagoret/desc/augur', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/delight-1.0.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/libradtranpy-0.1.0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Django-4.1.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/sqlparse-0.4.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/backports.zoneinfo-0.2.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/asgiref-3.5.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/getCalspec-0.1.4-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coverage-5.6b1-py3.8-linux-x86_64.egg']

# %%
all_paths_to_remove = ['/opt/conda/lib/python3.8/site-packages','/pbs/home/d/dagoret/.local/lib/python3.8/site-packages']

for path_to_remove in all_paths_to_remove:
    if path_to_remove in sys.path:
        print(f"remove {path_to_remove} from sys.path")
        sys.path.remove(path_to_remove)
# Out:
# remove /opt/conda/lib/python3.8/site-packages from sys.path
# remove /pbs/home/d/dagoret/.local/lib/python3.8/site-packages from sys.path

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_11',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/pbs/throng/lsst/users/dagoret/desc/firecrown',
#  '/pbs/throng/lsst/users/dagoret/desc/augur',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/delight-1.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/libradtranpy-0.1.0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Django-4.1.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/sqlparse-0.4.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/backports.zoneinfo-0.2.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/asgiref-3.5.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/getCalspec-0.1.4-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coverage-5.6b1-py3.8-linux-x86_64.egg']

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
from matplotlib import  transforms
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (12,12)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
print(sys.executable)
print(sys.version)
#print(sys.version_info)
# Out:
# /sps/lsst/groups/auxtel/softs/utils/anaconda3/bin/python
# 3.8.13 (default, Oct 21 2022, 23:50:54)
# [GCC 11.2.0]

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_subplot(1,1,1)
X=np.linspace(-10,10,50)
Y=np.sin(X)
ax.plot(X,Y)
plt.show()

# %%
from iminuit import Minuit
import iminuit

# %%
iminuit.__version__
# Out:
# '2.8.4'

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.7.3

# %%
from astropy.io import fits
from astropy.coordinates import Angle
from astropy import units as u
from spectractor import parameters
from spectractor.extractor.extractor import Spectractor,dumpParameters,dumpfitparameters
from spectractor.extractor.images import *
from spectractor.config import load_config, set_logger
from scipy import ndimage, misc
# Out:
# WARNING: AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version. [astroquery._astropy_init]
# 2022-11-07 19:46:14  astropy    _showwarning         WARNING AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version.

# %%
import logging

# %%
from scipy.stats import kurtosis,skew
from scipy.stats import kurtosistest,skewtest,normaltest

# %%
from distutils.dir_util import copy_tree
import shutil

# %% [markdown]
# # Configuration

# %% [markdown]
# ## Logger

# %%
my_logger = logging

# %% [markdown]
# ## Config for the notebook

# %%
version="v5.0"  # version of flipping
# create output directories if not exist and clean existing files
FLAG_MANAGE_OUTPUT_SPECTRACTOR=True
# allow to run reconstruction with Spectractor
FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR=True
FLAG_RUNWITHEXCEPTIONS = False

# %% [markdown]
# ## Configuration for Spectractor

# %%
print("List of configuration files available : ",os.listdir("config"))
# Out:
# List of configuration files available :  ['auxtel_config_holo_DECONVOLUTION_REBIN2FFMvNov2022.ini', '.ipynb_checkpoints', 'auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini']

# %%
# Choose the config filename
list_of_spectractorconfigfiles= ['auxtel_config_holo_DECONVOLUTION_PSF1D.ini' ,
                                 'auxtel_config_holo_DECONVOLUTION_PSF2D.ini',
                                 'auxtel_config_holo_DECONVOLUTION_FFM.ini',
                                 'auxtel_config_holo_DECONVOLUTION_PSF2DFFM.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1D.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2FFM.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DFFM300650.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF2D.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotA.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotB.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotC.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotD.ini',
                                 'auxtel_config_holo_DECONVOLUTION_PSF1D_BG40.ini',
                                 'auxtel_config_holo_DECONVOLUTION_PSF1DTRUNC.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2FFMvNov2022.ini',
                                 'auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini']

config_idx = len(list_of_spectractorconfigfiles)-1
                                
configfilename= os.path.join("./config",list_of_spectractorconfigfiles[config_idx])
#configdir = (list_of_spectractorconfigfiles[config_idx].split("_")[-1]).split(".") [0]
configdir = "config_" + (list_of_spectractorconfigfiles[config_idx].split("auxtel_config_holo_")[-1]).split(".") [0]

# %%
configfilename
# Out:
# './config/auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini'

# %%
configdir
# Out:
# 'config_DECONVOLUTION_FFMvNov2022'

# %%
! pwd
# Out:
# /pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_11

# %%
config=configfilename
print(f">>>>> Spectractor configuration filename : {configfilename}")
# Out:
# >>>>> Spectractor configuration filename : ./config/auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini

# %%
load_config(configfilename)
# Out:
# No rebinning: parameters.REBIN is forced to 1.

# %%
dumpParameters()
# Out:
# ASTROMETRYNET_DIR
# BGD_ORDER 1
# CALIB_BGD_NPARAMS 4
# CALIB_BGD_ORDER 3
# CALIB_BGD_WIDTH 15
# CALIB_PEAK_WIDTH 7
# CALIB_SAVGOL_ORDER 2
# CALIB_SAVGOL_WINDOW 5
# CCD_ARCSEC2RADIANS 4.84813681109536e-06
# CCD_GAIN 1.1
# CCD_IMSIZE 4096
# CCD_MAXADU 170000
# CCD_PIXEL2ARCSEC 0.0952
# CCD_PIXEL2MM 0.01
# CCD_REBIN 1
# CONFIG_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/../config/
# DEBUG False
# DEBUG_LOGGING False
# DISPERSER_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/
# DISPLAY False
# DISTANCE2CCD 181
# DISTANCE2CCD_ERR 0.4
# FGB37 {'label': 'FGB37', 'min': 350, 'max': 750}
# FILTERS [{'label': 'RG715', 'min': 690, 'max': 1100}, {'label': 'FGB37', 'min': 350, 'max': 750}, {'label': 'Halfa', 'min': 0.0006431, 'max': 0.0006686999999999999}, {'label': 'Z-Gunn', 'min': 800, 'max': 1100}]
#   944  945  946  947  948  949  950  951  952  953  954  955  956  957
#   958  959  960  961  962  963  964  965  966  967  968  969  970  971
#   972  973  974  975  976  977  978  979  980  981  982  983  984  985
#   986  987  988  989  990  991  992  993  994  995  996  997  998  999
#  1000 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013
#  1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027
#  1028 1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041
#  1042 1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055
#  1056 1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068 1069
#  1070 1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082 1083
#  1084 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096 1097
#  1098 1099]
# LAMBDA_CONSTRUCTOR 0.000639
# LAMBDA_MAX 1100
# LAMBDA_MIN 300
# LAMBDA_STEP 0.2
# LIBRADTRAN_DIR
# LINEWIDTH 2
# MY_FORMAT %(asctime)-20s %(name)-10s %(funcName)-20s %(levelname)-6s %(message)s
# OBS_ALTITUDE 2.66299616375123
# OBS_CAMERA_DEC_FLIP_SIGN 1
# OBS_CAMERA_RA_FLIP_SIGN 1
# OBS_CAMERA_ROTATION 0
# OBS_DIAMETER 1.2 m
# OBS_EPOCH J2000.0
# OBS_FULL_INSTRUMENT_TRANSMISSON multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_LATITUDE -30.2446389756252
# OBS_NAME AUXTEL
# OBS_OBJECT_TYPE STAR
# OBS_QUANTUM_EFFICIENCY multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_SURFACE 1.1309733552923256 m2
# OBS_TELESCOPE_TRANSMISSION multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_TRANSMISSION_SYSTEMATICS 0.005
# PAPER False
# PIXDIST_BACKGROUND 140
# PIXSHIFT_PRIOR 5
# PIXWIDTH_BACKGROUND 40
# PIXWIDTH_BOXSIZE 20
# PIXWIDTH_SIGNAL 20
# PLATE_CENTER_SHIFT_X -6.0
# PLATE_CENTER_SHIFT_X_ERR 2.0
# PLATE_CENTER_SHIFT_Y -8.0
# PLATE_CENTER_SHIFT_Y_ERR 2.0
# PLOT_DIR plots
# PLOT_ROT_LABEL $\alpha$ [degrees]
# PLOT_XLABEL $x$ [pixels]
# PLOT_YLABEL $y$ [pixels]
# PSF_FIT_REG_PARAM 0.1
# PSF_FWHM_CLIP 2
# PSF_PIXEL_STEP_TRANSVERSE_FIT 50
# PSF_POLY_ORDER 2
# PSF_TYPE MoffatGauss
# RG715 {'label': 'RG715', 'min': 690, 'max': 1100}
# ROT_ANGLE_MAX 10
# ROT_ANGLE_MIN -10
# ROT_ORDER 5
# ROT_PREFILTER True
# SAVE False
# SED_UNIT 1.0 erg / (cm2 nm s)
# SPECTRACTOR_COMPUTE_ROTATION_ANGLE disperser
# SPECTRACTOR_DECONVOLUTION_FFM True
# SPECTRACTOR_DECONVOLUTION_PSF2D False
# SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP 100
# SPECTRACTOR_FIT_TARGET_CENTROID fit
# SPEC_ORDER 1
# THROUGHPUT_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/
# TIME_UNIT 1.0 s
# VERBOSE False
# XWINDOW 100
# XWINDOW_ROT 50
# YWINDOW 100
# YWINDOW_ROT 50
# ZGUNN {'label': 'Z-Gunn', 'min': 800, 'max': 1100}
# const <module 'astropy.constants' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astropy/constants/__init__.py'>
# hc 1.9864458571489286e-25 J m
# mpl <module 'matplotlib' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py'>
# mypath /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor
# np <module 'numpy' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/numpy/__init__.py'>
# os <module 'os' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/os.py'>
# units <module 'astropy.units' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astropy/units/__init__.py'>
# wl_dwl_unit nm2

# %% [markdown]
# # Exposure config

# %%
! ls logbooks
# Out:
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.csv
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.xlsx

# %%
# path index for each month
DATE="20211103"
#DATE="20211104"
#filterdispersername = "empty~holo4_003"
#filterdispersername = "BG40~holo4_003"
filterdispersername = "FELH0600~holo4_003"
imagemode = "postISRCCD"
#imagemode = "unflattened"

# %%
disperser_label = filterdispersername.split("~")[-1]

# %% [markdown]
# ## Paths

# %%
# select if we run at CC or not (locally) 
# /sps/lsst/groups/auxtel/data/2022/holo/20220317
HOSTCC=True
LAPTOP=False

# %%
# Set path depending on which computer running (according HOSTCC)
if HOSTCC:
    path_auxtel="/sps/lsst/groups/auxtel"
    path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
        path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
        path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)

else:
    if not LAPTOP:
        path_auxtel="/Users/sylvie/DATA/AuxTelData2022"
        path_spectractor=os.path.join(path_auxtel,"/Users/sylvie/MacOSX/GitHub/LSST/Spectractor")
        path_spectractor_config=os.path.join(path_spectractor,"config")
        path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)
    else:
        path_auxtel="/Users/dagoret/DATA/AuxTelData2022"
        path_spectractor=os.path.join(path_auxtel,"/Users/dagoret/MacOSX/GitHub/LSST/Spectractor")
        path_spectractor_config=os.path.join(path_spectractor,"config")
        path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)

# %%
path_images
# Out:
# '/sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103'

# %%
path_topoutput_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022'

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103'

# %% [markdown]
# # Utility Functions

# %%
def is_nan(x):
    return (x != x)

# %% [markdown]
# # Logbook for input file selection
#
# - the logbook contains all input image path and possibily the order 0 position

# %%
# !ls logbooks
# Out:
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.csv
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.xlsx

# %%
filename_logbook='logbooks/auxtellogbook_'+filterdispersername+"_"+DATE+'_' + version+'.csv'

# %%
filename_logbook
# Out:
# 'logbooks/auxtellogbook_FELH0600~holo4_003_20211103_v5.0.csv'

# %%
df=pd.read_csv(filename_logbook,index_col=0)

# %%
pd.set_option('display.max_rows', None)

# %%
# show the list of input files from the logbook to select the file index in the logbook
df
# Out:
#     index                     date  \
# 0       0  2021-11-04T05:07:43.370
# 1       1  2021-11-04T05:08:20.217
# 2       2  2021-11-04T05:08:54.415
# 3       3  2021-11-04T05:11:43.527
# 4       4  2021-11-04T05:12:19.215
# 5       5  2021-11-04T05:12:52.522
# 6       6  2021-11-04T05:17:12.323
# 7       7  2021-11-04T05:17:52.968
# 8       8  2021-11-04T05:25:31.608
# 9       9  2021-11-04T05:29:35.261
# 10     10  2021-11-04T05:33:38.278
# 11     11  2021-11-04T05:37:46.464
# 12     12  2021-11-04T05:41:49.637
# 13     13  2021-11-04T05:45:53.070
# 14     14  2021-11-04T05:50:02.060
# 20  exposure_2021110300534_postisrccd.fits  534  HD 38666  FELH0600
# 21  exposure_2021110300540_postisrccd.fits  540  HD 38666  FELH0600
# 22  exposure_2021110300552_postisrccd.fits  552  HD 38666  FELH0600
# 23  exposure_2021110300553_postisrccd.fits  553  HD 38666  FELH0600
# 24  exposure_2021110300559_postisrccd.fits  559  HD 38666  FELH0600
# 25  exposure_2021110300565_postisrccd.fits  565  HD 38666  FELH0600
# 26  exposure_2021110300571_postisrccd.fits  571  HD 38666  FELH0600
# 27  exposure_2021110300577_postisrccd.fits  577  HD 38666  FELH0600
# 28  exposure_2021110300583_postisrccd.fits  583  HD 38666  FELH0600
# 29  exposure_2021110300589_postisrccd.fits  589  HD 38666  FELH0600
# 30  exposure_2021110300595_postisrccd.fits  595  HD 38666  FELH0600
# 31  exposure_2021110300601_postisrccd.fits  601  HD 38666  FELH0600
# 32  exposure_2021110300607_postisrccd.fits  607  HD 38666  FELH0600
# 33  exposure_2021110300613_postisrccd.fits  613  HD 38666  FELH0600
# 34  exposure_2021110300694_postisrccd.fits  694  HD 38666  FELH0600
# 35  exposure_2021110300700_postisrccd.fits  700  HD 38666  FELH0600
# 36  exposure_2021110300706_postisrccd.fits  706  HD 38666  FELH0600
# 37  exposure_2021110300712_postisrccd.fits  712  HD 38666  FELH0600
# 38  exposure_2021110300718_postisrccd.fits  718  HD 38666  FELH0600
# 39  exposure_2021110300724_postisrccd.fits  724  HD 38666  FELH0600
# 40  exposure_2021110300730_postisrccd.fits  730  HD 38666  FELH0600
# 41  exposure_2021110300736_postisrccd.fits  736  HD 38666  FELH0600
# 42  exposure_2021110300742_postisrccd.fits  742  HD 38666  FELH0600
#
#     disperser   airmass  exposure  ...  temperature  humidity  windspd  \
# 0   holo4_003  1.154825       2.0  ...          7.2      33.0      6.8
# 1   holo4_003  1.153394       2.0  ...          7.2      34.0      4.8
# 2   holo4_003  1.151521       2.0  ...          7.2      34.0      6.0
# 3   holo4_003  1.145281       1.0  ...          7.2      33.0      6.3
# 4   holo4_003  1.144045       1.0  ...          7.2      33.0      6.4
# 5   holo4_003  1.142759       1.0  ...          7.2      33.0      6.7
# 6   holo4_003  1.148628       1.0  ...          7.3      33.0      6.3
# 7   holo4_003  1.147130       1.0  ...          7.3      34.0      6.2
# 8   holo4_003  1.129715      30.0  ...          7.3      31.0      5.8
# 9   holo4_003  1.121020      30.0  ...          7.4      32.0      5.8
# 10  holo4_003  1.112729      30.0  ...          7.3      33.0      6.4
# 11  holo4_003  1.104633      30.0  ...          7.3      33.0      5.3
# 12  holo4_003  1.097056      30.0  ...          7.2      32.0      5.9
# 13  holo4_003  1.089817      30.0  ...          7.4      29.0      6.4
# 14  holo4_003  1.082750      30.0  ...          7.5      27.0      5.8
# 15  holo4_003  1.076182      30.0  ...          7.5      30.0      6.7
# 16  holo4_003  1.069920      30.0  ...          7.4      32.0      6.6
# 17  holo4_003  1.063292      30.0  ...          7.4      28.0      6.4
# 18  holo4_003  1.057678      30.0  ...          7.4      30.0      5.8
# 19  holo4_003  1.052357      30.0  ...          7.3      32.0      6.6
# 20  holo4_003  1.047237      30.0  ...          7.4      33.0      6.6
# 21  holo4_003  1.042495      30.0  ...          7.4      32.0      7.5
# 22  holo4_003  1.027853       1.0  ...          7.6      27.0      7.6
# 23  holo4_003  1.027286       1.0  ...          7.6      27.0     14.6
# 24  holo4_003  1.022363      30.0  ...          7.7      24.0      8.2
# 25  holo4_003  1.019248      30.0  ...          7.6      23.0      8.1
# 26  holo4_003  1.016383      30.0  ...          7.8      24.0      7.9
# 27  holo4_003  1.013720      30.0  ...          7.7      24.0      7.3
# 28  holo4_003  1.011346      30.0  ...          7.6      23.0      8.9
# 29  holo4_003  1.009234      30.0  ...          7.7      22.0      6.4
# 30  holo4_003  1.007330      30.0  ...          7.7      27.0      7.0
# 31  holo4_003  1.005678      30.0  ...          7.5      25.0      8.4
# 32  holo4_003  1.004261      30.0  ...          7.6      23.0      7.5
# 33  holo4_003  1.001928      30.0  ...          7.5      25.0      7.0
# 34  holo4_003  1.018841      30.0  ...          7.4      26.0      7.4
# 35  holo4_003  1.021924      30.0  ...          7.5      24.0     12.8
# 36  holo4_003  1.025256      30.0  ...          7.4      24.0      6.7
# 37  holo4_003  1.028908      30.0  ...          7.4      26.0      6.1
# 38  holo4_003  1.032791      30.0  ...          7.5      26.0      5.8
# 39  holo4_003  1.036875      30.0  ...          7.4      25.0      5.7
# 40  holo4_003  1.041304      30.0  ...          7.2      27.0      5.0
# 41  holo4_003  1.045928      30.0  ...          7.4      25.0      4.6
# 42  holo4_003  1.050899      30.0  ...          7.6      24.0      5.6
#
#     Obj-posXpix  Obj-posYpix  Dx  Dy  skip  run  quality
# 0           NaN          NaN NaN NaN        NaN      NaN
# 1           NaN          NaN NaN NaN        NaN      NaN
# 2           NaN          NaN NaN NaN        NaN      NaN
# 3           NaN          NaN NaN NaN        NaN      NaN
# 4           NaN          NaN NaN NaN        NaN      NaN
# 5           NaN          NaN NaN NaN        NaN      NaN
# 6           NaN          NaN NaN NaN        NaN      NaN
# 7           NaN          NaN NaN NaN        NaN      NaN
# 8           NaN          NaN NaN NaN        NaN      NaN
# 9           NaN          NaN NaN NaN        NaN      NaN
# 10          NaN          NaN NaN NaN        NaN      NaN
# 11          NaN          NaN NaN NaN        NaN      NaN
# 12          NaN          NaN NaN NaN        NaN      NaN
# 13          NaN          NaN NaN NaN        NaN      NaN
# 14          NaN          NaN NaN NaN        NaN      NaN
# 15          NaN          NaN NaN NaN        NaN      NaN
# 16          NaN          NaN NaN NaN        NaN      NaN
# 17          NaN          NaN NaN NaN        NaN      NaN
# 18          NaN          NaN NaN NaN        NaN      NaN
# 19          NaN          NaN NaN NaN        NaN      NaN
# 20          NaN          NaN NaN NaN        NaN      NaN
# 21          NaN          NaN NaN NaN        NaN      NaN
# 22          NaN          NaN NaN NaN        NaN      NaN
# 23          NaN          NaN NaN NaN        NaN      NaN
# 24          NaN          NaN NaN NaN        NaN      NaN
# 25          NaN          NaN NaN NaN        NaN      NaN
# 26          NaN          NaN NaN NaN        NaN      NaN
# 27          NaN          NaN NaN NaN        NaN      NaN
# 28          NaN          NaN NaN NaN        NaN      NaN
# 29          NaN          NaN NaN NaN        NaN      NaN
# 30          NaN          NaN NaN NaN        NaN      NaN
# 31          NaN          NaN NaN NaN        NaN      NaN
# 32          NaN          NaN NaN NaN        NaN      NaN
# 33          NaN          NaN NaN NaN        NaN      NaN
# 34          NaN          NaN NaN NaN        NaN      NaN
# 35          NaN          NaN NaN NaN        NaN      NaN
# 36          NaN          NaN NaN NaN        NaN      NaN
# 37          NaN          NaN NaN NaN        NaN      NaN
# 38          NaN          NaN NaN NaN        NaN      NaN
# 39          NaN          NaN NaN NaN        NaN      NaN
# 40          NaN          NaN NaN NaN        NaN      NaN
# 41          NaN          NaN NaN NaN        NaN      NaN
# 42          NaN          NaN NaN NaN        NaN      NaN
#
# [43 rows x 23 columns]

# %% [markdown]
# # Selection of input file
# - the input file is selected from the logbook list above

# %%
idx=4

# %%
print(df.iloc[idx]['file'])
# Out:
# exposure_2021110300452_postisrccd.fits

# %%
print(df.iloc[idx])
# Out:
# index                                                          4
# date                                     2021-11-04T05:12:19.215
# path           /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# file                      exposure_2021110300452_postisrccd.fits
# num                                                          452
# object                                                  HD 37795
# filter                                                  FELH0600
# disperser                                              holo4_003
# airmass                                                 1.144045
# exposure                                                     1.0
# focus                                                   0.043359
# seeing                                                  0.943947
# pressure                                                   740.4
# temperature                                                  7.2
# humidity                                                    33.0
# windspd                                                      6.4
# Obj-posXpix                                                  NaN
# Obj-posYpix                                                  NaN
# Dx                                                           NaN
# Dy                                                           NaN
# skip
# run                                                          NaN
# quality                                                      NaN
# Name: 4, dtype: object

# %%
myhome=os.getenv("HOME")

# %%
dir_images=path_images

# %%
dir_images
# Out:
# '/sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103'

# %%
filename_image=df['file'][idx]
filename_image
# Out:
# 'exposure_2021110300452_postisrccd.fits'

# %%
target = df['object'][idx]
target
# Out:
# 'HD 37795'

# %% [markdown]
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

# %%
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

x0=300
y0=1700

if 'Obj-posXpix' in df.columns and 'Obj-posYpix' in df.columns:
    thex0 = df['Obj-posXpix'][idx]
    if not is_nan(thex0):
        x0=thex0
    they0 = df['Obj-posYpix'][idx]
    if not is_nan(they0):
        y0=they0
    
if not is_nan(x0) and not is_nan(y0):

    print("Order 0 location from logbook : ({},{})".format(x0,y0))
else:
    print("NO Order 0 location from logbook ! ")      

print(f"guess (x0,y0) = ({x0},{y0})")
# Out:
# Order 0 location from logbook : (300,1700)
# guess (x0,y0) = (300,1700)

# %% [markdown]
# ## Spectractor Configuration
#
# - Usually the Spectractor configuration file is put in local dir **./config**
#
#
# Ma suggestion, pour l'étude du centre optique via les scans des hologrammes, est de **mettre SPECTRACTOR_COMPUTE_ROTATION_ANGLE sur False** .
#
# Comme les angles ne sont pas très grands, si les marges du rectangle sont assez larges, réglables avec :
#
#     [background subtraction parameters]
#     # half transverse width of the signal rectangular window in pixels
#     PIXWIDTH_SIGNAL = 40
#
# alors le spectrogramme devrait tenir dans une boite rectangulaire même sans rotation de l'image. **L'important est de garder SPECTRACTOR_DECONVOLUTION_FFM à True car c'est lui qui te donnera l'angle de l'axe de dispersion ajusté sur les données, dont la valeur sera dans le mot clé ROTANGLE du header de sortie**.

# %%
rootfilename = filename_image.split(".")[0]
rootfilename_split =  rootfilename.split("_") 
filenumberdir = rootfilename_split[1]

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103'

# %%
configdir
# Out:
# 'config_DECONVOLUTION_FFMvNov2022'

# %%
# Fullfilename
filename=os.path.join(dir_images,filename_image)


# subdirectory
#subdir=filename_image.split(".")[0]
subdir=filenumberdir

# final output directory (where results will be copied to be backed up at the end)
finalpath_output_spectractor=os.path.join(path_output_spectractor,subdir)


# local directories to put spectra and plots
    
if configdir =="":
    output_directory="./outputs_process_" + DATE  + '_' + dispersername +'_nb_' + str(idx+1)
    output_figures="figures_process_" + DATE + '_' + dispersername + '_nb_' + str(idx+1)
else:
    output_directory = "./outputs_process_"+ DATE +"_"+ filterdispersername + "_" + configdir + "_nb_" + str(idx+1)
    output_figures   = "./figures_process_"+ DATE +"_"+ filterdispersername + "_" + configdir + "_nb_" + str(idx+1)
    
    

#guess = [300,1700]
guess = [350,1700]

# configuration

config=configfilename    
target=df.iloc[idx]["object"]

# %%
print(f"finalpath_output_spectractor = {finalpath_output_spectractor}")
print(f"output_directory = {output_directory}")
print(f"output_figures = {output_figures}")
print(f"config filename = {config}")
# Out:
# finalpath_output_spectractor = /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452
# output_directory = ./outputs_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5
# output_figures = ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5
# config filename = ./config/auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini

# %%
def cleandir(path):
    if os.path.isdir(path):
        files=os.listdir(path)
        if len(files) > 0:
            for f in files:
                if os.path.isdir(os.path.join(path,f)):
                    if f==".ipynb_checkpoints":
                        shutil.rmtree(os.path.join(path,f))
                    else:
                        print(" Cannot remove this directory {}".format(os.path.join(path,f)))
                else:
                    os.remove(os.path.join(path,f))

# %%
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
else:
    cleandir(output_directory)
 
# manage subdirs spectrum/ and plots/
if not os.path.isdir(output_figures):
    os.mkdir(output_figures)
else:
    cleandir(output_figures)

# %% [markdown]
# # Configuration of the Spectractor running mode

# %%
parameters.LSST_SAVEFIGPATH=True
parameters.LSST_SAVEFIGPATH=output_figures

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

# %%
target
# Out:
# 'HD 37795'

# %%
#target_name_stripped = target.replace(" ", "")
target_name_stripped = ''.join(target.split())
target_name_stripped
# Out:
# 'HD37795'

# %% [markdown]
# ## Load the image in the new image file with Spectractor

# %%
image=Image(file_name=filename, disperser_label=disperser_label,target_label=target_name_stripped, config=config)
# Out:
# No rebinning: parameters.REBIN is forced to 1.
# 2022-11-07 19:46:41  Image      check_statistical_error WARNING
# 	Fitted read out noise seems to be different than input readout noise. Fit=8.33086466869782 but average of self.read_out_noise is 8.5.
# WARNING: AstropyDeprecationWarning: "pedantic" was deprecated in version 5.0 and will be removed in a future version. Use argument "verify" instead. [astropy.io.votable.table]
# 2022-11-07 19:46:42  astropy    _showwarning         WARNING AstropyDeprecationWarning: "pedantic" was deprecated in version 5.0 and will be removed in a future version. Use argument "verify" instead.

# %%
image.data.shape
# Out:
# (4072, 4000)

# %% [markdown]
# ## Show relevant parameters

# %%
parameters.LSST_SAVEFIGPATH=True
parameters.LSST_SAVEFIGPATH=output_figures

# %%
image.header["FILTER"]
# Out:
# 'FELH0600'

# %%
image.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'LSST DM Header Service'
# TIMESYS = 'TAI     '
# DATE    = '2021-11-04T05:11:46.140'
# DATE-OBS= '2021-11-04T05:11:46.140'
# DATE-BEG= '2021-11-04T05:12:19.215'
# DATE-END= '2021-11-04T05:12:20.455'
# MJD     =     59522.2165062475
# MJD-OBS =      59522.216889068
# MJD-BEG =      59522.216889068
# MJD-END =     59522.2169034091
# OBSID   = 'AT_O_20211103_000452'
# GROUPID = '2021-11-04T05:12:14.029'
# IMGTYPE = 'OBJECT  '
# BUNIT   = 'adu     '
# FACILITY= 'Vera C. Rubin Observatory'
# TELESCOP= 'LSST AuxTelescope'
# INSTRUME= 'LATISS  '
# OBSERVER= 'LSST    '
# OBS-LONG=   -70.74941699999999
# OBS-LAT =           -30.244639
# OBS-ELEV=               2663.0
# OBSGEO-X=           1818938.94
# OBSGEO-Y=          -5208470.95
# OBSGEO-Z=          -3195172.08
# RA      =     84.9122541666667
# DEC     =    -34.0741094444444
# RASTART =     84.9253860670668
# DECSTART=    -34.0390789585719
# RAEND   =     84.9255030404665
# DECEND  =     -34.039355454217
# ROTPA   =     357.965340622756
# ROTCOORD= 'sky     '
# HASTART =    -2.28518844095587
# ELSTART =     60.9040281756752
# AZSTART =     106.492345262785
# AMSTART =     1.14404546360107
# HAEND   =    -2.28412793304412
# ELEND   =     60.9177834375732
# AZEND   =     106.491889287252
# AMEND   =     1.14389949446159
# INSTPORT=                    2
# ATM3PORT=                    2
# TRACKSYS= 'SIDEREAL'
# FOCUSZ  =   0.0433590225875378
# OBJECT  = 'HD 37795'
# DOMEAZ  =               103.91
# SHUTLOWR=                  0.0
# SHUTUPPR=                100.0
# CAMCODE = 'AT      '
# CONTRLLR= 'O       '
# DAYOBS  = '20211103'
# SEQNUM  =                  452
# TESTTYPE=
# EMUIMAGE= ''
# TSTAND  =
# IMAGETAG= 'd684620597fbff12'
# OBSANNOT= ''
# TEMP_SET=   -94.15000152587891
# CCDTEMP =    -90.2656173706055
# FILTBAND= 'Empty   '
# FILTER  = 'FELH0600'
# FILTSLOT=                    3
# GRATING = 'holo4_003'          / name of the disperser
# GRATBAND= 'Empty   '
# GRATSLOT=                    3
# LINSPOS =    67.99900054931641
# EXPTIME =                  1.0
# SHUTTIME=
# DARKTIME=     1.32709193229675
# AIRTEMP =                  7.2
# PRESSURE=                740.4
# HUMIDITY=                 33.0
# WINDSPD =                  6.4
# WINDDIR =                319.0
# SEEING  =    0.943946897983551
# FILENAME= 'AT_O_20211103_000452.fits'
# HEADVER = '2.9.2   '
# CHECKSUM=
# DATASUM =
# CCD_MANU= 'ITL     '
# CCD_TYPE=                    2
# CCD_SERN= '20862   '
# LSST_NUM= 'ITL-3800C-068'
# SEQCKSUM= '2552520002'
# SEQNAME = 'FP_ITL_2s_ir2_v25.seq'
# REBNAME = 'Unknown '
# CONTNUM = '412227310'
# CCDSLOT = 'S00     '
# RAFTBAY = 'R00     '
# OVERH   =                   64
# OVERV   =                   48
# PREH    =                    0
# INHERIT =                    T
# EXTNAME = 'Segment10'
# DATASEC = '[1:509,1:2000]'
# DETSEC  = '[509:1,1:2000]'
# DETSIZE = '[1:4072,1:4000]'
# DTV1    =                  510
# DTV2    =                    0
# DTM1_1  =                 -1.0
# DTM2_2  =                  1.0
# DTM1_2  =                    0
# DTM2_1  =                    0
# HIERARCH ASTRO METADATA FIX MODIFIED = T
# HIERARCH ASTRO METADATA FIX DATE = '2022-10-30T20:40:21.487894'
# HIERARCH ASTRO METADATA FIX VERSION = 'g66e8411885+78f5e69161'
# HA      =   -2.284658186999995
# CAM_ROT =     -87.965340622756
# PARANGLE=   -92.03361550892801 / parallactic angle in degree
# AIRMASS =     1.14397247903133
# OUTTEMP =                  7.2
# OUTPRESS=                740.4
# OUTHUM  =                 33.0
# CCDREBIN=                    1
# TARGET  = 'HD 37795'           / name of the target in the image
# REDSHIFT= '0.000117'           / redshift of the target
# ROTANGLE=                    0 / [deg] angle of the dispersion axis
# D2CCD   =    180.9990005493164 / [mm] distance between disperser and CCD
# COMMENT ["  FITS (Flexible Image Transport System) format is defined in 'Astrono
# COMMENT my", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376.
# COMMENT .359H", "= '        '", '---- Date, night and basic image information --
# COMMENT --', "= '        '", '---- Telescope info, location, observer ----', "=
# COMMENT '        '", '---- Pointing info, etc. ----', "= '        '", '---- TAN
# COMMENT Projection ----', "= '        '", '---- Image-identifying used to build
# COMMENT OBS-ID ----', "= '        '", '---- Test Stand information ----', "= '
# COMMENT       '", '---- Information from Camera (Common block) ----', "= '
# COMMENT   '", '---- Information from Camera ----', "= '        '", '---- Filter/
# COMMENT grating information ----', "= '        '", '---- Exposure-related inform
# COMMENT ation ----', "= '        '", '---- Weather information ----', "= '
# COMMENT   '", '---- Header information ----', "= '        '", '---- Checksums --
# COMMENT --', '---- Information from Camera per sensor ----', "= '        '", '--
# COMMENT -- Geometry from Camera ----']

# %% [markdown]
# # Plot image and find the target position
#
# - this image plotting is used to find the order 0 location to be set in logbook
#
# - for the moment this is humanly done

# %% [markdown]
# ## Load the new image file with Spectractor

# %%
import matplotlib.pyplot as plt
title="{}) {}".format(idx,filename_image)
image.plot_image(figsize=(12, 10),scale="log",title=title)
plt.show()

# %% [markdown]
# - note now the position are written in the make_logbook.ipynb notebook

# %% [markdown]
# ## Set the 0th order location to be provided to Spectractor

# %%
filename_image
# Out:
# 'exposure_2021110300452_postisrccd.fits'

# %% [markdown]
# ## Let Spectractor find the location of the 0th order

# %%
parameters.VERBOSE = True
parameters.DEBUG = True
#x1, y1 = find_target(image, guess,rotated=False, use_wcs=False)
x1, y1 = find_target(image, guess,rotated=False)
# Out:
# 2022-11-07 19:46:52  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                c1_0                c0_1
#     ------------------ ------------------- -------------------
#     406.51819811649364 -1.2589398390529452 -0.2919122341189143
# 2022-11-07 19:46:57  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 18 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-11-07 19:46:57  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 4 iterations because the relative change of cost is below ftol=5e-05.

# %%
print(x1,y1)
# Out:
# 327.9338293319683 1696.1159905705304

# %% [markdown]
# ## Check the location of 0th order and Analysis of the quality of its focus

# %%
if x1>100:
    WID=100
else:
    WID=50
    

thumbnail=np.copy(image.data[int(y1)-WID:int(y1)+WID,int(x1)-WID:int(x1)+WID])
thumbnail_y=thumbnail.sum(axis=1)
thumbnail_x=thumbnail.sum(axis=0)
xx=np.linspace(int(x1)-WID,int(x1)+WID,len(thumbnail_x))
yy=np.linspace(int(y1)-WID,int(y1)+WID,len(thumbnail_y))
k0=kurtosis(thumbnail,axis=None,bias=True,fisher=True)
kx=kurtosis(thumbnail_x,bias=True,fisher=True)
ky=kurtosis(thumbnail_y,bias=True,fisher=True)
s0=skew(thumbnail,axis=None,bias=True)
sx=skew(thumbnail_x,bias=True)
sy=skew(thumbnail_y,bias=True)

# %%
shape_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}, Skx = {:3.3f}, Sky = {:3.3f} \n'.format(s0,sx,sy),
        r'kurtosis : K0  = {:3.3f}, Kx  = {:3.3f},  Ky = {:3.3f}'.format(k0,kx,ky)))

# %%
skew_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}'.format(s0),
        r'             : Skx = {:3.3f}'.format(sx),
        r'             : Sky = {:3.3f}'.format(sy)))

# %%
kurt_str='\n'.join((
        r'kurtosis : K0 = {:3.3f}'.format(k0),
        r'             : Kx = {:3.3f}'.format(kx),
        r'             : Ky = {:3.3f}'.format(ky)))

# %%
kurtosis_test_prob=kurtosistest(thumbnail,axis=None).pvalue
skew_test_prob=skewtest(thumbnail,axis=None).pvalue
normal_test_prob=normaltest(thumbnail,axis=None).pvalue

# %%
kurtosis_test_val=kurtosistest(thumbnail,axis=None).statistic
skew_test_val=skewtest(thumbnail,axis=None).statistic
normal_test_val=normaltest(thumbnail,axis=None).statistic

# %%
kurtosis_test_prob_x=kurtosistest(thumbnail_x).pvalue
skew_test_prob_x=skewtest(thumbnail_x).pvalue
normal_test_prob_x=normaltest(thumbnail_x).pvalue

# %%
kurtosis_test_prob_y=kurtosistest(thumbnail_y).pvalue
skew_test_prob_y=skewtest(thumbnail_y).pvalue
normal_test_prob_y=normaltest(thumbnail_y).pvalue

# %%
skew_str='\n'.join((
    r'skew     : Sk0 = {:3.3f}'.format(s0),
    r'             : Skx = {:3.3f}'.format(sx),
    r'             : Sky = {:3.3f}'.format(sy),
    r'             : p_test   = {:3.3e}'.format(skew_test_prob),
    r'             : p_test_x = {:3.3e}'.format(skew_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(skew_test_prob_y)))

# %%
kurt_str='\n'.join((
    r'kurtosis : K0 = {:3.3f}'.format(k0),
    r'             : Kx = {:3.3f}'.format(kx),
    r'             : Ky = {:3.3f}'.format(ky),
    r'             : p_test   = {:3.3e}'.format(kurtosis_test_prob),
    r'             : p_test_x = {:3.3e}'.format(kurtosis_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(kurtosis_test_prob_y)))

# %%
norm_str='\n'.join((
    r'normal  : p_test   = {:3.3e}'.format(normal_test_prob),
    r'             : p_test_x = {:3.3e}'.format(normal_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(normal_test_prob_y)))

# %%
props = dict(boxstyle='round',edgecolor="w",facecolor="w", alpha=0.5)

# %%
#matplotlib.pyplot.hist(x, 
#                       bins=10, 
#                       range=None, 
#                       normed=False, 
#                       weights=None, 
#                       cumulative=False, 
#                       bottom=None, 
#                       histtype=u'bar', 
#                       align=u'mid', 
#                       orientation=u'vertical', 
#                       rwidth=None, 
#                       log=False, 
#                       color=None, 
#                       label=None, 
#                       stacked=False, 
#                       hold=None, 
#                       **kwargs)

# %%
fig=plt.figure(figsize=(10,10))
fig.subplots_adjust(left=0.12, right=0.95, wspace=0.3,
                    bottom=0.15, top=0.9)

ax=fig.add_subplot(222)
ax.imshow(thumbnail,origin="lower",extent=(int(x1)-WID,int(x1)+WID,int(y1)-WID,int(y1)+WID))
ax.set_xlabel("X")
ax.set_ylabel("Y")

ax=fig.add_subplot(221)
base = plt.gca().transData
rot = transforms.Affine2D().rotate_deg(-90)
#ax.plot(yy,thumbnail_y,"g",rotation=u'vertical')
ax.plot(-yy,thumbnail_y,"g",transform= rot + base)
ax.set_ylabel("Y")

ax=fig.add_subplot(224)
ax.plot(xx,thumbnail_x,"b")
ax.set_xlabel("X")
plt.tight_layout()

ax=fig.add_subplot(223)
ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_yticks([])

ax.text(0.05, 0.9, skew_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.55, kurt_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.2, norm_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
plt.suptitle(title)
# Out:
# Text(0.5, 0.98, '4) exposure_2021110300452_postisrccd.fits')

# %%
# Usually stop here if one just want to get the 0th order location
if not FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR:
    assert False
else:
    assert True

# %% [markdown]
# # Go for spectrum reconstruction

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

parameters.DEBUG=True
parameters.VERBOSE=True
parameters.DISPLAY=True
parameters.LIVE_FIT=False

# %%
filename
# Out:
# '/sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103/exposure_2021110300452_postisrccd.fits'

# %%
output_directory
# Out:
# './outputs_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5'

# %%
if FLAG_RUNWITHEXCEPTIONS:
    try:
        spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target_name_stripped, disperser_label=disperser_label, config=config)
    except:
        errtype = sys.exc_info()[0]  # E.g. <class 'PermissionError'>
        description = sys.exc_info()[1]   # E.g. [Errno 13] Permission denied: ...
        
        print("\t +++++++++++++++++++++ Exception occured +++++++++++++++++++++++++++++++++++++++++")
        print(f"\t >>>>>  errtype = {errtype}")
        print(f"\t >>>>>> description = {description}")
else:
    spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target_name_stripped, disperser_label=disperser_label, config=config)
# Out:
# 2022-11-07 19:46:59  spectractor.extractor.extractor Spectractor          INFO
# 	Start SPECTRACTOR
# 2022-11-07 19:46:59  Image      load_AUXTEL_image    INFO
# 	Loading AUXTEL image /sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103/exposure_2021110300452_postisrccd.fits...
# 2022-11-07 19:46:59  Image      load_AUXTEL_image    INFO
# 	Image loaded
# 2022-11-07 19:46:59  Image      load_image           INFO
# 	Loading disperser holo4_003...
# 2022-11-07 19:46:59  Hologram   load_specs           INFO
# 	Load disperser holo4_003:
# 	from /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/holo4_003
# 2022-11-07 19:46:59  Hologram   load_specs           INFO
# 	Grating characteristics:
# 	N = 156.00 +/- 1.00 grooves/mm
# 	Average tilt of 0.2 degrees
# No rebinning: parameters.REBIN is forced to 1.
# Section: paths
# x disperser_dir: extractor/dispersers/	=> parameters.DISPERSER_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/	 <class 'str'>
# x throughput_dir: simulation/AuxTelThroughput/	=> parameters.THROUGHPUT_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/	 <class 'str'>
# Section: pipeline
# x spectractor_fit_target_centroid: fit	=> parameters.SPECTRACTOR_FIT_TARGET_CENTROID: fit	 <class 'str'>
# x spectractor_compute_rotation_angle: disperser	=> parameters.SPECTRACTOR_COMPUTE_ROTATION_ANGLE: disperser	 <class 'str'>
# x spectractor_deconvolution_psf2d: False	=> parameters.SPECTRACTOR_DECONVOLUTION_PSF2D: False	 <class 'bool'>
# x spectractor_deconvolution_ffm: True	=> parameters.SPECTRACTOR_DECONVOLUTION_FFM: True	 <class 'bool'>
# x spectractor_deconvolution_sigma_clip: 100	=> parameters.SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP: 100	 <class 'int'>
# Section: instrument
# x obs_name: AUXTEL	=> parameters.OBS_NAME: AUXTEL	 <class 'str'>
# x obs_altitude: 2.66299616375123	=> parameters.OBS_ALTITUDE: 2.66299616375123	 <class 'float'>
# x obs_latitude: -30.2446389756252	=> parameters.OBS_LATITUDE: -30.2446389756252	 <class 'float'>
# x obs_diameter: 1.20	=> parameters.OBS_DIAMETER: 1.2 m	 <class 'astropy.units.quantity.Quantity'>
# x obs_epoch: J2000.0	=> parameters.OBS_EPOCH: J2000.0	 <class 'str'>
# x obs_transmission_systematics: 0.005	=> parameters.OBS_TRANSMISSION_SYSTEMATICS: 0.005	 <class 'float'>
# x obs_object_type: STAR	=> parameters.OBS_OBJECT_TYPE: STAR	 <class 'str'>
# x obs_telescope_transmission: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	=> parameters.OBS_TELESCOPE_TRANSMISSION: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	 <class 'str'>
# x obs_full_instrument_transmisson: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	=> parameters.OBS_FULL_INSTRUMENT_TRANSMISSON: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	 <class 'str'>
# x obs_quantum_efficiency: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	=> parameters.OBS_QUANTUM_EFFICIENCY: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	 <class 'str'>
# x obs_camera_rotation: 0	=> parameters.OBS_CAMERA_ROTATION: 0	 <class 'int'>
# x obs_camera_dec_flip_sign: 1	=> parameters.OBS_CAMERA_DEC_FLIP_SIGN: 1	 <class 'int'>
# x obs_camera_ra_flip_sign: 1	=> parameters.OBS_CAMERA_RA_FLIP_SIGN: 1	 <class 'int'>
# Section: CCD
# x ccd_imsize: 4096	=> parameters.CCD_IMSIZE: 4096	 <class 'int'>
# x ccd_pixel2mm: 10e-3	=> parameters.CCD_PIXEL2MM: 0.01	 <class 'float'>
# x ccd_pixel2arcsec: 0.0952	=> parameters.CCD_PIXEL2ARCSEC: 0.0952	 <class 'float'>
# x ccd_maxadu: 170000	=> parameters.CCD_MAXADU: 170000	 <class 'int'>
# x ccd_gain: 1.1	=> parameters.CCD_GAIN: 1.1	 <class 'float'>
# x ccd_rebin: 1	=> parameters.CCD_REBIN: 1	 <class 'int'>
# Section: spectrograph
# x distance2ccd: 181	=> parameters.DISTANCE2CCD: 181	 <class 'int'>
# x distance2ccd_err: 0.4	=> parameters.DISTANCE2CCD_ERR: 0.4	 <class 'float'>
# x grating_order_2over1: 0.1	=> parameters.GRATING_ORDER_2OVER1: 0.1	 <class 'float'>
# Section: search windows
# x xwindow: 100	=> parameters.XWINDOW: 100	 <class 'int'>
# x ywindow: 100	=> parameters.YWINDOW: 100	 <class 'int'>
# x xwindow_rot: 50	=> parameters.XWINDOW_ROT: 50	 <class 'int'>
# x ywindow_rot: 50	=> parameters.YWINDOW_ROT: 50	 <class 'int'>
# x pixshift_prior: 5	=> parameters.PIXSHIFT_PRIOR: 5	 <class 'int'>
# Section: rotation parameters
# x rot_prefilter: True	=> parameters.ROT_PREFILTER: True	 <class 'bool'>
# x rot_order: 5	=> parameters.ROT_ORDER: 5	 <class 'int'>
# x rot_angle_min: -10	=> parameters.ROT_ANGLE_MIN: -10	 <class 'int'>
# x rot_angle_max: 10	=> parameters.ROT_ANGLE_MAX: 10	 <class 'int'>
# Section: spectrum range
# x lambda_min: 300	=> parameters.LAMBDA_MIN: 300	 <class 'int'>
# x lambda_max: 1100	=> parameters.LAMBDA_MAX: 1100	 <class 'int'>
# x spec_order: 1	=> parameters.SPEC_ORDER: 1	 <class 'int'>
# Section: background subtraction parameters
# x pixwidth_signal: 20	=> parameters.PIXWIDTH_SIGNAL: 20	 <class 'int'>
# x pixdist_background: 140	=> parameters.PIXDIST_BACKGROUND: 140	 <class 'int'>
# x pixwidth_background: 40	=> parameters.PIXWIDTH_BACKGROUND: 40	 <class 'int'>
# x pixwidth_boxsize: 20	=> parameters.PIXWIDTH_BOXSIZE: 20	 <class 'int'>
# Section: PSF
# x psf_type: MoffatGauss	=> parameters.PSF_TYPE: MoffatGauss	 <class 'str'>
# x psf_poly_order: 2	=> parameters.PSF_POLY_ORDER: 2	 <class 'int'>
# x psf_fit_reg_param: 0.1	=> parameters.PSF_FIT_REG_PARAM: 0.1	 <class 'float'>
# x psf_pixel_step_transverse_fit: 50	=> parameters.PSF_PIXEL_STEP_TRANSVERSE_FIT: 50	 <class 'int'>
# x psf_fwhm_clip: 2	=> parameters.PSF_FWHM_CLIP: 2	 <class 'int'>
# Section: detection line algorithm parameters
# x calib_bgd_order: 3	=> parameters.CALIB_BGD_ORDER: 3	 <class 'int'>
# x calib_peak_width: 7	=> parameters.CALIB_PEAK_WIDTH: 7	 <class 'int'>
# x calib_bgd_width: 15	=> parameters.CALIB_BGD_WIDTH: 15	 <class 'int'>
# x calib_savgol_window: 5	=> parameters.CALIB_SAVGOL_WINDOW: 5	 <class 'int'>
# x calib_savgol_order: 2	=> parameters.CALIB_SAVGOL_ORDER: 2	 <class 'int'>
# Section: plot settings
# x paper: False	=> parameters.PAPER: False	 <class 'bool'>
# x linewidth: 2	=> parameters.LINEWIDTH: 2	 <class 'int'>
# x plot_dir: plots	=> parameters.PLOT_DIR: plots	 <class 'str'>
# x save: False	=> parameters.SAVE: False	 <class 'bool'>
# 2022-11-07 19:47:03  Image      check_statistical_error WARNING
# 	Fitted read out noise seems to be different than input readout noise. Fit=8.33086466869782 but average of self.read_out_noise is 8.5.
# 2022-11-07 19:47:03  TelescopeTransmission reset_lambda_range   INFO
# 	With filter FELH0600, set parameters.LAMBDA_MIN=583 and parameters.LAMBDA_MAX=1069.
# WARNING: AstropyDeprecationWarning: "pedantic" was deprecated in version 5.0 and will be removed in a future version. Use argument "verify" instead. [astropy.io.votable.table]
# 2022-11-07 19:47:03  astropy    _showwarning         WARNING AstropyDeprecationWarning: "pedantic" was deprecated in version 5.0 and will be removed in a future version. Use argument "verify" instead.
# 2022-11-07 19:47:03  Star       load                 INFO
# 	Simbad:
#  MAIN_ID        RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... --------- ----------------
# * alf Col 05 39 38.9410 -34 04 26.794 ... 0.0001170                1
# 2022-11-07 19:47:05  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the image with guess=[ 327.93382933 1696.11599057]...
# 2022-11-07 19:47:05  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                 c1_0                 c0_1
#     ------------------ --------------------- --------------------
#     259.32872937399105 -0.025946031143574307 -0.08500830516721992
# 2022-11-07 19:47:06  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 18 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-11-07 19:47:07  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 4 iterations because the relative change of cost is below ftol=5e-05.
# 2022-11-07 19:47:07  Image      find_target          INFO
# 	X,Y target position in pixels: 327.915,1696.122
# 2022-11-07 19:47:07  Image      turn_image           INFO
# 	Rotate the image with angle theta=0.20 degree
# 2022-11-07 19:47:19  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the rotated image...
# 2022-11-07 19:47:19  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0              c1_0              c0_1
#     ------------------ ---------------- -----------------
#     30110.050736079134 71.9019638023178 60.71863961510095
# 2022-11-07 19:47:19  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 2 iterations because the sum of parameter shift relative to the sum of the parameters is below xtol=1e-06.
# 2022-11-07 19:47:20  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 4 iterations because the sum of parameter shift relative to the sum of the parameters is below xtol=1e-06.
# 2022-11-07 19:47:20  Image      find_target          INFO
# 	X,Y target position in pixels: 334.947,1706.967
# 2022-11-07 19:47:20  Spectrum   __init__             INFO
# 	Spectrum info copied from image
# 2022-11-07 19:47:20  TelescopeTransmission reset_lambda_range   INFO
# 	With filter FELH0600, set parameters.LAMBDA_MIN=590.0000000000016 and parameters.LAMBDA_MAX=1061.2000000001087.
# 2022-11-07 19:47:20  spectractor.extractor.extractor Spectractor          INFO
# 	  ======================= PSF1D Extraction ====================================
# 2022-11-07 19:47:20  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	  ======================= extract_spectrum_from_image =============================
# 2022-11-07 19:47:20  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extracting spectrum from image: spectrum with width 2*20 pixels and background from 140 to 180 pixels
# 2022-11-07 19:47:20  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop rotated image [2008:3373,1526:1886] (size (1365, 360))
# 2022-11-07 19:47:22  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	  ======================= Fit the transverse profile =============================
# 2022-11-07 19:47:22  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Start PSF1D transverse fit...
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:22  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-07 19:47:27  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_1 has a null Jacobian; parameter is fixed at its last known current value (2.1201860654986974e-16).
# 2022-11-07 19:47:27  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_2 has a null Jacobian; parameter is fixed at its last known current value (-6.887712812896478e-16).
# 2022-11-07 19:47:27  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=1.6416e+07 initial chisq_red=300.66
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [ 0.17872362 -0.15099857 -0.70971419  1.54280863 -4.723169   -5.46642903
#  -0.11726035 -1.87058252 -1.40373313  0.08043783 -0.18700105 -0.35818908
#   0.62379317]
# 	New parameters: [  0.86668841  -3.05281409  -2.9348604    5.45156776 -12.70134588
#   -7.63727529   1.17449479  -2.60180391  -1.67646408  -0.19928804
#   -0.38198748  -0.41924999   1.62379317]
# 	Final cost=1.117e+07 final chisq_red=204.58 computed in 1.04s
# 2022-11-07 19:47:28  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=1.117e+07 initial chisq_red=204.58
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.05189105  0.00352252 -0.38553227 -0.48204236  0.5084045  -2.9255871
#  -0.01892649  0.04333338 -0.82398055 -0.11698275 -0.02004875 -0.01609341
#   0.58346633]
# 	New parameters: [  0.91857946  -3.04929157  -3.32039267   4.9695254  -12.19294138
#  -10.56286239   1.1555683   -2.55847053  -2.50044463  -0.31627079
#   -0.40203623  -0.4353434    2.2072595 ]
# 	Final cost=9.8583e+06 final chisq_red=180.55 computed in 0.94s
# 2022-11-07 19:47:29  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=9.8583e+06 initial chisq_red=180.55
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [ 0.04857405  0.06290638 -0.25861808  0.15594586 -0.16354671 -2.51478788
#   0.3104133   0.17527991 -0.16460819 -0.12680319 -0.21822801 -0.49915791
#   0.65569643]
# 	New parameters: [  0.96715351  -2.98638518  -3.57901074   5.12547126 -12.3564881
#  -13.07765027   1.4659816   -2.38319063  -2.66505282  -0.44307398
#   -0.62026425  -0.93450131   2.86295593]
# 	Final cost=9.1639e+06 final chisq_red=167.84 computed in 0.93s
# 2022-11-07 19:47:30  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=9.1639e+06 initial chisq_red=167.84
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [ 0.099026    0.15540785  0.08640608  0.64068231 -0.22095393  1.32569605
#   0.07592553 -0.23403705 -0.03494372 -0.02243099 -0.01916534  0.21505204
#   0.10471534]
# 	New parameters: [  1.06617951  -2.83097733  -3.49260466   5.76615358 -12.57744202
#  -11.75195421   1.54190713  -2.61722768  -2.69999654  -0.46550497
#   -0.63942958  -0.71944927   2.96767127]
# 	Final cost=8.8312e+06 final chisq_red=161.74 computed in 0.93s
# 2022-11-07 19:47:31  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration
spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=28: initial cost=3.8613e+06 initial chisq_red=70.72
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [ 0.00805998  0.01626546  0.01356556 -0.25261877  0.4587962  -0.58163697
#  -0.04461268  0.13127497  0.05824876 -0.00778486  0.01738168 -0.12467804
#   0.04064001]
# 	New parameters: [  2.46389145   0.1379912   -1.18853462   7.0194907  -10.32876198
#  -11.57627728   1.83963691  -2.17888702  -2.67737771  -0.34736646
#   -0.42856627  -0.71308822   3.11961398]
# 	Final cost=3.8078e+06 final chisq_red=69.74 computed in 1.05s
# 2022-11-07 19:47:56  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=29: initial cost=3.8078e+06 initial chisq_red=69.74
# 		 Line search: alpha_min=3.2 iter=0 funcalls=7
# 	Parameter shifts: [ 0.06715757  0.15959934  0.14095734  0.13060216 -0.25936465  1.26567285
#   0.0064067  -0.1579972   0.22285683  0.04239115  0.07305839  0.11426666
#  -0.02100828]
# 	New parameters: [  2.53104902   0.29759054  -1.04757728   7.15009285 -10.58812663
#  -10.31060442   1.84604361  -2.33688422  -2.45452088  -0.30497531
#   -0.35550788  -0.59882156   3.0986057 ]
# 	Final cost=3.7025e+06 final chisq_red=67.811 computed in 1.03s
# 2022-11-07 19:47:57  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=30: initial cost=3.7025e+06 initial chisq_red=67.811
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [ 0.00671551  0.01742304  0.02792081 -0.28095418  0.50822188 -0.96789668
#  -0.04914675  0.13101917 -0.1389832  -0.01678833  0.03715149 -0.06656051
#   0.06009259]
# 	New parameters: [  2.53776453   0.31501358  -1.01965647   6.86913867 -10.07990475
#  -11.2785011    1.79689686  -2.20586505  -2.59350408  -0.32176364
#   -0.31835639  -0.66538208   3.15869829]
# 	Final cost=3.6541e+06 final chisq_red=66.925 computed in 1.05s
# 2022-11-07 19:47:58  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=31: initial cost=3.6541e+06 initial chisq_red=66.925
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.01556132  0.04645383  0.07474068  0.49552795 -0.83699748 -0.22956979
#   0.08434532 -0.24511608 -0.26555509  0.03382078 -0.03976914  0.05465931
#   0.02641509]
# 	New parameters: [  2.55332585   0.36146741  -0.94491579   7.36466662 -10.91690223
#  -11.50807089   1.88124218  -2.45098113  -2.85905917  -0.28794286
#   -0.35812553  -0.61072277   3.18511338]
# 	Final cost=3.626e+06 final chisq_red=66.41 computed in 0.95s
# 2022-11-07 19:47:59  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=32: initial cost=3.626e+06 initial chisq_red=66.41
# 		 Line search: alpha_min=0.573 iter=3 funcalls=7
# 	Parameter shifts: [ 0.01086487  0.02926222  0.03708633 -0.1827208   0.33041581 -0.39781456
#  -0.0196006   0.06842    -0.00219255 -0.01404177  0.04223943 -0.03597403
#   0.05164117]
# 	New parameters: [  2.56419072   0.39072963  -0.90782946   7.18194582 -10.58648643
#  -11.90588545   1.86164158  -2.38256113  -2.86125172  -0.30198464
#   -0.3158861   -0.6466968    3.23675456]
# 	Final cost=3.61e+06 final chisq_red=66.118 computed in 1.05s
# 2022-11-07 19:48:00  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration
spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=43: initial cost=3.2686e+06 initial chisq_red=59.865
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.00307974 -0.00644287 -0.0524059  -0.32517693  0.57716966 -0.02728134
#  -0.02548439  0.25020758  0.2778271   0.04215632 -0.05901018 -0.34687732
#   0.54640015]
# 	New parameters: [  2.52891197   0.33336192  -0.88137175   8.56597587 -13.24221345
#  -11.46964869   2.04206373  -3.58480105  -3.46874342   0.04526234
#   -0.13399662  -0.64902135   4.80191615]
# 	Final cost=3.2005e+06 final chisq_red=58.618 computed in 0.94s
# 2022-11-07 19:48:11  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=44: initial cost=3.2005e+06 initial chisq_red=58.618
# 		 Line search: alpha_min=0.573 iter=3 funcalls=7
# 	Parameter shifts: [ 0.00189229 -0.00260262  0.01827261  0.21408044 -0.35461956 -0.01898643
#  -0.04121082 -0.18199244 -0.40092537  0.03623521 -0.06935878  0.17541677
#   0.07223292]
# 	New parameters: [  2.53080426   0.3307593   -0.86309915   8.78005631 -13.59683302
#  -11.48863512   2.00085291  -3.76679349  -3.86966879   0.08149755
#   -0.2033554   -0.47360458   4.87414908]
# 	Final cost=3.1351e+06 final chisq_red=57.42 computed in 1.05s
# 2022-11-07 19:48:12  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=45: initial cost=3.1351e+06 initial chisq_red=57.42
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.006153   -0.01061999 -0.06528676 -0.04161357  0.00616804  0.47202652
#  -0.04877569 -0.00701392  0.02598329  0.38885983 -0.56542136 -0.99712146
#   0.38541595]
# 	New parameters: [  2.53695726   0.3201393   -0.9283859    8.73844274 -13.59066498
#  -11.0166086    1.95207721  -3.77380741  -3.84368549   0.47035737
#   -0.76877676  -1.47072604   5.25956503]
# 	Final cost=3.0122e+06 final chisq_red=55.169 computed in 0.94s
# 2022-11-07 19:48:13  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=46: initial cost=3.0122e+06 initial chisq_red=55.169
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.07002839  0.14175724  0.09974157 -0.20126592  0.511199   -0.79693306
#  -0.06128339  0.12265214 -0.23541732  1.87960076 -2.92697972 -5.07748159
#   0.34973405]
# 	New parameters: [  2.60698565   0.46189654  -0.82864434   8.53717682 -13.07946598
#  -11.81354167   1.89079383  -3.65115528  -4.07910282   2.34995814
#   -3.69575648  -6.54820763   5.60929908]
# 	Final cost=2.885e+06 final chisq_red=52.84 computed in 0.95s
# 2022-11-07 19:48:14  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=47: initial cost=2.885e+06 initial chisq_red=52.84
# 		 Line search: alpha_min=2.62 iter=1 funcalls=6
# 	Parameter shifts: [  0.26005917   0.59838915   0.60055822   0.14608869   0.80396554
#    3.61337792   0.10013779   0.51001009   1.51127953  30.11208201
#  -46.51163726 -82.36835507  -0.08999434]
# 	New parameters: [  2.86704482   1.0602857   -0.22808612   8.6832655  -12.27550044
#   -8.20016375   1.99093162  -3.14114518  -2.56782329  32.46204015
#  -50.20739373 -88.91656271   5.51930474]
# 	Final cost=2.206e+06 final chisq_red=40.404 computed in 0.98s
# 2022-11-07 19:48:15  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=48: initial cost=2.206e+06 initial chisq_red=40.404
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 5.52672483e-02  7.16991831e-02 -2.67906290e-02 -5.01427016e-01
#   2.17598310e+00  9.28348089e-01 -1.97035852e-01  7.11619139e-01
#   2.75121129e-01  2.29370216e+01 -3.56011148e+01 -6.21251631e+01
#  -3.98611582e-01]
# 	New parameters: [   2.92231207    1.13198488   -0.25487675    8.18183848  -10.09951734
#    -7.27181566    1.79389576   -2.42952605   -2.29270216   55.39906177
#   -85.80850851 -151.04172578    5.12069316]
# 	Final cost=1.8939e+06 final chisq_red=34.686 computed in 1.02s
# 2022-11-07 19:48:16  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=49: initial cost=1.8939e+06 initial chisq_red=34.686
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [-1.30954406e-02 -4.20880988e-02 -4.50183372e-02  2.90967112e-01
#   2.14883382e-01  7.28493408e-01  1.02460807e-01  3.14818433e-02
#   2.38795625e-01  4.44609866e+01 -6.86326288e+01 -1.20012802e+02
#  -1.65585161e-01]
# 	New parameters: [   2.90921663    1.08989678   -0.29989509    8.4728056    -9.88463396
#    -6.54332225    1.89635657   -2.3980442    -2.05390653   99.86004836
#  -154.44113729 -271.05452769    4.95510799]
# 	Final cost=1.8401e+06 final chisq_red=33.701 computed in 0.98s
# 2022-11-07 19:48:16  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: 2.9092 +0.0006 -0.0006
# 	y_c_1: 1.090 +0.001 -0.001
# 	y_c_2: -0.300 +0.001 -0.001
# 	gamma_0: 8.473 +0.004 -0.004
# 	gamma_1: -9.885 +0.006 -0.006
# 	gamma_2: -6.543 +0.009 -0.009
# 	alpha_0: 1.896 +0.001 -0.001
# 	alpha_1: -2.398 +0.003 -0.003
# 	alpha_2: -2.054 +0.003 -0.003
# 	eta_gauss_0: 99.9 +0.7 -0.7
# 	eta_gauss_1: -154 +1 -1
# 	eta_gauss_2: -271 +2 -2
# 	stddev_0: 4.955 +0.002 -0.002
#
# ...
# - fit param #2 :: shift_x [pix] = -0.16145266769226255 	 fixed = True 	 bounds -5.000 - 5.000
# - fit param #3 :: shift_y [pix] = 1.4252901818079584 	 fixed = True 	 bounds -50.000 - 50.000
# - fit param #4 :: angle [deg] = 0.17830677811525494 	 fixed = True 	 bounds -90.000 - 90.000
# - fit param #5 :: B = 1.0 	 fixed = True 	 bounds 0.200 - 5.000
# - fit param #6 :: R = -87.965340622756 	 fixed = True 	 bounds -360.000 - 360.000
# - fit param #7 :: P [hPa] = 740.4 	 fixed = True 	 bounds 300.000 - 1100.000
# - fit param #8 :: T [Celsius] = 7.2 	 fixed = True 	 bounds -100.000 - 100.000
# - fit param #9 :: z = 1.14397247903133 	 fixed = True 	 bounds 1.001 - 3.000
# - fit param #10 :: x_c_0 = 2355.0382078509356 	 fixed = True 	 bounds -inf - inf
# - fit param #11 :: x_c_1 = 681.9958450226125 	 fixed = True 	 bounds -inf - inf
# - fit param #12 :: x_c_2 = 6.109907029582339e-13 	 fixed = True 	 bounds -inf - inf
# - fit param #13 :: y_c_0 = 0.07472577639669925 	 fixed = False 	 bounds -inf - inf
# - fit param #14 :: y_c_1 = 0.13588877467359153 	 fixed = False 	 bounds -inf - inf
# - fit param #15 :: y_c_2 = 0.20362668005749102 	 fixed = False 	 bounds -inf - inf
# - fit param #16 :: gamma_0 = 9.24170561751183 	 fixed = False 	 bounds -inf - inf
# - fit param #17 :: gamma_1 = -4.677737509223676 	 fixed = False 	 bounds -inf - inf
# - fit param #18 :: gamma_2 = -0.8503594189767607 	 fixed = False 	 bounds -inf - inf
# - fit param #19 :: alpha_0 = 2.554035076853413 	 fixed = False 	 bounds -inf - inf
# - fit param #20 :: alpha_1 = -0.863163653062489 	 fixed = False 	 bounds -inf - inf
# - fit param #21 :: alpha_2 = -0.38709795380462453 	 fixed = False 	 bounds -inf - inf
# - fit param #22 :: eta_gauss_0 = 639.2202304982112 	 fixed = False 	 bounds -inf - inf
# - fit param #23 :: eta_gauss_1 = -1048.6652743748937 	 fixed = False 	 bounds -inf - inf
# - fit param #24 :: eta_gauss_2 = 427.9641289158029 	 fixed = False 	 bounds -inf - inf
# - fit param #25 :: stddev_0 = 5.527350782274116 	 fixed = False 	 bounds -inf - inf
# - fit param #26 :: stddev_1 = -1.1786182061879515e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #27 :: stddev_2 = 1.1766775134835457e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #28 :: saturation_0 = 170000.00000000012 	 fixed = True 	 bounds 0.000 - 340000.000
# - fit param #29 :: x_c_0_2 = 2355.0382078509356 	 fixed = True 	 bounds -inf - inf
# - fit param #30 :: x_c_1_2 = 681.9958450226125 	 fixed = True 	 bounds -inf - inf
# - fit param #31 :: x_c_2_2 = 6.109907029582339e-13 	 fixed = True 	 bounds -inf - inf
# - fit param #32 :: y_c_0_2 = 0.0 	 fixed = True 	 bounds -inf - inf
# - fit param #33 :: y_c_1_2 = 0.0 	 fixed = True 	 bounds -inf - inf
# - fit param #34 :: y_c_2_2 = 0.0 	 fixed = True 	 bounds -inf - inf
# - fit param #35 :: gamma_0_2 = 8.49710400455191 	 fixed = True 	 bounds -inf - inf
# - fit param #36 :: gamma_1_2 = -9.833658690640503 	 fixed = True 	 bounds -inf - inf
# - fit param #37 :: gamma_2_2 = -6.506783741135401 	 fixed = True 	 bounds -inf - inf
# - fit param #38 :: alpha_0_2 = 1.9772076195145918 	 fixed = True 	 bounds -inf - inf
# - fit param #39 :: alpha_1_2 = -2.231422069239595 	 fixed = True 	 bounds -inf - inf
# - fit param #40 :: alpha_2_2 = -1.938962936029293 	 fixed = True 	 bounds -inf - inf
# - fit param #41 :: eta_gauss_0_2 = -0.0455946104599145 	 fixed = True 	 bounds -inf - inf
# - fit param #42 :: eta_gauss_1_2 = -0.09429214912201273 	 fixed = True 	 bounds -inf - inf
# - fit param #43 :: eta_gauss_2_2 = -0.06600581547926647 	 fixed = True 	 bounds -inf - inf
# - fit param #44 :: stddev_0_2 = 4.955107994073156 	 fixed = True 	 bounds -inf - inf
# - fit param #45 :: stddev_1_2 = -1.1786182061879515e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #46 :: stddev_2_2 = 1.1766775134835457e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #47 :: saturation_0_2 = 170000.00000000012 	 fixed = True 	 bounds 0.000 - 340000.000
# 2022-11-07 20:18:09  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/ffm_bestfit.pdf.
# 2022-11-07 20:18:11  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/ffm_bestfit_2.pdf.
# 2022-11-07 20:18:36  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: -1.000pix
# 	D = 181.557 mm (default: DISTANCE2CCD = 181.00 +/- 0.40 mm, 1.4 sigma shift)
# 2022-11-07 20:18:36  FullForwardModelFitWorkspace set_mask             INFO
# 	Reset spectrogram mask with current parameters.
# 2022-11-07 20:18:40  spectractor.fit.fitter run_minimisation_sigma_clipping INFO
# 	Sigma-clipping step 0/3 (sigma=100)
# 2022-11-07 20:20:18  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=1.0332e+06 initial chisq_red=18.776
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.01594697 -0.01084321  0.00292828 -0.01136797  0.01092693  0.06595978
#  -0.00377171  0.00489645  0.02157741  0.11818139 -0.16293946  0.08686416
#  -0.11946057]
# 	New parameters: [ 9.06727511e-02  1.25045561e-01  2.06554960e-01  9.23033764e+00
#  -4.66681058e+00 -7.84399644e-01  2.55026336e+00 -8.58267206e-01
#  -3.65520547e-01  6.39338412e+02 -1.04882821e+03  4.28050993e+02
#   5.40789021e+00]
# 	Final cost=1.0296e+06 final chisq_red=18.71 computed in 92.30s
# 2022-11-07 20:22:10  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=1.0296e+06 initial chisq_red=18.71
# 		 Line search: alpha_min=0.146 iter=5 funcalls=9
# 	Parameter shifts: [ 4.81309146e-05  3.81226811e-05 -4.94030597e-06 -2.31789092e-03
#  -1.20369698e-03 -4.99485238e-03 -5.73382432e-04 -2.25916435e-04
#  -1.22151120e-03 -2.69252455e-02  4.84149542e-02 -1.63049362e-02
#  -6.66630473e-03]
# 	New parameters: [ 9.07208820e-02  1.25083683e-01  2.06550020e-01  9.22801975e+00
#  -4.66801428e+00 -7.89394496e-01  2.54968998e+00 -8.58493122e-01
#  -3.66742058e-01  6.39311487e+02 -1.04877980e+03  4.28034688e+02
#   5.40122391e+00]
# 	Final cost=1.0295e+06 final chisq_red=18.708 computed in 111.96s
# 2022-11-07 20:22:10  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 1 iterations because the relative change of cost is below ftol=0.0018172566693319765.
# 2022-11-07 20:22:10  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: 0.0907 +0.0007 -0.0007
# 	y_c_1: 0.125 +0.002 -0.002
# 	y_c_2: 0.207 +0.002 -0.002
# 	gamma_0: 9.228 +0.005 -0.005
# 	gamma_1: -4.67 +0.01 -0.01
# 	gamma_2: -0.79 +0.01 -0.01
# 	alpha_0: 2.550 +0.001 -0.001
# 	alpha_1: -0.858 +0.003 -0.003
# 	alpha_2: -0.367 +0.004 -0.004
# 	eta_gauss_0: 639.31 +0.09 -0.09
# 	eta_gauss_1: -1048.8 +0.1 -0.1
# 	eta_gauss_2: 428.03 +0.06 -0.06
# 	stddev_0: 5.401 +0.005 -0.005
#
# 2022-11-07 20:22:16  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/ffm_bestfit.pdf.
# 2022-11-07 20:22:18  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/ffm_bestfit_2.pdf.
# 2022-11-07 20:22:19  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/parameters_correlation.pdf.
# 2022-11-07 20:22:19  spectractor.fit.fitter run_minimisation_sigma_clipping INFO
# 	No outliers detected at first iteration: break the sigma clipping iterations.
# 2022-11-07 20:22:19  spectractor.extractor.extractor run_ffm_minimisation INFO
# 	  niter = 1 : Newton: total computation time: 1838.5874984264374s
# 2022-11-07 20:22:19  spectractor.extractor.extractor run_ffm_minimisation INFO
#  --- after  run_minimisation_sigma_clipping ---
# 2022-11-07 20:22:19  spectractor.extractor.extractor dumpfitparameters    INFO
#
# - fit param #0 :: A2 = 1.0 	 fixed = True 	 bounds 0.000 - 20.000
# - fit param #1 :: D_CCD [mm] = 181.55700018046628 	 fixed = True 	 bounds 179.544 - 181.944
# - fit param #2 :: shift_x [pix] = -0.9997443679376464 	 fixed = True 	 bounds -5.000 - 5.000
# - fit param #3 :: shift_y [pix] = 1.4252901818079584 	 fixed = True 	 bounds -50.000 - 50.000
# - fit param #4 :: angle [deg] = 0.17830677811525494 	 fixed = True 	 bounds -90.000 - 90.000
# - fit param #5 :: B = 1.0 	 fixed = True 	 bounds 0.200 - 5.000
# - fit param #6 :: R = -87.965340622756 	 fixed = True 	 bounds -360.000 - 360.000
# - fit param #7 :: P [hPa] = 740.4 	 fixed = True 	 bounds 300.000 - 1100.000
# - fit param #8 :: T [Celsius] = 7.2 	 fixed = True 	 bounds -100.000 - 100.000
# - fit param #9 :: z = 1.14397247903133 	 fixed = True 	 bounds 1.001 - 3.000
# - fit param #10 :: x_c_0 = 2355.0382078509356 	 fixed = True 	 bounds -inf - inf
# - fit param #11 :: x_c_1 = 681.9958450226125 	 fixed = True 	 bounds -inf - inf
# - fit param #12 :: x_c_2 = 6.109907029582339e-13 	 fixed = True 	 bounds -inf - inf
# - fit param #13 :: y_c_0 = 0.09072088196466015 	 fixed = False 	 bounds -inf - inf
# - fit param #14 :: y_c_1 = 0.12508368335433864 	 fixed = False 	 bounds -inf - inf
# - fit param #15 :: y_c_2 = 0.20655002014096274 	 fixed = False 	 bounds -inf - inf
# - fit param #16 :: gamma_0 = 9.228019752900087 	 fixed = False 	 bounds -inf - inf
# - fit param #17 :: gamma_1 = -4.668014276445444 	 fixed = False 	 bounds -inf - inf
# - fit param #18 :: gamma_2 = -0.789394496205339 	 fixed = False 	 bounds -inf - inf
# - fit param #19 :: alpha_0 = 2.549689980509357 	 fixed = False 	 bounds -inf - inf
# - fit param #20 :: alpha_1 = -0.8584931224204557 	 fixed = False 	 bounds -inf - inf
# - fit param #21 :: alpha_2 = -0.3667420584756551 	 fixed = False 	 bounds -inf - inf
# - fit param #22 :: eta_gauss_0 = 639.3114866395409 	 fixed = False 	 bounds -inf - inf
# - fit param #23 :: eta_gauss_1 = -1048.7797988804052 	 fixed = False 	 bounds -inf - inf
# - fit param #24 :: eta_gauss_2 = 428.03468814107015 	 fixed = False 	 bounds -inf - inf
# - fit param #25 :: stddev_0 = 5.401223910084357 	 fixed = False 	 bounds -inf - inf
# - fit param #26 :: stddev_1 = -1.1786182061879515e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #27 :: stddev_2 = 1.1766775134835457e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #28 :: saturation_0 = 170000.00000000012 	 fixed = True 	 bounds 0.000 - 340000.000
# - fit param #29 :: x_c_0_2 = 2355.0382078509356 	 fixed = True 	 bounds -inf - inf
# - fit param #30 :: x_c_1_2 = 681.9958450226125 	 fixed = True 	 bounds -inf - inf
# - fit param #31 :: x_c_2_2 = 6.109907029582339e-13 	 fixed = True 	 bounds -inf - inf
# - fit param #32 :: y_c_0_2 = 0.0 	 fixed = True 	 bounds -inf - inf
# - fit param #33 :: y_c_1_2 = 0.0 	 fixed = True 	 bounds -inf - inf
# - fit param #34 :: y_c_2_2 = 0.0 	 fixed = True 	 bounds -inf - inf
# - fit param #35 :: gamma_0_2 = 8.49710400455191 	 fixed = True 	 bounds -inf - inf
# - fit param #36 :: gamma_1_2 = -9.833658690640503 	 fixed = True 	 bounds -inf - inf
# - fit param #37 :: gamma_2_2 = -6.506783741135401 	 fixed = True 	 bounds -inf - inf
# - fit param #38 :: alpha_0_2 = 1.9772076195145918 	 fixed = True 	 bounds -inf - inf
# - fit param #39 :: alpha_1_2 = -2.231422069239595 	 fixed = True 	 bounds -inf - inf
# - fit param #40 :: alpha_2_2 = -1.938962936029293 	 fixed = True 	 bounds -inf - inf
# - fit param #41 :: eta_gauss_0_2 = -0.0455946104599145 	 fixed = True 	 bounds -inf - inf
# - fit param #42 :: eta_gauss_1_2 = -0.09429214912201273 	 fixed = True 	 bounds -inf - inf
# - fit param #43 :: eta_gauss_2_2 = -0.06600581547926647 	 fixed = True 	 bounds -inf - inf
# - fit param #44 :: stddev_0_2 = 4.955107994073156 	 fixed = True 	 bounds -inf - inf
# - fit param #45 :: stddev_1_2 = -1.1786182061879515e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #46 :: stddev_2_2 = 1.1766775134835457e-15 	 fixed = True 	 bounds -inf - inf
# - fit param #47 :: saturation_0_2 = 170000.00000000012 	 fixed = True 	 bounds 0.000 - 340000.000
# 2022-11-07 20:22:20  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/ffm_bestfit.pdf.
# 2022-11-07 20:22:22  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/ffm_bestfit_2.pdf.
# 2022-11-07 20:22:40  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: 1.000pix
# 	D = 180.952 mm (default: DISTANCE2CCD = 181.00 +/- 0.40 mm, -0.1 sigma shift)
# 2022-11-07 20:22:40  spectractor.extractor.extractor Spectractor          INFO
# 	  ======================= SAVE SPECTRUM =============================
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# 2022-11-07 20:22:40  astropy    _showwarning         WARNING VerifyWarning: Card is too long, comment will be truncated.
# 2022-11-07 20:22:40  Spectrum   save_spectrum        INFO
# 	Spectrum saved in ./outputs_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/exposure_2021110300452_postisrccd_spectrum.fits
# 2022-11-07 20:22:40  Spectrum   save_spectrogram     INFO
# 	Spectrogram saved in ./outputs_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5/exposure_2021110300452_postisrccd_spectrogram.fits
# WARNING: UnitsWarning: 'erg/s/cm$^2$/nm' did not parse as fits unit: Invalid character at col 8 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# 2022-11-07 20:22:45  astropy    _showwarning         WARNING UnitsWarning: 'erg/s/cm$^2$/nm' did not parse as fits unit: Invalid character at col 8 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
# WARNING: UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# 2022-11-07 20:22:45  astropy    _showwarning         WARNING UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
#  Line Tabulated  Detected   Shift    ...   Chisq   Eqwidth_mod Eqwidth_data
#           nm        nm        nm     ...  reduced       nm          nm
# ----- --------- --------- ---------- ... --------- ----------- ------------
#           760.3 758.61127 -1.6887197 ... 15.730206   5.1978116     33.81215
# $O_2$     763.1  764.9552  1.8551708 ... 15.730206   14.245204    39.295704
# WARNING: UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# 2022-11-07 20:22:45  astropy    _showwarning         WARNING UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html

# %%
spectrum.plot_spectrum(force_lines=True)
# Out:
#  Line Tabulated  Detected   Shift    ...   Chisq   Eqwidth_mod Eqwidth_data
#           nm        nm        nm     ...  reduced       nm          nm
# ----- --------- --------- ---------- ... --------- ----------- ------------
#           760.3 758.61127 -1.6887197 ... 15.730206   5.1978116     33.81215
# $O_2$     763.1  764.9552  1.8551708 ... 15.730206   14.245204    39.295704
# WARNING: UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# 2022-11-07 20:22:55  astropy    _showwarning         WARNING UnitsWarning: 'reduced' did not parse as fits unit: At col 0, Unit 'reduced' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html

# %% [markdown]
# # Backup output

# %% [markdown]
# - If no crash occurs, arrive here
#
# ./outputs_process_holo_config_DECONVOLUTION_PSF2D

# %%
def cleandir(path):
    if os.path.isdir(path):
        files=os.listdir(path)
        if len(files) > 0:
            for f in files:
                if os.path.isdir(os.path.join(path,f)):
                    if f==".ipynb_checkpoints":
                        shutil.rmtree(os.path.join(path,f))
                    else:
                        print(" Cannot remove this directory {}".format(os.path.join(path,f)))
                else:
                    os.remove(os.path.join(path,f))

# %%
# this flag must be set if one want to clean results from previous runs
if FLAG_MANAGE_OUTPUT_SPECTRACTOR:
    
    # manage global output directory of spectractor
    # Basically it has the name of the input file image
    
    if not os.path.isdir(path_toptoptopoutput_spectractor):
        os.mkdir(path_toptoptopoutput_spectractor)
    
    if not os.path.isdir(path_toptopoutput_spectractor):
        os.mkdir(path_toptopoutput_spectractor) 
        
    if configdir !="":
    # top directory    
        if not os.path.isdir(path_topoutput_spectractor):
            os.mkdir(path_topoutput_spectractor)   
            
            
        if not os.path.isdir(path_output_spectractor):
            os.mkdir(path_output_spectractor)
  
    
    if not os.path.isdir(finalpath_output_spectractor):
        os.mkdir(finalpath_output_spectractor)
        os.mkdir(os.path.join(finalpath_output_spectractor,"basespec"))
        os.mkdir(os.path.join(finalpath_output_spectractor,"plots"))
    else:
        cleandir(os.path.join(finalpath_output_spectractor,"basespec"))
        cleandir(os.path.join(finalpath_output_spectractor,"plots"))

# %%
print("******************************** SUCCESS ********************************************")
# Out:
# ******************************** SUCCESS ********************************************

# %%
copy_tree(output_directory,os.path.join(finalpath_output_spectractor,"basespec"))
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/basespec/exposure_2021110300452_postisrccd_spectrogram.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/basespec/exposure_2021110300452_postisrccd_spectrum.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/basespec/exposure_2021110300452_postisrccd_lines.csv',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/basespec/exposure_2021110300452_postisrccd_table.csv']

# %%
copy_tree(output_figures,os.path.join(finalpath_output_spectractor,"plots"))
# Out:
# ['/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/amplitude_correlation_matrix.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/background_extraction.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/.ipynb_checkpoints/intermediate_spectrum-checkpoint.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/.ipynb_checkpoints/image-checkpoint.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/regularisation.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/extractedLines.fits',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/D2CCD_x0_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/intermediate_spectrum.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/ffm_bestfit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/image.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/sub_image_subtracted.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/HD 37795_spectrum.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/order0_centroid_fit.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/parameters_correlation.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/fwhm.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/fit_chromatic_psf_best_fit_noprior.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/rotated_image.pdf',
#  '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452/plots/ffm_bestfit_2.pdf']

# %%
print("finalpath_output_spectractor = ",finalpath_output_spectractor)
# Out:
# finalpath_output_spectractor =  /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300452

# %%
os.listdir(os.path.join(finalpath_output_spectractor,"basespec"))
# Out:
# ['exposure_2021110300452_postisrccd_lines.csv',
#  'exposure_2021110300452_postisrccd_spectrum.fits',
#  'exposure_2021110300452_postisrccd_table.csv',
#  'exposure_2021110300452_postisrccd_spectrogram.fits']

# %%
os.listdir(os.path.join(finalpath_output_spectractor,"plots"))
# Out:
# ['D2CCD_x0_fit.pdf',
#  'rotated_image.pdf',
#  'order0_centroid_fit.pdf',
#  'ffm_bestfit_2.pdf',
#  'fit_chromatic_psf_best_fit_noprior.pdf',
#  'sub_image_subtracted.pdf',
#  'extractedLines.fits',
#  'amplitude_correlation_matrix.pdf',
#  'image.pdf',
#  'regularisation.pdf',
#  'fwhm.pdf',
#  'ffm_bestfit.pdf',
#  'intermediate_spectrum.pdf',
#  'background_extraction.pdf',
#  'HD 37795_spectrum.pdf',
#  'parameters_correlation.pdf',
#  '.ipynb_checkpoints']

# %%
output_directory
# Out:
# './outputs_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_5'
