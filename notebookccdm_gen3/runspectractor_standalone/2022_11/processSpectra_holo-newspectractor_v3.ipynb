# %% [markdown]
# # process spectra for AuxTel with new spectractor (version=2.1, November 2022) for particular config for Hologram

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : October 31th 2022
# - update : 2022-11-07
#
# - version v3 : Work with exposure butlen gen3
#
# This notebook is to help for finding the position of order 0
#
# CCIN2P3:
#
# - works with kernels **anaconda3_auxtel** (with libradtran) and **anaconda3_auxtel_v2** (no libradtran)
# - works with kernel **python 3** locally

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
print(sys.path)
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_11', '', '/opt/conda/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload', '/pbs/home/d/dagoret/.local/lib/python3.8/site-packages', '/pbs/throng/lsst/users/dagoret/desc/firecrown', '/pbs/throng/lsst/users/dagoret/desc/augur', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/delight-1.0.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/libradtranpy-0.1.0-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Django-4.1.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/sqlparse-0.4.3-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/backports.zoneinfo-0.2.1-py3.8-linux-x86_64.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/asgiref-3.5.2-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/getCalspec-0.1.4-py3.8.egg', '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coverage-5.6b1-py3.8-linux-x86_64.egg']

# %%
all_paths_to_remove = ['/opt/conda/lib/python3.8/site-packages','/pbs/home/d/dagoret/.local/lib/python3.8/site-packages']

for path_to_remove in all_paths_to_remove:
    if path_to_remove in sys.path:
        print(f"remove {path_to_remove} from sys.path")
        sys.path.remove(path_to_remove)
# Out:
# remove /opt/conda/lib/python3.8/site-packages from sys.path
# remove /pbs/home/d/dagoret/.local/lib/python3.8/site-packages from sys.path

# %%
sys.path
# Out:
# ['/pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_11',
#  '',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python38.zip',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/lib-dynload',
#  '/pbs/throng/lsst/users/dagoret/desc/firecrown',
#  '/pbs/throng/lsst/users/dagoret/desc/augur',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Deprecated-1.2.11-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyarrow-4.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/importlib_metadata-4.11.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coveralls-3.0.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astroquery-0.4.2.dev0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/pyvo-1.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/delight-1.0.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/libradtranpy-0.1.0-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Django-4.1.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/sqlparse-0.4.3-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/backports.zoneinfo-0.2.1-py3.8-linux-x86_64.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/asgiref-3.5.2-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/getCalspec-0.1.4-py3.8.egg',
#  '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/coverage-5.6b1-py3.8-linux-x86_64.egg']

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
from matplotlib import  transforms
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (12,12)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
print(sys.executable)
print(sys.version)
#print(sys.version_info)
# Out:
# /sps/lsst/groups/auxtel/softs/utils/anaconda3/bin/python
# 3.8.13 (default, Oct 21 2022, 23:50:54)
# [GCC 11.2.0]

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_subplot(1,1,1)
X=np.linspace(-10,10,50)
Y=np.sin(X)
ax.plot(X,Y)
plt.show()

# %%
from iminuit import Minuit
import iminuit

# %%
iminuit.__version__
# Out:
# '2.8.4'

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.7.3

# %%
from astropy.io import fits
from astropy.coordinates import Angle
from astropy import units as u
from spectractor import parameters
from spectractor.extractor.extractor import Spectractor,dumpParameters,dumpfitparameters
from spectractor.extractor.images import *
from spectractor.config import load_config, set_logger
from scipy import ndimage, misc

# %%
import logging

# %%
from scipy.stats import kurtosis,skew
from scipy.stats import kurtosistest,skewtest,normaltest

# %%
from distutils.dir_util import copy_tree
import shutil

# %%
from astroquery.simbad import Simbad
import astroquery
astroquery.__version__
#result_table = Simbad.query_object("M1")
# Out:
# '0.4.6'

# %%
def find_target_name(tag):
    try:
        target_name=tag
        result_table = Simbad.query_object(target_name)
        return target_name
    except:
        target_name_stripped = ''.join(tag.split())
        result_table = Simbad.query_object(target_name_stripped)
        return target_name_stripped

# %% [markdown]
# # Configuration

# %% [markdown]
# ## Logger

# %%
my_logger = logging

# %% [markdown]
# ## Config for the notebook

# %%
version="v5.0"  # version of flipping
# create output directories if not exist and clean existing files
FLAG_MANAGE_OUTPUT_SPECTRACTOR=True
# allow to run reconstruction with Spectractor
FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR=True
FLAG_RUNWITHEXCEPTIONS = False

# %% [markdown]
# ## Configuration for Spectractor

# %%
print("List of configuration files available : ",os.listdir("config"))
# Out:
# List of configuration files available :  ['auxtel_config_holo_DECONVOLUTION_REBIN2FFMvNov2022.ini', '.ipynb_checkpoints', 'auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini']

# %%
# Choose the config filename
list_of_spectractorconfigfiles= ['auxtel_config_holo_DECONVOLUTION_PSF1D.ini' ,
                                 'auxtel_config_holo_DECONVOLUTION_PSF2D.ini',
                                 'auxtel_config_holo_DECONVOLUTION_FFM.ini',
                                 'auxtel_config_holo_DECONVOLUTION_PSF2DFFM.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1D.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2FFM.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DFFM300650.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF2D.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotA.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotB.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotC.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2PSF1DrotD.ini',
                                 'auxtel_config_holo_DECONVOLUTION_PSF1D_BG40.ini',
                                 'auxtel_config_holo_DECONVOLUTION_PSF1DTRUNC.ini',
                                 'auxtel_config_holo_DECONVOLUTION_REBIN2FFMvNov2022.ini',
                                 'auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini']

config_idx = len(list_of_spectractorconfigfiles)-1
                                
configfilename= os.path.join("./config",list_of_spectractorconfigfiles[config_idx])
#configdir = (list_of_spectractorconfigfiles[config_idx].split("_")[-1]).split(".") [0]
configdir = "config_" + (list_of_spectractorconfigfiles[config_idx].split("auxtel_config_holo_")[-1]).split(".") [0]

# %%
configfilename
# Out:
# './config/auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini'

# %%
configdir
# Out:
# 'config_DECONVOLUTION_FFMvNov2022'

# %%
! pwd
# Out:
# /pbs/throng/lsst/users/dagoret/desc/AuxTelComm/notebookccdm_gen3/runspectractor_standalone/2022_11

# %%
config=configfilename
print(f">>>>> Spectractor configuration filename : {configfilename}")
# Out:
# >>>>> Spectractor configuration filename : ./config/auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini

# %%
load_config(configfilename)
# Out:
# No rebinning: parameters.REBIN is forced to 1.

# %%
dumpParameters()
# Out:
# ASTROMETRYNET_DIR
# BGD_ORDER 1
# CALIB_BGD_NPARAMS 4
# CALIB_BGD_ORDER 3
# CALIB_BGD_WIDTH 15
# CALIB_PEAK_WIDTH 7
# CALIB_SAVGOL_ORDER 2
# CALIB_SAVGOL_WINDOW 5
# CCD_ARCSEC2RADIANS 4.84813681109536e-06
# CCD_GAIN 1.1
# CCD_IMSIZE 4096
# CCD_MAXADU 170000
# CCD_PIXEL2ARCSEC 0.0952
# CCD_PIXEL2MM 0.01
# CCD_REBIN 1
# CONFIG_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/../config/
# DEBUG False
# DEBUG_LOGGING False
# DISPERSER_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/
# DISPLAY False
# DISTANCE2CCD 181
# DISTANCE2CCD_ERR 0.4
# FGB37 {'label': 'FGB37', 'min': 350, 'max': 750}
# FILTERS [{'label': 'RG715', 'min': 690, 'max': 1100}, {'label': 'FGB37', 'min': 350, 'max': 750}, {'label': 'Halfa', 'min': 0.0006431, 'max': 0.0006686999999999999}, {'label': 'Z-Gunn', 'min': 800, 'max': 1100}]
# FLAM_TO_ADURATE 5175865186660.421
# GRATING_ORDER_2OVER1 0.1
# GROOVES_PER_MM 350
# HALPHA_CENTER 0.0006559
# HALPHA_FILTER {'label': 'Halfa', 'min': 0.0006431, 'max': 0.0006686999999999999}
# HALPHA_WIDTH 6.4e-06
# LAMBDAS [ 300  301  302  303  304  305  306  307  308  309  310  311  312  313
#   314  315  316  317  318  319  320  321  322  323  324  325  326  327
#   328  329  330  331  332  333  334  335  336  337  338  339  340  341
#   342  343  344  345  346  347  348  349  350  351  352  353  354  355
#   356  357  358  359  360  361  362  363  364  365  366  367  368  369
#   370  371  372  373  374  375  376  377  378  379  380  381  382  383
#   384  385  386  387  388  389  390  391  392  393  394  395  396  397
#   398  399  400  401  402  403  404  405  406  407  408  409  410  411
#   412  413  414  415  416  417  418  419  420  421  422  423  424  425
#   426  427  428  429  430  431  432  433  434  435  436  437  438  439
#   440  441  442  443  444  445  446  447  448  449  450  451  452  453
#   454  455  456  457  458  459  460  461  462  463  464  465  466  467
#   468  469  470  471  472  473  474  475  476  477  478  479  480  481
#   482  483  484  485  486  487  488  489  490  491  492  493  494  495
#   496  497  498  499  500  501  502  503  504  505  506  507  508  509
#   510  511  512  513  514  515  516  517  518  519  520  521  522  523
#   524  525  526  527  528  529  530  531  532  533  534  535  536  537
#   538  539  540  541  542  543  544  545  546  547  548  549  550  551
#   552  553  554  555  556  557  558  559  560  561  562  563  564  565
#   566  567  568  569  570  571  572  573  574  575  576  577  578  579
#   580  581  582  583  584  585  586  587  588  589  590  591  592  593
#   594  595  596  597  598  599  600  601  602  603  604  605  606  607
#   608  609  610  611  612  613  614  615  616  617  618  619  620  621
#   622  623  624  625  626  627  628  629  630  631  632  633  634  635
#   636  637  638  639  640  641  642  643  644  645  646  647  648  649
#   650  651  652  653  654  655  656  657  658  659  660  661  662  663
#   664  665  666  667  668  669  670  671  672  673  674  675  676  677
#   678  679  680  681  682  683  684  685  686  687  688  689  690  691
#   692  693  694  695  696  697  698  699  700  701  702  703  704  705
#   706  707  708  709  710  711  712  713  714  715  716  717  718  719
#   720  721  722  723  724  725  726  727  728  729  730  731  732  733
#   734  735  736  737  738  739  740  741  742  743  744  745  746  747
#   748  749  750  751  752  753  754  755  756  757  758  759  760  761
#   762  763  764  765  766  767  768  769  770  771  772  773  774  775
#   776  777  778  779  780  781  782  783  784  785  786  787  788  789
#   790  791  792  793  794  795  796  797  798  799  800  801  802  803
#   804  805  806  807  808  809  810  811  812  813  814  815  816  817
#   818  819  820  821  822  823  824  825  826  827  828  829  830  831
#   832  833  834  835  836  837  838  839  840  841  842  843  844  845
#   846  847  848  849  850  851  852  853  854  855  856  857  858  859
#   860  861  862  863  864  865  866  867  868  869  870  871  872  873
#   874  875  876  877  878  879  880  881  882  883  884  885  886  887
#   888  889  890  891  892  893  894  895  896  897  898  899  900  901
#   902  903  904  905  906  907  908  909  910  911  912  913  914  915
#   916  917  918  919  920  921  922  923  924  925  926  927  928  929
#   930  931  932  933  934  935  936  937  938  939  940  941  942  943
#   944  945  946  947  948  949  950  951  952  953  954  955  956  957
#   958  959  960  961  962  963  964  965  966  967  968  969  970  971
#   972  973  974  975  976  977  978  979  980  981  982  983  984  985
#   986  987  988  989  990  991  992  993  994  995  996  997  998  999
#  1000 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013
#  1014 1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027
#  1028 1029 1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041
#  1042 1043 1044 1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055
#  1056 1057 1058 1059 1060 1061 1062 1063 1064 1065 1066 1067 1068 1069
#  1070 1071 1072 1073 1074 1075 1076 1077 1078 1079 1080 1081 1082 1083
#  1084 1085 1086 1087 1088 1089 1090 1091 1092 1093 1094 1095 1096 1097
#  1098 1099]
# LAMBDA_CONSTRUCTOR 0.000639
# LAMBDA_MAX 1100
# LAMBDA_MIN 300
# LAMBDA_STEP 0.2
# LIBRADTRAN_DIR
# LINEWIDTH 2
# MY_FORMAT %(asctime)-20s %(name)-10s %(funcName)-20s %(levelname)-6s %(message)s
# OBS_ALTITUDE 2.66299616375123
# OBS_CAMERA_DEC_FLIP_SIGN 1
# OBS_CAMERA_RA_FLIP_SIGN 1
# OBS_CAMERA_ROTATION 0
# OBS_DIAMETER 1.2 m
# OBS_EPOCH J2000.0
# OBS_FULL_INSTRUMENT_TRANSMISSON multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_LATITUDE -30.2446389756252
# OBS_NAME AUXTEL
# OBS_OBJECT_TYPE STAR
# OBS_QUANTUM_EFFICIENCY multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_SURFACE 1.1309733552923256 m2
# OBS_TELESCOPE_TRANSMISSION multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_TRANSMISSION_SYSTEMATICS 0.005
# PAPER False
# PIXDIST_BACKGROUND 140
# PIXSHIFT_PRIOR 5
# PIXWIDTH_BACKGROUND 40
# PIXWIDTH_BOXSIZE 20
# PIXWIDTH_SIGNAL 20
# PLATE_CENTER_SHIFT_X -6.0
# PLATE_CENTER_SHIFT_X_ERR 2.0
# PLATE_CENTER_SHIFT_Y -8.0
# PLATE_CENTER_SHIFT_Y_ERR 2.0
# PLOT_DIR plots
# PLOT_ROT_LABEL $\alpha$ [degrees]
# PLOT_XLABEL $x$ [pixels]
# PLOT_YLABEL $y$ [pixels]
# PSF_FIT_REG_PARAM 0.1
# PSF_FWHM_CLIP 2
# PSF_PIXEL_STEP_TRANSVERSE_FIT 50
# PSF_POLY_ORDER 2
# PSF_TYPE MoffatGauss
# RG715 {'label': 'RG715', 'min': 690, 'max': 1100}
# ROT_ANGLE_MAX 10
# ROT_ANGLE_MIN -10
# ROT_ORDER 5
# ROT_PREFILTER True
# SAVE False
# SED_UNIT 1.0 erg / (cm2 nm s)
# SPECTRACTOR_COMPUTE_ROTATION_ANGLE disperser
# SPECTRACTOR_DECONVOLUTION_FFM True
# SPECTRACTOR_DECONVOLUTION_PSF2D False
# SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP 100
# SPECTRACTOR_FIT_TARGET_CENTROID fit
# SPEC_ORDER 1
# THROUGHPUT_DIR /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/
# TIME_UNIT 1.0 s
# VERBOSE False
# XWINDOW 100
# XWINDOW_ROT 50
# YWINDOW 100
# YWINDOW_ROT 50
# ZGUNN {'label': 'Z-Gunn', 'min': 800, 'max': 1100}
# const <module 'astropy.constants' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astropy/constants/__init__.py'>
# hc 1.9864458571489286e-25 J m
# mpl <module 'matplotlib' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py'>
# mypath /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor
# np <module 'numpy' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/numpy/__init__.py'>
# os <module 'os' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/os.py'>
# units <module 'astropy.units' from '/sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/astropy/units/__init__.py'>
# wl_dwl_unit nm2

# %% [markdown]
# # Exposure config

# %%
! ls logbooks
# Out:
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.csv
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.xlsx

# %%
# path index for each month
DATE="20211103"
#DATE="20211104"
#filterdispersername = "empty~holo4_003"
#filterdispersername = "BG40~holo4_003"
filterdispersername = "FELH0600~holo4_003"
imagemode = "postISRCCD"
#imagemode = "unflattened"

# %%
disperser_label = filterdispersername.split("~")[-1]

# %% [markdown]
# ## Paths

# %%
# select if we run at CC or not (locally) 
# /sps/lsst/groups/auxtel/data/2022/holo/20220317
HOSTCC=True
LAPTOP=False

# %%
# Set path depending on which computer running (according HOSTCC)
if HOSTCC:
    path_auxtel="/sps/lsst/groups/auxtel"
    path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
    if configdir == "":
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
    else:
        path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
        path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
        path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
        path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)

else:
    if not LAPTOP:
        path_auxtel="/Users/sylvie/DATA/AuxTelData2022"
        path_spectractor=os.path.join(path_auxtel,"/Users/sylvie/MacOSX/GitHub/LSST/Spectractor")
        path_spectractor_config=os.path.join(path_spectractor,"config")
        path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)
    else:
        path_auxtel="/Users/dagoret/DATA/AuxTelData2022"
        path_spectractor=os.path.join(path_auxtel,"/Users/dagoret/MacOSX/GitHub/LSST/Spectractor")
        path_spectractor_config=os.path.join(path_spectractor,"config")
        path_images=os.path.join(path_auxtel,"data/2022/"+filterdispersername+"/"+DATE)
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2022/OutputSpectractor/"+imagemode)

# %%
path_images
# Out:
# '/sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103'

# %%
path_topoutput_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022'

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103'

# %% [markdown]
# # Utility Functions

# %%
def is_nan(x):
    return (x != x)

# %% [markdown]
# # Logbook for input file selection
#
# - the logbook contains all input image path and possibily the order 0 position

# %%
# !ls logbooks
# Out:
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.csv
# auxtellogbook_FELH0600~holo4_003_20211103_v5.0.xlsx

# %%
filename_logbook='logbooks/auxtellogbook_'+filterdispersername+"_"+DATE+'_' + version+'.csv'

# %%
filename_logbook
# Out:
# 'logbooks/auxtellogbook_FELH0600~holo4_003_20211103_v5.0.csv'

# %%
df=pd.read_csv(filename_logbook,index_col=0)

# %%
pd.set_option('display.max_rows', None)

# %%
# show the list of input files from the logbook to select the file index in the logbook
df
# Out:
#     index                     date  \
# 0       0  2021-11-04T05:07:43.370
# 1       1  2021-11-04T05:08:20.217
# 2       2  2021-11-04T05:08:54.415
# 3       3  2021-11-04T05:11:43.527
# 4       4  2021-11-04T05:12:19.215
# 5       5  2021-11-04T05:12:52.522
# 6       6  2021-11-04T05:17:12.323
# 7       7  2021-11-04T05:17:52.968
# 8       8  2021-11-04T05:25:31.608
# 9       9  2021-11-04T05:29:35.261
# 10     10  2021-11-04T05:33:38.278
# 11     11  2021-11-04T05:37:46.464
# 12     12  2021-11-04T05:41:49.637
# 13     13  2021-11-04T05:45:53.070
# 14     14  2021-11-04T05:50:02.060
# 15     15  2021-11-04T05:54:05.369
# 16     16  2021-11-04T05:58:08.939
# 17     17  2021-11-04T06:02:40.917
# 18     18  2021-11-04T06:06:44.490
# 19     19  2021-11-04T06:10:47.908
# 20     20  2021-11-04T06:14:55.903
# 21     21  2021-11-04T06:18:59.356
# 22     22  2021-11-04T06:33:23.762
# 23     23  2021-11-04T06:34:05.373
# 24     24  2021-11-04T06:39:55.171
# 25     25  2021-11-04T06:43:58.556
# 26     26  2021-11-04T06:48:01.936
# 27     27  2021-11-04T06:52:09.638
# 28     28  2021-11-04T06:56:13.432
# 29     29  2021-11-04T07:00:14.765
# 30     30  2021-11-04T07:04:19.847
# 31     31  2021-11-04T07:08:23.057
# 32     32  2021-11-04T07:12:26.287
# 33     33  2021-11-04T07:21:31.757
# 34     34  2021-11-04T08:26:27.749
# 35     35  2021-11-04T08:30:31.368
# 36     36  2021-11-04T08:34:34.562
# 37     37  2021-11-04T08:38:41.846
# 38     38  2021-11-04T08:42:46.668
# 39     39  2021-11-04T08:46:47.919
# 40     40  2021-11-04T08:50:53.274
# 41     41  2021-11-04T08:54:54.377
# 42     42  2021-11-04T08:58:58.855
#
#                                                  path  \
# 0   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 1   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 2   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 3   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 4   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 5   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 6   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 7   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 8   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 9   /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 10  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 11  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 12  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 13  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 14  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 15  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 16  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 17  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 18  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 19  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 20  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 21  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 22  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 23  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 24  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 25  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 26  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 27  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 28  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 29  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 30  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 31  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 32  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 33  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 34  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 35  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 36  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 37  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 38  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 39  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 40  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 41  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# 42  /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
#
#                                       file  num    object    filter  \
# 0   exposure_2021110300448_postisrccd.fits  448  HD 37795  FELH0600
# 1   exposure_2021110300449_postisrccd.fits  449  HD 37795  FELH0600
# 2   exposure_2021110300450_postisrccd.fits  450  HD 37795  FELH0600
# 3   exposure_2021110300451_postisrccd.fits  451  HD 37795  FELH0600
# 4   exposure_2021110300452_postisrccd.fits  452  HD 37795  FELH0600
# 5   exposure_2021110300453_postisrccd.fits  453  HD 37795  FELH0600
# 6   exposure_2021110300455_postisrccd.fits  455  HD 38666  FELH0600
# 7   exposure_2021110300456_postisrccd.fits  456  HD 38666  FELH0600
# 8   exposure_2021110300462_postisrccd.fits  462  HD 38666  FELH0600
# 9   exposure_2021110300468_postisrccd.fits  468  HD 38666  FELH0600
# 10  exposure_2021110300474_postisrccd.fits  474  HD 38666  FELH0600
# 11  exposure_2021110300480_postisrccd.fits  480  HD 38666  FELH0600
# 12  exposure_2021110300486_postisrccd.fits  486  HD 38666  FELH0600
# 13  exposure_2021110300492_postisrccd.fits  492  HD 38666  FELH0600
# 14  exposure_2021110300498_postisrccd.fits  498  HD 38666  FELH0600
# 15  exposure_2021110300504_postisrccd.fits  504  HD 38666  FELH0600
# 16  exposure_2021110300510_postisrccd.fits  510  HD 38666  FELH0600
# 17  exposure_2021110300516_postisrccd.fits  516  HD 38666  FELH0600
# 18  exposure_2021110300522_postisrccd.fits  522  HD 38666  FELH0600
# 19  exposure_2021110300528_postisrccd.fits  528  HD 38666  FELH0600
# 20  exposure_2021110300534_postisrccd.fits  534  HD 38666  FELH0600
# 21  exposure_2021110300540_postisrccd.fits  540  HD 38666  FELH0600
# 22  exposure_2021110300552_postisrccd.fits  552  HD 38666  FELH0600
# 23  exposure_2021110300553_postisrccd.fits  553  HD 38666  FELH0600
# 24  exposure_2021110300559_postisrccd.fits  559  HD 38666  FELH0600
# 25  exposure_2021110300565_postisrccd.fits  565  HD 38666  FELH0600
# 26  exposure_2021110300571_postisrccd.fits  571  HD 38666  FELH0600
# 27  exposure_2021110300577_postisrccd.fits  577  HD 38666  FELH0600
# 28  exposure_2021110300583_postisrccd.fits  583  HD 38666  FELH0600
# 29  exposure_2021110300589_postisrccd.fits  589  HD 38666  FELH0600
# 30  exposure_2021110300595_postisrccd.fits  595  HD 38666  FELH0600
# 31  exposure_2021110300601_postisrccd.fits  601  HD 38666  FELH0600
# 32  exposure_2021110300607_postisrccd.fits  607  HD 38666  FELH0600
# 33  exposure_2021110300613_postisrccd.fits  613  HD 38666  FELH0600
# 34  exposure_2021110300694_postisrccd.fits  694  HD 38666  FELH0600
# 35  exposure_2021110300700_postisrccd.fits  700  HD 38666  FELH0600
# 36  exposure_2021110300706_postisrccd.fits  706  HD 38666  FELH0600
# 37  exposure_2021110300712_postisrccd.fits  712  HD 38666  FELH0600
# 38  exposure_2021110300718_postisrccd.fits  718  HD 38666  FELH0600
# 39  exposure_2021110300724_postisrccd.fits  724  HD 38666  FELH0600
# 40  exposure_2021110300730_postisrccd.fits  730  HD 38666  FELH0600
# 41  exposure_2021110300736_postisrccd.fits  736  HD 38666  FELH0600
# 42  exposure_2021110300742_postisrccd.fits  742  HD 38666  FELH0600
#
#     disperser   airmass  exposure  ...  temperature  humidity  windspd  \
# 0   holo4_003  1.154825       2.0  ...          7.2      33.0      6.8
# 1   holo4_003  1.153394       2.0  ...          7.2      34.0      4.8
# 2   holo4_003  1.151521       2.0  ...          7.2      34.0      6.0
# 3   holo4_003  1.145281       1.0  ...          7.2      33.0      6.3
# 4   holo4_003  1.144045       1.0  ...          7.2      33.0      6.4
# 5   holo4_003  1.142759       1.0  ...          7.2      33.0      6.7
# 6   holo4_003  1.148628       1.0  ...          7.3      33.0      6.3
# 7   holo4_003  1.147130       1.0  ...          7.3      34.0      6.2
# 8   holo4_003  1.129715      30.0  ...          7.3      31.0      5.8
# 9   holo4_003  1.121020      30.0  ...          7.4      32.0      5.8
# 10  holo4_003  1.112729      30.0  ...          7.3      33.0      6.4
# 11  holo4_003  1.104633      30.0  ...          7.3      33.0      5.3
# 12  holo4_003  1.097056      30.0  ...          7.2      32.0      5.9
# 13  holo4_003  1.089817      30.0  ...          7.4      29.0      6.4
# 14  holo4_003  1.082750      30.0  ...          7.5      27.0      5.8
# 15  holo4_003  1.076182      30.0  ...          7.5      30.0      6.7
# 16  holo4_003  1.069920      30.0  ...          7.4      32.0      6.6
# 17  holo4_003  1.063292      30.0  ...          7.4      28.0      6.4
# 18  holo4_003  1.057678      30.0  ...          7.4      30.0      5.8
# 19  holo4_003  1.052357      30.0  ...          7.3      32.0      6.6
# 20  holo4_003  1.047237      30.0  ...          7.4      33.0      6.6
# 21  holo4_003  1.042495      30.0  ...          7.4      32.0      7.5
# 22  holo4_003  1.027853       1.0  ...          7.6      27.0      7.6
# 23  holo4_003  1.027286       1.0  ...          7.6      27.0     14.6
# 24  holo4_003  1.022363      30.0  ...          7.7      24.0      8.2
# 25  holo4_003  1.019248      30.0  ...          7.6      23.0      8.1
# 26  holo4_003  1.016383      30.0  ...          7.8      24.0      7.9
# 27  holo4_003  1.013720      30.0  ...          7.7      24.0      7.3
# 28  holo4_003  1.011346      30.0  ...          7.6      23.0      8.9
# 29  holo4_003  1.009234      30.0  ...          7.7      22.0      6.4
# 30  holo4_003  1.007330      30.0  ...          7.7      27.0      7.0
# 31  holo4_003  1.005678      30.0  ...          7.5      25.0      8.4
# 32  holo4_003  1.004261      30.0  ...          7.6      23.0      7.5
# 33  holo4_003  1.001928      30.0  ...          7.5      25.0      7.0
# 34  holo4_003  1.018841      30.0  ...          7.4      26.0      7.4
# 35  holo4_003  1.021924      30.0  ...          7.5      24.0     12.8
# 36  holo4_003  1.025256      30.0  ...          7.4      24.0      6.7
# 37  holo4_003  1.028908      30.0  ...          7.4      26.0      6.1
# 38  holo4_003  1.032791      30.0  ...          7.5      26.0      5.8
# 39  holo4_003  1.036875      30.0  ...          7.4      25.0      5.7
# 40  holo4_003  1.041304      30.0  ...          7.2      27.0      5.0
# 41  holo4_003  1.045928      30.0  ...          7.4      25.0      4.6
# 42  holo4_003  1.050899      30.0  ...          7.6      24.0      5.6
#
#     Obj-posXpix  Obj-posYpix  Dx  Dy  skip  run  quality
# 0           NaN          NaN NaN NaN        NaN      NaN
# 1           NaN          NaN NaN NaN        NaN      NaN
# 2           NaN          NaN NaN NaN        NaN      NaN
# 3           NaN          NaN NaN NaN        NaN      NaN
# 4           NaN          NaN NaN NaN        NaN      NaN
# 5           NaN          NaN NaN NaN        NaN      NaN
# 6           NaN          NaN NaN NaN        NaN      NaN
# 7           NaN          NaN NaN NaN        NaN      NaN
# 8           NaN          NaN NaN NaN        NaN      NaN
# 9           NaN          NaN NaN NaN        NaN      NaN
# 10          NaN          NaN NaN NaN        NaN      NaN
# 11          NaN          NaN NaN NaN        NaN      NaN
# 12          NaN          NaN NaN NaN        NaN      NaN
# 13          NaN          NaN NaN NaN        NaN      NaN
# 14          NaN          NaN NaN NaN        NaN      NaN
# 15          NaN          NaN NaN NaN        NaN      NaN
# 16          NaN          NaN NaN NaN        NaN      NaN
# 17          NaN          NaN NaN NaN        NaN      NaN
# 18          NaN          NaN NaN NaN        NaN      NaN
# 19          NaN          NaN NaN NaN        NaN      NaN
# 20          NaN          NaN NaN NaN        NaN      NaN
# 21          NaN          NaN NaN NaN        NaN      NaN
# 22          NaN          NaN NaN NaN        NaN      NaN
# 23          NaN          NaN NaN NaN        NaN      NaN
# 24          NaN          NaN NaN NaN        NaN      NaN
# 25          NaN          NaN NaN NaN        NaN      NaN
# 26          NaN          NaN NaN NaN        NaN      NaN
# 27          NaN          NaN NaN NaN        NaN      NaN
# 28          NaN          NaN NaN NaN        NaN      NaN
# 29          NaN          NaN NaN NaN        NaN      NaN
# 30          NaN          NaN NaN NaN        NaN      NaN
# 31          NaN          NaN NaN NaN        NaN      NaN
# 32          NaN          NaN NaN NaN        NaN      NaN
# 33          NaN          NaN NaN NaN        NaN      NaN
# 34          NaN          NaN NaN NaN        NaN      NaN
# 35          NaN          NaN NaN NaN        NaN      NaN
# 36          NaN          NaN NaN NaN        NaN      NaN
# 37          NaN          NaN NaN NaN        NaN      NaN
# 38          NaN          NaN NaN NaN        NaN      NaN
# 39          NaN          NaN NaN NaN        NaN      NaN
# 40          NaN          NaN NaN NaN        NaN      NaN
# 41          NaN          NaN NaN NaN        NaN      NaN
# 42          NaN          NaN NaN NaN        NaN      NaN
#
# [43 rows x 23 columns]

# %% [markdown]
# # Selection of input file
# - the input file is selected from the logbook list above

# %%
idx=7

# %%
print(df.iloc[idx]['file'])
# Out:
# exposure_2021110300456_postisrccd.fits

# %%
print(df.iloc[idx])
# Out:
# index                                                          7
# date                                     2021-11-04T05:17:52.968
# path           /sps/lsst/groups/auxtel/data/2022/FELH0600~hol...
# file                      exposure_2021110300456_postisrccd.fits
# num                                                          456
# object                                                  HD 38666
# filter                                                  FELH0600
# disperser                                              holo4_003
# airmass                                                  1.14713
# exposure                                                     1.0
# focus                                                   0.043359
# seeing                                                  0.973952
# pressure                                                  740.35
# temperature                                                  7.3
# humidity                                                    34.0
# windspd                                                      6.2
# Obj-posXpix                                                  NaN
# Obj-posYpix                                                  NaN
# Dx                                                           NaN
# Dy                                                           NaN
# skip
# run                                                          NaN
# quality                                                      NaN
# Name: 7, dtype: object

# %%
myhome=os.getenv("HOME")

# %%
dir_images=path_images

# %%
dir_images
# Out:
# '/sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103'

# %%
filename_image=df['file'][idx]
filename_image
# Out:
# 'exposure_2021110300456_postisrccd.fits'

# %%
target = df['object'][idx]
target
# Out:
# 'HD 38666'

# %% [markdown]
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

# %%
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

x0=300
y0=1700

if 'Obj-posXpix' in df.columns and 'Obj-posYpix' in df.columns:
    thex0 = df['Obj-posXpix'][idx]
    if not is_nan(thex0):
        x0=thex0
    they0 = df['Obj-posYpix'][idx]
    if not is_nan(they0):
        y0=they0
    
if not is_nan(x0) and not is_nan(y0):

    print("Order 0 location from logbook : ({},{})".format(x0,y0))
else:
    print("NO Order 0 location from logbook ! ")      

print(f"guess (x0,y0) = ({x0},{y0})")
# Out:
# Order 0 location from logbook : (300,1700)
# guess (x0,y0) = (300,1700)

# %% [markdown]
# ## Spectractor Configuration
#
# - Usually the Spectractor configuration file is put in local dir **./config**
#
#
# Ma suggestion, pour l'étude du centre optique via les scans des hologrammes, est de **mettre SPECTRACTOR_COMPUTE_ROTATION_ANGLE sur False** .
#
# Comme les angles ne sont pas très grands, si les marges du rectangle sont assez larges, réglables avec :
#
#     [background subtraction parameters]
#     # half transverse width of the signal rectangular window in pixels
#     PIXWIDTH_SIGNAL = 40
#
# alors le spectrogramme devrait tenir dans une boite rectangulaire même sans rotation de l'image. **L'important est de garder SPECTRACTOR_DECONVOLUTION_FFM à True car c'est lui qui te donnera l'angle de l'axe de dispersion ajusté sur les données, dont la valeur sera dans le mot clé ROTANGLE du header de sortie**.

# %%
rootfilename = filename_image.split(".")[0]
rootfilename_split =  rootfilename.split("_") 
filenumberdir = rootfilename_split[1]

# %%
path_output_spectractor
# Out:
# '/sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103'

# %%
configdir
# Out:
# 'config_DECONVOLUTION_FFMvNov2022'

# %%
# Fullfilename
filename=os.path.join(dir_images,filename_image)


# subdirectory
#subdir=filename_image.split(".")[0]
subdir=filenumberdir

# final output directory (where results will be copied to be backed up at the end)
finalpath_output_spectractor=os.path.join(path_output_spectractor,subdir)


# local directories to put spectra and plots
    
if configdir =="":
    output_directory="./outputs_process_" + DATE  + '_' + dispersername +'_nb_' + str(idx+1)
    output_figures="figures_process_" + DATE + '_' + dispersername + '_nb_' + str(idx+1)
else:
    output_directory = "./outputs_process_"+ DATE +"_"+ filterdispersername + "_" + configdir + "_nb_" + str(idx+1)
    output_figures   = "./figures_process_"+ DATE +"_"+ filterdispersername + "_" + configdir + "_nb_" + str(idx+1)
    
    

#guess = [300,1700]
guess = [350,1700]

# configuration

config=configfilename    
target=df.iloc[idx]["object"]

# %%
print(f"finalpath_output_spectractor = {finalpath_output_spectractor}")
print(f"output_directory = {output_directory}")
print(f"output_figures = {output_figures}")
print(f"config filename = {config}")
# Out:
# finalpath_output_spectractor = /sps/lsst/groups/auxtel/data/2022/OutputSpectractor/postISRCCD/FELH0600~holo4_003/config_DECONVOLUTION_FFMvNov2022/20211103/2021110300456
# output_directory = ./outputs_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8
# output_figures = ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8
# config filename = ./config/auxtel_config_holo_DECONVOLUTION_FFMvNov2022.ini

# %%
def cleandir(path):
    if os.path.isdir(path):
        files=os.listdir(path)
        if len(files) > 0:
            for f in files:
                if os.path.isdir(os.path.join(path,f)):
                    if f==".ipynb_checkpoints":
                        shutil.rmtree(os.path.join(path,f))
                    else:
                        print(" Cannot remove this directory {}".format(os.path.join(path,f)))
                else:
                    os.remove(os.path.join(path,f))

# %%
if not os.path.isdir(output_directory):
    os.mkdir(output_directory)
else:
    cleandir(output_directory)
    
# manage subdirs spectrum/ and plots/

if not os.path.isdir(output_figures):
    os.mkdir(output_figures)
else:
    cleandir(output_figures)

# %% [markdown]
# # Configuration of the Spectractor running mode

# %%
parameters.LSST_SAVEFIGPATH=True
parameters.LSST_SAVEFIGPATH=output_figures

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

# %%
target_name_sel0 = find_target_name(target)
print(f"target_name_sel0 = {target_name_sel0}")
#target_name_sel0 = ''.join(target.split())
#target_name_sel1 = target_name_sel0.encode(encoding='UTF-8',errors='strict')
#target_name_sel = target_name_sel0.encode()
target_name_sel = target_name_sel0.encode(encoding="ascii", errors="ignore")
print(f'target_name_sel = {target_name_sel}')
#target_name_sel=f"{target_name_sel}"
# Out:
# target_name_sel0 = HD 38666
# target_name_sel = b'HD 38666'

# %% [markdown]
# ## Load the image in the new image file with Spectractor

# %%
image=Image(file_name=filename, disperser_label=disperser_label,target_label=target_name_sel, config=config)
# Out:
# No rebinning: parameters.REBIN is forced to 1.
# 2022-11-08 09:06:35  Image      check_statistical_error WARNING
# 	Fitted read out noise seems to be different than input readout noise. Fit=8.309574417531536 but average of self.read_out_noise is 8.5.

# %%
image.data.shape
# Out:
# (4072, 4000)

# %% [markdown]
# ## Show relevant parameters

# %%
parameters.LSST_SAVEFIGPATH=True
parameters.LSST_SAVEFIGPATH=output_figures

# %%
image.header["FILTER"]
# Out:
# 'FELH0600'

# %%
image.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'LSST DM Header Service'
# TIMESYS = 'TAI     '
# DATE    = '2021-11-04T05:17:19.895'
# DATE-OBS= '2021-11-04T05:17:19.895'
# DATE-BEG= '2021-11-04T05:17:52.968'
# DATE-END= '2021-11-04T05:17:54.212'
# MJD     =     59522.2203691576
# MJD-OBS =     59522.2207519478
# MJD-BEG =     59522.2207519478
# MJD-END =      59522.220766342
# OBSID   = 'AT_O_20211103_000456'
# GROUPID = '2021-11-04T05:17:47.777'
# IMGTYPE = 'OBJECT  '
# BUNIT   = 'adu     '
# FACILITY= 'Vera C. Rubin Observatory'
# TELESCOP= 'LSST AuxTelescope'
# INSTRUME= 'LATISS  '
# OBSERVER= 'LSST    '
# OBS-LONG=   -70.74941699999999
# OBS-LAT =           -30.244639
# OBS-ELEV=               2663.0
# OBSGEO-X=           1818938.94
# OBSGEO-Y=          -5208470.95
# OBSGEO-Z=          -3195172.08
# RA      =    86.49956374999999
# DEC     =    -32.3064344444444
# RASTART =    86.50860463818751
# DECSTART=    -32.2714765682665
# RAEND   =     86.5085451027318
# DECEND  =    -32.2706351218998
# ROTPA   =     354.725127670165
# ROTCOORD= 'sky     '
# HASTART =    -2.29807637181429
# ELSTART =     60.6247525497311
# AZSTART =     102.916129608173
# AMSTART =     1.14713001232324
# HAEND   =    -2.29701585960461
# ELEND   =     60.6387930198543
# AZEND   =     102.911757160444
# AMEND   =     1.14697953175521
# INSTPORT=                    2
# ATM3PORT=                    2
# TRACKSYS= 'SIDEREAL'
# FOCUSZ  =   0.0433590225875378
# OBJECT  = 'HD 38666'
# DOMEAZ  =               103.91
# SHUTLOWR=                  0.0
# SHUTUPPR=                100.0
# CAMCODE = 'AT      '
# CONTRLLR= 'O       '
# DAYOBS  = '20211103'
# SEQNUM  =                  456
# TESTTYPE=
# EMUIMAGE= ''
# TSTAND  =
# IMAGETAG= 'd3924aea97d7033c'
# OBSANNOT= ''
# TEMP_SET=   -94.15000152587891
# CCDTEMP =    -90.2624588012695
# FILTBAND= 'Empty   '
# FILTER  = 'FELH0600'
# FILTSLOT=                    3
# GRATING = 'holo4_003'          / name of the disperser
# GRATBAND= 'Empty   '
# GRATSLOT=                    3
# LINSPOS =    67.99900054931641
# EXPTIME =                  1.0
# SHUTTIME=
# DARKTIME=       1.331782579422
# AIRTEMP =                  7.3
# PRESSURE=               740.35
# HUMIDITY=                 34.0
# WINDSPD =                  6.2
# WINDDIR =                313.0
# SEEING  =    0.973951578140259
# FILENAME= 'AT_O_20211103_000456.fits'
# HEADVER = '2.9.2   '
# CHECKSUM=
# DATASUM =
# CCD_MANU= 'ITL     '
# CCD_TYPE=                    2
# CCD_SERN= '20862   '
# LSST_NUM= 'ITL-3800C-068'
# SEQCKSUM= '2552520002'
# SEQNAME = 'FP_ITL_2s_ir2_v25.seq'
# REBNAME = 'Unknown '
# CONTNUM = '412227310'
# CCDSLOT = 'S00     '
# RAFTBAY = 'R00     '
# OVERH   =                   64
# OVERV   =                   48
# PREH    =                    0
# INHERIT =                    T
# EXTNAME = 'Segment10'
# DATASEC = '[1:509,1:2000]'
# DETSEC  = '[509:1,1:2000]'
# DETSIZE = '[1:4072,1:4000]'
# DTV1    =                  510
# DTV2    =                    0
# DTM1_1  =                 -1.0
# DTM2_2  =                  1.0
# DTM1_2  =                    0
# DTM2_1  =                    0
# HIERARCH ASTRO METADATA FIX MODIFIED = T
# HIERARCH ASTRO METADATA FIX DATE = '2022-10-30T20:41:12.085173'
# HIERARCH ASTRO METADATA FIX VERSION = 'g66e8411885+78f5e69161'
# HA      =    -2.29754611570945
# CAM_ROT =   -84.72512767016502
# PARANGLE=   -95.26902155736136 / parallactic angle in degree
# AIRMASS =    1.147054772039225
# OUTTEMP =                  7.3
# OUTPRESS=               740.35
# OUTHUM  =                 34.0
# CCDREBIN=                    1
# TARGET  = 'HD 38666'           / name of the target in the image
# REDSHIFT= '0.000364'           / redshift of the target
# ROTANGLE=                    0 / [deg] angle of the dispersion axis
# D2CCD   =    180.9990005493164 / [mm] distance between disperser and CCD
# COMMENT ["  FITS (Flexible Image Transport System) format is defined in 'Astrono
# COMMENT my", "  and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376.
# COMMENT .359H", "= '        '", '---- Date, night and basic image information --
# COMMENT --', "= '        '", '---- Telescope info, location, observer ----', "=
# COMMENT '        '", '---- Pointing info, etc. ----', "= '        '", '---- TAN
# COMMENT Projection ----', "= '        '", '---- Image-identifying used to build
# COMMENT OBS-ID ----', "= '        '", '---- Test Stand information ----', "= '
# COMMENT       '", '---- Information from Camera (Common block) ----', "= '
# COMMENT   '", '---- Information from Camera ----', "= '        '", '---- Filter/
# COMMENT grating information ----', "= '        '", '---- Exposure-related inform
# COMMENT ation ----', "= '        '", '---- Weather information ----', "= '
# COMMENT   '", '---- Header information ----', "= '        '", '---- Checksums --
# COMMENT --', '---- Information from Camera per sensor ----', "= '        '", '--
# COMMENT -- Geometry from Camera ----']

# %% [markdown]
# # Plot image and find the target position
#
# - this image plotting is used to find the order 0 location to be set in logbook
#
# - for the moment this is humanly done

# %% [markdown]
# ## Load the new image file with Spectractor

# %%
import matplotlib.pyplot as plt
title="{}) {}".format(idx,filename_image)
image.plot_image(figsize=(12, 10),scale="log",title=title)
plt.show()

# %% [markdown]
# - note now the position are written in the make_logbook.ipynb notebook

# %% [markdown]
# ## Set the 0th order location to be provided to Spectractor

# %%
filename_image
# Out:
# 'exposure_2021110300456_postisrccd.fits'

# %% [markdown]
# ## Let Spectractor find the location of the 0th order

# %%
parameters.VERBOSE = True
parameters.DEBUG = True
#x1, y1 = find_target(image, guess,rotated=False, use_wcs=False)
x1, y1 = find_target(image, guess,rotated=False)
# Out:
# 2022-11-08 09:06:49  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                c1_0                c0_1
#     ------------------ -------------------- ------------------
#     30.691480627585655 -0.22620987767409104 0.1964619626417343
# 2022-11-08 09:06:56  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 7 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-11-08 09:06:56  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 2 iterations because the relative change of cost is below ftol=5e-05.

# %%
print(x1,y1)
# Out:
# 311.31643520585675 1733.7661215441858

# %% [markdown]
# ## Check the location of 0th order and Analysis of the quality of its focus

# %%
if x1>100:
    WID=100
else:
    WID=50
    

thumbnail=np.copy(image.data[int(y1)-WID:int(y1)+WID,int(x1)-WID:int(x1)+WID])
thumbnail_y=thumbnail.sum(axis=1)
thumbnail_x=thumbnail.sum(axis=0)
xx=np.linspace(int(x1)-WID,int(x1)+WID,len(thumbnail_x))
yy=np.linspace(int(y1)-WID,int(y1)+WID,len(thumbnail_y))
k0=kurtosis(thumbnail,axis=None,bias=True,fisher=True)
kx=kurtosis(thumbnail_x,bias=True,fisher=True)
ky=kurtosis(thumbnail_y,bias=True,fisher=True)
s0=skew(thumbnail,axis=None,bias=True)
sx=skew(thumbnail_x,bias=True)
sy=skew(thumbnail_y,bias=True)

# %%
shape_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}, Skx = {:3.3f}, Sky = {:3.3f} \n'.format(s0,sx,sy),
        r'kurtosis : K0  = {:3.3f}, Kx  = {:3.3f},  Ky = {:3.3f}'.format(k0,kx,ky)))

# %%
skew_str='\n'.join((
        r'skew     : Sk0 = {:3.3f}'.format(s0),
        r'             : Skx = {:3.3f}'.format(sx),
        r'             : Sky = {:3.3f}'.format(sy)))

# %%
kurt_str='\n'.join((
        r'kurtosis : K0 = {:3.3f}'.format(k0),
        r'             : Kx = {:3.3f}'.format(kx),
        r'             : Ky = {:3.3f}'.format(ky)))

# %%
kurtosis_test_prob=kurtosistest(thumbnail,axis=None).pvalue
skew_test_prob=skewtest(thumbnail,axis=None).pvalue
normal_test_prob=normaltest(thumbnail,axis=None).pvalue

# %%
kurtosis_test_val=kurtosistest(thumbnail,axis=None).statistic
skew_test_val=skewtest(thumbnail,axis=None).statistic
normal_test_val=normaltest(thumbnail,axis=None).statistic

# %%
kurtosis_test_prob_x=kurtosistest(thumbnail_x).pvalue
skew_test_prob_x=skewtest(thumbnail_x).pvalue
normal_test_prob_x=normaltest(thumbnail_x).pvalue

# %%
kurtosis_test_prob_y=kurtosistest(thumbnail_y).pvalue
skew_test_prob_y=skewtest(thumbnail_y).pvalue
normal_test_prob_y=normaltest(thumbnail_y).pvalue

# %%
skew_str='\n'.join((
    r'skew     : Sk0 = {:3.3f}'.format(s0),
    r'             : Skx = {:3.3f}'.format(sx),
    r'             : Sky = {:3.3f}'.format(sy),
    r'             : p_test   = {:3.3e}'.format(skew_test_prob),
    r'             : p_test_x = {:3.3e}'.format(skew_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(skew_test_prob_y)))

# %%
kurt_str='\n'.join((
    r'kurtosis : K0 = {:3.3f}'.format(k0),
    r'             : Kx = {:3.3f}'.format(kx),
    r'             : Ky = {:3.3f}'.format(ky),
    r'             : p_test   = {:3.3e}'.format(kurtosis_test_prob),
    r'             : p_test_x = {:3.3e}'.format(kurtosis_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(kurtosis_test_prob_y)))

# %%
norm_str='\n'.join((
    r'normal  : p_test   = {:3.3e}'.format(normal_test_prob),
    r'             : p_test_x = {:3.3e}'.format(normal_test_prob_x),
    r'             : p_test_y = {:3.3e}'.format(normal_test_prob_y)))

# %%
props = dict(boxstyle='round',edgecolor="w",facecolor="w", alpha=0.5)

# %%
#matplotlib.pyplot.hist(x, 
#                       bins=10, 
#                       range=None, 
#                       normed=False, 
#                       weights=None, 
#                       cumulative=False, 
#                       bottom=None, 
#                       histtype=u'bar', 
#                       align=u'mid', 
#                       orientation=u'vertical', 
#                       rwidth=None, 
#                       log=False, 
#                       color=None, 
#                       label=None, 
#                       stacked=False, 
#                       hold=None, 
#                       **kwargs)

# %%
fig=plt.figure(figsize=(10,10))
fig.subplots_adjust(left=0.12, right=0.95, wspace=0.3,
                    bottom=0.15, top=0.9)

ax=fig.add_subplot(222)
ax.imshow(thumbnail,origin="lower",extent=(int(x1)-WID,int(x1)+WID,int(y1)-WID,int(y1)+WID))
ax.set_xlabel("X")
ax.set_ylabel("Y")

ax=fig.add_subplot(221)
base = plt.gca().transData
rot = transforms.Affine2D().rotate_deg(-90)
#ax.plot(yy,thumbnail_y,"g",rotation=u'vertical')
ax.plot(-yy,thumbnail_y,"g",transform= rot + base)
ax.set_ylabel("Y")

ax=fig.add_subplot(224)
ax.plot(xx,thumbnail_x,"b")
ax.set_xlabel("X")
plt.tight_layout()

ax=fig.add_subplot(223)
ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.set_xticklabels([])
ax.set_xticks([])
ax.set_yticks([])

ax.text(0.05, 0.9, skew_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.55, kurt_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
ax.text(0.05, 0.2, norm_str, transform=ax.transAxes, fontsize=12,verticalalignment='top', bbox=props)
plt.suptitle(title)
# Out:
# Text(0.5, 0.98, '7) exposure_2021110300456_postisrccd.fits')

# %%
# Usually stop here if one just want to get the 0th order location
if not FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR:
    assert False
else:
    assert True

# %% [markdown]
# # Go for spectrum reconstruction

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

parameters.DEBUG=True
parameters.VERBOSE=True
parameters.DISPLAY=True
parameters.LIVE_FIT=False

# %%
filename
# Out:
# '/sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103/exposure_2021110300456_postisrccd.fits'

# %%
output_directory
# Out:
# './outputs_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8'

# %%
if FLAG_RUNWITHEXCEPTIONS:
    try:
        spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target_name_sel, disperser_label=disperser_label, config=config)
    except:
        errtype = sys.exc_info()[0]  # E.g. <class 'PermissionError'>
        description = sys.exc_info()[1]   # E.g. [Errno 13] Permission denied: ...
        
        print("\t +++++++++++++++++++++ Exception occured +++++++++++++++++++++++++++++++++++++++++")
        print(f"\t >>>>>  errtype = {errtype}")
        print(f"\t >>>>>> description = {description}")
else:
    spectrum = Spectractor(filename, output_directory, guess=[x1,y1], target_label=target_name_sel, disperser_label=disperser_label, config=config)
# Out:
# 2022-11-08 09:06:58  spectractor.extractor.extractor Spectractor          INFO
# 	Start SPECTRACTOR
# 2022-11-08 09:06:58  Image      load_AUXTEL_image    INFO
# 	Loading AUXTEL image /sps/lsst/groups/auxtel/data/2022/FELH0600~holo4_003/20211103/exposure_2021110300456_postisrccd.fits...
# 2022-11-08 09:06:58  Image      load_AUXTEL_image    INFO
# 	Image loaded
# No rebinning: parameters.REBIN is forced to 1.
# Section: paths
# x disperser_dir: extractor/dispersers/	=> parameters.DISPERSER_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/	 <class 'str'>
# x throughput_dir: simulation/AuxTelThroughput/	=> parameters.THROUGHPUT_DIR: /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/simulation/AuxTelThroughput/	 <class 'str'>
# Section: pipeline
# x spectractor_fit_target_centroid: fit	=> parameters.SPECTRACTOR_FIT_TARGET_CENTROID: fit	 <class 'str'>
# x spectractor_compute_rotation_angle: disperser	=> parameters.SPECTRACTOR_COMPUTE_ROTATION_ANGLE: disperser	 <class 'str'>
# x spectractor_deconvolution_psf2d: False	=> parameters.SPECTRACTOR_DECONVOLUTION_PSF2D: False	 <class 'bool'>
# x spectractor_deconvolution_ffm: True	=> parameters.SPECTRACTOR_DECONVOLUTION_FFM: True	 <class 'bool'>
# x spectractor_deconvolution_sigma_clip: 100	=> parameters.SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP: 100	 <class 'int'>
# Section: instrument
# x obs_name: AUXTEL	=> parameters.OBS_NAME: AUXTEL	 <class 'str'>
# x obs_altitude: 2.66299616375123	=> parameters.OBS_ALTITUDE: 2.66299616375123	 <class 'float'>
# x obs_latitude: -30.2446389756252	=> parameters.OBS_LATITUDE: -30.2446389756252	 <class 'float'>
# x obs_diameter: 1.20	=> parameters.OBS_DIAMETER: 1.2 m	 <class 'astropy.units.quantity.Quantity'>
# x obs_epoch: J2000.0	=> parameters.OBS_EPOCH: J2000.0	 <class 'str'>
# x obs_transmission_systematics: 0.005	=> parameters.OBS_TRANSMISSION_SYSTEMATICS: 0.005	 <class 'float'>
# x obs_object_type: STAR	=> parameters.OBS_OBJECT_TYPE: STAR	 <class 'str'>
# x obs_telescope_transmission: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	=> parameters.OBS_TELESCOPE_TRANSMISSION: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	 <class 'str'>
# x obs_full_instrument_transmisson: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	=> parameters.OBS_FULL_INSTRUMENT_TRANSMISSON: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	 <class 'str'>
# x obs_quantum_efficiency: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	=> parameters.OBS_QUANTUM_EFFICIENCY: multispectra_holo4_003_HD142331_AuxTel_throughput.txt	 <class 'str'>
# x obs_camera_rotation: 0	=> parameters.OBS_CAMERA_ROTATION: 0	 <class 'int'>
# x obs_camera_dec_flip_sign: 1	=> parameters.OBS_CAMERA_DEC_FLIP_SIGN: 1	 <class 'int'>
# x obs_camera_ra_flip_sign: 1	=> parameters.OBS_CAMERA_RA_FLIP_SIGN: 1	 <class 'int'>
# Section: CCD
# x ccd_imsize: 4096	=> parameters.CCD_IMSIZE: 4096	 <class 'int'>
# x ccd_pixel2mm: 10e-3	=> parameters.CCD_PIXEL2MM: 0.01	 <class 'float'>
# x ccd_pixel2arcsec: 0.0952	=> parameters.CCD_PIXEL2ARCSEC: 0.0952	 <class 'float'>
# x ccd_maxadu: 170000	=> parameters.CCD_MAXADU: 170000	 <class 'int'>
# x ccd_gain: 1.1	=> parameters.CCD_GAIN: 1.1	 <class 'float'>
# x ccd_rebin: 1	=> parameters.CCD_REBIN: 1	 <class 'int'>
# Section: spectrograph
# x distance2ccd: 181	=> parameters.DISTANCE2CCD: 181	 <class 'int'>
# x distance2ccd_err: 0.4	=> parameters.DISTANCE2CCD_ERR: 0.4	 <class 'float'>
# x grating_order_2over1: 0.1	=> parameters.GRATING_ORDER_2OVER1: 0.1	 <class 'float'>
# Section: search windows
# x xwindow: 100	=> parameters.XWINDOW: 100	 <class 'int'>
# x ywindow: 100	=> parameters.YWINDOW: 100	 <class 'int'>
# x xwindow_rot: 50	=> parameters.XWINDOW_ROT: 50	 <class 'int'>
# x ywindow_rot: 50	=> parameters.YWINDOW_ROT: 50	 <class 'int'>
# x pixshift_prior: 5	=> parameters.PIXSHIFT_PRIOR: 5	 <class 'int'>
# Section: rotation parameters
# x rot_prefilter: True	=> parameters.ROT_PREFILTER: True	 <class 'bool'>
# x rot_order: 5	=> parameters.ROT_ORDER: 5	 <class 'int'>
# x rot_angle_min: -10	=> parameters.ROT_ANGLE_MIN: -10	 <class 'int'>
# x rot_angle_max: 10	=> parameters.ROT_ANGLE_MAX: 10	 <class 'int'>
# Section: spectrum range
# x lambda_min: 300	=> parameters.LAMBDA_MIN: 300	 <class 'int'>
# x lambda_max: 1100	=> parameters.LAMBDA_MAX: 1100	 <class 'int'>
# x spec_order: 1	=> parameters.SPEC_ORDER: 1	 <class 'int'>
# Section: background subtraction parameters
# x pixwidth_signal: 20	=> parameters.PIXWIDTH_SIGNAL: 20	 <class 'int'>
# x pixdist_background: 140	=> parameters.PIXDIST_BACKGROUND: 140	 <class 'int'>
# x pixwidth_background: 40	=> parameters.PIXWIDTH_BACKGROUND: 40	 <class 'int'>
# x pixwidth_boxsize: 20	=> parameters.PIXWIDTH_BOXSIZE: 20	 <class 'int'>
# Section: PSF
# x psf_type: MoffatGauss	=> parameters.PSF_TYPE: MoffatGauss	 <class 'str'>
# x psf_poly_order: 2	=> parameters.PSF_POLY_ORDER: 2	 <class 'int'>
# x psf_fit_reg_param: 0.1	=> parameters.PSF_FIT_REG_PARAM: 0.1	 <class 'float'>
# x psf_pixel_step_transverse_fit: 50	=> parameters.PSF_PIXEL_STEP_TRANSVERSE_FIT: 50	 <class 'int'>
# x psf_fwhm_clip: 2	=> parameters.PSF_FWHM_CLIP: 2	 <class 'int'>
# Section: detection line algorithm parameters
# x calib_bgd_order: 3	=> parameters.CALIB_BGD_ORDER: 3	 <class 'int'>
# x calib_peak_width: 7	=> parameters.CALIB_PEAK_WIDTH: 7	 <class 'int'>
# x calib_bgd_width: 15	=> parameters.CALIB_BGD_WIDTH: 15	 <class 'int'>
# x calib_savgol_window: 5	=> parameters.CALIB_SAVGOL_WINDOW: 5	 <class 'int'>
# x calib_savgol_order: 2	=> parameters.CALIB_SAVGOL_ORDER: 2	 <class 'int'>
# Section: plot settings
# x paper: False	=> parameters.PAPER: False	 <class 'bool'>
# x linewidth: 2	=> parameters.LINEWIDTH: 2	 <class 'int'>
# x plot_dir: plots	=> parameters.PLOT_DIR: plots	 <class 'str'>
# x save: False	=> parameters.SAVE: False	 <class 'bool'>
# 2022-11-08 09:06:58  Image      load_image           INFO
# 	Loading disperser holo4_003...
# 2022-11-08 09:06:58  Hologram   load_specs           INFO
# 	Load disperser holo4_003:
# 	from /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg/spectractor/extractor/dispersers/holo4_003
# 2022-11-08 09:06:58  Hologram   load_specs           INFO
# 	Grating characteristics:
# 	N = 156.00 +/- 1.00 grooves/mm
# 	Average tilt of 0.2 degrees
# 2022-11-08 09:07:03  Image      check_statistical_error WARNING
# 	Fitted read out noise seems to be different than input readout noise. Fit=8.309574417531536 but average of self.read_out_noise is 8.5.
# 2022-11-08 09:07:03  TelescopeTransmission reset_lambda_range   INFO
# 	With filter FELH0600, set parameters.LAMBDA_MIN=583 and parameters.LAMBDA_MAX=1069.
# 2022-11-08 09:07:03  Star       load                 INFO
# 	Simbad:
#  MAIN_ID        RA           DEC      ... Z_VALUE_2 SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... --------- ----------------
# * mu. Col 05 45 59.8950 -32 18 23.162 ... 0.0003640                1
# 2022-11-08 09:07:05  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the image with guess=[ 311.31643521 1733.76612154]...
# 2022-11-08 09:07:05  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                c1_0                c0_1
#     ------------------ ------------------- --------------------
#     24.712270923095456 0.00510746843141318 0.007571201199202011
# 2022-11-08 09:07:06  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 7 iterations because the relative change of cost is below ftol=1.25e-05.
# 2022-11-08 09:07:07  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 2 iterations because the relative change of cost is below ftol=5e-05.
# 2022-11-08 09:07:07  Image      find_target          INFO
# 	X,Y target position in pixels: 311.308,1733.771
# 2022-11-08 09:07:07  Image      turn_image           INFO
# 	Rotate the image with angle theta=0.20 degree
# 2022-11-08 09:07:19  spectractor.extractor.extractor Spectractor          INFO
# 	Search for the target in the rotated image...
# 2022-11-08 09:07:19  spectractor.tools fit_poly2d_outlier_removal INFO
# 	Model: Polynomial2D
# Inputs: ('x', 'y')
# Outputs: ('z',)
# Model set size: 1
# Degree: 1
# Parameters:
#            c0_0                 c1_0                c0_1
#     ------------------ --------------------- ------------------
#     189.45745452799204 -0.037116966821006306 0.6036310081339927
# 2022-11-08 09:07:19  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 4 iterations because the relative change of cost is below ftol=5e-05.
# 2022-11-08 09:07:20  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 3 iterations because the relative change of cost is below ftol=0.0002.
# 2022-11-08 09:07:21  Image      find_target          INFO
# 	X,Y target position in pixels: 317.433,1746.087
# 2022-11-08 09:07:21  Spectrum   __init__             INFO
# 	Spectrum info copied from image
# 2022-11-08 09:07:21  TelescopeTransmission reset_lambda_range   INFO
# 	With filter FELH0600, set parameters.LAMBDA_MIN=590.0000000000016 and parameters.LAMBDA_MAX=1061.2000000001087.
# 2022-11-08 09:07:21  spectractor.extractor.extractor Spectractor          INFO
# 	  ======================= PSF1D Extraction ====================================
# 2022-11-08 09:07:21  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	  ======================= extract_spectrum_from_image =============================
# 2022-11-08 09:07:21  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extracting spectrum from image: spectrum with width 2*20 pixels and background from 140 to 180 pixels
# 2022-11-08 09:07:21  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop rotated image [1990:3355,1566:1926] (size (1365, 360))
# 2022-11-08 09:07:23  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	  ======================= Fit the transverse profile =============================
# 2022-11-08 09:07:23  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Start PSF1D transverse fit...
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:23  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev has a null Jacobian; parameter is fixed at its last known current value (1.0).
# 2022-11-08 09:07:28  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_1 has a null Jacobian; parameter is fixed at its last known current value (-2.392299886580566e-16).
# 2022-11-08 09:07:28  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_2 has a null Jacobian; parameter is fixed at its last known current value (-2.523831515379806e-16).
# 2022-11-08 09:07:28  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=3.5449e+05 initial chisq_red=6.4925
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.0370469   0.19647802  0.26120422 -0.14916798  0.63438509  0.49944087
#   0.72576065  1.41849704  2.00937637 -0.07747754 -0.05331213 -0.07851437
#   0.62378286]
# 	New parameters: [ 1.68968599  1.47373658  0.09416128  4.04000538 -7.50235417 -7.04917243
#   0.90109263 -1.31423462 -1.56747617 -0.17813941 -0.03076274 -0.05281448
#   1.62378286]
# 	Final cost=2.4921e+05 final chisq_red=4.5642 computed in 1.21s
# 2022-11-08 09:07:29  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=2.4921e+05 initial chisq_red=4.5642
# 		 Line search: alpha_min=1.62 iter=1 funcalls=5
# 	Parameter shifts: [ 2.34401269e-02  4.56278976e-03 -1.05287338e-01  1.01621627e+00
#  -2.10675751e+00 -4.27319328e+00  2.41514975e-01 -6.01720553e-01
#  -9.30620901e-01 -3.59040453e-03 -3.49659484e-02 -3.98900654e-01
#   8.11897928e-01]
# 	New parameters: [ 1.71312612e+00  1.47829937e+00 -1.11260536e-02  5.05622165e+00
#  -9.60911168e+00 -1.13223657e+01  1.14260761e+00 -1.91595517e+00
#  -2.49809707e+00 -1.81729813e-01 -6.57286869e-02 -4.51715132e-01
#   2.43568078e+00]
# 	Final cost=1.7377e+05 final chisq_red=3.1826 computed in 1.06s
# 2022-11-08 09:07:30  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=1.7377e+05 initial chisq_red=3.1826
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00726101 -0.03325794  0.01416583 -0.16686062  0.48843867 -0.36865087
#   0.075213    0.16028319  0.1674537  -0.05549977 -0.0294767  -0.1209137
#   0.22082684]
# 	New parameters: [ 1.70586511e+00  1.44504142e+00  3.03977510e-03  4.88936103e+00
#  -9.12067301e+00 -1.16910166e+01  1.21782061e+00 -1.75567199e+00
#  -2.33064337e+00 -2.37229582e-01 -9.52053886e-02 -5.72628832e-01
#   2.65650763e+00]
# 	Final cost=1.6736e+05 final chisq_red=3.0653 computed in 0.94s
# 2022-11-08 09:07:31  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=3: initial cost=1.6736e+05 initial chisq_red=3.0653
# 		 Line search: alpha_min=1.92 iter=0 funcalls=5
# 	Parameter shifts: [-0.02449501 -0.05725595 -0.08950562  0.50488881 -0.65824117 -0.03038185
#   0.08471655 -0.14754216 -0.18022914 -0.00538241 -0.1069346   0.05081293
#  -0.10115285]
# 	New parameters: [  1.68137011   1.38778548  -0.08646585   5.39424984  -9.77891419
#  -11.72139842   1.30253716  -1.90321414  -2.51087251  -0.242612
#   -0.20213999  -0.5218159    2.55535478]
# 	Final cost=1.5387e+05 final chisq_red=2.8181 computed in 0.98s
# 2022-11-08 09:07:32  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=4: initial cost=1.5387e+05 initial chisq_red=2.8181
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.0094873  -0.03206215 -0.04293131 -0.22946814  0.58016255  0.28182728
#   0.00400687  0.1936803   0.24557627 -0.03108413  0.01845489 -0.05104218
#   0.07712805]
# 	New parameters: [  1.6718828    1.35572332  -0.12939716   5.1647817   -9.19875163
#  -11.43957113   1.30654402  -1.70953384  -2.26529624  -0.27369613
#   -0.1836851   -0.57285808   2.63248283]
# 	Final cost=1.5293e+05 final chisq_red=2.8009 computed in 0.97s
# 2022-11-08 09:07:33  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=5: initial cost=1.5293e+05 initial chisq_red=2.8009
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00651757 -0.02043647 -0.02957878  0.19920371 -0.27834207  0.11747862
#   0.01959144 -0.07371486 -0.07730425  0.01446204 -0.0288557   0.04450076
#  -0.03671432]
# 	New parameters: [  1.66536523   1.33528685  -0.15897594   5.36398541  -9.47709371
#  -11.32209251   1.32613547  -1.7832487   -2.3426005   -0.25923409
#   -0.2125408   -0.52835732   2.59576851]
# 	Final cost=1.5143e+05 final chisq_red=2.7735 computed in 1.02s
# 2022-11-08 09:07:34  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=6: initial cost=1.5143e+05 initial chisq_red=2.7735
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00193339 -0.00355188 -0.00675692 -0.08623781  0.26737632  0.02049818
#   0.00737237  0.09428409  0.11831785 -0.01485846 -0.00086435 -0.05838326
#   0.02504031]
# 	New parameters: [  1.66343184   1.33173497  -0.16573286   5.2777476   -9.20971739
#  -11.30159433   1.33350784  -1.68896461  -2.22428264  -0.27409256
#   -0.21340515  -0.58674058   2.62080882]
# 	Final cost=1.5083e+05 final chisq_red=2.7624 computed in 0.98s
# 2022-11-08 09:07:35  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=7: initial cost=1.5083e+05 initial chisq_red=2.7624
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00080347 -0.00229591 -0.0014385   0.14059541 -0.13982629  0.25744938
#   0.01752708 -0.04152603 -0.03190944  0.00180989 -0.01601589  0.06028096
#  -0.01856092]
# 	New parameters: [  1.66262838   1.32943906  -0.16717136   5.418343    -9.34954368
#  -11.04414495   1.35103492  -1.73049064  -2.25619208  -0.27228266
#   -0.22942104  -0.52645962   2.6022479 ]
# 	Final cost=1.4996e+05 final chisq_red=2.7466 computed in 1.05s
# 2022-11-08 09:07:36  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=8: initial cost=1.4996e+05 initial chisq_red=2.7466
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00107538 -0.00116032 -0.00328918 -0.00407122  0.10629441 -0.15849353
#   0.01892785  0.06481809  0.09343085 -0.00404742 -0.01749826 -0.0947359
#   0.05014889]
# 	New parameters: [  1.661553     1.32827874  -0.17046055   5.41427178  -9.24324927
#  -11.20263848   1.36996276  -1.66567254  -2.16276123  -0.27633009
#   -0.2469193   -0.62119552   2.65239679]
# 	Final cost=1.4918e+05 final chisq_red=2.7321 computed in 0.96s
# 2022-11-08 09:07:37  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=9: initial cost=1.4918e+05 initial chisq_red=2.7321
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00230427 -0.00357637 -0.00363685  0.22422355 -0.27254919  0.53657644
#   0.02584425 -0.11001939 -0.04631103  0.00245501 -0.00074294  0.11853934
#   0.03387363]
# 	New parameters: [  1.65924873   1.32470237  -0.1740974    5.63849534  -9.51579847
#  -10.66606203   1.39580701  -1.77569193  -2.20907226  -0.27387508
#   -0.24766224  -0.50265617   2.68627042]
# 	Final cost=1.4703e+05 final chisq_red=2.6929 computed in 1.10s
# 2022-11-08 09:07:38  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=10: initial cost=1.4703e+05 initial chisq_red=2.6929
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [-0.00086657 -0.00075685 -0.00316113  0.28062201 -0.51565905 -0.60853777
#   0.05300754 -0.09865405 -0.08484522  0.02274179 -0.04087662 -0.09570906
#   0.06876703]
# 	New parameters: [  1.65838216   1.32394551  -0.17725854   5.91911735 -10.03145752
#  -11.2745998    1.44881455  -1.87434598  -2.29391749  -0.25113328
#   -0.28853887  -0.59836523   2.75503745]
# 	Final cost=1.4667e+05 final chisq_red=2.6863 computed in 1.08s
# 2022-11-08 09:07:39  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=11: initial cost=1.4667e+05 initial chisq_red=2.6863
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00250326 -0.00237757 -0.00476843  0.08946458 -0.05046074  0.82944206
#   0.00561788 -0.10609385  0.02434288 -0.00323062  0.03918694  0.11670084
#   0.0624817 ]
# 	New parameters: [  1.65587891   1.32156794  -0.18202697   6.00858193 -10.08191826
#  -10.44515774   1.45443243  -1.98043982  -2.26957461  -0.2543639
#   -0.24935193  -0.48166439   2.81751915]
# 	Final cost=1.4488e+05 final chisq_red=2.6535 computed in 1.08s
# 2022-11-08 09:07:41  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=12: initial cost=1.4488e+05 initial chisq_red=2.6535
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [-1.59284881e-04 -8.27906957e-04 -1.19610557e-03 -5.35347106e-03
#   1.62319652e-03 -2.71516619e-01  8.62327577e-04  4.08584379e-03
#  -1.53328600e-02  7.17074450e-03 -4.09294965e-04 -4.86365904e-02
#   3.27058506e-02]
# 	New parameters: [  1.65571962   1.32074004  -0.18322308   6.00322846 -10.08029506
#  -10.71667436   1.45529475  -1.97635398  -2.28490746  -0.24719315
#   -0.24976122  -0.53030098   2.850225  ]
# 	Final cost=1.4427e+05 final chisq_red=2.6424 computed in 1.11s
# 2022-11-08 09:07:42  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=13: initial cost=1.4427e+05 initial chisq_red=2.6424
# 		 Line search: alpha_min=7.8 iter=0 funcalls=7
# 	Parameter shifts: [-0.00551103 -0.01201874 -0.01535868  0.14843559 -0.19163288  0.90412748
#  -0.04052901 -0.3490836  -0.15289293  0.09258859  0.20811751  0.2224322
#   0.20494787]
# 	New parameters: [  1.65020859   1.3087213   -0.19858176   6.15166406 -10.27192794
#   -9.81254688   1.41476575  -2.32543758  -2.4378004   -0.15460456
#   -0.04164372  -0.30786878   3.05517288]
# 	Final cost=1.4244e+05 final chisq_red=2.6087 computed in 1.29s
# 2022-11-08 09:07:43  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=14: initial cost=1.4244e+05 initial chisq_red=2.6087
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [-1.21631073e-03 -2.30250853e-03 -2.73779112e-03  1.16959576e-01
#  -2.81160148e-01 -1.14447410e+00  2.01697876e-02  1.10580184e-03
#  -7.37137847e-02  3.21919213e-02 -8.69334595e-03 -1.41466304e-01
#   7.50518030e-02]
# 	New parameters: [  1.64899228   1.30641879  -0.20131955   6.26862363 -10.55308809
#  -10.95702099   1.43493553  -2.32433178  -2.51151418  -0.12241264
#   -0.05033706  -0.44933509   3.13022468]
# 	Final cost=1.3925e+05 final chisq_red=2.5504 computed in 1.11s
# 2022-11-08 09:07:44  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=15: initial cost=1.3925e+05 initial chisq_red=2.5504
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.00813489 -0.01697489 -0.0203479   0.20947782 -0.54637592  0.42918595
#  -0.0024429  -0.22579814 -0.12326052  0.0512402   0.0771207   0.16304441
#   0.05648833]
# 	New parameters: [  1.6408574    1.2894439   -0.22166745   6.47810145 -11.09946401
#  -10.52783504   1.43249264  -2.55012992  -2.63477471  -0.07117244
#    0.02678364  -0.28629067   3.18671301]
# 	Final cost=1.3695e+05 final chisq_red=2.5082 computed in 0.94s
# 2022-11-08 09:07:45  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=16: initial cost=1.3695e+05 initial chisq_red=2.5082
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [ 8.67020248e-04  1.38904396e-03 -5.66592354e-06 -2.31666609e-01
#   4.16617405e-01 -2.39583398e-01 -7.51993186e-03  1.59597187e-01
#   1.03621508e-01 -1.54095494e-02  2.03607569e-02 -7.51062361e-02
#   1.28950551e-01]
# 	New parameters: [  1.64172442   1.29083294  -0.22167311   6.24643484 -10.68284661
#  -10.76741844   1.42497271  -2.39053274  -2.5311532   -0.08658199
#    0.04714439  -0.36139691   3.31566356]
# 	Final cost=1.3633e+05 final chisq_red=2.4968 computed in 1.24s
# 2022-11-08 09:07:46  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=17: initial cost=1.3633e+05 initial chisq_red=2.4968
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [-0.00083855 -0.00194716 -0.00455145  0.2138344  -0.36665226  0.16331708
#   0.02513697 -0.10994746 -0.05463125  0.01574898 -0.02769193  0.02280018
#   0.02092419]
# 	New parameters: [  1.64088587   1.28888578  -0.22622456   6.46026924 -11.04949886
#  -10.60410136   1.45010967  -2.5004802   -2.58578445  -0.07083301
#    0.01945246  -0.33859672   3.33658775]
# 	Final cost=1.361e+05 final chisq_red=2.4927 computed in 1.16s
# 2022-11-08 09:07:47  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=18: initial cost=1.361e+05 initial chisq_red=2.4927
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.0002816  -0.00022122 -0.00370079 -0.04697208  0.09415613 -0.0647533
#   0.01721674  0.03590417  0.06197311 -0.00719108  0.0108244  -0.04987607
#   0.12679483]
# 	New parameters: [  1.64060427   1.28866456  -0.22992535   6.41329716 -10.95534273
#  -10.66885466   1.46732642  -2.46457602  -2.52381134  -0.07802409
#    0.03027686  -0.38847279   3.46338258]
# 	Final cost=1.3607e+05 final chisq_red=2.4921 computed in 1.07s
# 2022-11-08 09:07:49  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=19: initial cost=1.3607e+05 initial chisq_red=2.4921
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [-0.00053361 -0.00089025 -0.00132681  0.20672165 -0.35972612  0.14684418
#   0.01408409 -0.12462232 -0.09049768  0.01570098 -0.0244201   0.04617734
#  -0.0050492 ]
# 	New parameters: [ 1.64007066e+00  1.28777431e+00 -2.31252166e-01  6.62001881e+00
#  -1.13150689e+01 -1.05220105e+01  1.48141051e+00 -2.58919834e+00
#  -2.61430902e+00 -6.23231070e-02  5.85675719e-03 -3.42295455e-01
#   3.45833338e+00]
# 	Final cost=1.3592e+05 final chisq_red=2.4893 computed in 1.15s
# 2022-11-08 09:07:50  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=20: initial cost=1.3592e+05 initial chisq_red=2.4893
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [ 2.11839349e-05  3.51705759e-04  2.22929452e-04 -4.14339623e-02
#   7.53869548e-02 -6.66968921e-02  1.18599460e-03  2.35463537e-02
#   1.64598387e-02 -4.58037847e-03  7.77409879e-03 -1.55263260e-02
#   3.57835994e-02]
# 	New parameters: [  1.64009184   1.28812601  -0.23102924   6.57858485 -11.2396819
#  -10.58870737   1.4825965   -2.56565199  -2.59784918  -0.06690349
#    0.01363086  -0.35782178   3.49411698]
# 	Final cost=1.3585e+05 final chisq_red=2.4881 computed in 1.07s
# 2022-11-08 09:07:51  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=21: initial cost=1.3585e+05 initial chisq_red=2.4881
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [-0.00022691 -0.00028469 -0.00059297  0.06723845 -0.11409279  0.0488334
#   0.00723152 -0.04246718 -0.0239368   0.00386458 -0.00611019  0.01146309
#   0.01029906]
# 	New parameters: [ 1.63986493e+00  1.28784132e+00 -2.31622207e-01  6.64582330e+00
#  -1.13537747e+01 -1.05398740e+01  1.48982802e+00 -2.60811917e+00
#  -2.62178598e+00 -6.30389044e-02  7.52066545e-03 -3.46358691e-01
#   3.50441604e+00]
# 	Final cost=1.3584e+05 final chisq_red=2.488 computed in 1.05s
# 2022-11-08 09:07:52  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=22: initial cost=1.3584e+05 initial chisq_red=2.488
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.0001408   0.00018579 -0.0001426   0.00511803 -0.00024568 -0.04368956
#   0.00782155 -0.00491006  0.00136703 -0.00213805  0.0038129  -0.01196653
#   0.05556574]
# 	New parameters: [ 1.63972413e+00  1.28802712e+00 -2.31764804e-01  6.65094134e+00
#  -1.13540204e+01 -1.05835635e+01  1.49764958e+00 -2.61302922e+00
#  -2.62041895e+00 -6.51769584e-02  1.13335655e-02 -3.58325225e-01
#   3.55998178e+00]
# 	Final cost=1.3581e+05 final chisq_red=2.4873 computed in 0.98s
# 2022-11-08 09:07:53  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=23: initial cost=1.3581e+05 initial chisq_red=2.4873
# 		 Line search: alpha_min=0.382 iter=3 funcalls=7
# 	Parameter shifts: [-0.0002388  -0.00043819 -0.00063661  0.08634037 -0.1467584   0.07273087
#   0.00698908 -0.05177792 -0.03283445  0.00617842 -0.01023595  0.01790131
#   0.00081545]
# 	New parameters: [ 1.63948533e+00  1.28758893e+00 -2.32401418e-01  6.73728171e+00
#  -1.15007788e+01 -1.05108327e+01  1.50463865e+00 -2.66480714e+00
#  -2.65325339e+00 -5.89985358e-02  1.09761548e-03 -3.40423917e-01
#   3.56079723e+00]
# 	Final cost=1.3581e+05 final chisq_red=2.4873 computed in 1.05s
# 2022-11-08 09:07:53  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 23 iterations because the relative change of cost is below ftol=1.8315018315018315e-05.
# 2022-11-08 09:07:53  spectractor.fit.fitter print_parameter_summary INFO
# 	y_c_0: 1.639 +0.002 -0.002
# 	y_c_1: 1.288 +0.003 -0.003
# 	y_c_2: -0.232 +0.005 -0.005
# 	gamma_0: 6.74 +0.02 -0.02
# 	gamma_1: -11.50 +0.04 -0.04
# 	gamma_2: -10.51 +0.04 -0.04
# 	alpha_0: 1.505 +0.005 -0.005
# 	alpha_1: -2.66 +0.02 -0.02
# 	alpha_2: -2.65 +0.02 -0.02
# 	eta_gauss_0: -0.059 +0.002 -0.002
# 	eta_gauss_1: 0.001 +0.003 -0.003
# 	eta_gauss_2: -0.340 +0.006 -0.006
# 	stddev_0: 3.56 +0.01 -0.01
#
# 2022-11-08 09:07:55  ChromaticPSF1DFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8/parameters_correlation.pdf.
# 2022-11-08 09:07:59  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop raw image [1983:3348,1558:1924] (size (1365, 366))
# 2022-11-08 09:07:59  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	  ======================= Extract the non rotated background  =============================
# 2022-11-08 09:08:01  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Background statistics: mean=1.670 ADU/s, RMS=8.502 ADU/s.
# 2022-11-08 09:08:01  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	  ======================= first guess for lambdas  =============================
# 2022-11-08 09:08:01  spectractor.extractor.extractor extract_spectrum_from_image INFO
# 	Extract spectrogram: crop image [1983:3348,1558:1924] (size (1365, 366))
# 	New target position in spectrogram frame: [-1671.6923126569802, 175.77088848832682]
# 2022-11-08 09:08:02  spectractor.extractor.extractor Spectractor          INFO
# 	Calibrating order 1 spectrum...
# 2022-11-08 09:08:17  Spectrum   calibrate_spectrum   INFO
# 	Order0 total shift: 0.056pix
# 	D = 180.996 mm (default: DISTANCE2CCD = 181.00 +/- 0.40 mm, -0.0 sigma shift)
# 2022-11-08 09:08:17  spectractor.extractor.extractor Spectractor          INFO
# 	  ======================= FFM DECONVOLUTION =============================
# 2022-11-08 09:08:17  FullForwardModelFitWorkspace set_mask             INFO
# 	Reset spectrogram mask with current parameters.
# 2022-11-08 09:08:21  FullForwardModelFitWorkspace __init__             INFO
# 	Full forward model fitting with regularisation parameter r=0.1.
# 2022-11-08 09:08:21  spectractor.extractor.extractor run_ffm_minimisation INFO
#  --- Start FFM with adjust_spectrogram_position_parameters ---
# 2022-11-08 09:09:15  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=3.4135e+05 initial chisq_red=6.1246
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 1.84003346 -0.03145848]
# 	New parameters: [1.84003346 0.16854152]
# 	Final cost=2.586e+05 final chisq_red=4.6399 computed in 46.66s
# 2022-11-08 09:10:02  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=2.586e+05 initial chisq_red=4.6399
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [-0.38647079  0.0080086 ]
# 	New parameters: [1.45356267 0.17655012]
# 	Final cost=2.5692e+05 final chisq_red=4.6097 computed in 46.84s
# 2022-11-08 09:10:49  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=2.5692e+05 initial chisq_red=4.6097
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.05545294 -0.0011236 ]
# 	New parameters: [1.50901561 0.17542651]
# 	Final cost=2.5687e+05 final chisq_red=4.6089 computed in 46.81s
# 2022-11-08 09:10:49  spectractor.fit.fitter gradient_descent     INFO
# 	Gradient descent terminated in 2 iterations because the relative change of cost is below ftol=0.0015926102882624622.
# 2022-11-08 09:10:49  spectractor.fit.fitter print_parameter_summary INFO
# 	shift_y [pix]: 1.51 +0.01 -0.01
# 	angle [deg]: 0.1754 +0.0003 -0.0003
#
# 2022-11-08 09:10:56  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8/ffm_bestfit.pdf.
# 2022-11-08 09:10:57  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8/ffm_bestfit_2.pdf.
# 2022-11-08 09:10:58  FullForwardModelFitWorkspace plot_correlation_matrix INFO   Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8/parameters_correlation.pdf.
# 2022-11-08 09:10:59  FullForwardModelFitWorkspace set_mask             INFO
# 	Reset spectrogram mask with current parameters.
# 2022-11-08 09:11:10  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8/ffm_bestfit.pdf.
# 2022-11-08 09:11:12  FullForwardModelFitWorkspace plot_fit             INFO
# 	Save figure ./figures_process_20211103_FELH0600~holo4_003_config_DECONVOLUTION_FFMvNov2022_nb_8/ffm_bestfit_2.pdf.
# 2022-11-08 09:11:13  spectractor.extractor.extractor run_ffm_minimisation INFO
# 	Start guess: [ 1.00000000e+00  1.80996117e+02  5.58779828e-02  1.50901561e+00
#   1.75426515e-01  1.00000000e+00 -8.47251277e+01  7.40350000e+02
#   7.30000000e+00  1.14705477e+00  2.35455273e+03  6.81995845e+02
#   5.90080346e-13  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.82190843e+00 -1.13284634e+01 -1.03961215e+01  1.58025815e+00
#  -2.51266433e+00 -2.55452628e+00 -1.36918423e-01 -1.00931409e-01
#  -3.47116627e-01  3.56079723e+00  3.65305267e-16  1.19742417e-15
#   1.70000000e+05  2.35455273e+03  6.81995845e+02  5.90080346e-13
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  6.82190843e+00
#  -1.13284634e+01 -1.03961215e+01  1.58025815e+00 -2.51266433e+00
#  -2.55452628e+00 -1.36918423e-01 -1.00931409e-01 -3.47116627e-01
#   3.56079723e+00  3.65305267e-16  1.19742417e-15  1.70000000e+05]
# 	with ['A2', 'D_CCD [mm]', 'shift_x [pix]', 'shift_y [pix]', 'angle [deg]', 'B', 'R', 'P [hPa]', 'T [Celsius]', 'z', 'x_c_0', 'x_c_1', 'x_c_2', 'y_c_0', 'y_c_1', 'y_c_2', 'gamma_0', 'gamma_1', 'gamma_2', 'alpha_0', 'alpha_1', 'alpha_2', 'eta_gauss_0', 'eta_gauss_1', 'eta_gauss_2', 'stddev_0', 'stddev_1', 'stddev_2', 'saturation_0', 'x_c_0_2', 'x_c_1_2', 'x_c_2_2', 'y_c_0_2', 'y_c_1_2', 'y_c_2_2', 'gamma_0_2', 'gamma_1_2', 'gamma_2_2', 'alpha_0_2', 'alpha_1_2', 'alpha_2_2', 'eta_gauss_0_2', 'eta_gauss_1_2', 'eta_gauss_2_2', 'stddev_0_2', 'stddev_1_2', 'stddev_2_2', 'saturation_0_2']
# 2022-11-08 09:11:13  spectractor.extractor.extractor run_ffm_minimisation INFO
#  --- before  run_minimisation ---
# 2022-11-08 09:11:13  spectractor.extractor.extractor dumpfitparameters    INFO
#
# - fit param #0 :: A2 = 1.0 	 fixed = True 	 bounds 0.000 - 20.000
# - fit param #1 :: D_CCD [mm] = 180.99611694967382 	 fixed = True 	 bounds 179.796 - 182.196
# - fit param #2 :: shift_x [pix] = 0.055877982823333075 	 fixed = True 	 bounds -5.000 - 5.000
# - fit param #3 :: shift_y [pix] = 1.509015608211051 	 fixed = True 	 bounds -50.000 - 50.000
# - fit param #4 :: angle [deg] = 0.17542651486154004 	 fixed = True 	 bounds -90.000 - 90.000
# - fit param #5 :: B = 1.0 	 fixed = True 	 bounds 0.200 - 5.000
# - fit param #6 :: R = -84.72512767016502 	 fixed = True 	 bounds -360.000 - 360.000
# - fit param #7 :: P [hPa] = 740.35 	 fixed = True 	 bounds 300.000 - 1100.000
# - fit param #8 :: T [Celsius] = 7.3 	 fixed = True 	 bounds -100.000 - 100.000
# - fit param #9 :: z = 1.147054772039225 	 fixed = True 	 bounds 1.001 - 3.000
# - fit param #10 :: x_c_0 = 2354.552731660757 	 fixed = True 	 bounds -inf - inf
# - fit param #11 :: x_c_1 = 681.9958450226144 	 fixed = True 	 bounds -inf - inf
# - fit param #12 :: x_c_2 = 5.900803462798864e-13 	 fixed = True 	 bounds -inf - inf
# - fit param #13 :: y_c_0 = 0.0 	 fixed = False 	 bounds -inf - inf
# - fit param #14 :: y_c_1 = 0.0 	 fixed = False 	 bounds -inf - inf
# - fit param #15 :: y_c_2 = 0.0 	 fixed = False 	 bounds -inf - inf
# - fit param #16 :: gamma_0 = 6.821908427573847 	 fixed = False 	 bounds -inf - inf
# - fit param #17 :: gamma_1 = -11.328463416519147 	 fixed = False 	 bounds -inf - inf
# - fit param #18 :: gamma_2 = -10.39612146460829 	 fixed = False 	 bounds -inf - inf
# - fit param #19 :: alpha_0 = 1.5802581457656606 	 fixed = False 	 bounds -inf - inf
# - fit param #20 :: alpha_1 = -2.512664330774265 	 fixed = False 	 bounds -inf - inf
# - fit param #21 :: alpha_2 = -2.5545262794441075 	 fixed = False 	 bounds -inf - inf
# - fit param #22 :: eta_gauss_0 = -0.13691842255317901 	 fixed = False 	 bounds -inf - inf
# - fit param #23 :: eta_gauss_1 = -0.10093140927915438 	 fixed = False 	 bounds -inf - inf
# - fit param #24 :: eta_gauss_2 = -0.3471166266942956 	 fixed = False 	 bounds -inf - inf
# - fit param #25 :: stddev_0 = 3.5607972327400144 	 fixed = False 	 bounds -inf - inf
# - fit param #26 :: stddev_1 = 3.653052672637897e-16 	 fixed = False 	 bounds -inf - inf
# - fit param #27 :: stddev_2 = 1.1974241708431427e-15 	 fixed = False 	 bounds -inf - inf
# - fit param #28 :: saturation_0 = 169999.9999999999 	 fixed = True 	 bounds 0.000 - 340000.000
# - fit param #29 :: x_c_0_2 = 2354.552731660757 	 fixed = True 	 bounds -inf - inf
# - fit param #30 :: x_c_1_2 = 681.9958450226144 	 fixed = True 	 bounds -inf - inf
# - fit param #31 :: x_c_2_2 = 5.900803462798864e-13 	 fixed = True 	 bounds -inf - inf
# - fit param #32 :: y_c_0_2 = 0.0 	 fixed = False 	 bounds -inf - inf
# - fit param #33 :: y_c_1_2 = 0.0 	 fixed = False 	 bounds -inf - inf
# - fit param #34 :: y_c_2_2 = 0.0 	 fixed = False 	 bounds -inf - inf
# - fit param #35 :: gamma_0_2 = 6.821908427573847 	 fixed = False 	 bounds -inf - inf
# - fit param #36 :: gamma_1_2 = -11.328463416519147 	 fixed = False 	 bounds -inf - inf
# - fit param #37 :: gamma_2_2 = -10.39612146460829 	 fixed = False 	 bounds -inf - inf
# - fit param #38 :: alpha_0_2 = 1.5802581457656606 	 fixed = False 	 bounds -inf - inf
# - fit param #39 :: alpha_1_2 = -2.512664330774265 	 fixed = False 	 bounds -inf - inf
# - fit param #40 :: alpha_2_2 = -2.5545262794441075 	 fixed = False 	 bounds -inf - inf
# - fit param #41 :: eta_gauss_0_2 = -0.13691842255317901 	 fixed = False 	 bounds -inf - inf
# - fit param #42 :: eta_gauss_1_2 = -0.10093140927915438 	 fixed = False 	 bounds -inf - inf
# - fit param #43 :: eta_gauss_2_2 = -0.3471166266942956 	 fixed = False 	 bounds -inf - inf
# - fit param #44 :: stddev_0_2 = 3.5607972327400144 	 fixed = False 	 bounds -inf - inf
# - fit param #45 :: stddev_1_2 = 3.653052672637897e-16 	 fixed = False 	 bounds -inf - inf
# - fit param #46 :: stddev_2_2 = 1.1974241708431427e-15 	 fixed = False 	 bounds -inf - inf
# - fit param #47 :: saturation_0_2 = 169999.9999999999 	 fixed = True 	 bounds 0.000 - 340000.000
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_1 has a null Jacobian; parameter is fixed at its last known current value (3.653052672637897e-16).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_2 has a null Jacobian; parameter is fixed at its last known current value (1.1974241708431427e-15).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: y_c_0_2 has a null Jacobian; parameter is fixed at its last known current value (0.0).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: y_c_1_2 has a null Jacobian; parameter is fixed at its last known current value (0.0).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: y_c_2_2 has a null Jacobian; parameter is fixed at its last known current value (0.0).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: gamma_0_2 has a null Jacobian; parameter is fixed at its last known current value (6.821908427573847).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: gamma_1_2 has a null Jacobian; parameter is fixed at its last known current value (-11.328463416519147).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: gamma_2_2 has a null Jacobian; parameter is fixed at its last known current value (-10.39612146460829).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: alpha_0_2 has a null Jacobian; parameter is fixed at its last known current value (1.5802581457656606).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: alpha_1_2 has a null Jacobian; parameter is fixed at its last known current value (-2.512664330774265).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: alpha_2_2 has a null Jacobian; parameter is fixed at its last known current value (-2.5545262794441075).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: eta_gauss_0_2 has a null Jacobian; parameter is fixed at its last known current value (-0.13691842255317901).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: eta_gauss_1_2 has a null Jacobian; parameter is fixed at its last known current value (-0.10093140927915438).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: eta_gauss_2_2 has a null Jacobian; parameter is fixed at its last known current value (-0.3471166266942956).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_0_2 has a null Jacobian; parameter is fixed at its last known current value (3.5607972327400144).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_1_2 has a null Jacobian; parameter is fixed at its last known current value (3.653052672637897e-16).
# 2022-11-08 09:14:21  spectractor.fit.fitter gradient_descent     WARNING
# 	Step 0: stddev_2_2 has a null Jacobian; parameter is fixed at its last known current value (1.1974241708431427e-15).
# 2022-11-08 09:15:02  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=0: initial cost=2.559e+05 initial chisq_red=4.6139
# 		 Line search: alpha_min=0.618 iter=3 funcalls=7
# 	Parameter shifts: [ 0.03827564  0.0902997   0.0937319  -1.55519793  2.81505611  2.13878102
#   0.01788558  0.89131262  0.99319565 -0.04089253  0.1588306  -0.12456536
#   0.11394176]
# 	New parameters: [ 0.03827564  0.0902997   0.0937319   5.26671049 -8.51340731 -8.25734044
#   1.59814372 -1.62135171 -1.56133062 -0.17781096  0.05789919 -0.47168198
#   3.67473899]
# 	Final cost=1.4333e+05 final chisq_red=2.5842 computed in 223.46s
# 2022-11-08 09:16:54  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=1: initial cost=1.4333e+05 initial chisq_red=2.5842
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.03918096  0.1045132   0.07649475  0.35698656 -0.80850478  0.72653149
#   0.06947072 -0.20141384 -0.12440762  0.10047968 -0.0901626  -0.028524
#  -0.21486499]
# 	New parameters: [ 0.07745661  0.1948129   0.17022665  5.62369705 -9.32191208 -7.53080896
#   1.66761444 -1.82276556 -1.68573825 -0.07733128 -0.03226341 -0.50020599
#   3.459874  ]
# 	Final cost=1.1075e+05 final chisq_red=1.9969 computed in 112.18s
# 2022-11-08 09:18:46  spectractor.fit.fitter gradient_descent     INFO
# 	Iteration=2: initial cost=1.1075e+05 initial chisq_red=1.9969
# 		 Line search: alpha_min=1 iter=1 funcalls=5
# 	Parameter shifts: [ 0.01445366  0.02694724  0.02761252  0.21371985  0.37229908  0.64778119
#   0.09843711  0.04211801  0.22370982 -0.10635192 -0.05156121  0.05623951
#   0.15816444]
# 	New parameters: [ 0.09191027  0.22176013  0.19783918  5.8374169  -8.949613   -6.88302777
#   1.76605155 -1.78064755 -1.46202843 -0.1836832  -0.08382462 -0.44396648
#   3.61803844]
# 	Final cost=1.0231e+05 final chisq_red=1.8447 computed in 111.88s
#
# KeyboardInterrupt

# %%
spectrum.plot_spectrum(force_lines=True)

# %% [markdown]
# # Backup output

# %% [markdown]
# - If no crash occurs, arrive here
#
# ./outputs_process_holo_config_DECONVOLUTION_PSF2D

# %%
def cleandir(path):
    if os.path.isdir(path):
        files=os.listdir(path)
        if len(files) > 0:
            for f in files:
                if os.path.isdir(os.path.join(path,f)):
                    if f==".ipynb_checkpoints":
                        shutil.rmtree(os.path.join(path,f))
                    else:
                        print(" Cannot remove this directory {}".format(os.path.join(path,f)))
                else:
                    os.remove(os.path.join(path,f))

# %%
# this flag must be set if one want to clean results from previous runs
if FLAG_MANAGE_OUTPUT_SPECTRACTOR:
    
    # manage global output directory of spectractor
    # Basically it has the name of the input file image
    
    if not os.path.isdir(path_toptoptopoutput_spectractor):
        os.mkdir(path_toptoptopoutput_spectractor)
    
    if not os.path.isdir(path_toptopoutput_spectractor):
        os.mkdir(path_toptopoutput_spectractor) 
        
    if configdir !="":
    # top directory    
        if not os.path.isdir(path_topoutput_spectractor):
            os.mkdir(path_topoutput_spectractor)   
            
            
        if not os.path.isdir(path_output_spectractor):
            os.mkdir(path_output_spectractor)
  
    
    if not os.path.isdir(finalpath_output_spectractor):
        os.mkdir(finalpath_output_spectractor)
        os.mkdir(os.path.join(finalpath_output_spectractor,"basespec"))
        os.mkdir(os.path.join(finalpath_output_spectractor,"plots"))
    else:
        cleandir(os.path.join(finalpath_output_spectractor,"basespec"))
        cleandir(os.path.join(finalpath_output_spectractor,"plots"))

# %%
print("******************************** SUCCESS ********************************************")

# %%
copy_tree(output_directory,os.path.join(finalpath_output_spectractor,"basespec"))

# %%
copy_tree(output_figures,os.path.join(finalpath_output_spectractor,"plots"))

# %%
print("finalpath_output_spectractor = ",finalpath_output_spectractor)

# %%
os.listdir(os.path.join(finalpath_output_spectractor,"basespec"))

# %%
os.listdir(os.path.join(finalpath_output_spectractor,"plots"))

# %%
output_directory
