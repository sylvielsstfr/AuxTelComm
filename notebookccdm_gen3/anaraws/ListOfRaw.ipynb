# %% [markdown]
# # List of Raw images
#
#
# - work with Weakly_2022_09
# - use jupyter kernel LSST
#
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/03/14

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/atmospec 	setup
# eups                  LOCAL:/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/w_2022_09/conda/envs/lsst-scipipe-2.0.0/eups 	setup
# rapid_analysis        LOCAL:/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/repos/w_2022_09/rapid_analysis 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
#    g64fc59b30a+e1dba0a6f6 	w_latest w_2022_09 current setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sps/lsst/groups/auxtel/softs/shared/auxteldm_gen3/data/butler.yaml'
butler = dafButler.Butler(repo)
registry = butler.registry

# %%
collection='LATISS/raw/all'

datasetRefs = registry.queryDatasets(datasetType='raw', collections=collection, 
                                     where= "instrument='LATISS'")

for i, ref in enumerate(datasetRefs):
    print("==========================================================================================================================")
   
    print("fullId: ",ref.dataId.full)
    print("..........................................................................................................................")
    print(ref.to_json())
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("\t type     = ", ref.datasetType.name)
    print("\t band     = ", ref.dataId["band"])
    print("\t filter   = ", ref.dataId["physical_filter"])
    print("\t exposure = ", ref.dataId["exposure"])

    
    if i> 5:
        break;
# Out:
# ==========================================================================================================================
# fullId:  {band: 'white', instrument: 'LATISS', detector: 0, physical_filter: 'empty~empty', exposure: 2021021600208}
# ..........................................................................................................................
# {"id": "4e6df063-6848-51ed-a633-b7891f627872", "datasetType": {"name": "raw", "storageClass": "Exposure", "dimensions": {"names": ["band", "instrument", "detector", "physical_filter", "exposure"]}}, "dataId": {"dataId": {"band": "white", "instrument": "LATISS", "detector": 0, "physical_filter": "empty~empty", "exposure": 2021021600208}}, "run": "LATISS/raw/all"}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 	 type     =  raw
# 	 band     =  white
# 	 filter   =  empty~empty
# 	 exposure =  2021021600208
# ==========================================================================================================================
# fullId:  {band: 'r', instrument: 'LATISS', detector: 0, physical_filter: 'RG610~empty', exposure: 2021021600163}
# ..........................................................................................................................
# {"id": "077e06c9-649b-5ca2-ad3c-8e45270b152a", "datasetType": {"name": "raw", "storageClass": "Exposure", "dimensions": {"names": ["band", "instrument", "detector", "physical_filter", "exposure"]}}, "dataId": {"dataId": {"band": "r", "instrument": "LATISS", "detector": 0, "physical_filter": "RG610~empty", "exposure": 2021021600163}}, "run": "LATISS/raw/all"}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 	 type     =  raw
# 	 band     =  r
# 	 filter   =  RG610~empty
# 	 exposure =  2021021600163
# ==========================================================================================================================
# fullId:  {band: 'white', instrument: 'LATISS', detector: 0, physical_filter: 'empty~empty', exposure: 2021021600070}
# ..........................................................................................................................
# {"id": "2d961969-15e8-5611-b79e-f3978849fd82", "datasetType": {"name": "raw", "storageClass": "Exposure", "dimensions": {"names": ["band", "instrument", "detector", "physical_filter", "exposure"]}}, "dataId": {"dataId": {"band": "white", "instrument": "LATISS", "detector": 0, "physical_filter": "empty~empty", "exposure": 2021021600070}}, "run": "LATISS/raw/all"}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 	 type     =  raw
# 	 band     =  white
# 	 filter   =  empty~empty
# 	 exposure =  2021021600070
# ==========================================================================================================================
# fullId:  {band: 'r', instrument: 'LATISS', detector: 0, physical_filter: 'RG610~empty', exposure: 2021021600173}
# ..........................................................................................................................
# {"id": "549110a0-dc4e-5914-aeef-a75ac093dca0", "datasetType": {"name": "raw", "storageClass": "Exposure", "dimensions": {"names": ["band", "instrument", "detector", "physical_filter", "exposure"]}}, "dataId": {"dataId": {"band": "r", "instrument": "LATISS", "detector": 0, "physical_filter": "RG610~empty", "exposure": 2021021600173}}, "run": "LATISS/raw/all"}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 	 type     =  raw
# 	 band     =  r
# 	 filter   =  RG610~empty
# 	 exposure =  2021021600173
# ==========================================================================================================================
# fullId:  {band: 'white', instrument: 'LATISS', detector: 0, physical_filter: 'empty~empty', exposure: 2021021600001}
# ..........................................................................................................................
# {"id": "8506e871-8882-5b09-98ae-6420d119e21b", "datasetType": {"name": "raw", "storageClass": "Exposure", "dimensions": {"names": ["band", "instrument", "detector", "physical_filter", "exposure"]}}, "dataId": {"dataId": {"band": "white", "instrument": "LATISS", "detector": 0, "physical_filter": "empty~empty", "exposure": 2021021600001}}, "run": "LATISS/raw/all"}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 	 type     =  raw
# 	 band     =  white
# 	 filter   =  empty~empty
# 	 exposure =  2021021600001
# ==========================================================================================================================
# fullId:  {band: 'r', instrument: 'LATISS', detector: 0, physical_filter: 'RG610~ronchi90lpmm', exposure: 2021021600223}
# ..........................................................................................................................
# {"id": "c29756d8-7cbb-5cd9-a33a-eeb265cdc672", "datasetType": {"name": "raw", "storageClass": "Exposure", "dimensions": {"names": ["band", "instrument", "detector", "physical_filter", "exposure"]}}, "dataId": {"dataId": {"band": "r", "instrument": "LATISS", "detector": 0, "physical_filter": "RG610~ronchi90lpmm", "exposure": 2021021600223}}, "run": "LATISS/raw/all"}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 	 type     =  raw
# 	 band     =  r
# 	 filter   =  RG610~ronchi90lpmm
# 	 exposure =  2021021600223
# ==========================================================================================================================
# fullId:  {band: 'white', instrument: 'LATISS', detector: 0, physical_filter: 'empty~ronchi90lpmm', exposure: 2021021600186}
# ..........................................................................................................................
# {"id": "9146a140-2123-594e-a271-23903425b688", "datasetType": {"name": "raw", "storageClass": "Exposure", "dimensions": {"names": ["band", "instrument", "detector", "physical_filter", "exposure"]}}, "dataId": {"dataId": {"band": "white", "instrument": "LATISS", "detector": 0, "physical_filter": "empty~ronchi90lpmm", "exposure": 2021021600186}}, "run": "LATISS/raw/all"}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 	 type     =  raw
# 	 band     =  white
# 	 filter   =  empty~ronchi90lpmm
# 	 exposure =  2021021600186

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure')):
    print("-----------------------------------------------------",count,"---------------------------------------------------------")
    print(info)
    print("\t id:                  ",info.id)
    print("\t day_obs:             ",info.day_obs)
    print("\t seq_num:             ",info.seq_num)
    print("\t type-of-observation: ",info.observation_type)
    print("\t target:              ",info.target_name)
    if count > 5:
        break;
# Out:
# ----------------------------------------------------- 0 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600208
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000208'
#   exposure_time: 2.0
#   dark_time: 2.33517265319824
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 208
#   group_name: '2021-02-17T03:35:45.035'
#   group_id: 1934625450350000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.384001783548
#   tracking_dec: -23.9734478006315
#   sky_angle: -180.0
#   zenith_angle: 24.314073266185005
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 03:35:45.295446', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 03:35:47.540000', scale='tai', format='iso'))
# 	 id:                   2021021600208
# 	 day_obs:              20210216
# 	 seq_num:              208
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 1 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600163
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000163'
#   exposure_time: 3.0
#   dark_time: 3.3251359462738
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 163
#   group_name: '2021-02-17T00:50:15.536'
#   group_id: 1934526155360000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.404029472597
#   tracking_dec: -23.9293904683577
#   sky_angle: -208.6217120790572
#   zenith_angle: 14.580610783508703
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 00:50:15.703984', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 00:50:18.939000', scale='tai', format='iso'))
# 	 id:                   2021021600163
# 	 day_obs:              20210216
# 	 seq_num:              163
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 2 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600070
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000070'
#   exposure_time: 0.0
#   dark_time: 0.0956339836120605
#   observation_type: 'bias'
#   observation_reason: 'unknown'
#   day_obs: 20210216
#   seq_num: 70
#   group_name: '2021-02-16T20:39:31.417'
#   group_id: 1934375714170000
#   target_name: 'azel_target'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   zenith_angle: None
#   timespan: Timespan(begin=astropy.time.Time('2021-02-16 20:39:31.586841', scale='tai', format='iso'), end=astropy.time.Time('2021-02-16 20:39:31.592000', scale='tai', format='iso'))
# 	 id:                   2021021600070
# 	 day_obs:              20210216
# 	 seq_num:              70
# 	 type-of-observation:  bias
# 	 target:               azel_target
# ----------------------------------------------------- 3 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600173
#   physical_filter: 'RG610~empty'
#   obs_id: 'AT_O_20210216_000173'
#   exposure_time: 2.0
#   dark_time: 2.32638740539551
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 173
#   group_name: '2021-02-17T01:21:19.215'
#   group_id: 1934544792150000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.395985711384
#   tracking_dec: -23.9270381200679
#   sky_angle: -208.6217120790572
#   zenith_angle: 8.829310478380606
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 01:21:19.482543', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 01:21:21.719000', scale='tai', format='iso'))
# 	 id:                   2021021600173
# 	 day_obs:              20210216
# 	 seq_num:              173
# 	 type-of-observation:  science
# 	 target:               HD 50896
# ----------------------------------------------------- 4 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600001
#   physical_filter: 'empty~empty'
#   obs_id: 'AT_O_20210216_000001'
#   exposure_time: 0.0
#   dark_time: 0.0993173122406006
#   observation_type: 'bias'
#   observation_reason: 'unknown'
#   day_obs: 20210216
#   seq_num: 1
#   group_name: '2021-02-16T19:50:21.993'
#   group_id: 1934346219930000
#   target_name: 'azel_target'
#   science_program: 'unknown'
#   tracking_ra: None
#   tracking_dec: None
#   sky_angle: None
#   zenith_angle: None
#   timespan: Timespan(begin=astropy.time.Time('2021-02-16 19:50:22.184100', scale='tai', format='iso'), end=astropy.time.Time('2021-02-16 19:50:22.190000', scale='tai', format='iso'))
# 	 id:                   2021021600001
# 	 day_obs:              20210216
# 	 seq_num:              1
# 	 type-of-observation:  bias
# 	 target:               azel_target
# ----------------------------------------------------- 5 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600223
#   physical_filter: 'RG610~ronchi90lpmm'
#   obs_id: 'AT_O_20210216_000223'
#   exposure_time: 30.0
#   dark_time: 30.2525644302368
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 223
#   group_name: '2021-02-17T04:18:44.771'
#   group_id: 1934651247710000
#   target_name: 'HD 74000'
#   science_program: 'unknown'
#   tracking_ra: 130.072350621493
#   tracking_dec: -16.3443087499682
#   sky_angle: -277.76871924511863
#   zenith_angle: 17.032810987642705
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 04:20:22.820568', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 04:20:53.051000', scale='tai', format='iso'))
# 	 id:                   2021021600223
# 	 day_obs:              20210216
# 	 seq_num:              223
# 	 type-of-observation:  science
# 	 target:               HD 74000
# ----------------------------------------------------- 6 ---------------------------------------------------------
# exposure:
#   instrument: 'LATISS'
#   id: 2021021600186
#   physical_filter: 'empty~ronchi90lpmm'
#   obs_id: 'AT_O_20210216_000186'
#   exposure_time: 20.0
#   dark_time: 20.3282701969147
#   observation_type: 'science'
#   observation_reason: 'science'
#   day_obs: 20210216
#   seq_num: 186
#   group_name: '2021-02-17T02:12:28.316'
#   group_id: 1934575483160000
#   target_name: 'HD 50896'
#   science_program: 'unknown'
#   tracking_ra: 103.376310787943
#   tracking_dec: -23.9414393919396
#   sky_angle: -208.6217120790572
#   zenith_angle: 7.977539689949495
#   timespan: Timespan(begin=astropy.time.Time('2021-02-17 02:12:30.077986', scale='tai', format='iso'), end=astropy.time.Time('2021-02-17 02:12:50.315000', scale='tai', format='iso'))
# 	 id:                   2021021600186
# 	 day_obs:              20210216
# 	 seq_num:              186
# 	 type-of-observation:  science
# 	 target:               HD 50896

# %%
datasetRefs = registry.queryDatasets(datasetType='bias',where= "instrument='LATISS'", collections=collection)

# %%
for i, ref in enumerate(datasetRefs):
    print("==================================================================================")
   
    print("fullId: ",ref.dataId.full)
