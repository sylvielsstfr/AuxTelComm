# %% [markdown]
# # Run the pipeline from the notebook

# %% [markdown]
# - work with Weakly_2022_39
# - use jupyter kernel LSST
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/09/20
# - update : 2022/09/23

# %%
#! eups list -s | grep LOCAL

# %%
from lsst.summit.utils.utils import checkStackSetup
checkStackSetup()
# Out:
# You are running w_2022_39 of lsst_distrib
#
# Locally setup packages:
# -----------------------
# atmospec     at /home/d/dagoret/repos/repos_w_2022_39/atmospec
# drp_pipe     at /home/d/dagoret/repos/repos_w_2022_39/drp_pipe
# summit_utils at /home/d/dagoret/repos/repos_w_2022_39/summit_utils

# %%
# Basic imports
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

from pprint import pprint

# %%
from lsst.ctrl.mpexec import SimplePipelineExecutor
from lsst.pipe.base import Pipeline

# %%
from lsst.daf.butler import Butler


repo = "/sdf/group/rubin/repo/main"
collection = "u/dagoret/test_processstar"

butler = Butler(repo)
registry = butler.registry

# %%
# set up an output collection with your username
#outputCollection = "u/nate2/analysisToolsExample"
inputCollections = ["LATISS/raw/all","refcats","LATISS/calib"]
outputCollection = "u/dagoret/test_processstar01"

# this can be skipped if you already have a read writable butler setup (above is read only)
butlerRW = SimplePipelineExecutor.prep_butler(repo, inputs = inputCollections,output=outputCollection)

# load in the pipeline to run
#pipeline = Pipeline.from_uri("$ANALYSIS_TOOLS_DIR/pipelines/coaddQualityCore.yaml")
pipeline = Pipeline.from_uri("$ATMOSPEC_DIR/pipelines/processStar.yaml")

# %%
# override a configuration within a certain AnalysisTool
#configKey = "plots.shapeSizeFractionalDiffScatter.prep.selectors.snSelector.threshold"
#pipeline.addConfigOverride("analyzeObjectTableCore", configKey, 400)

#bands = ['g', 'r', 'i', 'z']
#pipeline.addConfigOverride("analyzeObjectTableCore", "bands", bands)
#pipeline.addConfigOverride("catalogMatchTract", "bands", bands)
#pipeline.addConfigOverride("refCatObjectTract", "bands", bands)

# restrict processing to the same dataId used above
#whereString = "tract = 9813 AND skymap = 'hsc_rings_v1'"
whereString = "exposure.day_obs={} and exposure.seq_num={} and instrument='LATISS'".format("20220607","195") 

# Prevent the executor from dumping plots into the notebook
#backend_ =  mpl.get_backend() 
#mpl.use("Agg")

executor = SimplePipelineExecutor.from_pipeline(pipeline, where=whereString, butler=butlerRW)
quanta = executor.run(True)

# Restore the ability for plots to be put into the notebook
mpl.use(backend_)

# If you only want to run one plot in a task in the pipeline do the following prior to execution
# pipeline.addConfigOverride("analyzeObjectTableCore", "plots", None)
# pipeline.addConfigOverride("analyzeObjectTableCore", "plots", ShapeSizeFractionalDiffScatterPlot)
# Out:
# /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/pex_config/g71c1dbb2b5+9a7299d786/python/lsst/pex/config/configurableField.py:79: FutureWarning: Call to deprecated class LoadIndexedReferenceObjectsConfig. (This config is no longer used; it will be removed after v25. Please use LoadReferenceObjectsConfig instead.) -- Deprecated since version v25.0.
#   value = self._ConfigClass(__name=name, __at=at, __label=label, **storage)
# /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/pex_config/g71c1dbb2b5+9a7299d786/python/lsst/pex/config/configurableField.py:359: FutureWarning: Call to deprecated class LoadIndexedReferenceObjectsConfig. (This config is no longer used; it will be removed after v25. Please use LoadReferenceObjectsConfig instead.) -- Deprecated since version v25.0.
#   value = oldValue.ConfigClass()
# Loading config from /home/d/dagoret/repos/repos_w_2022_39/atmospec/config/auxtel.ini
# No rebinning: parameters.REBIN is forced to 1.
# ASTROMETRYNET_DIR
# BGD_ORDER 1
# CALIB_BGD_NPARAMS 4
# CALIB_BGD_ORDER 3
# CALIB_BGD_WIDTH 15
# CALIB_PEAK_WIDTH 7
# CALIB_SAVGOL_ORDER 2
# CALIB_SAVGOL_WINDOW 5
# CALLING_CODE LSST_DM
# CCD_ARCSEC2RADIANS 4.84813681109536e-06
# CCD_GAIN 1.1
# CCD_IMSIZE 4000
# CCD_MAXADU 170000
# CCD_PIXEL2ARCSEC 0.0952
# CCD_PIXEL2MM 0.01
# CCD_REBIN 2
# CONFIG_DIR /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/../config/
# DEBUG True
# DEBUG_LOGGING False
# DISPERSER_DIR /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/extractor/dispersers/
# DISPLAY True
# DISTANCE2CCD 180.9980010986328
# DISTANCE2CCD_ERR 0.4
# FGB37 {'label': 'FGB37', 'min': 350, 'max': 750}
# FILTERS [{'label': 'RG715', 'min': 690, 'max': 1100}, {'label': 'FGB37', 'min': 350, 'max': 750}, {'label': 'Halfa', 'min': 0.0006431, 'max': 0.0006686999999999999}, {'label': 'Z-Gunn', 'min': 800, 'max': 1100}]
# FLAM_TO_ADURATE 5175865186660.421
# GRATING_ORDER_2OVER1 0.1
# GROOVES_PER_MM 150
# HALPHA_CENTER 0.0006559
# HALPHA_FILTER {'label': 'Halfa', 'min': 0.0006431, 'max': 0.0006686999999999999}
# HALPHA_WIDTH 6.4e-06
# LAMBDAS [ 300.  301.  302.  303.  304.  305.  306.  307.  308.  309.  310.  311.
#   312.  313.  314.  315.  316.  317.  318.  319.  320.  321.  322.  323.
#   324.  325.  326.  327.  328.  329.  330.  331.  332.  333.  334.  335.
#   336.  337.  338.  339.  340.  341.  342.  343.  344.  345.  346.  347.
#   348.  349.  350.  351.  352.  353.  354.  355.  356.  357.  358.  359.
#   360.  361.  362.  363.  364.  365.  366.  367.  368.  369.  370.  371.
#   372.  373.  374.  375.  376.  377.  378.  379.  380.  381.  382.  383.
#   384.  385.  386.  387.  388.  389.  390.  391.  392.  393.  394.  395.
#   396.  397.  398.  399.  400.  401.  402.  403.  404.  405.  406.  407.
#   408.  409.  410.  411.  412.  413.  414.  415.  416.  417.  418.  419.
#   420.  421.  422.  423.  424.  425.  426.  427.  428.  429.  430.  431.
#   432.  433.  434.  435.  436.  437.  438.  439.  440.  441.  442.  443.
#   444.  445.  446.  447.  448.  449.  450.  451.  452.  453.  454.  455.
#   456.  457.  458.  459.  460.  461.  462.  463.  464.  465.  466.  467.
#   468.  469.  470.  471.  472.  473.  474.  475.  476.  477.  478.  479.
#   480.  481.  482.  483.  484.  485.  486.  487.  488.  489.  490.  491.
#   492.  493.  494.  495.  496.  497.  498.  499.  500.  501.  502.  503.
#   504.  505.  506.  507.  508.  509.  510.  511.  512.  513.  514.  515.
#   516.  517.  518.  519.  520.  521.  522.  523.  524.  525.  526.  527.
#   528.  529.  530.  531.  532.  533.  534.  535.  536.  537.  538.  539.
#   540.  541.  542.  543.  544.  545.  546.  547.  548.  549.  550.  551.
#   552.  553.  554.  555.  556.  557.  558.  559.  560.  561.  562.  563.
#   564.  565.  566.  567.  568.  569.  570.  571.  572.  573.  574.  575.
#   576.  577.  578.  579.  580.  581.  582.  583.  584.  585.  586.  587.
#   588.  589.  590.  591.  592.  593.  594.  595.  596.  597.  598.  599.
#   600.  601.  602.  603.  604.  605.  606.  607.  608.  609.  610.  611.
#   612.  613.  614.  615.  616.  617.  618.  619.  620.  621.  622.  623.
#   624.  625.  626.  627.  628.  629.  630.  631.  632.  633.  634.  635.
#   636.  637.  638.  639.  640.  641.  642.  643.  644.  645.  646.  647.
#   648.  649.  650.  651.  652.  653.  654.  655.  656.  657.  658.  659.
#   660.  661.  662.  663.  664.  665.  666.  667.  668.  669.  670.  671.
#   672.  673.  674.  675.  676.  677.  678.  679.  680.  681.  682.  683.
#   684.  685.  686.  687.  688.  689.  690.  691.  692.  693.  694.  695.
#   696.  697.  698.  699.  700.  701.  702.  703.  704.  705.  706.  707.
#   708.  709.  710.  711.  712.  713.  714.  715.  716.  717.  718.  719.
#   720.  721.  722.  723.  724.  725.  726.  727.  728.  729.  730.  731.
#   732.  733.  734.  735.  736.  737.  738.  739.  740.  741.  742.  743.
#   744.  745.  746.  747.  748.  749.  750.  751.  752.  753.  754.  755.
#   756.  757.  758.  759.  760.  761.  762.  763.  764.  765.  766.  767.
#   768.  769.  770.  771.  772.  773.  774.  775.  776.  777.  778.  779.
#   780.  781.  782.  783.  784.  785.  786.  787.  788.  789.  790.  791.
#   792.  793.  794.  795.  796.  797.  798.  799.  800.  801.  802.  803.
#   804.  805.  806.  807.  808.  809.  810.  811.  812.  813.  814.  815.
#   816.  817.  818.  819.  820.  821.  822.  823.  824.  825.  826.  827.
#   828.  829.  830.  831.  832.  833.  834.  835.  836.  837.  838.  839.
#   840.  841.  842.  843.  844.  845.  846.  847.  848.  849.  850.  851.
#   852.  853.  854.  855.  856.  857.  858.  859.  860.  861.  862.  863.
#   864.  865.  866.  867.  868.  869.  870.  871.  872.  873.  874.  875.
#   876.  877.  878.  879.  880.  881.  882.  883.  884.  885.  886.  887.
#   888.  889.  890.  891.  892.  893.  894.  895.  896.  897.  898.  899.
#   900.  901.  902.  903.  904.  905.  906.  907.  908.  909.  910.  911.
#   912.  913.  914.  915.  916.  917.  918.  919.  920.  921.  922.  923.
#   924.  925.  926.  927.  928.  929.  930.  931.  932.  933.  934.  935.
#   936.  937.  938.  939.  940.  941.  942.  943.  944.  945.  946.  947.
#   948.  949.  950.  951.  952.  953.  954.  955.  956.  957.  958.  959.
#   960.  961.  962.  963.  964.  965.  966.  967.  968.  969.  970.  971.
#   972.  973.  974.  975.  976.  977.  978.  979.  980.  981.  982.  983.
#   984.  985.  986.  987.  988.  989.  990.  991.  992.  993.  994.  995.
#   996.  997.  998.  999. 1000. 1001. 1002. 1003. 1004. 1005. 1006. 1007.
#  1008. 1009. 1010. 1011. 1012. 1013. 1014. 1015. 1016. 1017. 1018. 1019.
#  1020. 1021. 1022. 1023. 1024. 1025. 1026. 1027. 1028. 1029. 1030. 1031.
#  1032. 1033. 1034. 1035. 1036. 1037. 1038. 1039. 1040. 1041. 1042. 1043.
#  1044. 1045. 1046. 1047. 1048. 1049. 1050. 1051. 1052. 1053. 1054. 1055.
#  1056. 1057. 1058. 1059. 1060. 1061. 1062. 1063. 1064. 1065. 1066. 1067.
#  1068. 1069. 1070. 1071. 1072. 1073. 1074. 1075. 1076. 1077. 1078. 1079.
#  1080. 1081. 1082. 1083. 1084. 1085. 1086. 1087. 1088. 1089. 1090. 1091.
#  1092. 1093. 1094. 1095. 1096. 1097. 1098. 1099.]
# LAMBDA_CONSTRUCTOR 0.000639
# LAMBDA_MAX 1100
# LAMBDA_MIN 300
# LAMBDA_STEP 1.0
# LIBRADTRAN_DIR
# LINEWIDTH 2.0
# MY_FORMAT %(asctime)-20s %(name)-10s %(funcName)-20s %(levelname)-6s %(message)s
# OBS_ALTITUDE 2.66299616375123
# OBS_CAMERA_DEC_FLIP_SIGN 1
# OBS_CAMERA_RA_FLIP_SIGN 1
# OBS_CAMERA_ROTATION 0
# OBS_DIAMETER 1.2
# OBS_EPOCH J2000.0
# OBS_FULL_INSTRUMENT_TRANSMISSON calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt
# OBS_LATITUDE -30.2446389756252
# OBS_NAME AUXTEL
# OBS_OBJECT_TYPE STAR
# OBS_QUANTUM_EFFICIENCY calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt
# OBS_SURFACE 1.1309733552923256
# OBS_TELESCOPE_TRANSMISSION calexp_2020031500162-EMPTY_ronchi90lpmm-det000_auxtel_transmission.txt
# OBS_TRANSMISSION_SYSTEMATICS 0.005
# PAPER False
# PIXDIST_BACKGROUND 140
# PIXSHIFT_PRIOR 5.0
# PIXWIDTH_BACKGROUND 40
# PIXWIDTH_BOXSIZE 20
# PIXWIDTH_SIGNAL 40
# PLATE_CENTER_SHIFT_X -6.0
# PLATE_CENTER_SHIFT_X_ERR 2.0
# PLATE_CENTER_SHIFT_Y -8.0
# PLATE_CENTER_SHIFT_Y_ERR 2.0
# PLOT_DIR plots
# PLOT_ROT_LABEL $\alpha$ [degrees]
# PLOT_XLABEL $x$ [pixels]
# PLOT_YLABEL $y$ [pixels]
# PSF_EXTRACTION_MODE PSF_2D
# PSF_FIT_REG_PARAM 1.0
# PSF_FWHM_CLIP 2.0
# PSF_PIXEL_STEP_TRANSVERSE_FIT 50
# PSF_POLY_ORDER 2
# PSF_TYPE Moffat
# RG715 {'label': 'RG715', 'min': 690, 'max': 1100}
# ROT_ANGLE_MAX 10.0
# ROT_ANGLE_MIN -10.0
# ROT_ORDER 5
# ROT_PREFILTER True
# SAVE False
# SED_UNIT 1.0 erg / (cm2 nm s)
# SPECTRACTOR_COMPUTE_ROTATION_ANGLE hessian
# SPECTRACTOR_DECONVOLUTION_FFM True
# SPECTRACTOR_DECONVOLUTION_PSF2D False
# SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP 100.0
# SPECTRACTOR_FIT_TARGET_CENTROID fit
# SPEC_ORDER 1
# STAR_NAMES ['22 Lib', 'WD 1327-083', 'ETA1DOR', 'spec:ETA1DOR', 'spec:MUCOL']
# THROUGHPUT_DIR /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/simulation/AuxTelThroughput/
# TIME_UNIT 1.0 s
# VERBOSE True
# XWINDOW 100
# XWINDOW_ROT 50
# YWINDOW 100
# YWINDOW_ROT 50
# ZGUNN {'label': 'Z-Gunn', 'min': 800, 'max': 1100}
# const <module 'astropy.constants' from '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/astropy/constants/__init__.py'>
# hc 1.9864458571489286e-25 J m
# mpl <module 'matplotlib' from '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/__init__.py'>
# mypath /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor
# np <module 'numpy' from '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/numpy/__init__.py'>
# os <module 'os' from '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/os.py'>
# units <module 'astropy.units' from '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/astropy/units/__init__.py'>
# wl_dwl_unit nm2
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [7], in <cell line: 19>()
#      14 # Prevent the executor from dumping plots into the notebook
#      15 #backend_ =  mpl.get_backend()
#      16 #mpl.use("Agg")
#      18 executor = SimplePipelineExecutor.from_pipeline(pipeline, where=whereString, butler=butlerRW)
# ---> 19 quanta = executor.run(True)
#      21 # Restore the ability for plots to be put into the notebook
#      22 mpl.use(backend_)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/ctrl_mpexec/g5106228df7+8f386c43b7/python/lsst/ctrl/mpexec/simple_pipeline_executor.py:254, in SimplePipelineExecutor.run(self, register_dataset_types)
#     227 def run(self, register_dataset_types: bool = False) -> List[Quantum]:
#     228     """Run all the quanta in the `QuantumGraph` in topological order.
#     229
#     230     Use this method to run all quanta in the graph.  Use
#    (...)
#     252     guarantees are made about the order in which quanta are processed.
#     253     """
# --> 254     return list(self.as_generator(register_dataset_types=register_dataset_types))
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/ctrl_mpexec/g5106228df7+8f386c43b7/python/lsst/ctrl/mpexec/simple_pipeline_executor.py:298, in <genexpr>(.0)
#     291 single_quantum_executor = SingleQuantumExecutor(task_factory)
#     292 # Important that this returns a generator expression rather than being
#     293 # a generator itself; that is what makes the PreExecInit stuff above
#     294 # happen immediately instead of when the first quanta is executed,
#     295 # which might be useful for callers who want to check the state of the
#     296 # repo in between.
#     297 return (
# --> 298     single_quantum_executor.execute(qnode.taskDef, qnode.quantum, self.butler)
#     299     for qnode in self.quantum_graph
#     300 )
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/ctrl_mpexec/g5106228df7+8f386c43b7/python/lsst/ctrl/mpexec/singleQuantumExecutor.py:140, in SingleQuantumExecutor.execute(self, taskDef, quantum, butler)
#     135 def execute(self, taskDef: TaskDef, quantum: Quantum, butler: Butler) -> Quantum:
#     136     # Docstring inherited from QuantumExecutor.execute
#     137
#     138     # Catch any exception and make a report based on that.
#     139     try:
# --> 140         result = self._execute(taskDef, quantum, butler)
#     141         self.report = QuantumReport(dataId=quantum.dataId, taskLabel=taskDef.label)
#     142         return result
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/ctrl_mpexec/g5106228df7+8f386c43b7/python/lsst/ctrl/mpexec/singleQuantumExecutor.py:218, in SingleQuantumExecutor._execute(self, taskDef, quantum, butler)
#     216     else:
#     217         runTask = task
# --> 218     self.runQuantum(runTask, quantum, taskDef, butler)
#     219 except Exception as e:
#     220     _LOG.error(
#     221         "Execution of task '%s' on quantum %s failed. Exception %s: %s",
#     222         taskDef.label,
#    (...)
#     225         str(e),
#     226     )
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/ctrl_mpexec/g5106228df7+8f386c43b7/python/lsst/ctrl/mpexec/singleQuantumExecutor.py:582, in SingleQuantumExecutor.runQuantum(self, task, quantum, taskDef, butler)
#     579 # Call task runQuantum() method.  Catch a few known failure modes and
#     580 # translate them into specific
#     581 try:
# --> 582     task.runQuantum(butlerQC, inputRefs, outputRefs)
#     583 except NoWorkFound as err:
#     584     # Not an error, just an early exit.
#     585     _LOG.info("Task '%s' on quantum %s exited early: %s", taskDef.label, quantum.dataId, str(err))
#
# File ~/repos/repos_w_2022_39/atmospec/python/lsst/atmospec/processStar.py:655, in ProcessStarTask.runQuantum(self, butlerQC, inputRefs, outputRefs)
#     651 inputs = butlerQC.get(inputRefs)
#     653 inputs['dataIdDict'] = inputRefs.inputExp.dataId.byName()
# --> 655 outputs = self.run(**inputs)
#     656 butlerQC.put(outputs, outputRefs)
#
# File ~/repos/repos_w_2022_39/atmospec/python/lsst/atmospec/processStar.py:781, in ProcessStarTask.run(self, inputExp, inputCentroid, dataIdDict)
#     778 else:  # it's a raw tuple
#     779     centroid = inputCentroid  # TODO: put this support in the docstring
# --> 781 spectraction = spectractor.run(inputExp, *centroid, target)
#     783 self.log.info("Finished processing %s" % (dataIdDict))
#     785 # self.makeResultPickleable(spectraction)
#
# File ~/repos/repos_w_2022_39/atmospec/python/lsst/atmospec/spectraction.py:367, in SpectractorShim.run(self, exp, xpos, ypos, target, outputRoot, plotting)
#     364 ypos = int(np.round(ypos))
#     366 filter_label, disperser = self._getFilterAndDisperserFromExp(exp)
# --> 367 image = self.spectractorImageFromLsstExposure(exp, xpos, ypos, target_label=target,
#     368                                               disperser_label=disperser,
#     369                                               filter_label=filter_label)
#     371 if parameters.DEBUG:
#     372     self.debugPrintTargetCentroidValue(image)
#
# File ~/repos/repos_w_2022_39/atmospec/python/lsst/atmospec/spectraction.py:167, in SpectractorShim.spectractorImageFromLsstExposure(self, exp, xpos, ypos, target_label, disperser_label, filter_label)
#     164 self.log.debug(f'DM value at centroid: {exp.image.array[ypos, xpos]}\n')
#     166 # make a blank image, with the filter/disperser set
# --> 167 image = Image(file_name='', target_label=target_label, disperser_label=disperser_label,
#     168               filter_label=filter_label)
#     170 vi = exp.getInfo().getVisitInfo()
#     171 rotAngle = vi.getBoresightRotAngle().asDegrees()
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/extractor/images.py:186, in Image.__init__(self, file_name, target_label, disperser_label, config, **kwargs)
#     183     t.reset_lambda_range(transmission_threshold=1e-4)
#     185 if self.target_label != "":
# --> 186     self.target = load_target(self.target_label, verbose=parameters.VERBOSE)
#     187     self.header['REDSHIFT'] = str(self.target.redshift)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/extractor/targets.py:49, in load_target(label, verbose)
#      19 """Load the target properties according to the type set by parameters.OBS_OBJECT_TYPE.
#      20
#      21 Currently, the type can be either "STAR", "HG-AR" or "MONOCHROMATOR". The label parameter gives the
#    (...)
#      46 [253.652, 296.728, 302.15, 313.155, 334.148]
#      47 """
#      48 if parameters.OBS_OBJECT_TYPE == 'STAR':
# ---> 49     return Star(label, verbose)
#      50 elif parameters.OBS_OBJECT_TYPE == 'HG-AR':
#      51     return ArcLamp(label, verbose)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/extractor/targets.py:198, in Star.__init__(self, label, verbose)
#     196 Target.__init__(self, label, verbose=verbose)
#     197 self.my_logger = set_logger(self.__class__.__name__)
# --> 198 self.load()
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/extractor/targets.py:242, in Star.load(self)
#     240 else:
#     241     self.redshift = 0
# --> 242 self.load_spectra()
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/spectractor/g90263d33d7/lib/python/spectractor/extractor/targets.py:277, in Star.load_spectra(self)
#     273 self.hydrogen_only = False
#     274 self.lines = Lines(HYDROGEN_LINES + ATMOSPHERIC_LINES + STELLAR_LINES,
#     275                    redshift=self.redshift, emission_spectrum=self.emission_spectrum,
#     276                    hydrogen_only=self.hydrogen_only)
# --> 277 spec_dict = calspec.get_spectrum_numpy()
#     278 # official units in spectractor are nanometers for wavelengths and erg/s/cm2/nm for fluxes
#     279 spec_dict["WAVELENGTH"] = spec_dict["WAVELENGTH"].to(u.nm)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/getCalspec/getCalspec.py:203, in Calspec.get_spectrum_numpy(self, output_directory)
#     186 def get_spectrum_numpy(self, output_directory=None):
#     187     """Make a dictionary of numpy arrays with astropy units from Calspec
#     188     FITS file.
#     189
#    (...)
#     201
#     202     """
# --> 203     t = self.get_spectrum_table(output_directory=output_directory)
#     204     d = {}
#     205     for k in range(0, 4):
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/getCalspec/getCalspec.py:182, in Calspec.get_spectrum_table(self, output_directory)
#     165 def get_spectrum_table(self, output_directory=None):
#     166     """
#     167
#     168     Returns
#    (...)
#     180
#     181     """
# --> 182     output_file_name = self.get_spectrum_fits_filename(output_directory=output_directory)
#     183     t = Table.read(output_file_name)
#     184     return t
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/getCalspec/getCalspec.py:160, in Calspec.get_spectrum_fits_filename(self, output_directory)
#     158 url = CALSPEC_ARCHIVE+spectrum_file_name
#     159 try:
# --> 160     request.urlretrieve(url, output_file_name)
#     161 except HTTPError as e:
#     162     raise RuntimeError(f"Failed to get data for {self.Name} from {url}") from e
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/urllib/request.py:251, in urlretrieve(url, filename, reporthook, data)
#     249 # Handle temporary file setup.
#     250 if filename:
# --> 251     tfp = open(filename, 'wb')
#     252 else:
#     253     tfp = tempfile.NamedTemporaryFile(delete=False)
#
# PermissionError: [Errno 13] Permission denied: '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/getCalspec/../calspec_data/hd160617_stis_005.fits'

# %%
datasetRefs = registry.queryDatasets(datasetType='postISRCCD', collections = outputCollection , where= "instrument='LATISS'")

# %%
import getCalspec

# %%
getCalspec.__file__
