# %% [markdown]
# # Get Calspec

# %% [markdown]
# https://github.com/LSSTDESC/getCalspec

# %%
from getCalspec.getCalspec import *

# %%
from getCalspec.rebuild import rebuild_cache

# %%
from getCalspec.rebuild import rebuild_tables, rebuild_cache
rebuild_tables()
rebuild_cache()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from getCalspec.rebuild import rebuild_tables, rebuild_cache
# ----> 2 rebuild_tables()
#       3 rebuild_cache()
#
# File ~/anaconda3/lib/python3.9/site-packages/getCalspec/rebuild.py:70, in rebuild_tables()
#      69 def rebuild_tables():
# ---> 70     tables = pd.read_html(CALSPEC_URL)
#      71     for table in tables:
#      72         if isinstance(table.columns, pd.MultiIndex):
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
rebuild_cache()
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/getCalspec/getCalspec.py:154, in Calspec.get_spectrum_fits_filename(self)
#     153 try:
# --> 154     output_file_name = download_file(url, cache=True)
#     155 except URLError as e:
#
# File ~/anaconda3/lib/python3.9/site-packages/astropy/utils/data.py:1541, in download_file(remote_url, cache, show_progress, timeout, sources, pkgname, http_headers, ssl_context, allow_insecure)
#    1540 elif len(sources) == 1:
# -> 1541     raise errors[sources[0]]
#    1542 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/astropy/utils/data.py:1509, in download_file(remote_url, cache, show_progress, timeout, sources, pkgname, http_headers, ssl_context, allow_insecure)
#    1508 try:
# -> 1509     f_name = _download_file_from_source(
#    1510         source_url,
# ...
