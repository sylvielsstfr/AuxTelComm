# %% [markdown]
# # List of Exposures with Biases
#
#
# - work with Weakly_2022_34
# - use jupyter kernel LSST
# - run at SLAC USDF
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2022/09/19

# %%
! eups list -s | grep LOCAL
# Out:
# atmospec              LOCAL:/home/d/dagoret/repos/repos_w_2022_34/atmospec 	setup
# eups                  LOCAL:/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/eups 	setup

# %%
! echo $IMAGE_DESCRIPTION
! eups list -s lsst_distrib
# Out:
# w_2022_34
#    g0b29ad24fb+897c4bc163 	current w_2022_34 setup

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib.colors import LogNorm

from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.ticker                         # here's where the formatter is
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

from astropy.io import fits

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
import lsst.daf.butler as dafButler

# %%
repo = '/sdf/group/rubin/repo/main'
butler = dafButler.Butler(repo)
registry = butler.registry

# %% [markdown]
# ## List of Exposures

# %%
df_exposure = pd.DataFrame(columns=['id', 'obs_id','day_obs','group_name' ,'seq_num', 'type', 'target','filter','zenith_angle','expos','ra','dec','skyangle'])

# %%
for count, info in enumerate(registry.queryDimensionRecords('exposure',where= "instrument='LATISS'")):
    
    
    df_exposure.loc[count] = [info.id, info.obs_id, info.day_obs, info.group_name,info.seq_num, info.observation_type, info.target_name, info.physical_filter, info.zenith_angle, \
                             info.exposure_time,info.tracking_ra, info.tracking_dec, info.sky_angle]
    
    if count < 0:
        print("-----------------------------------------------------",count,"---------------------------------------------------------")
        print(info)
        print("\t id:                  ",info.id)
        print("\t day_obs:             ",info.day_obs)
        print("\t group_name:             ",info.group_name)
        print("\t seq_num:             ",info.seq_num)
        print("\t type-of-observation: ",info.observation_type)
        print("\t target:              ",info.target_name)

# %%
df_exposure
# Out:
#                   id                obs_id   day_obs               group_name  \
# 0      2022062800004  AT_O_20220628_000004  20220628  2022-06-28T17:03:59.508
# 1      2022070600001  AT_O_20220706_000001  20220706            2022070600001
# 2      2022070700001  AT_O_20220707_000001  20220707  2022-07-07T13:58:52.184
# 3      2022071100001  AT_O_20220711_000001  20220711  2022-07-11T18:15:33.507
# 4      2022071200001  AT_O_20220712_000001  20220712  2022-07-12T15:42:44.109
# ...              ...                   ...       ...                      ...
# 44232  2022060900935  AT_O_20220609_000935  20220609  2022-06-10T10:20:00.477
# 44233  2022060900936  AT_O_20220609_000936  20220609  2022-06-10T10:20:00.477
# 44234  2022060900937  AT_O_20220609_000937  20220609  2022-06-10T10:20:00.477
# 44235  2022060900938  AT_O_20220609_000938  20220609  2022-06-10T10:20:00.477
# 44236  2022060900939  AT_O_20220609_000939  20220609  2022-06-10T10:20:00.477
#
#        seq_num  type         target               filter zenith_angle  expos  \
# 0            4  bias  Park position          SDSSr~empty          NaN    0.0
# 1            1  test        UNKNOWN      unknown~unknown          NaN    5.0
# 2            1  bias        UNKNOWN  empty~ronchi170lpmm          NaN    0.0
# 3            1  bias        UNKNOWN   FELH0600~holo4_003          NaN    0.0
# 4            1  bias        UNKNOWN      SDSSg~holo4_003          NaN    0.0
# ...        ...   ...            ...                  ...          ...    ...
# 44232      935  cwfs      HD 221054          SDSSg~empty    21.707667   30.0
# 44233      936  cwfs      HD 221054          SDSSg~empty    21.670582   30.0
# 44234      937  cwfs      HD 221054          SDSSg~empty    21.594164   30.0
# 44235      938  cwfs      HD 221054          SDSSg~empty    21.559853   30.0
# 44236      939   acq      HD 221054          SDSSg~empty    21.491898    5.0
#
#                ra        dec    skyangle
# 0             NaN        NaN         NaN
# 1             NaN        NaN         NaN
# 2             NaN        NaN         NaN
# 3             NaN        NaN         NaN
# 4             NaN        NaN         NaN
# ...           ...        ...         ...
# 44232  352.285362 -51.019608  269.453648
# 44233   352.28535 -51.019575  269.453634
# 44234  352.285373 -51.019592  269.453635
# 44235  352.285369 -51.019605  269.453759
# 44236  352.285365  -51.01959  269.453698
#
# [44237 rows x 13 columns]

# %% [markdown]
# ## Selection of Bias

# %%
df_bias = df_exposure[df_exposure.type == 'bias']

# %%
df_bias.sort_values(by="id",ascending=True,inplace=True)
# Out:
# /tmp/ipykernel_6003/1884773382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bias.sort_values(by="id",ascending=True,inplace=True)

# %%
df_bias.tail(60)
# Out:
#                   id                obs_id   day_obs               group_name  \
# 42506  2022060800113  AT_O_20220608_000113  20220608  2022-06-08T21:22:47.182
# 42507  2022060800114  AT_O_20220608_000114  20220608  2022-06-08T21:22:49.514
# 42508  2022060800115  AT_O_20220608_000115  20220608  2022-06-08T21:22:52.005
# 42509  2022060800117  AT_O_20220608_000117  20220608  2022-06-08T21:22:56.826
# 42510  2022060800118  AT_O_20220608_000118  20220608  2022-06-08T21:22:59.165
# 42511  2022060800119  AT_O_20220608_000119  20220608  2022-06-08T21:23:01.651
# 42512  2022060800120  AT_O_20220608_000120  20220608  2022-06-08T21:23:03.984
# 42513  2022060800121  AT_O_20220608_000121  20220608  2022-06-08T21:23:06.475
# 42514  2022060800122  AT_O_20220608_000122  20220608  2022-06-08T21:23:08.811
# 42515  2022060800123  AT_O_20220608_000123  20220608  2022-06-08T21:27:05.401
# 42516  2022060800124  AT_O_20220608_000124  20220608  2022-06-08T21:27:07.888
# 42517  2022060800125  AT_O_20220608_000125  20220608  2022-06-08T21:27:10.221
# 42518  2022060800126  AT_O_20220608_000126  20220608  2022-06-08T21:27:12.718
# 42519  2022060800127  AT_O_20220608_000127  20220608  2022-06-08T21:27:15.053
# 42520  2022060800128  AT_O_20220608_000128  20220608  2022-06-08T21:27:17.540
# 42521  2022060800129  AT_O_20220608_000129  20220608  2022-06-08T21:27:19.876
# 42522  2022060800130  AT_O_20220608_000130  20220608  2022-06-08T21:27:22.362
# 42523  2022060800131  AT_O_20220608_000131  20220608  2022-06-08T21:27:24.699
# 42524  2022060800132  AT_O_20220608_000132  20220608  2022-06-08T21:27:27.188
# 42525  2022060800133  AT_O_20220608_000133  20220608  2022-06-08T21:27:29.521
# 42526  2022060800134  AT_O_20220608_000134  20220608  2022-06-08T21:27:32.009
# 42527  2022060800135  AT_O_20220608_000135  20220608  2022-06-08T21:27:34.346
# 42528  2022060800136  AT_O_20220608_000136  20220608  2022-06-08T21:27:36.835
# 42529  2022060800137  AT_O_20220608_000137  20220608  2022-06-08T21:27:39.172
# 43299  2022060900001  AT_O_20220609_000001  20220609  2022-06-09T19:22:28.546
# 43303  2022060900005  AT_O_20220609_000005  20220609  2022-06-09T21:11:40.565
# 43304  2022060900006  AT_O_20220609_000006  20220609  2022-06-09T21:11:40.565
# 43305  2022060900007  AT_O_20220609_000007  20220609  2022-06-09T21:11:40.565
# 43306  2022060900008  AT_O_20220609_000008  20220609  2022-06-09T21:11:40.565
# 43307  2022060900009  AT_O_20220609_000009  20220609  2022-06-09T21:11:40.565
# 43308  2022060900010  AT_O_20220609_000010  20220609  2022-06-09T21:11:40.565
# 43309  2022060900011  AT_O_20220609_000011  20220609  2022-06-09T21:11:40.565
# 43310  2022060900012  AT_O_20220609_000012  20220609  2022-06-09T21:11:40.565
# 43311  2022060900013  AT_O_20220609_000013  20220609  2022-06-09T21:11:40.565
# 43312  2022060900014  AT_O_20220609_000014  20220609  2022-06-09T21:11:40.565
# 0      2022062800004  AT_O_20220628_000004  20220628  2022-06-28T17:03:59.508
# 22     2022062800010  AT_O_20220628_000010  20220628  2022-06-28T22:23:59.482
# 25     2022062800011  AT_O_20220628_000011  20220628  2022-06-28T22:24:01.976
# 28     2022062800012  AT_O_20220628_000012  20220628  2022-06-28T22:24:04.315
# 31     2022062800013  AT_O_20220628_000013  20220628  2022-06-28T22:24:06.806
# 34     2022062800014  AT_O_20220628_000014  20220628  2022-06-28T22:24:09.141
# 37     2022062800015  AT_O_20220628_000015  20220628  2022-06-28T22:24:11.631
# 764    2022062900001  AT_O_20220629_000001  20220629  2022-06-29T19:07:18.779
# 769    2022062900006  AT_O_20220629_000006  20220629  2022-06-29T21:23:51.873
# 770    2022062900007  AT_O_20220629_000007  20220629  2022-06-29T21:23:54.364
# 771    2022062900008  AT_O_20220629_000008  20220629  2022-06-29T21:23:56.700
# 772    2022062900009  AT_O_20220629_000009  20220629  2022-06-29T21:23:59.186
# 773    2022062900010  AT_O_20220629_000010  20220629  2022-06-29T21:24:01.520
# 774    2022062900011  AT_O_20220629_000011  20220629  2022-06-29T21:24:04.011
# 1324   2022063000001  AT_O_20220630_000001  20220630  2022-06-30T19:58:59.212
# 1326   2022063000003  AT_O_20220630_000003  20220630  2022-06-30T22:06:32.048
# 1327   2022063000004  AT_O_20220630_000004  20220630  2022-06-30T22:06:34.534
# 1328   2022063000005  AT_O_20220630_000005  20220630  2022-06-30T22:06:36.871
# 1329   2022063000006  AT_O_20220630_000006  20220630  2022-06-30T22:06:39.363
# 1330   2022063000007  AT_O_20220630_000007  20220630  2022-06-30T22:06:41.698
# 1331   2022063000008  AT_O_20220630_000008  20220630  2022-06-30T22:06:44.186
# 2      2022070700001  AT_O_20220707_000001  20220707  2022-07-07T13:58:52.184
# 3      2022071100001  AT_O_20220711_000001  20220711  2022-07-11T18:15:33.507
# 44     2022071100014  AT_O_20220711_000014  20220711  2022-07-11T22:34:15.469
# 4      2022071200001  AT_O_20220712_000001  20220712  2022-07-12T15:42:44.109
#
#        seq_num  type              target               filter zenith_angle  \
# 42506      113  bias  FlatField position       FELH0600~empty         None
# 42507      114  bias  FlatField position       FELH0600~empty         None
# 42508      115  bias  FlatField position       FELH0600~empty         None
# 42509      117  bias  FlatField position       FELH0600~empty         None
# 42510      118  bias  FlatField position       FELH0600~empty         None
# 42511      119  bias  FlatField position       FELH0600~empty         None
# 42512      120  bias  FlatField position       FELH0600~empty         None
# 42513      121  bias  FlatField position       FELH0600~empty         None
# 42514      122  bias  FlatField position       FELH0600~empty         None
# 42515      123  bias  FlatField position       FELH0600~empty         None
# 42516      124  bias  FlatField position       FELH0600~empty         None
# 42517      125  bias  FlatField position       FELH0600~empty         None
# 42518      126  bias  FlatField position       FELH0600~empty         None
# 42519      127  bias  FlatField position       FELH0600~empty         None
# 42520      128  bias  FlatField position       FELH0600~empty         None
# 42521      129  bias  FlatField position       FELH0600~empty         None
# 42522      130  bias  FlatField position       FELH0600~empty         None
# 42523      131  bias  FlatField position       FELH0600~empty         None
# 42524      132  bias  FlatField position       FELH0600~empty         None
# 42525      133  bias  FlatField position       FELH0600~empty         None
# 42526      134  bias  FlatField position       FELH0600~empty         None
# 42527      135  bias  FlatField position       FELH0600~empty         None
# 42528      136  bias  FlatField position       FELH0600~empty         None
# 42529      137  bias  FlatField position       FELH0600~empty         None
# 43299        1  bias       Park position  empty~ronchi170lpmm         None
# 43303        5  bias  FlatField position          empty~empty         None
# 43304        6  bias  FlatField position          empty~empty         None
# 43305        7  bias  FlatField position          empty~empty         None
# 43306        8  bias  FlatField position          empty~empty         None
# 43307        9  bias  FlatField position          empty~empty         None
# 43308       10  bias  FlatField position          empty~empty         None
# 43309       11  bias  FlatField position          empty~empty         None
# 43310       12  bias  FlatField position          empty~empty         None
# 43311       13  bias  FlatField position          empty~empty         None
# 43312       14  bias  FlatField position          empty~empty         None
# 0            4  bias       Park position          SDSSr~empty          NaN
# 22          10  bias  FlatField position       FELH0600~empty         None
# 25          11  bias  FlatField position       FELH0600~empty         None
# 28          12  bias  FlatField position       FELH0600~empty         None
# 31          13  bias  FlatField position       FELH0600~empty         None
# 34          14  bias  FlatField position       FELH0600~empty         None
# 37          15  bias  FlatField position       FELH0600~empty         None
# 764          1  bias       Park position          SDSSr~empty         None
# 769          6  bias  FlatField position          SDSSr~empty         None
# 770          7  bias  FlatField position          SDSSr~empty         None
# 771          8  bias  FlatField position          SDSSr~empty         None
# 772          9  bias  FlatField position          SDSSr~empty         None
# 773         10  bias  FlatField position          SDSSr~empty         None
# 774         11  bias  FlatField position          SDSSr~empty         None
# 1324         1  bias       Park position          SDSSr~empty         None
# 1326         3  bias  FlatField position      SDSSr~holo4_003         None
# 1327         4  bias  FlatField position      SDSSr~holo4_003         None
# 1328         5  bias  FlatField position      SDSSr~holo4_003         None
# 1329         6  bias  FlatField position      SDSSr~holo4_003         None
# 1330         7  bias  FlatField position      SDSSr~holo4_003         None
# 1331         8  bias  FlatField position      SDSSr~holo4_003         None
# 2            1  bias             UNKNOWN  empty~ronchi170lpmm          NaN
# 3            1  bias             UNKNOWN   FELH0600~holo4_003          NaN
# 44          14  bias             UNKNOWN      SDSSg~holo4_003         None
# 4            1  bias             UNKNOWN      SDSSg~holo4_003          NaN
#
#        expos    ra   dec skyangle
# 42506    0.0  None  None     None
# 42507    0.0  None  None     None
# 42508    0.0  None  None     None
# 42509    0.0  None  None     None
# 42510    0.0  None  None     None
# 42511    0.0  None  None     None
# 42512    0.0  None  None     None
# 42513    0.0  None  None     None
# 42514    0.0  None  None     None
# 42515    0.0  None  None     None
# 42516    0.0  None  None     None
# 42517    0.0  None  None     None
# 42518    0.0  None  None     None
# 42519    0.0  None  None     None
# 42520    0.0  None  None     None
# 42521    0.0  None  None     None
# 42522    0.0  None  None     None
# 42523    0.0  None  None     None
# 42524    0.0  None  None     None
# 42525    0.0  None  None     None
# 42526    0.0  None  None     None
# 42527    0.0  None  None     None
# 42528    0.0  None  None     None
# 42529    0.0  None  None     None
# 43299    0.0  None  None     None
# 43303    0.0  None  None     None
# 43304    0.0  None  None     None
# 43305    0.0  None  None     None
# 43306    0.0  None  None     None
# 43307    0.0  None  None     None
# 43308    0.0  None  None     None
# 43309    0.0  None  None     None
# 43310    0.0  None  None     None
# 43311    0.0  None  None     None
# 43312    0.0  None  None     None
# 0        0.0   NaN   NaN      NaN
# 22       0.0  None  None     None
# 25       0.0  None  None     None
# 28       0.0  None  None     None
# 31       0.0  None  None     None
# 34       0.0  None  None     None
# 37       0.0  None  None     None
# 764      0.0  None  None     None
# 769      0.0  None  None     None
# 770      0.0  None  None     None
# 771      0.0  None  None     None
# 772      0.0  None  None     None
# 773      0.0  None  None     None
# 774      0.0  None  None     None
# 1324     0.0  None  None     None
# 1326     0.0  None  None     None
# 1327     0.0  None  None     None
# 1328     0.0  None  None     None
# 1329     0.0  None  None     None
# 1330     0.0  None  None     None
# 1331     0.0  None  None     None
# 2        0.0   NaN   NaN      NaN
# 3        0.0   NaN   NaN      NaN
# 44       0.0  None  None     None
# 4        0.0   NaN   NaN      NaN

# %%
df_bias.day_obs.unique()
# Out:
# array([20190309, 20190322, 20190326, 20190329, 20190402, 20190403,
#        20190404, 20190405, 20190412, 20190612, 20190810, 20190814,
#        20190817, 20190819, 20190821, 20190915, 20191106, 20191108,
#        20200117, 20200121, 20200122, 20200123, 20200127, 20200128,
#        20200129, 20200212, 20200217, 20200218, 20200219, 20200220,
#        20200221, 20200312, 20200313, 20200314, 20200315, 20200316,
#        20201030, 20210115, 20210119, 20210120, 20210121, 20210126,
#        20210127, 20210201, 20210202, 20210204, 20210215, 20210216,
#        20210217, 20210218, 20210304, 20210305, 20210309, 20210310,
#        20210311, 20210318, 20210322, 20210323, 20210408, 20210414,
#        20210521, 20210524, 20210525, 20210607, 20210608, 20210609,
#        20210610, 20210625, 20210628, 20210702, 20210706, 20210707,
#        20210708, 20210712, 20210713, 20210716, 20210720, 20210727,
#        20210728, 20210804, 20210805, 20210816, 20210817, 20210818,
#        20210820, 20210902, 20210903, 20210907, 20210908, 20210909,
#        20210913, 20210930, 20211004, 20211005, 20211006, 20211007,
#        20211008, 20211013, 20211014, 20211102, 20211103, 20211104,
#        20211130, 20211201, 20211202, 20220203, 20220204, 20220207,
#        20220208, 20220209, 20220211, 20220215, 20220216, 20220217,
#        20220223, 20220224, 20220304, 20220308, 20220311, 20220314,
#        20220315, 20220316, 20220317, 20220318, 20220324, 20220325,
#        20220329, 20220404, 20220405, 20220406, 20220407, 20220414,
#        20220421, 20220422, 20220425, 20220426, 20220427, 20220428,
#        20220429, 20220502, 20220503, 20220504, 20220505, 20220511,
#        20220520, 20220524, 20220525, 20220526, 20220527, 20220531,
#        20220601, 20220602, 20220603, 20220606, 20220607, 20220608,
#        20220609, 20220628, 20220629, 20220630, 20220707, 20220711,
#        20220712])

# %% [markdown]
# ## Selection of date

# %%
date_sel = 20220609

# %%
df_bias_selected = df_bias[df_bias.day_obs == date_sel ]

# %%
len(df_bias_selected)
# Out:
# 11

# %% [markdown]
# ## Final selection of exposure

# %%
pd.set_option('display.max_rows', None)

# %%
df = df_bias_selected
df_sel = df[['day_obs', 'seq_num']]
    
    
NN = len(df)
    
if NN>0:
        # build the line
        
    df_sel['line'] = df_sel.apply(lambda row: str(row['day_obs'])  + " " + str(row['seq_num']),axis = 1)
    
    
    # prepare output
    filename_out = "visitbias_"+ str(date_sel) + ".list"
    print(filename_out)
        
    df_out = df_sel[["line"]]
    df_out.to_csv(filename_out, index=False, header=None)
# Out:
# visitbias_20220609.list
# /tmp/ipykernel_6003/1927370446.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sel['line'] = df_sel.apply(lambda row: str(row['day_obs'])  + " " + str(row['seq_num']),axis = 1)

# %%
df_sel
# Out:
#         day_obs  seq_num         line
# 43299  20220609        1   20220609 1
# 43303  20220609        5   20220609 5
# 43304  20220609        6   20220609 6
# 43305  20220609        7   20220609 7
# 43306  20220609        8   20220609 8
# 43307  20220609        9   20220609 9
# 43308  20220609       10  20220609 10
# 43309  20220609       11  20220609 11
# 43310  20220609       12  20220609 12
# 43311  20220609       13  20220609 13
# 43312  20220609       14  20220609 14
