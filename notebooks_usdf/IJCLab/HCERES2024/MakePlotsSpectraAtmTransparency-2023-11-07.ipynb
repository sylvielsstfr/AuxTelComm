# %% [markdown]
# # MakePlotsForHCERES2024

# %% [markdown]
# https://github.com/JospehCeh/PhotoZ_PhD/blob/u/dagoret/StudyFors2SED/ReadFors2spectrafromh5.ipynb
#
# https://www.christopherlovell.co.uk/blog/2016/04/27/h5py-intro.html
#
#
# - creation date : 2024-01-21
# - update : 2024-01-22

# %%
import os,sys,re
import h5py # one standard python package to work on hdf5 file
import tables #naother python package to work on df5 file and have dump capabilities

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import seaborn as sns 
from matplotlib.backends.backend_pdf import PdfPages

# %matplotlib inline
import pandas as pd

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'large',
          'figure.figsize': (4, 4),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

# %%
# SMOOTHING

def smooth_data_convolve_my_average(arr, span):
    re = np.convolve(arr, np.ones(span * 2 + 1) / (span * 2 + 1), mode="same")

    # The "my_average" part: shrinks the averaging window on the side that 
    # reaches beyond the data, keeps the other side the same size as given 
    # by "span"
    re[0] = np.average(arr[:span])
    for i in range(1, span + 1):
        re[i] = np.average(arr[:i + span])
        re[-i] = np.average(arr[-i - span:])
    return re

def smooth_data_np_average(arr, span):  # my original, naive approach
    return [np.average(arr[val - span:val + span + 1]) for val in range(len(arr))]

def smooth_data_np_convolve(arr, span):
    return np.convolve(arr, np.ones(span * 2 + 1) / (span * 2 + 1), mode="same")

def smooth_data_np_cumsum_my_average(arr, span):
    cumsum_vec = np.cumsum(arr)
    moving_average = (cumsum_vec[2 * span:] - cumsum_vec[:-2 * span]) / (2 * span)

    # The "my_average" part again. Slightly different to before, because the
    # moving average from cumsum is shorter than the input and needs to be padded
    front, back = [np.average(arr[:span])], []
    for i in range(1, span):
        front.append(np.average(arr[:i + span]))
        back.insert(0, np.average(arr[-i - span:]))
    back.insert(0, np.average(arr[-2 * span:]))
    return np.concatenate((front, moving_average, back))

def smooth_data_lowess(arr, span):
    x = np.linspace(0, 1, len(arr))
    return sm.nonparametric.lowess(arr, x, frac=(5*span / len(arr)), return_sorted=False)

def smooth_data_kernel_regression(arr, span):
    # "span" smoothing parameter is ignored. If you know how to 
    # incorporate that with kernel regression, please comment below.
    kr = KernelReg(arr, np.linspace(0, 1, len(arr)), 'c')
    return kr.fit()[0]

def smooth_data_savgol_0(arr, span):  
    return savgol_filter(arr, span * 2 + 1, 0)

def smooth_data_savgol_1(arr, span):  
    return savgol_filter(arr, span * 2 + 1, 1)

def smooth_data_savgol_2(arr, span):  
    return savgol_filter(arr, span * 2 + 1, 2)

def smooth_data_fft(arr, span):  # the scaling of "span" is open to suggestions
    w = fftpack.rfft(arr)
    spectrum = w ** 2
    cutoff_idx = spectrum < (spectrum.max() * (1 - np.exp(-span / 2000)))
    w[cutoff_idx] = 0
    return fftpack.irfft(w)

# %%
def get_all(name):
    """
    Use it with  hf.visit(get_all)
    Then it will print all groups, subgroups and datasets
    Note this function returns nothing so it cannot be used to retrieve somthing
    it will keep iterating.
    """
    print(name)

# %%
def print_attrs(name, obj):
    """
    Use it with hf.visititems(print_attrs)
    """
    for key, val in obj.attrs.items():
        print("  %s  %s: %s" % (name,key, val))

# %%
def get_attrs(name,obj):
    d = {}
    for key, val in obj.attrs.items():
        d[key] = val
    return d

# %%
# list all attributes
# hf.visititems(print_attrs)

# %%
def get_objects_group(name, obj):
    """
    hf.visititems(get_objects_group)
    act as a kind of filter
    """
    if isinstance(obj,h5py.Group):
        print("\t >>> ",name,'is a Group')
    return obj

# %%
def get_objects_dataset(name, obj):
    """
    hf.visititems(get_objects_dataset)
    act as a kind of filter
    """
    if isinstance(obj,h5py.Dataset):
            print("\t >>> ", name,'is a Dataset')
    return obj

# %%
# get all the name of the groups nd datasets , not the attributes
#hf.visit(get_all)

# %%
path = "Data_Auxtel_Spectro"

# %%
list_of_files = sorted(os.listdir(path))
list_of_files
# Out:
# ['spectra_transmission_ratio_20230927.h5',
#  'spectra_transmission_ratio_20230928.h5',
#  'spectra_transmission_ratio_20231010.h5',
#  'spectra_transmission_ratio_20231107.h5',
#  'spectra_transmission_ratio_20231113.h5',
#  'spectra_transmission_ratio_20231114.h5',
#  'spectra_transmission_ratio_20231115.h5',
#  'spectra_transmission_ratio_20231116.h5',
#  'spectra_transmission_ratio_20231120.h5',
#  'spectra_transmission_ratio_20231127.h5',
#  'spectra_transmission_ratio_20231128.h5',
#  'spectra_transmission_ratio_20231129.h5',
#  'spectra_transmission_ratio_20231130.h5',
#  'spectra_transmission_ratio_20231204.h5',
#  'spectra_transmission_ratio_20231205.h5',
#  'spectra_transmission_ratio_20231206.h5',
#  'spectra_transmission_ratio_20231207.h5']

# %% [markdown]
# ## Open the selected

# %%
#DATEOBS = 20231010
#DATEOBS = 20231127
DATEOBS = 20231107
base_filename = f"spectra_transmission_ratio_{DATEOBS}.h5"
filename = os.path.join(path,base_filename)

# %%
# Dump the file
#the_table = tables.open_file(filename, mode="r")
#the_table

# %%
hf = h5py.File(filename, 'r')

# %%
# Best way to dump the content of a file
hf.visititems(print_attrs)
# Out:
#   median_param_atm  md_PWV: 2.1019619347222998
#   median_param_atm  md_VAOD: 0.01323898800907555
#   median_param_atm  md_grey: 0.9720176299051349
#   median_param_atm  md_ozone: 304.65923242464345
#   sim_spec  PWV: 2.1019619347222998
#   sim_spec  VAOD: 0.01323898800907555
#   sim_spec  ozone: 304.65923242464345
#   spec_2023110700364  PWV: 1.7129097920767338
#   spec_2023110700364  VAOD: 0.020489989086570615
#   spec_2023110700364  airmass: 1.08150410157688
#   spec_2023110700364  flag_atmparam: 1
#   spec_2023110700364  grey: 0.9720176299051349
#   spec_2023110700364  ozone: 339.3446205954324
#   spec_2023110700364  target: HD2811
#   spec_2023110700384  PWV: 2.1019619347222998
#   spec_2023110700384  VAOD: 0.01323898800907555
#   spec_2023110700384  airmass: 1.97467446800652
#   spec_2023110700384  flag_atmparam: 0
#   spec_2023110700384  grey: 0.9720176299051349
#   spec_2023110700384  ozone: 304.65923242464345
#   spec_2023110700384  target: HD185975
#   spec_2023110700385  PWV: 1.7378620241653329
#   spec_2023110700385  VAOD: 2.7454686030056197e-12
#   spec_2023110700385  airmass: 1.9754688916128
#   spec_2023110700385  flag_atmparam: 1
#   spec_2023110700385  grey: 0.9720176299051349
#   spec_2023110700385  ozone: 303.97171028697744
#   spec_2023110700385  target: HD185975
#   spec_2023110700426  PWV: 1.9861044007411615
#   spec_2023110700426  VAOD: 0.023666832644435525
#   spec_2023110700500  VAOD: 0.01323898800907555
#   spec_2023110700500  airmass: 1.65605846678763
#   spec_2023110700500  flag_atmparam: 0
#   spec_2023110700500  grey: 0.9720176299051349
#   spec_2023110700500  ozone: 304.65923242464345
#   spec_2023110700500  target: HD2811
#   spec_2023110700501  PWV: 2.1019619347222998
#   spec_2023110700501  VAOD: 0.01323898800907555
#   spec_2023110700501  airmass: 1.66442527123212
#   spec_2023110700501  flag_atmparam: 0
#   spec_2023110700501  grey: 0.9720176299051349
#   spec_2023110700501  ozone: 304.65923242464345
#   spec_2023110700501  target: HD2811
#   spec_2023110700530  PWV: 2.1019619347222998
#   spec_2023110700530  VAOD: 0.01323898800907555
#   spec_2023110700530  airmass: 1.91953405499685
#   spec_2023110700530  flag_atmparam: 0
#   spec_2023110700530  grey: 0.9720176299051349
#   spec_2023110700530  ozone: 304.65923242464345
#   spec_2023110700530  target: HD2811
#   spec_2023110700550  PWV: 2.1019619347222998
#   spec_2023110700550  VAOD: 0.01323898800907555
#   spec_2023110700550  airmass: 2.16652078072684
#   spec_2023110700550  flag_atmparam: 0
#   spec_2023110700550  grey: 0.9720176299051349
#   spec_2023110700550  ozone: 304.65923242464345
#   spec_2023110700550  target: HD2811
#   spec_2023110700556  PWV: 1.9523079104138183
#   spec_2023110700556  VAOD: 0.0
#   spec_2023110700556  airmass: 2.10331080531695
#   spec_2023110700556  flag_atmparam: 1
#   spec_2023110700556  grey: 0.9720176299051349
#   spec_2023110700556  ozone: 307.0621627695475
#   spec_2023110700556  target: HD185975
#   spec_2023110700557  PWV: 2.1019619347222998
#   spec_2023110700557  VAOD: 0.01323898800907555
#   spec_2023110700557  airmass: 2.10388585205142
#   spec_2023110700557  flag_atmparam: 0
#   spec_2023110700557  grey: 0.9720176299051349
#   spec_2023110700557  ozone: 304.65923242464345
#   spec_2023110700557  target: HD185975
#   spec_2023110700571  PWV: 2.1019619347222998
#   spec_2023110700571  VAOD: 0.01323898800907555
#   spec_2023110700571  airmass: 1.00759612281391
#   spec_2023110700571  flag_atmparam: 0
#   spec_2023110700571  grey: 0.9720176299051349
#   spec_2023110700571  ozone: 304.65923242464345
#   spec_2023110700571  target: HD38666

# %%
list(hf.keys())
# Out:
# ['median_param_atm',
#  'sim_spec',
#  'spec_2023110700364',
#  'spec_2023110700384',
#  'spec_2023110700385',
#  'spec_2023110700426',
#  'spec_2023110700427',
#  'spec_2023110700434',
#  'spec_2023110700439',
#  'spec_2023110700440',
#  'spec_2023110700452',
#  'spec_2023110700453',
#  'spec_2023110700486',
#  'spec_2023110700493',
#  'spec_2023110700494',
#  'spec_2023110700500',
#  'spec_2023110700501',
#  'spec_2023110700530',
#  'spec_2023110700550',
#  'spec_2023110700556',
#  'spec_2023110700557',
#  'spec_2023110700571']

# %% [markdown]
# ## Read all the attributes and the datasets for all top level group in this loop

# %%
all_attributes = {}
all_datasets = {}
list_of_keys = list(hf.keys())

# loop on each key of top level groups
for key in list_of_keys: 
    group = hf.get(key)
    
    # retrieve all attributes for each group
    all_attributes[key] = get_attrs(key,group)

    datasets = {}
    for name, h5obj in group.items():
        if isinstance(h5obj,h5py.Group):
            # just check if there are subgroups that would need to be red recursively
            print("\t >>> ",key,' / ',name,'is a Group')
         
        elif isinstance(h5obj,h5py.Dataset):
            print("\t >>> ", key , name,'is a Dataset')
            arr = h5obj[:]
            #arr = hf[name][:] # same thing
            # add that dataset to the current group datasets
            datasets[name] = arr
    
    all_datasets[key] = datasets
# Out:
# 	 >>>  sim_spec transm is a Dataset
# 	 >>>  sim_spec wls is a Dataset
# 	 >>>  spec_2023110700364 fls is a Dataset
# 	 >>>  spec_2023110700364 fls_err is a Dataset
# 	 >>>  spec_2023110700364 ratio is a Dataset
# 	 >>>  spec_2023110700364 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700364 ratio_err is a Dataset
# 	 >>>  spec_2023110700364 wlr is a Dataset
# 	 >>>  spec_2023110700364 wls is a Dataset
# 	 >>>  spec_2023110700384 fls is a Dataset
# 	 >>>  spec_2023110700384 fls_err is a Dataset
# 	 >>>  spec_2023110700384 ratio is a Dataset
# 	 >>>  spec_2023110700384 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700384 ratio_err is a Dataset
# 	 >>>  spec_2023110700384 wlr is a Dataset
# 	 >>>  spec_2023110700384 wls is a Dataset
# 	 >>>  spec_2023110700385 fls is a Dataset
# 	 >>>  spec_2023110700385 fls_err is a Dataset
# 	 >>>  spec_2023110700385 ratio is a Dataset
# 	 >>>  spec_2023110700385 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700385 ratio_err is a Dataset
# 	 >>>  spec_2023110700385 wlr is a Dataset
# 	 >>>  spec_2023110700385 wls is a Dataset
# 	 >>>  spec_2023110700426 fls is a Dataset
# 	 >>>  spec_2023110700426 fls_err is a Dataset
# 	 >>>  spec_2023110700426 ratio is a Dataset
# 	 >>>  spec_2023110700426 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700426 ratio_err is a Dataset
# 	 >>>  spec_2023110700426 wlr is a Dataset
# 	 >>>  spec_2023110700426 wls is a Dataset
# 	 >>>  spec_2023110700427 fls is a Dataset
# 	 >>>  spec_2023110700427 fls_err is a Dataset
# 	 >>>  spec_2023110700427 ratio is a Dataset
# 	 >>>  spec_2023110700427 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700427 ratio_err is a Dataset
# 	 >>>  spec_2023110700427 wlr is a Dataset
# 	 >>>  spec_2023110700427 wls is a Dataset
# 	 >>>  spec_2023110700434 fls is a Dataset
# 	 >>>  spec_2023110700434 fls_err is a Dataset
# 	 >>>  spec_2023110700434 ratio is a Dataset
# 	 >>>  spec_2023110700434 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700434 ratio_err is a Dataset
# 	 >>>  spec_2023110700434 wlr is a Dataset
# 	 >>>  spec_2023110700434 wls is a Dataset
# 	 >>>  spec_2023110700439 fls is a Dataset
# 	 >>>  spec_2023110700439 fls_err is a Dataset
# 	 >>>  spec_2023110700439 ratio is a Dataset
# 	 >>>  spec_2023110700439 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700439 ratio_err is a Dataset
# 	 >>>  spec_2023110700439 wlr is a Dataset
# 	 >>>  spec_2023110700439 wls is a Dataset
# 	 >>>  spec_2023110700440 fls is a Dataset
# 	 >>>  spec_2023110700440 fls_err is a Dataset
# 	 >>>  spec_2023110700440 ratio is a Dataset
# 	 >>>  spec_2023110700440 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700440 ratio_err is a Dataset
# 	 >>>  spec_2023110700440 wlr is a Dataset
# 	 >>>  spec_2023110700440 wls is a Dataset
# 	 >>>  spec_2023110700452 fls is a Dataset
# 	 >>>  spec_2023110700452 fls_err is a Dataset
# 	 >>>  spec_2023110700452 ratio is a Dataset
# 	 >>>  spec_2023110700452 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700452 ratio_err is a Dataset
# 	 >>>  spec_2023110700452 wlr is a Dataset
# 	 >>>  spec_2023110700452 wls is a Dataset
# 	 >>>  spec_2023110700453 fls is a Dataset
# 	 >>>  spec_2023110700453 fls_err is a Dataset
# 	 >>>  spec_2023110700453 ratio is a Dataset
# 	 >>>  spec_2023110700453 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700453 ratio_err is a Dataset
# 	 >>>  spec_2023110700453 wlr is a Dataset
# 	 >>>  spec_2023110700453 wls is a Dataset
# 	 >>>  spec_2023110700486 fls is a Dataset
# 	 >>>  spec_2023110700486 fls_err is a Dataset
# 	 >>>  spec_2023110700486 ratio is a Dataset
# 	 >>>  spec_2023110700486 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700486 ratio_err is a Dataset
# 	 >>>  spec_2023110700486 wlr is a Dataset
# 	 >>>  spec_2023110700486 wls is a Dataset
# 	 >>>  spec_2023110700493 fls is a Dataset
# 	 >>>  spec_2023110700493 fls_err is a Dataset
# 	 >>>  spec_2023110700493 ratio is a Dataset
# 	 >>>  spec_2023110700493 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700493 ratio_err is a Dataset
# 	 >>>  spec_2023110700493 wlr is a Dataset
# 	 >>>  spec_2023110700493 wls is a Dataset
# 	 >>>  spec_2023110700494 fls is a Dataset
# 	 >>>  spec_2023110700494 fls_err is a Dataset
# 	 >>>  spec_2023110700494 ratio is a Dataset
# 	 >>>  spec_2023110700494 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700494 ratio_err is a Dataset
# 	 >>>  spec_2023110700494 wlr is a Dataset
# 	 >>>  spec_2023110700494 wls is a Dataset
# 	 >>>  spec_2023110700500 fls is a Dataset
# 	 >>>  spec_2023110700500 fls_err is a Dataset
# 	 >>>  spec_2023110700500 ratio is a Dataset
# 	 >>>  spec_2023110700500 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700500 ratio_err is a Dataset
# 	 >>>  spec_2023110700500 wlr is a Dataset
# 	 >>>  spec_2023110700500 wls is a Dataset
# 	 >>>  spec_2023110700501 fls is a Dataset
# 	 >>>  spec_2023110700501 fls_err is a Dataset
# 	 >>>  spec_2023110700501 ratio is a Dataset
# 	 >>>  spec_2023110700501 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700501 ratio_err is a Dataset
# 	 >>>  spec_2023110700501 wlr is a Dataset
# 	 >>>  spec_2023110700501 wls is a Dataset
# 	 >>>  spec_2023110700530 fls is a Dataset
# 	 >>>  spec_2023110700530 fls_err is a Dataset
# 	 >>>  spec_2023110700530 ratio is a Dataset
# 	 >>>  spec_2023110700530 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700530 ratio_err is a Dataset
# 	 >>>  spec_2023110700530 wlr is a Dataset
# 	 >>>  spec_2023110700530 wls is a Dataset
# 	 >>>  spec_2023110700550 fls is a Dataset
# 	 >>>  spec_2023110700550 fls_err is a Dataset
# 	 >>>  spec_2023110700550 ratio is a Dataset
# 	 >>>  spec_2023110700550 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700550 ratio_err is a Dataset
# 	 >>>  spec_2023110700550 wlr is a Dataset
# 	 >>>  spec_2023110700550 wls is a Dataset
# 	 >>>  spec_2023110700556 fls is a Dataset
# 	 >>>  spec_2023110700556 fls_err is a Dataset
# 	 >>>  spec_2023110700556 ratio is a Dataset
# 	 >>>  spec_2023110700556 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700556 ratio_err is a Dataset
# 	 >>>  spec_2023110700556 wlr is a Dataset
# 	 >>>  spec_2023110700556 wls is a Dataset
# 	 >>>  spec_2023110700557 fls is a Dataset
# 	 >>>  spec_2023110700557 fls_err is a Dataset
# 	 >>>  spec_2023110700557 ratio is a Dataset
# 	 >>>  spec_2023110700557 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700557 ratio_err is a Dataset
# 	 >>>  spec_2023110700557 wlr is a Dataset
# 	 >>>  spec_2023110700557 wls is a Dataset
# 	 >>>  spec_2023110700571 fls is a Dataset
# 	 >>>  spec_2023110700571 fls_err is a Dataset
# 	 >>>  spec_2023110700571 ratio is a Dataset
# 	 >>>  spec_2023110700571 ratio_airmass1 is a Dataset
# 	 >>>  spec_2023110700571 ratio_err is a Dataset
# 	 >>>  spec_2023110700571 wlr is a Dataset
# 	 >>>  spec_2023110700571 wls is a Dataset

# %%
#all_attributes

# %%
#all_datasets

# %% [markdown]
# ## Retrieve the list of observed spectra

# %% [markdown]
# ### Selection of good Spectra

# %%
spec_nums_list = ["spec_" + re.findall("^spec_(.*)", keyname)[0] for keyname in list_of_keys if len(re.findall("^spec_(.*)", keyname)) > 0 ]

# %%
print(spec_nums_list)
# Out:
# ['spec_2023110700364', 'spec_2023110700384', 'spec_2023110700385', 'spec_2023110700426', 'spec_2023110700427', 'spec_2023110700434', 'spec_2023110700439', 'spec_2023110700440', 'spec_2023110700452', 'spec_2023110700453', 'spec_2023110700486', 'spec_2023110700493', 'spec_2023110700494', 'spec_2023110700500', 'spec_2023110700501', 'spec_2023110700530', 'spec_2023110700550', 'spec_2023110700556', 'spec_2023110700557', 'spec_2023110700571']

# %%
Nspec = len(spec_nums_list)
cmap = sns.color_palette("hls", Nspec)

# %%
all_targets = []
my_flags = []
for idx,spec_num in enumerate(spec_nums_list):
    the_dataset = all_datasets[spec_num]
    the_attrs = all_attributes[spec_num]
    the_target = the_attrs['target']
    all_targets.append(the_target)
    the_airmass = the_attrs['airmass']
    the_flag = the_attrs['flag_atmparam']
    the_title = f"{idx}) {spec_num} , target = {the_target}"
    the_label = f"z={the_airmass:.2f}, flag = {the_flag}"
    the_color = cmap[idx]
    print(the_attrs)
    wls = the_dataset['wls']
    fls = the_dataset['fls']
    fls_err = the_dataset['fls_err']
    fig,ax = plt.subplots(1,1,figsize=(16,4))
    #ax.errorbar(wls,fls, yerr=fls_err, xerr=0.0,fmt='+', ecolor="grey", elinewidth=0, capsize=12,color="r",label=the_label )
    ax.plot(wls,fls,color=the_color,label=the_label )
    ax.legend()
    ax.set_title(the_title)

    if spec_num in ['spec_2023101000451','spec_2023101000631', 'spec_2023101000638']:
        my_flags.append(False)
    else:
        my_flags.append(True)
        
    plt.show()
# Out:
# {'PWV': 1.7129097920767338, 'VAOD': 0.020489989086570615, 'airmass': 1.08150410157688, 'flag_atmparam': 1, 'grey': 0.9720176299051349, 'ozone': 339.3446205954324, 'target': 'HD2811'}
# {'PWV': 2.1019619347222998, 'VAOD': 0.01323898800907555, 'airmass': 1.97467446800652, 'flag_atmparam': 0, 'grey': 0.9720176299051349, 'ozone': 304.65923242464345, 'target': 'HD185975'}
# {'PWV': 2.1019619347222998, 'VAOD': 0.01323898800907555, 'airmass': 2.10388585205142, 'flag_atmparam': 0, 'grey': 0.9720176299051349, 'ozone': 304.65923242464345, 'target': 'HD185975'}
# {'PWV': 2.1019619347222998, 'VAOD': 0.01323898800907555, 'airmass': 1.00759612281391, 'flag_atmparam': 0, 'grey': 0.9720176299051349, 'ozone': 304.65923242464345, 'target': 'HD38666'}

# %% [markdown]
# ### Plot for the hceres

# %%
targets_unique = np.unique(all_targets)
Ntags = len(targets_unique )

# %%
#cmap = sns.color_palette("hls", Ntags)
cmap = sns.color_palette("husl", Ntags)

# %%
atm = all_attributes['median_param_atm']

# %%
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
textstr = '\n'.join((
    r'$PWV=%.3f$ mm' % (atm["md_PWV"], ),
    r'$ozone=%.1f$ DU' % (atm["md_ozone"], ),
    r'$VAOD=%.3f$' % (atm['md_VAOD'], )))

# %%
def convertNumToDatestr(num):
    year = num//10_000
    month= (num-year*10_000)//100
    day = (num-year*10_000-month*100)

    year_str = str(year).zfill(4)
    month_str = str(month).zfill(2)
    day_str = str(day).zfill(2)
    
    datestr = f"{year_str}-{month_str}-{day_str}"
    return datestr

DATEOBS_STR = convertNumToDatestr(DATEOBS)

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,8),sharex=True)

color_counts = np.zeros(Ntags)
for idx,spec_num in enumerate(spec_nums_list):
    the_dataset = all_datasets[spec_num]
    the_attrs = all_attributes[spec_num]
    the_target = the_attrs['target']

    the_label = the_target
    idxc = np.where(targets_unique== the_target )[0][0]
    the_col = cmap[idxc]
    
 
    all_targets.append(the_target)
    the_airmass = the_attrs['airmass']
    the_flag = the_attrs['flag_atmparam']
    the_title = f"{spec_num} , target = {the_target}"
    
   
    wls = the_dataset['wls']
    fls = the_dataset['fls']
    fls_err = the_dataset['fls_err']

    ratio_airmass1 = the_dataset['ratio_airmass1']
    wlr = the_dataset['wlr']

    span=4
    ratio_airmass2 = smooth_data_np_convolve(ratio_airmass1,span)
   
    if spec_num not in ['spec_2023101000358','spec_2023101000451','spec_2023101000631', 'spec_2023101000638']:
        if color_counts[idxc] == 0:
            ax1.plot(wls,fls,'-', color= the_col,label = the_label)
            ax2.plot(wlr,ratio_airmass2,'-', color= the_col,label=the_label)
            color_counts[idxc] = color_counts[idxc]+1
        else:
            ax1.plot(wls,fls,'-', color= the_col)
            ax2.plot(wlr,ratio_airmass2,'-', color= the_col)
            color_counts[idxc] = color_counts[idxc]+1

        

the_sim = all_datasets['sim_spec']
transm = the_sim["transm"] 
wls = the_sim["wls"] 
ax2.plot(wls,transm,'k',label="simulation")
ax2.text(0.75, 0.25, textstr, transform=ax2.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
   
ax2.set_ylim(0.,1.2)  
ax1.legend()  
ax2.legend()
ax1.set_title(f"{DATEOBS_STR}")
ax1.set_xlim(370.,980.)
ax2.set_xlabel("wavelength (nm)")
ax1.set_ylabel("flux (ergs/cm$^2$/s/nm)")
ax2.set_ylabel("atmospheric transmission")
#plt.tight_layout()
plt.subplots_adjust(wspace=None, hspace=0)
plt.show()
