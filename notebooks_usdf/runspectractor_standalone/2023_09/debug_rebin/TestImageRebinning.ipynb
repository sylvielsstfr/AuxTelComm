# %% [markdown]
# # Test Image rebinning

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNRS, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : September 7th th 2023
# - update : 2023-09-07
#
# - version v7 :
#
# - w_2023_35

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
! eups list -s | grep LOCAL
# Out:
# analysis_tools        LOCAL:/home/d/dagoret/repos/repos_w_2023_35/analysis_tools 	setup
# atmospec              LOCAL:/home/d/dagoret/repos/repos_w_2023_35/atmospec 	setup
# eups                  LOCAL:/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/eups 	setup
# spectractor           LOCAL:/home/d/dagoret/repos/repos_w_2023_35/Spectractor 	setup

# %%
import sys
print(sys.path)
# Out:
# ['/sdf/data/rubin/user/dagoret/AuxTelComm/notebooks_usdf/runspectractor_standalone/2023_09/debug_rebin', '/home/d/dagoret/repos/repos_w_2023_35/analysis_tools/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/cp_pipe/g857a3418e4+7df23b908a/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/shapelet/g44018dc512+ea6441928c/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_modelfit/g93c4d6e787+79b822255a/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/scarlet_extensions/g9d18589735+d445b4966c/lib/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/proxmin/g33b4157f25/lib/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/scarlet/g63ff1f842d+4083830bf8/lib/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_scarlet/g943cb464a2+f79590064d/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/psfex/gc054bea089+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_psfex/g58be5f913a+32f1932512/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_piff/gc86a011abf+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_gaap/g8dd6597355+dceeeb951c/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_photometryKron/gb2715bf1a1+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_convolved/g42fff21dfb+94f62ec815/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/kht/gafcb7142de/cpp/build', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/verify_metrics/gd129bed42c+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/felis/g56b87fd2ae+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/dax_apdb/g4c90b7bd52+fc57afb704/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/verify/gffb8816710+02c788d496/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_deblender/g2cc88a2952+6327360372/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_shapeHSM/g571dde35ae+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_trailedSources/g47da3c6c86+f7136a40d1/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_astrom/g0a0026dc87+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ip_diffim/g07994bdeae+16b1756208/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/dustmaps_cachedata/gbb0a0c949e+81bc2a20b4/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/coadd_utils/g337abbeb29+ea6441928c/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/pipe_tasks/g68a3911fdd+6ad9f154ac/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/astro_metadata_translator/g0978aabd1f+2a7d2c9fe3/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/obs_base/gcc620a9fd9+e9a6d3d3e6/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/skymap/g37c6e7c3d5+905c2c68d7/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_base/g67924a670a+edc5793283/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_algorithms/g6f40f426a6+f7136a40d1/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ip_isr/gba31a79951+9acc3d8d25/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/daf_relation/g8a20fa5453+e358f92434/python', '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0. ...

# %%
all_paths_to_remove = ['/opt/conda/lib/python3.10/site-packages','/pbs/home/d/dagoret/.local/lib/python3.10/site-packages']

for path_to_remove in all_paths_to_remove:
    if path_to_remove in sys.path:
        print(f"remove {path_to_remove} from sys.path")
        sys.path.remove(path_to_remove)

# %%
sys.path
# Out:
# ['/sdf/data/rubin/user/dagoret/AuxTelComm/notebooks_usdf/runspectractor_standalone/2023_09/debug_rebin',
#  '/home/d/dagoret/repos/repos_w_2023_35/analysis_tools/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/cp_pipe/g857a3418e4+7df23b908a/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/shapelet/g44018dc512+ea6441928c/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_modelfit/g93c4d6e787+79b822255a/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/scarlet_extensions/g9d18589735+d445b4966c/lib/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64
python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/obs_decam/gcd84e84c5d+9bde498c3c/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/obs_cfht/g98ea1558ea+7a1fade221/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ctrl_bps_parsl/gfe186b85dc+6e30524a5b/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ctrl_bps_panda/g72cefa85e0+6e30524a5b/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ctrl_bps_htcondor/g4bda180e2e+6e30524a5b/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/lsst_bps_plugins/g3a590c521e+29bb66eb6d/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ctrl_bps/gf871a26735+9b83f7e51d/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ctrl_platform_s3df/g3be6bbf6ee+b8e28c3ebe/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ctrl_execute/g3288a415c1+d78986aaf7/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/display_ds9/gdb4ec4c597+ea6441928c/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_extensions_simpleShape/gcf0d15dbbd+f7136a40d1/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/meas_transiNet/g2ca692352a+f7136a40d1/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/alert_packet/gc1f99d08cb/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ap_association/g6758148a95+cc00875cc0/python',
#  '/opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-7.0.1/Linux64/ap_pipe/g06c608b3b8+b6810408d8/python',
#  '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/eups/python',
#  '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/lib/python311.zip',
#  '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/lib/python3.11',
#  '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/lib/python3.11/lib-dynload',
#  '',
#  '/home/d/dagoret/.local/lib/python3.11/site-packages',
#  '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/lib/python3.11/site-packages']

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm
from matplotlib import  transforms
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (12,12)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/bin/python3
# 3.11.4 | packaged by conda-forge | (main, Jun 10 2023, 18:08:17) [GCC 12.2.0]
# sys.version_info(major=3, minor=11, micro=4, releaselevel='final', serial=0)

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_subplot(1,1,1)
X=np.linspace(-10,10,50)
Y=np.sin(X)
ax.plot(X,Y)
plt.title("matplotlib test")
plt.show()

# %%
from iminuit import Minuit
import iminuit

# %%
iminuit.__version__
# Out:
# '2.22.0'

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.10.1

# %%
from astropy.io import fits
from astropy.coordinates import Angle
from astropy import units as u
from spectractor import parameters
from spectractor.extractor.extractor import Spectractor,dumpParameters
#dumpfitparameters
from spectractor.extractor.images import *
from spectractor.config import load_config, set_logger
from scipy import ndimage, misc

# %%
import logging

# %%
from scipy.stats import kurtosis,skew
from scipy.stats import kurtosistest,skewtest,normaltest

# %%
from distutils.dir_util import copy_tree
import shutil

# %%
from astroquery.simbad import Simbad
import astroquery
astroquery.__version__
result_table = Simbad.query_object("M1")

# %%
def find_target_name(tag):
    try:
        target_name=tag
        result_table = Simbad.query_object(target_name)
        return target_name
    except:
        target_name_stripped = ''.join(tag.split())
        result_table = Simbad.query_object(target_name_stripped)
        return target_name_stripped

# %% [markdown]
# # Configuration

# %% [markdown]
# ## Logger

# %%
my_logger = logging

# %% [markdown]
# ## Config for the notebook

# %%
version="v7.0"  # version for taking images from data/2023 (images come from usdf)
# create output directories if not exist and clean existing files
FLAG_MANAGE_OUTPUT_SPECTRACTOR=True
# allow to run reconstruction with Spectractor
FLAG_GO_FOR_RECONSTRUCTION_WTH_SPECTRACTOR=True
FLAG_RUNWITHEXCEPTIONS = False

# %% [markdown]
# ## Configuration for Spectractor

# %%
print("List of configuration files available : ",os.listdir("../config"))
# Out:
# List of configuration files available :  ['auxtel_config_holo_DECONVOLUTION_FFMv_REBIN2_Janv2023.ini', 'auxtel_config_holo_DECONVOLUTION_FFMv_REBIN1_Janv2023.ini']

# %%
# Choose the config filename
list_of_spectractorconfigfiles= ['auxtel_config_holo_DECONVOLUTION_FFMv_REBIN2_Janv2023.ini' ,
                                 'auxtel_config_holo_DECONVOLUTION_FFMv_REBIN1_Janv2023.ini']

config_idx = len(list_of_spectractorconfigfiles)-2
                                
configfilename= os.path.join("../config",list_of_spectractorconfigfiles[config_idx])
#configdir = (list_of_spectractorconfigfiles[config_idx].split("_")[-1]).split(".") [0]
configdir = "config_" + (list_of_spectractorconfigfiles[config_idx].split("auxtel_config_holo_")[-1]).split(".") [0]

# %%
configfilename
# Out:
# '../config/auxtel_config_holo_DECONVOLUTION_FFMv_REBIN2_Janv2023.ini'

# %%
configdir
# Out:
# 'config_DECONVOLUTION_FFMv_REBIN2_Janv2023'

# %%
! pwd
# Out:
# /sdf/data/rubin/user/dagoret/AuxTelComm/notebooks_usdf/runspectractor_standalone/2023_09/debug_rebin

# %%
config=configfilename
print(f">>>>> Spectractor configuration filename : {configfilename}")
# Out:
# >>>>> Spectractor configuration filename : ../config/auxtel_config_holo_DECONVOLUTION_FFMv_REBIN2_Janv2023.ini

# %%
load_config(configfilename)

# %%
dumpParameters()
# Out:
# ASTROMETRYNET_DIR
# BGD_ORDER 1
# CALIB_BGD_NPARAMS 4
# CALIB_BGD_ORDER 3
# CALIB_BGD_WIDTH 15
# CALIB_PEAK_WIDTH 7
# CALIB_SAVGOL_ORDER 2
# CALIB_SAVGOL_WINDOW 5
# CCD_ARCSEC2RADIANS 4.84813681109536e-06
# CCD_GAIN 1.1
# CCD_IMSIZE 2048
# CCD_MAXADU 170000
# CCD_PIXEL2ARCSEC 0.1904
# CCD_PIXEL2MM 0.02
# CCD_REBIN 2
# CONFIG_DIR ../config/
# DEBUG False
# DEBUG_LOGGING False
# DISPERSER_DIR extractor/dispersers/
# DISPLAY False
# DISTANCE2CCD 181
# DISTANCE2CCD_ERR 0.4
# FLAM_TO_ADURATE 5175865186660.421
# GRATING_ORDER_2OVER1 0.1
# LAMBDAS [ 300  301  302  303  304  305  306  307  308  309  310  311  312  313
#   314  315  316  317  318  319  320  321  322  323  324  325  326  327
#   328  329  330  331  332  333  334  335  336  337  338  339  340  341
#   342  343  344  345  346  347  348  349  350  351  352  353  354  355
#   356  357  358  359  360  361  362  363  364  365  366  367  368  369
#   370  371  372  373  374  375  376  377  378  379  380  381  382  383
#   384  385  386  387  388  389  390  391  392  393  394  395  396  397
#   398  399  400  401  402  403  404  405  406  407  408  409  410  411
#   412  413  414  415  416  417  418  419  420  421  422  423  424  425
#   426  427  428  429  430  431  432  433  434  435  436  437  438  439
#   440  441  442  443  444  445  446  447  448  449  450  451  452  453
#   454  455  456  457  458  459  460  461  462  463  464  465  466  467
#   468  469  470  471  472  473  474  475  476  477  478  479  480  481
#   482  483  484  485  486  487  488  489  490  491  492  493  494  495
#   496  497  498  499  500  501  502  503  504  505  506  507  508  509
#   510  511  512  513  514  515  516  517  518  519  520  521  522  523
# OBS_LATITUDE -30.2446389756252
# OBS_NAME AUXTEL
# OBS_OBJECT_TYPE STAR
# OBS_QUANTUM_EFFICIENCY multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_SECONDARY_DIAMETER 0.0 m
# OBS_SURFACE 1.1309733552923256 m2
# OBS_TELESCOPE_TRANSMISSION multispectra_holo4_003_HD142331_AuxTel_throughput.txt
# OBS_TRANSMISSION_SYSTEMATICS 0.005
# PAPER False
# PIXDIST_BACKGROUND 70
# PIXSHIFT_PRIOR 5
# PIXWIDTH_BACKGROUND 20
# PIXWIDTH_BOXSIZE 10
# PIXWIDTH_SIGNAL 10
# PLOT_DIR plots
# PLOT_ROT_LABEL $\varphi_d$ [degrees]
# PLOT_XLABEL $x$ [pixels]
# PLOT_YLABEL $y$ [pixels]
# PSF_FIT_REG_PARAM 0.1
# PSF_FWHM_CLIP 2
# PSF_PIXEL_STEP_TRANSVERSE_FIT 25
# PSF_POLY_ORDER 2
# PSF_TYPE Moffat
# ROT_ANGLE_MAX 10
# ROT_ANGLE_MIN -10
# ROT_ORDER 5
# ROT_PREFILTER True
# SAVE False
# SED_UNIT 1.0 erg / (nm s cm2)
# SPECTRACTOR_BACKGROUND_SUBTRACTION True
# SPECTRACTOR_COMPUTE_ROTATION_ANGLE disperser
# SPECTRACTOR_DECONVOLUTION_FFM True
# SPECTRACTOR_DECONVOLUTION_PSF2D False
# SPECTRACTOR_DECONVOLUTION_SIGMA_CLIP 100
# SPECTRACTOR_FIT_TARGET_CENTROID fit
# SPEC_ORDER 1
# STYLE_PARAMETERS ['VERBOSE', 'DEBUG', 'PAPER', 'LINEWIDTH', 'PLOT_DIR', 'SAVE', 'DEBUG_LOGGING', 'DISPLAY', 'PLOT_XLABEL', 'PLOT_YLABEL', 'PLOT_ROT_LABEL']
# THROUGHPUT_DIR simulation/AuxTelThroughput/
# TIME_UNIT 1.0 s
# VERBOSE False
# XWINDOW 50
# XWINDOW_ROT 25
# YWINDOW 50
# YWINDOW_ROT 25
# hc 1.9864458571489286e-25 J m
# mpl <module 'matplotlib' from '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/lib/python3.11/site-packages/matplotlib/__init__.py'>
# np <module 'numpy' from '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-7.0.1/lib/python3.11/site-packages/numpy/__init__.py'>
# os <module 'os' (frozen)>
# wl_dwl_unit nm2

# %% [markdown]
# # Exposure config

# %%
! ls logbooks
# Out:
# ls: cannot access logbooks: No such file or directory

# %%
# path index for each month
DATE="20230817"
#DATE="20211104"
filterdispersername = "empty~holo4_003"
#filterdispersername = "empty~holo4_001"
#filterdispersername = "BG40~holo4_003"
#filterdispersername = "FELH0600~holo4_003"
imagemode = "postISRCCD"
#imagemode = "unflattened"

# %%
disperser_label = filterdispersername.split("~")[-1]

# %% [markdown]
# ## Paths

# %%
# select if we run at CC or not (locally) 
# /sps/lsst/groups/auxtel/data/2022/holo/20220317
HOSTCC=False
LAPTOP=True

# %%
def GetPaths(computer_name):
    """
    """
    
    if computer_name == "HOSTCC":
        
        path_auxtel="/sps/lsst/groups/auxtel"
        path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
        path_spectractor_config=os.path.join(path_spectractor,"config")
    
        path_images=os.path.join(path_auxtel,"data/hack_usdf/my_postisrccd_img_forspectractor_2023/"+filterdispersername+"/"+DATE)
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode)
        
    elif computer_name == "LAPTOP1":
        path_auxtel="/Users/dagoret/DATA/AuxTelData2023"
        path_spectractor=os.path.join(path_auxtel,"/Users/dagoret/MacOSX/GitHub/LSST/Spectractor")
        path_spectractor_config=os.path.join(path_spectractor,"config")
        path_images=os.path.join(path_auxtel,"data/2023/"+filterdispersername+"/"+DATE)
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode)
        
        
    elif computer_name == "WORKIMAC":
        path_auxtel="/Users/sylvie/DATA/AuxTelData2023"
        path_spectractor=os.path.join(path_auxtel,"/Users/sylvie/MacOSX/GitHub/LSST/Spectractor")
        path_spectractor_config=os.path.join(path_spectractor,"config")
        path_images=os.path.join(path_auxtel,"data/2023/"+filterdispersername+"/"+DATE)
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"data/2023/OutputSpectractor/"+imagemode)
            
            
        
    elif computer_name == "HOMEIMAC":
        path_auxtel="/Volumes/Backup2020/DATA"
        path_spectractor=os.path.join(path_auxtel,"MacOSX/GitHub/LSST/Spectractor")
        path_spectractor_config=os.path.join(".","config")
        path_images=os.path.join(path_auxtel,"hack_usdf/my_postisrccd_img_forspectractor_2023/"+filterdispersername+"/"+DATE)
        
        # /Volumes/Backup2020/DATA/AuxTelDATA2023/data/2023/OutputSpectractor
        
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"AuxTelDATA2023/data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"AuxTelDATA2023/data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"AuxTelDATA2023/data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"AuxTelDATA2023/data/2023/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"AuxTelDATA2023/data/2023/OutputSpectractor/"+imagemode)
            
    elif computer_name == "USDF":
        path_auxtel="/home/d/dagoret/rubin-user/DATA"
        path_spectractor=os.path.join("/home/d/dagoret","repos/repos_w_2023_35/Spectractor")
        path_spectractor_config=os.path.join(".","config")
        path_images=os.path.join(path_auxtel,"AuxtelData2023/my_postisrccd_img_forspectractor_2023/"+filterdispersername+"/"+DATE)
        
        # /Volumes/Backup2020/DATA/AuxTelDATA2023/data/2023/OutputSpectractor
        
        if configdir == "":
            path_output_spectractor=os.path.join(path_auxtel,"AuxtelData2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+DATE)
        else:
            path_output_spectractor=os.path.join(path_auxtel,"AuxtelData2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir+"/"+DATE)
            path_topoutput_spectractor=os.path.join(path_auxtel,"AuxtelData2023/OutputSpectractor/"+imagemode+"/"+filterdispersername+"/"+configdir)
            path_toptopoutput_spectractor=os.path.join(path_auxtel,"AuxtelData2023/OutputSpectractor/"+imagemode+"/"+filterdispersername)
            path_toptoptopoutput_spectractor=os.path.join(path_auxtel,"AuxtelData2023/OutputSpectractor/"+imagemode)     
        
    else:
        print(f"Unknown computer {computer_name}")
        
              
    return path_auxtel,path_spectractor,path_spectractor_config,path_images,path_toptoptopoutput_spectractor, path_toptopoutput_spectractor, path_topoutput_spectractor, path_output_spectractor

# %% [markdown]
# ## Define paths

# %%
mycomputer_name = "USDF"
path_auxtel,path_spectractor,path_spectractor_config,path_images,path_toptoptopoutput_spectractor, path_toptopoutput_spectractor, path_topoutput_spectractor, path_output_spectractor  = GetPaths(mycomputer_name)

# %%
path_images
# Out:
# '/home/d/dagoret/rubin-user/DATA/AuxtelData2023/my_postisrccd_img_forspectractor_2023/empty~holo4_003/20230817'

# %%
path_topoutput_spectractor
# Out:
# '/home/d/dagoret/rubin-user/DATA/AuxtelData2023/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_FFMv_REBIN2_Janv2023'

# %%
path_output_spectractor
# Out:
# '/home/d/dagoret/rubin-user/DATA/AuxtelData2023/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_FFMv_REBIN2_Janv2023/20230817'

# %% [markdown]
# # Utility Functions

# %%
def is_nan(x):
    return (x != x)

# %% [markdown]
# # Logbook for input file selection
#
# - the logbook contains all input image path and possibily the order 0 position

# %%
# !ls ../logbooks
# Out:
# auxtellogbook_empty~holo4_003_20230815_v7.0.csv
# auxtellogbook_empty~holo4_003_20230817_v7.0.csv

# %%
filename_logbook='../logbooks/auxtellogbook_'+filterdispersername+"_"+DATE+'_' + version+'.csv'

# %%
filename_logbook
# Out:
# '../logbooks/auxtellogbook_empty~holo4_003_20230817_v7.0.csv'

# %%
df=pd.read_csv(filename_logbook,index_col=0)

# %%
pd.set_option('display.max_rows', None)

# %%
# show the list of input files from the logbook to select the file index in the logbook
df
# Out:
#     index                     date  \
# 0       0  2023-08-17T23:42:04.293
# 1       1  2023-08-17T23:43:56.231
# 2       2  2023-08-17T23:44:39.311
# 3       3  2023-08-18T00:01:25.370
# 4       4  2023-08-18T00:02:08.272
# 5       5  2023-08-18T00:03:54.913
# 6       6  2023-08-18T00:04:37.826
# 7       7  2023-08-18T00:09:47.082
# 8       8  2023-08-18T00:10:29.990
# 9       9  2023-08-18T00:12:16.474
# 10     10  2023-08-18T00:12:59.433
# 11     11  2023-08-18T00:18:09.169
# 12     12  2023-08-18T00:18:52.135
# 13     13  2023-08-18T00:20:39.588
# 14     14  2023-08-18T00:21:22.492
# 15     15  2023-08-18T00:28:32.047
# 16     16  2023-08-18T00:29:14.950
# 17     17  2023-08-18T00:31:06.546
# 18     18  2023-08-18T00:31:49.506
# 19     19  2023-08-18T00:39:45.254
# 20     20  2023-08-18T00:40:28.186
# 21     21  2023-08-18T00:42:16.378
# 22     22  2023-08-18T00:42:59.328
# 23     23  2023-08-18T00:48:07.123
# 24     24  2023-08-18T00:48:50.223
# 25     25  2023-08-18T00:50:37.298
home/d/dagoret/rubin-user/DATA/AuxtelData2023...
#
#                                              file  num    object   filter  \
# 0   exposure_2023081700144_pseudo-postisrccd.fits  144  HD185975  empty_1
# 1   exposure_2023081700147_pseudo-postisrccd.fits  147  HD185975  empty_1
# 2   exposure_2023081700148_pseudo-postisrccd.fits  148  HD185975  empty_1
# 3   exposure_2023081700166_pseudo-postisrccd.fits  166  HD146233  empty_1
# 4   exposure_2023081700167_pseudo-postisrccd.fits  167  HD146233  empty_1
# 5   exposure_2023081700170_pseudo-postisrccd.fits  170  HD146233  empty_1
# 6   exposure_2023081700171_pseudo-postisrccd.fits  171  HD146233  empty_1
# 7   exposure_2023081700180_pseudo-postisrccd.fits  180  HD146233  empty_1
# 8   exposure_2023081700181_pseudo-postisrccd.fits  181  HD146233  empty_1
# 9   exposure_2023081700184_pseudo-postisrccd.fits  184  HD146233  empty_1
# 10  exposure_2023081700185_pseudo-postisrccd.fits  185  HD146233  empty_1
# 11  exposure_2023081700194_pseudo-postisrccd.fits  194  HD146233  empty_1
# 12  exposure_2023081700195_pseudo-postisrccd.fits  195  HD146233  empty_1
# 13  exposure_2023081700198_pseudo-postisrccd.fits  198  HD146233  empty_1
# 14  exposure_2023081700199_pseudo-postisrccd.fits  199  HD146233  empty_1
# 15  exposure_2023081700209_pseudo-postisrccd.fits  209  HD185975  empty_1
# 16  exposure_2023081700210_pseudo-postisrccd.fits  210  HD185975  empty_1
# 17  exposure_2023081700213_pseudo-postisrccd.fits  213  HD185975  empty_1
# 18  exposure_2023081700214_pseudo-postisrccd.fits  214  HD185975  empty_1
# 19  exposure_2023081700223_pseudo-postisrccd.fits  223  HD146233  empty_1
# 20  exposure_2023081700224_pseudo-postisrccd.fits  224  HD146233  empty_1
# 21  exposure_2023081700227_pseudo-postisrccd.fits  227  HD146233  empty_1
# 22  exposure_2023081700228_pseudo-postisrccd.fits  228  HD146233  empty_1
# 23  exposure_2023081700237_pseudo-postisrccd.fits  237  HD146233  empty_1
# 24  exposure_2023081700238_pseudo-postisrccd.fits  238  HD146233  empty_1
# 25  exposure_2023081700241_pseudo-postisrccd.fits  241  HD146233  empty_1
# 26  exposure_2023081700242_pseudo-postisrccd.fits  242  HD146233  empty_1
# 27  exposure_2023081700251_pseudo-postisrccd.fits  251  HD146233  empty_1
# 28  exposure_2023081700252_pseudo-postisrccd.fits  252  HD146233  empty_1
# 29  exposure_2023081700255_pseudo-postisrccd.fits  255  HD146233  empty_1
# 30  exposure_2023081700256_pseudo-postisrccd.fits  256  HD146233  empty_1
# 31  exposure_2023081700265_pseudo-postisrccd.fits  265  HD146233  empty_1
# 32  exposure_2023081700266_pseudo-postisrccd.fits  266  HD146233  empty_1
# 33  exposure_2023081700269_pseudo-postisrccd.fits  269  HD146233  empty_1
# 34  exposure_2023081700270_pseudo-postisrccd.fits  270  HD146233  empty_1
# 35  exposure_2023081700277_pseudo-postisrccd.fits  277  HD185975  empty_1
# 36  exposure_2023081700278_pseudo-postisrccd.fits  278  HD185975  empty_1
# 37  exposure_2023081700282_pseudo-postisrccd.fits  282  HD185975  empty_1
# 38  exposure_2023081700283_pseudo-postisrccd.fits  283  HD185975  empty_1
# 39  exposure_2023081700300_pseudo-postisrccd.fits  300  HD146233  empty_1
# 40  exposure_2023081700301_pseudo-postisrccd.fits  301  HD146233  empty_1
# 41  exposure_2023081700304_pseudo-postisrccd.fits  304  HD146233  empty_1
# 42  exposure_2023081700305_pseudo-postisrccd.fits  305  HD146233  empty_1
# 43  exposure_2023081700314_pseudo-postisrccd.fits  314  HD146233  empty_1
# 44  exposure_2023081700315_pseudo-postisrccd.fits  315  HD146233  empty_1
# 45  exposure_2023081700318_pseudo-postisrccd.fits  318  HD146233  empty_1
# 46  exposure_2023081700319_pseudo-postisrccd.fits  319  HD146233  empty_1
# 47  exposure_2023081700328_pseudo-postisrccd.fits  328  HD146233  empty_1
# 48  exposure_2023081700329_pseudo-postisrccd.fits  329  HD146233  empty_1
# 49  exposure_2023081700332_pseudo-postisrccd.fits  332  HD146233  empty_1
# 50  exposure_2023081700333_pseudo-postisrccd.fits  333  HD146233  empty_1
# 51  exposure_2023081700342_pseudo-postisrccd.fits  342  HD146233  empty_1
# 52  exposure_2023081700343_pseudo-postisrccd.fits  343  HD146233  empty_1
# 53  exposure_2023081700346_pseudo-postisrccd.fits  346  HD146233  empty_1
# 54  exposure_2023081700347_pseudo-postisrccd.fits  347  HD146233  empty_1
# 55  exposure_2023081700356_pseudo-postisrccd.fits  356  HD146233  empty_1
# 56  exposure_2023081700357_pseudo-postisrccd.fits  357  HD146233  empty_1
# 57  exposure_2023081700360_pseudo-postisrccd.fits  360  HD146233  empty_1
# 58  exposure_2023081700361_pseudo-postisrccd.fits  361  HD146233  empty_1
# 59  exposure_2023081700370_pseudo-postisrccd.fits  370  HD146233  empty_1
# 60  exposure_2023081700371_pseudo-postisrccd.fits  371  HD146233  empty_1
# 61  exposure_2023081700374_pseudo-postisrccd.fits  374  HD146233  empty_1
# 62  exposure_2023081700375_pseudo-postisrccd.fits  375  HD146233  empty_1
# 63  exposure_2023081700384_pseudo-postisrccd.fits  384  HD146233  empty_1
# 64  exposure_2023081700385_pseudo-postisrccd.fits  385  HD146233  empty_1
# 65  exposure_2023081700388_pseudo-postisrccd.fits  388  HD146233  empty_1
# 66  exposure_2023081700389_pseudo-postisrccd.fits  389  HD146233  empty_1
# 67  exposure_2023081700398_pseudo-postisrccd.fits  398  HD146233  empty_1
# 68  exposure_2023081700399_pseudo-postisrccd.fits  399  HD146233  empty_1
# 69  exposure_2023081700402_pseudo-postisrccd.fits  402  HD146233  empty_1
# 70  exposure_2023081700403_pseudo-postisrccd.fits  403  HD146233  empty_1
# 71  exposure_2023081700413_pseudo-postisrccd.fits  413  HD185975  empty_1
# 72  exposure_2023081700414_pseudo-postisrccd.fits  414  HD185975  empty_1
# 73  exposure_2023081700417_pseudo-postisrccd.fits  417  HD185975  empty_1
# 74  exposure_2023081700418_pseudo-postisrccd.fits  418  HD185975  empty_1
# 75  exposure_2023081700427_pseudo-postisrccd.fits  427  HD146233  empty_1
# 76  exposure_2023081700428_pseudo-postisrccd.fits  428  HD146233  empty_1
# 77  exposure_2023081700431_pseudo-postisrccd.fits  431  HD146233  empty_1
# 78  exposure_2023081700432_pseudo-postisrccd.fits  432  HD146233  empty_1
#
#     disperser   airmass  exposure  ...  temperature   humidity  windspd  \
# 42  holo4_003  1.408336      30.0  ...       3.8000  47.000000   6.0882
# 43  holo4_003  1.434963      30.0  ...       3.7500  50.887501   6.2550
# 44  holo4_003  1.438752      30.0  ...       3.7500  52.250000   6.0882
# 45  holo4_003  1.448259      30.0  ...       3.8000  54.900002   6.0882
# 46  holo4_003  1.452145      30.0  ...       3.7500  55.325001   5.7546
# 47  holo4_003  1.481564      30.0  ...       3.7000  56.799999   6.4218
# 48  holo4_003  1.485757      30.0  ...       3.7000  56.775002   6.5052
# 49  holo4_003  1.496201      30.0  ...       3.7250  56.137501   6.4218
# 50  holo4_003  1.500523      30.0  ...       3.7500  55.137501   6.0882
# 51  holo4_003  1.533170      30.0  ...       3.7750  53.299999   5.0874
# 52  holo4_003  1.537821      30.0  ...       3.8000  53.200001   5.5878
# 53  holo4_003  1.549466      30.0  ...       3.8000  52.974998   5.0874
# 54  holo4_003  1.554246      30.0  ...       3.8250  51.562500   6.6720
# 55  holo4_003  1.591120      30.0  ...       3.8250  51.400002   6.6720
# 56  holo4_003  1.596295      30.0  ...       3.8000  50.687500   6.5886
# 57  holo4_003  1.609218      30.0  ...       3.8500  48.099998   6.9222
# 58  holo4_003  1.614536      30.0  ...       3.8500  47.837502   5.9214
# 59  holo4_003  1.655544      30.0  ...       4.0000  44.500000   6.4218
# 60  holo4_003  1.661319      30.0  ...       4.0000  45.075001   6.7554
# 61  holo4_003  1.675776      30.0  ...       3.9500  45.512501   6.9222
# 62  holo4_003  1.681743      30.0  ...       3.9750  44.525002   6.7554
# 63  holo4_003  1.727728      30.0  ...       3.9250  49.575001   6.2550
# 64  holo4_003  1.734196      30.0  ...       3.9250  50.150002   7.0056
# 65  holo4_003  1.750370      30.0  ...       3.9250  48.112499   6.5886
# 66  holo4_003  1.757062      30.0  ...       3.9000  49.599998   6.3384
# 67  holo4_003  1.808591      30.0  ...       3.8500  49.500000   6.9222
# 68  holo4_003  1.815867      30.0  ...       3.8500  48.162498   6.6720
# 69  holo4_003  1.834146      30.0  ...       3.8500  47.724998   6.0882
# 70  holo4_003  1.841681      30.0  ...       3.8250  48.337502   6.5052
# 71  holo4_003  1.837855      30.0  ...       3.8000  52.075001   6.0882
# 72  holo4_003  1.837799      30.0  ...       3.8250  49.012501   6.5052
# 73  holo4_003  1.837473      30.0  ...       3.8000  48.549999   6.2550
# 74  holo4_003  1.837421      30.0  ...       3.8875  45.487499   6.2550
# 75  holo4_003  2.056575      30.0  ...       3.8500  44.862499   6.4218
# 76  holo4_003  2.066518      30.0  ...       3.8500  45.200001   7.0890
# 77  holo4_003  2.091697      30.0  ...       3.8375  45.987499   6.4218
# 78  holo4_003  2.102043      30.0  ...       3.8250  47.125000   6.4218
#
#     Obj-posXpix  Obj-posYpix  Dx  Dy  skip  run  quality
# 0           NaN          NaN NaN NaN        NaN      NaN
# 1           NaN          NaN NaN NaN        NaN      NaN
# 2           NaN          NaN NaN NaN        NaN      NaN
# 3           NaN          NaN NaN NaN        NaN      NaN
# 4           NaN          NaN NaN NaN        NaN      NaN
# 5           NaN          NaN NaN NaN        NaN      NaN
# 66          NaN          NaN NaN NaN        NaN      NaN
# 67          NaN          NaN NaN NaN        NaN      NaN
# 68          NaN          NaN NaN NaN        NaN      NaN
# 69          NaN          NaN NaN NaN        NaN      NaN
# 70          NaN          NaN NaN NaN        NaN      NaN
# 71          NaN          NaN NaN NaN        NaN      NaN
# 72          NaN          NaN NaN NaN        NaN      NaN
# 73          NaN          NaN NaN NaN        NaN      NaN
# 74          NaN          NaN NaN NaN        NaN      NaN
# 75          NaN          NaN NaN NaN        NaN      NaN
# 76          NaN          NaN NaN NaN        NaN      NaN
# 77          NaN          NaN NaN NaN        NaN      NaN
# 78          NaN          NaN NaN NaN        NaN      NaN
#
# [79 rows x 23 columns]

# %% [markdown]
# # Selection of input file
# - the input file is selected from the logbook list above

# %%
idx = 0

# %%
print(df.iloc[idx]['file'])
# Out:
# exposure_2023081700144_pseudo-postisrccd.fits

# %%
print(df.iloc[idx])
# Out:
# index                                                          0
# date                                     2023-08-17T23:42:04.293
# path           /home/d/dagoret/rubin-user/DATA/AuxtelData2023...
# file               exposure_2023081700144_pseudo-postisrccd.fits
# num                                                          144
# object                                                  HD185975
# filter                                                   empty_1
# disperser                                              holo4_003
# airmass                                                 1.903331
# exposure                                                    30.0
# focus                                                   0.039449
# seeing                                                      1.15
# pressure                                              741.950012
# temperature                                                 4.05
# humidity                                               39.362499
# windspd                                                   5.2542
# Obj-posXpix                                                  NaN
# Obj-posYpix                                                  NaN
# Dx                                                           NaN
# Dy                                                           NaN
# skip
# run                                                          NaN
# quality                                                      NaN
# Name: 0, dtype: object

# %%
the_num = df.iloc[idx]["num"]

# %%
myhome=os.getenv("HOME")

# %%
dir_images=path_images

# %%
dir_images
# Out:
# '/home/d/dagoret/rubin-user/DATA/AuxtelData2023/my_postisrccd_img_forspectractor_2023/empty~holo4_003/20230817'

# %%
filename_image=df['file'][idx]
filename_image
# Out:
# 'exposure_2023081700144_pseudo-postisrccd.fits'

# %%
target = df['object'][idx]
target
# Out:
# 'HD185975'

# %% [markdown]
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

# %%
# ## If order 0 position exists in logbook it is selected, otherwise put it by hand

x0=300
y0=1700

if 'Obj-posXpix' in df.columns and 'Obj-posYpix' in df.columns:
    thex0 = df['Obj-posXpix'][idx]
    if not is_nan(thex0):
        x0=thex0
    they0 = df['Obj-posYpix'][idx]
    if not is_nan(they0):
        y0=they0
    
if not is_nan(x0) and not is_nan(y0):

    print("Order 0 location from logbook : ({},{})".format(x0,y0))
else:
    print("NO Order 0 location from logbook ! ")      

print(f"guess (x0,y0) = ({x0},{y0})")
# Out:
# Order 0 location from logbook : (300,1700)
# guess (x0,y0) = (300,1700)

# %% [markdown]
# ## Spectractor Configuration
#
# - Usually the Spectractor configuration file is put in local dir **./config**
#
#
# Ma suggestion, pour l'étude du centre optique via les scans des hologrammes, est de **mettre SPECTRACTOR_COMPUTE_ROTATION_ANGLE sur False** .
#
# Comme les angles ne sont pas très grands, si les marges du rectangle sont assez larges, réglables avec :
#
#     [background subtraction parameters]
#     # half transverse width of the signal rectangular window in pixels
#     PIXWIDTH_SIGNAL = 40
#
# alors le spectrogramme devrait tenir dans une boite rectangulaire même sans rotation de l'image. **L'important est de garder SPECTRACTOR_DECONVOLUTION_FFM à True car c'est lui qui te donnera l'angle de l'axe de dispersion ajusté sur les données, dont la valeur sera dans le mot clé ROTANGLE du header de sortie**.

# %%
rootfilename = filename_image.split(".")[0]
rootfilename_split =  rootfilename.split("_") 
filenumberdir = rootfilename_split[1]

# %%
path_output_spectractor
# Out:
# '/home/d/dagoret/rubin-user/DATA/AuxtelData2023/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_FFMv_REBIN2_Janv2023/20230817'

# %%
configdir
# Out:
# 'config_DECONVOLUTION_FFMv_REBIN2_Janv2023'

# %%
# Fullfilename
filename=os.path.join(dir_images,filename_image)


# subdirectory
#subdir=filename_image.split(".")[0]
subdir=filenumberdir

# final output directory (where results will be copied to be backed up at the end)
finalpath_output_spectractor=os.path.join(path_output_spectractor,subdir)


# local directories to put spectra and plots
    
if configdir =="":
    output_directory="./outputs_process_" + DATE  + '_' + dispersername +'_nb_' + str(idx+1)
    output_figures="figures_process_" + DATE + '_' + dispersername + '_nb_' + str(idx+1)
else:
    output_directory = "./outputs_process_"+ DATE +"_"+ filterdispersername + "_" + configdir + "_nb_" + str(idx+1)
    output_figures   = "./figures_process_"+ DATE +"_"+ filterdispersername + "_" + configdir + "_nb_" + str(idx+1)
    
    

#guess = [300,1700]
guess = [350,1700]

# configuration

config=configfilename    
target=df.iloc[idx]["object"]

# %%
print(f"finalpath_output_spectractor = {finalpath_output_spectractor}")
print(f"output_directory = {output_directory}")
print(f"output_figures = {output_figures}")
print(f"config filename = {config}")
# Out:
# finalpath_output_spectractor = /home/d/dagoret/rubin-user/DATA/AuxtelData2023/OutputSpectractor/postISRCCD/empty~holo4_003/config_DECONVOLUTION_FFMv_REBIN2_Janv2023/20230817/2023081700144
# output_directory = ./outputs_process_20230817_empty~holo4_003_config_DECONVOLUTION_FFMv_REBIN2_Janv2023_nb_1
# output_figures = ./figures_process_20230817_empty~holo4_003_config_DECONVOLUTION_FFMv_REBIN2_Janv2023_nb_1
# config filename = ../config/auxtel_config_holo_DECONVOLUTION_FFMv_REBIN2_Janv2023.ini

# %% [markdown]
# # Configuration of the Spectractor running mode

# %%
parameters.LSST_SAVEFIGPATH=False

# %%
parameters.debug=True
parameters.verbose=True
parameters.display=True
parameters.LIVE_FIT=False

# %%
target_name_sel0 = find_target_name(target)
print(f"target_name_sel0 = {target_name_sel0}")
#target_name_sel0 = ''.join(target.split())
#target_name_sel1 = target_name_sel0.encode(encoding='UTF-8',errors='strict')
#target_name_sel = target_name_sel0.encode()
target_name_sel = target_name_sel0.encode(encoding="ascii", errors="ignore")
print(f'target_name_sel = {target_name_sel}')
#target_name_sel=f"{target_name_sel}"
# Out:
# target_name_sel0 = HD185975
# target_name_sel = b'HD185975'

# %% [markdown]
# ## Load the image in the new image file with Spectractor

# %%
disperser_label
# Out:
# 'holo4_003'

# %%
# %matplotlib inline
image=Image(file_name=filename, disperser_label=disperser_label,target_label=target_name_sel, config=config)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">Image</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:
# 	Fitted read out noise seems to be different than input readout noise. Fit=4.24731543388897 but average of self.read_out_noise is 8.5.</pre>
# 2023-09-08 09:25:19  Image      check_statistical_error WARNING
# 	Fitted read out noise seems to be different than input readout noise. Fit=4.24731543388897 but average of self.read_out_noise is 8.5.

# %%
image.data.shape
# Out:
# (4072, 4000)

# %% [markdown]
# ## Show relevant parameters

# %%
parameters.LSST_SAVEFIGPATH=False

# %%
image.header["FILTER"]
# Out:
# 'empty_1'

# %%
image.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# CCD_MANU= 'ITL     '
# CCD_TYPE= '3800C   '
# DETSIZE = '[1:4072,1:4000]'
# BINX    =                    1
# BINY    =                    1
# CCDGAIN =                  1.0
# CCDNOISE=                 10.0
# CCDSLOT = 'S00     '
# RAFTBAY = 'R00     '
# FIRMWARE= '11384004'
# PLATFORM= 'auxtel  '
# CONTNUM = '189216ee'
# DAQVERS = 'R5-V6.7 2023-06-22T07:15:56Z (113ce6c8)'
# DAQPART = 'lat     '
# DAQFOLD = 'raw     '
# SEQFILE = 'FP_ITL_2s_ir2_v26_no_RG.seq'
# SEQNAME = 'FP_ITL_2s_ir2_v26_no_RG.seq'
# SEQCKSUM= '1477162166'
# LSST_NUM= 'ITL-3800C-068'
# CCD_SERN= '20862   '
# REBNAME = 'Unknown '
# RAFTNAME= 'AuxTel-Raft'
# FPVERS  = '1.1.8   '
# IHVERS  = '1.0.38  '
# HIERARCH STUTTER ROWS = 0
# HIERARCH STUTTER DELAY = 0.0
# HIERARCH STUTTER NSHIFTS = 0
# FILTPOS =
# DATE    = '2023-08-17T23:42:34.531'
# MJD     =    60173.98789966432
# IMGTYPE = 'OBJECT  '
# DATE-OBS= '2023-08-17T23:42:34.531'
# MJD-OBS =    60173.98754968727
# DATE-TRG= '2023-08-17T23:42:34.526'
# MJD-TRG =    60173.98789960658
# OBSID   = 'AT_O_20230817_000144'
# DATE-BEG= '2023-08-17T23:42:04.293'
# MJD-BEG =    60173.98754968727
# DATE-END= '2023-08-17T23:42:34.531'
# MJD-END =    60173.98789966432
# GROUPID = '2023-08-17T23:38:06.617'
# BUNIT   = 'adu     '
# TIMESYS = 'TAI     '
# INSTRUME= 'LATISS  '
# TELESCOP= 'LSST AuxTelescope'
# OBS-LONG=          -70.7476862
# OBS-LAT =          -30.2447889
# OBS-ELEV=               2663.0
# OBSGEO-X=           1819093.52
# OBSGEO-Y=           -5208408.1
# OBSGEO-Z=           3195186.45
# FACILITY= 'Vera C. Rubin Observatory'
# RA      =              307.075
# DEC     =   -87.47219444444444
# RASTART =    307.7596233731081
# DECSTART=   -87.44625043484436
# RAEND   =    307.7594527714129
# DECEND  =   -87.44624569873727
# ROTPA   =    31.34903440217217
# ROTCOORD= 'sky     '
# HASTART =   -3.982847856216009
# ELSTART =    31.56359090140506
# AZSTART =    177.3307592410568
# AMSTART =    1.903331368739209
# AHAEND  =
# AELEND  =
# AAZEND  =
# AAMEND  =
# TRACKSYS=
# RADESYS = 'ICRS    '
# FOCUSZ  =  0.03944919630885124
# OBJECT  = 'HD185975'
# INSTPORT=                    2
# ATM3PORT=
# DOMEAZ  =               176.87
# SHUTLOWR=                  0.0
# SHUTUPPR=                100.0
# WCSAXES =
# CTYPE1  =
# CTYPE2  =
# CUNIT1  =
# CUNIT2  =
# CRVAL1  =
# CRVAL2  =
# CRPIX1  =
# CRPIX2  =
# CD1_1   =
# CD1_2   =
# CD2_1   =
# CD2_2   =
# EQUINOX =
# TESTTYPE= 'OBJECT  '
# CAMCODE = 'AT      '
# CONTRLLR= 'O       '
# DAYOBS  = '20230817'
# SEQNUM  =                  144
# PROGRAM = 'spec    '
# REASON  = 'Generic '
# CURINDEX=                    1
# MAXINDEX=                    1
# TSTAND  =
# IMAGETAG= 'cf9742817e4b4b88'
# OBSANNOT= ''
# TEMP_SET=   -94.15000000000001
# GRATING = 'holo4_003'          / name of the disperser
# GRATBAND= 'H4-003  '
# GRATSLOT=                    3
# LINSPOS =                 67.0
# FILTBAND= 'EMPTY   '
# FILTER  = 'empty_1 '
# FILTSLOT=                    0
# EXPTIME =                 30.0
# DARKTIME=              30.2382
# SHUTTIME=
# AIRTEMP =    4.050000190734863
# PRESSURE=    741.9500122070312
# HUMIDITY=    39.36249923706055
# WINDSPD =    5.254199981689453
# WINDDIR =    42.33641815185547
# SEEING  =                 1.15
# FILENAME= 'AT_O_20230817_000144_R00_S00.fits'
# HEADVER =                    2
# HIERARCH SIMULATE ATMCS =
# HIERARCH SIMULATE ATHEXAPOD = 0
# HIERARCH SIMULATE ATPNEUMATICS =
# HIERARCH SIMULATE ATDOME = 0
# HIERARCH SIMULATE ATSPECTROGRAPH = 0
# CHECKSUM= 'gbUChZUCgaUCgYUC'
# EXTNAME = 'REB_COND'
# TEMP1   =               23.875
# TEMP2   =               26.625
# TEMP3   =                 26.0
# TEMP4   =              25.4375
# TEMP5   =               25.125
# TEMP6   =                 25.0
# ATEMPU  =              16.5179
# ATEMPL  =              16.5179
# CCDTEMP =             -90.4636
# RTDTEMP =              362.012
# DIGPS_V =                5.275
# DIGPS_I =               695.25
# ANAPS_V =                  7.2
# ANAPS_I =               307.25
# CLKHPS_V=               12.025
# CLKHPS_I=                 31.0
# CLKLPS_V=             -11.9782
# ODPS_V  =                32.05
# ODPS_I  =                 30.0
# HTRPS_V =                  0.0
# HTRPS_W =                  0.0
# PCKU_V  =              1.98708
# PCKL_V  =             -7.99653
# SCKU_V  =              4.99984
# SCKL_V  =             -4.99663
# RGU_V   =    8.000819999999999
# RGL_V   =             -1.99779
# ODV     =                32.05
# ODI     =                 28.3
# GDP     =                 20.0
# RDP     =                 13.0
# OGP     =                 -2.0
# ODP     =                 26.9
# CSGATEP =                  1.0
# SCK_LOWP=                 -5.0
# SCK_HIP =                  5.0
# PCK_LOWP=                 -8.0
# PCK_HIP =                  2.0
# RG_LOWP =                 -2.0
# RG_HIP  =                  8.0
# AP0_RC  =                   14
# AP1_RC  =                   14
# AP0_GAIN=                    0
# AP1_GAIN=                    0
# AP0_CLMP=                    0
# AP1_CLMP=                    0
# AP0_AF1 =                    0
# AP1_AF1 =                    0
# AP0_TM  =                    0
# AP1_TM  =                    0
# HVBIAS  = 'ON      '
# ANAV    =                  7.2
# ANAI    =                302.4
# DIGV    =                 5.25
# DIGI    =                668.0
# FANV    =                  0.0
# FANI    =                  0.0
# CLKHIGHV=                 12.0
# CLKHIGHI=                 30.1
# CLKLOWV =                 12.0
# CLKLOWI =                 30.5
# HVBIASV =                -50.0
# HVBIASI =          1.44865E-11
# DPHIV   =                 10.0
# DPHII   =                  6.3
# OTMV    =                  5.0
# OTMI    =                462.2
# AUXV    =                  0.0
# AUXI    =                  0.0
# DATASUM = '0       '
# HIERARCH ASTRO METADATA FIX MODIFIED = T
# HIERARCH ASTRO METADATA FIX DATE = '2023-08-30T08:06:47.036162'
# HIERARCH ASTRO METADATA FIX VERSION = 'gfd7e96728c+6f6aa72e7b'
# HIERARCH LSST CALIB DATE BIAS = '2023-04-28 14:13:20 PDT'
# HIERARCH LSST CALIB DATE DEFECTS = '2022-06-08 17:35:34'
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C10 = 14767.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C10 = 14767.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C10 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C10 = -0.2544765624997947
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C10 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C10 = 6.666711646490232
# OVERSCAN= 'Overscan corrected'
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C11 = 14006.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C11 = 14006.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C11 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C11 = 0.4594687500005513
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C11 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C11 = 6.564640501993127
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C12 = 13001.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C12 = 13001.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C12 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C12 = 0.2493125000003643
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C12 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C12 = 6.515217047246265
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C13 = 12543.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C13 = 12543.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C13 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C13 = -0.277820312498982
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C13 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C13 = 6.650696871450616
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C14 = 13174.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C14 = 13174.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C14 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C14 = -0.03178125000020161
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C14 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C14 = 6.478775141975386
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C15 = 14037.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C15 = 14037.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C15 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C15 = -0.4968671875000307
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C15 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C15 = 6.608522477235235
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C16 = 14964.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C16 = 14964.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C16 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C16 = 0.3170937500000836
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C16 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C16 = 6.698102094016986
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C17 = 18655.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C17 = 18655.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C17 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C17 = 0.2688437499999147
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C17 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C17 = 6.49457087758123
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C07 = 18246.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C07 = 18246.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C07 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C07 = -0.139328124999802
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C07 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C07 = 6.8421638516183
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C06 = 14946.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C06 = 14946.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C06 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C06 = -0.02731250000004262
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C06 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C06 = 7.748845810254446
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C05 = 13702.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C05 = 13702.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C05 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C05 = 0.01732812500004686
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C05 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C05 = 8.103201850793265
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C04 = 13027.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C04 = 13027.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C04 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C04 = 0.2712890624997473
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C04 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C04 = 7.25642574793148
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C03 = 12611.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C03 = 12611.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C03 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C03 = -0.3972890624994634
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C03 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C03 = 7.054446268301266
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C02 = 13562.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C02 = 13562.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C02 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C02 = -0.2980781249998308
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C02 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C02 = 7.066555620015889
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C01 = 13828.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C01 = 13828.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C01 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C01 = -0.3262031250001637
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C01 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C01 = 7.400814342642255
# HIERARCH LSST ISR OVERSCAN SERIAL MEAN C00 = 14928.0
# HIERARCH LSST ISR OVERSCAN SERIAL MEDIAN C00 = 14928.0
# HIERARCH LSST ISR OVERSCAN SERIAL STDEV C00 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEAN C00 = 0.393609375000091
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL MEDIAN C00 = 0.0
# HIERARCH LSST ISR OVERSCAN RESIDUAL SERIAL STDEV C00 = 7.097542123263814
# HIERARCH LSST GAIN C10 = 1.0811
# HIERARCH LSST READNOISE C10 = 8.4
# HIERARCH LSST GAIN C11 = 1.047
# HIERARCH LSST READNOISE C11 = 8.5
# HIERARCH LSST GAIN C12 = 1.0795
# HIERARCH LSST READNOISE C12 = 8.4
# HIERARCH LSST GAIN C13 = 1.081
# HIERARCH LSST READNOISE C13 = 8.6
# HIERARCH LSST GAIN C14 = 1.0644
# HIERARCH LSST READNOISE C14 = 8.4
# HIERARCH LSST GAIN C15 = 1.0669
# HIERARCH LSST READNOISE C15 = 8.4
# HIERARCH LSST GAIN C16 = 1.0795
# HIERARCH LSST READNOISE C16 = 8.4
# HIERARCH LSST GAIN C17 = 1.056
# HIERARCH LSST READNOISE C17 = 8.0
# HIERARCH LSST GAIN C07 = 1.1033
# HIERARCH LSST READNOISE C07 = 8.5
# HIERARCH LSST GAIN C06 = 1.1039
# HIERARCH LSST READNOISE C06 = 10.0
# HIERARCH LSST GAIN C05 = 1.1047
# HIERARCH LSST READNOISE C05 = 10.3
# HIERARCH LSST GAIN C04 = 1.084
# HIERARCH LSST READNOISE C04 = 9.699999999999999
# HIERARCH LSST GAIN C03 = 1.0939
# HIERARCH LSST READNOISE C03 = 9.1
# HIERARCH LSST GAIN C02 = 1.0874
# HIERARCH LSST READNOISE C02 = 9.4
# HIERARCH LSST GAIN C01 = 1.0933
# HIERARCH LSST READNOISE C01 = 9.9
# HIERARCH LSST GAIN C00 = 1.0972
# HIERARCH LSST READNOISE C00 = 9.1
# HIERARCH LSST ISR MASK SAT C10 = 0
# HIERARCH LSST ISR MASK BAD C10 = 22304
# HIERARCH LSST ISR FINAL MEAN C10 = 43.9559940189638
# HIERARCH LSST ISR FINAL MEDIAN C10 = 46.48562240600586
# HIERARCH LSST ISR FINAL STDEV C10 = 18.06411645588556
# HIERARCH LSST ISR LEVEL C10 = -14720.51437759399
# HIERARCH LSST ISR MASK SAT C11 = 0
# HIERARCH LSST ISR MASK BAD C11 = 22304
# HIERARCH LSST ISR FINAL MEAN C11 = 46.67107141624121
# HIERARCH LSST ISR FINAL MEDIAN C11 = 49.19696617126465
# HIERARCH LSST ISR FINAL STDEV C11 = 17.35178560893993
# HIERARCH LSST ISR LEVEL C11 = -13956.80303382874
# HIERARCH LSST ISR MASK SAT C12 = 0
# HIERARCH LSST ISR MASK BAD C12 = 25668
# HIERARCH LSST ISR FINAL MEAN C12 = 45.98443736556144
# HIERARCH LSST ISR FINAL MEDIAN C12 = 48.7485294342041
# HIERARCH LSST ISR FINAL STDEV C12 = 17.64429218313007
# HIERARCH LSST ISR LEVEL C12 = -12952.2514705658
# HIERARCH LSST ISR MASK SAT C13 = 0
# HIERARCH LSST ISR MASK BAD C13 = 25668
# HIERARCH LSST ISR FINAL MEAN C13 = 50.71187583694464
# HIERARCH LSST ISR FINAL MEDIAN C13 = 49.29962539672852
# HIERARCH LSST ISR FINAL STDEV C13 = 19.14101886587157
# HIERARCH LSST ISR LEVEL C13 = -12493.70037460327
# HIERARCH LSST ISR MASK SAT C14 = 0
# HIERARCH LSST ISR MASK BAD C14 = 23500
# HIERARCH LSST ISR FINAL MEAN C14 = 45.98623744624126
# HIERARCH LSST ISR FINAL MEDIAN C14 = 49.0031795501709
# HIERARCH LSST ISR FINAL STDEV C14 = 18.55958510104217
# HIERARCH LSST ISR LEVEL C14 = -13124.99682044983
# HIERARCH LSST ISR MASK SAT C15 = 0
# HIERARCH LSST ISR MASK BAD C15 = 23500
# HIERARCH LSST ISR FINAL MEAN C15 = 46.50011509058172
# HIERARCH LSST ISR FINAL MEDIAN C15 = 50.3811206817627
# HIERARCH LSST ISR FINAL STDEV C15 = 20.48425938918381
# HIERARCH LSST ISR LEVEL C15 = -13986.61887931824
# HIERARCH LSST ISR MASK SAT C16 = 0
# HIERARCH LSST ISR MASK BAD C16 = 23500
# HIERARCH LSST ISR FINAL MEAN C16 = 46.88145271452784
# HIERARCH LSST ISR FINAL MEDIAN C16 = 50.30382347106934
# HIERARCH LSST ISR FINAL STDEV C16 = 21.77956503111626
# HIERARCH LSST ISR LEVEL C16 = -14913.69617652893
# HIERARCH LSST ISR MASK SAT C17 = 0
# HIERARCH LSST ISR MASK BAD C17 = 20000
# HIERARCH LSST ISR FINAL MEAN C17 = 23.91607319129716
# HIERARCH LSST ISR FINAL MEDIAN C17 = 23.39448738098145
# HIERARCH LSST ISR FINAL STDEV C17 = 16.28858767689994
# HIERARCH LSST ISR LEVEL C17 = -18631.60551261902
# HIERARCH LSST ISR MASK SAT C07 = 0
# HIERARCH LSST ISR MASK BAD C07 = 0
# HIERARCH LSST ISR FINAL MEAN C07 = 31.54886727682191
# HIERARCH LSST ISR FINAL MEDIAN C07 = 31.68567371368408
# HIERARCH LSST ISR FINAL STDEV C07 = 12.22299168741278
# HIERARCH LSST ISR LEVEL C07 = -18214.31432628632
# HIERARCH LSST ISR MASK SAT C06 = 0
# HIERARCH LSST ISR MASK BAD C06 = 0
# HIERARCH LSST ISR FINAL MEAN C06 = 54.80475895051264
# HIERARCH LSST ISR FINAL MEDIAN C06 = 55.26871490478516
# HIERARCH LSST ISR FINAL STDEV C06 = 11.34022244434137
# HIERARCH LSST ISR LEVEL C06 = -14890.73128509521
# HIERARCH LSST ISR MASK SAT C05 = 0
# HIERARCH LSST ISR MASK BAD C05 = 20000
# HIERARCH LSST ISR FINAL MEAN C05 = 56.5719154996097
# HIERARCH LSST ISR FINAL MEDIAN C05 = 56.71303367614746
# HIERARCH LSST ISR FINAL STDEV C05 = 10.615222707144
# HIERARCH LSST ISR LEVEL C05 = -13645.28696632385
# HIERARCH LSST ISR MASK SAT C04 = 0
# HIERARCH LSST ISR MASK BAD C04 = 24500
# HIERARCH LSST ISR FINAL MEAN C04 = 56.05785755758356
# HIERARCH LSST ISR FINAL MEDIAN C04 = 56.12465858459473
# HIERARCH LSST ISR FINAL STDEV C04 = 10.03443010018627
# HIERARCH LSST ISR LEVEL C04 = -12970.87534141541
# HIERARCH LSST ISR MASK SAT C03 = 0
# HIERARCH LSST ISR MASK BAD C03 = 24500
# HIERARCH LSST ISR FINAL MEAN C03 = 68.64538999580759
# HIERARCH LSST ISR FINAL MEDIAN C03 = 55.43457794189453
# HIERARCH LSST ISR FINAL STDEV C03 = 10.61739443271198
# HIERARCH LSST ISR LEVEL C03 = -12555.56542205811
# HIERARCH LSST ISR MASK SAT C02 = 0
# HIERARCH LSST ISR MASK BAD C02 = 23500
# HIERARCH LSST ISR FINAL MEAN C02 = 54.47713705426164
# HIERARCH LSST ISR FINAL MEDIAN C02 = 54.50306129455566
# HIERARCH LSST ISR FINAL STDEV C02 = 10.04649602723648
# HIERARCH LSST ISR LEVEL C02 = -13507.49693870544
# HIERARCH LSST ISR MASK SAT C01 = 0
# HIERARCH LSST ISR MASK BAD C01 = 23500
# HIERARCH LSST ISR FINAL MEAN C01 = 52.49623826025326
# HIERARCH LSST ISR FINAL MEDIAN C01 = 52.5257511138916
# HIERARCH LSST ISR FINAL STDEV C01 = 10.07953796922043
# HIERARCH LSST ISR LEVEL C01 = -13775.47424888611
# HIERARCH LSST ISR MASK SAT C00 = 0
# HIERARCH LSST ISR MASK BAD C00 = 20000
# HIERARCH LSST ISR FINAL MEAN C00 = 51.80229312547082
# HIERARCH LSST ISR FINAL MEDIAN C00 = 51.60127830505371
# HIERARCH LSST ISR FINAL STDEV C00 = 10.2090705491229
# HIERARCH LSST ISR LEVEL C00 = -14876.39872169495
# AMEND   =    1.903331368739209
# CAM_ROT =   238.65096559782782
# PARANGLE=   -61.05677706482834 / parallactic angle in degree
# AIRMASS =    1.903331368739209
# OUTTEMP =    4.050000190734863
# OUTPRESS=    741.9500122070312
# OUTHUM  =    39.36249923706055
# CCDREBIN=                    2
# TARGET  = 'HD185975'           / name of the target in the image
# REDSHIFT=             -6.5E-05 / redshift of the target
# ROTANGLE=                    0 / [deg] angle of the dispersion axis
# D2CCD   =                186.0 / [mm] distance between disperser and CCD
# COMMENT ---- Checksums ----

# %% [markdown]
# # Plot image and find the target position
#
# - this image plotting is used to find the order 0 location to be set in logbook
#
# - for the moment this is humanly done

# %% [markdown]
# ## Load the new image file with Spectractor

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
title="{}) {}".format(idx,filename_image)
image.plot_image(figsize=(12, 10),scale="log",title=title)
plt.show()

# %%
image_original = copy.deepcopy(image.data)
image_original.shape
# Out:
# (4072, 4000)

# %%
if parameters.CCD_REBIN > 1:
        my_logger.info('\n\t  ======================= REBIN =============================')
        image.rebin()
        if parameters.DEBUG:
            image.plot_image(scale='symlog', title="after rebinning ", target_pixcoords=image.target_guess)
# Out:
# REBIN DO MAKESUM
# REBIN DO MAKESUM

# %%
image.plot_image(figsize=(12, 10),scale="log",title=title)

# %%
image_truncated = copy.deepcopy(image.data)

# %%
image_truncated.shape
# Out:
# (2036, 2000)

# %%
spectrum_original = image_original.sum(axis=0)
pixels_numbers_orignal = np.arange(0,spectrum_original.shape[0])
spectrum_truncated = image_truncated.sum(axis=0)
pixels_numbers_truncated = np.arange(0,spectrum_truncated.shape[0])

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)
ax.plot(pixels_numbers_orignal,spectrum_original,color="b",label="original")
ax.plot(2*pixels_numbers_truncated,spectrum_truncated,color="r",label="rebin")
ax.plot(2*pixels_numbers_truncated,spectrum_truncated/2,":",color="orange",label="rebin/2")
ax.set_ylim(0,20000)
ax.legend()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1,1,1)
ax.plot(pixels_numbers_orignal,spectrum_original,color="b",label="original")
ax.plot(2*pixels_numbers_truncated,spectrum_truncated,color="r",label="rebin")
ax.plot(2*pixels_numbers_truncated,spectrum_truncated/2,":",color="r",label="rebin/2")
ax.set_xlim(0,500)
ax.legend()

# %%
plt.imshow(image_original,origin="lower",norm=LogNorm(vmin=0.01, vmax=20000))
plt.grid()

# %%
plt.imshow(image_truncated,origin="lower",norm=LogNorm(vmin=0.01, vmax=20000))
plt.grid()
