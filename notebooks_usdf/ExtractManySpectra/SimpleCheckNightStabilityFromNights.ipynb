# %% [markdown]
# # Check Spectra Stability Spectra written in the pickle files
#
#
# work with Weakly_2023_01
# - use jupyter kernel LSST
#
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab
# - creation date : 2023/02/20
# - last update : 2023/02/20

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.cm as cm 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import numpy as np
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import os,sys,re

from astropy.io import fits
import matplotlib.colors as colors
import matplotlib.cm as cmx
import matplotlib.dates as mdates
from matplotlib import gridspec
# %matplotlib inline
import pickle

# %%
import matplotlib.offsetbox
props = dict(boxstyle='round',edgecolor="w",facecolor="w", alpha=0.5)

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (10, 6),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

# %%
import time
from datetime import datetime,date
from astropy.time import Time
import dateutil.parser
import pytz

import argparse

import logging
import coloredlogs
import configparser

# %%
from scipy import interpolate
from scipy.interpolate import interp1d
from scipy.signal import savgol_filter
from scipy import fftpack

# %%
class Line:
    """Class modeling the emission or absorption lines."""

    def __init__(self, wavelength, label, atmospheric=False, emission=False, label_pos=[0.007, 0.02],
                 width_bounds=[0.5, 6], use_for_calibration=False):
        """Class modeling the emission or absorption lines. lines attributes contains main spectral lines
        sorted in wavelength.

        Parameters
        ----------
        wavelength: float
            Wavelength of the spectral line in nm
        label: str

        atmospheric: bool
            Set True if the spectral line is atmospheric (default: False)
        emission: bool
            Set True if the spectral line has to be detected in emission. Can't be true if the line is atmospheric.
            (default: False)
        label_pos: [float, float]
            Position of the label in the plot with respect to the vertical lin (default: [0.007,0.02])
        width_bounds: [float, float]
            Minimum and maximum width (in nm) of the line for fitting procedures (default: [1,7])
        use_for_calibration: bool
            Use this line for the dispersion relation calibration, bright line recommended (default: False)

        Examples
        --------
        >>> l = Line(550, label='test', atmospheric=True, emission=True)
        >>> print(l.wavelength)
        550
        >>> print(l.label)
        test
        >>> print(l.atmospheric)
        True
        >>> print(l.emission)
        False
        """
        self.wavelength = wavelength  # in nm
        self.label = label
        self.label_pos = label_pos
        self.atmospheric = atmospheric
        self.emission = emission
        if self.atmospheric:
            self.emission = False
        self.width_bounds = width_bounds
        self.fitted = False
        self.use_for_calibration = use_for_calibration
        self.high_snr = False
        self.fit_lambdas = None
        self.fit_gauss = None
        self.fit_bgd = None
        self.fit_snr = None
        self.fit_fwhm = None
        self.fit_popt = None
        self.fit_pcov = None
        self.fit_popt_gaussian = None
        self.fit_pcov_gaussian = None
        self.fit_chisq = None
        self.fit_eqwidth_mod = None
        self.fit_eqwidth_data = None
        #self.fit_bgd_npar = parameters.CALIB_BGD_NPARAMS
        self.fit_bgd_npar = None

# %%
HALPHA = Line(656.3, atmospheric=False, label='$H\\alpha$', label_pos=[-0.01, 0.02], use_for_calibration=True)
HBETA = Line(486.3, atmospheric=False, label='$H\\beta$', label_pos=[0.001, 0.02], use_for_calibration=True)
HGAMMA = Line(434.0, atmospheric=False, label='$H\\gamma$', label_pos=[0.001, 0.02], use_for_calibration=True)
HDELTA = Line(410.2, atmospheric=False, label='$H\\delta$', label_pos=[0.001, 0.02], use_for_calibration=True)
HEPSILON = Line(397.0, atmospheric=False, label='$H\\epsilon$', label_pos=[0.001, 0.02], use_for_calibration=True)

HZETA = Line(388.9064, atmospheric=False, label='$H\\zeta$', label_pos=[0.001, 0.02], use_for_calibration=False)
HETA = Line(383.5397, atmospheric=False, label='$H\\eta$', label_pos=[0.001, 0.02], use_for_calibration=False)

HBETA2 = Line(486.3*2, atmospheric=False, label='$H\\beta$2', label_pos=[0.001, 0.02], use_for_calibration=True)
HGAMMA2 = Line(434.0*2, atmospheric=False, label='$H\\gamma$2', label_pos=[0.001, 0.02], use_for_calibration=True)
HDELTA2 = Line(410.2*2, atmospheric=False, label='$H\\delta$2', label_pos=[0.001, 0.02], use_for_calibration=True)
HEPSILON2 = Line(397.0*2, atmospheric=False, label='$H\\epsilon$2', label_pos=[0.001, 0.02], use_for_calibration=True)
HZETA2 = Line(388.9064*2, atmospheric=False, label='$H\\zeta$2', label_pos=[0.001, 0.02], use_for_calibration=False)
HETA2 = Line(383.5397*2, atmospheric=False, label='$H\\eta$2', label_pos=[0.001, 0.02], use_for_calibration=False)

O2_1 = Line(760.3, atmospheric=True, label='$O_2$',label_pos=[0.001, 0.02], use_for_calibration=True)  # libradtran paper fig.3
O2_2 = Line(763.1, atmospheric=True, label='$O_2$',label_pos=[0.001, 0.02], use_for_calibration=True)  # libradtran paper fig.3

O2B = Line(687.472, atmospheric=True, label=r'$O_2(B)$',  # 687.472 is a weighted average of the O2B line simulated by Libradtran
           label_pos=[0.001, 0.02], use_for_calibration=True)  # https://en.wikipedia.org/wiki/Fraunhofer_lines
O2Y = Line(898.765, atmospheric=True, label=r'$O_2(Y)$',
           label_pos=[0.001, 0.02])  # https://en.wikipedia.org/wiki/Fraunhofer_lines
O2Z = Line(822.696, atmospheric=True, label=r'$O_2(Z)$',
           label_pos=[0.001, 0.02])  # https://en.wikipedia.org/wiki/Fraunhofer_lines
# H2O = Line( 960,atmospheric=True,label='$H_2 O$',label_pos=[0.007,0.02],width_bounds=(1,50))  #
H2O_1 = Line(935, atmospheric=True, label=r'$H_2 O$', label_pos=[0.001, 0.02],  # MFL: don't these need different labels?
             width_bounds=[5, 30])  # libradtran paper fig.3, broad line
H2O_2 = Line(960, atmospheric=True, label=r'$H_2 O$', label_pos=[0.001, 0.02],  # MFL: don't these need different labels?
              width_bounds=[5, 30])  # libradtran paper fig.3, broad line
ATMOSPHERIC_LINES = [O2_1, O2_2, O2B, O2Y, O2Z, H2O_1]

# %%
def smooth_data_convolve_my_average(arr, span):
    re = np.convolve(arr, np.ones(span * 2 + 1) / (span * 2 + 1), mode="same")

    # The "my_average" part: shrinks the averaging window on the side that 
    # reaches beyond the data, keeps the other side the same size as given 
    # by "span"
    re[0] = np.average(arr[:span])
    for i in range(1, span + 1):
        re[i] = np.average(arr[:i + span])
        re[-i] = np.average(arr[-i - span:])
    return re

def smooth_data_np_average(arr, span):  # my original, naive approach
    return [np.average(arr[val - span:val + span + 1]) for val in range(len(arr))]

def smooth_data_np_convolve(arr, span):
    return np.convolve(arr, np.ones(span * 2 + 1) / (span * 2 + 1), mode="same")

def smooth_data_np_cumsum_my_average(arr, span):
    cumsum_vec = np.cumsum(arr)
    moving_average = (cumsum_vec[2 * span:] - cumsum_vec[:-2 * span]) / (2 * span)

    # The "my_average" part again. Slightly different to before, because the
    # moving average from cumsum is shorter than the input and needs to be padded
    front, back = [np.average(arr[:span])], []
    for i in range(1, span):
        front.append(np.average(arr[:i + span]))
        back.insert(0, np.average(arr[-i - span:]))
    back.insert(0, np.average(arr[-2 * span:]))
    return np.concatenate((front, moving_average, back))

def smooth_data_lowess(arr, span):
    x = np.linspace(0, 1, len(arr))
    return sm.nonparametric.lowess(arr, x, frac=(5*span / len(arr)), return_sorted=False)

def smooth_data_kernel_regression(arr, span):
    # "span" smoothing parameter is ignored. If you know how to 
    # incorporate that with kernel regression, please comment below.
    kr = KernelReg(arr, np.linspace(0, 1, len(arr)), 'c')
    return kr.fit()[0]

def smooth_data_savgol_0(arr, span):  
    return savgol_filter(arr, span * 2 + 1, 0)

def smooth_data_savgol_1(arr, span):  
    return savgol_filter(arr, span * 2 + 1, 1)

def smooth_data_savgol_2(arr, span):  
    return savgol_filter(arr, span * 2 + 1, 2)

def smooth_data_fft(arr, span):  # the scaling of "span" is open to suggestions
    w = fftpack.rfft(arr)
    spectrum = w ** 2
    cutoff_idx = spectrum < (spectrum.max() * (1 - np.exp(-span / 2000)))
    w[cutoff_idx] = 0
    return fftpack.irfft(w)

# %%
def find_nearest(a, a0):
    "Element in nd array `a` closest to the scalar value `a0`"
    idx = np.abs(a - a0).argmin()
    return a.flat[idx],int(idx)

# %%
def GetSpectra(dict_spectra):
    """
    GetSpectra(dict_spectra)
    
    input:
      - dict_spectra : dictionnary of input spectra
      
      
      {'number': 238.0, 'object': 'mu. Col', 'dateobs': '2022-03-18T00:51:22.049', 'refhour': 0.0, 'airmass': 1.11557476948966, 'pressure': 743.45, 'temperature': 8.9, 
      'humidity': 48.0, 'targetx_pix': 312.7442668572934, 'targety_pix': 1738.0006619324693, 'rotangle': 0.1753951396614214, 'd2ccd': 181.0974436798836, 
      'all_lambdas': array([ 302.20970512,  302.91544585,  303.62117594, ..., 1108.67461764,
       1109.35162338, 1110.02859124]), 'all_fluxes': array([1.04110833e-13, 9.83856109e-14, 8.99209206e-14, ...,
       5.34113538e-13, 5.36905940e-13, 5.53127394e-13]), 'all_fluxes_err': array([3.51303583e-15, 3.10100695e-15, 2.58677333e-15, ...,
       3.34568263e-15, 4.01784054e-15, 4.54242555e-15]), 'all_lambdas_order2': array([ 302.24857475,  302.9543149 ,  303.66004442, ..., 1108.71192607,
       1109.38892974, 1110.06589555]), 'all_fluxes_order2': array([420.23653349, 386.95227531, 344.90384603, ...,  60.47440612,
        60.74615545,  62.53491353]), 'all_fluxes_err_order2': array([14.15542468, 12.17674916,  9.90751987, ...,  0.37846535,
        0.45415764,  0.51307916])}
      
    
    return
      - list of dataframes
    """
    
    #correction_area = 1.06/1.13
    correction_area = 1
    
    list_of_columns = ["number","object",'dateobs','refhour','airmass','pressure','temperature','humidity','filename','targetx_pix', 'targety_pix','rotangle', 'd2ccd']   

    all_df = []  # container for spectra
    
    df_info = pd.DataFrame(columns=list_of_columns)
    
    idx=0
    #for key, value in dict_spectra.items():
    sorted_dict_spectra = sorted(dict_spectra.items())
    for key, value in sorted_dict_spectra:    
        df_info.loc[idx] = [int(value["number"]),value["object"],value["dateobs"],value["refhour"],value["airmass"],value["pressure"],value["temperature"],value["humidity"],key,value['targetx_pix'],value['targety_pix'],value['rotangle'], value['d2ccd']]
         
        df = pd.DataFrame()
        df["all_lambdas"] = value["all_lambdas"]
        df["all_fluxes"] = value["all_fluxes"]/ correction_area 
        df["all_fluxes_err"] = value["all_fluxes_err"]
        
        if 'all_lambdas_order2' in value.keys():
            df["all_lambdas_order2"] = value["all_lambdas_order2"]
            df["all_fluxes_order2"] = value["all_fluxes_order2"]/ correction_area 
            df["all_fluxes_err_order2"] = value["all_fluxes_err_order2"]
            
        
        all_df.append(df)
        
        
        idx+=1
        
    return df_info , all_df

# %%
def GetSpectraFiltered(dict_spectra,list_of_bad_spectra):
    """
    GetSpectraFiltered(inputdir,inputfiles)
    
    input:
      - dict_spectra
      - ist_of_bad_spectra
    
    return
      - filtered infos, filtered spectra
    """
    
    # factor to correct fluxes (over estimated collection surface)
    #correction_area = 1.06/1.13
    correction_area = 1
    
    
    
    list_of_columns = ["number","object",'dateobs','refhour','airmass','pressure','temperature','humidity','filename','targetx_pix', 'targety_pix','rotangle', 'd2ccd']   
        

    all_df = []  # container for spectra
    
    df_info = pd.DataFrame(columns=list_of_columns)
    
    idx=0       # counter on input spectra
    idx_out = 0 # counter on save spectra
    #for key, value in dict_spectra.items():
    sorted_dict_spectra = sorted(dict_spectra.items())
    for key, value in sorted_dict_spectra:    
        
        
        if int(value["number"]) not in list_of_bad_spectra:
        
            
            df_info.loc[idx] = [int(value["number"]),value["object"],value["dateobs"],value["refhour"],value["airmass"],value["pressure"],value["temperature"],value["humidity"],key,value['targetx_pix'],value['targety_pix'],value['rotangle'], value['d2ccd']] 
        
            df = pd.DataFrame()
            df["all_lambdas"] = value["all_lambdas"]
            df["all_fluxes"] = value["all_fluxes"]/correction_area
            df["all_fluxes_err"] = value["all_fluxes_err"]
        
            if 'all_lambdas_order2' in value.keys():
                df["all_lambdas_order2"] = value["all_lambdas_order2"]
                df["all_fluxes_order2"] = value["all_fluxes_order2"]/correction_area
                df["all_fluxes_err_order2"] = value["all_fluxes_err_order2"]
               
            all_df.append(df)
            idx_out+=1  # increase count on saved spectra
            
        else:
            num = int(value["number"])
            msg = f"Remove spectrum {idx} for exposure {num}"
            print(msg)
            
        idx+=1
            

        
    return df_info,all_df

# %% [markdown]
# # Initialisation

# %%
# start with logs
#-----------------
logging.basicConfig()
logging.root.setLevel(logging.NOTSET)

handle = __name__

logger = logging.getLogger(handle)
# logging.getLogger().setLevel(logging.INFO)
logger.setLevel(logging.DEBUG)

# If you don't want to see log messages from libraries, you can pass a
# specific logger object to the install() function. In this case only log
# messages originating from that logger will show up on the terminal.
coloredlogs.install(level='DEBUG', logger=logger)
coloredlogs.install(fmt='%(asctime)s,%(msecs)03d %(hostname)s %(name)s[%(process)d] %(levelname)s %(message)s')

# %% [markdown]
# ## Input file

# %%
def get_filename(the_date,the_filtertype):

    list_of_badnums1 = []
    input_filename = None

    if the_date == 20220317:
        input_filename = "run-auxtel-holo-20220317-empty~holo4_003-PSF2DFFM_REBIN2-main.pickle"
        list_of_badnums1 = [330,338,359,366,415,429,436,442,443]
    
    if the_date == 20220629:
        input_filename = "run-auxtel-holo-20220629-empty~holo4_003-PSF2DFFM_REBIN2-main.pickle"
        list_of_badnums1 = [499]
    
    if the_date == 20220630:
        input_filename = "run-auxtel-holo-20220630-empty~holo4_003-PSF2DFFM_REBIN2-main.pickle"
        list_of_badnums1 = []
    

    if the_date == 20230117:
        ##input_filename = "run-auxtel-holo-20230117-empty~holo4_003-PSF2DFFM_REBIN2.pickle"
        ##list_of_badnums1 = [240,348]
    
        if the_filtertype == "empty~holo4_003":
            input_filename = "run-auxtel-holo-20230117-empty~holo4_003-PSF2DFFM_REBIN2_b.pickle"
            list_of_badnums1 = [239,243,244,265,285,326,334,348,376,390,457,477,524,535,607,608,616,617,646, 647]
    
        #input_filename = "run-auxtel-holo-20230117-empty~holo4_003-PSF2DFFM_REBIN1-oga.pickle"
        #list_of_badnums1 = [238,239,248,249,265,285,297,298,349,375,376,389,390,447,487,505,506,524,543,599,617,660,661,669]
    
        if the_filtertype == "OG550_65mm_1~holo4_003":
            input_filename ="run-auxtel-holo-20230117-OG550_65mm_1~holo4_003-PSF2DFFM_REBIN2-oga.pickle"
            list_of_badnums1 = [252,321,353,379,380,462,593,650,651,692]
    
    
    elif the_date == 20230118:
        ##input_filename = "run-auxtel-holo-20230118-empty~holo4_003-PSF2DFFM_REBIN2.pickle"
    
        if the_filtertype == "empty~holo4_003":
            input_filename = "run-auxtel-holo-20230118-empty~holo4_003-PSF2DFFM_REBIN2_b.pickle"
            list_of_badnums1 = [208,312,313,322,375,420,463,464,482,563,564,618,626,627,707]
    
    
            #input_filename = "run-auxtel-holo-20230118-empty~holo4_003-PSF2DFFM_REBIN1-oga.pickle"
            #list_of_badnums1 = [208,273,374,396,408,431,432,463,472,473,502,539,540,554,573,591,600,617,626,636,644,645,654,671,672,690,698,707]
        if the_filtertype == "OG550_65mm_1~holo4_003":
            input_filename = "run-auxtel-holo-20230118-OG550_65mm_1~holo4_003-PSF2DFFM_REBIN2-oga.pickle"
            list_of_badnums1 = [230,277,278,351,379,448,458,467,476,505,506,576,586,666,667,675]
    
  
    
    elif the_date == 20230119:
        ##input_filename = "run-auxtel-holo-20230119-empty~holo4_003-PSF2DFFM_REBIN2.pickle"
    
        if the_filtertype == "empty~holo4_003":
            input_filename = "run-auxtel-holo-20230119-empty~holo4_003-PSF2DFFM_REBIN2_b.pickle"
            list_of_badnums1 = [218,287,288,393]
    
        if the_filtertype == "OG550_65mm_1~holo4_003":
            input_filename = "run-auxtel-holo-20230119-OG550_65mm_1~holo4_003-PSF2DFFM_REBIN2-oga.pickle"
            list_of_badnums1 = [221,230,258,330,378]

    elif the_date == 20230201:
        if the_filtertype == "empty~holo4_003":
            input_filename = "run-auxtel-holo-20230201-empty~holo4_003-PSF2DFFM_REBIN1-oga.pickle"
            list_of_badnums1 = [387,397,444,445,463,500,509,518,529,539,540,549,569,623,624,633,651]
    
    


    elif the_date == 20230202:
    
        if the_filtertype == "empty~holo4_003":
            input_filename = "run-auxtel-holo-20230202-empty~holo4_003-PSF2DFFM_REBIN1-oga.pickle"
            list_of_badnums1 = [387,397,444,445,463,500,509,518,529,539,540,549,569,587,588,627,623,624,633,651,669]
        
        if the_filtertype == "OG550_65mm_1~holo4_003":
            #input_filename = "run-auxtel-holo-20230202-OG550_65mm_1~holo4_003-PSF2DFFM_REBIN2-oga.pickle"
            #list_of_badnums1 = [] # al OK
        
            input_filename = "run-auxtel-holo-20230202-OG550_65mm_1~holo4_003-PSF2DFFM_REBIN1-oga.pickle"
            list_of_badnums1 = [647,954,955]

    else:
        msg = f"No valid date spected {the_date}"
        logger.error(msg)
        
        
    return input_filename, list_of_badnums1

# %% [markdown]
# # Start

# %%
# set time
# date
today = date.today()
string_date = today.strftime("%Y-%m-%d")

# time
now = datetime.now()
current_time = now.strftime("%H:%M:%S")

tim = time.localtime()
current_time = time.strftime("%H:%M:%S", tim)

# timezones
tz_LA = pytz.timezone('America/Los_Angeles')
datetime_LA = datetime.now(tz_LA)
msg="LA time:"+  datetime_LA.strftime("%H:%M:%S")
logger.info(msg)

tz_NY = pytz.timezone('America/New_York')
datetime_NY = datetime.now(tz_NY)
msg="NY time:"+ datetime_NY.strftime("%H:%M:%S")
logger.info(msg)

tz_London = pytz.timezone('Europe/London')
datetime_London = datetime.now(tz_London)
msg="London time:"+ datetime_London.strftime("%H:%M:%S")
logger.info(msg)

tz_Paris = pytz.timezone('Europe/Paris')
datetime_Paris = datetime.now(tz_Paris)
msg="Paris time:"+ datetime_Paris.strftime("%H:%M:%S")
logger.info(msg)
# Out:
# 2023-02-20 21:33:34,514 MacBook-Pro-de-admin.local __main__[7157] INFO LA time:12:33:34
# 2023-02-20 21:33:34,516 MacBook-Pro-de-admin.local __main__[7157] INFO NY time:15:33:34
# 2023-02-20 21:33:34,518 MacBook-Pro-de-admin.local __main__[7157] INFO London time:20:33:34
# 2023-02-20 21:33:34,520 MacBook-Pro-de-admin.local __main__[7157] INFO Paris time:21:33:34

# %% [markdown]
# # Config

# %%
all_dates = [20220317, 20220630, 20230117, 20230118, 20230119, 20230202]
the_filtertype = "empty~holo4_003"
#the_filtertype = "OG550_65mm_1~holo4_003"
path=os.path.join("./extracted_spectra",the_filtertype)

# %% [markdown]
# # Read input file

# %%
all_infos_set = []
all_spectra_set = []
#all_list_of_badnum_set = []
#all_summary_content = []


for the_date in all_dates:
    
    input_filename,list_of_badnum = get_filename(the_date,the_filtertype)
    fullfilename=os.path.join(path,input_filename)
    with open(fullfilename, 'rb') as f:
        summary_content = pickle.load(f)
        
    NBSPECTRA=len(summary_content)
    msg=f" Number of selected files is {NBSPECTRA}"
    logger.info(msg)
    
    #infos, all_spectra = GetSpectra(summary_content)
    infos, all_spectra = GetSpectraFiltered(summary_content,list_of_badnum)
    
    all_infos_set.append(infos)
    all_spectra_set.append(all_spectra)
# Out:
# 2023-02-20 21:33:34,534 MacBook-Pro-de-admin.local __main__[7157] ERROR No valid date spected 20220317
# 2023-02-20 21:33:34,539 MacBook-Pro-de-admin.local __main__[7157] INFO  Number of selected files is 59
# 2023-02-20 21:33:34,764 MacBook-Pro-de-admin.local __main__[7157] ERROR No valid date spected 20220630
# 2023-02-20 21:33:34,768 MacBook-Pro-de-admin.local __main__[7157] INFO  Number of selected files is 61
# Remove spectrum 25 for exposure 330
# Remove spectrum 28 for exposure 338
# Remove spectrum 34 for exposure 359
# Remove spectrum 36 for exposure 366
# Remove spectrum 50 for exposure 415
# Remove spectrum 54 for exposure 429
# Remove spectrum 56 for exposure 436
# Remove spectrum 57 for exposure 442
# Remove spectrum 58 for exposure 443
# 2023-02-20 21:33:35,031 MacBook-Pro-de-admin.local __main__[7157] INFO  Number of selected files is 70
# 2023-02-20 21:33:35,233 MacBook-Pro-de-admin.local __main__[7157] INFO  Number of selected files is 77
# Remove spectrum 1 for exposure 239
# Remove spectrum 2 for exposure 243
# Remove spectrum 3 for exposure 244
# Remove spectrum 6 for exposure 265
# Remove spectrum 10 for exposure 285
# Remove spectrum 17 for exposure 326
# Remove spectrum 18 for exposure 334
# Remove spectrum 20 for exposure 348
# Remove spectrum 24 for exposure 376
# Remove spectrum 26 for exposure 390
# Remove spectrum 33 for exposure 457
# Remove spectrum 37 for exposure 477
# Remove spectrum 44 for exposure 524
# Remove spectrum 47 for exposure 535
# Remove spectrum 58 for exposure 607
# Remove spectrum 59 for exposure 608
# Remove spectrum 60 for exposure 616
# Remove spectrum 61 for exposure 617
# Remove spectrum 62 for exposure 646
# Remove spectrum 63 for exposure 647
# Remove spectrum 1 for exposure 208
# 2023-02-20 21:33:35,486 MacBook-Pro-de-admin.local __main__[7157] INFO  Number of selected files is 43
# Remove spectrum 15 for exposure 312
# Remove spectrum 16 for exposure 313
# Remove spectrum 18 for exposure 322
# Remove spectrum 26 for exposure 375
# Remove spectrum 31 for exposure 420
# Remove spectrum 37 for exposure 463
# Remove spectrum 38 for exposure 464
# Remove spectrum 41 for exposure 482
# Remove spectrum 47 for exposure 563
# Remove spectrum 48 for exposure 564
# Remove spectrum 56 for exposure 618
# Remove spectrum 57 for exposure 626
# Remove spectrum 58 for exposure 627
# Remove spectrum 72 for exposure 707
# Remove spectrum 8 for exposure 218
# 2023-02-20 21:33:35,657 MacBook-Pro-de-admin.local __main__[7157] INFO  Number of selected files is 66
# Remove spectrum 17 for exposure 287
# Remove spectrum 18 for exposure 288
# Remove spectrum 40 for exposure 393
# Remove spectrum 0 for exposure 387
# Remove spectrum 3 for exposure 397
# Remove spectrum 12 for exposure 444
# Remove spectrum 13 for exposure 445
# Remove spectrum 17 for exposure 463
# Remove spectrum 25 for exposure 500
# Remove spectrum 27 for exposure 509
# Remove spectrum 29 for exposure 518
# Remove spectrum 30 for exposure 529
# Remove spectrum 31 for exposure 539
# Remove spectrum 32 for exposure 540
# Remove spectrum 33 for exposure 549
# Remove spectrum 36 for exposure 569
# Remove spectrum 40 for exposure 587
# Remove spectrum 41 for exposure 588
# Remove spectrum 48 for exposure 623
# Remove spectrum 49 for exposure 624
# Remove spectrum 51 for exposure 633
# Remove spectrum 55 for exposure 651
# Remove spectrum 59 for exposure 669

# %% [markdown]
# ### Select  spectra with target HD185975

# %%
all_infos_selected = []
all_airmasses = []
for idx,infos in enumerate(all_infos_set):
    infos_selected = infos[infos.object == "HD185975"]
    all_airmasses = all_airmasses + list(infos_selected["airmass"].values)
    all_infos_selected.append(infos_selected)

# %%
airmass_min = min(all_airmasses)
airmass_max = max(all_airmasses)

# %%
print(airmass_min,airmass_max)
# Out:
# 1.83612381151793 2.14421704201687

# %%
# wavelength bin colors
jet = plt.get_cmap('jet')
cNorm = colors.Normalize(vmin=airmass_min, vmax=airmass_max)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
#all_colors = scalarMap.to_rgba(np.arange(NBSPECTRA), alpha=1)

# %%
WL = np.arange(350,1050)
NWL=len(WL)

# %% [markdown]
# ## Read all spectra

# %%
N=len(all_dates)

# %%
# number of columns
NX=2
# numbers of rows
NY=N/NX

if NY != int(NY):
    NY= int(NY)+1
else:
    NY=int(NY)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(20,NY*6))

ny=0
nx=0

all_interpolated_spectra = []

# loop on each date
for idx in range(N):
    the_dat = all_dates[idx]
    iy = idx//NX
    ix = (idx-iy*NX)
    
    ax=fig.add_subplot(NY,NX,idx+1)
    ax.set_title(all_dates[idx])
    
    print(f"=== {the_dat} ====")
    infos_selected = all_infos_selected[idx]
    
    NSP = len(infos_selected)
    
    arr = np.zeros((NSP,NWL))
    
    nums = infos_selected.number.values
    c=0
    for spec_idx,am in zip(infos_selected.index,infos_selected.airmass.values):
        #print(">>> ",the_dat,spec_idx,am)
        spec_ii = np.where(all_infos_set[idx].index==spec_idx)[0][0]
        the_spectra = all_spectra_set[idx][spec_ii]
        wl = the_spectra.all_lambdas
        fl = the_spectra.all_fluxes
        efl = the_spectra.all_fluxes_err
        color = scalarMap.to_rgba(am)
        num=nums[c]
        label=f"z({num})={am:.2f}"
        ax.plot(wl,fl,"-",color=color,label=label)
        
        func = interpolate.interp1d(wl, fl)
        arr[c,:] = func(WL)       
        c+=1
        
    all_interpolated_spectra.append(arr)    
    ax.set_ylim(0,5e-12)
    ax.legend(loc="upper right",ncol=3)
    ax.grid()
    ax.set_xlabel("$\lambda$ (nm)")
    ax.set_ylabel("flux (ergs/nm/cm2/s)")
plt.tight_layout()    
plt.suptitle("target HD185975 (polar star)",fontsize=20,fontweight="bold",y=1)
plt.savefig("stability_HD185975.png")
# Out:
# === 20220317 ====
# === 20220630 ====
# === 20230117 ====
# === 20230118 ====
# === 20230119 ====
# === 20230202 ====

# %%
bigf = np.median(all_interpolated_spectra[1],axis=0)
smallf = np.median(all_interpolated_spectra[3],axis=0)

# %%
WL = np.arange(350,1050)

# %%
bigf.shape
# Out:
# (700,)

# %%
fig=plt.figure(figsize=(8,4))
ax=fig.add_subplot(1,1,1)             
ax.plot(WL,smallf/bigf,'b-')
ax.set_ylim(0,1)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("ratio")
ax.set_title("flux ratio (2023/01/18)/(2022/06/30)")
ax.grid()
