# %% [markdown]
# # Quick view of my images with bad WCS
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : 9 juin 2021
# - kernel : anaconda3_auxtel
# - update : July 22th 2021
# - update : September 6th 2021 : View QuickLookExp

# %% [markdown]
# # Selection Flag

# %%
from astropy.io import fits
import sys, platform, os
#from astropy.visualization import simple_norm
#from astropy.visualization import imshow_norm, MinMaxInterval, SqrtStretch
import astropy.visualization  as aspv
from astropy.wcs import WCS
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.colors import LogNorm

# %%
from astroquery.simbad import Simbad
from astropy.coordinates import SkyCoord
# Out:
# /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /sps/lsst/groups/auxtel/softs/utils/anaconda3/lib/python3.8/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes

# %%
plt.rcParams["axes.labelsize"]="large"
plt.rcParams["axes.linewidth"]=2.0
plt.rcParams["xtick.major.size"]=8
plt.rcParams["ytick.major.size"]=8
plt.rcParams["ytick.minor.size"]=5
plt.rcParams["xtick.labelsize"]="large"
plt.rcParams["ytick.labelsize"]="large"

plt.rcParams["figure.figsize"]=(12,12)
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.titleweight'] = 'bold'
#plt.rcParams['axes.facecolor'] = 'blue'
plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['lines.markeredgewidth'] = 0.3 # the line width around the marker symbol
plt.rcParams['lines.markersize'] = 5  # markersize, in points
plt.rcParams['grid.alpha'] = 0.75 # transparency, between 0.0 and 1.0
plt.rcParams['grid.linestyle'] = '-' # simple line
plt.rcParams['grid.linewidth'] = 0.4 # in points
plt.rcParams['font.size'] = 13

# %% [markdown]
# # Work

# %%
#intputdir_day_1="/sps/lsst/groups/auxtel/data/2021/holo/localreduced/2021-07-07/"   
intputdir_day_1="/sps/lsst/groups/auxtel/data/2021/holo/quickLookExp/2021-07-07/"   
list_of_files=os.listdir(intputdir_day_1)

# %%
print(list_of_files)
# Out:
# ['holo4_003_empty_HD160617_20210707_000272_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000280_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000291_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000299_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000255_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000262_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000358_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000290_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000287_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000253_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000364_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000357_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000319_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000259_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000360_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000324_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000276_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000348_quickLookExp.fits', 'holo4_003_RG610_HD160617_20210707_000237_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000325_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000277_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000292_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000334_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000288_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000356_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000254_quickLookExp.fits', 'holo4_003_RG610_HD160617_20210707_000247_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000293_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000359_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000341_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000330_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000248_quickLookExp.fits', 'holo4_003_RG610_HD160617_20210707_000243_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000281_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000261_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000300_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000349_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000309_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000265_quickLookExp.fits', 'holo4_003_RG610_HD160617_20210707_000236_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000322_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000266_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000263_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000249_quickLookExp.fits', 'holo4_003_RG610_HD160617_20210707_000238_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000298_quickLookExp.fits', 'holo4_003_RG610_HD160617_20210707_000306_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000343_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000318_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000252_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000305_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000284_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000321_quickLookExp.fits', 'holo4_003_RG610_HD160617_20210707_000244_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000326_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000302_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000264_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000289_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000347_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000342_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000361_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000363_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000317_quickLookExp.fits', 'holo4_003_empty_HD160617_20210707_000329_quickLookExp.fits', 'holo4_003_empty_HD160617_20210 ...

# %%
idx_file=30

# %%
fits_image_filename=list_of_files[idx_file]
full_fits_image_filename=os.path.join(intputdir_day_1,fits_image_filename)

# %%
fits_image_filename
# Out:
# 'holo4_003_empty_HD160617_20210707_000330_quickLookExp.fits'

# %%
hdul = fits.open(full_fits_image_filename)

# %%
hdul.info()
# Out:
# Filename: /sps/lsst/groups/auxtel/data/2021/holo/quickLookExp/2021-07-07/holo4_003_empty_HD160617_20210707_000330_quickLookExp.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  Segment10     1 PrimaryHDU     124   (4072, 4000)   float32

# %%
image=hdul[0].data
header=hdul[0].header

# %%
image.shape
# Out:
# (4000, 4072)

# %%
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(1,1,1)

ax.imshow(image,origin="lower",norm=LogNorm())

ax.minorticks_on()
ax.grid(color="k")
ax.set_title(fits_image_filename)
# Out:
# Text(0.5, 1.0, 'holo4_003_empty_HD160617_20210707_000330_quickLookExp.fits')

# %% [markdown]
# # Target

# %%
target_name="HD160617"

# %%
target_coord=SkyCoord.from_name(target_name)
target_coord
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (265.705515, -40.32097381)>

# %% [markdown]
# # View in WCS

# %%
fig=plt.figure(figsize=(12,12))
wcs = WCS(header)
ax = plt.subplot(projection = wcs)

ax.imshow(image ,origin="lower",norm=LogNorm())
ax.grid(color='white', ls='solid')

ax.set_xlabel('RA')
ax.set_ylabel('Dec')

#overlay = ax.get_coords_overlay('icrs')
#overlay.grid(color='blue', ls='dotted')
ax.set_title(fits_image_filename)
# Out:
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -70.749417 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -30.244639 from OBSGEO-[XYZ].
# Set OBSGEO-H to     2659.990 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Text(0.5, 1.0, 'holo4_003_empty_HD160617_20210707_000330_quickLookExp.fits')

# %%
wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 265.705514583333  -40.3209736111111
# CRPIX : 2000.0  2036.0
# CD1_1 CD1_2  : 0.0719009611125575  0.0765196170343952
# CD2_1 CD2_2  : -0.0765196170343952  0.0719009611125575
# NAXIS : 4072  4000

# %%
target_coord
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (265.705515, -40.32097381)>

# %%
x,y=wcs.world_to_pixel(target_coord)

# %%
print(x,y)
# Out:
# 1999.0000034521906 2035.000000907796

# %%
circle = plt.Circle((x, y), 50, color='r')

# %%
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(1,1,1)

ax.imshow(image,origin="lower",norm=LogNorm())
ax.add_patch(circle)
ax.minorticks_on()
ax.grid(color="k")
ax.set_title(fits_image_filename)
# Out:
# Text(0.5, 1.0, 'holo4_003_empty_HD160617_20210707_000330_quickLookExp.fits')
