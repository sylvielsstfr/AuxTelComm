# %% [markdown]
# # Build the logbook for Ronchi

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : November 22th 2021
# - Update :
#
# Works directory per directory (day by day)
#
# CCIN2P3:
#
# - works with kernels **anaconda3_auxtel** (with libradtran) at CC
# - works with kernel **python 3** locally

# %%
import sys
sys.path
# Out:
# ['/Users/dagoret/MacOSX/GitHub/LSST/AuxTelComm/notebookscc/ana_summer2021',
#  '/users/dagoret/anaconda3/lib/python38.zip',
#  '/users/dagoret/anaconda3/lib/python3.8',
#  '/users/dagoret/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/Spectractor-2.1-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/coveralls-3.2.0-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/astroquery-0.4.4.dev6955-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/docopt-0.6.2-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/mimeparse-0.1.3-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/staralt-0.0.1a0-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/rail-0.1.dev0-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/qp-0.5.dev10+gc04c254-py3.8.egg',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg',
#  '/Users/dagoret/anaconda3/lib/python3.8/site-packages',
#  '/users/dagoret/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/dagoret/.ipython']

# %%
#version="v3.0" # previous orientation
version="v4.0"  # new orientation

# %%
# reconstructed / good /xpos /ypos

if version == "v4.0":
    info={\

          # with red filter
          'ronchi170lpmm_empty_HD2811_20210909_000600_quickLookExp.fits':(1,1,400.,2400),\
          'ronchi170lpmm_empty_HD2811_20210909_000601_quickLookExp.fits':(1,1,400.,2400),\
          'ronchi170lpmm_empty_HD2811_20210909_000602_quickLookExp.fits':(1,1,300.,2300),\
          'ronchi170lpmm_empty_HD2811_20210909_000603_quickLookExp.fits':(1,1,300.,2300),\
          'ronchi170lpmm_empty_HD2811_20210909_000604_quickLookExp.fits':(1,1,300.,2300),\
          'ronchi170lpmm_empty_HD2811_20210909_000605_quickLookExp.fits':(1,1,300.,2300),\

           'ronchi170lpmm_empty_HD2811_20210909_000606_quickLookExp.fits':(1,1,300.,2300),\
           'ronchi170lpmm_empty_HD2811_20210909_000607_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000608_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000609_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000610_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000611_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000612_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000613_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000614_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000615_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000616_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000617_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000618_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000619_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000620_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000621_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000622_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000623_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000624_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000625_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000626_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000627_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000628_quickLookExp.fits':(1,1,300.,2300),\
            'ronchi170lpmm_empty_HD2811_20210909_000629_quickLookExp.fits':(1,1,300.,2300),\
          'holo4_003_empty_HD160617_20210707_000337_quickLookExp.fits':(1,1,300.,1600.)
                    
         }
else:
        
  
        
    info={\


 
          'holo4_003_empty_HD160617_20210707_000360_quickLookExp.fits':(1,1,0.,1800),\
          'holo4_003_empty_HD160617_20210707_000361_quickLookExp.fits':(1,1,0.,1900),\
          'holo4_003_empty_HD160617_20210707_000362_quickLookExp.fits':(1,1,0.,2100),\
          'holo4_003_empty_HD160617_20210707_000363_quickLookExp.fits':(1,1,0.,2200),\
          'holo4_003_empty_HD160617_20210707_000364_quickLookExp.fits':(1,1,0.,2300),\
          'holo4_003_empty_HD160617_20210707_000365_quickLookExp.fits':(1,1,0.,2300),\
         }

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
from astropy.io import fits

# %%
import imp
MODULE_EXTENSIONS = ('.py', '.pyc', '.pyo')

# %%
def package_contents(package_name):
    file, pathname, description = imp.find_module(package_name)
    if file:
        raise ImportError('Not a package: %r', package_name)
    # Use a set because some may be both source and compiled.
    return set([os.path.splitext(module)[0]
        for module in os.listdir(pathname)
        if module.endswith(MODULE_EXTENSIONS)])

# %%
package_contents("spectractor")
# Out:
# {'__init__',
#  '_version',
#  'astrometry',
#  'config',
#  'logbook',
#  'parameters',
#  'tools'}

# %%
package_contents("spectractor/extractor")
# Out:
# {'__init__',
#  'background',
#  'chromaticpsf',
#  'dispersers',
#  'extractor',
#  'images',
#  'psf',
#  'spectroscopy',
#  'spectrum',
#  'targets'}

# %% [markdown]
# # Initialisation

# %%
dir_logbooks="logbooks"

# %%
import os
if not os.path.exists(dir_logbooks):
    os.makedirs(dir_logbooks)

# %% [markdown]
# ## Get inputs files and sort them according date and number

# %%
FLAG_HOLO=False
home=os.getenv("HOME")

# %%
if FLAG_HOLO:
    image_path="holo"
    logbook_csv=os.path.join(dir_logbooks,"auxtelholologbook_2021_07_07_" + version + ".csv")
    logbook_xlsx=os.path.join(dir_logbooks,"auxtelholologbook_2021_07_07_" + version + ".xlsx")
else:
    image_path="ronchi170lpmm"
    logbook_csv=os.path.join(dir_logbooks,"auxtelronchilogbook_2021_09_09_" + version + ".csv")
    logbook_xlsx=os.path.join(dir_logbooks,"auxtelronchilogbook_2021_09_09_" + version + ".xlsx")

# %% [markdown]
# # Path

# %%
HOSTCC=False

# %%
if HOSTCC:
    path_auxtel="/sps/lsst/groups/auxtel"
    path_spectractor=os.path.join(path_auxtel,"softs/github/desc/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    #path_images=os.path.join(path_auxtel,"data/2021/holo/localreduced/2021-07-06")
    path_images=os.path.join(path_auxtel,"data/2021/holo/quickLookExp/2021-07-07")
else:
    path_auxtel="/Users/dagoret/DATA/AuxTelData2021"
    path_spectractor=os.path.join(path_auxtel,"/users/dagoret/softs/github/lsst/Spectractor")
    path_spectractor_config=os.path.join(path_spectractor,"config")
    #path_images=os.path.join(path_auxtel,"data/2021/holo/localreduced/2021-07-06")
    path_images=os.path.join(path_auxtel,"ronchi170lpmm/quickLookExp_v2/2021_09_09")

# %%
dir_images=path_images

# %%
all_files=os.listdir(dir_images)

# %%
all_files
# Out:
# ['ronchi170lpmm_empty_HD2811_20210909_000603_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000606_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000602_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000607_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000601_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000629_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000604_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000618_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000600_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000628_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000605_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000619_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000624_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000610_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000621_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000609_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000615_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000625_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000611_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000620_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000608_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000614_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000626_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000612_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000623_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000617_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000627_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000613_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000622_quickLookExp.fits',
#  'ronchi170lpmm_empty_HD2811_20210909_000616_quickLookExp.fits']

# %%
all_selected_files = []
for filename in all_files:
    if re.search(".fits$",filename):
        all_selected_files.append(filename)
N=len(all_selected_files)

# %%
all_selected_files=np.array(all_selected_files)

# %% [markdown]
# ### Sort files

# %%
def file_tag_forsorting(filename):
    #m=re.findall('^Cor_holo4_003_.*([0-9][0-9][0-9][0-9]-[0-9][0-9]-[0-9][0-9]_.*)[.]fits$',filename)
    m=re.findall('^ronchi170lpmm_.*_(.*)_quickLookExp[.]fits$',filename)
    
    return m[0]

# %%
file_tag_forsorting('ronchi170lpmm_empty_HD2811_20210909_000600_quickLookExp.fits')
# Out:
# '000600'

# %%
#all_tags = [ file_tag_forsorting(filename)[0] for filename in all_selected_files]
all_tags = [ file_tag_forsorting(filename) for filename in all_selected_files]
all_tags=np.array(all_tags)
all_tags
# Out:
# array(['000603', '000606', '000602', '000607', '000601', '000629',
#        '000604', '000618', '000600', '000628', '000605', '000619',
#        '000624', '000610', '000621', '000609', '000615', '000625',
#        '000611', '000620', '000608', '000614', '000626', '000612',
#        '000623', '000617', '000627', '000613', '000622', '000616'],
#       dtype='<U6')

# %%
indexes=np.argsort(all_tags)

# %%
sorted_files=all_selected_files[indexes]

# %%
sorted_files
# Out:
# array(['ronchi170lpmm_empty_HD2811_20210909_000600_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000601_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000602_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000603_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000604_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000605_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000606_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000607_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000608_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000609_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000610_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000611_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000612_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000613_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000614_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000615_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000616_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000617_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000618_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000619_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000620_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000621_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000622_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000623_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000624_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000625_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000626_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000627_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000628_quickLookExp.fits',
#        'ronchi170lpmm_empty_HD2811_20210909_000629_quickLookExp.fits'],
#       dtype='<U60')

# %%
N=len(sorted_files)

# %% [markdown]
# ### Filter bad files

# %%
idx=0
indexes_bad=[]
for filename in sorted_files:
    fullfilename=os.path.join(dir_images,filename)
    hdu = fits.open(fullfilename)
    hdu0=hdu[0]
    hdr0=hdu0.header
    #print(hdr0['OBJECT'],"\t",filename)
    if hdr0['OBJECT'] == '35 Tau' or hdr0['OBJECT'] == 'Park position':
        print('bad file ', filename)
        indexes_bad.append(idx)
        
    idx+=1

# %%
indexes_bad
# Out:
# []

# %% [markdown]
# ### Remove bad files

# %%
sorted_files=np.delete(sorted_files,indexes_bad)

# %% [markdown]
# ### Check for target

# %%
re.findall('^/ronchi170lpmm_.*_(.*)_[0-9][0-9][0-9][0-9][0-9][0-9][0-9][0-9]_.*_quickLookExp[.]fits$','holo4_003_RG610_HD120144_20210706_000098_quickLookExp.fits')
# Out:
# []

# %%
def file_target(filename):
    m=re.findall('^ronchi170lpmm_.*_(.*)_[0-9][0-9][0-9][0-9][0-9][0-9][0-9][0-9]_.*_quickLookExp[.]fits$',filename)
    if len(m)>0:
        return m
    elif re.search('NGC4755',filename):
        return ['NGC4755']
    else:
        return []

# %%
for filename in sorted_files:
    print(file_target(filename),"\t",filename)
# Out:
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000600_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000601_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000602_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000603_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000604_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000605_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000606_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000607_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000608_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000609_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000610_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000611_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000612_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000613_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000614_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000615_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000616_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000617_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000618_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000619_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000620_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000621_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000622_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000623_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000624_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000625_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000626_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000627_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000628_quickLookExp.fits
# ['HD2811'] 	 ronchi170lpmm_empty_HD2811_20210909_000629_quickLookExp.fits

# %%
idx=0
for filename in sorted_files:
    fullfilename=os.path.join(dir_images,filename)
    hdu = fits.open(fullfilename)
    hdu0=hdu[0]
    hdr0=hdu0.header
    #print(hdr0,"\t",filename)
        
    idx+=1

# %% [markdown]
# # Build the logbook from the headers

# %%
idx=0
#ccdir='/sps/lsst/groups/auxtel/data/2021/holo/FlipCleans'
ccdir=dir_images
all_dates=[]
all_files=[]
all_seqnum=[]
all_subdir=[]
all_indexes=[]
all_targets=[]
all_filters=[]
all_disperser=[]
all_airmass=[]
all_exposures=[]
all_focus=[]
all_seeing=[]
all_P=[]
all_T=[]
all_H=[]
all_W=[]
for filename in sorted_files:
    fullfilename=os.path.join(dir_images,filename)
    hdu = fits.open(fullfilename)
    hdu0=hdu[0]
    hdr0=hdu0.header 
    all_indexes.append(idx)
    all_seqnum.append(hdr0['SEQNUM'])
    all_files.append(filename)
    all_subdir.append(ccdir)
    targetname=file_target(filename)[0]
    all_targets.append(targetname)
    all_dates.append(hdr0['DATE-OBS'])
    all_airmass.append(hdr0['AMSTART'])
    all_filters.append(hdr0['FILTER'])
    all_disperser.append(hdr0['GRATING'])
    all_exposures.append(hdr0['EXPTIME'])
    all_focus.append(hdr0['FOCUSZ'])
    all_seeing.append(hdr0['SEEING'])
    all_P.append(hdr0['PRESSURE'])
    all_T.append(hdr0['AIRTEMP'])
    all_H.append(hdr0['HUMIDITY'])
    all_W.append(hdr0['WINDSPD'])
       
    
    idx+=1

# %% [markdown]
# # Make pandas dataframe

# %% [markdown]
# ## Create pandas dataframe

# %%
df=pd.DataFrame()

# %%
len(all_airmass)
# Out:
# 30

# %%
N=len(all_indexes)

# %% [markdown]
# ## Fill with container info

# %%
df['index']=all_indexes
df['date']=all_dates
df['path']=all_subdir
df['file']=all_files
df['num']=all_seqnum
df['object']=all_targets
df['filter']=all_filters
df['disperser']=all_disperser
df['airmass']=all_airmass
df['exposure']=all_exposures
df['focus']=all_focus
df['seeing']=all_seeing
df['pressure']=all_P
df['temperature']=all_T
df['humidity']=all_H
df['windspd']=all_W

# %% [markdown]
# ## Add dictionnary info

# %% [markdown]
# ### Initialise new columns

# %%
Obj_posXpix=np.full(N,np.nan)
Obj_posYpix=np.full(N,np.nan)
Dx=np.full(N,np.nan)
Dy=np.full(N,np.nan)
run=np.full(N,np.nan)
quality=np.full(N,np.nan)
skip=np.full(N,"    ")

# %% [markdown]
# ### Fill dictionnary info

# %%
# loop on rows index
for idx in np.arange(N):
    filename=all_files[idx]
    # check if filename is in dictionnary
    if filename in info.keys():
        (run_flag,quality_flag,xpos,ypos)=info[filename]
        Obj_posXpix[idx]=int(xpos)
        Obj_posYpix[idx]=int(ypos)
        run[idx]=run_flag
        if quality_flag==1:
            skip[idx] = "    "
            quality[idx]=1
        else:
            skip[idx] = "skip"
            quality[idx]=0

# %%
df['Obj-posXpix']=Obj_posXpix
df['Obj-posYpix']=Obj_posYpix
df['Dx']=Dx
df['Dy']=Dy
df['skip']=skip
df['run']=run
df['quality']=quality

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#     index                     date  \
# 0       0  2021-09-10T06:15:30.580
# 1       1  2021-09-10T06:15:34.147
# 2       2  2021-09-10T06:15:37.709
# 3       3  2021-09-10T06:15:41.301
# 4       4  2021-09-10T06:15:44.871
# 5       5  2021-09-10T06:15:48.436
# 6       6  2021-09-10T06:15:51.992
# 7       7  2021-09-10T06:15:55.562
# 8       8  2021-09-10T06:15:59.140
# 9       9  2021-09-10T06:16:02.722
# 10     10  2021-09-10T06:16:06.298
# 11     11  2021-09-10T06:16:09.872
# 12     12  2021-09-10T06:16:13.439
# 13     13  2021-09-10T06:16:17.018
# 14     14  2021-09-10T06:16:20.576
# 15     15  2021-09-10T06:16:24.155
# 16     16  2021-09-10T06:16:27.722
# 17     17  2021-09-10T06:16:31.288
# 18     18  2021-09-10T06:16:34.861
# 19     19  2021-09-10T06:16:38.422
# 20     20  2021-09-10T06:16:42.003
# 21     21  2021-09-10T06:16:45.593
# 22     22  2021-09-10T06:16:49.169
# 23     23  2021-09-10T06:16:52.744
# 24     24  2021-09-10T06:16:56.302
# 25     25  2021-09-10T06:16:59.883
# 26     26  2021-09-10T06:17:03.511
# 27     27  2021-09-10T06:17:07.098
# 28     28  2021-09-10T06:17:10.663
# 29     29  2021-09-10T06:17:14.230
#
#                                                  path  \
# 0   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 1   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 2   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 3   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 4   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 5   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 6   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 7   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 8   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 9   /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 10  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 11  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 12  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 13  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 14  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 15  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 16  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 17  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 18  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 19  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 20  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 21  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 22  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 23  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 24  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 25  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 26  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 27  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 28  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
# 29  /Users/dagoret/DATA/AuxTelData2021/ronchi170lp...
#
#                                                  file  num  object   filter  \
# 0   ronchi170lpmm_empty_HD2811_20210909_000600_qui...  600  HD2811  empty_1
# 1   ronchi170lpmm_empty_HD2811_20210909_000601_qui...  601  HD2811  empty_1
# 2   ronchi170lpmm_empty_HD2811_20210909_000602_qui...  602  HD2811  empty_1
# 3   ronchi170lpmm_empty_HD2811_20210909_000603_qui...  603  HD2811  empty_1
# 4   ronchi170lpmm_empty_HD2811_20210909_000604_qui...  604  HD2811  empty_1
# 5   ronchi170lpmm_empty_HD2811_20210909_000605_qui...  605  HD2811  empty_1
# 6   ronchi170lpmm_empty_HD2811_20210909_000606_qui...  606  HD2811  empty_1
# 7   ronchi170lpmm_empty_HD2811_20210909_000607_qui...  607  HD2811  empty_1
# 8   ronchi170lpmm_empty_HD2811_20210909_000608_qui...  608  HD2811  empty_1
# 9   ronchi170lpmm_empty_HD2811_20210909_000609_qui...  609  HD2811  empty_1
# 10  ronchi170lpmm_empty_HD2811_20210909_000610_qui...  610  HD2811  empty_1
# 11  ronchi170lpmm_empty_HD2811_20210909_000611_qui...  611  HD2811  empty_1
# 12  ronchi170lpmm_empty_HD2811_20210909_000612_qui...  612  HD2811  empty_1
# 13  ronchi170lpmm_empty_HD2811_20210909_000613_qui...  613  HD2811  empty_1
# 14  ronchi170lpmm_empty_HD2811_20210909_000614_qui...  614  HD2811  empty_1
# 15  ronchi170lpmm_empty_HD2811_20210909_000615_qui...  615  HD2811  empty_1
# 16  ronchi170lpmm_empty_HD2811_20210909_000616_qui...  616  HD2811  empty_1
# 17  ronchi170lpmm_empty_HD2811_20210909_000617_qui...  617  HD2811  empty_1
# 18  ronchi170lpmm_empty_HD2811_20210909_000618_qui...  618  HD2811  empty_1
# 19  ronchi170lpmm_empty_HD2811_20210909_000619_qui...  619  HD2811  empty_1
# 20  ronchi170lpmm_empty_HD2811_20210909_000620_qui...  620  HD2811  empty_1
# 21  ronchi170lpmm_empty_HD2811_20210909_000621_qui...  621  HD2811  empty_1
# 22  ronchi170lpmm_empty_HD2811_20210909_000622_qui...  622  HD2811  empty_1
# 23  ronchi170lpmm_empty_HD2811_20210909_000623_qui...  623  HD2811  empty_1
# 24  ronchi170lpmm_empty_HD2811_20210909_000624_qui...  624  HD2811  empty_1
# 25  ronchi170lpmm_empty_HD2811_20210909_000625_qui...  625  HD2811  empty_1
# 26  ronchi170lpmm_empty_HD2811_20210909_000626_qui...  626  HD2811  empty_1
# 27  ronchi170lpmm_empty_HD2811_20210909_000627_qui...  627  HD2811  empty_1
# 28  ronchi170lpmm_empty_HD2811_20210909_000628_qui...  628  HD2811  empty_1
# 29  ronchi170lpmm_empty_HD2811_20210909_000629_qui...  629  HD2811  empty_1
#
#         disperser   airmass  exposure  ...  temperature  humidity  windspd  \
# 0   ronchi170lpmm  1.028983       1.0  ...          9.0      18.0      9.1
# 1   ronchi170lpmm  1.028996       1.0  ...          9.0      18.0      9.1
# 2   ronchi170lpmm  1.029009       1.0  ...          9.0      18.0      9.1
# 3   ronchi170lpmm  1.029022       1.0  ...          9.0      18.0      9.1
# 4   ronchi170lpmm  1.029036       1.0  ...          9.0      18.0      9.1
# 5   ronchi170lpmm  1.029049       1.0  ...          9.0      18.0      9.1
# 6   ronchi170lpmm  1.029063       1.0  ...          9.0      18.0      9.1
# 7   ronchi170lpmm  1.029077       1.0  ...          9.0      18.0      9.1
# 8   ronchi170lpmm  1.029090       1.0  ...          9.0      18.0      9.1
# 9   ronchi170lpmm  1.029104       1.0  ...          9.0      18.0      9.1
# 10  ronchi170lpmm  1.029117       1.0  ...          9.0      18.0      9.1
# 11  ronchi170lpmm  1.029131       1.0  ...          9.0      18.0      8.3
# 12  ronchi170lpmm  1.029145       1.0  ...          9.0      18.0      8.3
# 13  ronchi170lpmm  1.029159       1.0  ...          9.0      18.0      8.3
# 14  ronchi170lpmm  1.029173       1.0  ...          9.0      18.0      8.3
# 15  ronchi170lpmm  1.029187       1.0  ...          9.0      18.0      8.3
# 16  ronchi170lpmm  1.029200       1.0  ...          9.0      18.0      8.3
# 17  ronchi170lpmm  1.029214       1.0  ...          9.0      18.0      8.3
# 18  ronchi170lpmm  1.029228       1.0  ...          9.0      18.0      8.3
# 19  ronchi170lpmm  1.029242       1.0  ...          9.0      18.0      8.3
# 20  ronchi170lpmm  1.029257       1.0  ...          9.0      18.0      8.3
# 21  ronchi170lpmm  1.029271       1.0  ...          9.0      18.0      8.3
# 22  ronchi170lpmm  1.029285       1.0  ...          9.0      18.0      8.3
# 23  ronchi170lpmm  1.029300       1.0  ...          9.0      18.0      8.3
# 24  ronchi170lpmm  1.029313       1.0  ...          9.0      18.0      8.3
# 25  ronchi170lpmm  1.029328       1.0  ...          9.0      18.0      8.3
# 26  ronchi170lpmm  1.029342       1.0  ...          9.0      18.0      8.3
# 27  ronchi170lpmm  1.029357       1.0  ...          9.0      18.0      9.1
# 28  ronchi170lpmm  1.029371       1.0  ...          9.0      18.0      9.1
# 29  ronchi170lpmm  1.029386       1.0  ...          9.0      18.0      9.1
#
#     Obj-posXpix  Obj-posYpix  Dx  Dy  skip  run  quality
# 0         400.0       2400.0 NaN NaN        1.0      1.0
# 1         400.0       2400.0 NaN NaN        1.0      1.0
# 2         300.0       2300.0 NaN NaN        1.0      1.0
# 3         300.0       2300.0 NaN NaN        1.0      1.0
# 4         300.0       2300.0 NaN NaN        1.0      1.0
# 5         300.0       2300.0 NaN NaN        1.0      1.0
# 6         300.0       2300.0 NaN NaN        1.0      1.0
# 7         300.0       2300.0 NaN NaN        1.0      1.0
# 8         300.0       2300.0 NaN NaN        1.0      1.0
# 9         300.0       2300.0 NaN NaN        1.0      1.0
# 10        300.0       2300.0 NaN NaN        1.0      1.0
# 11        300.0       2300.0 NaN NaN        1.0      1.0
# 12        300.0       2300.0 NaN NaN        1.0      1.0
# 13        300.0       2300.0 NaN NaN        1.0      1.0
# 14        300.0       2300.0 NaN NaN        1.0      1.0
# 15        300.0       2300.0 NaN NaN        1.0      1.0
# 16        300.0       2300.0 NaN NaN        1.0      1.0
# 17        300.0       2300.0 NaN NaN        1.0      1.0
# 18        300.0       2300.0 NaN NaN        1.0      1.0
# 19        300.0       2300.0 NaN NaN        1.0      1.0
# 20        300.0       2300.0 NaN NaN        1.0      1.0
# 21        300.0       2300.0 NaN NaN        1.0      1.0
# 22        300.0       2300.0 NaN NaN        1.0      1.0
# 23        300.0       2300.0 NaN NaN        1.0      1.0
# 24        300.0       2300.0 NaN NaN        1.0      1.0
# 25        300.0       2300.0 NaN NaN        1.0      1.0
# 26        300.0       2300.0 NaN NaN        1.0      1.0
# 27        300.0       2300.0 NaN NaN        1.0      1.0
# 28        300.0       2300.0 NaN NaN        1.0      1.0
# 29        300.0       2300.0 NaN NaN        1.0      1.0
#
# [30 rows x 23 columns]

# %% [markdown]
# # Make logbook

# %%
df.to_excel(logbook_xlsx)
df.to_csv(logbook_csv)

# %%
logbook_csv
# Out:
# 'logbooks/auxtelronchilogbook_2021_09_09_v4.0.csv'
