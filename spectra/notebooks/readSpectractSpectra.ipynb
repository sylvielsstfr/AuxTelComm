# %% [markdown]
# # Study spectra

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNES, DESC-LSST fullmember, behalf AuxTel Teal VERA C. Rubin observatory
# - creation date : March 29th 2021
# - version
#
#
# Spectra reconstructed by Jeremy

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd

import matplotlib.ticker                         # here's where the formatter is
import os
import re

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
import imp
MODULE_EXTENSIONS = ('.py', '.pyc', '.pyo')

# %%
def package_contents(package_name):
    file, pathname, description = imp.find_module(package_name)
    if file:
        raise ImportError('Not a package: %r', package_name)
    # Use a set because some may be both source and compiled.
    return set([os.path.splitext(module)[0]
        for module in os.listdir(pathname)
        if module.endswith(MODULE_EXTENSIONS)])

# %%
package_contents("spectractor")
# Out:
# {'__init__',
#  '_version',
#  'astrometry',
#  'config',
#  'logbook',
#  'parameters',
#  'tools'}

# %%
package_contents("spectractor/extractor")
# Out:
# {'__init__',
#  'background',
#  'chromaticpsf',
#  'dispersers',
#  'extractor',
#  'images',
#  'psf',
#  'spectroscopy',
#  'spectrum',
#  'targets'}

# %%
from spectractor.extractor.spectrum import Spectrum
from spectractor.config import load_config
from spectractor import parameters

# %% [markdown]
# # Configuration

# %%
dir_spectra="/Users/dagoret/DATA/AuxTelData2021/holo/SpectractorQuickLook/FlipCleans"
dir_spectra_model="/Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans"

# %%
parameters.DISPLAY=False

# %% [markdown]
# # Find spectra files

# %%
all_files=os.listdir(dir_spectra)
all_files_model=os.listdir(dir_spectra_model)

# %%
all_spectra_files = []
for filename in all_files:
    if re.search("_spectrum.fits$",filename):
        all_spectra_files.append(filename)
N=len(all_spectra_files)

# %%
N
# Out:
# 39

# %%
all_spectra_files_model = []
for filename in all_files_model:
    if re.search("_spectrum.fits$",filename):
        all_spectra_files_model.append(filename)
N1=len(all_spectra_files_model)

# %%
N1
# Out:
# 37

# %%
for filename in all_spectra_files:
    if filename in all_spectra_files_model:
        print("found {}".format(filename))
    else:
        print("NOT found {}".format(filename))
# Out:
# found Cor_holo4_003_NGC4755_2021-02-17_357_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_353_spectrum.fits
# found Cor_holo4_003_RG610_HD60753_2021-02-18_564_spectrum.fits
# found Cor_holo4_003_RG610_HD60753_2021-02-18_560_spectrum.fits
# found Cor_holo4_003_RG610_HD60753_2021-02-18_559_spectrum.fits
# NOT found Cor_holo4_003_empty_HD60753_2021-02-18_578_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_568_spectrum.fits
# found Cor_holo4_003_RG610_HD60753_2021-02-18_563_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_354_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_350_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_585_spectrum.fits
# NOT found Cor_holo4_003_empty_HD60753_2021-02-18_581_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_566_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_575_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_572_spectrum.fits
# NOT found Cor_holo4_003_RG610_HD60753_2021-02-18_557_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_576_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_586_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_582_spectrum.fits
# found Cor_holo4_003_empty_HD50896_2021-02-16_209_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_577_spectrum.fits
# found Cor_holo4_003_RG610_HD60753_2021-02-18_556_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_573_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_583_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_358_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_587_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_580_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_584_spectrum.fits
# NOT found Cor_holo4_003_empty_HD60753_2021-02-18_574_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_567_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_569_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_351_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_355_spectrum.fits
# found Cor_holo4_003_RG610_HD50896_2021-02-16_181_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_352_spectrum.fits
# found Cor_holo4_003_NGC4755_2021-02-17_356_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_579_spectrum.fits
# NOT found Cor_holo4_003_RG610_HD60753_2021-02-18_558_spectrum.fits
# found Cor_holo4_003_RG610_HD60753_2021-02-18_561_spectrum.fits

# %% [markdown]
# # Plots

# %%
for filename in all_spectra_files:
    fig, axes  = plt.subplots(1, 2)
    fullfilename = os.path.join(dir_spectra,filename)
    
    s=Spectrum(fullfilename, config="config/auxtel_quicklook.ini")
    s.plot_spectrum(ax=axes[0],force_lines=True)
    axes[0].set_title(filename)
    
    if filename in all_spectra_files_model:
        print("found {}".format(filename))
        fullfilename2 = os.path.join(dir_spectra_model,filename)
        print(fullfilename2)
        s2=Spectrum(fullfilename2, config="config/auxtel_quicklook.ini")
        
        print(s2.target.label)
        s2.plot_spectrum(ax=axes[1],force_lines=False)
        axes[1].set_title(filename)
    else:
        print("NOT found {}".format(filename))
    
    plt.show()
# Out:
# found Cor_holo4_003_NGC4755_2021-02-17_357_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_357_spectrum.fits
# NGC4755
# found Cor_holo4_003_NGC4755_2021-02-17_353_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_353_spectrum.fits
# NGC4755
# found Cor_holo4_003_RG610_HD60753_2021-02-18_564_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_RG610_HD60753_2021-02-18_564_spectrum.fits
# HD60753
# found Cor_holo4_003_RG610_HD60753_2021-02-18_560_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_RG610_HD60753_2021-02-18_560_spectrum.fits
# HD60753
# found Cor_holo4_003_RG610_HD60753_2021-02-18_559_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_RG610_HD60753_2021-02-18_559_spectrum.fits
# HD60753
# NOT found Cor_holo4_003_empty_HD60753_2021-02-18_578_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_568_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_568_spectrum.fits
# HD60753
# found Cor_holo4_003_RG610_HD60753_2021-02-18_563_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_RG610_HD60753_2021-02-18_563_spectrum.fits
# HD60753
# found Cor_holo4_003_NGC4755_2021-02-17_354_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_354_spectrum.fits
# NGC4755
# found Cor_holo4_003_NGC4755_2021-02-17_350_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_350_spectrum.fits
# NGC4755
# found Cor_holo4_003_empty_HD60753_2021-02-18_585_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_585_spectrum.fits
# HD60753
# NOT found Cor_holo4_003_empty_HD60753_2021-02-18_581_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_566_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_566_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_575_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_575_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_572_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_572_spectrum.fits
# HD60753
# NOT found Cor_holo4_003_RG610_HD60753_2021-02-18_557_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_576_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_576_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_586_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_586_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_582_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_582_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD50896_2021-02-16_209_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD50896_2021-02-16_209_spectrum.fits
# HD50896
# found Cor_holo4_003_empty_HD60753_2021-02-18_577_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_577_spectrum.fits
# HD60753
# found Cor_holo4_003_RG610_HD60753_2021-02-18_556_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_RG610_HD60753_2021-02-18_556_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_573_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_573_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_583_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_583_spectrum.fits
# HD60753
# found Cor_holo4_003_NGC4755_2021-02-17_358_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_358_spectrum.fits
# NGC4755
# found Cor_holo4_003_empty_HD60753_2021-02-18_587_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_587_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_580_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_580_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_584_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_584_spectrum.fits
# HD60753
# NOT found Cor_holo4_003_empty_HD60753_2021-02-18_574_spectrum.fits
# found Cor_holo4_003_empty_HD60753_2021-02-18_567_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_567_spectrum.fits
# HD60753
# found Cor_holo4_003_empty_HD60753_2021-02-18_569_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_569_spectrum.fits
# HD60753
# found Cor_holo4_003_NGC4755_2021-02-17_351_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_351_spectrum.fits
# NGC4755
# found Cor_holo4_003_NGC4755_2021-02-17_355_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_355_spectrum.fits
# NGC4755
# found Cor_holo4_003_RG610_HD50896_2021-02-16_181_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_RG610_HD50896_2021-02-16_181_spectrum.fits
# HD50896
# found Cor_holo4_003_NGC4755_2021-02-17_352_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_352_spectrum.fits
# NGC4755
# found Cor_holo4_003_NGC4755_2021-02-17_356_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_NGC4755_2021-02-17_356_spectrum.fits
# NGC4755
# found Cor_holo4_003_empty_HD60753_2021-02-18_579_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_empty_HD60753_2021-02-18_579_spectrum.fits
# HD60753
# NOT found Cor_holo4_003_RG610_HD60753_2021-02-18_558_spectrum.fits
# found Cor_holo4_003_RG610_HD60753_2021-02-18_561_spectrum.fits
# /Users/dagoret/DATA/AuxTelData2021/holo/SpectractorForwardModel/FlipCleans/Cor_holo4_003_RG610_HD60753_2021-02-18_561_spectrum.fits
# HD60753
